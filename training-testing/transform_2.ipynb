# %%
"""
Cambios en la arquitectura de la red neuronal convolucional

    - Cambio de tamaño de kernel de 5x5 a 3x3
    - Modificacion de funcion de optimizacion, se agrego regularizacion L2
    - Se cambio el valor de 0.5 a 0.8 en randomVerticalFlip y randomHorizontalFlip
"""

# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %%
# --> Definir si viene desde local o drive

ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')
train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))       # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')                         # Quitar los ejes
    plt.show()

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        """
        Las convoluciones más pequeñas, como de tamaño 3x3, son útiles para capturar características más detalladas.
        Al combinar capas de convoluciones más pequeñas (en lugar de kernels grandes como 5x5), el modelo puede aprender
        mejor características complejas a través de múltiples capas.
        """
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),   # Convolución más pequeña
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # Pooling
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=3, padding=1),           # Otra convolución 3x3
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(),                                           # Dropout para regularización

            nn.Conv2d(128, 128, kernel_size=3, padding=1),          # Convolución 3x3 más profunda
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(128, 64, kernel_size=3, padding=1),           # Última convolución 3x3
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(37440, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 64*24*24)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            # Valores a proar: 0.05, 0.01, 0.001
            l2_lambda = 0.001 
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones
data1 = CustomImageDataset(df=train)

# Dataset con transformación de normalización
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desplazamiento de canales y normalización
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),    # Cambiar los canales RGB a BGR
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                        # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                         # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo horizontal y normalización
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.8),            # Girar horizontalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo vertical y normalización
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=0.8),              # Girar verticalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desenfoque gaussiano y normalización
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Imagen Original', 'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    if i == 1:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}")
    else:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data1, data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 2597 Val: 289

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data1, data2, data3, data4, data5, data6

# %%
# --> Crear los dataloaders
batch_size_train = 53
batch_size_val = 17
# batch_size=64

train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True, drop_last=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 2597 - Baches 49
# Muestras de test: 289 - Baches 17

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
# optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda

# %%
# Entrenamiento
n_epochs = 165
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 93, Batch 45/49, Batch Loss: 73973.4141
# Epoch 93, Batch 46/49, Batch Loss: 60191.8867
# Epoch 93, Batch 47/49, Batch Loss: 95038.3359
# Epoch 93, Batch 48/49, Batch Loss: 84171.6094
# Epoch 93, Batch 49/49, Batch Loss: 76853.6172
# Batch 1/17, Batch Loss: 57726.7148
# Batch 2/17, Batch Loss: 283421.8438
# Batch 3/17, Batch Loss: 229855.7344
# Batch 4/17, Batch Loss: 139979.7500
# Batch 5/17, Batch Loss: 289539.7500
# Batch 6/17, Batch Loss: 345484.1875
# Batch 7/17, Batch Loss: 191412.9844
# Batch 8/17, Batch Loss: 243972.9219
# Batch 9/17, Batch Loss: 314835.2812
# Batch 10/17, Batch Loss: 140628.9531
# Batch 11/17, Batch Loss: 233211.3906
# Batch 12/17, Batch Loss: 168594.9062
# Batch 13/17, Batch Loss: 173655.7344
# Batch 14/17, Batch Loss: 219201.8750
# Batch 15/17, Batch Loss: 166252.0938
# Batch 16/17, Batch Loss: 293955.8750
# Batch 17/17, Batch Loss: 131725.1562
# Test Error:
#  Avg loss: 213144.420726, Avg error: 136201.272275
#
# Epoch 94, Batch 1/49, Batch Loss: 68720.5078
# Epoch 94, Batch 2/49, Batch Loss: 68659.4453
# Epoch 94, Batch 3/49, Batch Loss: 72552.7969
# Epoch 94, Batch 4/49, Batch Loss: 102994.5938
# Epoch 94, Batch 5/49, Batch Loss: 83937.3047
# Epoch 94, Batch 6/49, Batch Loss: 121583.2500
# Epoch 94, Batch 7/49, Batch Loss: 83147.0312
# Epoch 94, Batch 8/49, Batch Loss: 106714.3359
# Epoch 94, Batch 9/49, Batch Loss: 66374.2109
# Epoch 94, Batch 10/49, Batch Loss: 77975.3047
# Epoch 94, Batch 11/49, Batch Loss: 72492.2578
# Epoch 94, Batch 12/49, Batch Loss: 70762.9219
# Epoch 94, Batch 13/49, Batch Loss: 81234.7656
# Epoch 94, Batch 14/49, Batch Loss: 84369.7734
# Epoch 94, Batch 15/49, Batch Loss: 78855.5469
# Epoch 94, Batch 16/49, Batch Loss: 60319.2656
# Epoch 94, Batch 17/49, Batch Loss: 84845.0156
# Epoch 94, Batch 18/49, Batch Loss: 79986.2344
# Epoch 94, Batch 19/49, Batch Loss: 104004.6406
# Epoch 94, Batch 20/49, Batch Loss: 64033.1016
# Epoch 94, Batch 21/49, Batch Loss: 59280.4414
# Epoch 94, Batch 22/49, Batch Loss: 80682.5625
# Epoch 94, Batch 23/49, Batch Loss: 78678.1641
# Epoch 94, Batch 24/49, Batch Loss: 59931.0469
# Epoch 94, Batch 25/49, Batch Loss: 97865.8359
# Epoch 94, Batch 26/49, Batch Loss: 52249.8242
# Epoch 94, Batch 27/49, Batch Loss: 84516.2109
# Epoch 94, Batch 28/49, Batch Loss: 69114.3047
# Epoch 94, Batch 29/49, Batch Loss: 55214.9648
# Epoch 94, Batch 30/49, Batch Loss: 162402.2969
# Epoch 94, Batch 31/49, Batch Loss: 60278.1758
# Epoch 94, Batch 32/49, Batch Loss: 84280.4453
# Epoch 94, Batch 33/49, Batch Loss: 63359.4531
# Epoch 94, Batch 34/49, Batch Loss: 75723.7188
# Epoch 94, Batch 35/49, Batch Loss: 53284.0898
# Epoch 94, Batch 36/49, Batch Loss: 89456.6328
# Epoch 94, Batch 37/49, Batch Loss: 85437.0391
# Epoch 94, Batch 38/49, Batch Loss: 70255.4297
# Epoch 94, Batch 39/49, Batch Loss: 86723.2656
# Epoch 94, Batch 40/49, Batch Loss: 80713.6484
# Epoch 94, Batch 41/49, Batch Loss: 89868.0312
# Epoch 94, Batch 42/49, Batch Loss: 66269.8594
# Epoch 94, Batch 43/49, Batch Loss: 86352.9609
# Epoch 94, Batch 44/49, Batch Loss: 66299.3281
# Epoch 94, Batch 45/49, Batch Loss: 71451.7891
# Epoch 94, Batch 46/49, Batch Loss: 74011.7578
# Epoch 94, Batch 47/49, Batch Loss: 95417.9531
# Epoch 94, Batch 48/49, Batch Loss: 72212.8594
# Epoch 94, Batch 49/49, Batch Loss: 83236.2422
# Batch 1/17, Batch Loss: 99077.7734
# Batch 2/17, Batch Loss: 295392.2812
# Batch 3/17, Batch Loss: 246063.6406
# Batch 4/17, Batch Loss: 135037.6406
# Batch 5/17, Batch Loss: 340749.8125
# Batch 6/17, Batch Loss: 347859.5625
# Batch 7/17, Batch Loss: 182448.8281
# Batch 8/17, Batch Loss: 242124.1250
# Batch 9/17, Batch Loss: 315216.3438
# Batch 10/17, Batch Loss: 191196.9688
# Batch 11/17, Batch Loss: 259519.8438
# Batch 12/17, Batch Loss: 172439.4531
# Batch 13/17, Batch Loss: 174507.8594
# Batch 14/17, Batch Loss: 347570.0312
# Batch 15/17, Batch Loss: 172792.4531
# Batch 16/17, Batch Loss: 256885.6406
# Batch 17/17, Batch Loss: 165199.2969
# Test Error:
#  Avg loss: 232004.797335, Avg error: 157411.190744
#
# Epoch 95, Batch 1/49, Batch Loss: 56864.8789
# Epoch 95, Batch 2/49, Batch Loss: 80329.8047
# Epoch 95, Batch 3/49, Batch Loss: 84602.2266
# Epoch 95, Batch 4/49, Batch Loss: 60244.9883
# Epoch 95, Batch 5/49, Batch Loss: 55055.9609
# Epoch 95, Batch 6/49, Batch Loss: 88760.7109
# Epoch 95, Batch 7/49, Batch Loss: 148086.1875
# Epoch 95, Batch 8/49, Batch Loss: 120111.1406
# Epoch 95, Batch 9/49, Batch Loss: 54046.5156
# Epoch 95, Batch 10/49, Batch Loss: 65375.0273
# Epoch 95, Batch 11/49, Batch Loss: 71469.1797
# Epoch 95, Batch 12/49, Batch Loss: 86592.9844
# Epoch 95, Batch 13/49, Batch Loss: 86178.2188
# Epoch 95, Batch 14/49, Batch Loss: 77846.1406
# Epoch 95, Batch 15/49, Batch Loss: 78482.0000
# Epoch 95, Batch 16/49, Batch Loss: 73451.8359
# Epoch 95, Batch 17/49, Batch Loss: 72736.5391
# Epoch 95, Batch 18/49, Batch Loss: 83683.8047
# Epoch 95, Batch 19/49, Batch Loss: 84476.2266
# Epoch 95, Batch 20/49, Batch Loss: 84715.7031
# Epoch 95, Batch 21/49, Batch Loss: 172992.9844
# Epoch 95, Batch 22/49, Batch Loss: 63646.5859
# Epoch 95, Batch 23/49, Batch Loss: 88411.9766
# Epoch 95, Batch 24/49, Batch Loss: 68043.5547
# Epoch 95, Batch 25/49, Batch Loss: 63484.2109
# Epoch 95, Batch 26/49, Batch Loss: 64376.6328
# Epoch 95, Batch 27/49, Batch Loss: 63228.0938
# Epoch 95, Batch 28/49, Batch Loss: 73795.1562
# Epoch 95, Batch 29/49, Batch Loss: 163125.5000
# Epoch 95, Batch 30/49, Batch Loss: 86665.7344
# Epoch 95, Batch 31/49, Batch Loss: 87036.0078
# Epoch 95, Batch 32/49, Batch Loss: 78772.2031
# Epoch 95, Batch 33/49, Batch Loss: 80788.7344
# Epoch 95, Batch 34/49, Batch Loss: 69337.1094
# Epoch 95, Batch 35/49, Batch Loss: 77562.7969
# Epoch 95, Batch 36/49, Batch Loss: 71855.5391
# Epoch 95, Batch 37/49, Batch Loss: 61125.0430
# Epoch 95, Batch 38/49, Batch Loss: 140226.6250
# Epoch 95, Batch 39/49, Batch Loss: 103824.5000
# Epoch 95, Batch 40/49, Batch Loss: 74642.4375
# Epoch 95, Batch 41/49, Batch Loss: 65534.8320
# Epoch 95, Batch 42/49, Batch Loss: 68630.5156
# Epoch 95, Batch 43/49, Batch Loss: 64075.8477
# Epoch 95, Batch 44/49, Batch Loss: 91667.6328
# Epoch 95, Batch 45/49, Batch Loss: 67353.9453
# Epoch 95, Batch 46/49, Batch Loss: 63685.5820
# Epoch 95, Batch 47/49, Batch Loss: 67687.5234
# Epoch 95, Batch 48/49, Batch Loss: 63695.4883
# Epoch 95, Batch 49/49, Batch Loss: 66172.3281
# Batch 1/17, Batch Loss: 84358.3594
# Batch 2/17, Batch Loss: 316243.4375
# Batch 3/17, Batch Loss: 244820.3438
# Batch 4/17, Batch Loss: 105351.7344
# Batch 5/17, Batch Loss: 291609.0625
# Batch 6/17, Batch Loss: 344601.7812
# Batch 7/17, Batch Loss: 166640.1250
# Batch 8/17, Batch Loss: 251904.4375
# Batch 9/17, Batch Loss: 332499.5625
# Batch 10/17, Batch Loss: 193327.4531
# Batch 11/17, Batch Loss: 284848.9062
# Batch 12/17, Batch Loss: 177446.9688
# Batch 13/17, Batch Loss: 192991.7344
# Batch 14/17, Batch Loss: 259495.3594
# Batch 15/17, Batch Loss: 193653.7031
# Batch 16/17, Batch Loss: 319036.5625
# Batch 17/17, Batch Loss: 155065.4062
# Test Error:
#  Avg loss: 230229.113971, Avg error: 157888.194637
#
# Epoch 96, Batch 1/49, Batch Loss: 75162.6953
# Epoch 96, Batch 2/49, Batch Loss: 70363.4062
# Epoch 96, Batch 3/49, Batch Loss: 141530.2188
# Epoch 96, Batch 4/49, Batch Loss: 92768.6094
# Epoch 96, Batch 5/49, Batch Loss: 82978.5156
# Epoch 96, Batch 6/49, Batch Loss: 118262.7578
# Epoch 96, Batch 7/49, Batch Loss: 121059.5078
# Epoch 96, Batch 8/49, Batch Loss: 115134.8281
# Epoch 96, Batch 9/49, Batch Loss: 116209.3359
# Epoch 96, Batch 10/49, Batch Loss: 117699.5312
# Epoch 96, Batch 11/49, Batch Loss: 85914.5703
# Epoch 96, Batch 12/49, Batch Loss: 82248.2188
# Epoch 96, Batch 13/49, Batch Loss: 88574.4453
# Epoch 96, Batch 14/49, Batch Loss: 76855.0781
# Epoch 96, Batch 15/49, Batch Loss: 117711.9766
# Epoch 96, Batch 16/49, Batch Loss: 99146.0547
# Epoch 96, Batch 17/49, Batch Loss: 93626.0547
# Epoch 96, Batch 18/49, Batch Loss: 72805.5156
# Epoch 96, Batch 19/49, Batch Loss: 178641.9219
# Epoch 96, Batch 20/49, Batch Loss: 63188.2422
# Epoch 96, Batch 21/49, Batch Loss: 91103.5469
# Epoch 96, Batch 22/49, Batch Loss: 101657.9375
# Epoch 96, Batch 23/49, Batch Loss: 93198.0781
# Epoch 96, Batch 24/49, Batch Loss: 78070.4766
# Epoch 96, Batch 25/49, Batch Loss: 65785.1562
# Epoch 96, Batch 26/49, Batch Loss: 67429.7422
# Epoch 96, Batch 27/49, Batch Loss: 70157.0859
# Epoch 96, Batch 28/49, Batch Loss: 83018.7031
# Epoch 96, Batch 29/49, Batch Loss: 128874.4922
# Epoch 96, Batch 30/49, Batch Loss: 94212.0234
# Epoch 96, Batch 31/49, Batch Loss: 64893.9492
# Epoch 96, Batch 32/49, Batch Loss: 58397.2383
# Epoch 96, Batch 33/49, Batch Loss: 92856.9297
# Epoch 96, Batch 34/49, Batch Loss: 64641.0078
# Epoch 96, Batch 35/49, Batch Loss: 62505.4023
# Epoch 96, Batch 36/49, Batch Loss: 85022.6172
# Epoch 96, Batch 37/49, Batch Loss: 100918.5859
# Epoch 96, Batch 38/49, Batch Loss: 71400.7031
# Epoch 96, Batch 39/49, Batch Loss: 133076.9375
# Epoch 96, Batch 40/49, Batch Loss: 49633.7617
# Epoch 96, Batch 41/49, Batch Loss: 78525.1016
# Epoch 96, Batch 42/49, Batch Loss: 69929.9922
# Epoch 96, Batch 43/49, Batch Loss: 69113.0391
# Epoch 96, Batch 44/49, Batch Loss: 79711.7500
# Epoch 96, Batch 45/49, Batch Loss: 71005.8281
# Epoch 96, Batch 46/49, Batch Loss: 82603.6328
# Epoch 96, Batch 47/49, Batch Loss: 114554.1875
# Epoch 96, Batch 48/49, Batch Loss: 61639.2266
# Epoch 96, Batch 49/49, Batch Loss: 61547.1914
# Batch 1/17, Batch Loss: 112845.2734
# Batch 2/17, Batch Loss: 311427.9375
# Batch 3/17, Batch Loss: 233183.7812
# Batch 4/17, Batch Loss: 158925.7812
# Batch 5/17, Batch Loss: 308191.2500
# Batch 6/17, Batch Loss: 374788.8750
# Batch 7/17, Batch Loss: 172498.3750
# Batch 8/17, Batch Loss: 152206.8438
# Batch 9/17, Batch Loss: 301738.9062
# Batch 10/17, Batch Loss: 212417.8906
# Batch 11/17, Batch Loss: 304531.4375
# Batch 12/17, Batch Loss: 158403.2812
# Batch 13/17, Batch Loss: 180791.2500
# Batch 14/17, Batch Loss: 362937.1875
# Batch 15/17, Batch Loss: 169640.4219
# Batch 16/17, Batch Loss: 328870.9375
# Batch 17/17, Batch Loss: 167074.4062
# Test Error:
#  Avg loss: 235910.225643, Avg error: 160604.280277
#
# Epoch 97, Batch 1/49, Batch Loss: 104288.1172
# Epoch 97, Batch 2/49, Batch Loss: 57418.5391
# Epoch 97, Batch 3/49, Batch Loss: 88293.3906
# Epoch 97, Batch 4/49, Batch Loss: 68878.9688
# Epoch 97, Batch 5/49, Batch Loss: 82112.4609
# Epoch 97, Batch 6/49, Batch Loss: 74260.2266
# Epoch 97, Batch 7/49, Batch Loss: 135816.2812
# Epoch 97, Batch 8/49, Batch Loss: 72955.4375
# Epoch 97, Batch 9/49, Batch Loss: 79405.5078
# Epoch 97, Batch 10/49, Batch Loss: 71392.2344
# Epoch 97, Batch 11/49, Batch Loss: 50048.6836
# Epoch 97, Batch 12/49, Batch Loss: 77749.8281
# Epoch 97, Batch 13/49, Batch Loss: 74518.7188
# Epoch 97, Batch 14/49, Batch Loss: 58423.3945
# Epoch 97, Batch 15/49, Batch Loss: 62264.4570
# Epoch 97, Batch 16/49, Batch Loss: 75818.1719
# Epoch 97, Batch 17/49, Batch Loss: 70018.5625
# Epoch 97, Batch 18/49, Batch Loss: 67116.4062
# Epoch 97, Batch 19/49, Batch Loss: 75981.5703
# Epoch 97, Batch 20/49, Batch Loss: 66290.7188
# Epoch 97, Batch 21/49, Batch Loss: 69010.2188
# Epoch 97, Batch 22/49, Batch Loss: 262481.8750
# Epoch 97, Batch 23/49, Batch Loss: 107817.9062
# Epoch 97, Batch 24/49, Batch Loss: 59047.4062
# Epoch 97, Batch 25/49, Batch Loss: 74506.5312
# Epoch 97, Batch 26/49, Batch Loss: 93677.2422
# Epoch 97, Batch 27/49, Batch Loss: 61548.2734
# Epoch 97, Batch 28/49, Batch Loss: 81345.4922
# Epoch 97, Batch 29/49, Batch Loss: 78206.7969
# Epoch 97, Batch 30/49, Batch Loss: 85924.9453
# Epoch 97, Batch 31/49, Batch Loss: 73972.9609
# Epoch 97, Batch 32/49, Batch Loss: 147914.4375
# Epoch 97, Batch 33/49, Batch Loss: 66299.7891
# Epoch 97, Batch 34/49, Batch Loss: 70990.7031
# Epoch 97, Batch 35/49, Batch Loss: 99866.0781
# Epoch 97, Batch 36/49, Batch Loss: 92135.8906
# Epoch 97, Batch 37/49, Batch Loss: 79481.3125
# Epoch 97, Batch 38/49, Batch Loss: 89237.0234
# Epoch 97, Batch 39/49, Batch Loss: 64937.1289
# Epoch 97, Batch 40/49, Batch Loss: 94689.3750
# Epoch 97, Batch 41/49, Batch Loss: 155700.8125
# Epoch 97, Batch 42/49, Batch Loss: 89762.5781
# Epoch 97, Batch 43/49, Batch Loss: 67694.2344
# Epoch 97, Batch 44/49, Batch Loss: 66361.9766
# Epoch 97, Batch 45/49, Batch Loss: 130116.4922
# Epoch 97, Batch 46/49, Batch Loss: 84726.2500
# Epoch 97, Batch 47/49, Batch Loss: 68019.0703
# Epoch 97, Batch 48/49, Batch Loss: 57337.3672
# Epoch 97, Batch 49/49, Batch Loss: 56482.9141
# Batch 1/17, Batch Loss: 88482.2188
# Batch 2/17, Batch Loss: 284991.3125
# Batch 3/17, Batch Loss: 207803.1875
# Batch 4/17, Batch Loss: 125680.2656
# Batch 5/17, Batch Loss: 283436.8750
# Batch 6/17, Batch Loss: 333939.2812
# Batch 7/17, Batch Loss: 169256.3438
# Batch 8/17, Batch Loss: 155866.0781
# Batch 9/17, Batch Loss: 331054.3125
# Batch 10/17, Batch Loss: 147600.8594
# Batch 11/17, Batch Loss: 260317.0156
# Batch 12/17, Batch Loss: 164488.0312
# Batch 13/17, Batch Loss: 128809.9219
# Batch 14/17, Batch Loss: 371823.2500
# Batch 15/17, Batch Loss: 140411.5938
# Batch 16/17, Batch Loss: 299188.4375
# Batch 17/17, Batch Loss: 163193.2031
# Test Error:
#  Avg loss: 215078.952206, Avg error: 146126.387111
#
# Epoch 98, Batch 1/49, Batch Loss: 61580.3320
# Epoch 98, Batch 2/49, Batch Loss: 91665.7109
# Epoch 98, Batch 3/49, Batch Loss: 58234.2852
# Epoch 98, Batch 4/49, Batch Loss: 53332.5859
# Epoch 98, Batch 5/49, Batch Loss: 50415.8516
# Epoch 98, Batch 6/49, Batch Loss: 69318.5312
# Epoch 98, Batch 7/49, Batch Loss: 131498.7500
# Epoch 98, Batch 8/49, Batch Loss: 80429.1328
# Epoch 98, Batch 9/49, Batch Loss: 88367.5234
# Epoch 98, Batch 10/49, Batch Loss: 122787.3359
# Epoch 98, Batch 11/49, Batch Loss: 68405.8828
# Epoch 98, Batch 12/49, Batch Loss: 84003.3594
# Epoch 98, Batch 13/49, Batch Loss: 68116.2188
# Epoch 98, Batch 14/49, Batch Loss: 118605.5391
# Epoch 98, Batch 15/49, Batch Loss: 79559.2656
# Epoch 98, Batch 16/49, Batch Loss: 94115.2734
# Epoch 98, Batch 17/49, Batch Loss: 94317.2031
# Epoch 98, Batch 18/49, Batch Loss: 65335.7305
# Epoch 98, Batch 19/49, Batch Loss: 63015.5039
# Epoch 98, Batch 20/49, Batch Loss: 74299.1484
# Epoch 98, Batch 21/49, Batch Loss: 92750.3281
# Epoch 98, Batch 22/49, Batch Loss: 61173.7773
# Epoch 98, Batch 23/49, Batch Loss: 61908.7031
# Epoch 98, Batch 24/49, Batch Loss: 69704.7266
# Epoch 98, Batch 25/49, Batch Loss: 70909.2344
# Epoch 98, Batch 26/49, Batch Loss: 70775.0469
# Epoch 98, Batch 27/49, Batch Loss: 74355.0234
# Epoch 98, Batch 28/49, Batch Loss: 242413.4375
# Epoch 98, Batch 29/49, Batch Loss: 91941.2188
# Epoch 98, Batch 30/49, Batch Loss: 106286.3672
# Epoch 98, Batch 31/49, Batch Loss: 69177.8281
# Epoch 98, Batch 32/49, Batch Loss: 75740.1719
# Epoch 98, Batch 33/49, Batch Loss: 54365.6836
# Epoch 98, Batch 34/49, Batch Loss: 72284.1172
# Epoch 98, Batch 35/49, Batch Loss: 73571.3672
# Epoch 98, Batch 36/49, Batch Loss: 120846.1562
# Epoch 98, Batch 37/49, Batch Loss: 63094.0273
# Epoch 98, Batch 38/49, Batch Loss: 68660.4453
# Epoch 98, Batch 39/49, Batch Loss: 58650.4609
# Epoch 98, Batch 40/49, Batch Loss: 103446.6406
# Epoch 98, Batch 41/49, Batch Loss: 93446.2422
# Epoch 98, Batch 42/49, Batch Loss: 61310.0781
# Epoch 98, Batch 43/49, Batch Loss: 54407.7109
# Epoch 98, Batch 44/49, Batch Loss: 79195.1250
# Epoch 98, Batch 45/49, Batch Loss: 98558.3516
# Epoch 98, Batch 46/49, Batch Loss: 93850.2188
# Epoch 98, Batch 47/49, Batch Loss: 80225.8281
# Epoch 98, Batch 48/49, Batch Loss: 84565.9375
# Epoch 98, Batch 49/49, Batch Loss: 76539.8359
# Batch 1/17, Batch Loss: 51641.8789
# Batch 2/17, Batch Loss: 297515.9375
# Batch 3/17, Batch Loss: 216661.0938
# Batch 4/17, Batch Loss: 93844.8906
# Batch 5/17, Batch Loss: 285334.8125
# Batch 6/17, Batch Loss: 324548.5312
# Batch 7/17, Batch Loss: 187518.1719
# Batch 8/17, Batch Loss: 226645.1406
# Batch 9/17, Batch Loss: 324785.1250
# Batch 10/17, Batch Loss: 156160.9375
# Batch 11/17, Batch Loss: 263003.5938
# Batch 12/17, Batch Loss: 156852.7812
# Batch 13/17, Batch Loss: 197714.4844
# Batch 14/17, Batch Loss: 183699.7031
# Batch 15/17, Batch Loss: 173251.2188
# Batch 16/17, Batch Loss: 266576.7812
# Batch 17/17, Batch Loss: 177834.3281
# Test Error:
#  Avg loss: 210799.377068, Avg error: 131547.255839
#
# Epoch 99, Batch 1/49, Batch Loss: 78248.9609
# Epoch 99, Batch 2/49, Batch Loss: 98203.7500
# Epoch 99, Batch 3/49, Batch Loss: 88947.3281
# Epoch 99, Batch 4/49, Batch Loss: 69375.2578
# Epoch 99, Batch 5/49, Batch Loss: 65806.3438
# Epoch 99, Batch 6/49, Batch Loss: 66287.6875
# Epoch 99, Batch 7/49, Batch Loss: 78013.9453
# Epoch 99, Batch 8/49, Batch Loss: 58965.1758
# Epoch 99, Batch 9/49, Batch Loss: 78011.2031
# Epoch 99, Batch 10/49, Batch Loss: 74491.4531
# Epoch 99, Batch 11/49, Batch Loss: 89357.8750
# Epoch 99, Batch 12/49, Batch Loss: 54626.6992
# Epoch 99, Batch 13/49, Batch Loss: 77964.2578
# Epoch 99, Batch 14/49, Batch Loss: 190834.9688
# Epoch 99, Batch 15/49, Batch Loss: 101537.3828
# Epoch 99, Batch 16/49, Batch Loss: 69128.0859
# Epoch 99, Batch 17/49, Batch Loss: 78911.5156
# Epoch 99, Batch 18/49, Batch Loss: 105930.3672
# Epoch 99, Batch 19/49, Batch Loss: 64668.8789
# Epoch 99, Batch 20/49, Batch Loss: 85583.5859
# Epoch 99, Batch 21/49, Batch Loss: 100045.4688
# Epoch 99, Batch 22/49, Batch Loss: 81292.8594
# Epoch 99, Batch 23/49, Batch Loss: 72526.7812
# Epoch 99, Batch 24/49, Batch Loss: 69543.9453
# Epoch 99, Batch 25/49, Batch Loss: 87984.0781
# Epoch 99, Batch 26/49, Batch Loss: 75420.0938
# Epoch 99, Batch 27/49, Batch Loss: 208497.8750
# Epoch 99, Batch 28/49, Batch Loss: 80847.4297
# Epoch 99, Batch 29/49, Batch Loss: 85822.8672
# Epoch 99, Batch 30/49, Batch Loss: 100765.6406
# Epoch 99, Batch 31/49, Batch Loss: 64033.7734
# Epoch 99, Batch 32/49, Batch Loss: 81576.2188
# Epoch 99, Batch 33/49, Batch Loss: 139581.1094
# Epoch 99, Batch 34/49, Batch Loss: 70761.0469
# Epoch 99, Batch 35/49, Batch Loss: 84864.8281
# Epoch 99, Batch 36/49, Batch Loss: 109261.2812
# Epoch 99, Batch 37/49, Batch Loss: 85372.6953
# Epoch 99, Batch 38/49, Batch Loss: 89759.7422
# Epoch 99, Batch 39/49, Batch Loss: 75251.1641
# Epoch 99, Batch 40/49, Batch Loss: 65545.4531
# Epoch 99, Batch 41/49, Batch Loss: 62807.2461
# Epoch 99, Batch 42/49, Batch Loss: 58480.3945
# Epoch 99, Batch 43/49, Batch Loss: 41205.2305
# Epoch 99, Batch 44/49, Batch Loss: 76369.2578
# Epoch 99, Batch 45/49, Batch Loss: 78700.0391
# Epoch 99, Batch 46/49, Batch Loss: 63081.7773
# Epoch 99, Batch 47/49, Batch Loss: 73590.5234
# Epoch 99, Batch 48/49, Batch Loss: 65609.3672
# Epoch 99, Batch 49/49, Batch Loss: 63789.3438
# Batch 1/17, Batch Loss: 89700.7969
# Batch 2/17, Batch Loss: 259512.2344
# Batch 3/17, Batch Loss: 236924.0625
# Batch 4/17, Batch Loss: 162705.8750
# Batch 5/17, Batch Loss: 325797.4688
# Batch 6/17, Batch Loss: 360783.6562
# Batch 7/17, Batch Loss: 179438.3906
# Batch 8/17, Batch Loss: 232820.5781
# Batch 9/17, Batch Loss: 278958.0938
# Batch 10/17, Batch Loss: 191161.7656
# Batch 11/17, Batch Loss: 271377.6875
# Batch 12/17, Batch Loss: 135063.1094
# Batch 13/17, Batch Loss: 187171.4688
# Batch 14/17, Batch Loss: 326112.5000
# Batch 15/17, Batch Loss: 181395.7969
# Batch 16/17, Batch Loss: 298551.2812
# Batch 17/17, Batch Loss: 175109.0469
# Test Error:
#  Avg loss: 228975.518382, Avg error: 149080.942042
#
# Epoch 100, Batch 1/49, Batch Loss: 61809.3438
# Epoch 100, Batch 2/49, Batch Loss: 59631.6484
# Epoch 100, Batch 3/49, Batch Loss: 40792.4414
# Epoch 100, Batch 4/49, Batch Loss: 71722.2031
# Epoch 100, Batch 5/49, Batch Loss: 126284.4844
# Epoch 100, Batch 6/49, Batch Loss: 77126.4297
# Epoch 100, Batch 7/49, Batch Loss: 73257.8438
# Epoch 100, Batch 8/49, Batch Loss: 77505.9609
# Epoch 100, Batch 9/49, Batch Loss: 88488.8047
# Epoch 100, Batch 10/49, Batch Loss: 69160.2422
# Epoch 100, Batch 11/49, Batch Loss: 122420.1016
# Epoch 100, Batch 12/49, Batch Loss: 78937.8438
# Epoch 100, Batch 13/49, Batch Loss: 98783.2578
# Epoch 100, Batch 14/49, Batch Loss: 92971.9531
# Epoch 100, Batch 15/49, Batch Loss: 67048.5625
# Epoch 100, Batch 16/49, Batch Loss: 67295.6484
# Epoch 100, Batch 17/49, Batch Loss: 72448.6719
# Epoch 100, Batch 18/49, Batch Loss: 76247.6250
# Epoch 100, Batch 19/49, Batch Loss: 87898.0078
# Epoch 100, Batch 20/49, Batch Loss: 89358.2500
# Epoch 100, Batch 21/49, Batch Loss: 59085.2617
# Epoch 100, Batch 22/49, Batch Loss: 65773.6797
# Epoch 100, Batch 23/49, Batch Loss: 70699.4453
# Epoch 100, Batch 24/49, Batch Loss: 79121.4141
# Epoch 100, Batch 25/49, Batch Loss: 90111.7812
# Epoch 100, Batch 26/49, Batch Loss: 78419.1641
# Epoch 100, Batch 27/49, Batch Loss: 44641.5000
# Epoch 100, Batch 28/49, Batch Loss: 78611.9688
# Epoch 100, Batch 29/49, Batch Loss: 61629.9102
# Epoch 100, Batch 30/49, Batch Loss: 92393.6094
# Epoch 100, Batch 31/49, Batch Loss: 70924.5859
# Epoch 100, Batch 32/49, Batch Loss: 53926.6328
# Epoch 100, Batch 33/49, Batch Loss: 77499.8516
# Epoch 100, Batch 34/49, Batch Loss: 102589.6562
# Epoch 100, Batch 35/49, Batch Loss: 95819.4297
# Epoch 100, Batch 36/49, Batch Loss: 62190.0391
# Epoch 100, Batch 37/49, Batch Loss: 83256.2031
# Epoch 100, Batch 38/49, Batch Loss: 83995.4141
# Epoch 100, Batch 39/49, Batch Loss: 63106.0078
# Epoch 100, Batch 40/49, Batch Loss: 87534.2344
# Epoch 100, Batch 41/49, Batch Loss: 67887.8516
# Epoch 100, Batch 42/49, Batch Loss: 127687.6094
# Epoch 100, Batch 43/49, Batch Loss: 94168.0625
# Epoch 100, Batch 44/49, Batch Loss: 82445.0938
# Epoch 100, Batch 45/49, Batch Loss: 78054.4375
# Epoch 100, Batch 46/49, Batch Loss: 217028.6562
# Epoch 100, Batch 47/49, Batch Loss: 73938.1797
# Epoch 100, Batch 48/49, Batch Loss: 138710.1406
# Epoch 100, Batch 49/49, Batch Loss: 73654.0469
# Batch 1/17, Batch Loss: 117670.3906
# Batch 2/17, Batch Loss: 313657.0000
# Batch 3/17, Batch Loss: 233407.6562
# Batch 4/17, Batch Loss: 153879.3438
# Batch 5/17, Batch Loss: 343932.2812
# Batch 6/17, Batch Loss: 353462.7188
# Batch 7/17, Batch Loss: 175883.7500
# Batch 8/17, Batch Loss: 265937.2812
# Batch 9/17, Batch Loss: 342254.3125
# Batch 10/17, Batch Loss: 142508.5000
# Batch 11/17, Batch Loss: 286312.3125
# Batch 12/17, Batch Loss: 183192.6094
# Batch 13/17, Batch Loss: 171685.2031
# Batch 14/17, Batch Loss: 314624.8438
# Batch 15/17, Batch Loss: 188589.7500
# Batch 16/17, Batch Loss: 313138.8125
# Batch 17/17, Batch Loss: 192331.9219
# Test Error:
#  Avg loss: 240733.452206, Avg error: 167997.477941
#
# 2024-09-27 15:29:51.484529 Epoch 100, Average Training loss 82736.59574298469
# Epoch 101, Batch 1/49, Batch Loss: 64218.3086
# Epoch 101, Batch 2/49, Batch Loss: 64079.1836
# Epoch 101, Batch 3/49, Batch Loss: 54495.6953
# Epoch 101, Batch 4/49, Batch Loss: 80175.5156
# Epoch 101, Batch 5/49, Batch Loss: 105064.9141
# Epoch 101, Batch 6/49, Batch Loss: 97762.0391
# Epoch 101, Batch 7/49, Batch Loss: 122610.6797
# Epoch 101, Batch 8/49, Batch Loss: 93868.4453
# Epoch 101, Batch 9/49, Batch Loss: 100621.4609
# Epoch 101, Batch 10/49, Batch Loss: 73090.4766
# Epoch 101, Batch 11/49, Batch Loss: 148953.1719
# Epoch 101, Batch 12/49, Batch Loss: 100644.6719
# Epoch 101, Batch 13/49, Batch Loss: 98686.7422
# Epoch 101, Batch 14/49, Batch Loss: 70767.4141
# Epoch 101, Batch 15/49, Batch Loss: 85973.1094
# Epoch 101, Batch 16/49, Batch Loss: 84814.0938
# Epoch 101, Batch 17/49, Batch Loss: 108050.9766
# Epoch 101, Batch 18/49, Batch Loss: 76853.9531
# Epoch 101, Batch 19/49, Batch Loss: 49558.4609
# Epoch 101, Batch 20/49, Batch Loss: 224713.9219
# Epoch 101, Batch 21/49, Batch Loss: 73332.7812
# Epoch 101, Batch 22/49, Batch Loss: 75759.5938
# Epoch 101, Batch 23/49, Batch Loss: 95206.2422
# Epoch 101, Batch 24/49, Batch Loss: 73436.2812
# Epoch 101, Batch 25/49, Batch Loss: 67817.8594
# Epoch 101, Batch 26/49, Batch Loss: 83071.0469
# Epoch 101, Batch 27/49, Batch Loss: 61622.8203
# Epoch 101, Batch 28/49, Batch Loss: 81411.9844
# Epoch 101, Batch 29/49, Batch Loss: 92763.2500
# Epoch 101, Batch 30/49, Batch Loss: 65271.3008
# Epoch 101, Batch 31/49, Batch Loss: 48224.7148
# Epoch 101, Batch 32/49, Batch Loss: 92937.2188
# Epoch 101, Batch 33/49, Batch Loss: 83384.9141
# Epoch 101, Batch 34/49, Batch Loss: 75310.8125
# Epoch 101, Batch 35/49, Batch Loss: 60432.6484
# Epoch 101, Batch 36/49, Batch Loss: 76011.2344
# Epoch 101, Batch 37/49, Batch Loss: 67847.9297
# Epoch 101, Batch 38/49, Batch Loss: 80010.1484
# Epoch 101, Batch 39/49, Batch Loss: 56285.5117
# Epoch 101, Batch 40/49, Batch Loss: 137272.5156
# Epoch 101, Batch 41/49, Batch Loss: 90344.5156
# Epoch 101, Batch 42/49, Batch Loss: 63371.9766
# Epoch 101, Batch 43/49, Batch Loss: 81873.1562
# Epoch 101, Batch 44/49, Batch Loss: 77109.5078
# Epoch 101, Batch 45/49, Batch Loss: 101859.3906
# Epoch 101, Batch 46/49, Batch Loss: 84328.0156
# Epoch 101, Batch 47/49, Batch Loss: 71141.1406
# Epoch 101, Batch 48/49, Batch Loss: 78111.2812
# Epoch 101, Batch 49/49, Batch Loss: 92438.3438
# Batch 1/17, Batch Loss: 136387.7812
# Batch 2/17, Batch Loss: 331973.4375
# Batch 3/17, Batch Loss: 283826.4375
# Batch 4/17, Batch Loss: 127697.8359
# Batch 5/17, Batch Loss: 291696.6250
# Batch 6/17, Batch Loss: 393757.3438
# Batch 7/17, Batch Loss: 169340.0938
# Batch 8/17, Batch Loss: 154948.0781
# Batch 9/17, Batch Loss: 362684.6562
# Batch 10/17, Batch Loss: 200484.3594
# Batch 11/17, Batch Loss: 322481.4688
# Batch 12/17, Batch Loss: 196057.4844
# Batch 13/17, Batch Loss: 167787.7344
# Batch 14/17, Batch Loss: 321497.5000
# Batch 15/17, Batch Loss: 189317.5312
# Batch 16/17, Batch Loss: 338165.5312
# Batch 17/17, Batch Loss: 179381.8438
# Test Error:
#  Avg loss: 245146.220129, Avg error: 169239.246540
#
# Epoch 102, Batch 1/49, Batch Loss: 86962.9609
# Epoch 102, Batch 2/49, Batch Loss: 98385.1250
# Epoch 102, Batch 3/49, Batch Loss: 75237.1562
# Epoch 102, Batch 4/49, Batch Loss: 97481.4922
# Epoch 102, Batch 5/49, Batch Loss: 84246.5234
# Epoch 102, Batch 6/49, Batch Loss: 109400.3516
# Epoch 102, Batch 7/49, Batch Loss: 248941.0781
# Epoch 102, Batch 8/49, Batch Loss: 90073.6484
# Epoch 102, Batch 9/49, Batch Loss: 76069.5625
# Epoch 102, Batch 10/49, Batch Loss: 91560.2500
# Epoch 102, Batch 11/49, Batch Loss: 75679.9375
# Epoch 102, Batch 12/49, Batch Loss: 68827.6328
# Epoch 102, Batch 13/49, Batch Loss: 76318.9688
# Epoch 102, Batch 14/49, Batch Loss: 77186.7969
# Epoch 102, Batch 15/49, Batch Loss: 81529.6953
# Epoch 102, Batch 16/49, Batch Loss: 80101.4297
# Epoch 102, Batch 17/49, Batch Loss: 63709.0000
# Epoch 102, Batch 18/49, Batch Loss: 101152.9375
# Epoch 102, Batch 19/49, Batch Loss: 76862.6953
# Epoch 102, Batch 20/49, Batch Loss: 67595.9688
# Epoch 102, Batch 21/49, Batch Loss: 97475.9531
# Epoch 102, Batch 22/49, Batch Loss: 121555.0312
# Epoch 102, Batch 23/49, Batch Loss: 66944.1484
# Epoch 102, Batch 24/49, Batch Loss: 70879.0234
# Epoch 102, Batch 25/49, Batch Loss: 229146.9844
# Epoch 102, Batch 26/49, Batch Loss: 72151.5078
# Epoch 102, Batch 27/49, Batch Loss: 100129.9844
# Epoch 102, Batch 28/49, Batch Loss: 96275.2578
# Epoch 102, Batch 29/49, Batch Loss: 79007.0547
# Epoch 102, Batch 30/49, Batch Loss: 75037.1953
# Epoch 102, Batch 31/49, Batch Loss: 67629.6953
# Epoch 102, Batch 32/49, Batch Loss: 68446.3984
# Epoch 102, Batch 33/49, Batch Loss: 80307.0703
# Epoch 102, Batch 34/49, Batch Loss: 71922.1250
# Epoch 102, Batch 35/49, Batch Loss: 68033.2656
# Epoch 102, Batch 36/49, Batch Loss: 56738.5430
# Epoch 102, Batch 37/49, Batch Loss: 77851.3750
# Epoch 102, Batch 38/49, Batch Loss: 86361.4297
# Epoch 102, Batch 39/49, Batch Loss: 99513.2891
# Epoch 102, Batch 40/49, Batch Loss: 73290.8750
# Epoch 102, Batch 41/49, Batch Loss: 62289.2461
# Epoch 102, Batch 42/49, Batch Loss: 62964.5742
# Epoch 102, Batch 43/49, Batch Loss: 118846.4219
# Epoch 102, Batch 44/49, Batch Loss: 81453.8203
# Epoch 102, Batch 45/49, Batch Loss: 89635.8828
# Epoch 102, Batch 46/49, Batch Loss: 98870.9375
# Epoch 102, Batch 47/49, Batch Loss: 54943.8984
# Epoch 102, Batch 48/49, Batch Loss: 106151.5156
# Epoch 102, Batch 49/49, Batch Loss: 138974.7344
# Batch 1/17, Batch Loss: 135786.1719
# Batch 2/17, Batch Loss: 301861.5000
# Batch 3/17, Batch Loss: 179067.6250
# Batch 4/17, Batch Loss: 150175.8750
# Batch 5/17, Batch Loss: 356538.8750
# Batch 6/17, Batch Loss: 348165.3125
# Batch 7/17, Batch Loss: 177449.1719
# Batch 8/17, Batch Loss: 258338.4062
# Batch 9/17, Batch Loss: 324072.8438
# Batch 10/17, Batch Loss: 178418.0156
# Batch 11/17, Batch Loss: 267251.6250
# Batch 12/17, Batch Loss: 184286.9688
# Batch 13/17, Batch Loss: 182738.0938
# Batch 14/17, Batch Loss: 302901.0938
# Batch 15/17, Batch Loss: 194409.8125
# Batch 16/17, Batch Loss: 278119.6875
# Batch 17/17, Batch Loss: 170675.8750
# Test Error:
#  Avg loss: 234720.997243, Avg error: 166813.720156
#
# Epoch 103, Batch 1/49, Batch Loss: 67670.1172
# Epoch 103, Batch 2/49, Batch Loss: 86831.3281
# Epoch 103, Batch 3/49, Batch Loss: 94884.1797
# Epoch 103, Batch 4/49, Batch Loss: 55120.7969
# Epoch 103, Batch 5/49, Batch Loss: 69747.0547
# Epoch 103, Batch 6/49, Batch Loss: 86296.9531
# Epoch 103, Batch 7/49, Batch Loss: 120297.7969
# Epoch 103, Batch 8/49, Batch Loss: 86817.3125
# Epoch 103, Batch 9/49, Batch Loss: 44829.1250
# Epoch 103, Batch 10/49, Batch Loss: 61756.8867
# Epoch 103, Batch 11/49, Batch Loss: 71200.5625
# Epoch 103, Batch 12/49, Batch Loss: 112307.4219
# Epoch 103, Batch 13/49, Batch Loss: 85248.5078
# Epoch 103, Batch 14/49, Batch Loss: 85528.3438
# Epoch 103, Batch 15/49, Batch Loss: 94023.3047
# Epoch 103, Batch 16/49, Batch Loss: 69133.5312
# Epoch 103, Batch 17/49, Batch Loss: 75239.6016
# Epoch 103, Batch 18/49, Batch Loss: 71495.8906
# Epoch 103, Batch 19/49, Batch Loss: 108862.7188
# Epoch 103, Batch 20/49, Batch Loss: 88479.3828
# Epoch 103, Batch 21/49, Batch Loss: 76287.2109
# Epoch 103, Batch 22/49, Batch Loss: 67617.1250
# Epoch 103, Batch 23/49, Batch Loss: 68317.2500
# Epoch 103, Batch 24/49, Batch Loss: 87206.6953
# Epoch 103, Batch 25/49, Batch Loss: 72645.7812
# Epoch 103, Batch 26/49, Batch Loss: 89614.6328
# Epoch 103, Batch 27/49, Batch Loss: 66528.0703
# Epoch 103, Batch 28/49, Batch Loss: 123204.4141
# Epoch 103, Batch 29/49, Batch Loss: 120787.4922
# Epoch 103, Batch 30/49, Batch Loss: 67892.8828
# Epoch 103, Batch 31/49, Batch Loss: 55266.6055
# Epoch 103, Batch 32/49, Batch Loss: 65399.3984
# Epoch 103, Batch 33/49, Batch Loss: 65583.8438
# Epoch 103, Batch 34/49, Batch Loss: 76512.3906
# Epoch 103, Batch 35/49, Batch Loss: 60370.4648
# Epoch 103, Batch 36/49, Batch Loss: 60364.1094
# Epoch 103, Batch 37/49, Batch Loss: 81024.3516
# Epoch 103, Batch 38/49, Batch Loss: 94018.2969
# Epoch 103, Batch 39/49, Batch Loss: 75890.2344
# Epoch 103, Batch 40/49, Batch Loss: 79675.2969
# Epoch 103, Batch 41/49, Batch Loss: 83994.9375
# Epoch 103, Batch 42/49, Batch Loss: 137427.9531
# Epoch 103, Batch 43/49, Batch Loss: 69078.0391
# Epoch 103, Batch 44/49, Batch Loss: 203777.3750
# Epoch 103, Batch 45/49, Batch Loss: 77889.9375
# Epoch 103, Batch 46/49, Batch Loss: 71202.6406
# Epoch 103, Batch 47/49, Batch Loss: 82436.0938
# Epoch 103, Batch 48/49, Batch Loss: 126309.5469
# Epoch 103, Batch 49/49, Batch Loss: 93858.0156
# Batch 1/17, Batch Loss: 68075.3672
# Batch 2/17, Batch Loss: 258204.4531
# Batch 3/17, Batch Loss: 233629.6406
# Batch 4/17, Batch Loss: 131421.3750
# Batch 5/17, Batch Loss: 290636.9375
# Batch 6/17, Batch Loss: 307329.5625
# Batch 7/17, Batch Loss: 145185.7500
# Batch 8/17, Batch Loss: 137760.8906
# Batch 9/17, Batch Loss: 313098.2812
# Batch 10/17, Batch Loss: 159154.6562
# Batch 11/17, Batch Loss: 256843.5156
# Batch 12/17, Batch Loss: 163276.8906
# Batch 13/17, Batch Loss: 188807.0938
# Batch 14/17, Batch Loss: 251516.1406
# Batch 15/17, Batch Loss: 177098.9219
# Batch 16/17, Batch Loss: 308628.8125
# Batch 17/17, Batch Loss: 168807.6875
# Test Error:
#  Avg loss: 209380.939798, Avg error: 136203.518599
#
# Epoch 104, Batch 1/49, Batch Loss: 91264.2734
# Epoch 104, Batch 2/49, Batch Loss: 64496.3203
# Epoch 104, Batch 3/49, Batch Loss: 82714.6797
# Epoch 104, Batch 4/49, Batch Loss: 105180.7500
# Epoch 104, Batch 5/49, Batch Loss: 126353.4531
# Epoch 104, Batch 6/49, Batch Loss: 94754.2188
# Epoch 104, Batch 7/49, Batch Loss: 66607.6016
# Epoch 104, Batch 8/49, Batch Loss: 89499.1250
# Epoch 104, Batch 9/49, Batch Loss: 57732.9297
# Epoch 104, Batch 10/49, Batch Loss: 78693.5391
# Epoch 104, Batch 11/49, Batch Loss: 75108.1016
# Epoch 104, Batch 12/49, Batch Loss: 91946.4688
# Epoch 104, Batch 13/49, Batch Loss: 85372.9375
# Epoch 104, Batch 14/49, Batch Loss: 66299.6875
# Epoch 104, Batch 15/49, Batch Loss: 113332.3672
# Epoch 104, Batch 16/49, Batch Loss: 153019.9219
# Epoch 104, Batch 17/49, Batch Loss: 74707.7266
# Epoch 104, Batch 18/49, Batch Loss: 104990.6641
# Epoch 104, Batch 19/49, Batch Loss: 106476.6641
# Epoch 104, Batch 20/49, Batch Loss: 61152.4609
# Epoch 104, Batch 21/49, Batch Loss: 105751.4609
# Epoch 104, Batch 22/49, Batch Loss: 112011.1797
# Epoch 104, Batch 23/49, Batch Loss: 102386.9297
# Epoch 104, Batch 24/49, Batch Loss: 94335.4297
# Epoch 104, Batch 25/49, Batch Loss: 66511.8672
# Epoch 104, Batch 26/49, Batch Loss: 69351.2891
# Epoch 104, Batch 27/49, Batch Loss: 77831.8750
# Epoch 104, Batch 28/49, Batch Loss: 64806.3203
# Epoch 104, Batch 29/49, Batch Loss: 158724.3438
# Epoch 104, Batch 30/49, Batch Loss: 73610.1562
# Epoch 104, Batch 31/49, Batch Loss: 66599.6016
# Epoch 104, Batch 32/49, Batch Loss: 82485.7969
# Epoch 104, Batch 33/49, Batch Loss: 116201.0547
# Epoch 104, Batch 34/49, Batch Loss: 65086.9414
# Epoch 104, Batch 35/49, Batch Loss: 76671.2344
# Epoch 104, Batch 36/49, Batch Loss: 76922.4219
# Epoch 104, Batch 37/49, Batch Loss: 71528.9531
# Epoch 104, Batch 38/49, Batch Loss: 95520.3359
# Epoch 104, Batch 39/49, Batch Loss: 119866.7578
# Epoch 104, Batch 40/49, Batch Loss: 98833.5391
# Epoch 104, Batch 41/49, Batch Loss: 91156.2969
# Epoch 104, Batch 42/49, Batch Loss: 61484.0391
# Epoch 104, Batch 43/49, Batch Loss: 83646.5469
# Epoch 104, Batch 44/49, Batch Loss: 127847.4375
# Epoch 104, Batch 45/49, Batch Loss: 116714.4219
# Epoch 104, Batch 46/49, Batch Loss: 84360.2891
# Epoch 104, Batch 47/49, Batch Loss: 119110.3047
# Epoch 104, Batch 48/49, Batch Loss: 88914.6562
# Epoch 104, Batch 49/49, Batch Loss: 79188.9062
# Batch 1/17, Batch Loss: 93275.0469
# Batch 2/17, Batch Loss: 323658.6250
# Batch 3/17, Batch Loss: 251952.1094
# Batch 4/17, Batch Loss: 100447.9844
# Batch 5/17, Batch Loss: 281614.3125
# Batch 6/17, Batch Loss: 348121.8125
# Batch 7/17, Batch Loss: 173615.6719
# Batch 8/17, Batch Loss: 243633.3594
# Batch 9/17, Batch Loss: 339019.4375
# Batch 10/17, Batch Loss: 208028.4688
# Batch 11/17, Batch Loss: 309453.7500
# Batch 12/17, Batch Loss: 177285.3906
# Batch 13/17, Batch Loss: 172416.5781
# Batch 14/17, Batch Loss: 202359.4219
# Batch 15/17, Batch Loss: 195062.9531
# Batch 16/17, Batch Loss: 335319.1875
# Batch 17/17, Batch Loss: 163611.5625
# Test Error:
#  Avg loss: 230522.098346, Avg error: 155737.152682
#
# Epoch 105, Batch 1/49, Batch Loss: 97547.4141
# Epoch 105, Batch 2/49, Batch Loss: 74933.1250
# Epoch 105, Batch 3/49, Batch Loss: 63005.8242
# Epoch 105, Batch 4/49, Batch Loss: 65525.1172
# Epoch 105, Batch 5/49, Batch Loss: 85080.7266
# Epoch 105, Batch 6/49, Batch Loss: 88776.6875
# Epoch 105, Batch 7/49, Batch Loss: 63534.5977
# Epoch 105, Batch 8/49, Batch Loss: 69272.8672
# Epoch 105, Batch 9/49, Batch Loss: 89531.2969
# Epoch 105, Batch 10/49, Batch Loss: 104455.5938
# Epoch 105, Batch 11/49, Batch Loss: 124528.2188
# Epoch 105, Batch 12/49, Batch Loss: 76407.7344
# Epoch 105, Batch 13/49, Batch Loss: 97606.2578
# Epoch 105, Batch 14/49, Batch Loss: 91914.5078
# Epoch 105, Batch 15/49, Batch Loss: 55362.6016
# Epoch 105, Batch 16/49, Batch Loss: 62971.4336
# Epoch 105, Batch 17/49, Batch Loss: 89001.8203
# Epoch 105, Batch 18/49, Batch Loss: 134452.7969
# Epoch 105, Batch 19/49, Batch Loss: 100426.9219
# Epoch 105, Batch 20/49, Batch Loss: 70698.4375
# Epoch 105, Batch 21/49, Batch Loss: 52887.4688
# Epoch 105, Batch 22/49, Batch Loss: 78804.6328
# Epoch 105, Batch 23/49, Batch Loss: 85886.6641
# Epoch 105, Batch 24/49, Batch Loss: 75423.9141
# Epoch 105, Batch 25/49, Batch Loss: 93765.0781
# Epoch 105, Batch 26/49, Batch Loss: 78972.7734
# Epoch 105, Batch 27/49, Batch Loss: 77815.2656
# Epoch 105, Batch 28/49, Batch Loss: 96714.6641
# Epoch 105, Batch 29/49, Batch Loss: 107504.0938
# Epoch 105, Batch 30/49, Batch Loss: 76572.3984
# Epoch 105, Batch 31/49, Batch Loss: 95615.7969
# Epoch 105, Batch 32/49, Batch Loss: 63000.4961
# Epoch 105, Batch 33/49, Batch Loss: 149068.5000
# Epoch 105, Batch 34/49, Batch Loss: 89216.2031
# Epoch 105, Batch 35/49, Batch Loss: 92174.5000
# Epoch 105, Batch 36/49, Batch Loss: 92924.0625
# Epoch 105, Batch 37/49, Batch Loss: 68972.7031
# Epoch 105, Batch 38/49, Batch Loss: 64662.4648
# Epoch 105, Batch 39/49, Batch Loss: 98176.1484
# Epoch 105, Batch 40/49, Batch Loss: 64801.5195
# Epoch 105, Batch 41/49, Batch Loss: 80930.8438
# Epoch 105, Batch 42/49, Batch Loss: 60403.6719
# Epoch 105, Batch 43/49, Batch Loss: 63641.4570
# Epoch 105, Batch 44/49, Batch Loss: 85859.0312
# Epoch 105, Batch 45/49, Batch Loss: 105728.6562
# Epoch 105, Batch 46/49, Batch Loss: 80380.2266
# Epoch 105, Batch 47/49, Batch Loss: 101377.1016
# Epoch 105, Batch 48/49, Batch Loss: 96000.9453
# Epoch 105, Batch 49/49, Batch Loss: 60833.6875
# Batch 1/17, Batch Loss: 94817.3828
# Batch 2/17, Batch Loss: 287546.0312
# Batch 3/17, Batch Loss: 251138.7812
# Batch 4/17, Batch Loss: 130356.3672
# Batch 5/17, Batch Loss: 336779.2812
# Batch 6/17, Batch Loss: 335668.3750
# Batch 7/17, Batch Loss: 167682.5312
# Batch 8/17, Batch Loss: 252465.2812
# Batch 9/17, Batch Loss: 326252.6562
# Batch 10/17, Batch Loss: 191415.5000
# Batch 11/17, Batch Loss: 259422.7812
# Batch 12/17, Batch Loss: 181301.2969
# Batch 13/17, Batch Loss: 154259.2188
# Batch 14/17, Batch Loss: 288660.0000
# Batch 15/17, Batch Loss: 165617.5625
# Batch 16/17, Batch Loss: 319952.6250
# Batch 17/17, Batch Loss: 148279.6719
# Test Error:
#  Avg loss: 228918.549632, Avg error: 153027.013841
#
# Epoch 106, Batch 1/49, Batch Loss: 74527.5078
# Epoch 106, Batch 2/49, Batch Loss: 93373.5234
# Epoch 106, Batch 3/49, Batch Loss: 72614.6797
# Epoch 106, Batch 4/49, Batch Loss: 96278.6016
# Epoch 106, Batch 5/49, Batch Loss: 70744.7734
# Epoch 106, Batch 6/49, Batch Loss: 75840.5781
# Epoch 106, Batch 7/49, Batch Loss: 74318.2422
# Epoch 106, Batch 8/49, Batch Loss: 100877.3125
# Epoch 106, Batch 9/49, Batch Loss: 90057.6406
# Epoch 106, Batch 10/49, Batch Loss: 150723.4531
# Epoch 106, Batch 11/49, Batch Loss: 64200.1289
# Epoch 106, Batch 12/49, Batch Loss: 70399.2031
# Epoch 106, Batch 13/49, Batch Loss: 74406.1406
# Epoch 106, Batch 14/49, Batch Loss: 73855.9062
# Epoch 106, Batch 15/49, Batch Loss: 52685.0547
# Epoch 106, Batch 16/49, Batch Loss: 70788.6953
# Epoch 106, Batch 17/49, Batch Loss: 73368.7891
# Epoch 106, Batch 18/49, Batch Loss: 62204.7461
# Epoch 106, Batch 19/49, Batch Loss: 72968.2344
# Epoch 106, Batch 20/49, Batch Loss: 59258.5195
# Epoch 106, Batch 21/49, Batch Loss: 74140.7656
# Epoch 106, Batch 22/49, Batch Loss: 74554.1797
# Epoch 106, Batch 23/49, Batch Loss: 79840.8516
# Epoch 106, Batch 24/49, Batch Loss: 91602.6484
# Epoch 106, Batch 25/49, Batch Loss: 90357.1016
# Epoch 106, Batch 26/49, Batch Loss: 66500.5391
# Epoch 106, Batch 27/49, Batch Loss: 66004.3984
# Epoch 106, Batch 28/49, Batch Loss: 101368.5938
# Epoch 106, Batch 29/49, Batch Loss: 116853.9609
# Epoch 106, Batch 30/49, Batch Loss: 69519.8359
# Epoch 106, Batch 31/49, Batch Loss: 88136.9141
# Epoch 106, Batch 32/49, Batch Loss: 73514.8281
# Epoch 106, Batch 33/49, Batch Loss: 76237.5781
# Epoch 106, Batch 34/49, Batch Loss: 65450.8203
# Epoch 106, Batch 35/49, Batch Loss: 73597.2188
# Epoch 106, Batch 36/49, Batch Loss: 85946.7500
# Epoch 106, Batch 37/49, Batch Loss: 89747.7031
# Epoch 106, Batch 38/49, Batch Loss: 43626.5000
# Epoch 106, Batch 39/49, Batch Loss: 69674.0000
# Epoch 106, Batch 40/49, Batch Loss: 80457.3125
# Epoch 106, Batch 41/49, Batch Loss: 66193.5938
# Epoch 106, Batch 42/49, Batch Loss: 79095.0078
# Epoch 106, Batch 43/49, Batch Loss: 60877.3359
# Epoch 106, Batch 44/49, Batch Loss: 46739.1211
# Epoch 106, Batch 45/49, Batch Loss: 82144.7812
# Epoch 106, Batch 46/49, Batch Loss: 64231.2734
# Epoch 106, Batch 47/49, Batch Loss: 83630.1094
# Epoch 106, Batch 48/49, Batch Loss: 69679.4375
# Epoch 106, Batch 49/49, Batch Loss: 83003.0625
# Batch 1/17, Batch Loss: 84695.1250
# Batch 2/17, Batch Loss: 288652.5938
# Batch 3/17, Batch Loss: 200454.3594
# Batch 4/17, Batch Loss: 78487.1641
# Batch 5/17, Batch Loss: 330227.1250
# Batch 6/17, Batch Loss: 336658.6875
# Batch 7/17, Batch Loss: 182259.0312
# Batch 8/17, Batch Loss: 143746.2969
# Batch 9/17, Batch Loss: 324105.4375
# Batch 10/17, Batch Loss: 187269.9531
# Batch 11/17, Batch Loss: 257757.0000
# Batch 12/17, Batch Loss: 178600.3594
# Batch 13/17, Batch Loss: 192667.5781
# Batch 14/17, Batch Loss: 218113.3594
# Batch 15/17, Batch Loss: 134569.0156
# Batch 16/17, Batch Loss: 317744.8125
# Batch 17/17, Batch Loss: 161222.3906
# Test Error:
#  Avg loss: 212778.252298, Avg error: 139726.804498
#
# Epoch 107, Batch 1/49, Batch Loss: 76976.8906
# Epoch 107, Batch 2/49, Batch Loss: 86212.2109
# Epoch 107, Batch 3/49, Batch Loss: 46817.5273
# Epoch 107, Batch 4/49, Batch Loss: 81826.9844
# Epoch 107, Batch 5/49, Batch Loss: 47249.7344
# Epoch 107, Batch 6/49, Batch Loss: 83762.9531
# Epoch 107, Batch 7/49, Batch Loss: 62477.3438
# Epoch 107, Batch 8/49, Batch Loss: 122168.7656
# Epoch 107, Batch 9/49, Batch Loss: 77098.0078
# Epoch 107, Batch 10/49, Batch Loss: 77901.1562
# Epoch 107, Batch 11/49, Batch Loss: 61399.7578
# Epoch 107, Batch 12/49, Batch Loss: 68445.8828
# Epoch 107, Batch 13/49, Batch Loss: 68359.1641
# Epoch 107, Batch 14/49, Batch Loss: 70074.5000
# Epoch 107, Batch 15/49, Batch Loss: 67907.9609
# Epoch 107, Batch 16/49, Batch Loss: 48052.4570
# Epoch 107, Batch 17/49, Batch Loss: 73260.7656
# Epoch 107, Batch 18/49, Batch Loss: 67536.1641
# Epoch 107, Batch 19/49, Batch Loss: 82970.4219
# Epoch 107, Batch 20/49, Batch Loss: 69816.5938
# Epoch 107, Batch 21/49, Batch Loss: 85985.8984
# Epoch 107, Batch 22/49, Batch Loss: 65599.2812
# Epoch 107, Batch 23/49, Batch Loss: 78881.6328
# Epoch 107, Batch 24/49, Batch Loss: 73055.3438
# Epoch 107, Batch 25/49, Batch Loss: 55359.8789
# Epoch 107, Batch 26/49, Batch Loss: 85365.6562
# Epoch 107, Batch 27/49, Batch Loss: 64356.8867
# Epoch 107, Batch 28/49, Batch Loss: 68411.5938
# Epoch 107, Batch 29/49, Batch Loss: 98269.3906
# Epoch 107, Batch 30/49, Batch Loss: 84004.3281
# Epoch 107, Batch 31/49, Batch Loss: 63168.0000
# Epoch 107, Batch 32/49, Batch Loss: 66649.2578
# Epoch 107, Batch 33/49, Batch Loss: 81215.5703
# Epoch 107, Batch 34/49, Batch Loss: 81324.5781
# Epoch 107, Batch 35/49, Batch Loss: 99320.9531
# Epoch 107, Batch 36/49, Batch Loss: 80508.0938
# Epoch 107, Batch 37/49, Batch Loss: 71817.1328
# Epoch 107, Batch 38/49, Batch Loss: 73671.4297
# Epoch 107, Batch 39/49, Batch Loss: 48499.8555
# Epoch 107, Batch 40/49, Batch Loss: 93351.7812
# Epoch 107, Batch 41/49, Batch Loss: 98003.3438
# Epoch 107, Batch 42/49, Batch Loss: 85986.6641
# Epoch 107, Batch 43/49, Batch Loss: 70084.4297
# Epoch 107, Batch 44/49, Batch Loss: 57801.8750
# Epoch 107, Batch 45/49, Batch Loss: 84350.4375
# Epoch 107, Batch 46/49, Batch Loss: 76837.1797
# Epoch 107, Batch 47/49, Batch Loss: 78125.6172
# Epoch 107, Batch 48/49, Batch Loss: 53647.4102
# Epoch 107, Batch 49/49, Batch Loss: 63731.1836
# Batch 1/17, Batch Loss: 49407.7266
# Batch 2/17, Batch Loss: 299655.8750
# Batch 3/17, Batch Loss: 216244.4531
# Batch 4/17, Batch Loss: 124813.4844
# Batch 5/17, Batch Loss: 273131.4688
# Batch 6/17, Batch Loss: 337589.7812
# Batch 7/17, Batch Loss: 110155.7891
# Batch 8/17, Batch Loss: 225030.4531
# Batch 9/17, Batch Loss: 314085.9375
# Batch 10/17, Batch Loss: 186688.3125
# Batch 11/17, Batch Loss: 273142.5938
# Batch 12/17, Batch Loss: 173806.4375
# Batch 13/17, Batch Loss: 186721.0000
# Batch 14/17, Batch Loss: 360619.0312
# Batch 15/17, Batch Loss: 167281.0625
# Batch 16/17, Batch Loss: 280489.4062
# Batch 17/17, Batch Loss: 170317.3750
# Test Error:
#  Avg loss: 220540.011029, Avg error: 134195.979239
#
# Epoch 108, Batch 1/49, Batch Loss: 88646.3672
# Epoch 108, Batch 2/49, Batch Loss: 112161.0078
# Epoch 108, Batch 3/49, Batch Loss: 103016.0234
# Epoch 108, Batch 4/49, Batch Loss: 97609.0234
# Epoch 108, Batch 5/49, Batch Loss: 72591.6797
# Epoch 108, Batch 6/49, Batch Loss: 67766.2734
# Epoch 108, Batch 7/49, Batch Loss: 64513.3242
# Epoch 108, Batch 8/49, Batch Loss: 90764.2266
# Epoch 108, Batch 9/49, Batch Loss: 101008.9297
# Epoch 108, Batch 10/49, Batch Loss: 104175.0938
# Epoch 108, Batch 11/49, Batch Loss: 87940.0547
# Epoch 108, Batch 12/49, Batch Loss: 63753.3047
# Epoch 108, Batch 13/49, Batch Loss: 75083.5547
# Epoch 108, Batch 14/49, Batch Loss: 73466.4219
# Epoch 108, Batch 15/49, Batch Loss: 83237.7734
# Epoch 108, Batch 16/49, Batch Loss: 69480.0703
# Epoch 108, Batch 17/49, Batch Loss: 91023.2891
# Epoch 108, Batch 18/49, Batch Loss: 93132.4297
# Epoch 108, Batch 19/49, Batch Loss: 66256.2812
# Epoch 108, Batch 20/49, Batch Loss: 78139.0703
# Epoch 108, Batch 21/49, Batch Loss: 166435.7812
# Epoch 108, Batch 22/49, Batch Loss: 64874.7031
# Epoch 108, Batch 23/49, Batch Loss: 79495.0625
# Epoch 108, Batch 24/49, Batch Loss: 72312.1797
# Epoch 108, Batch 25/49, Batch Loss: 141526.8906
# Epoch 108, Batch 26/49, Batch Loss: 113262.3281
# Epoch 108, Batch 27/49, Batch Loss: 74671.1016
# Epoch 108, Batch 28/49, Batch Loss: 70171.0234
# Epoch 108, Batch 29/49, Batch Loss: 83081.7266
# Epoch 108, Batch 30/49, Batch Loss: 55339.7656
# Epoch 108, Batch 31/49, Batch Loss: 68465.4688
# Epoch 108, Batch 32/49, Batch Loss: 80059.8281
# Epoch 108, Batch 33/49, Batch Loss: 80711.4922
# Epoch 108, Batch 34/49, Batch Loss: 85053.7656
# Epoch 108, Batch 35/49, Batch Loss: 73917.8594
# Epoch 108, Batch 36/49, Batch Loss: 87715.8047
# Epoch 108, Batch 37/49, Batch Loss: 70230.9375
# Epoch 108, Batch 38/49, Batch Loss: 57660.5977
# Epoch 108, Batch 39/49, Batch Loss: 85099.8359
# Epoch 108, Batch 40/49, Batch Loss: 60833.6055
# Epoch 108, Batch 41/49, Batch Loss: 71570.0312
# Epoch 108, Batch 42/49, Batch Loss: 83522.5391
# Epoch 108, Batch 43/49, Batch Loss: 64052.3984
# Epoch 108, Batch 44/49, Batch Loss: 73947.2109
# Epoch 108, Batch 45/49, Batch Loss: 99579.7969
# Epoch 108, Batch 46/49, Batch Loss: 196603.0312
# Epoch 108, Batch 47/49, Batch Loss: 66949.9453
# Epoch 108, Batch 48/49, Batch Loss: 74220.7031
# Epoch 108, Batch 49/49, Batch Loss: 90376.1953
# Batch 1/17, Batch Loss: 59208.4570
# Batch 2/17, Batch Loss: 288631.5938
# Batch 3/17, Batch Loss: 211836.8125
# Batch 4/17, Batch Loss: 161702.9062
# Batch 5/17, Batch Loss: 327034.7500
# Batch 6/17, Batch Loss: 339032.5000
# Batch 7/17, Batch Loss: 140135.9375
# Batch 8/17, Batch Loss: 115076.6953
# Batch 9/17, Batch Loss: 303510.4062
# Batch 10/17, Batch Loss: 185277.4375
# Batch 11/17, Batch Loss: 218877.3281
# Batch 12/17, Batch Loss: 149765.3438
# Batch 13/17, Batch Loss: 184775.1562
# Batch 14/17, Batch Loss: 226967.1406
# Batch 15/17, Batch Loss: 160165.9219
# Batch 16/17, Batch Loss: 295682.8750
# Batch 17/17, Batch Loss: 159289.8125
# Test Error:
#  Avg loss: 207468.886719, Avg error: 131712.172794
#
# Epoch 109, Batch 1/49, Batch Loss: 103435.5859
# Epoch 109, Batch 2/49, Batch Loss: 66765.7500
# Epoch 109, Batch 3/49, Batch Loss: 60068.7734
# Epoch 109, Batch 4/49, Batch Loss: 108992.5625
# Epoch 109, Batch 5/49, Batch Loss: 140918.6094
# Epoch 109, Batch 6/49, Batch Loss: 58254.8555
# Epoch 109, Batch 7/49, Batch Loss: 54102.8359
# Epoch 109, Batch 8/49, Batch Loss: 60040.2227
# Epoch 109, Batch 9/49, Batch Loss: 76798.6250
# Epoch 109, Batch 10/49, Batch Loss: 128986.4375
# Epoch 109, Batch 11/49, Batch Loss: 103768.8594
# Epoch 109, Batch 12/49, Batch Loss: 51538.8906
# Epoch 109, Batch 13/49, Batch Loss: 82403.2266
# Epoch 109, Batch 14/49, Batch Loss: 64738.7773
# Epoch 109, Batch 15/49, Batch Loss: 71106.7812
# Epoch 109, Batch 16/49, Batch Loss: 61098.9141
# Epoch 109, Batch 17/49, Batch Loss: 90995.5312
# Epoch 109, Batch 18/49, Batch Loss: 63915.8516
# Epoch 109, Batch 19/49, Batch Loss: 88152.2969
# Epoch 109, Batch 20/49, Batch Loss: 63724.7930
# Epoch 109, Batch 21/49, Batch Loss: 76084.3672
# Epoch 109, Batch 22/49, Batch Loss: 51725.7539
# Epoch 109, Batch 23/49, Batch Loss: 59641.9414
# Epoch 109, Batch 24/49, Batch Loss: 86118.9141
# Epoch 109, Batch 25/49, Batch Loss: 57266.8711
# Epoch 109, Batch 26/49, Batch Loss: 51517.0703
# Epoch 109, Batch 27/49, Batch Loss: 68523.8750
# Epoch 109, Batch 28/49, Batch Loss: 90533.0000
# Epoch 109, Batch 29/49, Batch Loss: 56840.4336
# Epoch 109, Batch 30/49, Batch Loss: 111041.5000
# Epoch 109, Batch 31/49, Batch Loss: 68572.1641
# Epoch 109, Batch 32/49, Batch Loss: 89861.4297
# Epoch 109, Batch 33/49, Batch Loss: 68782.8516
# Epoch 109, Batch 34/49, Batch Loss: 121260.6953
# Epoch 109, Batch 35/49, Batch Loss: 118446.5703
# Epoch 109, Batch 36/49, Batch Loss: 87821.5859
# Epoch 109, Batch 37/49, Batch Loss: 98658.8047
# Epoch 109, Batch 38/49, Batch Loss: 96078.3203
# Epoch 109, Batch 39/49, Batch Loss: 80878.5000
# Epoch 109, Batch 40/49, Batch Loss: 111692.3594
# Epoch 109, Batch 41/49, Batch Loss: 47480.0195
# Epoch 109, Batch 42/49, Batch Loss: 61861.9219
# Epoch 109, Batch 43/49, Batch Loss: 80423.7734
# Epoch 109, Batch 44/49, Batch Loss: 113480.7812
# Epoch 109, Batch 45/49, Batch Loss: 76156.7344
# Epoch 109, Batch 46/49, Batch Loss: 86074.5156
# Epoch 109, Batch 47/49, Batch Loss: 87913.3672
# Epoch 109, Batch 48/49, Batch Loss: 75190.9375
# Epoch 109, Batch 49/49, Batch Loss: 62623.5859
# Batch 1/17, Batch Loss: 92125.6328
# Batch 2/17, Batch Loss: 322722.7188
# Batch 3/17, Batch Loss: 266087.0000
# ...
# Epoch 160, Batch 44/49, Batch Loss: 47980.2461
# Epoch 160, Batch 45/49, Batch Loss: 58733.2773
# Epoch 160, Batch 46/49, Batch Loss: 73003.5547
# Epoch 160, Batch 47/49, Batch Loss: 91218.7266
# Epoch 160, Batch 48/49, Batch Loss: 80408.8047
# Epoch 160, Batch 49/49, Batch Loss: 89492.9219
# Batch 1/17, Batch Loss: 102562.0234
# Batch 2/17, Batch Loss: 284756.9375
# Batch 3/17, Batch Loss: 241604.1562
# Batch 4/17, Batch Loss: 113827.0469
# Batch 5/17, Batch Loss: 159371.0156
# Batch 6/17, Batch Loss: 351321.2812
# Batch 7/17, Batch Loss: 177500.6875
# Batch 8/17, Batch Loss: 242368.9062
# Batch 9/17, Batch Loss: 319487.2812
# Batch 10/17, Batch Loss: 154658.1562
# Batch 11/17, Batch Loss: 270808.5000
# Batch 12/17, Batch Loss: 154370.6406
# Batch 13/17, Batch Loss: 163118.8438
# Batch 14/17, Batch Loss: 268741.6875
# Batch 15/17, Batch Loss: 178895.3125
# Batch 16/17, Batch Loss: 324341.3125
# Batch 17/17, Batch Loss: 150450.0938
# Test Error:
#  Avg loss: 215187.287224, Avg error: 149382.535467
#
# 2024-09-27 16:32:30.879505 Epoch 160, Average Training loss 70623.93279655612
# Epoch 161, Batch 1/49, Batch Loss: 96805.0938
# Epoch 161, Batch 2/49, Batch Loss: 52681.3203
# Epoch 161, Batch 3/49, Batch Loss: 58140.4062
# Epoch 161, Batch 4/49, Batch Loss: 73406.9688
# Epoch 161, Batch 5/49, Batch Loss: 63597.0625
# Epoch 161, Batch 6/49, Batch Loss: 65840.1094
# Epoch 161, Batch 7/49, Batch Loss: 85617.0391
# Epoch 161, Batch 8/49, Batch Loss: 62642.4531
# Epoch 161, Batch 9/49, Batch Loss: 81204.8281
# Epoch 161, Batch 10/49, Batch Loss: 70752.4844
# Epoch 161, Batch 11/49, Batch Loss: 91197.8594
# Epoch 161, Batch 12/49, Batch Loss: 81024.0234
# Epoch 161, Batch 13/49, Batch Loss: 111382.2891
# Epoch 161, Batch 14/49, Batch Loss: 58607.9688
# Epoch 161, Batch 15/49, Batch Loss: 96551.2969
# Epoch 161, Batch 16/49, Batch Loss: 56383.1133
# Epoch 161, Batch 17/49, Batch Loss: 116330.5078
# Epoch 161, Batch 18/49, Batch Loss: 66230.0547
# Epoch 161, Batch 19/49, Batch Loss: 89665.2656
# Epoch 161, Batch 20/49, Batch Loss: 60442.4492
# Epoch 161, Batch 21/49, Batch Loss: 53097.4492
# Epoch 161, Batch 22/49, Batch Loss: 63165.3438
# Epoch 161, Batch 23/49, Batch Loss: 63133.2461
# Epoch 161, Batch 24/49, Batch Loss: 63937.2539
# Epoch 161, Batch 25/49, Batch Loss: 93810.4688
# Epoch 161, Batch 26/49, Batch Loss: 84017.4844
# Epoch 161, Batch 27/49, Batch Loss: 99004.6875
# Epoch 161, Batch 28/49, Batch Loss: 112016.0000
# Epoch 161, Batch 29/49, Batch Loss: 73583.3594
# Epoch 161, Batch 30/49, Batch Loss: 70080.1484
# Epoch 161, Batch 31/49, Batch Loss: 64679.8633
# Epoch 161, Batch 32/49, Batch Loss: 55776.4375
# Epoch 161, Batch 33/49, Batch Loss: 68184.9688
# Epoch 161, Batch 34/49, Batch Loss: 66111.5469
# Epoch 161, Batch 35/49, Batch Loss: 105639.2266
# Epoch 161, Batch 36/49, Batch Loss: 75595.7891
# Epoch 161, Batch 37/49, Batch Loss: 135920.0625
# Epoch 161, Batch 38/49, Batch Loss: 142239.1250
# Epoch 161, Batch 39/49, Batch Loss: 57383.0508
# Epoch 161, Batch 40/49, Batch Loss: 80280.2734
# Epoch 161, Batch 41/49, Batch Loss: 84165.2891
# Epoch 161, Batch 42/49, Batch Loss: 76644.7891
# Epoch 161, Batch 43/49, Batch Loss: 65311.4062
# Epoch 161, Batch 44/49, Batch Loss: 65541.8594
# Epoch 161, Batch 45/49, Batch Loss: 64382.6562
# Epoch 161, Batch 46/49, Batch Loss: 72171.6875
# Epoch 161, Batch 47/49, Batch Loss: 205629.3594
# Epoch 161, Batch 48/49, Batch Loss: 64947.0781
# Epoch 161, Batch 49/49, Batch Loss: 51744.2617
# Batch 1/17, Batch Loss: 58859.1133
# Batch 2/17, Batch Loss: 274208.2812
# Batch 3/17, Batch Loss: 198793.4062
# Batch 4/17, Batch Loss: 103622.3281
# Batch 5/17, Batch Loss: 330467.8438
# Batch 6/17, Batch Loss: 289393.0312
# Batch 7/17, Batch Loss: 109538.7656
# Batch 8/17, Batch Loss: 232455.3438
# Batch 9/17, Batch Loss: 282889.0625
# Batch 10/17, Batch Loss: 185582.9688
# Batch 11/17, Batch Loss: 235775.2031
# Batch 12/17, Batch Loss: 163100.1406
# Batch 13/17, Batch Loss: 182214.5625
# Batch 14/17, Batch Loss: 321156.2188
# Batch 15/17, Batch Loss: 139531.7500
# Batch 16/17, Batch Loss: 276475.9375
# Batch 17/17, Batch Loss: 119201.8594
# Test Error:
#  Avg loss: 206074.459789, Avg error: 126818.390138
#
# Epoch 162, Batch 1/49, Batch Loss: 79189.1953
# Epoch 162, Batch 2/49, Batch Loss: 67671.5312
# Epoch 162, Batch 3/49, Batch Loss: 126684.4766
# Epoch 162, Batch 4/49, Batch Loss: 79890.8906
# Epoch 162, Batch 5/49, Batch Loss: 63887.9961
# Epoch 162, Batch 6/49, Batch Loss: 71616.1328
# Epoch 162, Batch 7/49, Batch Loss: 77178.8125
# Epoch 162, Batch 8/49, Batch Loss: 63067.5156
# Epoch 162, Batch 9/49, Batch Loss: 77127.3516
# Epoch 162, Batch 10/49, Batch Loss: 51265.8984
# Epoch 162, Batch 11/49, Batch Loss: 91682.2031
# Epoch 162, Batch 12/49, Batch Loss: 67309.4531
# Epoch 162, Batch 13/49, Batch Loss: 72672.3672
# Epoch 162, Batch 14/49, Batch Loss: 79502.0469
# Epoch 162, Batch 15/49, Batch Loss: 70791.5938
# Epoch 162, Batch 16/49, Batch Loss: 58589.2812
# Epoch 162, Batch 17/49, Batch Loss: 90362.8984
# Epoch 162, Batch 18/49, Batch Loss: 52021.8984
# Epoch 162, Batch 19/49, Batch Loss: 77963.7969
# Epoch 162, Batch 20/49, Batch Loss: 71754.6328
# Epoch 162, Batch 21/49, Batch Loss: 96929.8594
# Epoch 162, Batch 22/49, Batch Loss: 109877.2031
# Epoch 162, Batch 23/49, Batch Loss: 55817.5703
# Epoch 162, Batch 24/49, Batch Loss: 120285.9062
# Epoch 162, Batch 25/49, Batch Loss: 76659.4141
# Epoch 162, Batch 26/49, Batch Loss: 67592.8594
# Epoch 162, Batch 27/49, Batch Loss: 50311.4297
# Epoch 162, Batch 28/49, Batch Loss: 56115.3359
# Epoch 162, Batch 29/49, Batch Loss: 74057.9688
# Epoch 162, Batch 30/49, Batch Loss: 78387.6406
# Epoch 162, Batch 31/49, Batch Loss: 123505.0156
# Epoch 162, Batch 32/49, Batch Loss: 78709.0156
# Epoch 162, Batch 33/49, Batch Loss: 45292.3242
# Epoch 162, Batch 34/49, Batch Loss: 77912.9219
# Epoch 162, Batch 35/49, Batch Loss: 71902.7188
# Epoch 162, Batch 36/49, Batch Loss: 65632.3359
# Epoch 162, Batch 37/49, Batch Loss: 60056.4414
# Epoch 162, Batch 38/49, Batch Loss: 71440.4766
# Epoch 162, Batch 39/49, Batch Loss: 59291.3906
# Epoch 162, Batch 40/49, Batch Loss: 67197.4609
# Epoch 162, Batch 41/49, Batch Loss: 79961.2188
# Epoch 162, Batch 42/49, Batch Loss: 66149.7891
# Epoch 162, Batch 43/49, Batch Loss: 55891.6875
# Epoch 162, Batch 44/49, Batch Loss: 78312.8906
# Epoch 162, Batch 45/49, Batch Loss: 59723.5859
# Epoch 162, Batch 46/49, Batch Loss: 67877.2422
# Epoch 162, Batch 47/49, Batch Loss: 101443.4609
# Epoch 162, Batch 48/49, Batch Loss: 57569.0312
# Epoch 162, Batch 49/49, Batch Loss: 58982.4922
# Batch 1/17, Batch Loss: 83239.9453
# Batch 2/17, Batch Loss: 283379.8750
# Batch 3/17, Batch Loss: 221451.8750
# Batch 4/17, Batch Loss: 129642.9062
# Batch 5/17, Batch Loss: 247068.7031
# Batch 6/17, Batch Loss: 314587.0312
# Batch 7/17, Batch Loss: 156396.9375
# Batch 8/17, Batch Loss: 243521.4844
# Batch 9/17, Batch Loss: 295327.3125
# Batch 10/17, Batch Loss: 184410.7812
# Batch 11/17, Batch Loss: 252762.7656
# Batch 12/17, Batch Loss: 183528.5000
# Batch 13/17, Batch Loss: 146798.1875
# Batch 14/17, Batch Loss: 264155.3125
# Batch 15/17, Batch Loss: 178139.6562
# Batch 16/17, Batch Loss: 314255.9062
# Batch 17/17, Batch Loss: 152477.5469
# Test Error:
#  Avg loss: 214773.219210, Avg error: 143927.720588
#
# Epoch 163, Batch 1/49, Batch Loss: 50901.3789
# Epoch 163, Batch 2/49, Batch Loss: 60161.9688
# Epoch 163, Batch 3/49, Batch Loss: 74369.4688
# Epoch 163, Batch 4/49, Batch Loss: 131910.7344
# Epoch 163, Batch 5/49, Batch Loss: 68446.0156
# Epoch 163, Batch 6/49, Batch Loss: 64228.4453
# Epoch 163, Batch 7/49, Batch Loss: 74950.2656
# Epoch 163, Batch 8/49, Batch Loss: 55139.7031
# Epoch 163, Batch 9/49, Batch Loss: 62200.6328
# Epoch 163, Batch 10/49, Batch Loss: 74628.0938
# Epoch 163, Batch 11/49, Batch Loss: 76597.3359
# Epoch 163, Batch 12/49, Batch Loss: 66988.0156
# Epoch 163, Batch 13/49, Batch Loss: 80791.3984
# Epoch 163, Batch 14/49, Batch Loss: 107846.1016
# Epoch 163, Batch 15/49, Batch Loss: 60935.0078
# Epoch 163, Batch 16/49, Batch Loss: 60974.1172
# Epoch 163, Batch 17/49, Batch Loss: 113701.3750
# Epoch 163, Batch 18/49, Batch Loss: 57166.6602
# Epoch 163, Batch 19/49, Batch Loss: 46040.7773
# Epoch 163, Batch 20/49, Batch Loss: 77586.0469
# Epoch 163, Batch 21/49, Batch Loss: 69399.0625
# Epoch 163, Batch 22/49, Batch Loss: 87919.1797
# Epoch 163, Batch 23/49, Batch Loss: 60776.8164
# Epoch 163, Batch 24/49, Batch Loss: 56239.3477
# Epoch 163, Batch 25/49, Batch Loss: 56400.3086
# Epoch 163, Batch 26/49, Batch Loss: 64024.3125
# Epoch 163, Batch 27/49, Batch Loss: 62985.8867
# Epoch 163, Batch 28/49, Batch Loss: 52919.4102
# Epoch 163, Batch 29/49, Batch Loss: 63996.9297
# Epoch 163, Batch 30/49, Batch Loss: 73359.1328
# Epoch 163, Batch 31/49, Batch Loss: 56293.3047
# Epoch 163, Batch 32/49, Batch Loss: 74853.8984
# Epoch 163, Batch 33/49, Batch Loss: 61659.8164
# Epoch 163, Batch 34/49, Batch Loss: 115127.1484
# Epoch 163, Batch 35/49, Batch Loss: 63795.0312
# Epoch 163, Batch 36/49, Batch Loss: 73035.8203
# Epoch 163, Batch 37/49, Batch Loss: 63694.4883
# Epoch 163, Batch 38/49, Batch Loss: 83677.1875
# Epoch 163, Batch 39/49, Batch Loss: 76068.9609
# Epoch 163, Batch 40/49, Batch Loss: 61262.6797
# Epoch 163, Batch 41/49, Batch Loss: 70246.6094
# Epoch 163, Batch 42/49, Batch Loss: 103539.3750
# Epoch 163, Batch 43/49, Batch Loss: 132028.6719
# Epoch 163, Batch 44/49, Batch Loss: 62243.0391
# Epoch 163, Batch 45/49, Batch Loss: 75662.2188
# Epoch 163, Batch 46/49, Batch Loss: 84485.0391
# Epoch 163, Batch 47/49, Batch Loss: 82819.3984
# Epoch 163, Batch 48/49, Batch Loss: 69668.3828
# Epoch 163, Batch 49/49, Batch Loss: 71637.5000
# Batch 1/17, Batch Loss: 72008.9844
# Batch 2/17, Batch Loss: 282774.0938
# Batch 3/17, Batch Loss: 209187.9688
# Batch 4/17, Batch Loss: 135422.4219
# Batch 5/17, Batch Loss: 293684.3125
# Batch 6/17, Batch Loss: 280626.8125
# Batch 7/17, Batch Loss: 157122.8594
# Batch 8/17, Batch Loss: 226054.4219
# Batch 9/17, Batch Loss: 292684.2188
# Batch 10/17, Batch Loss: 139046.6094
# Batch 11/17, Batch Loss: 238008.1875
# Batch 12/17, Batch Loss: 165683.3281
# Batch 13/17, Batch Loss: 198454.1250
# Batch 14/17, Batch Loss: 223274.1562
# Batch 15/17, Batch Loss: 174606.0000
# Batch 16/17, Batch Loss: 299186.2812
# Batch 17/17, Batch Loss: 123089.2578
# Test Error:
#  Avg loss: 206524.355239, Avg error: 124990.006272
#
# Epoch 164, Batch 1/49, Batch Loss: 65202.9297
# Epoch 164, Batch 2/49, Batch Loss: 101924.7578
# Epoch 164, Batch 3/49, Batch Loss: 50574.8867
# Epoch 164, Batch 4/49, Batch Loss: 56492.0625
# Epoch 164, Batch 5/49, Batch Loss: 228768.3594
# Epoch 164, Batch 6/49, Batch Loss: 62672.6055
# Epoch 164, Batch 7/49, Batch Loss: 59945.6172
# Epoch 164, Batch 8/49, Batch Loss: 73643.2891
# Epoch 164, Batch 9/49, Batch Loss: 52008.6016
# Epoch 164, Batch 10/49, Batch Loss: 65851.9844
# Epoch 164, Batch 11/49, Batch Loss: 89782.7266
# Epoch 164, Batch 12/49, Batch Loss: 51224.0859
# Epoch 164, Batch 13/49, Batch Loss: 70390.2891
# Epoch 164, Batch 14/49, Batch Loss: 61074.9062
# Epoch 164, Batch 15/49, Batch Loss: 55672.8750
# Epoch 164, Batch 16/49, Batch Loss: 73119.5078
# Epoch 164, Batch 17/49, Batch Loss: 53302.8477
# Epoch 164, Batch 18/49, Batch Loss: 87974.3750
# Epoch 164, Batch 19/49, Batch Loss: 49945.8945
# Epoch 164, Batch 20/49, Batch Loss: 72720.0078
# Epoch 164, Batch 21/49, Batch Loss: 60796.6406
# Epoch 164, Batch 22/49, Batch Loss: 71451.3438
# Epoch 164, Batch 23/49, Batch Loss: 60293.7852
# Epoch 164, Batch 24/49, Batch Loss: 76235.5156
# Epoch 164, Batch 25/49, Batch Loss: 119008.1406
# Epoch 164, Batch 26/49, Batch Loss: 83835.9688
# Epoch 164, Batch 27/49, Batch Loss: 55138.5312
# Epoch 164, Batch 28/49, Batch Loss: 79910.0781
# Epoch 164, Batch 29/49, Batch Loss: 54094.4805
# Epoch 164, Batch 30/49, Batch Loss: 80989.7734
# Epoch 164, Batch 31/49, Batch Loss: 71363.9219
# Epoch 164, Batch 32/49, Batch Loss: 64882.7578
# Epoch 164, Batch 33/49, Batch Loss: 59673.4102
# Epoch 164, Batch 34/49, Batch Loss: 72295.6328
# Epoch 164, Batch 35/49, Batch Loss: 62467.9492
# Epoch 164, Batch 36/49, Batch Loss: 47206.0781
# Epoch 164, Batch 37/49, Batch Loss: 37274.4922
# Epoch 164, Batch 38/49, Batch Loss: 70573.2031
# Epoch 164, Batch 39/49, Batch Loss: 94121.4766
# Epoch 164, Batch 40/49, Batch Loss: 59172.3672
# Epoch 164, Batch 41/49, Batch Loss: 80644.9062
# Epoch 164, Batch 42/49, Batch Loss: 158717.2344
# Epoch 164, Batch 43/49, Batch Loss: 85226.6797
# Epoch 164, Batch 44/49, Batch Loss: 123298.9844
# Epoch 164, Batch 45/49, Batch Loss: 61408.3555
# Epoch 164, Batch 46/49, Batch Loss: 69252.1875
# Epoch 164, Batch 47/49, Batch Loss: 65308.5234
# Epoch 164, Batch 48/49, Batch Loss: 136397.9219
# Epoch 164, Batch 49/49, Batch Loss: 63453.3320
# Batch 1/17, Batch Loss: 78524.6406
# Batch 2/17, Batch Loss: 285696.1875
# Batch 3/17, Batch Loss: 223223.7344
# Batch 4/17, Batch Loss: 129779.7344
# Batch 5/17, Batch Loss: 297291.0625
# Batch 6/17, Batch Loss: 316876.4375
# Batch 7/17, Batch Loss: 171209.3125
# Batch 8/17, Batch Loss: 230139.2344
# Batch 9/17, Batch Loss: 306485.3438
# Batch 10/17, Batch Loss: 99326.6172
# Batch 11/17, Batch Loss: 244827.0312
# Batch 12/17, Batch Loss: 175576.2812
# Batch 13/17, Batch Loss: 191315.7500
# Batch 14/17, Batch Loss: 243413.6094
# Batch 15/17, Batch Loss: 145997.2500
# Batch 16/17, Batch Loss: 265357.1250
# Batch 17/17, Batch Loss: 147278.9531
# Test Error:
#  Avg loss: 208959.900276, Avg error: 132770.185986
#
# Epoch 165, Batch 1/49, Batch Loss: 78758.2031
# Epoch 165, Batch 2/49, Batch Loss: 66558.0547
# Epoch 165, Batch 3/49, Batch Loss: 61958.0625
# Epoch 165, Batch 4/49, Batch Loss: 66228.6016
# Epoch 165, Batch 5/49, Batch Loss: 68410.2734
# Epoch 165, Batch 6/49, Batch Loss: 71127.1641
# Epoch 165, Batch 7/49, Batch Loss: 58348.4492
# Epoch 165, Batch 8/49, Batch Loss: 63891.8477
# Epoch 165, Batch 9/49, Batch Loss: 56148.0078
# Epoch 165, Batch 10/49, Batch Loss: 142171.2656
# Epoch 165, Batch 11/49, Batch Loss: 63806.1992
# Epoch 165, Batch 12/49, Batch Loss: 57788.0469
# Epoch 165, Batch 13/49, Batch Loss: 59449.5977
# Epoch 165, Batch 14/49, Batch Loss: 44994.8945
# Epoch 165, Batch 15/49, Batch Loss: 93032.6094
# Epoch 165, Batch 16/49, Batch Loss: 76116.9375
# Epoch 165, Batch 17/49, Batch Loss: 62441.5820
# Epoch 165, Batch 18/49, Batch Loss: 70237.9375
# Epoch 165, Batch 19/49, Batch Loss: 71618.3750
# Epoch 165, Batch 20/49, Batch Loss: 147372.8594
# Epoch 165, Batch 21/49, Batch Loss: 75941.4453
# Epoch 165, Batch 22/49, Batch Loss: 95411.5547
# Epoch 165, Batch 23/49, Batch Loss: 96111.3047
# Epoch 165, Batch 24/49, Batch Loss: 64349.1992
# Epoch 165, Batch 25/49, Batch Loss: 55073.1719
# Epoch 165, Batch 26/49, Batch Loss: 89118.7969
# Epoch 165, Batch 27/49, Batch Loss: 51908.1719
# Epoch 165, Batch 28/49, Batch Loss: 62270.1250
# Epoch 165, Batch 29/49, Batch Loss: 75112.9219
# Epoch 165, Batch 30/49, Batch Loss: 58256.6523
# Epoch 165, Batch 31/49, Batch Loss: 158097.4375
# Epoch 165, Batch 32/49, Batch Loss: 42004.4453
# Epoch 165, Batch 33/49, Batch Loss: 58303.9492
# Epoch 165, Batch 34/49, Batch Loss: 65509.3477
# Epoch 165, Batch 35/49, Batch Loss: 72724.8750
# Epoch 165, Batch 36/49, Batch Loss: 50297.1250
# Epoch 165, Batch 37/49, Batch Loss: 157663.2969
# Epoch 165, Batch 38/49, Batch Loss: 62792.5312
# Epoch 165, Batch 39/49, Batch Loss: 80382.0234
# Epoch 165, Batch 40/49, Batch Loss: 73675.9297
# Epoch 165, Batch 41/49, Batch Loss: 58140.5742
# Epoch 165, Batch 42/49, Batch Loss: 58506.4492
# Epoch 165, Batch 43/49, Batch Loss: 64993.2578
# Epoch 165, Batch 44/49, Batch Loss: 63545.0859
# Epoch 165, Batch 45/49, Batch Loss: 81389.4766
# Epoch 165, Batch 46/49, Batch Loss: 68367.3359
# Epoch 165, Batch 47/49, Batch Loss: 50202.1328
# Epoch 165, Batch 48/49, Batch Loss: 83730.5938
# Epoch 165, Batch 49/49, Batch Loss: 63747.2656
# Batch 1/17, Batch Loss: 69085.9844
# Batch 2/17, Batch Loss: 271108.0312
# Batch 3/17, Batch Loss: 211744.9219
# Batch 4/17, Batch Loss: 97381.1016
# Batch 5/17, Batch Loss: 350083.1562
# Batch 6/17, Batch Loss: 285066.3750
# Batch 7/17, Batch Loss: 165486.3594
# Batch 8/17, Batch Loss: 217463.1719
# Batch 9/17, Batch Loss: 222243.0000
# Batch 10/17, Batch Loss: 129373.4922
# Batch 11/17, Batch Loss: 216050.4844
# Batch 12/17, Batch Loss: 168705.7344
# Batch 13/17, Batch Loss: 150204.5156
# Batch 14/17, Batch Loss: 182150.8750
# Batch 15/17, Batch Loss: 160889.7656
# Batch 16/17, Batch Loss: 298945.1875
# Batch 17/17, Batch Loss: 110998.2734
# Test Error:
#  Avg loss: 194528.260570, Avg error: 119199.125865

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        2.5         3  1915    92021      117.png   485000
# 1        2.5         3  2248    92677      132.png  1199000
# 2        1.0         3  1132    96019      154.png   170000
# 3        4.0         6  3375    92880      245.png   538000
# 4        2.5         3  2733    91901       84.png   689000

# %%
len(test)
# Out:
# 54

# %%
# Crear dataset
test_data = CustomImageDataset(df=test)

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
len(test_loader)
# Out:
# 6

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 358747.53125, Valor real: 485000.0
# Predicción: 411566.03125, Valor real: 1199000.0
# Predicción: 188643.0625, Valor real: 170000.0
# Predicción: 418016.75, Valor real: 538000.0
# Predicción: 447500.1875, Valor real: 689000.0
# Predicción: 205532.890625, Valor real: 118900.0
# Predicción: 597498.125, Valor real: 799000.0
# Predicción: 449125.25, Valor real: 895000.0
# Predicción: 573553.1875, Valor real: 599000.0
# Predicción: 290732.3125, Valor real: 535000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 346564.0312
# MAE en el conjunto de prueba: 224922.0000

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
