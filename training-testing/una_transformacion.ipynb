# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %%
# Definir si viene desde local o drive
ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train y test

# %%
train = pd.read_csv(f'{ruta}train.csv')
test = pd.read_csv(f'{ruta}test.csv')

train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bathrooms     481 non-null    float64
#  1   bedrooms      481 non-null    int64
#  2   area          481 non-null    int64
#  3   zipcode       481 non-null    int64
#  4   mosaic_image  481 non-null    object
#  5   price         481 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 22.7+ KB

# %% [markdown]
# ## Preparar Dataset

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %% [markdown]
# ## Aumentar datos

# %%
data = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %% [markdown]
# ## Ver imagenes de cada data

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1)  # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)    # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None):
    # Deshacer la normalización
    image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))  # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')  # Quitar los ejes
    plt.show()

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data]
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    show_image(image, title=f"Imagen de data{i}")

# %% [markdown]
# ## Dividir en train y test

# %%
# Determinar el tamaño de los conjuntos de entrenamiento y validación
valor_train = int(0.9*len(data))
valor_val = len(data)-valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 432 Val: 49

# %%
# Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(data,[valor_train,valor_val])

# Eliminar las variables que ya no se necesitan
del data

# %%
# Crear los dataloaders
batch_size=64

train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True, drop_last=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size, shuffle=False)

print(f"Train: {len(train_data)} batches de tamaño {len(train_dataloader)}")
print(f"Val: {len(val_data)} batches de tamaño {len(val_dataloader)}")
# Out:
# Train: 432 batches de tamaño 6
# Val: 49 batches de tamaño 1

# %% [markdown]
# ## Red neuronal

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=5, stride=1, padding=2),   # 400x400
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 200x200
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 100x100
            nn.Dropout(),

            nn.Conv2d(128, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 50x50

            nn.Conv2d(128, 64, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                  # 25x25
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(37440, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 64*24*24)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
# Definir el dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))

# Definir el modelo, la función de pérdida y el optimizador
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)
optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Using cuda device

# %% [markdown]
# ## Ciclos de entrenamiento y pruebas

# %%
def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader):
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            l2_lambda = 0.001
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Entrenamiento

# %%
# Entrenamiento
n_epochs = 400
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader
)
# Out:
# Epoch 1, Batch 1/6, Batch Loss: 713118.0000
# Epoch 1, Batch 2/6, Batch Loss: 649839.0625
# Epoch 1, Batch 3/6, Batch Loss: 658342.1875
# Epoch 1, Batch 4/6, Batch Loss: 716126.8125
# Epoch 1, Batch 5/6, Batch Loss: 532216.0000
# Epoch 1, Batch 6/6, Batch Loss: 702861.9375
# Batch 1/1, Batch Loss: 678942.7500
# Test Error:
#  Avg loss: 678942.750000, Avg error: 627597.959184
#
# 2024-09-16 18:02:22.564980 Epoch 1, Average Training loss 662084.0
# Epoch 2, Batch 1/6, Batch Loss: 1400731.0000
# Epoch 2, Batch 2/6, Batch Loss: 597962.1250
# Epoch 2, Batch 3/6, Batch Loss: 496076.6875
# Epoch 2, Batch 4/6, Batch Loss: 472493.0625
# Epoch 2, Batch 5/6, Batch Loss: 595777.3125
# Epoch 2, Batch 6/6, Batch Loss: 919957.3125
# Batch 1/1, Batch Loss: 665631.9375
# Test Error:
#  Avg loss: 665631.937500, Avg error: 502375.755102
#
# Epoch 3, Batch 1/6, Batch Loss: 706876.0625
# Epoch 3, Batch 2/6, Batch Loss: 709375.4375
# Epoch 3, Batch 3/6, Batch Loss: 602727.6875
# Epoch 3, Batch 4/6, Batch Loss: 946671.0000
# Epoch 3, Batch 5/6, Batch Loss: 765069.6875
# Epoch 3, Batch 6/6, Batch Loss: 843855.6875
# Batch 1/1, Batch Loss: 675920.0000
# Test Error:
#  Avg loss: 675920.000000, Avg error: 515373.061224
#
# Epoch 4, Batch 1/6, Batch Loss: 935230.3750
# Epoch 4, Batch 2/6, Batch Loss: 782374.5625
# Epoch 4, Batch 3/6, Batch Loss: 737953.0625
# Epoch 4, Batch 4/6, Batch Loss: 779232.5000
# Epoch 4, Batch 5/6, Batch Loss: 587011.6250
# Epoch 4, Batch 6/6, Batch Loss: 916068.3125
# Batch 1/1, Batch Loss: 666602.5625
# Test Error:
#  Avg loss: 666602.562500, Avg error: 503575.265306
#
# Epoch 5, Batch 1/6, Batch Loss: 660584.9375
# Epoch 5, Batch 2/6, Batch Loss: 687231.4375
# Epoch 5, Batch 3/6, Batch Loss: 718214.3125
# Epoch 5, Batch 4/6, Batch Loss: 630514.5000
# Epoch 5, Batch 5/6, Batch Loss: 517895.0938
# Epoch 5, Batch 6/6, Batch Loss: 1026993.4375
# Batch 1/1, Batch Loss: 540425.5000
# Test Error:
#  Avg loss: 540425.500000, Avg error: 353049.632653
#
# Epoch 6, Batch 1/6, Batch Loss: 455172.3750
# Epoch 6, Batch 2/6, Batch Loss: 597703.8750
# Epoch 6, Batch 3/6, Batch Loss: 659088.7500
# Epoch 6, Batch 4/6, Batch Loss: 843992.3750
# Epoch 6, Batch 5/6, Batch Loss: 477537.2188
# Epoch 6, Batch 6/6, Batch Loss: 422433.3438
# Batch 1/1, Batch Loss: 541520.6250
# Test Error:
#  Avg loss: 541520.625000, Avg error: 353923.102041
#
# Epoch 7, Batch 1/6, Batch Loss: 721267.1875
# Epoch 7, Batch 2/6, Batch Loss: 447321.8125
# Epoch 7, Batch 3/6, Batch Loss: 382758.6562
# Epoch 7, Batch 4/6, Batch Loss: 505615.7812
# Epoch 7, Batch 5/6, Batch Loss: 598743.4375
# Epoch 7, Batch 6/6, Batch Loss: 339260.4062
# Batch 1/1, Batch Loss: 520720.1250
# Test Error:
#  Avg loss: 520720.125000, Avg error: 332587.142857
#
# Epoch 8, Batch 1/6, Batch Loss: 431741.5312
# Epoch 8, Batch 2/6, Batch Loss: 388700.2812
# Epoch 8, Batch 3/6, Batch Loss: 553897.4375
# Epoch 8, Batch 4/6, Batch Loss: 446404.9688
# Epoch 8, Batch 5/6, Batch Loss: 930192.5000
# Epoch 8, Batch 6/6, Batch Loss: 377621.1250
# Batch 1/1, Batch Loss: 513647.1562
# Test Error:
#  Avg loss: 513647.156250, Avg error: 326370.408163
#
# Epoch 9, Batch 1/6, Batch Loss: 484255.8438
# Epoch 9, Batch 2/6, Batch Loss: 589692.3750
# Epoch 9, Batch 3/6, Batch Loss: 389167.9375
# Epoch 9, Batch 4/6, Batch Loss: 773857.3750
# Epoch 9, Batch 5/6, Batch Loss: 477723.1875
# Epoch 9, Batch 6/6, Batch Loss: 385654.0625
# Batch 1/1, Batch Loss: 468498.3750
# Test Error:
#  Avg loss: 468498.375000, Avg error: 293934.061224
#
# Epoch 10, Batch 1/6, Batch Loss: 739615.3125
# Epoch 10, Batch 2/6, Batch Loss: 432391.0938
# Epoch 10, Batch 3/6, Batch Loss: 406688.8750
# Epoch 10, Batch 4/6, Batch Loss: 587130.0000
# Epoch 10, Batch 5/6, Batch Loss: 629496.6250
# Epoch 10, Batch 6/6, Batch Loss: 336304.4688
# Batch 1/1, Batch Loss: 497969.0312
# Test Error:
#  Avg loss: 497969.031250, Avg error: 312743.142857
#
# 2024-09-16 18:04:18.078300 Epoch 10, Average Training loss 521937.7291666667
# Epoch 11, Batch 1/6, Batch Loss: 718100.8750
# Epoch 11, Batch 2/6, Batch Loss: 514160.8438
# Epoch 11, Batch 3/6, Batch Loss: 433710.7500
# Epoch 11, Batch 4/6, Batch Loss: 599792.8125
# Epoch 11, Batch 5/6, Batch Loss: 469825.6875
# Epoch 11, Batch 6/6, Batch Loss: 400791.0000
# Batch 1/1, Batch Loss: 469376.6562
# Test Error:
#  Avg loss: 469376.656250, Avg error: 290392.734694
#
# Epoch 12, Batch 1/6, Batch Loss: 406212.5312
# Epoch 12, Batch 2/6, Batch Loss: 320344.2500
# Epoch 12, Batch 3/6, Batch Loss: 451517.5625
# Epoch 12, Batch 4/6, Batch Loss: 463467.4062
# Epoch 12, Batch 5/6, Batch Loss: 443070.3438
# Epoch 12, Batch 6/6, Batch Loss: 301198.8750
# Batch 1/1, Batch Loss: 451000.5938
# Test Error:
#  Avg loss: 451000.593750, Avg error: 275835.959184
#
# Epoch 13, Batch 1/6, Batch Loss: 604140.8750
# Epoch 13, Batch 2/6, Batch Loss: 581606.5000
# Epoch 13, Batch 3/6, Batch Loss: 762853.6250
# Epoch 13, Batch 4/6, Batch Loss: 407259.8438
# Epoch 13, Batch 5/6, Batch Loss: 335530.8438
# Epoch 13, Batch 6/6, Batch Loss: 360694.0938
# Batch 1/1, Batch Loss: 521399.1875
# Test Error:
#  Avg loss: 521399.187500, Avg error: 329421.714286
#
# Epoch 14, Batch 1/6, Batch Loss: 589484.2500
# Epoch 14, Batch 2/6, Batch Loss: 613697.1250
# Epoch 14, Batch 3/6, Batch Loss: 833478.5625
# Epoch 14, Batch 4/6, Batch Loss: 326059.5000
# Epoch 14, Batch 5/6, Batch Loss: 461382.5625
# Epoch 14, Batch 6/6, Batch Loss: 306947.6875
# Batch 1/1, Batch Loss: 432559.2500
# Test Error:
#  Avg loss: 432559.250000, Avg error: 274605.285714
#
# Epoch 15, Batch 1/6, Batch Loss: 382814.5312
# Epoch 15, Batch 2/6, Batch Loss: 382810.7188
# Epoch 15, Batch 3/6, Batch Loss: 273017.6875
# Epoch 15, Batch 4/6, Batch Loss: 491018.5938
# Epoch 15, Batch 5/6, Batch Loss: 988549.0625
# Epoch 15, Batch 6/6, Batch Loss: 408748.2500
# Batch 1/1, Batch Loss: 472272.9062
# Test Error:
#  Avg loss: 472272.906250, Avg error: 285109.510204
#
# Epoch 16, Batch 1/6, Batch Loss: 350803.1875
# Epoch 16, Batch 2/6, Batch Loss: 742385.8750
# Epoch 16, Batch 3/6, Batch Loss: 429302.2188
# Epoch 16, Batch 4/6, Batch Loss: 410049.8750
# Epoch 16, Batch 5/6, Batch Loss: 533344.2500
# Epoch 16, Batch 6/6, Batch Loss: 555630.6250
# Batch 1/1, Batch Loss: 465657.2812
# Test Error:
#  Avg loss: 465657.281250, Avg error: 278908.387755
#
# Epoch 17, Batch 1/6, Batch Loss: 300331.3438
# Epoch 17, Batch 2/6, Batch Loss: 803928.7500
# Epoch 17, Batch 3/6, Batch Loss: 407073.3438
# Epoch 17, Batch 4/6, Batch Loss: 353669.6562
# Epoch 17, Batch 5/6, Batch Loss: 440340.0625
# Epoch 17, Batch 6/6, Batch Loss: 569489.3750
# Batch 1/1, Batch Loss: 420590.5625
# Test Error:
#  Avg loss: 420590.562500, Avg error: 261975.244898
#
# Epoch 18, Batch 1/6, Batch Loss: 528828.5000
# Epoch 18, Batch 2/6, Batch Loss: 727846.6250
# Epoch 18, Batch 3/6, Batch Loss: 339436.6562
# Epoch 18, Batch 4/6, Batch Loss: 373054.1875
# Epoch 18, Batch 5/6, Batch Loss: 395484.0312
# Epoch 18, Batch 6/6, Batch Loss: 510322.3125
# Batch 1/1, Batch Loss: 466856.8750
# Test Error:
#  Avg loss: 466856.875000, Avg error: 279792.591837
#
# Epoch 19, Batch 1/6, Batch Loss: 290067.7188
# Epoch 19, Batch 2/6, Batch Loss: 311985.9375
# Epoch 19, Batch 3/6, Batch Loss: 751645.2500
# Epoch 19, Batch 4/6, Batch Loss: 426332.0312
# Epoch 19, Batch 5/6, Batch Loss: 433463.7188
# Epoch 19, Batch 6/6, Batch Loss: 532525.4375
# Batch 1/1, Batch Loss: 405938.5625
# Test Error:
#  Avg loss: 405938.562500, Avg error: 266963.142857
#
# Epoch 20, Batch 1/6, Batch Loss: 390995.9688
# Epoch 20, Batch 2/6, Batch Loss: 779566.8125
# Epoch 20, Batch 3/6, Batch Loss: 368855.2500
# Epoch 20, Batch 4/6, Batch Loss: 365157.1562
# Epoch 20, Batch 5/6, Batch Loss: 372942.3125
# Epoch 20, Batch 6/6, Batch Loss: 368793.2812
# Batch 1/1, Batch Loss: 451796.6562
# Test Error:
#  Avg loss: 451796.656250, Avg error: 270466.693878
#
# 2024-09-16 18:06:05.755450 Epoch 20, Average Training loss 441051.796875
# Epoch 21, Batch 1/6, Batch Loss: 380567.9688
# Epoch 21, Batch 2/6, Batch Loss: 853202.8125
# Epoch 21, Batch 3/6, Batch Loss: 312790.1250
# Epoch 21, Batch 4/6, Batch Loss: 344245.3750
# Epoch 21, Batch 5/6, Batch Loss: 442585.1875
# Epoch 21, Batch 6/6, Batch Loss: 304050.4688
# Batch 1/1, Batch Loss: 413457.5000
# Test Error:
#  Avg loss: 413457.500000, Avg error: 253513.489796
#
# Epoch 22, Batch 1/6, Batch Loss: 350213.9062
# Epoch 22, Batch 2/6, Batch Loss: 756678.0000
# Epoch 22, Batch 3/6, Batch Loss: 373925.0312
# Epoch 22, Batch 4/6, Batch Loss: 416340.4062
# Epoch 22, Batch 5/6, Batch Loss: 429497.2188
# Epoch 22, Batch 6/6, Batch Loss: 343983.0938
# Batch 1/1, Batch Loss: 424988.3125
# Test Error:
#  Avg loss: 424988.312500, Avg error: 252337.061224
#
# Epoch 23, Batch 1/6, Batch Loss: 487147.7812
# Epoch 23, Batch 2/6, Batch Loss: 369455.5312
# Epoch 23, Batch 3/6, Batch Loss: 289262.1875
# Epoch 23, Batch 4/6, Batch Loss: 353885.6562
# Epoch 23, Batch 5/6, Batch Loss: 389597.9062
# Epoch 23, Batch 6/6, Batch Loss: 270752.2812
# Batch 1/1, Batch Loss: 427285.4062
# Test Error:
#  Avg loss: 427285.406250, Avg error: 248977.918367
#
# Epoch 24, Batch 1/6, Batch Loss: 468427.5312
# Epoch 24, Batch 2/6, Batch Loss: 272514.2500
# Epoch 24, Batch 3/6, Batch Loss: 506263.3125
# Epoch 24, Batch 4/6, Batch Loss: 735149.1250
# Epoch 24, Batch 5/6, Batch Loss: 356875.0625
# Epoch 24, Batch 6/6, Batch Loss: 326706.2188
# Batch 1/1, Batch Loss: 409572.0312
# Test Error:
#  Avg loss: 409572.031250, Avg error: 238268.734694
#
# Epoch 25, Batch 1/6, Batch Loss: 242445.8438
# Epoch 25, Batch 2/6, Batch Loss: 345326.4375
# Epoch 25, Batch 3/6, Batch Loss: 446456.0312
# Epoch 25, Batch 4/6, Batch Loss: 296074.1562
# Epoch 25, Batch 5/6, Batch Loss: 454114.4062
# Epoch 25, Batch 6/6, Batch Loss: 334826.6875
# Batch 1/1, Batch Loss: 411014.8750
# Test Error:
#  Avg loss: 411014.875000, Avg error: 238097.836735
#
# Epoch 26, Batch 1/6, Batch Loss: 330553.9062
# Epoch 26, Batch 2/6, Batch Loss: 367937.0625
# Epoch 26, Batch 3/6, Batch Loss: 365304.3438
# Epoch 26, Batch 4/6, Batch Loss: 739727.1250
# Epoch 26, Batch 5/6, Batch Loss: 552836.0625
# Epoch 26, Batch 6/6, Batch Loss: 319606.7500
# Batch 1/1, Batch Loss: 420627.2500
# Test Error:
#  Avg loss: 420627.250000, Avg error: 242869.857143
#
# Epoch 27, Batch 1/6, Batch Loss: 373492.0312
# Epoch 27, Batch 2/6, Batch Loss: 328417.4062
# Epoch 27, Batch 3/6, Batch Loss: 352111.0312
# Epoch 27, Batch 4/6, Batch Loss: 795727.0000
# Epoch 27, Batch 5/6, Batch Loss: 479897.5000
# Epoch 27, Batch 6/6, Batch Loss: 362018.1875
# Batch 1/1, Batch Loss: 401314.5938
# Test Error:
#  Avg loss: 401314.593750, Avg error: 235577.469388
#
# Epoch 28, Batch 1/6, Batch Loss: 309491.1875
# Epoch 28, Batch 2/6, Batch Loss: 315376.5938
# Epoch 28, Batch 3/6, Batch Loss: 461730.4688
# Epoch 28, Batch 4/6, Batch Loss: 483496.9688
# Epoch 28, Batch 5/6, Batch Loss: 349776.3438
# Epoch 28, Batch 6/6, Batch Loss: 718923.9375
# Batch 1/1, Batch Loss: 404838.5938
# Test Error:
#  Avg loss: 404838.593750, Avg error: 236052.265306
#
# Epoch 29, Batch 1/6, Batch Loss: 485046.4375
# Epoch 29, Batch 2/6, Batch Loss: 347294.4688
# Epoch 29, Batch 3/6, Batch Loss: 758739.2500
# Epoch 29, Batch 4/6, Batch Loss: 321332.6875
# Epoch 29, Batch 5/6, Batch Loss: 284736.6875
# Epoch 29, Batch 6/6, Batch Loss: 355072.9688
# Batch 1/1, Batch Loss: 418269.9688
# Test Error:
#  Avg loss: 418269.968750, Avg error: 241457.693878
#
# Epoch 30, Batch 1/6, Batch Loss: 495255.4375
# Epoch 30, Batch 2/6, Batch Loss: 290874.0938
# Epoch 30, Batch 3/6, Batch Loss: 317398.6562
# Epoch 30, Batch 4/6, Batch Loss: 287606.0938
# Epoch 30, Batch 5/6, Batch Loss: 383730.4062
# Epoch 30, Batch 6/6, Batch Loss: 784449.6250
# Batch 1/1, Batch Loss: 392015.0938
# Test Error:
#  Avg loss: 392015.093750, Avg error: 229349.061224
#
# 2024-09-16 18:07:51.863871 Epoch 30, Average Training loss 426552.3854166667
# Epoch 31, Batch 1/6, Batch Loss: 567474.1250
# Epoch 31, Batch 2/6, Batch Loss: 399777.7812
# Epoch 31, Batch 3/6, Batch Loss: 381883.7812
# Epoch 31, Batch 4/6, Batch Loss: 709699.3125
# Epoch 31, Batch 5/6, Batch Loss: 316760.1562
# Epoch 31, Batch 6/6, Batch Loss: 313436.9062
# Batch 1/1, Batch Loss: 420883.6875
# Test Error:
#  Avg loss: 420883.687500, Avg error: 241119.714286
#
# Epoch 32, Batch 1/6, Batch Loss: 318431.1875
# Epoch 32, Batch 2/6, Batch Loss: 297781.7812
# Epoch 32, Batch 3/6, Batch Loss: 731205.6250
# Epoch 32, Batch 4/6, Batch Loss: 324063.5000
# Epoch 32, Batch 5/6, Batch Loss: 414864.4688
# Epoch 32, Batch 6/6, Batch Loss: 369772.0938
# Batch 1/1, Batch Loss: 392966.1562
# Test Error:
#  Avg loss: 392966.156250, Avg error: 228889.959184
#
# Epoch 33, Batch 1/6, Batch Loss: 463697.5000
# Epoch 33, Batch 2/6, Batch Loss: 457110.5312
# Epoch 33, Batch 3/6, Batch Loss: 306643.8438
# Epoch 33, Batch 4/6, Batch Loss: 316355.6562
# Epoch 33, Batch 5/6, Batch Loss: 281288.1875
# Epoch 33, Batch 6/6, Batch Loss: 369262.5938
# Batch 1/1, Batch Loss: 425612.4375
# Test Error:
#  Avg loss: 425612.437500, Avg error: 244986.163265
#
# Epoch 34, Batch 1/6, Batch Loss: 321505.0938
# Epoch 34, Batch 2/6, Batch Loss: 312648.2812
# Epoch 34, Batch 3/6, Batch Loss: 381300.7812
# Epoch 34, Batch 4/6, Batch Loss: 520270.2812
# Epoch 34, Batch 5/6, Batch Loss: 726584.6250
# Epoch 34, Batch 6/6, Batch Loss: 389555.8750
# Batch 1/1, Batch Loss: 376151.2188
# Test Error:
#  Avg loss: 376151.218750, Avg error: 240289.326531
#
# Epoch 35, Batch 1/6, Batch Loss: 343821.0938
# Epoch 35, Batch 2/6, Batch Loss: 282025.0938
# Epoch 35, Batch 3/6, Batch Loss: 458260.4375
# Epoch 35, Batch 4/6, Batch Loss: 443773.5000
# Epoch 35, Batch 5/6, Batch Loss: 341324.4375
# Epoch 35, Batch 6/6, Batch Loss: 722479.5625
# Batch 1/1, Batch Loss: 445555.1562
# Test Error:
#  Avg loss: 445555.156250, Avg error: 267387.469388
#
# Epoch 36, Batch 1/6, Batch Loss: 332960.0938
# Epoch 36, Batch 2/6, Batch Loss: 270814.8750
# Epoch 36, Batch 3/6, Batch Loss: 573517.7500
# Epoch 36, Batch 4/6, Batch Loss: 321521.7500
# Epoch 36, Batch 5/6, Batch Loss: 726659.6875
# Epoch 36, Batch 6/6, Batch Loss: 351360.9062
# Batch 1/1, Batch Loss: 385261.5938
# Test Error:
#  Avg loss: 385261.593750, Avg error: 241570.040816
#
# Epoch 37, Batch 1/6, Batch Loss: 496520.0938
# Epoch 37, Batch 2/6, Batch Loss: 381186.1875
# Epoch 37, Batch 3/6, Batch Loss: 732352.3125
# Epoch 37, Batch 4/6, Batch Loss: 367318.2812
# Epoch 37, Batch 5/6, Batch Loss: 309171.5625
# Epoch 37, Batch 6/6, Batch Loss: 262308.4062
# Batch 1/1, Batch Loss: 419096.1875
# Test Error:
#  Avg loss: 419096.187500, Avg error: 243143.428571
#
# Epoch 38, Batch 1/6, Batch Loss: 275635.0312
# Epoch 38, Batch 2/6, Batch Loss: 359732.3438
# Epoch 38, Batch 3/6, Batch Loss: 288288.7500
# Epoch 38, Batch 4/6, Batch Loss: 342976.0625
# Epoch 38, Batch 5/6, Batch Loss: 330005.5000
# Epoch 38, Batch 6/6, Batch Loss: 755048.7500
# Batch 1/1, Batch Loss: 386324.3750
# Test Error:
#  Avg loss: 386324.375000, Avg error: 229368.612245
#
# Epoch 39, Batch 1/6, Batch Loss: 386252.0312
# Epoch 39, Batch 2/6, Batch Loss: 486497.4375
# Epoch 39, Batch 3/6, Batch Loss: 402994.0000
# Epoch 39, Batch 4/6, Batch Loss: 365991.0625
# Epoch 39, Batch 5/6, Batch Loss: 237671.9375
# Epoch 39, Batch 6/6, Batch Loss: 730419.5000
# Batch 1/1, Batch Loss: 402133.4688
# Test Error:
#  Avg loss: 402133.468750, Avg error: 229727.081633
#
# Epoch 40, Batch 1/6, Batch Loss: 243100.5000
# Epoch 40, Batch 2/6, Batch Loss: 388429.2500
# Epoch 40, Batch 3/6, Batch Loss: 740353.0625
# Epoch 40, Batch 4/6, Batch Loss: 306377.1875
# Epoch 40, Batch 5/6, Batch Loss: 267714.3125
# Epoch 40, Batch 6/6, Batch Loss: 420233.4062
# Batch 1/1, Batch Loss: 387320.4375
# Test Error:
#  Avg loss: 387320.437500, Avg error: 225154.551020
#
# 2024-09-16 18:09:40.162373 Epoch 40, Average Training loss 394367.953125
# Epoch 41, Batch 1/6, Batch Loss: 714481.1875
# Epoch 41, Batch 2/6, Batch Loss: 276880.3125
# Epoch 41, Batch 3/6, Batch Loss: 315880.4688
# Epoch 41, Batch 4/6, Batch Loss: 435511.5938
# Epoch 41, Batch 5/6, Batch Loss: 416337.7188
# Epoch 41, Batch 6/6, Batch Loss: 360247.0625
# Batch 1/1, Batch Loss: 382790.7188
# Test Error:
#  Avg loss: 382790.718750, Avg error: 224290.836735
#
# Epoch 42, Batch 1/6, Batch Loss: 471632.5000
# Epoch 42, Batch 2/6, Batch Loss: 326958.9688
# Epoch 42, Batch 3/6, Batch Loss: 312935.8750
# Epoch 42, Batch 4/6, Batch Loss: 370685.7500
# Epoch 42, Batch 5/6, Batch Loss: 386078.5000
# Epoch 42, Batch 6/6, Batch Loss: 340340.5000
# Batch 1/1, Batch Loss: 393429.9688
# Test Error:
#  Avg loss: 393429.968750, Avg error: 224646.510204
#
# Epoch 43, Batch 1/6, Batch Loss: 246017.9062
# Epoch 43, Batch 2/6, Batch Loss: 448640.8750
# Epoch 43, Batch 3/6, Batch Loss: 278221.4062
# Epoch 43, Batch 4/6, Batch Loss: 283829.4375
# Epoch 43, Batch 5/6, Batch Loss: 496863.6875
# Epoch 43, Batch 6/6, Batch Loss: 711024.5000
# Batch 1/1, Batch Loss: 373821.5938
# Test Error:
#  Avg loss: 373821.593750, Avg error: 223898.612245
#
# Epoch 44, Batch 1/6, Batch Loss: 488705.7500
# Epoch 44, Batch 2/6, Batch Loss: 275200.3438
# Epoch 44, Batch 3/6, Batch Loss: 298794.7500
# Epoch 44, Batch 4/6, Batch Loss: 367089.3750
# Epoch 44, Batch 5/6, Batch Loss: 741248.8750
# Epoch 44, Batch 6/6, Batch Loss: 308835.1250
# Batch 1/1, Batch Loss: 400736.3438
# Test Error:
#  Avg loss: 400736.343750, Avg error: 227828.040816
#
# Epoch 45, Batch 1/6, Batch Loss: 339595.8438
# Epoch 45, Batch 2/6, Batch Loss: 225367.3750
# Epoch 45, Batch 3/6, Batch Loss: 320444.3125
# Epoch 45, Batch 4/6, Batch Loss: 390155.0625
# Epoch 45, Batch 5/6, Batch Loss: 729769.8125
# Epoch 45, Batch 6/6, Batch Loss: 278077.0938
# Batch 1/1, Batch Loss: 371228.4375
# Test Error:
#  Avg loss: 371228.437500, Avg error: 222477.000000
#
# Epoch 46, Batch 1/6, Batch Loss: 308653.5000
# Epoch 46, Batch 2/6, Batch Loss: 332603.3438
# Epoch 46, Batch 3/6, Batch Loss: 291122.6250
# Epoch 46, Batch 4/6, Batch Loss: 448822.9375
# Epoch 46, Batch 5/6, Batch Loss: 320518.4688
# Epoch 46, Batch 6/6, Batch Loss: 333661.2188
# Batch 1/1, Batch Loss: 385044.8438
# Test Error:
#  Avg loss: 385044.843750, Avg error: 221650.081633
#
# Epoch 47, Batch 1/6, Batch Loss: 766737.8750
# Epoch 47, Batch 2/6, Batch Loss: 423071.8438
# Epoch 47, Batch 3/6, Batch Loss: 353260.0625
# Epoch 47, Batch 4/6, Batch Loss: 370318.8750
# Epoch 47, Batch 5/6, Batch Loss: 284194.0625
# Epoch 47, Batch 6/6, Batch Loss: 333604.0625
# Batch 1/1, Batch Loss: 410298.6875
# Test Error:
#  Avg loss: 410298.687500, Avg error: 236847.224490
#
# Epoch 48, Batch 1/6, Batch Loss: 381976.9375
# Epoch 48, Batch 2/6, Batch Loss: 387822.6875
# Epoch 48, Batch 3/6, Batch Loss: 485224.2188
# Epoch 48, Batch 4/6, Batch Loss: 775960.0625
# Epoch 48, Batch 5/6, Batch Loss: 273312.8750
# Epoch 48, Batch 6/6, Batch Loss: 340728.5625
# Batch 1/1, Batch Loss: 379398.8750
# Test Error:
#  Avg loss: 379398.875000, Avg error: 224772.061224
#
# Epoch 49, Batch 1/6, Batch Loss: 775682.3125
# Epoch 49, Batch 2/6, Batch Loss: 283034.3438
# Epoch 49, Batch 3/6, Batch Loss: 334662.4062
# Epoch 49, Batch 4/6, Batch Loss: 317192.1562
# Epoch 49, Batch 5/6, Batch Loss: 476318.5938
# Epoch 49, Batch 6/6, Batch Loss: 309115.4062
# Batch 1/1, Batch Loss: 415713.3750
# Test Error:
#  Avg loss: 415713.375000, Avg error: 242271.265306
#
# Epoch 50, Batch 1/6, Batch Loss: 262597.3750
# Epoch 50, Batch 2/6, Batch Loss: 379492.9375
# Epoch 50, Batch 3/6, Batch Loss: 273622.0625
# Epoch 50, Batch 4/6, Batch Loss: 285461.5938
# Epoch 50, Batch 5/6, Batch Loss: 308174.0000
# Epoch 50, Batch 6/6, Batch Loss: 733259.9375
# Batch 1/1, Batch Loss: 373659.7500
# Test Error:
#  Avg loss: 373659.750000, Avg error: 233863.775510
#
# 2024-09-16 18:11:27.575391 Epoch 50, Average Training loss 373767.984375
# Epoch 51, Batch 1/6, Batch Loss: 356057.0000
# Epoch 51, Batch 2/6, Batch Loss: 326925.2812
# Epoch 51, Batch 3/6, Batch Loss: 320933.5312
# Epoch 51, Batch 4/6, Batch Loss: 285344.1250
# Epoch 51, Batch 5/6, Batch Loss: 701120.1875
# Epoch 51, Batch 6/6, Batch Loss: 322359.6875
# Batch 1/1, Batch Loss: 402825.2500
# Test Error:
#  Avg loss: 402825.250000, Avg error: 232458.163265
#
# Epoch 52, Batch 1/6, Batch Loss: 330091.3750
# Epoch 52, Batch 2/6, Batch Loss: 434789.3125
# Epoch 52, Batch 3/6, Batch Loss: 383569.6250
# Epoch 52, Batch 4/6, Batch Loss: 338664.2188
# Epoch 52, Batch 5/6, Batch Loss: 336156.9375
# Epoch 52, Batch 6/6, Batch Loss: 703480.8750
# Batch 1/1, Batch Loss: 376579.7500
# Test Error:
#  Avg loss: 376579.750000, Avg error: 224991.428571
#
# Epoch 53, Batch 1/6, Batch Loss: 310937.7500
# Epoch 53, Batch 2/6, Batch Loss: 308807.9375
# Epoch 53, Batch 3/6, Batch Loss: 268849.5625
# Epoch 53, Batch 4/6, Batch Loss: 330235.7500
# Epoch 53, Batch 5/6, Batch Loss: 315775.3125
# Epoch 53, Batch 6/6, Batch Loss: 386433.5312
# Batch 1/1, Batch Loss: 397161.9375
# Test Error:
#  Avg loss: 397161.937500, Avg error: 226986.734694
#
# Epoch 54, Batch 1/6, Batch Loss: 324983.7812
# Epoch 54, Batch 2/6, Batch Loss: 490342.0312
# Epoch 54, Batch 3/6, Batch Loss: 696923.2500
# Epoch 54, Batch 4/6, Batch Loss: 478498.2500
# Epoch 54, Batch 5/6, Batch Loss: 327543.5312
# Epoch 54, Batch 6/6, Batch Loss: 284659.8750
# Batch 1/1, Batch Loss: 392008.7188
# Test Error:
#  Avg loss: 392008.718750, Avg error: 223692.918367
#
# Epoch 55, Batch 1/6, Batch Loss: 292014.7812
# Epoch 55, Batch 2/6, Batch Loss: 414009.6875
# Epoch 55, Batch 3/6, Batch Loss: 609513.5625
# Epoch 55, Batch 4/6, Batch Loss: 310883.9062
# Epoch 55, Batch 5/6, Batch Loss: 757034.8750
# Epoch 55, Batch 6/6, Batch Loss: 355025.1250
# Batch 1/1, Batch Loss: 401227.2812
# Test Error:
#  Avg loss: 401227.281250, Avg error: 233260.285714
#
# Epoch 56, Batch 1/6, Batch Loss: 307067.7188
# Epoch 56, Batch 2/6, Batch Loss: 335784.5625
# Epoch 56, Batch 3/6, Batch Loss: 332392.2812
# Epoch 56, Batch 4/6, Batch Loss: 408443.5000
# Epoch 56, Batch 5/6, Batch Loss: 776951.7500
# Epoch 56, Batch 6/6, Batch Loss: 313337.9375
# Batch 1/1, Batch Loss: 385624.8125
# Test Error:
#  Avg loss: 385624.812500, Avg error: 231311.714286
#
# Epoch 57, Batch 1/6, Batch Loss: 370226.0312
# Epoch 57, Batch 2/6, Batch Loss: 712271.1250
# Epoch 57, Batch 3/6, Batch Loss: 469126.5938
# Epoch 57, Batch 4/6, Batch Loss: 258035.9844
# Epoch 57, Batch 5/6, Batch Loss: 384555.6562
# Epoch 57, Batch 6/6, Batch Loss: 277846.5312
# Batch 1/1, Batch Loss: 386440.8125
# Test Error:
#  Avg loss: 386440.812500, Avg error: 229435.551020
#
# Epoch 58, Batch 1/6, Batch Loss: 310601.7500
# Epoch 58, Batch 2/6, Batch Loss: 340974.8750
# Epoch 58, Batch 3/6, Batch Loss: 783218.3125
# Epoch 58, Batch 4/6, Batch Loss: 309894.2500
# Epoch 58, Batch 5/6, Batch Loss: 345124.2500
# Epoch 58, Batch 6/6, Batch Loss: 346445.9062
# Batch 1/1, Batch Loss: 378510.4062
# Test Error:
#  Avg loss: 378510.406250, Avg error: 225311.428571
#
# Epoch 59, Batch 1/6, Batch Loss: 438167.9375
# Epoch 59, Batch 2/6, Batch Loss: 357692.1562
# Epoch 59, Batch 3/6, Batch Loss: 368591.6250
# Epoch 59, Batch 4/6, Batch Loss: 282078.4688
# Epoch 59, Batch 5/6, Batch Loss: 263228.9375
# Epoch 59, Batch 6/6, Batch Loss: 235999.5781
# Batch 1/1, Batch Loss: 375655.3438
# Test Error:
#  Avg loss: 375655.343750, Avg error: 222618.469388
#
# Epoch 60, Batch 1/6, Batch Loss: 369670.2188
# Epoch 60, Batch 2/6, Batch Loss: 258149.8906
# Epoch 60, Batch 3/6, Batch Loss: 261776.5781
# Epoch 60, Batch 4/6, Batch Loss: 717356.9375
# Epoch 60, Batch 5/6, Batch Loss: 510175.0312
# Epoch 60, Batch 6/6, Batch Loss: 323682.1875
# Batch 1/1, Batch Loss: 397860.8438
# Test Error:
#  Avg loss: 397860.843750, Avg error: 229084.653061
#
# 2024-09-16 18:13:16.315068 Epoch 60, Average Training loss 406801.8072916667
# Epoch 61, Batch 1/6, Batch Loss: 365483.8125
# Epoch 61, Batch 2/6, Batch Loss: 323514.1875
# Epoch 61, Batch 3/6, Batch Loss: 265143.8750
# Epoch 61, Batch 4/6, Batch Loss: 256777.6562
# Epoch 61, Batch 5/6, Batch Loss: 706796.3125
# Epoch 61, Batch 6/6, Batch Loss: 326140.1562
# Batch 1/1, Batch Loss: 382099.3750
# Test Error:
#  Avg loss: 382099.375000, Avg error: 221086.183673
#
# Epoch 62, Batch 1/6, Batch Loss: 239664.4531
# Epoch 62, Batch 2/6, Batch Loss: 218412.6562
# Epoch 62, Batch 3/6, Batch Loss: 372366.7812
# Epoch 62, Batch 4/6, Batch Loss: 371006.3125
# Epoch 62, Batch 5/6, Batch Loss: 345659.4062
# Epoch 62, Batch 6/6, Batch Loss: 778328.9375
# Batch 1/1, Batch Loss: 364474.3750
# Test Error:
#  Avg loss: 364474.375000, Avg error: 239879.612245
#
# Epoch 63, Batch 1/6, Batch Loss: 356059.3750
# Epoch 63, Batch 2/6, Batch Loss: 308740.8750
# Epoch 63, Batch 3/6, Batch Loss: 714635.5625
# Epoch 63, Batch 4/6, Batch Loss: 308471.7500
# Epoch 63, Batch 5/6, Batch Loss: 267175.5938
# Epoch 63, Batch 6/6, Batch Loss: 348497.0312
# Batch 1/1, Batch Loss: 390339.3125
# Test Error:
#  Avg loss: 390339.312500, Avg error: 224635.244898
#
# Epoch 64, Batch 1/6, Batch Loss: 327779.7500
# Epoch 64, Batch 2/6, Batch Loss: 223960.1406
# Epoch 64, Batch 3/6, Batch Loss: 699067.7500
# Epoch 64, Batch 4/6, Batch Loss: 541407.6250
# Epoch 64, Batch 5/6, Batch Loss: 332979.3750
# Epoch 64, Batch 6/6, Batch Loss: 329324.4062
# Batch 1/1, Batch Loss: 370722.5000
# Test Error:
#  Avg loss: 370722.500000, Avg error: 235840.163265
#
# Epoch 65, Batch 1/6, Batch Loss: 267838.0000
# Epoch 65, Batch 2/6, Batch Loss: 682501.4375
# Epoch 65, Batch 3/6, Batch Loss: 291538.1250
# Epoch 65, Batch 4/6, Batch Loss: 614855.5000
# Epoch 65, Batch 5/6, Batch Loss: 355630.4688
# Epoch 65, Batch 6/6, Batch Loss: 260726.6719
# Batch 1/1, Batch Loss: 380921.8125
# Test Error:
#  Avg loss: 380921.812500, Avg error: 226582.897959
#
# Epoch 66, Batch 1/6, Batch Loss: 245704.1250
# Epoch 66, Batch 2/6, Batch Loss: 314354.7812
# Epoch 66, Batch 3/6, Batch Loss: 294133.1875
# Epoch 66, Batch 4/6, Batch Loss: 319275.7812
# Epoch 66, Batch 5/6, Batch Loss: 288646.0938
# Epoch 66, Batch 6/6, Batch Loss: 787299.2500
# Batch 1/1, Batch Loss: 373208.0312
# Test Error:
#  Avg loss: 373208.031250, Avg error: 228770.755102
#
# Epoch 67, Batch 1/6, Batch Loss: 253272.2500
# Epoch 67, Batch 2/6, Batch Loss: 366024.1562
# Epoch 67, Batch 3/6, Batch Loss: 455428.6250
# Epoch 67, Batch 4/6, Batch Loss: 282702.8750
# Epoch 67, Batch 5/6, Batch Loss: 710241.3125
# Epoch 67, Batch 6/6, Batch Loss: 259915.9688
# Batch 1/1, Batch Loss: 377243.9062
# Test Error:
#  Avg loss: 377243.906250, Avg error: 227758.224490
#
# Epoch 68, Batch 1/6, Batch Loss: 528470.2500
# Epoch 68, Batch 2/6, Batch Loss: 312937.8125
# Epoch 68, Batch 3/6, Batch Loss: 216514.2969
# Epoch 68, Batch 4/6, Batch Loss: 731579.2500
# Epoch 68, Batch 5/6, Batch Loss: 312514.1562
# Epoch 68, Batch 6/6, Batch Loss: 215069.8438
# Batch 1/1, Batch Loss: 373730.5938
# Test Error:
#  Avg loss: 373730.593750, Avg error: 229556.081633
#
# Epoch 69, Batch 1/6, Batch Loss: 387285.2500
# Epoch 69, Batch 2/6, Batch Loss: 660370.7500
# Epoch 69, Batch 3/6, Batch Loss: 441242.5000
# Epoch 69, Batch 4/6, Batch Loss: 307260.4375
# Epoch 69, Batch 5/6, Batch Loss: 251528.0469
# Epoch 69, Batch 6/6, Batch Loss: 280423.4375
# Batch 1/1, Batch Loss: 414750.4688
# Test Error:
#  Avg loss: 414750.468750, Avg error: 244186.408163
#
# Epoch 70, Batch 1/6, Batch Loss: 425593.7500
# Epoch 70, Batch 2/6, Batch Loss: 466285.4062
# Epoch 70, Batch 3/6, Batch Loss: 276856.8750
# Epoch 70, Batch 4/6, Batch Loss: 708300.4375
# Epoch 70, Batch 5/6, Batch Loss: 296359.3750
# Epoch 70, Batch 6/6, Batch Loss: 309342.8438
# Batch 1/1, Batch Loss: 379725.6875
# Test Error:
#  Avg loss: 379725.687500, Avg error: 260981.346939
#
# 2024-09-16 18:15:04.109154 Epoch 70, Average Training loss 413789.78125
# Epoch 71, Batch 1/6, Batch Loss: 320343.2500
# Epoch 71, Batch 2/6, Batch Loss: 308038.2812
# Epoch 71, Batch 3/6, Batch Loss: 760235.3750
# Epoch 71, Batch 4/6, Batch Loss: 292001.8125
# Epoch 71, Batch 5/6, Batch Loss: 274367.9375
# Epoch 71, Batch 6/6, Batch Loss: 218249.9844
# Batch 1/1, Batch Loss: 395024.5625
# Test Error:
#  Avg loss: 395024.562500, Avg error: 237078.489796
#
# Epoch 72, Batch 1/6, Batch Loss: 488171.8438
# Epoch 72, Batch 2/6, Batch Loss: 380286.5938
# Epoch 72, Batch 3/6, Batch Loss: 689211.4375
# Epoch 72, Batch 4/6, Batch Loss: 329371.0000
# Epoch 72, Batch 5/6, Batch Loss: 262101.5938
# Epoch 72, Batch 6/6, Batch Loss: 298321.4688
# Batch 1/1, Batch Loss: 395824.1562
# Test Error:
#  Avg loss: 395824.156250, Avg error: 242474.244898
#
# Epoch 73, Batch 1/6, Batch Loss: 286652.2500
# Epoch 73, Batch 2/6, Batch Loss: 690648.5000
# Epoch 73, Batch 3/6, Batch Loss: 320747.7500
# Epoch 73, Batch 4/6, Batch Loss: 266241.1562
# Epoch 73, Batch 5/6, Batch Loss: 431273.0625
# Epoch 73, Batch 6/6, Batch Loss: 408912.8750
# Batch 1/1, Batch Loss: 388602.4688
# Test Error:
#  Avg loss: 388602.468750, Avg error: 252784.836735
#
# Epoch 74, Batch 1/6, Batch Loss: 681645.1250
# Epoch 74, Batch 2/6, Batch Loss: 316905.6562
# Epoch 74, Batch 3/6, Batch Loss: 357195.3125
# Epoch 74, Batch 4/6, Batch Loss: 222798.0156
# Epoch 74, Batch 5/6, Batch Loss: 245443.0469
# Epoch 74, Batch 6/6, Batch Loss: 496502.3125
# Batch 1/1, Batch Loss: 403873.3750
# Test Error:
#  Avg loss: 403873.375000, Avg error: 246482.979592
#
# Epoch 75, Batch 1/6, Batch Loss: 229323.2812
# Epoch 75, Batch 2/6, Batch Loss: 346608.1875
# Epoch 75, Batch 3/6, Batch Loss: 372471.7188
# Epoch 75, Batch 4/6, Batch Loss: 326637.3125
# Epoch 75, Batch 5/6, Batch Loss: 455186.3125
# Epoch 75, Batch 6/6, Batch Loss: 274975.3125
# Batch 1/1, Batch Loss: 403826.1875
# Test Error:
#  Avg loss: 403826.187500, Avg error: 251367.816327
#
# Epoch 76, Batch 1/6, Batch Loss: 423972.8750
# Epoch 76, Batch 2/6, Batch Loss: 269692.8125
# Epoch 76, Batch 3/6, Batch Loss: 236980.0781
# Epoch 76, Batch 4/6, Batch Loss: 276648.0312
# Epoch 76, Batch 5/6, Batch Loss: 298117.2188
# Epoch 76, Batch 6/6, Batch Loss: 316798.0000
# Batch 1/1, Batch Loss: 396214.0625
# Test Error:
#  Avg loss: 396214.062500, Avg error: 262806.571429
#
# Epoch 77, Batch 1/6, Batch Loss: 242283.8594
# Epoch 77, Batch 2/6, Batch Loss: 273651.9375
# Epoch 77, Batch 3/6, Batch Loss: 351193.5000
# Epoch 77, Batch 4/6, Batch Loss: 391000.5312
# Epoch 77, Batch 5/6, Batch Loss: 683231.7500
# Epoch 77, Batch 6/6, Batch Loss: 421266.1250
# Batch 1/1, Batch Loss: 395287.3438
# Test Error:
#  Avg loss: 395287.343750, Avg error: 273245.714286
#
# Epoch 78, Batch 1/6, Batch Loss: 314688.8750
# Epoch 78, Batch 2/6, Batch Loss: 358085.4375
# Epoch 78, Batch 3/6, Batch Loss: 294264.1875
# Epoch 78, Batch 4/6, Batch Loss: 252305.7500
# Epoch 78, Batch 5/6, Batch Loss: 751093.5000
# Epoch 78, Batch 6/6, Batch Loss: 267660.8125
# Batch 1/1, Batch Loss: 420278.9375
# Test Error:
#  Avg loss: 420278.937500, Avg error: 247632.448980
#
# Epoch 79, Batch 1/6, Batch Loss: 743724.8125
# Epoch 79, Batch 2/6, Batch Loss: 191853.4375
# Epoch 79, Batch 3/6, Batch Loss: 244015.1094
# Epoch 79, Batch 4/6, Batch Loss: 278620.2812
# Epoch 79, Batch 5/6, Batch Loss: 298106.4375
# Epoch 79, Batch 6/6, Batch Loss: 337709.0938
# Batch 1/1, Batch Loss: 396099.7500
# Test Error:
#  Avg loss: 396099.750000, Avg error: 251998.959184
#
# Epoch 80, Batch 1/6, Batch Loss: 269932.9062
# Epoch 80, Batch 2/6, Batch Loss: 346524.4688
# Epoch 80, Batch 3/6, Batch Loss: 281265.9375
# Epoch 80, Batch 4/6, Batch Loss: 325256.8750
# Epoch 80, Batch 5/6, Batch Loss: 272591.0000
# Epoch 80, Batch 6/6, Batch Loss: 415134.9062
# Batch 1/1, Batch Loss: 390574.6875
# Test Error:
#  Avg loss: 390574.687500, Avg error: 259038.979592
#
# 2024-09-16 18:16:51.755081 Epoch 80, Average Training loss 318451.015625
# Epoch 81, Batch 1/6, Batch Loss: 319631.8125
# Epoch 81, Batch 2/6, Batch Loss: 340464.8750
# Epoch 81, Batch 3/6, Batch Loss: 440053.8125
# Epoch 81, Batch 4/6, Batch Loss: 279540.2188
# Epoch 81, Batch 5/6, Batch Loss: 251219.7031
# Epoch 81, Batch 6/6, Batch Loss: 649661.7500
# Batch 1/1, Batch Loss: 417844.0625
# Test Error:
#  Avg loss: 417844.062500, Avg error: 248023.530612
#
# Epoch 82, Batch 1/6, Batch Loss: 264403.3125
# Epoch 82, Batch 2/6, Batch Loss: 724206.7500
# Epoch 82, Batch 3/6, Batch Loss: 232633.8281
# Epoch 82, Batch 4/6, Batch Loss: 264810.5625
# Epoch 82, Batch 5/6, Batch Loss: 296800.2812
# Epoch 82, Batch 6/6, Batch Loss: 401675.6250
# Batch 1/1, Batch Loss: 396646.6250
# Test Error:
#  Avg loss: 396646.625000, Avg error: 262163.530612
#
# Epoch 83, Batch 1/6, Batch Loss: 208061.5781
# Epoch 83, Batch 2/6, Batch Loss: 260468.0312
# Epoch 83, Batch 3/6, Batch Loss: 284547.5000
# Epoch 83, Batch 4/6, Batch Loss: 323645.0000
# Epoch 83, Batch 5/6, Batch Loss: 200092.9375
# Epoch 83, Batch 6/6, Batch Loss: 774745.5000
# Batch 1/1, Batch Loss: 410763.1562
# Test Error:
#  Avg loss: 410763.156250, Avg error: 242295.979592
#
# Epoch 84, Batch 1/6, Batch Loss: 415909.3125
# Epoch 84, Batch 2/6, Batch Loss: 253299.2031
# Epoch 84, Batch 3/6, Batch Loss: 231851.4062
# Epoch 84, Batch 4/6, Batch Loss: 244846.1406
# Epoch 84, Batch 5/6, Batch Loss: 718486.9375
# Epoch 84, Batch 6/6, Batch Loss: 283232.0312
# Batch 1/1, Batch Loss: 403821.1250
# Test Error:
#  Avg loss: 403821.125000, Avg error: 253316.918367
#
# Epoch 85, Batch 1/6, Batch Loss: 260088.0156
# Epoch 85, Batch 2/6, Batch Loss: 465747.0625
# Epoch 85, Batch 3/6, Batch Loss: 318944.0312
# Epoch 85, Batch 4/6, Batch Loss: 282733.2812
# Epoch 85, Batch 5/6, Batch Loss: 643704.3125
# Epoch 85, Batch 6/6, Batch Loss: 238373.1250
# Batch 1/1, Batch Loss: 404729.1250
# Test Error:
#  Avg loss: 404729.125000, Avg error: 270265.285714
#
# Epoch 86, Batch 1/6, Batch Loss: 616085.6875
# Epoch 86, Batch 2/6, Batch Loss: 395663.5312
# Epoch 86, Batch 3/6, Batch Loss: 304048.1875
# Epoch 86, Batch 4/6, Batch Loss: 270191.2188
# Epoch 86, Batch 5/6, Batch Loss: 325305.9375
# Epoch 86, Batch 6/6, Batch Loss: 266150.6562
# Batch 1/1, Batch Loss: 423489.7812
# Test Error:
#  Avg loss: 423489.781250, Avg error: 259084.836735
#
# Epoch 87, Batch 1/6, Batch Loss: 402209.2188
# Epoch 87, Batch 2/6, Batch Loss: 314723.8125
# Epoch 87, Batch 3/6, Batch Loss: 279151.8438
# Epoch 87, Batch 4/6, Batch Loss: 259261.7031
# Epoch 87, Batch 5/6, Batch Loss: 310510.3125
# Epoch 87, Batch 6/6, Batch Loss: 594637.9375
# Batch 1/1, Batch Loss: 411365.2500
# Test Error:
#  Avg loss: 411365.250000, Avg error: 258779.612245
#
# Epoch 88, Batch 1/6, Batch Loss: 232891.9531
# Epoch 88, Batch 2/6, Batch Loss: 710061.4375
# Epoch 88, Batch 3/6, Batch Loss: 258879.5312
# Epoch 88, Batch 4/6, Batch Loss: 255875.6719
# Epoch 88, Batch 5/6, Batch Loss: 337403.8438
# Epoch 88, Batch 6/6, Batch Loss: 246464.2812
# Batch 1/1, Batch Loss: 407278.5312
# Test Error:
#  Avg loss: 407278.531250, Avg error: 258563.714286
#
# Epoch 89, Batch 1/6, Batch Loss: 593765.1250
# Epoch 89, Batch 2/6, Batch Loss: 215794.2500
# Epoch 89, Batch 3/6, Batch Loss: 275186.1250
# Epoch 89, Batch 4/6, Batch Loss: 412689.9062
# Epoch 89, Batch 5/6, Batch Loss: 295608.9062
# Epoch 89, Batch 6/6, Batch Loss: 350702.2812
# Batch 1/1, Batch Loss: 419190.7812
# Test Error:
#  Avg loss: 419190.781250, Avg error: 312878.632653
#
# Epoch 90, Batch 1/6, Batch Loss: 298395.6250
# Epoch 90, Batch 2/6, Batch Loss: 285088.8438
# Epoch 90, Batch 3/6, Batch Loss: 343607.5312
# Epoch 90, Batch 4/6, Batch Loss: 291687.5938
# Epoch 90, Batch 5/6, Batch Loss: 300353.3750
# Epoch 90, Batch 6/6, Batch Loss: 664868.6875
# Batch 1/1, Batch Loss: 430219.0312
# Test Error:
#  Avg loss: 430219.031250, Avg error: 268306.183673
#
# 2024-09-16 18:18:39.200046 Epoch 90, Average Training loss 364000.2760416667
# Epoch 91, Batch 1/6, Batch Loss: 335212.2812
# Epoch 91, Batch 2/6, Batch Loss: 249059.2344
# Epoch 91, Batch 3/6, Batch Loss: 243987.8906
# Epoch 91, Batch 4/6, Batch Loss: 251629.5625
# Epoch 91, Batch 5/6, Batch Loss: 601060.2500
# Epoch 91, Batch 6/6, Batch Loss: 361501.4688
# Batch 1/1, Batch Loss: 418795.6562
# Test Error:
#  Avg loss: 418795.656250, Avg error: 264182.816327
#
# Epoch 92, Batch 1/6, Batch Loss: 266123.1250
# Epoch 92, Batch 2/6, Batch Loss: 582322.1875
# Epoch 92, Batch 3/6, Batch Loss: 452399.7812
# Epoch 92, Batch 4/6, Batch Loss: 279990.4688
# Epoch 92, Batch 5/6, Batch Loss: 231036.7812
# Epoch 92, Batch 6/6, Batch Loss: 269459.4062
# Batch 1/1, Batch Loss: 461197.8438
# Test Error:
#  Avg loss: 461197.843750, Avg error: 282419.387755
#
# Epoch 93, Batch 1/6, Batch Loss: 241583.9531
# Epoch 93, Batch 2/6, Batch Loss: 396758.5312
# Epoch 93, Batch 3/6, Batch Loss: 552400.5625
# Epoch 93, Batch 4/6, Batch Loss: 310952.5625
# Epoch 93, Batch 5/6, Batch Loss: 359523.1562
# Epoch 93, Batch 6/6, Batch Loss: 247720.4844
# Batch 1/1, Batch Loss: 449979.6875
# Test Error:
#  Avg loss: 449979.687500, Avg error: 285660.163265
#
# Epoch 94, Batch 1/6, Batch Loss: 307494.1250
# Epoch 94, Batch 2/6, Batch Loss: 372403.7812
# Epoch 94, Batch 3/6, Batch Loss: 319059.6250
# Epoch 94, Batch 4/6, Batch Loss: 565333.8750
# Epoch 94, Batch 5/6, Batch Loss: 280826.5000
# Epoch 94, Batch 6/6, Batch Loss: 258847.1562
# Batch 1/1, Batch Loss: 418423.2812
# Test Error:
#  Avg loss: 418423.281250, Avg error: 278527.265306
#
# Epoch 95, Batch 1/6, Batch Loss: 234530.9844
# Epoch 95, Batch 2/6, Batch Loss: 261559.4062
# Epoch 95, Batch 3/6, Batch Loss: 537685.8750
# Epoch 95, Batch 4/6, Batch Loss: 361051.5312
# Epoch 95, Batch 5/6, Batch Loss: 240480.9375
# Epoch 95, Batch 6/6, Batch Loss: 289129.4688
# Batch 1/1, Batch Loss: 437158.7812
# Test Error:
#  Avg loss: 437158.781250, Avg error: 291678.775510
#
# Epoch 96, Batch 1/6, Batch Loss: 220873.7188
# Epoch 96, Batch 2/6, Batch Loss: 297772.8750
# Epoch 96, Batch 3/6, Batch Loss: 368345.8438
# Epoch 96, Batch 4/6, Batch Loss: 221598.5156
# Epoch 96, Batch 5/6, Batch Loss: 258122.8281
# Epoch 96, Batch 6/6, Batch Loss: 214736.2344
# Batch 1/1, Batch Loss: 434379.8125
# Test Error:
#  Avg loss: 434379.812500, Avg error: 280347.122449
#
# Epoch 97, Batch 1/6, Batch Loss: 206019.3906
# Epoch 97, Batch 2/6, Batch Loss: 238582.2656
# Epoch 97, Batch 3/6, Batch Loss: 287765.6562
# Epoch 97, Batch 4/6, Batch Loss: 372959.2812
# Epoch 97, Batch 5/6, Batch Loss: 293378.6875
# Epoch 97, Batch 6/6, Batch Loss: 474086.0312
# Batch 1/1, Batch Loss: 436410.2188
# Test Error:
#  Avg loss: 436410.218750, Avg error: 288783.183673
#
# Epoch 98, Batch 1/6, Batch Loss: 233054.2500
# Epoch 98, Batch 2/6, Batch Loss: 252051.0781
# Epoch 98, Batch 3/6, Batch Loss: 290582.5312
# Epoch 98, Batch 4/6, Batch Loss: 233206.8281
# Epoch 98, Batch 5/6, Batch Loss: 529999.6250
# Epoch 98, Batch 6/6, Batch Loss: 241316.2188
# Batch 1/1, Batch Loss: 471841.3125
# Test Error:
#  Avg loss: 471841.312500, Avg error: 321400.775510
#
# Epoch 99, Batch 1/6, Batch Loss: 320285.2812
# Epoch 99, Batch 2/6, Batch Loss: 299502.0625
# Epoch 99, Batch 3/6, Batch Loss: 411357.2500
# Epoch 99, Batch 4/6, Batch Loss: 268584.0000
# Epoch 99, Batch 5/6, Batch Loss: 310966.4688
# Epoch 99, Batch 6/6, Batch Loss: 283440.7188
# Batch 1/1, Batch Loss: 478242.8125
# Test Error:
#  Avg loss: 478242.812500, Avg error: 326887.795918
#
# Epoch 100, Batch 1/6, Batch Loss: 325892.8125
# Epoch 100, Batch 2/6, Batch Loss: 251976.5156
# Epoch 100, Batch 3/6, Batch Loss: 244541.8906
# Epoch 100, Batch 4/6, Batch Loss: 313875.0938
# Epoch 100, Batch 5/6, Batch Loss: 245041.7031
# Epoch 100, Batch 6/6, Batch Loss: 255860.1250
# Batch 1/1, Batch Loss: 480158.9688
# Test Error:
#  Avg loss: 480158.968750, Avg error: 334750.408163
#
# 2024-09-16 18:20:27.207973 Epoch 100, Average Training loss 272864.6901041667
# Epoch 101, Batch 1/6, Batch Loss: 274209.7188
# Epoch 101, Batch 2/6, Batch Loss: 266198.2188
# Epoch 101, Batch 3/6, Batch Loss: 261669.8594
# Epoch 101, Batch 4/6, Batch Loss: 241324.1562
# Epoch 101, Batch 5/6, Batch Loss: 372009.2188
# Epoch 101, Batch 6/6, Batch Loss: 278469.0625
# Batch 1/1, Batch Loss: 494164.5000
# Test Error:
#  Avg loss: 494164.500000, Avg error: 324152.204082
#
# Epoch 102, Batch 1/6, Batch Loss: 316402.0625
# Epoch 102, Batch 2/6, Batch Loss: 239420.5781
# Epoch 102, Batch 3/6, Batch Loss: 223092.2031
# Epoch 102, Batch 4/6, Batch Loss: 253297.5000
# Epoch 102, Batch 5/6, Batch Loss: 216529.7812
# Epoch 102, Batch 6/6, Batch Loss: 238430.0312
# Batch 1/1, Batch Loss: 434487.1562
# Test Error:
#  Avg loss: 434487.156250, Avg error: 278440.163265
#
# Epoch 103, Batch 1/6, Batch Loss: 241084.4688
# Epoch 103, Batch 2/6, Batch Loss: 276600.5000
# Epoch 103, Batch 3/6, Batch Loss: 240266.3125
# Epoch 103, Batch 4/6, Batch Loss: 257111.9375
# Epoch 103, Batch 5/6, Batch Loss: 253244.4844
# Epoch 103, Batch 6/6, Batch Loss: 201439.2344
# Batch 1/1, Batch Loss: 533900.4375
# Test Error:
#  Avg loss: 533900.437500, Avg error: 342724.408163
#
# Epoch 104, Batch 1/6, Batch Loss: 261253.9219
# Epoch 104, Batch 2/6, Batch Loss: 290831.7500
# Epoch 104, Batch 3/6, Batch Loss: 281406.0312
# Epoch 104, Batch 4/6, Batch Loss: 222133.7500
# Epoch 104, Batch 5/6, Batch Loss: 308179.2188
# Epoch 104, Batch 6/6, Batch Loss: 258400.0000
# Batch 1/1, Batch Loss: 474887.4062
# Test Error:
#  Avg loss: 474887.406250, Avg error: 311248.510204
#
# Epoch 105, Batch 1/6, Batch Loss: 216309.3594
# Epoch 105, Batch 2/6, Batch Loss: 298451.3750
# Epoch 105, Batch 3/6, Batch Loss: 253067.9688
# Epoch 105, Batch 4/6, Batch Loss: 189321.7031
# Epoch 105, Batch 5/6, Batch Loss: 238483.5312
# Epoch 105, Batch 6/6, Batch Loss: 224581.7500
# Batch 1/1, Batch Loss: 464718.5000
# Test Error:
#  Avg loss: 464718.500000, Avg error: 298859.306122
#
# Epoch 106, Batch 1/6, Batch Loss: 226836.7031
# Epoch 106, Batch 2/6, Batch Loss: 242010.3281
# Epoch 106, Batch 3/6, Batch Loss: 245246.6562
# Epoch 106, Batch 4/6, Batch Loss: 232665.5625
# Epoch 106, Batch 5/6, Batch Loss: 266923.6875
# Epoch 106, Batch 6/6, Batch Loss: 221643.3594
# Batch 1/1, Batch Loss: 511021.7812
# Test Error:
#  Avg loss: 511021.781250, Avg error: 322577.816327
#
# Epoch 107, Batch 1/6, Batch Loss: 210833.2500
# Epoch 107, Batch 2/6, Batch Loss: 219899.3438
# Epoch 107, Batch 3/6, Batch Loss: 239353.7188
# Epoch 107, Batch 4/6, Batch Loss: 203816.3750
# Epoch 107, Batch 5/6, Batch Loss: 269071.0312
# Epoch 107, Batch 6/6, Batch Loss: 226737.8281
# Batch 1/1, Batch Loss: 484467.5000
# Test Error:
#  Avg loss: 484467.500000, Avg error: 304331.918367
#
# Epoch 108, Batch 1/6, Batch Loss: 193172.2812
# Epoch 108, Batch 2/6, Batch Loss: 190589.5938
# Epoch 108, Batch 3/6, Batch Loss: 199300.3281
# Epoch 108, Batch 4/6, Batch Loss: 236066.7188
# Epoch 108, Batch 5/6, Batch Loss: 213544.5312
# Epoch 108, Batch 6/6, Batch Loss: 212169.8750
# Batch 1/1, Batch Loss: 495074.5000
# Test Error:
#  Avg loss: 495074.500000, Avg error: 303546.714286
#
# Epoch 109, Batch 1/6, Batch Loss: 228345.0938
# Epoch 109, Batch 2/6, Batch Loss: 244254.6719
# Epoch 109, Batch 3/6, Batch Loss: 283969.9375
# Epoch 109, Batch 4/6, Batch Loss: 173638.1250
# Epoch 109, Batch 5/6, Batch Loss: 287513.5000
# Epoch 109, Batch 6/6, Batch Loss: 167868.8594
# Batch 1/1, Batch Loss: 482188.5000
# Test Error:
#  Avg loss: 482188.500000, Avg error: 298841.102041
#
# Epoch 110, Batch 1/6, Batch Loss: 197965.2188
# Epoch 110, Batch 2/6, Batch Loss: 249032.1406
# Epoch 110, Batch 3/6, Batch Loss: 207784.8438
# Epoch 110, Batch 4/6, Batch Loss: 212745.2500
# Epoch 110, Batch 5/6, Batch Loss: 254765.4844
# Epoch 110, Batch 6/6, Batch Loss: 185413.1406
# Batch 1/1, Batch Loss: 475574.8125
# Test Error:
#  Avg loss: 475574.812500, Avg error: 309459.020408
#
# 2024-09-16 18:22:15.679265 Epoch 110, Average Training loss 217951.01302083334
# Epoch 111, Batch 1/6, Batch Loss: 247598.2969
# Epoch 111, Batch 2/6, Batch Loss: 164306.3906
# Epoch 111, Batch 3/6, Batch Loss: 219343.4219
# Epoch 111, Batch 4/6, Batch Loss: 237871.1094
# Epoch 111, Batch 5/6, Batch Loss: 235245.4062
# Epoch 111, Batch 6/6, Batch Loss: 200986.4844
# Batch 1/1, Batch Loss: 549992.6250
# Test Error:
#  Avg loss: 549992.625000, Avg error: 359623.387755
#
# Epoch 112, Batch 1/6, Batch Loss: 225988.4375
# Epoch 112, Batch 2/6, Batch Loss: 200670.2031
# Epoch 112, Batch 3/6, Batch Loss: 199768.0625
# Epoch 112, Batch 4/6, Batch Loss: 199715.6406
# Epoch 112, Batch 5/6, Batch Loss: 236153.0312
# Epoch 112, Batch 6/6, Batch Loss: 180215.5312
# Batch 1/1, Batch Loss: 483343.2188
# Test Error:
#  Avg loss: 483343.218750, Avg error: 310709.081633
#
# Epoch 113, Batch 1/6, Batch Loss: 151239.2969
# Epoch 113, Batch 2/6, Batch Loss: 189457.0625
# Epoch 113, Batch 3/6, Batch Loss: 167524.8906
# Epoch 113, Batch 4/6, Batch Loss: 240927.1094
# Epoch 113, Batch 5/6, Batch Loss: 198711.2812
# Epoch 113, Batch 6/6, Batch Loss: 172747.8906
# Batch 1/1, Batch Loss: 490126.9688
# Test Error:
#  Avg loss: 490126.968750, Avg error: 303853.714286
#
# Epoch 114, Batch 1/6, Batch Loss: 210764.0312
# Epoch 114, Batch 2/6, Batch Loss: 177417.0625
# Epoch 114, Batch 3/6, Batch Loss: 190763.1875
# Epoch 114, Batch 4/6, Batch Loss: 273397.5312
# Epoch 114, Batch 5/6, Batch Loss: 182031.6406
# Epoch 114, Batch 6/6, Batch Loss: 180622.7500
# Batch 1/1, Batch Loss: 454593.5938
# Test Error:
#  Avg loss: 454593.593750, Avg error: 283903.183673
#
# Epoch 115, Batch 1/6, Batch Loss: 187205.6094
# Epoch 115, Batch 2/6, Batch Loss: 200461.7969
# Epoch 115, Batch 3/6, Batch Loss: 202624.4375
# Epoch 115, Batch 4/6, Batch Loss: 219995.9844
# Epoch 115, Batch 5/6, Batch Loss: 204291.9219
# Epoch 115, Batch 6/6, Batch Loss: 191048.5781
# Batch 1/1, Batch Loss: 451303.5000
# Test Error:
#  Avg loss: 451303.500000, Avg error: 278210.081633
#
# Epoch 116, Batch 1/6, Batch Loss: 141589.9844
# Epoch 116, Batch 2/6, Batch Loss: 231851.6719
# Epoch 116, Batch 3/6, Batch Loss: 201376.0781
# Epoch 116, Batch 4/6, Batch Loss: 195901.7031
# Epoch 116, Batch 5/6, Batch Loss: 166281.6875
# Epoch 116, Batch 6/6, Batch Loss: 238512.7188
# Batch 1/1, Batch Loss: 474223.7188
# Test Error:
#  Avg loss: 474223.718750, Avg error: 290993.510204
#
# Epoch 117, Batch 1/6, Batch Loss: 148776.8594
# Epoch 117, Batch 2/6, Batch Loss: 184181.5156
# Epoch 117, Batch 3/6, Batch Loss: 203040.1719
# Epoch 117, Batch 4/6, Batch Loss: 141080.7500
# Epoch 117, Batch 5/6, Batch Loss: 155677.2031
# Epoch 117, Batch 6/6, Batch Loss: 223336.1719
# Batch 1/1, Batch Loss: 492155.7500
# Test Error:
#  Avg loss: 492155.750000, Avg error: 303138.265306
#
# Epoch 118, Batch 1/6, Batch Loss: 171889.0625
# Epoch 118, Batch 2/6, Batch Loss: 154834.5312
# Epoch 118, Batch 3/6, Batch Loss: 136550.3750
# Epoch 118, Batch 4/6, Batch Loss: 170446.5938
# Epoch 118, Batch 5/6, Batch Loss: 223919.6250
# Epoch 118, Batch 6/6, Batch Loss: 164541.0938
# Batch 1/1, Batch Loss: 488378.3750
# Test Error:
#  Avg loss: 488378.375000, Avg error: 300479.122449
#
# Epoch 119, Batch 1/6, Batch Loss: 160117.2656
# Epoch 119, Batch 2/6, Batch Loss: 161177.5156
# Epoch 119, Batch 3/6, Batch Loss: 175196.2344
# Epoch 119, Batch 4/6, Batch Loss: 174180.3906
# Epoch 119, Batch 5/6, Batch Loss: 159523.3594
# Epoch 119, Batch 6/6, Batch Loss: 137126.2031
# Batch 1/1, Batch Loss: 465527.1250
# Test Error:
#  Avg loss: 465527.125000, Avg error: 282550.326531
#
# Epoch 120, Batch 1/6, Batch Loss: 147348.2969
# Epoch 120, Batch 2/6, Batch Loss: 196872.7188
# Epoch 120, Batch 3/6, Batch Loss: 166883.9375
# Epoch 120, Batch 4/6, Batch Loss: 172634.4688
# Epoch 120, Batch 5/6, Batch Loss: 126787.0156
# Epoch 120, Batch 6/6, Batch Loss: 191888.7812
# Batch 1/1, Batch Loss: 471304.3125
# Test Error:
#  Avg loss: 471304.312500, Avg error: 292599.755102
#
# 2024-09-16 18:24:02.840025 Epoch 120, Average Training loss 167069.203125
# Epoch 121, Batch 1/6, Batch Loss: 182137.8750
# Epoch 121, Batch 2/6, Batch Loss: 148454.3906
# Epoch 121, Batch 3/6, Batch Loss: 119099.6172
# Epoch 121, Batch 4/6, Batch Loss: 175768.6250
# Epoch 121, Batch 5/6, Batch Loss: 165892.0469
# Epoch 121, Batch 6/6, Batch Loss: 165122.8125
# Batch 1/1, Batch Loss: 488866.8750
# Test Error:
#  Avg loss: 488866.875000, Avg error: 308150.020408
#
# Epoch 122, Batch 1/6, Batch Loss: 153769.2344
# Epoch 122, Batch 2/6, Batch Loss: 164373.9375
# Epoch 122, Batch 3/6, Batch Loss: 178282.6406
# Epoch 122, Batch 4/6, Batch Loss: 182825.9531
# Epoch 122, Batch 5/6, Batch Loss: 135658.4375
# Epoch 122, Batch 6/6, Batch Loss: 124127.3281
# Batch 1/1, Batch Loss: 435497.6250
# Test Error:
#  Avg loss: 435497.625000, Avg error: 262794.612245
#
# Epoch 123, Batch 1/6, Batch Loss: 138570.6094
# Epoch 123, Batch 2/6, Batch Loss: 141251.6719
# Epoch 123, Batch 3/6, Batch Loss: 245031.4688
# Epoch 123, Batch 4/6, Batch Loss: 176004.0625
# Epoch 123, Batch 5/6, Batch Loss: 153524.9531
# Epoch 123, Batch 6/6, Batch Loss: 142687.8594
# Batch 1/1, Batch Loss: 477465.9375
# Test Error:
#  Avg loss: 477465.937500, Avg error: 301034.244898
#
# Epoch 124, Batch 1/6, Batch Loss: 151004.9219
# Epoch 124, Batch 2/6, Batch Loss: 173459.0312
# Epoch 124, Batch 3/6, Batch Loss: 145164.1875
# Epoch 124, Batch 4/6, Batch Loss: 211340.4844
# Epoch 124, Batch 5/6, Batch Loss: 115918.6484
# Epoch 124, Batch 6/6, Batch Loss: 130752.5625
# Batch 1/1, Batch Loss: 455345.5000
# Test Error:
#  Avg loss: 455345.500000, Avg error: 290125.224490
#
# Epoch 125, Batch 1/6, Batch Loss: 143903.3750
# Epoch 125, Batch 2/6, Batch Loss: 123172.4375
# Epoch 125, Batch 3/6, Batch Loss: 124747.1406
# Epoch 125, Batch 4/6, Batch Loss: 157559.0781
# Epoch 125, Batch 5/6, Batch Loss: 142056.8438
# Epoch 125, Batch 6/6, Batch Loss: 114018.6797
# Batch 1/1, Batch Loss: 464344.6875
# Test Error:
#  Avg loss: 464344.687500, Avg error: 290374.938776
#
# Epoch 126, Batch 1/6, Batch Loss: 115937.1797
# Epoch 126, Batch 2/6, Batch Loss: 126876.5078
# Epoch 126, Batch 3/6, Batch Loss: 121446.9062
# Epoch 126, Batch 4/6, Batch Loss: 143404.0000
# Epoch 126, Batch 5/6, Batch Loss: 139993.7500
# Epoch 126, Batch 6/6, Batch Loss: 141822.3906
# Batch 1/1, Batch Loss: 472602.5625
# Test Error:
#  Avg loss: 472602.562500, Avg error: 298527.469388
#
# Epoch 127, Batch 1/6, Batch Loss: 111415.3516
# Epoch 127, Batch 2/6, Batch Loss: 142007.8906
# Epoch 127, Batch 3/6, Batch Loss: 162199.1719
# ...
# Epoch 359, Batch 2/6, Batch Loss: 57018.4883
# Epoch 359, Batch 3/6, Batch Loss: 53841.9453
# Epoch 359, Batch 4/6, Batch Loss: 56077.9023
# Epoch 359, Batch 5/6, Batch Loss: 59478.7344
# Epoch 359, Batch 6/6, Batch Loss: 64124.9883
# Batch 1/1, Batch Loss: 411891.4375
# Test Error:
#  Avg loss: 411891.437500, Avg error: 248396.693878
#
# Epoch 360, Batch 1/6, Batch Loss: 51876.2227
# Epoch 360, Batch 2/6, Batch Loss: 71067.9141
# Epoch 360, Batch 3/6, Batch Loss: 67868.6484
# Epoch 360, Batch 4/6, Batch Loss: 89948.1562
# Epoch 360, Batch 5/6, Batch Loss: 70191.8281
# Epoch 360, Batch 6/6, Batch Loss: 72287.7422
# Batch 1/1, Batch Loss: 418758.2500
# Test Error:
#  Avg loss: 418758.250000, Avg error: 256008.918367
#
# 2024-09-16 19:06:39.958080 Epoch 360, Average Training loss 70540.08528645833
# Epoch 361, Batch 1/6, Batch Loss: 77672.2422
# Epoch 361, Batch 2/6, Batch Loss: 60337.7266
# Epoch 361, Batch 3/6, Batch Loss: 57050.9961
# Epoch 361, Batch 4/6, Batch Loss: 62249.4492
# Epoch 361, Batch 5/6, Batch Loss: 70113.6562
# Epoch 361, Batch 6/6, Batch Loss: 61732.3047
# Batch 1/1, Batch Loss: 416177.1875
# Test Error:
#  Avg loss: 416177.187500, Avg error: 255865.795918
#
# Epoch 362, Batch 1/6, Batch Loss: 67250.9922
# Epoch 362, Batch 2/6, Batch Loss: 54736.5469
# Epoch 362, Batch 3/6, Batch Loss: 70485.2266
# Epoch 362, Batch 4/6, Batch Loss: 79140.8594
# Epoch 362, Batch 5/6, Batch Loss: 66816.4375
# Epoch 362, Batch 6/6, Batch Loss: 90395.0859
# Batch 1/1, Batch Loss: 417413.5000
# Test Error:
#  Avg loss: 417413.500000, Avg error: 246653.489796
#
# Epoch 363, Batch 1/6, Batch Loss: 59962.3516
# Epoch 363, Batch 2/6, Batch Loss: 74444.2812
# Epoch 363, Batch 3/6, Batch Loss: 86758.9609
# Epoch 363, Batch 4/6, Batch Loss: 109538.6797
# Epoch 363, Batch 5/6, Batch Loss: 91592.8828
# Epoch 363, Batch 6/6, Batch Loss: 100646.6875
# Batch 1/1, Batch Loss: 415604.6562
# Test Error:
#  Avg loss: 415604.656250, Avg error: 267019.632653
#
# Epoch 364, Batch 1/6, Batch Loss: 127680.1719
# Epoch 364, Batch 2/6, Batch Loss: 74932.3984
# Epoch 364, Batch 3/6, Batch Loss: 91817.0156
# Epoch 364, Batch 4/6, Batch Loss: 129307.7500
# Epoch 364, Batch 5/6, Batch Loss: 138558.1406
# Epoch 364, Batch 6/6, Batch Loss: 96542.9453
# Batch 1/1, Batch Loss: 424960.4688
# Test Error:
#  Avg loss: 424960.468750, Avg error: 259779.326531
#
# Epoch 365, Batch 1/6, Batch Loss: 70020.3594
# Epoch 365, Batch 2/6, Batch Loss: 73415.6953
# Epoch 365, Batch 3/6, Batch Loss: 94839.0625
# Epoch 365, Batch 4/6, Batch Loss: 102026.2891
# Epoch 365, Batch 5/6, Batch Loss: 97368.2656
# Epoch 365, Batch 6/6, Batch Loss: 92198.9688
# Batch 1/1, Batch Loss: 421742.1875
# Test Error:
#  Avg loss: 421742.187500, Avg error: 256285.693878
#
# Epoch 366, Batch 1/6, Batch Loss: 74422.4844
# Epoch 366, Batch 2/6, Batch Loss: 147212.0312
# Epoch 366, Batch 3/6, Batch Loss: 112273.3125
# Epoch 366, Batch 4/6, Batch Loss: 82485.9844
# Epoch 366, Batch 5/6, Batch Loss: 62368.2461
# Epoch 366, Batch 6/6, Batch Loss: 82751.3359
# Batch 1/1, Batch Loss: 412468.8438
# Test Error:
#  Avg loss: 412468.843750, Avg error: 264566.734694
#
# Epoch 367, Batch 1/6, Batch Loss: 101062.7031
# Epoch 367, Batch 2/6, Batch Loss: 89794.9922
# Epoch 367, Batch 3/6, Batch Loss: 68194.5781
# Epoch 367, Batch 4/6, Batch Loss: 92251.9766
# Epoch 367, Batch 5/6, Batch Loss: 114258.0000
# Epoch 367, Batch 6/6, Batch Loss: 97384.7500
# Batch 1/1, Batch Loss: 416616.2812
# Test Error:
#  Avg loss: 416616.281250, Avg error: 259647.346939
#
# Epoch 368, Batch 1/6, Batch Loss: 70442.5234
# Epoch 368, Batch 2/6, Batch Loss: 89945.7109
# Epoch 368, Batch 3/6, Batch Loss: 85250.4531
# Epoch 368, Batch 4/6, Batch Loss: 60436.7617
# Epoch 368, Batch 5/6, Batch Loss: 88791.3359
# Epoch 368, Batch 6/6, Batch Loss: 90749.7188
# Batch 1/1, Batch Loss: 426702.4375
# Test Error:
#  Avg loss: 426702.437500, Avg error: 254459.265306
#
# Epoch 369, Batch 1/6, Batch Loss: 103799.1172
# Epoch 369, Batch 2/6, Batch Loss: 73205.8281
# Epoch 369, Batch 3/6, Batch Loss: 71008.0469
# Epoch 369, Batch 4/6, Batch Loss: 94215.7656
# Epoch 369, Batch 5/6, Batch Loss: 82304.1406
# Epoch 369, Batch 6/6, Batch Loss: 84312.3828
# Batch 1/1, Batch Loss: 411148.7188
# Test Error:
#  Avg loss: 411148.718750, Avg error: 252342.897959
#
# Epoch 370, Batch 1/6, Batch Loss: 45761.3125
# Epoch 370, Batch 2/6, Batch Loss: 74455.3594
# Epoch 370, Batch 3/6, Batch Loss: 82396.1094
# Epoch 370, Batch 4/6, Batch Loss: 113548.9062
# Epoch 370, Batch 5/6, Batch Loss: 50509.2617
# Epoch 370, Batch 6/6, Batch Loss: 140811.7188
# Batch 1/1, Batch Loss: 416774.7812
# Test Error:
#  Avg loss: 416774.781250, Avg error: 275525.714286
#
# 2024-09-16 19:08:25.920735 Epoch 370, Average Training loss 84580.44466145833
# Epoch 371, Batch 1/6, Batch Loss: 154633.3594
# Epoch 371, Batch 2/6, Batch Loss: 135087.1719
# Epoch 371, Batch 3/6, Batch Loss: 61594.2227
# Epoch 371, Batch 4/6, Batch Loss: 73356.1562
# Epoch 371, Batch 5/6, Batch Loss: 101704.2891
# Epoch 371, Batch 6/6, Batch Loss: 104618.1484
# Batch 1/1, Batch Loss: 427938.9062
# Test Error:
#  Avg loss: 427938.906250, Avg error: 258015.591837
#
# Epoch 372, Batch 1/6, Batch Loss: 77739.2031
# Epoch 372, Batch 2/6, Batch Loss: 67995.5234
# Epoch 372, Batch 3/6, Batch Loss: 112718.8906
# Epoch 372, Batch 4/6, Batch Loss: 109026.3281
# Epoch 372, Batch 5/6, Batch Loss: 76640.5469
# Epoch 372, Batch 6/6, Batch Loss: 55598.1172
# Batch 1/1, Batch Loss: 420421.2500
# Test Error:
#  Avg loss: 420421.250000, Avg error: 258913.551020
#
# Epoch 373, Batch 1/6, Batch Loss: 99165.6016
# Epoch 373, Batch 2/6, Batch Loss: 56881.8203
# Epoch 373, Batch 3/6, Batch Loss: 57459.8008
# Epoch 373, Batch 4/6, Batch Loss: 73492.5547
# Epoch 373, Batch 5/6, Batch Loss: 52718.7773
# Epoch 373, Batch 6/6, Batch Loss: 57794.5898
# Batch 1/1, Batch Loss: 415385.9062
# Test Error:
#  Avg loss: 415385.906250, Avg error: 249550.857143
#
# Epoch 374, Batch 1/6, Batch Loss: 128654.0781
# Epoch 374, Batch 2/6, Batch Loss: 50455.3906
# Epoch 374, Batch 3/6, Batch Loss: 70499.3984
# Epoch 374, Batch 4/6, Batch Loss: 66615.7812
# Epoch 374, Batch 5/6, Batch Loss: 69680.1797
# Epoch 374, Batch 6/6, Batch Loss: 83498.1094
# Batch 1/1, Batch Loss: 417126.0938
# Test Error:
#  Avg loss: 417126.093750, Avg error: 254645.346939
#
# Epoch 375, Batch 1/6, Batch Loss: 65226.3008
# Epoch 375, Batch 2/6, Batch Loss: 53624.5859
# Epoch 375, Batch 3/6, Batch Loss: 67246.1172
# Epoch 375, Batch 4/6, Batch Loss: 108144.6016
# Epoch 375, Batch 5/6, Batch Loss: 72893.0234
# Epoch 375, Batch 6/6, Batch Loss: 91692.0312
# Batch 1/1, Batch Loss: 425654.2188
# Test Error:
#  Avg loss: 425654.218750, Avg error: 265159.551020
#
# Epoch 376, Batch 1/6, Batch Loss: 82433.2109
# Epoch 376, Batch 2/6, Batch Loss: 70661.7500
# Epoch 376, Batch 3/6, Batch Loss: 79701.3516
# Epoch 376, Batch 4/6, Batch Loss: 85379.1094
# Epoch 376, Batch 5/6, Batch Loss: 59930.3125
# Epoch 376, Batch 6/6, Batch Loss: 69670.3203
# Batch 1/1, Batch Loss: 420477.2188
# Test Error:
#  Avg loss: 420477.218750, Avg error: 257576.979592
#
# Epoch 377, Batch 1/6, Batch Loss: 80511.7969
# Epoch 377, Batch 2/6, Batch Loss: 57399.5156
# Epoch 377, Batch 3/6, Batch Loss: 64138.2812
# Epoch 377, Batch 4/6, Batch Loss: 87778.3516
# Epoch 377, Batch 5/6, Batch Loss: 56387.0352
# Epoch 377, Batch 6/6, Batch Loss: 79030.5469
# Batch 1/1, Batch Loss: 422840.8750
# Test Error:
#  Avg loss: 422840.875000, Avg error: 254485.265306
#
# Epoch 378, Batch 1/6, Batch Loss: 78997.1094
# Epoch 378, Batch 2/6, Batch Loss: 65880.9453
# Epoch 378, Batch 3/6, Batch Loss: 90569.8984
# Epoch 378, Batch 4/6, Batch Loss: 73111.6641
# Epoch 378, Batch 5/6, Batch Loss: 70400.5547
# Epoch 378, Batch 6/6, Batch Loss: 53046.2031
# Batch 1/1, Batch Loss: 411797.8750
# Test Error:
#  Avg loss: 411797.875000, Avg error: 262323.081633
#
# Epoch 379, Batch 1/6, Batch Loss: 86279.8047
# Epoch 379, Batch 2/6, Batch Loss: 75238.7656
# Epoch 379, Batch 3/6, Batch Loss: 73844.3906
# Epoch 379, Batch 4/6, Batch Loss: 60446.5703
# Epoch 379, Batch 5/6, Batch Loss: 82320.4609
# Epoch 379, Batch 6/6, Batch Loss: 77641.7969
# Batch 1/1, Batch Loss: 412577.1875
# Test Error:
#  Avg loss: 412577.187500, Avg error: 257246.795918
#
# Epoch 380, Batch 1/6, Batch Loss: 73994.6016
# Epoch 380, Batch 2/6, Batch Loss: 75027.2578
# Epoch 380, Batch 3/6, Batch Loss: 68077.9453
# Epoch 380, Batch 4/6, Batch Loss: 69858.8438
# Epoch 380, Batch 5/6, Batch Loss: 52203.1367
# Epoch 380, Batch 6/6, Batch Loss: 82119.7422
# Batch 1/1, Batch Loss: 419458.0938
# Test Error:
#  Avg loss: 419458.093750, Avg error: 252286.734694
#
# 2024-09-16 19:10:12.774578 Epoch 380, Average Training loss 70213.587890625
# Epoch 381, Batch 1/6, Batch Loss: 67601.0391
# Epoch 381, Batch 2/6, Batch Loss: 65316.2617
# Epoch 381, Batch 3/6, Batch Loss: 75827.6094
# Epoch 381, Batch 4/6, Batch Loss: 83989.4531
# Epoch 381, Batch 5/6, Batch Loss: 68509.3828
# Epoch 381, Batch 6/6, Batch Loss: 47486.3984
# Batch 1/1, Batch Loss: 416281.5938
# Test Error:
#  Avg loss: 416281.593750, Avg error: 250924.224490
#
# Epoch 382, Batch 1/6, Batch Loss: 62186.2109
# Epoch 382, Batch 2/6, Batch Loss: 62073.0859
# Epoch 382, Batch 3/6, Batch Loss: 83823.9219
# Epoch 382, Batch 4/6, Batch Loss: 63010.6016
# Epoch 382, Batch 5/6, Batch Loss: 96402.0703
# Epoch 382, Batch 6/6, Batch Loss: 41970.7383
# Batch 1/1, Batch Loss: 413558.1250
# Test Error:
#  Avg loss: 413558.125000, Avg error: 256585.551020
#
# Epoch 383, Batch 1/6, Batch Loss: 68229.7031
# Epoch 383, Batch 2/6, Batch Loss: 41570.1914
# Epoch 383, Batch 3/6, Batch Loss: 62440.8125
# Epoch 383, Batch 4/6, Batch Loss: 63871.0312
# Epoch 383, Batch 5/6, Batch Loss: 97331.2344
# Epoch 383, Batch 6/6, Batch Loss: 56516.6680
# Batch 1/1, Batch Loss: 411763.3125
# Test Error:
#  Avg loss: 411763.312500, Avg error: 256696.285714
#
# Epoch 384, Batch 1/6, Batch Loss: 77463.3359
# Epoch 384, Batch 2/6, Batch Loss: 69560.0547
# Epoch 384, Batch 3/6, Batch Loss: 65187.7734
# Epoch 384, Batch 4/6, Batch Loss: 57865.3789
# Epoch 384, Batch 5/6, Batch Loss: 82870.9844
# Epoch 384, Batch 6/6, Batch Loss: 55094.5859
# Batch 1/1, Batch Loss: 414838.7500
# Test Error:
#  Avg loss: 414838.750000, Avg error: 250462.285714
#
# Epoch 385, Batch 1/6, Batch Loss: 128486.7812
# Epoch 385, Batch 2/6, Batch Loss: 53274.3203
# Epoch 385, Batch 3/6, Batch Loss: 84346.8359
# Epoch 385, Batch 4/6, Batch Loss: 52486.5078
# Epoch 385, Batch 5/6, Batch Loss: 58910.7188
# Epoch 385, Batch 6/6, Batch Loss: 73266.9531
# Batch 1/1, Batch Loss: 412206.4062
# Test Error:
#  Avg loss: 412206.406250, Avg error: 251624.306122
#
# Epoch 386, Batch 1/6, Batch Loss: 85940.8203
# Epoch 386, Batch 2/6, Batch Loss: 61101.2148
# Epoch 386, Batch 3/6, Batch Loss: 81404.0781
# Epoch 386, Batch 4/6, Batch Loss: 76407.7578
# Epoch 386, Batch 5/6, Batch Loss: 59880.0273
# Epoch 386, Batch 6/6, Batch Loss: 62157.3125
# Batch 1/1, Batch Loss: 415935.0000
# Test Error:
#  Avg loss: 415935.000000, Avg error: 253975.755102
#
# Epoch 387, Batch 1/6, Batch Loss: 65445.4219
# Epoch 387, Batch 2/6, Batch Loss: 71328.2500
# Epoch 387, Batch 3/6, Batch Loss: 63347.5391
# Epoch 387, Batch 4/6, Batch Loss: 69010.7031
# Epoch 387, Batch 5/6, Batch Loss: 59383.5586
# Epoch 387, Batch 6/6, Batch Loss: 105772.5469
# Batch 1/1, Batch Loss: 414077.0625
# Test Error:
#  Avg loss: 414077.062500, Avg error: 256415.326531
#
# Epoch 388, Batch 1/6, Batch Loss: 77461.7109
# Epoch 388, Batch 2/6, Batch Loss: 70887.3672
# Epoch 388, Batch 3/6, Batch Loss: 110652.7891
# Epoch 388, Batch 4/6, Batch Loss: 72688.1250
# Epoch 388, Batch 5/6, Batch Loss: 65270.6602
# Epoch 388, Batch 6/6, Batch Loss: 79622.4219
# Batch 1/1, Batch Loss: 418683.4688
# Test Error:
#  Avg loss: 418683.468750, Avg error: 271845.387755
#
# Epoch 389, Batch 1/6, Batch Loss: 86283.0312
# Epoch 389, Batch 2/6, Batch Loss: 46589.9062
# Epoch 389, Batch 3/6, Batch Loss: 56667.8945
# Epoch 389, Batch 4/6, Batch Loss: 91741.2031
# Epoch 389, Batch 5/6, Batch Loss: 115711.1719
# Epoch 389, Batch 6/6, Batch Loss: 77349.3594
# Batch 1/1, Batch Loss: 415055.4688
# Test Error:
#  Avg loss: 415055.468750, Avg error: 268048.693878
#
# Epoch 390, Batch 1/6, Batch Loss: 86487.1484
# Epoch 390, Batch 2/6, Batch Loss: 97891.2734
# Epoch 390, Batch 3/6, Batch Loss: 72014.8984
# Epoch 390, Batch 4/6, Batch Loss: 84952.6172
# Epoch 390, Batch 5/6, Batch Loss: 112868.3281
# Epoch 390, Batch 6/6, Batch Loss: 115116.5625
# Batch 1/1, Batch Loss: 418626.7500
# Test Error:
#  Avg loss: 418626.750000, Avg error: 250307.040816
#
# 2024-09-16 19:11:59.591491 Epoch 390, Average Training loss 94888.47135416667
# Epoch 391, Batch 1/6, Batch Loss: 94223.5391
# Epoch 391, Batch 2/6, Batch Loss: 71676.3906
# Epoch 391, Batch 3/6, Batch Loss: 91409.3594
# Epoch 391, Batch 4/6, Batch Loss: 75623.7578
# Epoch 391, Batch 5/6, Batch Loss: 69810.6641
# Epoch 391, Batch 6/6, Batch Loss: 178363.0781
# Batch 1/1, Batch Loss: 423505.0312
# Test Error:
#  Avg loss: 423505.031250, Avg error: 251971.469388
#
# Epoch 392, Batch 1/6, Batch Loss: 96143.2969
# Epoch 392, Batch 2/6, Batch Loss: 134281.0781
# Epoch 392, Batch 3/6, Batch Loss: 171082.6094
# Epoch 392, Batch 4/6, Batch Loss: 156395.0156
# Epoch 392, Batch 5/6, Batch Loss: 87977.4922
# Epoch 392, Batch 6/6, Batch Loss: 82330.5703
# Batch 1/1, Batch Loss: 415755.5312
# Test Error:
#  Avg loss: 415755.531250, Avg error: 278221.510204
#
# Epoch 393, Batch 1/6, Batch Loss: 94170.4531
# Epoch 393, Batch 2/6, Batch Loss: 102618.2500
# Epoch 393, Batch 3/6, Batch Loss: 87659.8984
# Epoch 393, Batch 4/6, Batch Loss: 61447.3203
# Epoch 393, Batch 5/6, Batch Loss: 94633.1016
# Epoch 393, Batch 6/6, Batch Loss: 98492.7500
# Batch 1/1, Batch Loss: 425479.5625
# Test Error:
#  Avg loss: 425479.562500, Avg error: 251461.530612
#
# Epoch 394, Batch 1/6, Batch Loss: 79296.7266
# Epoch 394, Batch 2/6, Batch Loss: 87100.6172
# Epoch 394, Batch 3/6, Batch Loss: 60651.9492
# Epoch 394, Batch 4/6, Batch Loss: 115625.8750
# Epoch 394, Batch 5/6, Batch Loss: 50511.3477
# Epoch 394, Batch 6/6, Batch Loss: 67396.3672
# Batch 1/1, Batch Loss: 416084.7188
# Test Error:
#  Avg loss: 416084.718750, Avg error: 246132.489796
#
# Epoch 395, Batch 1/6, Batch Loss: 63594.7227
# Epoch 395, Batch 2/6, Batch Loss: 64269.3945
# Epoch 395, Batch 3/6, Batch Loss: 72347.7812
# Epoch 395, Batch 4/6, Batch Loss: 47741.1758
# Epoch 395, Batch 5/6, Batch Loss: 83600.4531
# Epoch 395, Batch 6/6, Batch Loss: 62234.6602
# Batch 1/1, Batch Loss: 413486.5312
# Test Error:
#  Avg loss: 413486.531250, Avg error: 262176.081633
#
# Epoch 396, Batch 1/6, Batch Loss: 68200.7891
# Epoch 396, Batch 2/6, Batch Loss: 59662.0547
# Epoch 396, Batch 3/6, Batch Loss: 98490.8359
# Epoch 396, Batch 4/6, Batch Loss: 71651.6953
# Epoch 396, Batch 5/6, Batch Loss: 127200.7344
# Epoch 396, Batch 6/6, Batch Loss: 88994.7500
# Batch 1/1, Batch Loss: 426591.2500
# Test Error:
#  Avg loss: 426591.250000, Avg error: 262363.836735
#
# Epoch 397, Batch 1/6, Batch Loss: 124032.4062
# Epoch 397, Batch 2/6, Batch Loss: 62722.0391
# Epoch 397, Batch 3/6, Batch Loss: 119672.7812
# Epoch 397, Batch 4/6, Batch Loss: 102324.7578
# Epoch 397, Batch 5/6, Batch Loss: 44484.6367
# Epoch 397, Batch 6/6, Batch Loss: 76877.2422
# Batch 1/1, Batch Loss: 422869.9688
# Test Error:
#  Avg loss: 422869.968750, Avg error: 254725.142857
#
# Epoch 398, Batch 1/6, Batch Loss: 92712.6406
# Epoch 398, Batch 2/6, Batch Loss: 94712.2188
# Epoch 398, Batch 3/6, Batch Loss: 72100.1484
# Epoch 398, Batch 4/6, Batch Loss: 75552.5625
# Epoch 398, Batch 5/6, Batch Loss: 77930.2734
# Epoch 398, Batch 6/6, Batch Loss: 71840.3984
# Batch 1/1, Batch Loss: 409229.8125
# Test Error:
#  Avg loss: 409229.812500, Avg error: 253099.265306
#
# Epoch 399, Batch 1/6, Batch Loss: 51741.5078
# Epoch 399, Batch 2/6, Batch Loss: 69334.1016
# Epoch 399, Batch 3/6, Batch Loss: 69465.2656
# Epoch 399, Batch 4/6, Batch Loss: 60427.6602
# Epoch 399, Batch 5/6, Batch Loss: 147233.3750
# Epoch 399, Batch 6/6, Batch Loss: 81531.3438
# Batch 1/1, Batch Loss: 418276.7500
# Test Error:
#  Avg loss: 418276.750000, Avg error: 261025.551020
#
# Epoch 400, Batch 1/6, Batch Loss: 51227.7695
# Epoch 400, Batch 2/6, Batch Loss: 58177.8008
# Epoch 400, Batch 3/6, Batch Loss: 69692.1250
# Epoch 400, Batch 4/6, Batch Loss: 72870.0078
# Epoch 400, Batch 5/6, Batch Loss: 72878.9141
# Epoch 400, Batch 6/6, Batch Loss: 60393.3828
# Batch 1/1, Batch Loss: 421752.2812
# Test Error:
#  Avg loss: 421752.281250, Avg error: 262117.244898
#
# 2024-09-16 19:13:46.738971 Epoch 400, Average Training loss 64206.666666666664

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
