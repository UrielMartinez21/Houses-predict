# %%
"""
Cambios en la arquitectura de la red neuronal convolucional

    - Valor de funcion de regularizacion L2 a 0.01
    - Cambiar tamaño del kernel 5x5 por 3x3
    - Se agrego una capa convolucional
    - Se cambio maxpool por averagepool
"""

# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %%
# --> Definir si viene desde local o drive

ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')
train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))       # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')                         # Quitar los ejes
    plt.show()

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        """
        Las convoluciones más pequeñas, como de tamaño 3x3, son útiles para capturar características más detalladas.
        Al combinar capas de convoluciones más pequeñas (en lugar de kernels grandes como 5x5), el modelo puede aprender
        mejor características complejas a través de múltiples capas.
        """
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),   # Convolución más pequeña
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=3, stride=2),                  # Pooling con AvgPool2d
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=3, padding=1),           # Otra convolución 3x3
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=3, stride=2),                  # AvgPool2d aquí también
            nn.Dropout(),

            nn.Conv2d(128, 128, kernel_size=3, padding=1),          # Convolución 3x3 más profunda
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=3, stride=2),                  # Cambiado a AvgPool2d
            nn.Dropout(),                                           # Añadir dropout adicional

            nn.Conv2d(128, 64, kernel_size=3, padding=1),           # Última convolución 3x3
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=2, stride=2),                  # AvgPool2d en la última capa
            nn.Dropout(),

            # Nueva capa convolucional adicional
            nn.Conv2d(64, 32, kernel_size=3, padding=1),            # Nueva convolución 3x3
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=2, stride=2),                  # Pooling después de la nueva convolución
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(5184, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 32*12*12)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            # Valores a proar: 0.05, 0.01, 0.001
            l2_lambda = 0.01
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones
data1 = CustomImageDataset(df=train)

# Dataset con transformación de normalización
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desplazamiento de canales y normalización
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),    # Cambiar los canales RGB a BGR
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                        # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                         # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo horizontal y normalización
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=1),            # Girar horizontalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo vertical y normalización
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=1),              # Girar verticalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desenfoque gaussiano y normalización
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Imagen Original', 'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    if i == 1:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}")
    else:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data1, data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 2597 Val: 289

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data1, data2, data3, data4, data5, data6

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
# optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda

# %%
# --> Crear los dataloaders
batch_size_train = 53
batch_size_val = 17
# batch_size=64

if device == 'cuda':
    train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True, num_workers=3)
    val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False, num_workers=3)
else:
    train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True)
    val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 2597 - Baches 49
# Muestras de test: 289 - Baches 17
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# Entrenamiento
n_epochs = 175
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 103, Batch 45/49, Batch Loss: 107992.9609
# Epoch 103, Batch 46/49, Batch Loss: 120466.6172
# Epoch 103, Batch 47/49, Batch Loss: 85788.3203
# Epoch 103, Batch 48/49, Batch Loss: 69238.5781
# Epoch 103, Batch 49/49, Batch Loss: 72930.1484
# Batch 1/17, Batch Loss: 139487.7344
# Batch 2/17, Batch Loss: 127458.8750
# Batch 3/17, Batch Loss: 200472.9688
# Batch 4/17, Batch Loss: 271292.2188
# Batch 5/17, Batch Loss: 317962.5625
# Batch 6/17, Batch Loss: 520790.6250
# Batch 7/17, Batch Loss: 99534.5469
# Batch 8/17, Batch Loss: 194784.6562
# Batch 9/17, Batch Loss: 106215.5391
# Batch 10/17, Batch Loss: 202683.7969
# Batch 11/17, Batch Loss: 390384.5000
# Batch 12/17, Batch Loss: 266532.2500
# Batch 13/17, Batch Loss: 278355.0000
# Batch 14/17, Batch Loss: 155805.7500
# Batch 15/17, Batch Loss: 310737.8438
# Batch 16/17, Batch Loss: 400476.9688
# Batch 17/17, Batch Loss: 132478.8281
# Test Error:
#  Avg loss: 242085.568474, Avg error: 149748.881488
#
# Epoch 104, Batch 1/49, Batch Loss: 97817.0859
# Epoch 104, Batch 2/49, Batch Loss: 79515.9609
# Epoch 104, Batch 3/49, Batch Loss: 143803.7969
# Epoch 104, Batch 4/49, Batch Loss: 107792.7109
# Epoch 104, Batch 5/49, Batch Loss: 111689.3750
# Epoch 104, Batch 6/49, Batch Loss: 97497.0938
# Epoch 104, Batch 7/49, Batch Loss: 88334.8203
# Epoch 104, Batch 8/49, Batch Loss: 84135.3125
# Epoch 104, Batch 9/49, Batch Loss: 71201.5938
# Epoch 104, Batch 10/49, Batch Loss: 86275.9141
# Epoch 104, Batch 11/49, Batch Loss: 77875.9062
# Epoch 104, Batch 12/49, Batch Loss: 97450.8594
# Epoch 104, Batch 13/49, Batch Loss: 172668.7812
# Epoch 104, Batch 14/49, Batch Loss: 88752.4141
# Epoch 104, Batch 15/49, Batch Loss: 90359.9453
# Epoch 104, Batch 16/49, Batch Loss: 97718.8359
# Epoch 104, Batch 17/49, Batch Loss: 143267.0469
# Epoch 104, Batch 18/49, Batch Loss: 118124.4141
# Epoch 104, Batch 19/49, Batch Loss: 118907.5469
# Epoch 104, Batch 20/49, Batch Loss: 115775.3047
# Epoch 104, Batch 21/49, Batch Loss: 125063.0156
# Epoch 104, Batch 22/49, Batch Loss: 97374.3906
# Epoch 104, Batch 23/49, Batch Loss: 75152.7266
# Epoch 104, Batch 24/49, Batch Loss: 87850.6562
# Epoch 104, Batch 25/49, Batch Loss: 159475.7031
# Epoch 104, Batch 26/49, Batch Loss: 101996.9922
# Epoch 104, Batch 27/49, Batch Loss: 110037.5391
# Epoch 104, Batch 28/49, Batch Loss: 82293.0703
# Epoch 104, Batch 29/49, Batch Loss: 98470.7266
# Epoch 104, Batch 30/49, Batch Loss: 92835.4062
# Epoch 104, Batch 31/49, Batch Loss: 114692.6953
# Epoch 104, Batch 32/49, Batch Loss: 87917.8281
# Epoch 104, Batch 33/49, Batch Loss: 90914.4297
# Epoch 104, Batch 34/49, Batch Loss: 77395.2344
# Epoch 104, Batch 35/49, Batch Loss: 116125.3359
# Epoch 104, Batch 36/49, Batch Loss: 83878.0312
# Epoch 104, Batch 37/49, Batch Loss: 112534.3594
# Epoch 104, Batch 38/49, Batch Loss: 78421.2188
# Epoch 104, Batch 39/49, Batch Loss: 102703.6719
# Epoch 104, Batch 40/49, Batch Loss: 100265.4844
# Epoch 104, Batch 41/49, Batch Loss: 76268.3594
# Epoch 104, Batch 42/49, Batch Loss: 97969.7891
# Epoch 104, Batch 43/49, Batch Loss: 80467.5469
# Epoch 104, Batch 44/49, Batch Loss: 88046.1953
# Epoch 104, Batch 45/49, Batch Loss: 69961.4141
# Epoch 104, Batch 46/49, Batch Loss: 101608.5469
# Epoch 104, Batch 47/49, Batch Loss: 110275.3750
# Epoch 104, Batch 48/49, Batch Loss: 137245.0000
# Epoch 104, Batch 49/49, Batch Loss: 87985.3438
# Batch 1/17, Batch Loss: 130440.7188
# Batch 2/17, Batch Loss: 117841.0469
# Batch 3/17, Batch Loss: 194605.7031
# Batch 4/17, Batch Loss: 275348.9375
# Batch 5/17, Batch Loss: 329464.4688
# Batch 6/17, Batch Loss: 505997.3750
# Batch 7/17, Batch Loss: 88919.1250
# Batch 8/17, Batch Loss: 190630.0469
# Batch 9/17, Batch Loss: 102926.4141
# Batch 10/17, Batch Loss: 192559.2969
# Batch 11/17, Batch Loss: 404809.3750
# Batch 12/17, Batch Loss: 273491.8438
# Batch 13/17, Batch Loss: 273507.4688
# Batch 14/17, Batch Loss: 205421.2188
# Batch 15/17, Batch Loss: 303083.3750
# Batch 16/17, Batch Loss: 364639.6875
# Batch 17/17, Batch Loss: 129925.6406
# Test Error:
#  Avg loss: 240212.455423, Avg error: 144436.339533
#
# Epoch 105, Batch 1/49, Batch Loss: 122412.6953
# Epoch 105, Batch 2/49, Batch Loss: 94258.9453
# Epoch 105, Batch 3/49, Batch Loss: 89607.3906
# Epoch 105, Batch 4/49, Batch Loss: 108608.8203
# Epoch 105, Batch 5/49, Batch Loss: 86215.1016
# Epoch 105, Batch 6/49, Batch Loss: 78683.9766
# Epoch 105, Batch 7/49, Batch Loss: 96015.9219
# Epoch 105, Batch 8/49, Batch Loss: 108763.5859
# Epoch 105, Batch 9/49, Batch Loss: 113682.3281
# Epoch 105, Batch 10/49, Batch Loss: 88228.4688
# Epoch 105, Batch 11/49, Batch Loss: 95377.9922
# Epoch 105, Batch 12/49, Batch Loss: 81916.3125
# Epoch 105, Batch 13/49, Batch Loss: 100897.5469
# Epoch 105, Batch 14/49, Batch Loss: 101262.6641
# Epoch 105, Batch 15/49, Batch Loss: 75414.4141
# Epoch 105, Batch 16/49, Batch Loss: 83875.6094
# Epoch 105, Batch 17/49, Batch Loss: 66100.9375
# Epoch 105, Batch 18/49, Batch Loss: 85921.5625
# Epoch 105, Batch 19/49, Batch Loss: 115577.6562
# Epoch 105, Batch 20/49, Batch Loss: 78130.7188
# Epoch 105, Batch 21/49, Batch Loss: 136574.8594
# Epoch 105, Batch 22/49, Batch Loss: 73934.5312
# Epoch 105, Batch 23/49, Batch Loss: 82407.6328
# Epoch 105, Batch 24/49, Batch Loss: 89889.2266
# Epoch 105, Batch 25/49, Batch Loss: 76215.6719
# Epoch 105, Batch 26/49, Batch Loss: 158238.7188
# Epoch 105, Batch 27/49, Batch Loss: 99994.0781
# Epoch 105, Batch 28/49, Batch Loss: 77925.5859
# Epoch 105, Batch 29/49, Batch Loss: 75044.0938
# Epoch 105, Batch 30/49, Batch Loss: 77696.6875
# Epoch 105, Batch 31/49, Batch Loss: 184267.5625
# Epoch 105, Batch 32/49, Batch Loss: 79749.3438
# Epoch 105, Batch 33/49, Batch Loss: 90778.8594
# Epoch 105, Batch 34/49, Batch Loss: 82658.5234
# Epoch 105, Batch 35/49, Batch Loss: 80567.5547
# Epoch 105, Batch 36/49, Batch Loss: 89382.6562
# Epoch 105, Batch 37/49, Batch Loss: 63686.2422
# Epoch 105, Batch 38/49, Batch Loss: 95395.0000
# Epoch 105, Batch 39/49, Batch Loss: 85788.4766
# Epoch 105, Batch 40/49, Batch Loss: 98490.2812
# Epoch 105, Batch 41/49, Batch Loss: 83596.7812
# Epoch 105, Batch 42/49, Batch Loss: 79812.9844
# Epoch 105, Batch 43/49, Batch Loss: 81432.7891
# Epoch 105, Batch 44/49, Batch Loss: 77288.2422
# Epoch 105, Batch 45/49, Batch Loss: 101152.8047
# Epoch 105, Batch 46/49, Batch Loss: 69729.7500
# Epoch 105, Batch 47/49, Batch Loss: 93296.6484
# Epoch 105, Batch 48/49, Batch Loss: 103369.8828
# Epoch 105, Batch 49/49, Batch Loss: 120928.9453
# Batch 1/17, Batch Loss: 146007.9062
# Batch 2/17, Batch Loss: 150082.8438
# Batch 3/17, Batch Loss: 182679.8594
# Batch 4/17, Batch Loss: 259665.0000
# Batch 5/17, Batch Loss: 320588.7188
# Batch 6/17, Batch Loss: 494901.5625
# Batch 7/17, Batch Loss: 112945.6719
# Batch 8/17, Batch Loss: 176251.7812
# Batch 9/17, Batch Loss: 100714.2734
# Batch 10/17, Batch Loss: 182433.2031
# Batch 11/17, Batch Loss: 384988.1875
# Batch 12/17, Batch Loss: 256118.7656
# Batch 13/17, Batch Loss: 248550.0781
# Batch 14/17, Batch Loss: 191653.2969
# Batch 15/17, Batch Loss: 296263.1250
# Batch 16/17, Batch Loss: 346576.6562
# Batch 17/17, Batch Loss: 135647.3438
# Test Error:
#  Avg loss: 234474.604320, Avg error: 141388.183824
#
# Epoch 106, Batch 1/49, Batch Loss: 91699.8281
# Epoch 106, Batch 2/49, Batch Loss: 79542.7812
# Epoch 106, Batch 3/49, Batch Loss: 84755.0859
# Epoch 106, Batch 4/49, Batch Loss: 88840.2422
# Epoch 106, Batch 5/49, Batch Loss: 87546.6641
# Epoch 106, Batch 6/49, Batch Loss: 112659.1250
# Epoch 106, Batch 7/49, Batch Loss: 99200.2578
# Epoch 106, Batch 8/49, Batch Loss: 86508.3438
# Epoch 106, Batch 9/49, Batch Loss: 74763.8906
# Epoch 106, Batch 10/49, Batch Loss: 83960.5703
# Epoch 106, Batch 11/49, Batch Loss: 104772.2109
# Epoch 106, Batch 12/49, Batch Loss: 84388.6484
# Epoch 106, Batch 13/49, Batch Loss: 82017.8828
# Epoch 106, Batch 14/49, Batch Loss: 84565.0000
# Epoch 106, Batch 15/49, Batch Loss: 97383.9297
# Epoch 106, Batch 16/49, Batch Loss: 227362.8906
# Epoch 106, Batch 17/49, Batch Loss: 95271.2734
# Epoch 106, Batch 18/49, Batch Loss: 83692.2500
# Epoch 106, Batch 19/49, Batch Loss: 96513.3672
# Epoch 106, Batch 20/49, Batch Loss: 325549.2500
# Epoch 106, Batch 21/49, Batch Loss: 82448.5391
# Epoch 106, Batch 22/49, Batch Loss: 98849.4922
# Epoch 106, Batch 23/49, Batch Loss: 121062.9531
# Epoch 106, Batch 24/49, Batch Loss: 102450.4141
# Epoch 106, Batch 25/49, Batch Loss: 79067.9141
# Epoch 106, Batch 26/49, Batch Loss: 91065.0000
# Epoch 106, Batch 27/49, Batch Loss: 83784.6094
# Epoch 106, Batch 28/49, Batch Loss: 60948.5547
# Epoch 106, Batch 29/49, Batch Loss: 61416.2383
# Epoch 106, Batch 30/49, Batch Loss: 82468.6641
# Epoch 106, Batch 31/49, Batch Loss: 136717.1250
# Epoch 106, Batch 32/49, Batch Loss: 78990.8203
# Epoch 106, Batch 33/49, Batch Loss: 103590.4766
# Epoch 106, Batch 34/49, Batch Loss: 87803.5703
# Epoch 106, Batch 35/49, Batch Loss: 111364.8984
# Epoch 106, Batch 36/49, Batch Loss: 105137.7969
# Epoch 106, Batch 37/49, Batch Loss: 81310.5781
# Epoch 106, Batch 38/49, Batch Loss: 86808.8359
# Epoch 106, Batch 39/49, Batch Loss: 118897.0859
# Epoch 106, Batch 40/49, Batch Loss: 103599.8438
# Epoch 106, Batch 41/49, Batch Loss: 100048.7344
# Epoch 106, Batch 42/49, Batch Loss: 88219.4375
# Epoch 106, Batch 43/49, Batch Loss: 122015.1484
# Epoch 106, Batch 44/49, Batch Loss: 109092.6719
# Epoch 106, Batch 45/49, Batch Loss: 104347.9297
# Epoch 106, Batch 46/49, Batch Loss: 174462.7031
# Epoch 106, Batch 47/49, Batch Loss: 76586.0625
# Epoch 106, Batch 48/49, Batch Loss: 85388.0625
# Epoch 106, Batch 49/49, Batch Loss: 101032.4609
# Batch 1/17, Batch Loss: 146205.9062
# Batch 2/17, Batch Loss: 118866.6562
# Batch 3/17, Batch Loss: 186126.3906
# Batch 4/17, Batch Loss: 253263.6406
# Batch 5/17, Batch Loss: 318877.5312
# Batch 6/17, Batch Loss: 510098.1875
# Batch 7/17, Batch Loss: 94224.5391
# Batch 8/17, Batch Loss: 191717.6406
# Batch 9/17, Batch Loss: 99206.1484
# Batch 10/17, Batch Loss: 189292.7656
# Batch 11/17, Batch Loss: 393819.3750
# Batch 12/17, Batch Loss: 269453.5938
# Batch 13/17, Batch Loss: 271475.4375
# Batch 14/17, Batch Loss: 176682.9688
# Batch 15/17, Batch Loss: 306750.2812
# Batch 16/17, Batch Loss: 377039.7188
# Batch 17/17, Batch Loss: 142441.9062
# Test Error:
#  Avg loss: 237973.099265, Avg error: 145540.710640
#
# Epoch 107, Batch 1/49, Batch Loss: 108731.9531
# Epoch 107, Batch 2/49, Batch Loss: 58091.8164
# Epoch 107, Batch 3/49, Batch Loss: 141875.2500
# Epoch 107, Batch 4/49, Batch Loss: 83459.3203
# Epoch 107, Batch 5/49, Batch Loss: 72199.2422
# Epoch 107, Batch 6/49, Batch Loss: 81057.0312
# Epoch 107, Batch 7/49, Batch Loss: 131998.8281
# Epoch 107, Batch 8/49, Batch Loss: 63532.3828
# Epoch 107, Batch 9/49, Batch Loss: 63226.2422
# Epoch 107, Batch 10/49, Batch Loss: 93572.3828
# Epoch 107, Batch 11/49, Batch Loss: 148318.2812
# Epoch 107, Batch 12/49, Batch Loss: 80539.4297
# Epoch 107, Batch 13/49, Batch Loss: 98956.9453
# Epoch 107, Batch 14/49, Batch Loss: 82402.6172
# Epoch 107, Batch 15/49, Batch Loss: 117415.0781
# Epoch 107, Batch 16/49, Batch Loss: 103292.6250
# Epoch 107, Batch 17/49, Batch Loss: 110976.1328
# Epoch 107, Batch 18/49, Batch Loss: 89033.2812
# Epoch 107, Batch 19/49, Batch Loss: 89187.1250
# Epoch 107, Batch 20/49, Batch Loss: 112324.2031
# Epoch 107, Batch 21/49, Batch Loss: 88260.6953
# Epoch 107, Batch 22/49, Batch Loss: 100759.6094
# Epoch 107, Batch 23/49, Batch Loss: 83681.9922
# Epoch 107, Batch 24/49, Batch Loss: 80464.7109
# Epoch 107, Batch 25/49, Batch Loss: 114277.4609
# Epoch 107, Batch 26/49, Batch Loss: 81363.0156
# Epoch 107, Batch 27/49, Batch Loss: 76855.4609
# Epoch 107, Batch 28/49, Batch Loss: 128737.6250
# Epoch 107, Batch 29/49, Batch Loss: 92663.0547
# Epoch 107, Batch 30/49, Batch Loss: 89384.8984
# Epoch 107, Batch 31/49, Batch Loss: 112355.9062
# Epoch 107, Batch 32/49, Batch Loss: 78292.8203
# Epoch 107, Batch 33/49, Batch Loss: 79118.6797
# Epoch 107, Batch 34/49, Batch Loss: 64786.4453
# Epoch 107, Batch 35/49, Batch Loss: 121446.8516
# Epoch 107, Batch 36/49, Batch Loss: 96260.2266
# Epoch 107, Batch 37/49, Batch Loss: 91789.9531
# Epoch 107, Batch 38/49, Batch Loss: 97479.7734
# Epoch 107, Batch 39/49, Batch Loss: 103103.8906
# Epoch 107, Batch 40/49, Batch Loss: 75599.8984
# Epoch 107, Batch 41/49, Batch Loss: 97773.1875
# Epoch 107, Batch 42/49, Batch Loss: 81524.7656
# Epoch 107, Batch 43/49, Batch Loss: 65595.6250
# Epoch 107, Batch 44/49, Batch Loss: 97259.0781
# Epoch 107, Batch 45/49, Batch Loss: 151669.4531
# Epoch 107, Batch 46/49, Batch Loss: 79899.6172
# Epoch 107, Batch 47/49, Batch Loss: 86661.0469
# Epoch 107, Batch 48/49, Batch Loss: 74299.8281
# Epoch 107, Batch 49/49, Batch Loss: 113617.8047
# Batch 1/17, Batch Loss: 134801.8594
# Batch 2/17, Batch Loss: 112216.0000
# Batch 3/17, Batch Loss: 173183.0000
# Batch 4/17, Batch Loss: 257838.0625
# Batch 5/17, Batch Loss: 312429.9688
# Batch 6/17, Batch Loss: 506921.9062
# Batch 7/17, Batch Loss: 96777.0781
# Batch 8/17, Batch Loss: 186009.6250
# Batch 9/17, Batch Loss: 96953.6641
# Batch 10/17, Batch Loss: 194301.3281
# Batch 11/17, Batch Loss: 380105.8125
# Batch 12/17, Batch Loss: 262880.4688
# Batch 13/17, Batch Loss: 249006.1094
# Batch 14/17, Batch Loss: 158874.6250
# Batch 15/17, Batch Loss: 303410.5625
# Batch 16/17, Batch Loss: 352364.8125
# Batch 17/17, Batch Loss: 116732.2344
# Test Error:
#  Avg loss: 229106.301011, Avg error: 134229.411765
#
# Epoch 108, Batch 1/49, Batch Loss: 79187.7422
# Epoch 108, Batch 2/49, Batch Loss: 90036.9844
# Epoch 108, Batch 3/49, Batch Loss: 99070.9531
# Epoch 108, Batch 4/49, Batch Loss: 75189.0312
# Epoch 108, Batch 5/49, Batch Loss: 101669.7812
# Epoch 108, Batch 6/49, Batch Loss: 89360.7031
# Epoch 108, Batch 7/49, Batch Loss: 174969.7188
# Epoch 108, Batch 8/49, Batch Loss: 80651.7031
# Epoch 108, Batch 9/49, Batch Loss: 74470.8125
# Epoch 108, Batch 10/49, Batch Loss: 68738.1016
# Epoch 108, Batch 11/49, Batch Loss: 136100.3125
# Epoch 108, Batch 12/49, Batch Loss: 75204.0547
# Epoch 108, Batch 13/49, Batch Loss: 84872.0703
# Epoch 108, Batch 14/49, Batch Loss: 71855.7500
# Epoch 108, Batch 15/49, Batch Loss: 142633.0469
# Epoch 108, Batch 16/49, Batch Loss: 90323.1250
# Epoch 108, Batch 17/49, Batch Loss: 94677.2656
# Epoch 108, Batch 18/49, Batch Loss: 102093.4531
# Epoch 108, Batch 19/49, Batch Loss: 143517.0000
# Epoch 108, Batch 20/49, Batch Loss: 99831.2656
# Epoch 108, Batch 21/49, Batch Loss: 76439.1406
# Epoch 108, Batch 22/49, Batch Loss: 154985.0469
# Epoch 108, Batch 23/49, Batch Loss: 127342.2969
# Epoch 108, Batch 24/49, Batch Loss: 68936.3750
# Epoch 108, Batch 25/49, Batch Loss: 84555.6016
# Epoch 108, Batch 26/49, Batch Loss: 109103.3672
# Epoch 108, Batch 27/49, Batch Loss: 79828.0312
# Epoch 108, Batch 28/49, Batch Loss: 107235.2031
# Epoch 108, Batch 29/49, Batch Loss: 89570.1797
# Epoch 108, Batch 30/49, Batch Loss: 134782.9062
# Epoch 108, Batch 31/49, Batch Loss: 86088.7188
# Epoch 108, Batch 32/49, Batch Loss: 82266.0781
# Epoch 108, Batch 33/49, Batch Loss: 164840.4062
# Epoch 108, Batch 34/49, Batch Loss: 117857.1250
# Epoch 108, Batch 35/49, Batch Loss: 89749.4219
# Epoch 108, Batch 36/49, Batch Loss: 137653.6094
# Epoch 108, Batch 37/49, Batch Loss: 87793.4453
# Epoch 108, Batch 38/49, Batch Loss: 86078.0625
# Epoch 108, Batch 39/49, Batch Loss: 73504.7344
# Epoch 108, Batch 40/49, Batch Loss: 100918.2031
# Epoch 108, Batch 41/49, Batch Loss: 73313.3438
# Epoch 108, Batch 42/49, Batch Loss: 112557.2812
# Epoch 108, Batch 43/49, Batch Loss: 96774.3672
# Epoch 108, Batch 44/49, Batch Loss: 167503.0469
# Epoch 108, Batch 45/49, Batch Loss: 99645.0625
# Epoch 108, Batch 46/49, Batch Loss: 80038.3828
# Epoch 108, Batch 47/49, Batch Loss: 90590.2891
# Epoch 108, Batch 48/49, Batch Loss: 124546.3359
# Epoch 108, Batch 49/49, Batch Loss: 116644.6094
# Batch 1/17, Batch Loss: 141867.6562
# Batch 2/17, Batch Loss: 123953.8750
# Batch 3/17, Batch Loss: 171520.5312
# Batch 4/17, Batch Loss: 266565.3438
# Batch 5/17, Batch Loss: 319836.7500
# Batch 6/17, Batch Loss: 513361.1875
# Batch 7/17, Batch Loss: 102940.2031
# Batch 8/17, Batch Loss: 186458.8906
# Batch 9/17, Batch Loss: 109330.6172
# Batch 10/17, Batch Loss: 191499.8438
# Batch 11/17, Batch Loss: 383727.5000
# Batch 12/17, Batch Loss: 261657.3906
# Batch 13/17, Batch Loss: 254581.4844
# Batch 14/17, Batch Loss: 154268.5781
# Batch 15/17, Batch Loss: 274856.0312
# Batch 16/17, Batch Loss: 413779.0000
# Batch 17/17, Batch Loss: 121901.7891
# Test Error:
#  Avg loss: 234829.804228, Avg error: 139261.548443
#
# Epoch 109, Batch 1/49, Batch Loss: 98857.9297
# Epoch 109, Batch 2/49, Batch Loss: 74973.3359
# Epoch 109, Batch 3/49, Batch Loss: 77695.0156
# Epoch 109, Batch 4/49, Batch Loss: 79698.5547
# Epoch 109, Batch 5/49, Batch Loss: 84571.8516
# Epoch 109, Batch 6/49, Batch Loss: 93488.7266
# Epoch 109, Batch 7/49, Batch Loss: 70629.8203
# Epoch 109, Batch 8/49, Batch Loss: 107515.1953
# Epoch 109, Batch 9/49, Batch Loss: 88079.3906
# Epoch 109, Batch 10/49, Batch Loss: 103862.4766
# Epoch 109, Batch 11/49, Batch Loss: 61340.6523
# Epoch 109, Batch 12/49, Batch Loss: 82034.1172
# Epoch 109, Batch 13/49, Batch Loss: 75986.8750
# Epoch 109, Batch 14/49, Batch Loss: 82154.8438
# Epoch 109, Batch 15/49, Batch Loss: 75468.9766
# Epoch 109, Batch 16/49, Batch Loss: 95287.3906
# Epoch 109, Batch 17/49, Batch Loss: 107970.7500
# Epoch 109, Batch 18/49, Batch Loss: 72906.4375
# Epoch 109, Batch 19/49, Batch Loss: 78123.3672
# Epoch 109, Batch 20/49, Batch Loss: 65366.8594
# Epoch 109, Batch 21/49, Batch Loss: 88877.9922
# Epoch 109, Batch 22/49, Batch Loss: 104501.3281
# Epoch 109, Batch 23/49, Batch Loss: 87898.6328
# Epoch 109, Batch 24/49, Batch Loss: 73676.0156
# Epoch 109, Batch 25/49, Batch Loss: 78724.7031
# Epoch 109, Batch 26/49, Batch Loss: 78543.8281
# Epoch 109, Batch 27/49, Batch Loss: 93778.6016
# Epoch 109, Batch 28/49, Batch Loss: 67759.5703
# Epoch 109, Batch 29/49, Batch Loss: 98583.7188
# Epoch 109, Batch 30/49, Batch Loss: 86051.1562
# Epoch 109, Batch 31/49, Batch Loss: 86571.0781
# Epoch 109, Batch 32/49, Batch Loss: 113748.9766
# Epoch 109, Batch 33/49, Batch Loss: 77386.1172
# Epoch 109, Batch 34/49, Batch Loss: 81301.3047
# Epoch 109, Batch 35/49, Batch Loss: 107479.6641
# Epoch 109, Batch 36/49, Batch Loss: 106332.5625
# Epoch 109, Batch 37/49, Batch Loss: 180326.4844
# Epoch 109, Batch 38/49, Batch Loss: 98093.0938
# Epoch 109, Batch 39/49, Batch Loss: 91652.4297
# Epoch 109, Batch 40/49, Batch Loss: 86343.5156
# Epoch 109, Batch 41/49, Batch Loss: 91492.5547
# Epoch 109, Batch 42/49, Batch Loss: 127922.8203
# Epoch 109, Batch 43/49, Batch Loss: 123027.2266
# Epoch 109, Batch 44/49, Batch Loss: 129101.0703
# Epoch 109, Batch 45/49, Batch Loss: 81566.1094
# Epoch 109, Batch 46/49, Batch Loss: 88228.4375
# Epoch 109, Batch 47/49, Batch Loss: 99528.2656
# Epoch 109, Batch 48/49, Batch Loss: 103066.8281
# Epoch 109, Batch 49/49, Batch Loss: 133180.4062
# Batch 1/17, Batch Loss: 137878.2344
# Batch 2/17, Batch Loss: 125870.1172
# Batch 3/17, Batch Loss: 179276.5625
# Batch 4/17, Batch Loss: 239307.6562
# Batch 5/17, Batch Loss: 306153.2500
# Batch 6/17, Batch Loss: 493352.0625
# Batch 7/17, Batch Loss: 104052.6016
# Batch 8/17, Batch Loss: 194155.1719
# Batch 9/17, Batch Loss: 97720.5781
# Batch 10/17, Batch Loss: 200870.6406
# Batch 11/17, Batch Loss: 397792.4688
# Batch 12/17, Batch Loss: 284887.2188
# Batch 13/17, Batch Loss: 281608.2188
# Batch 14/17, Batch Loss: 171967.9844
# Batch 15/17, Batch Loss: 262859.3125
# Batch 16/17, Batch Loss: 362787.5312
# Batch 17/17, Batch Loss: 135386.0469
# Test Error:
#  Avg loss: 233877.979779, Avg error: 138848.758218
#
# Epoch 110, Batch 1/49, Batch Loss: 67741.1484
# Epoch 110, Batch 2/49, Batch Loss: 83142.7734
# Epoch 110, Batch 3/49, Batch Loss: 92857.6641
# Epoch 110, Batch 4/49, Batch Loss: 110247.5781
# Epoch 110, Batch 5/49, Batch Loss: 114958.5078
# Epoch 110, Batch 6/49, Batch Loss: 96518.0078
# Epoch 110, Batch 7/49, Batch Loss: 66485.6719
# Epoch 110, Batch 8/49, Batch Loss: 64366.5859
# Epoch 110, Batch 9/49, Batch Loss: 63985.7266
# Epoch 110, Batch 10/49, Batch Loss: 189602.6094
# Epoch 110, Batch 11/49, Batch Loss: 88372.5156
# Epoch 110, Batch 12/49, Batch Loss: 93312.9688
# Epoch 110, Batch 13/49, Batch Loss: 83328.0938
# Epoch 110, Batch 14/49, Batch Loss: 66611.6406
# Epoch 110, Batch 15/49, Batch Loss: 137054.0625
# Epoch 110, Batch 16/49, Batch Loss: 126714.4531
# Epoch 110, Batch 17/49, Batch Loss: 112287.9844
# Epoch 110, Batch 18/49, Batch Loss: 76725.2656
# Epoch 110, Batch 19/49, Batch Loss: 71924.7422
# Epoch 110, Batch 20/49, Batch Loss: 122284.9062
# Epoch 110, Batch 21/49, Batch Loss: 105926.0391
# Epoch 110, Batch 22/49, Batch Loss: 76340.8984
# Epoch 110, Batch 23/49, Batch Loss: 139968.8594
# Epoch 110, Batch 24/49, Batch Loss: 85725.1016
# Epoch 110, Batch 25/49, Batch Loss: 91191.7734
# Epoch 110, Batch 26/49, Batch Loss: 90394.9844
# Epoch 110, Batch 27/49, Batch Loss: 76573.2422
# Epoch 110, Batch 28/49, Batch Loss: 78313.8203
# Epoch 110, Batch 29/49, Batch Loss: 71782.8047
# Epoch 110, Batch 30/49, Batch Loss: 185941.7031
# Epoch 110, Batch 31/49, Batch Loss: 98488.5156
# Epoch 110, Batch 32/49, Batch Loss: 93195.5156
# Epoch 110, Batch 33/49, Batch Loss: 92237.1406
# Epoch 110, Batch 34/49, Batch Loss: 87507.7266
# Epoch 110, Batch 35/49, Batch Loss: 131706.9219
# Epoch 110, Batch 36/49, Batch Loss: 76372.8438
# Epoch 110, Batch 37/49, Batch Loss: 85069.2891
# Epoch 110, Batch 38/49, Batch Loss: 95119.6719
# Epoch 110, Batch 39/49, Batch Loss: 117924.3828
# Epoch 110, Batch 40/49, Batch Loss: 104624.4141
# Epoch 110, Batch 41/49, Batch Loss: 113690.0000
# Epoch 110, Batch 42/49, Batch Loss: 109763.7422
# Epoch 110, Batch 43/49, Batch Loss: 108441.6328
# Epoch 110, Batch 44/49, Batch Loss: 143737.2031
# Epoch 110, Batch 45/49, Batch Loss: 127154.6328
# Epoch 110, Batch 46/49, Batch Loss: 68165.1250
# Epoch 110, Batch 47/49, Batch Loss: 100367.7031
# Epoch 110, Batch 48/49, Batch Loss: 76390.3203
# Epoch 110, Batch 49/49, Batch Loss: 116974.4922
# Batch 1/17, Batch Loss: 131392.9844
# Batch 2/17, Batch Loss: 107068.7109
# Batch 3/17, Batch Loss: 191502.7969
# Batch 4/17, Batch Loss: 280904.6562
# Batch 5/17, Batch Loss: 317733.3750
# Batch 6/17, Batch Loss: 509820.6562
# Batch 7/17, Batch Loss: 102642.9844
# Batch 8/17, Batch Loss: 205789.2656
# Batch 9/17, Batch Loss: 110653.9062
# Batch 10/17, Batch Loss: 212277.0938
# Batch 11/17, Batch Loss: 375887.8438
# Batch 12/17, Batch Loss: 259688.2656
# Batch 13/17, Batch Loss: 281482.6875
# Batch 14/17, Batch Loss: 141356.3281
# Batch 15/17, Batch Loss: 325456.1875
# Batch 16/17, Batch Loss: 361559.4375
# Batch 17/17, Batch Loss: 143862.7188
# Test Error:
#  Avg loss: 238769.405790, Avg error: 144662.230969
#
# 2024-10-08 03:38:42.038659 Epoch 110, Average Training loss 99543.13073979592
# Epoch 111, Batch 1/49, Batch Loss: 70969.5156
# Epoch 111, Batch 2/49, Batch Loss: 117489.2422
# Epoch 111, Batch 3/49, Batch Loss: 127118.0078
# Epoch 111, Batch 4/49, Batch Loss: 113885.2344
# Epoch 111, Batch 5/49, Batch Loss: 169006.6875
# Epoch 111, Batch 6/49, Batch Loss: 148369.3125
# Epoch 111, Batch 7/49, Batch Loss: 210819.9375
# Epoch 111, Batch 8/49, Batch Loss: 125028.7578
# Epoch 111, Batch 9/49, Batch Loss: 97888.6094
# Epoch 111, Batch 10/49, Batch Loss: 122922.3906
# Epoch 111, Batch 11/49, Batch Loss: 133918.9688
# Epoch 111, Batch 12/49, Batch Loss: 174909.1250
# Epoch 111, Batch 13/49, Batch Loss: 133957.5312
# Epoch 111, Batch 14/49, Batch Loss: 115671.0625
# Epoch 111, Batch 15/49, Batch Loss: 119831.1484
# Epoch 111, Batch 16/49, Batch Loss: 67747.2578
# Epoch 111, Batch 17/49, Batch Loss: 69415.2500
# Epoch 111, Batch 18/49, Batch Loss: 138355.2031
# Epoch 111, Batch 19/49, Batch Loss: 112032.9688
# Epoch 111, Batch 20/49, Batch Loss: 122377.4766
# Epoch 111, Batch 21/49, Batch Loss: 146470.4844
# Epoch 111, Batch 22/49, Batch Loss: 110590.7969
# Epoch 111, Batch 23/49, Batch Loss: 88294.2031
# Epoch 111, Batch 24/49, Batch Loss: 83017.5938
# Epoch 111, Batch 25/49, Batch Loss: 93541.3047
# Epoch 111, Batch 26/49, Batch Loss: 97143.5312
# Epoch 111, Batch 27/49, Batch Loss: 98261.5312
# Epoch 111, Batch 28/49, Batch Loss: 85643.3281
# Epoch 111, Batch 29/49, Batch Loss: 113136.1641
# Epoch 111, Batch 30/49, Batch Loss: 100675.1719
# Epoch 111, Batch 31/49, Batch Loss: 145262.3281
# Epoch 111, Batch 32/49, Batch Loss: 119467.2422
# Epoch 111, Batch 33/49, Batch Loss: 136952.4531
# Epoch 111, Batch 34/49, Batch Loss: 122024.0781
# Epoch 111, Batch 35/49, Batch Loss: 131031.7656
# Epoch 111, Batch 36/49, Batch Loss: 132149.0469
# Epoch 111, Batch 37/49, Batch Loss: 112092.8516
# Epoch 111, Batch 38/49, Batch Loss: 127850.7031
# Epoch 111, Batch 39/49, Batch Loss: 81409.1797
# Epoch 111, Batch 40/49, Batch Loss: 117869.4141
# Epoch 111, Batch 41/49, Batch Loss: 134814.0781
# Epoch 111, Batch 42/49, Batch Loss: 140916.2344
# Epoch 111, Batch 43/49, Batch Loss: 92660.9297
# Epoch 111, Batch 44/49, Batch Loss: 91461.4844
# Epoch 111, Batch 45/49, Batch Loss: 124561.2969
# Epoch 111, Batch 46/49, Batch Loss: 93220.2812
# Epoch 111, Batch 47/49, Batch Loss: 141075.9531
# Epoch 111, Batch 48/49, Batch Loss: 95750.7188
# Epoch 111, Batch 49/49, Batch Loss: 119518.3750
# Batch 1/17, Batch Loss: 150740.3594
# Batch 2/17, Batch Loss: 116250.7656
# Batch 3/17, Batch Loss: 211038.1875
# Batch 4/17, Batch Loss: 297892.6562
# Batch 5/17, Batch Loss: 368304.8750
# Batch 6/17, Batch Loss: 514788.6250
# Batch 7/17, Batch Loss: 129646.7500
# Batch 8/17, Batch Loss: 210606.0938
# Batch 9/17, Batch Loss: 134194.1875
# Batch 10/17, Batch Loss: 226221.3750
# Batch 11/17, Batch Loss: 428799.0312
# Batch 12/17, Batch Loss: 273451.4688
# Batch 13/17, Batch Loss: 290979.0625
# Batch 14/17, Batch Loss: 182841.1094
# Batch 15/17, Batch Loss: 359503.5938
# Batch 16/17, Batch Loss: 362382.7500
# Batch 17/17, Batch Loss: 144068.4219
# Test Error:
#  Avg loss: 258924.077206, Avg error: 169380.701557
#
# Epoch 112, Batch 1/49, Batch Loss: 102421.8750
# Epoch 112, Batch 2/49, Batch Loss: 189868.4844
# Epoch 112, Batch 3/49, Batch Loss: 83993.6484
# Epoch 112, Batch 4/49, Batch Loss: 83484.1016
# Epoch 112, Batch 5/49, Batch Loss: 137480.2812
# Epoch 112, Batch 6/49, Batch Loss: 124572.8672
# Epoch 112, Batch 7/49, Batch Loss: 110731.6875
# Epoch 112, Batch 8/49, Batch Loss: 103736.1250
# Epoch 112, Batch 9/49, Batch Loss: 88337.5234
# Epoch 112, Batch 10/49, Batch Loss: 116929.6953
# Epoch 112, Batch 11/49, Batch Loss: 124953.2656
# Epoch 112, Batch 12/49, Batch Loss: 101770.5469
# Epoch 112, Batch 13/49, Batch Loss: 128077.6875
# Epoch 112, Batch 14/49, Batch Loss: 108886.8438
# Epoch 112, Batch 15/49, Batch Loss: 161030.9688
# Epoch 112, Batch 16/49, Batch Loss: 136319.4375
# Epoch 112, Batch 17/49, Batch Loss: 133305.4062
# Epoch 112, Batch 18/49, Batch Loss: 147614.8594
# Epoch 112, Batch 19/49, Batch Loss: 129221.8203
# Epoch 112, Batch 20/49, Batch Loss: 137630.7344
# Epoch 112, Batch 21/49, Batch Loss: 122574.7422
# Epoch 112, Batch 22/49, Batch Loss: 138455.6875
# Epoch 112, Batch 23/49, Batch Loss: 118815.8906
# Epoch 112, Batch 24/49, Batch Loss: 113755.3203
# Epoch 112, Batch 25/49, Batch Loss: 79689.4688
# Epoch 112, Batch 26/49, Batch Loss: 119837.8516
# Epoch 112, Batch 27/49, Batch Loss: 74412.8906
# Epoch 112, Batch 28/49, Batch Loss: 93215.2109
# Epoch 112, Batch 29/49, Batch Loss: 96991.1094
# Epoch 112, Batch 30/49, Batch Loss: 113415.5781
# Epoch 112, Batch 31/49, Batch Loss: 172786.7656
# Epoch 112, Batch 32/49, Batch Loss: 138738.6719
# Epoch 112, Batch 33/49, Batch Loss: 97014.8516
# Epoch 112, Batch 34/49, Batch Loss: 158981.0781
# Epoch 112, Batch 35/49, Batch Loss: 91619.7969
# Epoch 112, Batch 36/49, Batch Loss: 104640.2500
# Epoch 112, Batch 37/49, Batch Loss: 68183.8359
# Epoch 112, Batch 38/49, Batch Loss: 69865.3359
# Epoch 112, Batch 39/49, Batch Loss: 98000.5938
# Epoch 112, Batch 40/49, Batch Loss: 107292.5859
# Epoch 112, Batch 41/49, Batch Loss: 95068.2969
# Epoch 112, Batch 42/49, Batch Loss: 76957.0938
# Epoch 112, Batch 43/49, Batch Loss: 92060.7031
# Epoch 112, Batch 44/49, Batch Loss: 63775.7148
# Epoch 112, Batch 45/49, Batch Loss: 80095.7578
# Epoch 112, Batch 46/49, Batch Loss: 91234.2031
# Epoch 112, Batch 47/49, Batch Loss: 160558.4219
# Epoch 112, Batch 48/49, Batch Loss: 148064.7656
# Epoch 112, Batch 49/49, Batch Loss: 92362.7891
# Batch 1/17, Batch Loss: 133820.0312
# Batch 2/17, Batch Loss: 112902.0625
# Batch 3/17, Batch Loss: 203033.3438
# Batch 4/17, Batch Loss: 275091.4375
# Batch 5/17, Batch Loss: 340992.6875
# Batch 6/17, Batch Loss: 521290.4375
# Batch 7/17, Batch Loss: 110700.8281
# Batch 8/17, Batch Loss: 185142.7656
# Batch 9/17, Batch Loss: 113521.8906
# Batch 10/17, Batch Loss: 196794.7188
# Batch 11/17, Batch Loss: 423012.1562
# Batch 12/17, Batch Loss: 271018.5000
# Batch 13/17, Batch Loss: 276021.2812
# Batch 14/17, Batch Loss: 197759.8125
# Batch 15/17, Batch Loss: 333339.2500
# Batch 16/17, Batch Loss: 324028.0000
# Batch 17/17, Batch Loss: 170261.9844
# Test Error:
#  Avg loss: 246395.952206, Avg error: 152540.602941
#
# Epoch 113, Batch 1/49, Batch Loss: 174306.6094
# Epoch 113, Batch 2/49, Batch Loss: 116550.2031
# Epoch 113, Batch 3/49, Batch Loss: 66817.6797
# Epoch 113, Batch 4/49, Batch Loss: 109716.3984
# Epoch 113, Batch 5/49, Batch Loss: 156521.9062
# Epoch 113, Batch 6/49, Batch Loss: 107166.2422
# Epoch 113, Batch 7/49, Batch Loss: 90898.8281
# Epoch 113, Batch 8/49, Batch Loss: 86780.6484
# Epoch 113, Batch 9/49, Batch Loss: 102262.0547
# Epoch 113, Batch 10/49, Batch Loss: 125569.2266
# Epoch 113, Batch 11/49, Batch Loss: 99447.5078
# Epoch 113, Batch 12/49, Batch Loss: 96411.4375
# Epoch 113, Batch 13/49, Batch Loss: 139697.9688
# Epoch 113, Batch 14/49, Batch Loss: 171433.8594
# Epoch 113, Batch 15/49, Batch Loss: 140693.5781
# Epoch 113, Batch 16/49, Batch Loss: 116355.8359
# Epoch 113, Batch 17/49, Batch Loss: 90189.7969
# Epoch 113, Batch 18/49, Batch Loss: 76001.2578
# Epoch 113, Batch 19/49, Batch Loss: 79133.5391
# Epoch 113, Batch 20/49, Batch Loss: 78398.0312
# Epoch 113, Batch 21/49, Batch Loss: 102365.3281
# Epoch 113, Batch 22/49, Batch Loss: 87025.8828
# Epoch 113, Batch 23/49, Batch Loss: 119370.4766
# Epoch 113, Batch 24/49, Batch Loss: 104801.1250
# Epoch 113, Batch 25/49, Batch Loss: 82995.0625
# Epoch 113, Batch 26/49, Batch Loss: 94035.0625
# Epoch 113, Batch 27/49, Batch Loss: 147402.1250
# Epoch 113, Batch 28/49, Batch Loss: 140619.2188
# Epoch 113, Batch 29/49, Batch Loss: 149228.4688
# Epoch 113, Batch 30/49, Batch Loss: 129909.7188
# Epoch 113, Batch 31/49, Batch Loss: 108955.7812
# Epoch 113, Batch 32/49, Batch Loss: 86249.1094
# Epoch 113, Batch 33/49, Batch Loss: 107253.0938
# Epoch 113, Batch 34/49, Batch Loss: 97162.2812
# Epoch 113, Batch 35/49, Batch Loss: 86867.1875
# Epoch 113, Batch 36/49, Batch Loss: 105696.9844
# Epoch 113, Batch 37/49, Batch Loss: 119976.2188
# Epoch 113, Batch 38/49, Batch Loss: 97490.5312
# Epoch 113, Batch 39/49, Batch Loss: 145024.9062
# Epoch 113, Batch 40/49, Batch Loss: 116317.5156
# Epoch 113, Batch 41/49, Batch Loss: 71091.0547
# Epoch 113, Batch 42/49, Batch Loss: 80201.3359
# Epoch 113, Batch 43/49, Batch Loss: 73681.7656
# Epoch 113, Batch 44/49, Batch Loss: 52222.6406
# Epoch 113, Batch 45/49, Batch Loss: 94336.6406
# Epoch 113, Batch 46/49, Batch Loss: 71833.1953
# Epoch 113, Batch 47/49, Batch Loss: 85089.5703
# Epoch 113, Batch 48/49, Batch Loss: 87804.2344
# Epoch 113, Batch 49/49, Batch Loss: 102377.8984
# Batch 1/17, Batch Loss: 133575.2188
# Batch 2/17, Batch Loss: 112092.4844
# Batch 3/17, Batch Loss: 183966.5781
# Batch 4/17, Batch Loss: 255689.6875
# Batch 5/17, Batch Loss: 317938.9375
# Batch 6/17, Batch Loss: 497187.1250
# Batch 7/17, Batch Loss: 96331.1641
# Batch 8/17, Batch Loss: 188550.6562
# Batch 9/17, Batch Loss: 102228.8125
# Batch 10/17, Batch Loss: 201920.7031
# Batch 11/17, Batch Loss: 394365.3438
# Batch 12/17, Batch Loss: 267027.5938
# Batch 13/17, Batch Loss: 254583.2656
# Batch 14/17, Batch Loss: 167850.5156
# Batch 15/17, Batch Loss: 272148.7812
# Batch 16/17, Batch Loss: 385948.6250
# Batch 17/17, Batch Loss: 131754.0000
# Test Error:
#  Avg loss: 233127.028952, Avg error: 139152.894464
#
# Epoch 114, Batch 1/49, Batch Loss: 99311.1328
# Epoch 114, Batch 2/49, Batch Loss: 88137.2500
# Epoch 114, Batch 3/49, Batch Loss: 93437.7734
# Epoch 114, Batch 4/49, Batch Loss: 83324.4375
# Epoch 114, Batch 5/49, Batch Loss: 68125.1953
# Epoch 114, Batch 6/49, Batch Loss: 73906.7188
# Epoch 114, Batch 7/49, Batch Loss: 67836.7344
# Epoch 114, Batch 8/49, Batch Loss: 77460.4531
# Epoch 114, Batch 9/49, Batch Loss: 89681.5078
# Epoch 114, Batch 10/49, Batch Loss: 69922.1562
# Epoch 114, Batch 11/49, Batch Loss: 93758.3359
# Epoch 114, Batch 12/49, Batch Loss: 72179.9609
# Epoch 114, Batch 13/49, Batch Loss: 118823.3047
# Epoch 114, Batch 14/49, Batch Loss: 106279.4297
# Epoch 114, Batch 15/49, Batch Loss: 69596.6797
# Epoch 114, Batch 16/49, Batch Loss: 81357.2734
# Epoch 114, Batch 17/49, Batch Loss: 81102.6719
# Epoch 114, Batch 18/49, Batch Loss: 83343.1875
# Epoch 114, Batch 19/49, Batch Loss: 101267.6250
# Epoch 114, Batch 20/49, Batch Loss: 120707.2891
# Epoch 114, Batch 21/49, Batch Loss: 96268.5703
# Epoch 114, Batch 22/49, Batch Loss: 136260.9844
# Epoch 114, Batch 23/49, Batch Loss: 91932.3984
# Epoch 114, Batch 24/49, Batch Loss: 89237.7344
# Epoch 114, Batch 25/49, Batch Loss: 65973.2656
# Epoch 114, Batch 26/49, Batch Loss: 98003.3828
# Epoch 114, Batch 27/49, Batch Loss: 76142.1250
# Epoch 114, Batch 28/49, Batch Loss: 81986.1016
# Epoch 114, Batch 29/49, Batch Loss: 77078.7734
# Epoch 114, Batch 30/49, Batch Loss: 121996.4141
# Epoch 114, Batch 31/49, Batch Loss: 87400.8438
# Epoch 114, Batch 32/49, Batch Loss: 116427.2656
# Epoch 114, Batch 33/49, Batch Loss: 77286.8203
# Epoch 114, Batch 34/49, Batch Loss: 114579.5000
# Epoch 114, Batch 35/49, Batch Loss: 99960.4375
# Epoch 114, Batch 36/49, Batch Loss: 73706.8125
# Epoch 114, Batch 37/49, Batch Loss: 78653.3047
# Epoch 114, Batch 38/49, Batch Loss: 91164.2266
# Epoch 114, Batch 39/49, Batch Loss: 133968.7344
# Epoch 114, Batch 40/49, Batch Loss: 76343.9844
# Epoch 114, Batch 41/49, Batch Loss: 92066.4766
# Epoch 114, Batch 42/49, Batch Loss: 112632.9375
# Epoch 114, Batch 43/49, Batch Loss: 164821.4219
# Epoch 114, Batch 44/49, Batch Loss: 71939.2344
# Epoch 114, Batch 45/49, Batch Loss: 88108.3359
# Epoch 114, Batch 46/49, Batch Loss: 67738.7109
# Epoch 114, Batch 47/49, Batch Loss: 114033.9688
# Epoch 114, Batch 48/49, Batch Loss: 74172.6250
# Epoch 114, Batch 49/49, Batch Loss: 71039.8359
# Batch 1/17, Batch Loss: 140437.3125
# Batch 2/17, Batch Loss: 122027.7266
# Batch 3/17, Batch Loss: 186306.9062
# Batch 4/17, Batch Loss: 260312.0469
# Batch 5/17, Batch Loss: 340616.0000
# Batch 6/17, Batch Loss: 502020.8750
# Batch 7/17, Batch Loss: 102126.4219
# Batch 8/17, Batch Loss: 179480.8594
# Batch 9/17, Batch Loss: 103530.0547
# Batch 10/17, Batch Loss: 205627.1719
# Batch 11/17, Batch Loss: 394327.9375
# Batch 12/17, Batch Loss: 246208.5781
# Batch 13/17, Batch Loss: 253667.2656
# Batch 14/17, Batch Loss: 128350.3984
# Batch 15/17, Batch Loss: 308171.1562
# Batch 16/17, Batch Loss: 372779.4062
# Batch 17/17, Batch Loss: 126212.1875
# Test Error:
#  Avg loss: 233658.959099, Avg error: 138285.550606
#
# Epoch 115, Batch 1/49, Batch Loss: 94613.1953
# Epoch 115, Batch 2/49, Batch Loss: 126799.3672
# Epoch 115, Batch 3/49, Batch Loss: 158583.7500
# Epoch 115, Batch 4/49, Batch Loss: 89040.4922
# Epoch 115, Batch 5/49, Batch Loss: 123267.6797
# Epoch 115, Batch 6/49, Batch Loss: 101217.9531
# Epoch 115, Batch 7/49, Batch Loss: 79467.4141
# Epoch 115, Batch 8/49, Batch Loss: 78779.1484
# Epoch 115, Batch 9/49, Batch Loss: 90438.3828
# Epoch 115, Batch 10/49, Batch Loss: 313378.2188
# Epoch 115, Batch 11/49, Batch Loss: 83539.4844
# Epoch 115, Batch 12/49, Batch Loss: 101707.6641
# Epoch 115, Batch 13/49, Batch Loss: 86241.9531
# Epoch 115, Batch 14/49, Batch Loss: 100363.2969
# Epoch 115, Batch 15/49, Batch Loss: 87078.4375
# Epoch 115, Batch 16/49, Batch Loss: 100915.7344
# Epoch 115, Batch 17/49, Batch Loss: 89373.7188
# Epoch 115, Batch 18/49, Batch Loss: 85848.6641
# Epoch 115, Batch 19/49, Batch Loss: 108021.5234
# Epoch 115, Batch 20/49, Batch Loss: 134638.5000
# Epoch 115, Batch 21/49, Batch Loss: 95630.5469
# Epoch 115, Batch 22/49, Batch Loss: 90819.4375
# Epoch 115, Batch 23/49, Batch Loss: 86645.1328
# Epoch 115, Batch 24/49, Batch Loss: 80579.3906
# Epoch 115, Batch 25/49, Batch Loss: 113566.6016
# Epoch 115, Batch 26/49, Batch Loss: 80946.7500
# Epoch 115, Batch 27/49, Batch Loss: 85360.6094
# Epoch 115, Batch 28/49, Batch Loss: 80585.7969
# Epoch 115, Batch 29/49, Batch Loss: 83968.1484
# Epoch 115, Batch 30/49, Batch Loss: 77742.2891
# Epoch 115, Batch 31/49, Batch Loss: 88044.2266
# Epoch 115, Batch 32/49, Batch Loss: 73946.0859
# Epoch 115, Batch 33/49, Batch Loss: 84343.4766
# Epoch 115, Batch 34/49, Batch Loss: 111876.6562
# Epoch 115, Batch 35/49, Batch Loss: 150469.6562
# Epoch 115, Batch 36/49, Batch Loss: 70737.1172
# Epoch 115, Batch 37/49, Batch Loss: 80591.4531
# Epoch 115, Batch 38/49, Batch Loss: 64404.0938
# Epoch 115, Batch 39/49, Batch Loss: 86655.6250
# Epoch 115, Batch 40/49, Batch Loss: 88350.5547
# Epoch 115, Batch 41/49, Batch Loss: 79319.7109
# Epoch 115, Batch 42/49, Batch Loss: 86294.7734
# Epoch 115, Batch 43/49, Batch Loss: 87696.9609
# Epoch 115, Batch 44/49, Batch Loss: 138872.5625
# Epoch 115, Batch 45/49, Batch Loss: 89893.0469
# Epoch 115, Batch 46/49, Batch Loss: 78269.7188
# Epoch 115, Batch 47/49, Batch Loss: 108720.9531
# Epoch 115, Batch 48/49, Batch Loss: 82815.5312
# Epoch 115, Batch 49/49, Batch Loss: 86004.4609
# Batch 1/17, Batch Loss: 140532.3281
# Batch 2/17, Batch Loss: 114685.2578
# Batch 3/17, Batch Loss: 191153.1562
# Batch 4/17, Batch Loss: 251611.2969
# Batch 5/17, Batch Loss: 327248.2188
# Batch 6/17, Batch Loss: 490312.0000
# Batch 7/17, Batch Loss: 96461.7812
# Batch 8/17, Batch Loss: 188050.6094
# Batch 9/17, Batch Loss: 102212.9609
# Batch 10/17, Batch Loss: 197208.9219
# Batch 11/17, Batch Loss: 407299.0938
# Batch 12/17, Batch Loss: 259020.3125
# Batch 13/17, Batch Loss: 250022.7812
# Batch 14/17, Batch Loss: 172312.4844
# Batch 15/17, Batch Loss: 293441.4688
# Batch 16/17, Batch Loss: 368286.8438
# Batch 17/17, Batch Loss: 130584.4922
# Test Error:
#  Avg loss: 234143.765165, Avg error: 141241.576557
#
# Epoch 116, Batch 1/49, Batch Loss: 98610.9531
# Epoch 116, Batch 2/49, Batch Loss: 69315.5938
# Epoch 116, Batch 3/49, Batch Loss: 78556.1484
# Epoch 116, Batch 4/49, Batch Loss: 105528.7734
# Epoch 116, Batch 5/49, Batch Loss: 134363.6562
# Epoch 116, Batch 6/49, Batch Loss: 74537.9453
# Epoch 116, Batch 7/49, Batch Loss: 132124.2188
# Epoch 116, Batch 8/49, Batch Loss: 87474.8047
# Epoch 116, Batch 9/49, Batch Loss: 73670.9688
# Epoch 116, Batch 10/49, Batch Loss: 198589.1875
# Epoch 116, Batch 11/49, Batch Loss: 80946.7500
# Epoch 116, Batch 12/49, Batch Loss: 108858.3438
# Epoch 116, Batch 13/49, Batch Loss: 78132.4062
# Epoch 116, Batch 14/49, Batch Loss: 80255.1797
# Epoch 116, Batch 15/49, Batch Loss: 97686.8438
# Epoch 116, Batch 16/49, Batch Loss: 81123.6406
# Epoch 116, Batch 17/49, Batch Loss: 87314.9375
# Epoch 116, Batch 18/49, Batch Loss: 91344.0391
# Epoch 116, Batch 19/49, Batch Loss: 138748.7188
# Epoch 116, Batch 20/49, Batch Loss: 98315.1641
# Epoch 116, Batch 21/49, Batch Loss: 71582.1250
# Epoch 116, Batch 22/49, Batch Loss: 86009.8359
# Epoch 116, Batch 23/49, Batch Loss: 149076.8438
# Epoch 116, Batch 24/49, Batch Loss: 86203.6953
# Epoch 116, Batch 25/49, Batch Loss: 83378.1406
# Epoch 116, Batch 26/49, Batch Loss: 106231.5156
# Epoch 116, Batch 27/49, Batch Loss: 102085.6719
# Epoch 116, Batch 28/49, Batch Loss: 110253.2656
# Epoch 116, Batch 29/49, Batch Loss: 87890.8906
# Epoch 116, Batch 30/49, Batch Loss: 92810.2734
# Epoch 116, Batch 31/49, Batch Loss: 92105.0234
# Epoch 116, Batch 32/49, Batch Loss: 128966.0703
# Epoch 116, Batch 33/49, Batch Loss: 105924.8203
# Epoch 116, Batch 34/49, Batch Loss: 92505.0312
# Epoch 116, Batch 35/49, Batch Loss: 104471.7031
# Epoch 116, Batch 36/49, Batch Loss: 130233.8047
# Epoch 116, Batch 37/49, Batch Loss: 105524.0469
# Epoch 116, Batch 38/49, Batch Loss: 94344.4375
# Epoch 116, Batch 39/49, Batch Loss: 124091.4453
# Epoch 116, Batch 40/49, Batch Loss: 107520.2578
# Epoch 116, Batch 41/49, Batch Loss: 113768.6328
# Epoch 116, Batch 42/49, Batch Loss: 110196.2109
# Epoch 116, Batch 43/49, Batch Loss: 130158.0234
# Epoch 116, Batch 44/49, Batch Loss: 73455.1250
# Epoch 116, Batch 45/49, Batch Loss: 77006.7812
# Epoch 116, Batch 46/49, Batch Loss: 75482.8047
# Epoch 116, Batch 47/49, Batch Loss: 94776.7891
# Epoch 116, Batch 48/49, Batch Loss: 98902.3047
# Epoch 116, Batch 49/49, Batch Loss: 138186.9062
# Batch 1/17, Batch Loss: 149335.5156
# Batch 2/17, Batch Loss: 98679.9766
# Batch 3/17, Batch Loss: 192508.6875
# Batch 4/17, Batch Loss: 261106.7500
# Batch 5/17, Batch Loss: 357248.0000
# Batch 6/17, Batch Loss: 495854.0938
# Batch 7/17, Batch Loss: 103222.3203
# Batch 8/17, Batch Loss: 192825.7188
# Batch 9/17, Batch Loss: 117610.1328
# Batch 10/17, Batch Loss: 202476.1719
# Batch 11/17, Batch Loss: 424845.9375
# Batch 12/17, Batch Loss: 277807.5000
# Batch 13/17, Batch Loss: 284579.5938
# Batch 14/17, Batch Loss: 233650.2969
# Batch 15/17, Batch Loss: 324377.3125
# Batch 16/17, Batch Loss: 371437.4062
# Batch 17/17, Batch Loss: 141261.1562
# Test Error:
#  Avg loss: 248754.504136, Avg error: 155056.997405
#
# Epoch 117, Batch 1/49, Batch Loss: 93507.6172
# Epoch 117, Batch 2/49, Batch Loss: 129861.7266
# Epoch 117, Batch 3/49, Batch Loss: 99301.3750
# Epoch 117, Batch 4/49, Batch Loss: 81950.9062
# Epoch 117, Batch 5/49, Batch Loss: 97453.5312
# Epoch 117, Batch 6/49, Batch Loss: 90548.2188
# Epoch 117, Batch 7/49, Batch Loss: 117114.8047
# Epoch 117, Batch 8/49, Batch Loss: 85830.4844
# Epoch 117, Batch 9/49, Batch Loss: 92901.5625
# Epoch 117, Batch 10/49, Batch Loss: 78702.8906
# Epoch 117, Batch 11/49, Batch Loss: 84685.0312
# Epoch 117, Batch 12/49, Batch Loss: 94130.4219
# Epoch 117, Batch 13/49, Batch Loss: 167452.2656
# Epoch 117, Batch 14/49, Batch Loss: 86276.9375
# Epoch 117, Batch 15/49, Batch Loss: 73410.8203
# Epoch 117, Batch 16/49, Batch Loss: 107099.5781
# Epoch 117, Batch 17/49, Batch Loss: 103562.7031
# Epoch 117, Batch 18/49, Batch Loss: 95938.9062
# Epoch 117, Batch 19/49, Batch Loss: 81897.5078
# Epoch 117, Batch 20/49, Batch Loss: 106803.9609
# Epoch 117, Batch 21/49, Batch Loss: 113032.8125
# Epoch 117, Batch 22/49, Batch Loss: 84884.9844
# Epoch 117, Batch 23/49, Batch Loss: 70581.7656
# Epoch 117, Batch 24/49, Batch Loss: 78547.6094
# Epoch 117, Batch 25/49, Batch Loss: 83334.9062
# Epoch 117, Batch 26/49, Batch Loss: 73684.6484
# Epoch 117, Batch 27/49, Batch Loss: 73279.8047
# Epoch 117, Batch 28/49, Batch Loss: 95819.7109
# Epoch 117, Batch 29/49, Batch Loss: 70220.4531
# Epoch 117, Batch 30/49, Batch Loss: 78527.1875
# Epoch 117, Batch 31/49, Batch Loss: 83883.7109
# Epoch 117, Batch 32/49, Batch Loss: 81012.8047
# Epoch 117, Batch 33/49, Batch Loss: 84119.6641
# Epoch 117, Batch 34/49, Batch Loss: 78814.3906
# Epoch 117, Batch 35/49, Batch Loss: 85246.9922
# Epoch 117, Batch 36/49, Batch Loss: 96724.7500
# Epoch 117, Batch 37/49, Batch Loss: 109937.5312
# Epoch 117, Batch 38/49, Batch Loss: 83691.9141
# Epoch 117, Batch 39/49, Batch Loss: 79731.1953
# Epoch 117, Batch 40/49, Batch Loss: 106634.3750
# Epoch 117, Batch 41/49, Batch Loss: 97036.0938
# Epoch 117, Batch 42/49, Batch Loss: 67651.1797
# Epoch 117, Batch 43/49, Batch Loss: 90592.9922
# Epoch 117, Batch 44/49, Batch Loss: 269653.3750
# Epoch 117, Batch 45/49, Batch Loss: 106476.2344
# Epoch 117, Batch 46/49, Batch Loss: 129742.6719
# Epoch 117, Batch 47/49, Batch Loss: 72610.3203
# Epoch 117, Batch 48/49, Batch Loss: 89022.6641
# Epoch 117, Batch 49/49, Batch Loss: 89445.7812
# Batch 1/17, Batch Loss: 147330.9219
# Batch 2/17, Batch Loss: 114984.6406
# Batch 3/17, Batch Loss: 187544.2344
# Batch 4/17, Batch Loss: 238226.5000
# Batch 5/17, Batch Loss: 310374.2500
# Batch 6/17, Batch Loss: 490638.5625
# Batch 7/17, Batch Loss: 97452.1641
# Batch 8/17, Batch Loss: 178538.9062
# Batch 9/17, Batch Loss: 95124.7422
# Batch 10/17, Batch Loss: 185672.9375
# Batch 11/17, Batch Loss: 404832.6875
# Batch 12/17, Batch Loss: 272563.4688
# Batch 13/17, Batch Loss: 271000.5312
# Batch 14/17, Batch Loss: 216313.4375
# Batch 15/17, Batch Loss: 265079.4062
# Batch 16/17, Batch Loss: 392512.5938
# Batch 17/17, Batch Loss: 131416.9062
# Test Error:
#  Avg loss: 235270.993566, Avg error: 138377.200692
#
# Epoch 118, Batch 1/49, Batch Loss: 98942.9688
# Epoch 118, Batch 2/49, Batch Loss: 88012.9219
# Epoch 118, Batch 3/49, Batch Loss: 95816.7656
# Epoch 118, Batch 4/49, Batch Loss: 90104.5469
# Epoch 118, Batch 5/49, Batch Loss: 68186.3203
# Epoch 118, Batch 6/49, Batch Loss: 99457.1953
# Epoch 118, Batch 7/49, Batch Loss: 76633.4531
# Epoch 118, Batch 8/49, Batch Loss: 67836.0156
# Epoch 118, Batch 9/49, Batch Loss: 85564.7891
# Epoch 118, Batch 10/49, Batch Loss: 89682.4453
# Epoch 118, Batch 11/49, Batch Loss: 163361.7500
# Epoch 118, Batch 12/49, Batch Loss: 83895.4062
# Epoch 118, Batch 13/49, Batch Loss: 73624.0703
# Epoch 118, Batch 14/49, Batch Loss: 100116.6953
# Epoch 118, Batch 15/49, Batch Loss: 128889.7734
# Epoch 118, Batch 16/49, Batch Loss: 101283.3125
# Epoch 118, Batch 17/49, Batch Loss: 88684.2188
# Epoch 118, Batch 18/49, Batch Loss: 87293.1953
# Epoch 118, Batch 19/49, Batch Loss: 85162.5078
# Epoch 118, Batch 20/49, Batch Loss: 101592.1562
# Epoch 118, Batch 21/49, Batch Loss: 90108.3906
# Epoch 118, Batch 22/49, Batch Loss: 87759.4766
# Epoch 118, Batch 23/49, Batch Loss: 68536.0000
# Epoch 118, Batch 24/49, Batch Loss: 91755.2188
# Epoch 118, Batch 25/49, Batch Loss: 105847.9766
# Epoch 118, Batch 26/49, Batch Loss: 107309.9375
# Epoch 118, Batch 27/49, Batch Loss: 93445.3750
# Epoch 118, Batch 28/49, Batch Loss: 117119.3594
# Epoch 118, Batch 29/49, Batch Loss: 92281.6641
# Epoch 118, Batch 30/49, Batch Loss: 78953.3906
# Epoch 118, Batch 31/49, Batch Loss: 100730.9375
# Epoch 118, Batch 32/49, Batch Loss: 101393.7188
# Epoch 118, Batch 33/49, Batch Loss: 92061.2578
# Epoch 118, Batch 34/49, Batch Loss: 88943.5859
# Epoch 118, Batch 35/49, Batch Loss: 86059.3984
# Epoch 118, Batch 36/49, Batch Loss: 77188.1484
# Epoch 118, Batch 37/49, Batch Loss: 78925.7734
# Epoch 118, Batch 38/49, Batch Loss: 168858.9844
# Epoch 118, Batch 39/49, Batch Loss: 97501.9453
# Epoch 118, Batch 40/49, Batch Loss: 74545.4609
# Epoch 118, Batch 41/49, Batch Loss: 150210.7656
# Epoch 118, Batch 42/49, Batch Loss: 144849.2344
# Epoch 118, Batch 43/49, Batch Loss: 100382.1875
# Epoch 118, Batch 44/49, Batch Loss: 168724.3438
# Epoch 118, Batch 45/49, Batch Loss: 54428.2734
# Epoch 118, Batch 46/49, Batch Loss: 54593.8633
# Epoch 118, Batch 47/49, Batch Loss: 73461.2422
# Epoch 118, Batch 48/49, Batch Loss: 80352.3516
# Epoch 118, Batch 49/49, Batch Loss: 101423.0469
# Batch 1/17, Batch Loss: 154672.0625
# Batch 2/17, Batch Loss: 105121.8594
# Batch 3/17, Batch Loss: 195767.8125
# Batch 4/17, Batch Loss: 279680.6250
# Batch 5/17, Batch Loss: 350659.6875
# Batch 6/17, Batch Loss: 497906.0000
# Batch 7/17, Batch Loss: 100260.0078
# Batch 8/17, Batch Loss: 199817.4844
# Batch 9/17, Batch Loss: 116042.7031
# Batch 10/17, Batch Loss: 196539.3594
# Batch 11/17, Batch Loss: 398936.1562
# Batch 12/17, Batch Loss: 258172.5312
# Batch 13/17, Batch Loss: 282051.2188
# Batch 14/17, Batch Loss: 145399.8281
# Batch 15/17, Batch Loss: 318830.3125
# Batch 16/17, Batch Loss: 366022.0000
# Batch 17/17, Batch Loss: 131876.7188
# Test Error:
#  Avg loss: 241044.492188, Avg error: 146233.106834
#
# Epoch 119, Batch 1/49, Batch Loss: 86440.2188
# Epoch 119, Batch 2/49, Batch Loss: 74130.8828
# Epoch 119, Batch 3/49, Batch Loss: 65130.3477
# Epoch 119, Batch 4/49, Batch Loss: 120379.5781
# Epoch 119, Batch 5/49, Batch Loss: 105253.2969
# Epoch 119, Batch 6/49, Batch Loss: 59005.1211
# Epoch 119, Batch 7/49, Batch Loss: 99632.2578
# Epoch 119, Batch 8/49, Batch Loss: 89474.3359
# Epoch 119, Batch 9/49, Batch Loss: 90402.8984
# Epoch 119, Batch 10/49, Batch Loss: 118512.4766
# Epoch 119, Batch 11/49, Batch Loss: 87781.7266
# Epoch 119, Batch 12/49, Batch Loss: 84050.1328
# Epoch 119, Batch 13/49, Batch Loss: 101277.6094
# Epoch 119, Batch 14/49, Batch Loss: 68110.3125
# Epoch 119, Batch 15/49, Batch Loss: 98846.0312
# Epoch 119, Batch 16/49, Batch Loss: 85724.5547
# Epoch 119, Batch 17/49, Batch Loss: 281503.2188
# Epoch 119, Batch 18/49, Batch Loss: 97718.7656
# Epoch 119, Batch 19/49, Batch Loss: 88039.7031
# Epoch 119, Batch 20/49, Batch Loss: 90617.8672
# Epoch 119, Batch 21/49, Batch Loss: 92872.5078
# Epoch 119, Batch 22/49, Batch Loss: 85208.1875
# Epoch 119, Batch 23/49, Batch Loss: 97774.7969
# Epoch 119, Batch 24/49, Batch Loss: 113709.9297
# Epoch 119, Batch 25/49, Batch Loss: 104113.3438
# Epoch 119, Batch 26/49, Batch Loss: 99625.8984
# Epoch 119, Batch 27/49, Batch Loss: 88760.8750
# Epoch 119, Batch 28/49, Batch Loss: 69944.8203
# Epoch 119, Batch 29/49, Batch Loss: 78205.1484
# Epoch 119, Batch 30/49, Batch Loss: 97327.8203
# Epoch 119, Batch 31/49, Batch Loss: 98343.3750
# Epoch 119, Batch 32/49, Batch Loss: 110588.0156
# Epoch 119, Batch 33/49, Batch Loss: 204957.0938
# Epoch 119, Batch 34/49, Batch Loss: 91083.1016
# Epoch 119, Batch 35/49, Batch Loss: 124190.1797
# Epoch 119, Batch 36/49, Batch Loss: 82362.9844
# Epoch 119, Batch 37/49, Batch Loss: 75639.9219
# Epoch 119, Batch 38/49, Batch Loss: 75866.8672
# Epoch 119, Batch 39/49, Batch Loss: 123909.3906
# Epoch 119, Batch 40/49, Batch Loss: 107240.6953
# Epoch 119, Batch 41/49, Batch Loss: 84079.3125
# ...
# Epoch 170, Batch 45/49, Batch Loss: 102745.2891
# Epoch 170, Batch 46/49, Batch Loss: 82259.4766
# Epoch 170, Batch 47/49, Batch Loss: 58856.9805
# Epoch 170, Batch 48/49, Batch Loss: 66646.5000
# Epoch 170, Batch 49/49, Batch Loss: 64650.3438
# Batch 1/17, Batch Loss: 125760.5078
# Batch 2/17, Batch Loss: 121699.8438
# Batch 3/17, Batch Loss: 180096.8906
# Batch 4/17, Batch Loss: 275019.5625
# Batch 5/17, Batch Loss: 339549.0000
# Batch 6/17, Batch Loss: 498889.0312
# Batch 7/17, Batch Loss: 115993.4688
# Batch 8/17, Batch Loss: 193515.8750
# Batch 9/17, Batch Loss: 97666.5703
# Batch 10/17, Batch Loss: 195040.5625
# Batch 11/17, Batch Loss: 415607.6875
# Batch 12/17, Batch Loss: 252953.1094
# Batch 13/17, Batch Loss: 274369.4688
# Batch 14/17, Batch Loss: 155582.9062
# Batch 15/17, Batch Loss: 325251.4688
# Batch 16/17, Batch Loss: 357331.3125
# Batch 17/17, Batch Loss: 148672.5312
# Test Error:
#  Avg loss: 239588.223346, Avg error: 139175.002379
#
# 2024-10-08 04:22:20.876306 Epoch 170, Average Training loss 86724.22552614796
# Epoch 171, Batch 1/49, Batch Loss: 68417.7188
# Epoch 171, Batch 2/49, Batch Loss: 77623.7734
# Epoch 171, Batch 3/49, Batch Loss: 67303.5000
# Epoch 171, Batch 4/49, Batch Loss: 76560.1406
# Epoch 171, Batch 5/49, Batch Loss: 82529.6172
# Epoch 171, Batch 6/49, Batch Loss: 71793.0391
# Epoch 171, Batch 7/49, Batch Loss: 98839.0781
# Epoch 171, Batch 8/49, Batch Loss: 73533.5703
# Epoch 171, Batch 9/49, Batch Loss: 101239.7656
# Epoch 171, Batch 10/49, Batch Loss: 77583.9609
# Epoch 171, Batch 11/49, Batch Loss: 84071.3594
# Epoch 171, Batch 12/49, Batch Loss: 73917.6016
# Epoch 171, Batch 13/49, Batch Loss: 69711.8359
# Epoch 171, Batch 14/49, Batch Loss: 65954.7422
# Epoch 171, Batch 15/49, Batch Loss: 61972.6289
# Epoch 171, Batch 16/49, Batch Loss: 69331.4219
# Epoch 171, Batch 17/49, Batch Loss: 68429.8672
# Epoch 171, Batch 18/49, Batch Loss: 54447.0703
# Epoch 171, Batch 19/49, Batch Loss: 102542.0625
# Epoch 171, Batch 20/49, Batch Loss: 108356.6797
# Epoch 171, Batch 21/49, Batch Loss: 98283.3750
# Epoch 171, Batch 22/49, Batch Loss: 102120.4219
# Epoch 171, Batch 23/49, Batch Loss: 110715.8672
# Epoch 171, Batch 24/49, Batch Loss: 58454.9180
# Epoch 171, Batch 25/49, Batch Loss: 88893.8281
# Epoch 171, Batch 26/49, Batch Loss: 60739.7188
# Epoch 171, Batch 27/49, Batch Loss: 111118.8047
# Epoch 171, Batch 28/49, Batch Loss: 80694.0234
# Epoch 171, Batch 29/49, Batch Loss: 74565.3672
# Epoch 171, Batch 30/49, Batch Loss: 62658.3438
# Epoch 171, Batch 31/49, Batch Loss: 85980.8984
# Epoch 171, Batch 32/49, Batch Loss: 80258.6172
# Epoch 171, Batch 33/49, Batch Loss: 72016.6797
# Epoch 171, Batch 34/49, Batch Loss: 145113.5781
# Epoch 171, Batch 35/49, Batch Loss: 145305.9375
# Epoch 171, Batch 36/49, Batch Loss: 90425.0469
# Epoch 171, Batch 37/49, Batch Loss: 111702.6484
# Epoch 171, Batch 38/49, Batch Loss: 84672.5312
# Epoch 171, Batch 39/49, Batch Loss: 106469.3516
# Epoch 171, Batch 40/49, Batch Loss: 71702.9297
# Epoch 171, Batch 41/49, Batch Loss: 113602.0000
# Epoch 171, Batch 42/49, Batch Loss: 75831.2109
# Epoch 171, Batch 43/49, Batch Loss: 116309.9141
# Epoch 171, Batch 44/49, Batch Loss: 125239.4062
# Epoch 171, Batch 45/49, Batch Loss: 104529.3984
# Epoch 171, Batch 46/49, Batch Loss: 77549.4688
# Epoch 171, Batch 47/49, Batch Loss: 96253.1250
# Epoch 171, Batch 48/49, Batch Loss: 60170.0430
# Epoch 171, Batch 49/49, Batch Loss: 80133.0391
# Batch 1/17, Batch Loss: 144997.6250
# Batch 2/17, Batch Loss: 120732.0312
# Batch 3/17, Batch Loss: 159719.1875
# Batch 4/17, Batch Loss: 255085.9531
# Batch 5/17, Batch Loss: 321538.5625
# Batch 6/17, Batch Loss: 489984.9375
# Batch 7/17, Batch Loss: 112685.7266
# Batch 8/17, Batch Loss: 191710.5000
# Batch 9/17, Batch Loss: 94705.6016
# Batch 10/17, Batch Loss: 184682.6562
# Batch 11/17, Batch Loss: 383760.4688
# Batch 12/17, Batch Loss: 267199.7812
# Batch 13/17, Batch Loss: 257718.3438
# Batch 14/17, Batch Loss: 167449.7500
# Batch 15/17, Batch Loss: 293735.4062
# Batch 16/17, Batch Loss: 384942.0938
# Batch 17/17, Batch Loss: 127861.7891
# Test Error:
#  Avg loss: 232853.553768, Avg error: 137099.886894
#
# Epoch 172, Batch 1/49, Batch Loss: 90205.6953
# Epoch 172, Batch 2/49, Batch Loss: 101241.0078
# Epoch 172, Batch 3/49, Batch Loss: 88269.4844
# Epoch 172, Batch 4/49, Batch Loss: 64981.5781
# Epoch 172, Batch 5/49, Batch Loss: 60445.9844
# Epoch 172, Batch 6/49, Batch Loss: 136487.5781
# Epoch 172, Batch 7/49, Batch Loss: 78505.5703
# Epoch 172, Batch 8/49, Batch Loss: 63014.1523
# Epoch 172, Batch 9/49, Batch Loss: 75500.6641
# Epoch 172, Batch 10/49, Batch Loss: 56696.5117
# Epoch 172, Batch 11/49, Batch Loss: 65500.9062
# Epoch 172, Batch 12/49, Batch Loss: 71288.5547
# Epoch 172, Batch 13/49, Batch Loss: 72000.6953
# Epoch 172, Batch 14/49, Batch Loss: 86488.6328
# Epoch 172, Batch 15/49, Batch Loss: 51391.5156
# Epoch 172, Batch 16/49, Batch Loss: 93490.3438
# Epoch 172, Batch 17/49, Batch Loss: 63577.6758
# Epoch 172, Batch 18/49, Batch Loss: 64260.8359
# Epoch 172, Batch 19/49, Batch Loss: 71549.4766
# Epoch 172, Batch 20/49, Batch Loss: 96430.7812
# Epoch 172, Batch 21/49, Batch Loss: 104043.5938
# Epoch 172, Batch 22/49, Batch Loss: 111418.7812
# Epoch 172, Batch 23/49, Batch Loss: 102233.1094
# Epoch 172, Batch 24/49, Batch Loss: 97887.4453
# Epoch 172, Batch 25/49, Batch Loss: 65939.9297
# Epoch 172, Batch 26/49, Batch Loss: 80783.2578
# Epoch 172, Batch 27/49, Batch Loss: 73149.7891
# Epoch 172, Batch 28/49, Batch Loss: 171363.1719
# Epoch 172, Batch 29/49, Batch Loss: 128777.3750
# Epoch 172, Batch 30/49, Batch Loss: 63815.4844
# Epoch 172, Batch 31/49, Batch Loss: 91153.0547
# Epoch 172, Batch 32/49, Batch Loss: 81833.0078
# Epoch 172, Batch 33/49, Batch Loss: 66208.8828
# Epoch 172, Batch 34/49, Batch Loss: 109739.0156
# Epoch 172, Batch 35/49, Batch Loss: 85474.7266
# Epoch 172, Batch 36/49, Batch Loss: 86184.4062
# Epoch 172, Batch 37/49, Batch Loss: 112673.9453
# Epoch 172, Batch 38/49, Batch Loss: 125134.3984
# Epoch 172, Batch 39/49, Batch Loss: 111487.7891
# Epoch 172, Batch 40/49, Batch Loss: 83137.3125
# Epoch 172, Batch 41/49, Batch Loss: 60820.9688
# Epoch 172, Batch 42/49, Batch Loss: 67567.2109
# Epoch 172, Batch 43/49, Batch Loss: 117783.6641
# Epoch 172, Batch 44/49, Batch Loss: 63639.3906
# Epoch 172, Batch 45/49, Batch Loss: 78725.4297
# Epoch 172, Batch 46/49, Batch Loss: 277346.7812
# Epoch 172, Batch 47/49, Batch Loss: 95714.4531
# Epoch 172, Batch 48/49, Batch Loss: 87983.4922
# Epoch 172, Batch 49/49, Batch Loss: 104747.7031
# Batch 1/17, Batch Loss: 139054.4375
# Batch 2/17, Batch Loss: 120657.9453
# Batch 3/17, Batch Loss: 164339.1562
# Batch 4/17, Batch Loss: 241513.4219
# Batch 5/17, Batch Loss: 313528.9375
# Batch 6/17, Batch Loss: 494060.6875
# Batch 7/17, Batch Loss: 118684.8203
# Batch 8/17, Batch Loss: 201720.2188
# Batch 9/17, Batch Loss: 106700.3906
# Batch 10/17, Batch Loss: 165643.5156
# Batch 11/17, Batch Loss: 411345.7500
# Batch 12/17, Batch Loss: 290976.9375
# Batch 13/17, Batch Loss: 289998.5938
# Batch 14/17, Batch Loss: 223974.4844
# Batch 15/17, Batch Loss: 257704.0469
# Batch 16/17, Batch Loss: 386798.2500
# Batch 17/17, Batch Loss: 157362.5312
# Test Error:
#  Avg loss: 240239.066176, Avg error: 145273.439014
#
# Epoch 173, Batch 1/49, Batch Loss: 69033.8906
# Epoch 173, Batch 2/49, Batch Loss: 91401.1797
# Epoch 173, Batch 3/49, Batch Loss: 163374.5000
# Epoch 173, Batch 4/49, Batch Loss: 102701.1953
# Epoch 173, Batch 5/49, Batch Loss: 98033.0156
# Epoch 173, Batch 6/49, Batch Loss: 109261.5312
# Epoch 173, Batch 7/49, Batch Loss: 82966.5156
# Epoch 173, Batch 8/49, Batch Loss: 92192.3438
# Epoch 173, Batch 9/49, Batch Loss: 116296.6172
# Epoch 173, Batch 10/49, Batch Loss: 108313.8125
# Epoch 173, Batch 11/49, Batch Loss: 200366.2656
# Epoch 173, Batch 12/49, Batch Loss: 101245.9453
# Epoch 173, Batch 13/49, Batch Loss: 122596.5078
# Epoch 173, Batch 14/49, Batch Loss: 69308.7422
# Epoch 173, Batch 15/49, Batch Loss: 96609.5859
# Epoch 173, Batch 16/49, Batch Loss: 145851.5312
# Epoch 173, Batch 17/49, Batch Loss: 88913.0312
# Epoch 173, Batch 18/49, Batch Loss: 85030.1172
# Epoch 173, Batch 19/49, Batch Loss: 69413.2109
# Epoch 173, Batch 20/49, Batch Loss: 74124.6250
# Epoch 173, Batch 21/49, Batch Loss: 76900.4062
# Epoch 173, Batch 22/49, Batch Loss: 73579.9453
# Epoch 173, Batch 23/49, Batch Loss: 152247.5781
# Epoch 173, Batch 24/49, Batch Loss: 69205.9922
# Epoch 173, Batch 25/49, Batch Loss: 76381.4531
# Epoch 173, Batch 26/49, Batch Loss: 118896.5547
# Epoch 173, Batch 27/49, Batch Loss: 159445.1094
# Epoch 173, Batch 28/49, Batch Loss: 80825.3438
# Epoch 173, Batch 29/49, Batch Loss: 85639.1094
# Epoch 173, Batch 30/49, Batch Loss: 100565.2031
# Epoch 173, Batch 31/49, Batch Loss: 68584.4766
# Epoch 173, Batch 32/49, Batch Loss: 61707.3008
# Epoch 173, Batch 33/49, Batch Loss: 105716.2969
# Epoch 173, Batch 34/49, Batch Loss: 108335.6016
# Epoch 173, Batch 35/49, Batch Loss: 52225.1758
# Epoch 173, Batch 36/49, Batch Loss: 73042.2031
# Epoch 173, Batch 37/49, Batch Loss: 101619.2656
# Epoch 173, Batch 38/49, Batch Loss: 103504.1875
# Epoch 173, Batch 39/49, Batch Loss: 81822.9609
# Epoch 173, Batch 40/49, Batch Loss: 82639.6641
# Epoch 173, Batch 41/49, Batch Loss: 59835.9609
# Epoch 173, Batch 42/49, Batch Loss: 103247.0547
# Epoch 173, Batch 43/49, Batch Loss: 84012.9375
# Epoch 173, Batch 44/49, Batch Loss: 75019.2031
# Epoch 173, Batch 45/49, Batch Loss: 70944.0156
# Epoch 173, Batch 46/49, Batch Loss: 81873.0547
# Epoch 173, Batch 47/49, Batch Loss: 71685.9062
# Epoch 173, Batch 48/49, Batch Loss: 80855.2422
# Epoch 173, Batch 49/49, Batch Loss: 166825.2812
# Batch 1/17, Batch Loss: 128074.0234
# Batch 2/17, Batch Loss: 115803.9297
# Batch 3/17, Batch Loss: 175939.7500
# Batch 4/17, Batch Loss: 260012.4844
# Batch 5/17, Batch Loss: 334382.8125
# Batch 6/17, Batch Loss: 496030.2812
# Batch 7/17, Batch Loss: 95023.5625
# Batch 8/17, Batch Loss: 194189.9062
# Batch 9/17, Batch Loss: 99824.4062
# Batch 10/17, Batch Loss: 185887.7500
# Batch 11/17, Batch Loss: 409562.0625
# Batch 12/17, Batch Loss: 271198.2188
# Batch 13/17, Batch Loss: 275494.3750
# Batch 14/17, Batch Loss: 178892.6562
# Batch 15/17, Batch Loss: 303069.1875
# Batch 16/17, Batch Loss: 365003.2812
# Batch 17/17, Batch Loss: 131514.9531
# Test Error:
#  Avg loss: 236464.920037, Avg error: 136870.278330
#
# Epoch 174, Batch 1/49, Batch Loss: 56457.6406
# Epoch 174, Batch 2/49, Batch Loss: 117636.7812
# Epoch 174, Batch 3/49, Batch Loss: 100993.3281
# Epoch 174, Batch 4/49, Batch Loss: 150858.2500
# Epoch 174, Batch 5/49, Batch Loss: 91945.7500
# Epoch 174, Batch 6/49, Batch Loss: 91389.1328
# Epoch 174, Batch 7/49, Batch Loss: 256512.0000
# Epoch 174, Batch 8/49, Batch Loss: 60494.2500
# Epoch 174, Batch 9/49, Batch Loss: 82108.0391
# Epoch 174, Batch 10/49, Batch Loss: 99651.9922
# Epoch 174, Batch 11/49, Batch Loss: 93198.1641
# Epoch 174, Batch 12/49, Batch Loss: 92138.9062
# Epoch 174, Batch 13/49, Batch Loss: 93222.1797
# Epoch 174, Batch 14/49, Batch Loss: 97782.0312
# Epoch 174, Batch 15/49, Batch Loss: 117170.1016
# Epoch 174, Batch 16/49, Batch Loss: 77177.2188
# Epoch 174, Batch 17/49, Batch Loss: 81257.2812
# Epoch 174, Batch 18/49, Batch Loss: 122040.3672
# Epoch 174, Batch 19/49, Batch Loss: 68896.4922
# Epoch 174, Batch 20/49, Batch Loss: 161309.1875
# Epoch 174, Batch 21/49, Batch Loss: 84920.8359
# Epoch 174, Batch 22/49, Batch Loss: 73506.7266
# Epoch 174, Batch 23/49, Batch Loss: 78486.0703
# Epoch 174, Batch 24/49, Batch Loss: 62920.5859
# Epoch 174, Batch 25/49, Batch Loss: 85810.8281
# Epoch 174, Batch 26/49, Batch Loss: 83132.7656
# Epoch 174, Batch 27/49, Batch Loss: 78957.3359
# Epoch 174, Batch 28/49, Batch Loss: 73336.9922
# Epoch 174, Batch 29/49, Batch Loss: 87289.9688
# Epoch 174, Batch 30/49, Batch Loss: 73821.8438
# Epoch 174, Batch 31/49, Batch Loss: 108801.6016
# Epoch 174, Batch 32/49, Batch Loss: 73826.6562
# Epoch 174, Batch 33/49, Batch Loss: 97041.0469
# Epoch 174, Batch 34/49, Batch Loss: 85784.2500
# Epoch 174, Batch 35/49, Batch Loss: 65485.9805
# Epoch 174, Batch 36/49, Batch Loss: 77767.9766
# Epoch 174, Batch 37/49, Batch Loss: 75817.1094
# Epoch 174, Batch 38/49, Batch Loss: 69716.1953
# Epoch 174, Batch 39/49, Batch Loss: 77686.7734
# Epoch 174, Batch 40/49, Batch Loss: 60086.5898
# Epoch 174, Batch 41/49, Batch Loss: 71043.0625
# Epoch 174, Batch 42/49, Batch Loss: 59854.9805
# Epoch 174, Batch 43/49, Batch Loss: 82671.7188
# Epoch 174, Batch 44/49, Batch Loss: 75082.7812
# Epoch 174, Batch 45/49, Batch Loss: 60475.3984
# Epoch 174, Batch 46/49, Batch Loss: 70336.9375
# Epoch 174, Batch 47/49, Batch Loss: 84330.6484
# Epoch 174, Batch 48/49, Batch Loss: 80693.2188
# Epoch 174, Batch 49/49, Batch Loss: 76418.2266
# Batch 1/17, Batch Loss: 138243.8438
# Batch 2/17, Batch Loss: 108382.7422
# Batch 3/17, Batch Loss: 192809.6250
# Batch 4/17, Batch Loss: 268719.0000
# Batch 5/17, Batch Loss: 338625.6875
# Batch 6/17, Batch Loss: 494779.1250
# Batch 7/17, Batch Loss: 95140.4219
# Batch 8/17, Batch Loss: 207015.1094
# Batch 9/17, Batch Loss: 103374.0156
# Batch 10/17, Batch Loss: 181746.6406
# Batch 11/17, Batch Loss: 407783.2812
# Batch 12/17, Batch Loss: 264528.4062
# Batch 13/17, Batch Loss: 271558.3438
# Batch 14/17, Batch Loss: 186000.0938
# Batch 15/17, Batch Loss: 299680.8438
# Batch 16/17, Batch Loss: 382230.5938
# Batch 17/17, Batch Loss: 151199.8750
# Test Error:
#  Avg loss: 240695.155790, Avg error: 138287.246107
#
# Epoch 175, Batch 1/49, Batch Loss: 108142.8594
# Epoch 175, Batch 2/49, Batch Loss: 77684.3828
# Epoch 175, Batch 3/49, Batch Loss: 58512.8711
# Epoch 175, Batch 4/49, Batch Loss: 73778.0859
# Epoch 175, Batch 5/49, Batch Loss: 68882.9062
# Epoch 175, Batch 6/49, Batch Loss: 84066.8047
# Epoch 175, Batch 7/49, Batch Loss: 67617.4297
# Epoch 175, Batch 8/49, Batch Loss: 89111.5625
# Epoch 175, Batch 9/49, Batch Loss: 61458.6094
# Epoch 175, Batch 10/49, Batch Loss: 55339.0234
# Epoch 175, Batch 11/49, Batch Loss: 91004.2422
# Epoch 175, Batch 12/49, Batch Loss: 64510.5508
# Epoch 175, Batch 13/49, Batch Loss: 87379.3047
# Epoch 175, Batch 14/49, Batch Loss: 75809.2578
# Epoch 175, Batch 15/49, Batch Loss: 71611.7891
# Epoch 175, Batch 16/49, Batch Loss: 76574.2891
# Epoch 175, Batch 17/49, Batch Loss: 83089.6172
# Epoch 175, Batch 18/49, Batch Loss: 93103.4219
# Epoch 175, Batch 19/49, Batch Loss: 67369.8750
# Epoch 175, Batch 20/49, Batch Loss: 60889.3750
# Epoch 175, Batch 21/49, Batch Loss: 79633.9609
# Epoch 175, Batch 22/49, Batch Loss: 104178.6562
# Epoch 175, Batch 23/49, Batch Loss: 184974.1406
# Epoch 175, Batch 24/49, Batch Loss: 82474.8125
# Epoch 175, Batch 25/49, Batch Loss: 92925.9219
# Epoch 175, Batch 26/49, Batch Loss: 73417.0547
# Epoch 175, Batch 27/49, Batch Loss: 70916.5391
# Epoch 175, Batch 28/49, Batch Loss: 113692.6484
# Epoch 175, Batch 29/49, Batch Loss: 82672.6016
# Epoch 175, Batch 30/49, Batch Loss: 77048.4531
# Epoch 175, Batch 31/49, Batch Loss: 70446.5859
# Epoch 175, Batch 32/49, Batch Loss: 159831.4688
# Epoch 175, Batch 33/49, Batch Loss: 58363.0938
# Epoch 175, Batch 34/49, Batch Loss: 103744.6797
# Epoch 175, Batch 35/49, Batch Loss: 72032.9922
# Epoch 175, Batch 36/49, Batch Loss: 70305.5781
# Epoch 175, Batch 37/49, Batch Loss: 70793.6484
# Epoch 175, Batch 38/49, Batch Loss: 109451.4062
# Epoch 175, Batch 39/49, Batch Loss: 138682.5469
# Epoch 175, Batch 40/49, Batch Loss: 94954.2109
# Epoch 175, Batch 41/49, Batch Loss: 84311.9219
# Epoch 175, Batch 42/49, Batch Loss: 78405.6094
# Epoch 175, Batch 43/49, Batch Loss: 85991.1562
# Epoch 175, Batch 44/49, Batch Loss: 59568.7617
# Epoch 175, Batch 45/49, Batch Loss: 71955.0156
# Epoch 175, Batch 46/49, Batch Loss: 122182.3438
# Epoch 175, Batch 47/49, Batch Loss: 76867.6406
# Epoch 175, Batch 48/49, Batch Loss: 101813.7812
# Epoch 175, Batch 49/49, Batch Loss: 133044.4688
# Batch 1/17, Batch Loss: 139462.9844
# Batch 2/17, Batch Loss: 127111.6797
# Batch 3/17, Batch Loss: 187976.6562
# Batch 4/17, Batch Loss: 259837.0312
# Batch 5/17, Batch Loss: 341111.2188
# Batch 6/17, Batch Loss: 498404.9688
# Batch 7/17, Batch Loss: 112603.1016
# Batch 8/17, Batch Loss: 199429.6875
# Batch 9/17, Batch Loss: 119667.2734
# Batch 10/17, Batch Loss: 187497.7656
# Batch 11/17, Batch Loss: 408027.6875
# Batch 12/17, Batch Loss: 271604.3438
# Batch 13/17, Batch Loss: 270994.5938
# Batch 14/17, Batch Loss: 185907.9531
# Batch 15/17, Batch Loss: 307833.5312
# Batch 16/17, Batch Loss: 376242.5000
# Batch 17/17, Batch Loss: 142239.0000
# Test Error:
#  Avg loss: 243291.292739, Avg error: 142702.492215

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        2.5         3  1915    92021      117.png   485000
# 1        2.5         3  2248    92677      132.png  1199000
# 2        1.0         3  1132    96019      154.png   170000
# 3        4.0         6  3375    92880      245.png   538000
# 4        2.5         3  2733    91901       84.png   689000

# %%
len(test)
# Out:
# 54

# %%
# Crear dataset
test_data = CustomImageDataset(df=test)

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
len(test_loader)
# Out:
# 6

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 505747.1875, Valor real: 485000.0
# Predicción: 496275.09375, Valor real: 1199000.0
# Predicción: 381255.6875, Valor real: 170000.0
# Predicción: 565960.125, Valor real: 538000.0
# Predicción: 596878.875, Valor real: 689000.0
# Predicción: 143755.015625, Valor real: 118900.0
# Predicción: 898288.625, Valor real: 799000.0
# Predicción: 673637.125, Valor real: 895000.0
# Predicción: 650040.5625, Valor real: 599000.0
# Predicción: 398813.15625, Valor real: 535000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 310478.7500
# MAE en el conjunto de prueba: 197929.4375

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
