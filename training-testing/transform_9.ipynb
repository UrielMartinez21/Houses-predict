# %%
"""
Cambios en la arquitectura de la red neuronal convolucional

    - Valor de funcion de regularizacion L2 a 0.01
    - Se quito zipcode
"""

# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %%
# --> Definir si viene desde local o drive

ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')

# Eliminar zipcode
train = train.drop(columns=['zipcode'])

train.head()
# Out:
#    bathrooms  bedrooms  area mosaic_image   price
# 0        2.0         4  7841       78.png  299000
# 1        2.5         3  3233       70.png  259000
# 2        1.0         2  1110      204.png  649000
# 3        3.0         4  2256       72.png  144900
# 4        2.0         2  2036      287.png  175000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        # zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))       # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')                         # Quitar los ejes
    plt.show()

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        """
        Las convoluciones más pequeñas, como de tamaño 3x3, son útiles para capturar características más detalladas.
        Al combinar capas de convoluciones más pequeñas (en lugar de kernels grandes como 5x5), el modelo puede aprender
        mejor características complejas a través de múltiples capas.
        """
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),   # Convolución más pequeña
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # Pooling
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=3, padding=1),           # Otra convolución 3x3
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(),                                           # Dropout para regularización

            nn.Conv2d(128, 128, kernel_size=3, padding=1),          # Convolución 3x3 más profunda
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(128, 64, kernel_size=3, padding=1),           # Última convolución 3x3
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(3, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(37440, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 64*24*24)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            # Valores a proar: 0.05, 0.01, 0.001
            l2_lambda = 0.01
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones
data1 = CustomImageDataset(df=train)

# Dataset con transformación de normalización
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desplazamiento de canales y normalización
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),    # Cambiar los canales RGB a BGR
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                        # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                         # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo horizontal y normalización
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=1),            # Girar horizontalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo vertical y normalización
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=1),              # Girar verticalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desenfoque gaussiano y normalización
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Imagen Original', 'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    if i == 1:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}")
    else:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data1, data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 2597 Val: 289

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data1, data2, data3, data4, data5, data6

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
# optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda

# %%
# --> Crear los dataloaders
batch_size_train = 53
batch_size_val = 17

if device == 'cuda':
    train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True, num_workers=4)
    val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False, num_workers=4)
else:
    train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True)
    val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 2597 - Baches 49
# Muestras de test: 289 - Baches 17

# %%
# Entrenamiento
n_epochs = 175
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 103, Batch 45/49, Batch Loss: 85377.5859
# Epoch 103, Batch 46/49, Batch Loss: 83906.5625
# Epoch 103, Batch 47/49, Batch Loss: 81845.6641
# Epoch 103, Batch 48/49, Batch Loss: 81958.3438
# Epoch 103, Batch 49/49, Batch Loss: 103306.2969
# Batch 1/17, Batch Loss: 311985.3125
# Batch 2/17, Batch Loss: 234874.9844
# Batch 3/17, Batch Loss: 206756.9844
# Batch 4/17, Batch Loss: 340749.6562
# Batch 5/17, Batch Loss: 212572.5625
# Batch 6/17, Batch Loss: 412631.8438
# Batch 7/17, Batch Loss: 245468.4219
# Batch 8/17, Batch Loss: 277566.0625
# Batch 9/17, Batch Loss: 230039.0156
# Batch 10/17, Batch Loss: 161730.0469
# Batch 11/17, Batch Loss: 292891.7812
# Batch 12/17, Batch Loss: 292827.2188
# Batch 13/17, Batch Loss: 559994.5625
# Batch 14/17, Batch Loss: 213442.0000
# Batch 15/17, Batch Loss: 248355.6875
# Batch 16/17, Batch Loss: 126250.9609
# Batch 17/17, Batch Loss: 258935.7812
# Test Error:
#  Avg loss: 272180.757812, Avg error: 195235.251730
#
# Epoch 104, Batch 1/49, Batch Loss: 129437.1172
# Epoch 104, Batch 2/49, Batch Loss: 216335.7188
# Epoch 104, Batch 3/49, Batch Loss: 87569.6484
# Epoch 104, Batch 4/49, Batch Loss: 72166.9766
# Epoch 104, Batch 5/49, Batch Loss: 153258.9062
# Epoch 104, Batch 6/49, Batch Loss: 96522.2266
# Epoch 104, Batch 7/49, Batch Loss: 97062.2500
# Epoch 104, Batch 8/49, Batch Loss: 81415.8516
# Epoch 104, Batch 9/49, Batch Loss: 70864.3750
# Epoch 104, Batch 10/49, Batch Loss: 75250.9453
# Epoch 104, Batch 11/49, Batch Loss: 92492.4922
# Epoch 104, Batch 12/49, Batch Loss: 72527.9219
# Epoch 104, Batch 13/49, Batch Loss: 66490.4297
# Epoch 104, Batch 14/49, Batch Loss: 86617.1172
# Epoch 104, Batch 15/49, Batch Loss: 85011.1016
# Epoch 104, Batch 16/49, Batch Loss: 79964.9922
# Epoch 104, Batch 17/49, Batch Loss: 87553.8750
# Epoch 104, Batch 18/49, Batch Loss: 89895.1562
# Epoch 104, Batch 19/49, Batch Loss: 86687.9844
# Epoch 104, Batch 20/49, Batch Loss: 84643.7266
# Epoch 104, Batch 21/49, Batch Loss: 172502.6406
# Epoch 104, Batch 22/49, Batch Loss: 73873.6641
# Epoch 104, Batch 23/49, Batch Loss: 105138.8750
# Epoch 104, Batch 24/49, Batch Loss: 93708.6641
# Epoch 104, Batch 25/49, Batch Loss: 108885.2031
# Epoch 104, Batch 26/49, Batch Loss: 78952.7031
# Epoch 104, Batch 27/49, Batch Loss: 97963.6484
# Epoch 104, Batch 28/49, Batch Loss: 68366.9922
# Epoch 104, Batch 29/49, Batch Loss: 76406.6484
# Epoch 104, Batch 30/49, Batch Loss: 110011.8516
# Epoch 104, Batch 31/49, Batch Loss: 92367.5000
# Epoch 104, Batch 32/49, Batch Loss: 84557.2344
# Epoch 104, Batch 33/49, Batch Loss: 64527.3672
# Epoch 104, Batch 34/49, Batch Loss: 52407.6836
# Epoch 104, Batch 35/49, Batch Loss: 101668.1016
# Epoch 104, Batch 36/49, Batch Loss: 75319.5469
# Epoch 104, Batch 37/49, Batch Loss: 78840.5391
# Epoch 104, Batch 38/49, Batch Loss: 90597.6953
# Epoch 104, Batch 39/49, Batch Loss: 91495.2109
# Epoch 104, Batch 40/49, Batch Loss: 85676.1953
# Epoch 104, Batch 41/49, Batch Loss: 80934.6484
# Epoch 104, Batch 42/49, Batch Loss: 82486.6875
# Epoch 104, Batch 43/49, Batch Loss: 84166.8359
# Epoch 104, Batch 44/49, Batch Loss: 70972.9922
# Epoch 104, Batch 45/49, Batch Loss: 89703.1406
# Epoch 104, Batch 46/49, Batch Loss: 74220.9375
# Epoch 104, Batch 47/49, Batch Loss: 88487.2734
# Epoch 104, Batch 48/49, Batch Loss: 114630.3750
# Epoch 104, Batch 49/49, Batch Loss: 107395.3594
# Batch 1/17, Batch Loss: 290685.5625
# Batch 2/17, Batch Loss: 219984.5469
# Batch 3/17, Batch Loss: 138774.8281
# Batch 4/17, Batch Loss: 275901.1875
# Batch 5/17, Batch Loss: 192045.6719
# Batch 6/17, Batch Loss: 395726.5625
# Batch 7/17, Batch Loss: 241980.4844
# Batch 8/17, Batch Loss: 248984.4375
# Batch 9/17, Batch Loss: 174585.6406
# Batch 10/17, Batch Loss: 154488.2031
# Batch 11/17, Batch Loss: 257818.6719
# Batch 12/17, Batch Loss: 238087.2969
# Batch 13/17, Batch Loss: 508758.3438
# Batch 14/17, Batch Loss: 157683.2656
# Batch 15/17, Batch Loss: 194681.6562
# Batch 16/17, Batch Loss: 98275.8828
# Batch 17/17, Batch Loss: 216539.8594
# Test Error:
#  Avg loss: 235588.358915, Avg error: 150849.575692
#
# Epoch 105, Batch 1/49, Batch Loss: 109111.3438
# Epoch 105, Batch 2/49, Batch Loss: 74958.4375
# Epoch 105, Batch 3/49, Batch Loss: 60667.4297
# Epoch 105, Batch 4/49, Batch Loss: 71868.4375
# Epoch 105, Batch 5/49, Batch Loss: 61429.2148
# Epoch 105, Batch 6/49, Batch Loss: 82966.3125
# Epoch 105, Batch 7/49, Batch Loss: 89256.1641
# Epoch 105, Batch 8/49, Batch Loss: 77500.9219
# Epoch 105, Batch 9/49, Batch Loss: 72858.8984
# Epoch 105, Batch 10/49, Batch Loss: 67459.1562
# Epoch 105, Batch 11/49, Batch Loss: 63642.7891
# Epoch 105, Batch 12/49, Batch Loss: 68766.7891
# Epoch 105, Batch 13/49, Batch Loss: 87828.1641
# Epoch 105, Batch 14/49, Batch Loss: 131813.7969
# Epoch 105, Batch 15/49, Batch Loss: 74429.8516
# Epoch 105, Batch 16/49, Batch Loss: 129003.5156
# Epoch 105, Batch 17/49, Batch Loss: 87707.9531
# Epoch 105, Batch 18/49, Batch Loss: 68174.5000
# Epoch 105, Batch 19/49, Batch Loss: 65538.9141
# Epoch 105, Batch 20/49, Batch Loss: 65981.9141
# Epoch 105, Batch 21/49, Batch Loss: 95225.1328
# Epoch 105, Batch 22/49, Batch Loss: 91828.9766
# Epoch 105, Batch 23/49, Batch Loss: 94472.1797
# Epoch 105, Batch 24/49, Batch Loss: 70395.6406
# Epoch 105, Batch 25/49, Batch Loss: 80031.8281
# Epoch 105, Batch 26/49, Batch Loss: 94022.6250
# Epoch 105, Batch 27/49, Batch Loss: 111013.1875
# Epoch 105, Batch 28/49, Batch Loss: 89938.3516
# Epoch 105, Batch 29/49, Batch Loss: 102034.3828
# Epoch 105, Batch 30/49, Batch Loss: 84544.9375
# Epoch 105, Batch 31/49, Batch Loss: 70164.8281
# Epoch 105, Batch 32/49, Batch Loss: 103208.4609
# Epoch 105, Batch 33/49, Batch Loss: 82932.7812
# Epoch 105, Batch 34/49, Batch Loss: 56879.6680
# Epoch 105, Batch 35/49, Batch Loss: 78650.1406
# Epoch 105, Batch 36/49, Batch Loss: 94927.0938
# Epoch 105, Batch 37/49, Batch Loss: 96772.3984
# Epoch 105, Batch 38/49, Batch Loss: 92779.1797
# Epoch 105, Batch 39/49, Batch Loss: 88687.1641
# Epoch 105, Batch 40/49, Batch Loss: 80528.4609
# Epoch 105, Batch 41/49, Batch Loss: 78981.2969
# Epoch 105, Batch 42/49, Batch Loss: 67062.2500
# Epoch 105, Batch 43/49, Batch Loss: 93714.9062
# Epoch 105, Batch 44/49, Batch Loss: 92769.2344
# Epoch 105, Batch 45/49, Batch Loss: 93539.2344
# Epoch 105, Batch 46/49, Batch Loss: 89048.8750
# Epoch 105, Batch 47/49, Batch Loss: 97994.6094
# Epoch 105, Batch 48/49, Batch Loss: 118819.2578
# Epoch 105, Batch 49/49, Batch Loss: 59855.4141
# Batch 1/17, Batch Loss: 290769.7188
# Batch 2/17, Batch Loss: 216743.4844
# Batch 3/17, Batch Loss: 176703.1719
# Batch 4/17, Batch Loss: 302616.0938
# Batch 5/17, Batch Loss: 198986.9688
# Batch 6/17, Batch Loss: 402758.7500
# Batch 7/17, Batch Loss: 232664.2812
# Batch 8/17, Batch Loss: 244825.9688
# Batch 9/17, Batch Loss: 178225.1719
# Batch 10/17, Batch Loss: 151310.5781
# Batch 11/17, Batch Loss: 258888.5625
# Batch 12/17, Batch Loss: 247219.1719
# Batch 13/17, Batch Loss: 517306.6562
# Batch 14/17, Batch Loss: 167036.4531
# Batch 15/17, Batch Loss: 196057.7969
# Batch 16/17, Batch Loss: 102956.8594
# Batch 17/17, Batch Loss: 230289.7969
# Test Error:
#  Avg loss: 242079.969669, Avg error: 158889.496107
#
# Epoch 106, Batch 1/49, Batch Loss: 59631.8477
# Epoch 106, Batch 2/49, Batch Loss: 68210.3359
# Epoch 106, Batch 3/49, Batch Loss: 79213.7188
# Epoch 106, Batch 4/49, Batch Loss: 101186.4062
# Epoch 106, Batch 5/49, Batch Loss: 87166.1953
# Epoch 106, Batch 6/49, Batch Loss: 102908.8125
# Epoch 106, Batch 7/49, Batch Loss: 57015.5195
# Epoch 106, Batch 8/49, Batch Loss: 110985.9609
# Epoch 106, Batch 9/49, Batch Loss: 96209.0469
# Epoch 106, Batch 10/49, Batch Loss: 86433.4609
# Epoch 106, Batch 11/49, Batch Loss: 77481.9297
# Epoch 106, Batch 12/49, Batch Loss: 73827.4219
# Epoch 106, Batch 13/49, Batch Loss: 68918.3281
# Epoch 106, Batch 14/49, Batch Loss: 119097.8281
# Epoch 106, Batch 15/49, Batch Loss: 91318.6250
# Epoch 106, Batch 16/49, Batch Loss: 221437.6094
# Epoch 106, Batch 17/49, Batch Loss: 60166.1172
# Epoch 106, Batch 18/49, Batch Loss: 144023.1875
# Epoch 106, Batch 19/49, Batch Loss: 201973.8594
# Epoch 106, Batch 20/49, Batch Loss: 135856.8438
# Epoch 106, Batch 21/49, Batch Loss: 147785.0156
# Epoch 106, Batch 22/49, Batch Loss: 168457.1562
# Epoch 106, Batch 23/49, Batch Loss: 149273.1875
# Epoch 106, Batch 24/49, Batch Loss: 66979.1797
# Epoch 106, Batch 25/49, Batch Loss: 84357.4453
# Epoch 106, Batch 26/49, Batch Loss: 111142.4609
# Epoch 106, Batch 27/49, Batch Loss: 82414.3047
# Epoch 106, Batch 28/49, Batch Loss: 105387.2500
# Epoch 106, Batch 29/49, Batch Loss: 112932.6406
# Epoch 106, Batch 30/49, Batch Loss: 49584.0391
# Epoch 106, Batch 31/49, Batch Loss: 69507.6875
# Epoch 106, Batch 32/49, Batch Loss: 84508.8438
# Epoch 106, Batch 33/49, Batch Loss: 102832.2656
# Epoch 106, Batch 34/49, Batch Loss: 83964.3125
# Epoch 106, Batch 35/49, Batch Loss: 106857.7656
# Epoch 106, Batch 36/49, Batch Loss: 76953.3438
# Epoch 106, Batch 37/49, Batch Loss: 66308.2891
# Epoch 106, Batch 38/49, Batch Loss: 68592.1953
# Epoch 106, Batch 39/49, Batch Loss: 113159.1328
# Epoch 106, Batch 40/49, Batch Loss: 168868.6719
# Epoch 106, Batch 41/49, Batch Loss: 92590.3516
# Epoch 106, Batch 42/49, Batch Loss: 83836.6172
# Epoch 106, Batch 43/49, Batch Loss: 94619.5156
# Epoch 106, Batch 44/49, Batch Loss: 97837.5547
# Epoch 106, Batch 45/49, Batch Loss: 96687.2734
# Epoch 106, Batch 46/49, Batch Loss: 106281.8828
# Epoch 106, Batch 47/49, Batch Loss: 87168.2734
# Epoch 106, Batch 48/49, Batch Loss: 93422.3281
# Epoch 106, Batch 49/49, Batch Loss: 150071.3906
# Batch 1/17, Batch Loss: 284773.8750
# Batch 2/17, Batch Loss: 220136.7188
# Batch 3/17, Batch Loss: 151556.9219
# Batch 4/17, Batch Loss: 280838.3750
# Batch 5/17, Batch Loss: 194660.8906
# Batch 6/17, Batch Loss: 419864.7500
# Batch 7/17, Batch Loss: 244994.1250
# Batch 8/17, Batch Loss: 254975.6250
# Batch 9/17, Batch Loss: 165146.8906
# Batch 10/17, Batch Loss: 156328.6094
# Batch 11/17, Batch Loss: 252618.2656
# Batch 12/17, Batch Loss: 232507.9531
# Batch 13/17, Batch Loss: 507135.3125
# Batch 14/17, Batch Loss: 136176.3438
# Batch 15/17, Batch Loss: 183514.3125
# Batch 16/17, Batch Loss: 104937.2734
# Batch 17/17, Batch Loss: 220896.7344
# Test Error:
#  Avg loss: 235944.880974, Avg error: 146058.272491
#
# Epoch 107, Batch 1/49, Batch Loss: 83827.2188
# Epoch 107, Batch 2/49, Batch Loss: 94665.9688
# Epoch 107, Batch 3/49, Batch Loss: 91501.7812
# Epoch 107, Batch 4/49, Batch Loss: 79348.1641
# Epoch 107, Batch 5/49, Batch Loss: 86763.5391
# Epoch 107, Batch 6/49, Batch Loss: 72798.1953
# Epoch 107, Batch 7/49, Batch Loss: 68151.1953
# Epoch 107, Batch 8/49, Batch Loss: 75543.6719
# Epoch 107, Batch 9/49, Batch Loss: 114693.3672
# Epoch 107, Batch 10/49, Batch Loss: 85433.6328
# Epoch 107, Batch 11/49, Batch Loss: 90208.4922
# Epoch 107, Batch 12/49, Batch Loss: 97638.9766
# Epoch 107, Batch 13/49, Batch Loss: 120888.6875
# Epoch 107, Batch 14/49, Batch Loss: 83886.5547
# Epoch 107, Batch 15/49, Batch Loss: 84328.2578
# Epoch 107, Batch 16/49, Batch Loss: 83028.3984
# Epoch 107, Batch 17/49, Batch Loss: 62125.2422
# Epoch 107, Batch 18/49, Batch Loss: 90654.1719
# Epoch 107, Batch 19/49, Batch Loss: 64380.6250
# Epoch 107, Batch 20/49, Batch Loss: 83282.7656
# Epoch 107, Batch 21/49, Batch Loss: 87833.0938
# Epoch 107, Batch 22/49, Batch Loss: 76783.5625
# Epoch 107, Batch 23/49, Batch Loss: 75252.9297
# Epoch 107, Batch 24/49, Batch Loss: 134695.7812
# Epoch 107, Batch 25/49, Batch Loss: 78691.3125
# Epoch 107, Batch 26/49, Batch Loss: 69362.9609
# Epoch 107, Batch 27/49, Batch Loss: 104201.8203
# Epoch 107, Batch 28/49, Batch Loss: 71392.3828
# Epoch 107, Batch 29/49, Batch Loss: 81023.9141
# Epoch 107, Batch 30/49, Batch Loss: 75331.6719
# Epoch 107, Batch 31/49, Batch Loss: 78831.0156
# Epoch 107, Batch 32/49, Batch Loss: 83836.5234
# Epoch 107, Batch 33/49, Batch Loss: 61275.4414
# Epoch 107, Batch 34/49, Batch Loss: 91868.6094
# Epoch 107, Batch 35/49, Batch Loss: 77129.8750
# Epoch 107, Batch 36/49, Batch Loss: 82485.7188
# Epoch 107, Batch 37/49, Batch Loss: 77470.2031
# Epoch 107, Batch 38/49, Batch Loss: 70995.5078
# Epoch 107, Batch 39/49, Batch Loss: 115891.1406
# Epoch 107, Batch 40/49, Batch Loss: 154837.2812
# Epoch 107, Batch 41/49, Batch Loss: 111786.5000
# Epoch 107, Batch 42/49, Batch Loss: 99864.7578
# Epoch 107, Batch 43/49, Batch Loss: 112828.8359
# Epoch 107, Batch 44/49, Batch Loss: 131504.4062
# Epoch 107, Batch 45/49, Batch Loss: 86272.7109
# Epoch 107, Batch 46/49, Batch Loss: 60001.6602
# Epoch 107, Batch 47/49, Batch Loss: 81592.8516
# Epoch 107, Batch 48/49, Batch Loss: 74148.6172
# Epoch 107, Batch 49/49, Batch Loss: 274933.7812
# Batch 1/17, Batch Loss: 253191.8125
# Batch 2/17, Batch Loss: 224416.7344
# Batch 3/17, Batch Loss: 137282.2031
# Batch 4/17, Batch Loss: 261074.3750
# Batch 5/17, Batch Loss: 173494.5312
# Batch 6/17, Batch Loss: 381142.0938
# Batch 7/17, Batch Loss: 253327.2188
# Batch 8/17, Batch Loss: 241118.1562
# Batch 9/17, Batch Loss: 158790.5469
# Batch 10/17, Batch Loss: 148019.8594
# Batch 11/17, Batch Loss: 239878.0469
# Batch 12/17, Batch Loss: 218568.2031
# Batch 13/17, Batch Loss: 487736.7188
# Batch 14/17, Batch Loss: 163635.8594
# Batch 15/17, Batch Loss: 173576.1250
# Batch 16/17, Batch Loss: 98065.9219
# Batch 17/17, Batch Loss: 210295.5938
# Test Error:
#  Avg loss: 224918.470588, Avg error: 138424.832612
#
# Epoch 108, Batch 1/49, Batch Loss: 86710.7188
# Epoch 108, Batch 2/49, Batch Loss: 110732.7266
# Epoch 108, Batch 3/49, Batch Loss: 88061.2344
# Epoch 108, Batch 4/49, Batch Loss: 63362.1836
# Epoch 108, Batch 5/49, Batch Loss: 94723.7734
# Epoch 108, Batch 6/49, Batch Loss: 112774.2969
# Epoch 108, Batch 7/49, Batch Loss: 67832.0156
# Epoch 108, Batch 8/49, Batch Loss: 58268.0195
# Epoch 108, Batch 9/49, Batch Loss: 63920.6172
# Epoch 108, Batch 10/49, Batch Loss: 93154.8281
# Epoch 108, Batch 11/49, Batch Loss: 88840.2422
# Epoch 108, Batch 12/49, Batch Loss: 74924.2734
# Epoch 108, Batch 13/49, Batch Loss: 80393.2891
# Epoch 108, Batch 14/49, Batch Loss: 79727.0859
# Epoch 108, Batch 15/49, Batch Loss: 90630.9297
# Epoch 108, Batch 16/49, Batch Loss: 69488.9141
# Epoch 108, Batch 17/49, Batch Loss: 83467.0859
# Epoch 108, Batch 18/49, Batch Loss: 51691.1406
# Epoch 108, Batch 19/49, Batch Loss: 84607.6484
# Epoch 108, Batch 20/49, Batch Loss: 115553.5859
# Epoch 108, Batch 21/49, Batch Loss: 71110.8594
# Epoch 108, Batch 22/49, Batch Loss: 79241.8359
# Epoch 108, Batch 23/49, Batch Loss: 69111.4453
# Epoch 108, Batch 24/49, Batch Loss: 101276.9062
# Epoch 108, Batch 25/49, Batch Loss: 68336.0859
# Epoch 108, Batch 26/49, Batch Loss: 53279.4023
# Epoch 108, Batch 27/49, Batch Loss: 73778.7969
# Epoch 108, Batch 28/49, Batch Loss: 79660.5781
# Epoch 108, Batch 29/49, Batch Loss: 74465.7344
# Epoch 108, Batch 30/49, Batch Loss: 86970.8125
# Epoch 108, Batch 31/49, Batch Loss: 125509.9844
# Epoch 108, Batch 32/49, Batch Loss: 91737.1797
# Epoch 108, Batch 33/49, Batch Loss: 116436.4062
# Epoch 108, Batch 34/49, Batch Loss: 87551.1719
# Epoch 108, Batch 35/49, Batch Loss: 97069.7422
# Epoch 108, Batch 36/49, Batch Loss: 146882.5781
# Epoch 108, Batch 37/49, Batch Loss: 100097.1016
# Epoch 108, Batch 38/49, Batch Loss: 121327.0391
# Epoch 108, Batch 39/49, Batch Loss: 111033.7500
# Epoch 108, Batch 40/49, Batch Loss: 88965.2500
# Epoch 108, Batch 41/49, Batch Loss: 99486.1328
# Epoch 108, Batch 42/49, Batch Loss: 83591.3047
# Epoch 108, Batch 43/49, Batch Loss: 69502.5156
# Epoch 108, Batch 44/49, Batch Loss: 69694.7344
# Epoch 108, Batch 45/49, Batch Loss: 71402.7578
# Epoch 108, Batch 46/49, Batch Loss: 73310.0000
# Epoch 108, Batch 47/49, Batch Loss: 78982.0781
# Epoch 108, Batch 48/49, Batch Loss: 69041.7031
# Epoch 108, Batch 49/49, Batch Loss: 94732.1797
# Batch 1/17, Batch Loss: 311466.0625
# Batch 2/17, Batch Loss: 235367.2188
# Batch 3/17, Batch Loss: 179779.2969
# Batch 4/17, Batch Loss: 301988.1875
# Batch 5/17, Batch Loss: 198297.6094
# Batch 6/17, Batch Loss: 400770.9688
# Batch 7/17, Batch Loss: 239615.7812
# Batch 8/17, Batch Loss: 268077.1250
# Batch 9/17, Batch Loss: 184202.2188
# Batch 10/17, Batch Loss: 150500.0781
# Batch 11/17, Batch Loss: 252792.9531
# Batch 12/17, Batch Loss: 255164.5625
# Batch 13/17, Batch Loss: 521301.0000
# Batch 14/17, Batch Loss: 141491.6562
# Batch 15/17, Batch Loss: 182563.2969
# Batch 16/17, Batch Loss: 117615.9531
# Batch 17/17, Batch Loss: 253361.1250
# Test Error:
#  Avg loss: 246726.770221, Avg error: 158961.047578
#
# Epoch 109, Batch 1/49, Batch Loss: 74051.4609
# Epoch 109, Batch 2/49, Batch Loss: 152440.1094
# Epoch 109, Batch 3/49, Batch Loss: 80767.3281
# Epoch 109, Batch 4/49, Batch Loss: 72755.3906
# Epoch 109, Batch 5/49, Batch Loss: 60755.3242
# Epoch 109, Batch 6/49, Batch Loss: 83619.8438
# Epoch 109, Batch 7/49, Batch Loss: 74408.4766
# Epoch 109, Batch 8/49, Batch Loss: 59936.0977
# Epoch 109, Batch 9/49, Batch Loss: 92673.7812
# Epoch 109, Batch 10/49, Batch Loss: 69337.4141
# Epoch 109, Batch 11/49, Batch Loss: 55320.2188
# Epoch 109, Batch 12/49, Batch Loss: 71530.3516
# Epoch 109, Batch 13/49, Batch Loss: 74641.8750
# Epoch 109, Batch 14/49, Batch Loss: 73882.5859
# Epoch 109, Batch 15/49, Batch Loss: 52792.3945
# Epoch 109, Batch 16/49, Batch Loss: 102284.0391
# Epoch 109, Batch 17/49, Batch Loss: 103732.4375
# Epoch 109, Batch 18/49, Batch Loss: 113307.6797
# Epoch 109, Batch 19/49, Batch Loss: 105768.0547
# Epoch 109, Batch 20/49, Batch Loss: 96284.7891
# Epoch 109, Batch 21/49, Batch Loss: 129389.0391
# Epoch 109, Batch 22/49, Batch Loss: 92440.4609
# Epoch 109, Batch 23/49, Batch Loss: 77779.6641
# Epoch 109, Batch 24/49, Batch Loss: 93920.7031
# Epoch 109, Batch 25/49, Batch Loss: 77949.1406
# Epoch 109, Batch 26/49, Batch Loss: 74100.6719
# Epoch 109, Batch 27/49, Batch Loss: 99818.2891
# Epoch 109, Batch 28/49, Batch Loss: 66360.0078
# Epoch 109, Batch 29/49, Batch Loss: 74105.0469
# Epoch 109, Batch 30/49, Batch Loss: 99916.2656
# Epoch 109, Batch 31/49, Batch Loss: 111398.5156
# Epoch 109, Batch 32/49, Batch Loss: 71633.7891
# Epoch 109, Batch 33/49, Batch Loss: 69413.9453
# Epoch 109, Batch 34/49, Batch Loss: 76704.7500
# Epoch 109, Batch 35/49, Batch Loss: 83619.6172
# Epoch 109, Batch 36/49, Batch Loss: 104877.5859
# Epoch 109, Batch 37/49, Batch Loss: 74282.5156
# Epoch 109, Batch 38/49, Batch Loss: 61646.2734
# Epoch 109, Batch 39/49, Batch Loss: 77901.2500
# Epoch 109, Batch 40/49, Batch Loss: 100637.5312
# Epoch 109, Batch 41/49, Batch Loss: 97934.6094
# Epoch 109, Batch 42/49, Batch Loss: 73509.1328
# Epoch 109, Batch 43/49, Batch Loss: 74846.1016
# Epoch 109, Batch 44/49, Batch Loss: 73866.3516
# Epoch 109, Batch 45/49, Batch Loss: 99864.3438
# Epoch 109, Batch 46/49, Batch Loss: 72289.5391
# Epoch 109, Batch 47/49, Batch Loss: 92255.5312
# Epoch 109, Batch 48/49, Batch Loss: 59364.1680
# Epoch 109, Batch 49/49, Batch Loss: 92813.2344
# Batch 1/17, Batch Loss: 311594.6562
# Batch 2/17, Batch Loss: 224533.0000
# Batch 3/17, Batch Loss: 189084.0312
# Batch 4/17, Batch Loss: 312289.8125
# Batch 5/17, Batch Loss: 202977.8906
# Batch 6/17, Batch Loss: 414455.9375
# Batch 7/17, Batch Loss: 248393.1250
# Batch 8/17, Batch Loss: 266064.1562
# Batch 9/17, Batch Loss: 199745.5312
# Batch 10/17, Batch Loss: 162530.4844
# Batch 11/17, Batch Loss: 269993.4375
# Batch 12/17, Batch Loss: 257802.7656
# Batch 13/17, Batch Loss: 529360.2500
# Batch 14/17, Batch Loss: 166832.6406
# Batch 15/17, Batch Loss: 210702.3594
# Batch 16/17, Batch Loss: 115125.1562
# Batch 17/17, Batch Loss: 246033.1406
# Test Error:
#  Avg loss: 254559.904412, Avg error: 173523.171280
#
# Epoch 110, Batch 1/49, Batch Loss: 71988.5000
# Epoch 110, Batch 2/49, Batch Loss: 66891.3984
# Epoch 110, Batch 3/49, Batch Loss: 87478.5859
# Epoch 110, Batch 4/49, Batch Loss: 79134.1484
# Epoch 110, Batch 5/49, Batch Loss: 92639.7969
# Epoch 110, Batch 6/49, Batch Loss: 61878.9102
# Epoch 110, Batch 7/49, Batch Loss: 88564.9766
# Epoch 110, Batch 8/49, Batch Loss: 108883.3672
# Epoch 110, Batch 9/49, Batch Loss: 70848.8906
# Epoch 110, Batch 10/49, Batch Loss: 72742.6875
# Epoch 110, Batch 11/49, Batch Loss: 83044.7812
# Epoch 110, Batch 12/49, Batch Loss: 79977.8906
# Epoch 110, Batch 13/49, Batch Loss: 64079.9336
# Epoch 110, Batch 14/49, Batch Loss: 63388.8789
# Epoch 110, Batch 15/49, Batch Loss: 69141.9062
# Epoch 110, Batch 16/49, Batch Loss: 116163.0391
# Epoch 110, Batch 17/49, Batch Loss: 120803.0781
# Epoch 110, Batch 18/49, Batch Loss: 82470.9609
# Epoch 110, Batch 19/49, Batch Loss: 131993.6094
# Epoch 110, Batch 20/49, Batch Loss: 75385.3047
# Epoch 110, Batch 21/49, Batch Loss: 69829.3281
# Epoch 110, Batch 22/49, Batch Loss: 76004.3203
# Epoch 110, Batch 23/49, Batch Loss: 64214.5781
# Epoch 110, Batch 24/49, Batch Loss: 66463.9609
# Epoch 110, Batch 25/49, Batch Loss: 83458.4062
# Epoch 110, Batch 26/49, Batch Loss: 98500.8438
# Epoch 110, Batch 27/49, Batch Loss: 75638.6484
# Epoch 110, Batch 28/49, Batch Loss: 148870.5469
# Epoch 110, Batch 29/49, Batch Loss: 72125.8984
# Epoch 110, Batch 30/49, Batch Loss: 65312.8047
# Epoch 110, Batch 31/49, Batch Loss: 84881.0312
# Epoch 110, Batch 32/49, Batch Loss: 71286.0234
# Epoch 110, Batch 33/49, Batch Loss: 70349.2891
# Epoch 110, Batch 34/49, Batch Loss: 84079.3984
# Epoch 110, Batch 35/49, Batch Loss: 72213.4062
# Epoch 110, Batch 36/49, Batch Loss: 78403.3203
# Epoch 110, Batch 37/49, Batch Loss: 100731.9688
# Epoch 110, Batch 38/49, Batch Loss: 53558.7891
# Epoch 110, Batch 39/49, Batch Loss: 148522.9375
# Epoch 110, Batch 40/49, Batch Loss: 84137.9375
# Epoch 110, Batch 41/49, Batch Loss: 90202.4219
# Epoch 110, Batch 42/49, Batch Loss: 71738.0547
# Epoch 110, Batch 43/49, Batch Loss: 74932.8125
# Epoch 110, Batch 44/49, Batch Loss: 67794.2578
# Epoch 110, Batch 45/49, Batch Loss: 68064.4531
# Epoch 110, Batch 46/49, Batch Loss: 62402.3320
# Epoch 110, Batch 47/49, Batch Loss: 80387.9609
# Epoch 110, Batch 48/49, Batch Loss: 77815.1406
# Epoch 110, Batch 49/49, Batch Loss: 76382.4688
# Batch 1/17, Batch Loss: 305265.7188
# Batch 2/17, Batch Loss: 230966.2812
# Batch 3/17, Batch Loss: 187909.3281
# Batch 4/17, Batch Loss: 315300.7188
# Batch 5/17, Batch Loss: 198694.6094
# Batch 6/17, Batch Loss: 404498.6875
# Batch 7/17, Batch Loss: 232577.6406
# Batch 8/17, Batch Loss: 273109.4688
# Batch 9/17, Batch Loss: 196783.3281
# Batch 10/17, Batch Loss: 158378.7031
# Batch 11/17, Batch Loss: 268543.3438
# Batch 12/17, Batch Loss: 266289.0625
# Batch 13/17, Batch Loss: 527004.7500
# Batch 14/17, Batch Loss: 160267.6719
# Batch 15/17, Batch Loss: 202309.7344
# Batch 16/17, Batch Loss: 122252.4609
# Batch 17/17, Batch Loss: 259321.9844
# Test Error:
#  Avg loss: 253498.440717, Avg error: 170356.488322
#
# 2024-10-08 21:59:49.128078 Epoch 110, Average Training loss 82159.2649872449
# Epoch 111, Batch 1/49, Batch Loss: 84243.0078
# Epoch 111, Batch 2/49, Batch Loss: 75984.5938
# Epoch 111, Batch 3/49, Batch Loss: 55742.1445
# Epoch 111, Batch 4/49, Batch Loss: 58086.0586
# Epoch 111, Batch 5/49, Batch Loss: 54178.4648
# Epoch 111, Batch 6/49, Batch Loss: 75048.5234
# Epoch 111, Batch 7/49, Batch Loss: 77128.4766
# Epoch 111, Batch 8/49, Batch Loss: 69060.3672
# Epoch 111, Batch 9/49, Batch Loss: 125179.2891
# Epoch 111, Batch 10/49, Batch Loss: 76577.1719
# Epoch 111, Batch 11/49, Batch Loss: 72203.8906
# Epoch 111, Batch 12/49, Batch Loss: 69952.1250
# Epoch 111, Batch 13/49, Batch Loss: 54045.4180
# Epoch 111, Batch 14/49, Batch Loss: 61129.6875
# Epoch 111, Batch 15/49, Batch Loss: 63237.1797
# Epoch 111, Batch 16/49, Batch Loss: 52102.4570
# Epoch 111, Batch 17/49, Batch Loss: 72338.4297
# Epoch 111, Batch 18/49, Batch Loss: 121245.9531
# Epoch 111, Batch 19/49, Batch Loss: 93144.8359
# Epoch 111, Batch 20/49, Batch Loss: 102032.9453
# Epoch 111, Batch 21/49, Batch Loss: 84148.6562
# Epoch 111, Batch 22/49, Batch Loss: 79771.8906
# Epoch 111, Batch 23/49, Batch Loss: 59709.4727
# Epoch 111, Batch 24/49, Batch Loss: 74226.2266
# Epoch 111, Batch 25/49, Batch Loss: 60920.1719
# Epoch 111, Batch 26/49, Batch Loss: 83314.6641
# Epoch 111, Batch 27/49, Batch Loss: 68309.8828
# Epoch 111, Batch 28/49, Batch Loss: 76233.5078
# Epoch 111, Batch 29/49, Batch Loss: 78540.9219
# Epoch 111, Batch 30/49, Batch Loss: 73268.9453
# Epoch 111, Batch 31/49, Batch Loss: 62623.4805
# Epoch 111, Batch 32/49, Batch Loss: 82089.6328
# Epoch 111, Batch 33/49, Batch Loss: 61850.9180
# Epoch 111, Batch 34/49, Batch Loss: 75754.7812
# Epoch 111, Batch 35/49, Batch Loss: 60752.1562
# Epoch 111, Batch 36/49, Batch Loss: 91677.2969
# Epoch 111, Batch 37/49, Batch Loss: 85191.4219
# Epoch 111, Batch 38/49, Batch Loss: 62641.3516
# Epoch 111, Batch 39/49, Batch Loss: 79229.9062
# Epoch 111, Batch 40/49, Batch Loss: 74014.2656
# Epoch 111, Batch 41/49, Batch Loss: 74259.7812
# Epoch 111, Batch 42/49, Batch Loss: 85176.1250
# Epoch 111, Batch 43/49, Batch Loss: 50608.3867
# Epoch 111, Batch 44/49, Batch Loss: 110305.5078
# Epoch 111, Batch 45/49, Batch Loss: 65227.4766
# Epoch 111, Batch 46/49, Batch Loss: 78965.4062
# Epoch 111, Batch 47/49, Batch Loss: 85581.9609
# Epoch 111, Batch 48/49, Batch Loss: 57464.0273
# Epoch 111, Batch 49/49, Batch Loss: 75460.9609
# Batch 1/17, Batch Loss: 302065.7500
# Batch 2/17, Batch Loss: 219430.2812
# Batch 3/17, Batch Loss: 160260.2656
# Batch 4/17, Batch Loss: 287343.9688
# Batch 5/17, Batch Loss: 186009.9844
# Batch 6/17, Batch Loss: 410829.9062
# Batch 7/17, Batch Loss: 248656.2188
# Batch 8/17, Batch Loss: 274263.7500
# Batch 9/17, Batch Loss: 173245.8594
# Batch 10/17, Batch Loss: 163417.7656
# Batch 11/17, Batch Loss: 255264.4219
# Batch 12/17, Batch Loss: 244139.8750
# Batch 13/17, Batch Loss: 518556.5625
# Batch 14/17, Batch Loss: 172272.0156
# Batch 15/17, Batch Loss: 189694.5469
# Batch 16/17, Batch Loss: 114716.2812
# Batch 17/17, Batch Loss: 227967.2344
# Test Error:
#  Avg loss: 244007.922794, Avg error: 155927.062716
#
# Epoch 112, Batch 1/49, Batch Loss: 54442.7891
# Epoch 112, Batch 2/49, Batch Loss: 76894.6953
# Epoch 112, Batch 3/49, Batch Loss: 73487.3828
# Epoch 112, Batch 4/49, Batch Loss: 63726.3359
# Epoch 112, Batch 5/49, Batch Loss: 62855.1562
# Epoch 112, Batch 6/49, Batch Loss: 92051.4688
# Epoch 112, Batch 7/49, Batch Loss: 89781.6250
# Epoch 112, Batch 8/49, Batch Loss: 59221.7031
# Epoch 112, Batch 9/49, Batch Loss: 78799.6406
# Epoch 112, Batch 10/49, Batch Loss: 79030.6797
# Epoch 112, Batch 11/49, Batch Loss: 62391.5117
# Epoch 112, Batch 12/49, Batch Loss: 72376.4531
# Epoch 112, Batch 13/49, Batch Loss: 119106.8281
# Epoch 112, Batch 14/49, Batch Loss: 91248.1719
# Epoch 112, Batch 15/49, Batch Loss: 92827.5234
# Epoch 112, Batch 16/49, Batch Loss: 52025.9062
# Epoch 112, Batch 17/49, Batch Loss: 83014.7109
# Epoch 112, Batch 18/49, Batch Loss: 85872.5469
# Epoch 112, Batch 19/49, Batch Loss: 73877.6094
# Epoch 112, Batch 20/49, Batch Loss: 65847.3203
# Epoch 112, Batch 21/49, Batch Loss: 72311.4922
# Epoch 112, Batch 22/49, Batch Loss: 73919.9688
# Epoch 112, Batch 23/49, Batch Loss: 61686.7500
# Epoch 112, Batch 24/49, Batch Loss: 46962.0586
# Epoch 112, Batch 25/49, Batch Loss: 90249.6406
# Epoch 112, Batch 26/49, Batch Loss: 79516.5625
# Epoch 112, Batch 27/49, Batch Loss: 59157.5430
# Epoch 112, Batch 28/49, Batch Loss: 57362.4336
# Epoch 112, Batch 29/49, Batch Loss: 70235.5625
# Epoch 112, Batch 30/49, Batch Loss: 84298.5938
# Epoch 112, Batch 31/49, Batch Loss: 92873.3125
# Epoch 112, Batch 32/49, Batch Loss: 68779.8672
# Epoch 112, Batch 33/49, Batch Loss: 105128.5391
# Epoch 112, Batch 34/49, Batch Loss: 72254.3984
# Epoch 112, Batch 35/49, Batch Loss: 92574.9844
# Epoch 112, Batch 36/49, Batch Loss: 95356.4062
# Epoch 112, Batch 37/49, Batch Loss: 154744.6562
# Epoch 112, Batch 38/49, Batch Loss: 59477.4688
# Epoch 112, Batch 39/49, Batch Loss: 86346.0078
# Epoch 112, Batch 40/49, Batch Loss: 133533.5938
# Epoch 112, Batch 41/49, Batch Loss: 92317.4531
# Epoch 112, Batch 42/49, Batch Loss: 68074.5625
# Epoch 112, Batch 43/49, Batch Loss: 85748.1172
# Epoch 112, Batch 44/49, Batch Loss: 63732.5664
# Epoch 112, Batch 45/49, Batch Loss: 162712.4844
# Epoch 112, Batch 46/49, Batch Loss: 95108.9375
# Epoch 112, Batch 47/49, Batch Loss: 80728.2031
# Epoch 112, Batch 48/49, Batch Loss: 95579.4922
# Epoch 112, Batch 49/49, Batch Loss: 88608.8047
# Batch 1/17, Batch Loss: 300294.5625
# Batch 2/17, Batch Loss: 221549.4531
# Batch 3/17, Batch Loss: 159813.1094
# Batch 4/17, Batch Loss: 313841.2188
# Batch 5/17, Batch Loss: 193304.0781
# Batch 6/17, Batch Loss: 403127.7500
# Batch 7/17, Batch Loss: 244568.9062
# Batch 8/17, Batch Loss: 267336.5000
# Batch 9/17, Batch Loss: 187728.2812
# Batch 10/17, Batch Loss: 159923.3125
# Batch 11/17, Batch Loss: 258795.7656
# Batch 12/17, Batch Loss: 249349.3438
# Batch 13/17, Batch Loss: 519323.9062
# Batch 14/17, Batch Loss: 215884.6250
# Batch 15/17, Batch Loss: 205699.9688
# Batch 16/17, Batch Loss: 101160.3594
# Batch 17/17, Batch Loss: 242487.8906
# Test Error:
#  Avg loss: 249658.178309, Avg error: 163565.214533
#
# Epoch 113, Batch 1/49, Batch Loss: 71657.8984
# Epoch 113, Batch 2/49, Batch Loss: 69910.8516
# Epoch 113, Batch 3/49, Batch Loss: 96815.3281
# Epoch 113, Batch 4/49, Batch Loss: 118885.6406
# Epoch 113, Batch 5/49, Batch Loss: 97170.6328
# Epoch 113, Batch 6/49, Batch Loss: 122599.6328
# Epoch 113, Batch 7/49, Batch Loss: 96470.9141
# Epoch 113, Batch 8/49, Batch Loss: 85563.5625
# Epoch 113, Batch 9/49, Batch Loss: 63420.5039
# Epoch 113, Batch 10/49, Batch Loss: 63932.3281
# Epoch 113, Batch 11/49, Batch Loss: 79449.1875
# Epoch 113, Batch 12/49, Batch Loss: 82481.1719
# Epoch 113, Batch 13/49, Batch Loss: 72400.4766
# Epoch 113, Batch 14/49, Batch Loss: 71461.6641
# Epoch 113, Batch 15/49, Batch Loss: 54119.8438
# Epoch 113, Batch 16/49, Batch Loss: 64299.8516
# Epoch 113, Batch 17/49, Batch Loss: 69507.4688
# Epoch 113, Batch 18/49, Batch Loss: 80941.7031
# Epoch 113, Batch 19/49, Batch Loss: 56951.7656
# Epoch 113, Batch 20/49, Batch Loss: 131811.5781
# Epoch 113, Batch 21/49, Batch Loss: 71229.3281
# Epoch 113, Batch 22/49, Batch Loss: 65798.4922
# Epoch 113, Batch 23/49, Batch Loss: 58447.4336
# Epoch 113, Batch 24/49, Batch Loss: 76210.6797
# Epoch 113, Batch 25/49, Batch Loss: 88860.8438
# Epoch 113, Batch 26/49, Batch Loss: 65900.3281
# Epoch 113, Batch 27/49, Batch Loss: 58392.9688
# Epoch 113, Batch 28/49, Batch Loss: 95962.3750
# Epoch 113, Batch 29/49, Batch Loss: 59085.8398
# Epoch 113, Batch 30/49, Batch Loss: 74770.1875
# Epoch 113, Batch 31/49, Batch Loss: 93840.8672
# Epoch 113, Batch 32/49, Batch Loss: 65579.6953
# Epoch 113, Batch 33/49, Batch Loss: 80244.3750
# Epoch 113, Batch 34/49, Batch Loss: 64264.7422
# Epoch 113, Batch 35/49, Batch Loss: 89856.8438
# Epoch 113, Batch 36/49, Batch Loss: 76444.1406
# Epoch 113, Batch 37/49, Batch Loss: 58104.9609
# Epoch 113, Batch 38/49, Batch Loss: 77773.8672
# Epoch 113, Batch 39/49, Batch Loss: 75036.0547
# Epoch 113, Batch 40/49, Batch Loss: 97662.5703
# Epoch 113, Batch 41/49, Batch Loss: 76784.6016
# Epoch 113, Batch 42/49, Batch Loss: 67184.5000
# Epoch 113, Batch 43/49, Batch Loss: 80958.3984
# Epoch 113, Batch 44/49, Batch Loss: 84423.2656
# Epoch 113, Batch 45/49, Batch Loss: 222109.3750
# Epoch 113, Batch 46/49, Batch Loss: 62765.5000
# Epoch 113, Batch 47/49, Batch Loss: 84735.0391
# Epoch 113, Batch 48/49, Batch Loss: 76873.5781
# Epoch 113, Batch 49/49, Batch Loss: 127524.0703
# Batch 1/17, Batch Loss: 299717.7500
# Batch 2/17, Batch Loss: 226829.8750
# Batch 3/17, Batch Loss: 139991.6875
# Batch 4/17, Batch Loss: 290103.7500
# Batch 5/17, Batch Loss: 196238.8750
# Batch 6/17, Batch Loss: 401323.2188
# Batch 7/17, Batch Loss: 248775.1094
# Batch 8/17, Batch Loss: 256448.0781
# Batch 9/17, Batch Loss: 178518.6562
# Batch 10/17, Batch Loss: 161789.9688
# Batch 11/17, Batch Loss: 255675.7031
# Batch 12/17, Batch Loss: 243807.1875
# Batch 13/17, Batch Loss: 517374.9062
# Batch 14/17, Batch Loss: 171686.3281
# Batch 15/17, Batch Loss: 194662.8594
# Batch 16/17, Batch Loss: 109786.2578
# Batch 17/17, Batch Loss: 240910.6719
# Test Error:
#  Avg loss: 243155.346048, Avg error: 156820.714533
#
# Epoch 114, Batch 1/49, Batch Loss: 62435.4570
# Epoch 114, Batch 2/49, Batch Loss: 68342.7188
# Epoch 114, Batch 3/49, Batch Loss: 113288.6719
# Epoch 114, Batch 4/49, Batch Loss: 67294.4609
# Epoch 114, Batch 5/49, Batch Loss: 73616.3594
# Epoch 114, Batch 6/49, Batch Loss: 59264.3789
# Epoch 114, Batch 7/49, Batch Loss: 66002.7500
# Epoch 114, Batch 8/49, Batch Loss: 67119.5312
# Epoch 114, Batch 9/49, Batch Loss: 91816.6328
# Epoch 114, Batch 10/49, Batch Loss: 69434.7812
# Epoch 114, Batch 11/49, Batch Loss: 85473.4219
# Epoch 114, Batch 12/49, Batch Loss: 66784.8438
# Epoch 114, Batch 13/49, Batch Loss: 87328.6328
# Epoch 114, Batch 14/49, Batch Loss: 70543.3984
# Epoch 114, Batch 15/49, Batch Loss: 77674.2031
# Epoch 114, Batch 16/49, Batch Loss: 61168.1094
# Epoch 114, Batch 17/49, Batch Loss: 87717.9688
# Epoch 114, Batch 18/49, Batch Loss: 129093.4219
# Epoch 114, Batch 19/49, Batch Loss: 73894.4766
# Epoch 114, Batch 20/49, Batch Loss: 100656.1016
# Epoch 114, Batch 21/49, Batch Loss: 70587.9844
# Epoch 114, Batch 22/49, Batch Loss: 77208.3594
# Epoch 114, Batch 23/49, Batch Loss: 68932.1406
# Epoch 114, Batch 24/49, Batch Loss: 55984.1250
# Epoch 114, Batch 25/49, Batch Loss: 58715.7891
# Epoch 114, Batch 26/49, Batch Loss: 77712.6562
# Epoch 114, Batch 27/49, Batch Loss: 86799.2266
# Epoch 114, Batch 28/49, Batch Loss: 89540.4453
# Epoch 114, Batch 29/49, Batch Loss: 83789.5938
# Epoch 114, Batch 30/49, Batch Loss: 64956.8125
# Epoch 114, Batch 31/49, Batch Loss: 67472.0938
# Epoch 114, Batch 32/49, Batch Loss: 73354.4375
# Epoch 114, Batch 33/49, Batch Loss: 85043.7266
# Epoch 114, Batch 34/49, Batch Loss: 63090.1641
# Epoch 114, Batch 35/49, Batch Loss: 65833.1172
# Epoch 114, Batch 36/49, Batch Loss: 83016.8438
# Epoch 114, Batch 37/49, Batch Loss: 72430.1094
# Epoch 114, Batch 38/49, Batch Loss: 122724.0625
# Epoch 114, Batch 39/49, Batch Loss: 89357.6562
# Epoch 114, Batch 40/49, Batch Loss: 82649.8516
# Epoch 114, Batch 41/49, Batch Loss: 82717.5938
# Epoch 114, Batch 42/49, Batch Loss: 76626.2109
# Epoch 114, Batch 43/49, Batch Loss: 205035.0781
# Epoch 114, Batch 44/49, Batch Loss: 79197.6406
# Epoch 114, Batch 45/49, Batch Loss: 68182.4453
# Epoch 114, Batch 46/49, Batch Loss: 67206.8125
# Epoch 114, Batch 47/49, Batch Loss: 73345.9219
# Epoch 114, Batch 48/49, Batch Loss: 88526.8750
# Epoch 114, Batch 49/49, Batch Loss: 122931.3125
# Batch 1/17, Batch Loss: 291304.4062
# Batch 2/17, Batch Loss: 218572.0469
# Batch 3/17, Batch Loss: 148175.7344
# Batch 4/17, Batch Loss: 292380.0625
# Batch 5/17, Batch Loss: 183995.7031
# Batch 6/17, Batch Loss: 403285.8438
# Batch 7/17, Batch Loss: 252195.6094
# Batch 8/17, Batch Loss: 252212.9531
# Batch 9/17, Batch Loss: 172534.6406
# Batch 10/17, Batch Loss: 161815.1406
# Batch 11/17, Batch Loss: 242872.6719
# Batch 12/17, Batch Loss: 237962.5469
# Batch 13/17, Batch Loss: 505795.2812
# Batch 14/17, Batch Loss: 169236.9531
# Batch 15/17, Batch Loss: 177083.3906
# Batch 16/17, Batch Loss: 93958.4922
# Batch 17/17, Batch Loss: 227869.8281
# Test Error:
#  Avg loss: 237132.429688, Avg error: 148369.836073
#
# Epoch 115, Batch 1/49, Batch Loss: 115931.8047
# Epoch 115, Batch 2/49, Batch Loss: 95918.2656
# Epoch 115, Batch 3/49, Batch Loss: 147004.0938
# Epoch 115, Batch 4/49, Batch Loss: 69550.1719
# Epoch 115, Batch 5/49, Batch Loss: 129846.7500
# Epoch 115, Batch 6/49, Batch Loss: 60613.0781
# Epoch 115, Batch 7/49, Batch Loss: 79302.5859
# Epoch 115, Batch 8/49, Batch Loss: 79421.5781
# Epoch 115, Batch 9/49, Batch Loss: 124210.5547
# Epoch 115, Batch 10/49, Batch Loss: 64848.1367
# Epoch 115, Batch 11/49, Batch Loss: 87936.0781
# Epoch 115, Batch 12/49, Batch Loss: 78334.0625
# Epoch 115, Batch 13/49, Batch Loss: 84670.3359
# Epoch 115, Batch 14/49, Batch Loss: 58969.0938
# Epoch 115, Batch 15/49, Batch Loss: 136565.9219
# Epoch 115, Batch 16/49, Batch Loss: 163682.0000
# Epoch 115, Batch 17/49, Batch Loss: 62081.6680
# Epoch 115, Batch 18/49, Batch Loss: 93245.2266
# Epoch 115, Batch 19/49, Batch Loss: 89120.8594
# Epoch 115, Batch 20/49, Batch Loss: 78949.5469
# Epoch 115, Batch 21/49, Batch Loss: 89029.3438
# Epoch 115, Batch 22/49, Batch Loss: 67476.4688
# Epoch 115, Batch 23/49, Batch Loss: 86787.4453
# Epoch 115, Batch 24/49, Batch Loss: 72794.4609
# Epoch 115, Batch 25/49, Batch Loss: 105713.0078
# Epoch 115, Batch 26/49, Batch Loss: 108333.0703
# Epoch 115, Batch 27/49, Batch Loss: 88684.0078
# Epoch 115, Batch 28/49, Batch Loss: 87763.1953
# Epoch 115, Batch 29/49, Batch Loss: 101495.7188
# Epoch 115, Batch 30/49, Batch Loss: 64848.5391
# Epoch 115, Batch 31/49, Batch Loss: 74359.3281
# Epoch 115, Batch 32/49, Batch Loss: 71980.8594
# Epoch 115, Batch 33/49, Batch Loss: 91339.5547
# Epoch 115, Batch 34/49, Batch Loss: 165633.2656
# Epoch 115, Batch 35/49, Batch Loss: 86284.5000
# Epoch 115, Batch 36/49, Batch Loss: 88311.8516
# Epoch 115, Batch 37/49, Batch Loss: 55033.1953
# Epoch 115, Batch 38/49, Batch Loss: 57252.6523
# Epoch 115, Batch 39/49, Batch Loss: 79332.8906
# Epoch 115, Batch 40/49, Batch Loss: 73348.2031
# Epoch 115, Batch 41/49, Batch Loss: 80838.0391
# Epoch 115, Batch 42/49, Batch Loss: 77955.4922
# Epoch 115, Batch 43/49, Batch Loss: 96363.1406
# Epoch 115, Batch 44/49, Batch Loss: 69871.4062
# Epoch 115, Batch 45/49, Batch Loss: 76235.6875
# Epoch 115, Batch 46/49, Batch Loss: 83768.7500
# Epoch 115, Batch 47/49, Batch Loss: 66389.1172
# Epoch 115, Batch 48/49, Batch Loss: 61371.1953
# Epoch 115, Batch 49/49, Batch Loss: 62788.7148
# Batch 1/17, Batch Loss: 301594.2188
# Batch 2/17, Batch Loss: 216052.0938
# Batch 3/17, Batch Loss: 171336.2344
# Batch 4/17, Batch Loss: 294716.6562
# Batch 5/17, Batch Loss: 182819.7031
# Batch 6/17, Batch Loss: 413399.0625
# Batch 7/17, Batch Loss: 241051.1094
# Batch 8/17, Batch Loss: 254021.8281
# Batch 9/17, Batch Loss: 182254.0469
# Batch 10/17, Batch Loss: 146115.1875
# Batch 11/17, Batch Loss: 263116.0938
# Batch 12/17, Batch Loss: 247693.4062
# Batch 13/17, Batch Loss: 521786.7812
# Batch 14/17, Batch Loss: 148938.3438
# Batch 15/17, Batch Loss: 188281.4219
# Batch 16/17, Batch Loss: 103416.0156
# Batch 17/17, Batch Loss: 226843.8750
# Test Error:
#  Avg loss: 241378.592831, Avg error: 155891.956747
#
# Epoch 116, Batch 1/49, Batch Loss: 78806.2500
# Epoch 116, Batch 2/49, Batch Loss: 56314.4102
# Epoch 116, Batch 3/49, Batch Loss: 66425.7812
# Epoch 116, Batch 4/49, Batch Loss: 70250.7344
# Epoch 116, Batch 5/49, Batch Loss: 80175.7812
# Epoch 116, Batch 6/49, Batch Loss: 68338.7500
# Epoch 116, Batch 7/49, Batch Loss: 95423.0625
# Epoch 116, Batch 8/49, Batch Loss: 84732.9453
# Epoch 116, Batch 9/49, Batch Loss: 53358.0781
# Epoch 116, Batch 10/49, Batch Loss: 138269.7969
# Epoch 116, Batch 11/49, Batch Loss: 60023.5000
# Epoch 116, Batch 12/49, Batch Loss: 68437.7656
# Epoch 116, Batch 13/49, Batch Loss: 67604.3516
# Epoch 116, Batch 14/49, Batch Loss: 131592.6250
# Epoch 116, Batch 15/49, Batch Loss: 78344.7656
# Epoch 116, Batch 16/49, Batch Loss: 58095.2617
# Epoch 116, Batch 17/49, Batch Loss: 51163.7422
# Epoch 116, Batch 18/49, Batch Loss: 69851.5078
# Epoch 116, Batch 19/49, Batch Loss: 82177.5000
# Epoch 116, Batch 20/49, Batch Loss: 169662.0625
# Epoch 116, Batch 21/49, Batch Loss: 69997.2031
# Epoch 116, Batch 22/49, Batch Loss: 70905.7109
# Epoch 116, Batch 23/49, Batch Loss: 104107.5781
# Epoch 116, Batch 24/49, Batch Loss: 81677.6562
# Epoch 116, Batch 25/49, Batch Loss: 91057.7891
# Epoch 116, Batch 26/49, Batch Loss: 85683.9531
# Epoch 116, Batch 27/49, Batch Loss: 66712.5156
# Epoch 116, Batch 28/49, Batch Loss: 72971.7344
# Epoch 116, Batch 29/49, Batch Loss: 185174.3594
# Epoch 116, Batch 30/49, Batch Loss: 101649.2500
# Epoch 116, Batch 31/49, Batch Loss: 100244.4531
# Epoch 116, Batch 32/49, Batch Loss: 92461.9297
# Epoch 116, Batch 33/49, Batch Loss: 131341.4688
# Epoch 116, Batch 34/49, Batch Loss: 93198.5703
# Epoch 116, Batch 35/49, Batch Loss: 78360.8750
# Epoch 116, Batch 36/49, Batch Loss: 88021.0000
# Epoch 116, Batch 37/49, Batch Loss: 76413.0469
# Epoch 116, Batch 38/49, Batch Loss: 105193.5156
# Epoch 116, Batch 39/49, Batch Loss: 128381.7656
# Epoch 116, Batch 40/49, Batch Loss: 131568.5625
# Epoch 116, Batch 41/49, Batch Loss: 102482.9219
# Epoch 116, Batch 42/49, Batch Loss: 85040.8672
# Epoch 116, Batch 43/49, Batch Loss: 70839.2734
# Epoch 116, Batch 44/49, Batch Loss: 105708.0391
# Epoch 116, Batch 45/49, Batch Loss: 96036.8672
# Epoch 116, Batch 46/49, Batch Loss: 89456.1797
# Epoch 116, Batch 47/49, Batch Loss: 130658.5625
# Epoch 116, Batch 48/49, Batch Loss: 71524.9922
# Epoch 116, Batch 49/49, Batch Loss: 80259.5469
# Batch 1/17, Batch Loss: 332775.3438
# Batch 2/17, Batch Loss: 251839.4219
# Batch 3/17, Batch Loss: 217419.6875
# Batch 4/17, Batch Loss: 344417.7188
# Batch 5/17, Batch Loss: 231722.3281
# Batch 6/17, Batch Loss: 424650.3438
# Batch 7/17, Batch Loss: 247757.9062
# Batch 8/17, Batch Loss: 305402.1250
# Batch 9/17, Batch Loss: 234757.7188
# Batch 10/17, Batch Loss: 165646.7188
# Batch 11/17, Batch Loss: 302355.4062
# Batch 12/17, Batch Loss: 293573.1562
# Batch 13/17, Batch Loss: 559311.2500
# Batch 14/17, Batch Loss: 197439.3906
# Batch 15/17, Batch Loss: 235794.2812
# Batch 16/17, Batch Loss: 146625.5938
# Batch 17/17, Batch Loss: 300145.3438
# Test Error:
#  Avg loss: 281860.807904, Avg error: 200739.622837
#
# Epoch 117, Batch 1/49, Batch Loss: 99261.0156
# Epoch 117, Batch 2/49, Batch Loss: 78987.5078
# Epoch 117, Batch 3/49, Batch Loss: 126064.0391
# Epoch 117, Batch 4/49, Batch Loss: 92418.5234
# Epoch 117, Batch 5/49, Batch Loss: 56990.3320
# Epoch 117, Batch 6/49, Batch Loss: 67883.5469
# Epoch 117, Batch 7/49, Batch Loss: 85862.9609
# Epoch 117, Batch 8/49, Batch Loss: 74751.7812
# Epoch 117, Batch 9/49, Batch Loss: 100758.4297
# Epoch 117, Batch 10/49, Batch Loss: 72863.0469
# Epoch 117, Batch 11/49, Batch Loss: 83524.4922
# Epoch 117, Batch 12/49, Batch Loss: 77441.4297
# Epoch 117, Batch 13/49, Batch Loss: 68603.2969
# Epoch 117, Batch 14/49, Batch Loss: 68720.5000
# Epoch 117, Batch 15/49, Batch Loss: 73147.9531
# Epoch 117, Batch 16/49, Batch Loss: 58461.9805
# Epoch 117, Batch 17/49, Batch Loss: 94556.7109
# Epoch 117, Batch 18/49, Batch Loss: 67901.7578
# Epoch 117, Batch 19/49, Batch Loss: 108148.3125
# Epoch 117, Batch 20/49, Batch Loss: 99107.2656
# Epoch 117, Batch 21/49, Batch Loss: 171891.1406
# Epoch 117, Batch 22/49, Batch Loss: 98740.6328
# Epoch 117, Batch 23/49, Batch Loss: 142123.0781
# Epoch 117, Batch 24/49, Batch Loss: 118885.5000
# Epoch 117, Batch 25/49, Batch Loss: 89849.3125
# Epoch 117, Batch 26/49, Batch Loss: 50463.6562
# Epoch 117, Batch 27/49, Batch Loss: 72684.0625
# Epoch 117, Batch 28/49, Batch Loss: 67406.6797
# Epoch 117, Batch 29/49, Batch Loss: 82541.1172
# Epoch 117, Batch 30/49, Batch Loss: 101768.5859
# Epoch 117, Batch 31/49, Batch Loss: 74494.0312
# Epoch 117, Batch 32/49, Batch Loss: 73738.1562
# Epoch 117, Batch 33/49, Batch Loss: 74851.6406
# Epoch 117, Batch 34/49, Batch Loss: 160424.9375
# Epoch 117, Batch 35/49, Batch Loss: 71373.0391
# Epoch 117, Batch 36/49, Batch Loss: 83752.9141
# Epoch 117, Batch 37/49, Batch Loss: 198186.3750
# Epoch 117, Batch 38/49, Batch Loss: 62336.9180
# Epoch 117, Batch 39/49, Batch Loss: 71986.0078
# Epoch 117, Batch 40/49, Batch Loss: 99666.0469
# Epoch 117, Batch 41/49, Batch Loss: 81470.3125
# Epoch 117, Batch 42/49, Batch Loss: 80333.0781
# Epoch 117, Batch 43/49, Batch Loss: 74650.1406
# Epoch 117, Batch 44/49, Batch Loss: 54010.2578
# Epoch 117, Batch 45/49, Batch Loss: 63688.7188
# Epoch 117, Batch 46/49, Batch Loss: 71887.6172
# Epoch 117, Batch 47/49, Batch Loss: 82976.2109
# Epoch 117, Batch 48/49, Batch Loss: 80537.3750
# Epoch 117, Batch 49/49, Batch Loss: 66283.1172
# Batch 1/17, Batch Loss: 308675.2188
# Batch 2/17, Batch Loss: 229466.0000
# Batch 3/17, Batch Loss: 166253.5938
# Batch 4/17, Batch Loss: 309079.8125
# Batch 5/17, Batch Loss: 204348.4062
# Batch 6/17, Batch Loss: 414165.1250
# Batch 7/17, Batch Loss: 239710.2656
# Batch 8/17, Batch Loss: 270102.2500
# Batch 9/17, Batch Loss: 196824.8438
# Batch 10/17, Batch Loss: 151420.5156
# Batch 11/17, Batch Loss: 260415.5000
# Batch 12/17, Batch Loss: 263158.7812
# Batch 13/17, Batch Loss: 530566.4375
# Batch 14/17, Batch Loss: 183733.5938
# Batch 15/17, Batch Loss: 205042.7031
# Batch 16/17, Batch Loss: 119546.7734
# Batch 17/17, Batch Loss: 255565.1875
# Test Error:
#  Avg loss: 253416.176930, Avg error: 167061.160035
#
# Epoch 118, Batch 1/49, Batch Loss: 52709.0898
# Epoch 118, Batch 2/49, Batch Loss: 66167.8438
# Epoch 118, Batch 3/49, Batch Loss: 162785.8906
# Epoch 118, Batch 4/49, Batch Loss: 75346.7734
# Epoch 118, Batch 5/49, Batch Loss: 86319.7734
# Epoch 118, Batch 6/49, Batch Loss: 102467.9141
# Epoch 118, Batch 7/49, Batch Loss: 70756.1641
# Epoch 118, Batch 8/49, Batch Loss: 59810.8906
# Epoch 118, Batch 9/49, Batch Loss: 78336.8359
# Epoch 118, Batch 10/49, Batch Loss: 66227.4688
# Epoch 118, Batch 11/49, Batch Loss: 86860.9141
# Epoch 118, Batch 12/49, Batch Loss: 134595.8281
# Epoch 118, Batch 13/49, Batch Loss: 71839.4062
# Epoch 118, Batch 14/49, Batch Loss: 62335.9727
# Epoch 118, Batch 15/49, Batch Loss: 72194.3672
# Epoch 118, Batch 16/49, Batch Loss: 92525.4141
# Epoch 118, Batch 17/49, Batch Loss: 95337.3359
# Epoch 118, Batch 18/49, Batch Loss: 129067.5859
# Epoch 118, Batch 19/49, Batch Loss: 68409.0156
# Epoch 118, Batch 20/49, Batch Loss: 70039.2969
# Epoch 118, Batch 21/49, Batch Loss: 94724.4688
# Epoch 118, Batch 22/49, Batch Loss: 102987.8125
# Epoch 118, Batch 23/49, Batch Loss: 91645.2500
# Epoch 118, Batch 24/49, Batch Loss: 76254.4453
# Epoch 118, Batch 25/49, Batch Loss: 77859.0078
# Epoch 118, Batch 26/49, Batch Loss: 71698.1172
# Epoch 118, Batch 27/49, Batch Loss: 79846.4297
# Epoch 118, Batch 28/49, Batch Loss: 93368.1953
# Epoch 118, Batch 29/49, Batch Loss: 70589.2188
# Epoch 118, Batch 30/49, Batch Loss: 79601.6484
# Epoch 118, Batch 31/49, Batch Loss: 107849.1016
# Epoch 118, Batch 32/49, Batch Loss: 91513.9531
# Epoch 118, Batch 33/49, Batch Loss: 67340.1094
# Epoch 118, Batch 34/49, Batch Loss: 94979.5938
# Epoch 118, Batch 35/49, Batch Loss: 103895.4141
# Epoch 118, Batch 36/49, Batch Loss: 94641.2891
# Epoch 118, Batch 37/49, Batch Loss: 65305.6211
# Epoch 118, Batch 38/49, Batch Loss: 70027.6094
# Epoch 118, Batch 39/49, Batch Loss: 53384.9141
# Epoch 118, Batch 40/49, Batch Loss: 68776.4609
# Epoch 118, Batch 41/49, Batch Loss: 80978.3203
# Epoch 118, Batch 42/49, Batch Loss: 79629.4141
# Epoch 118, Batch 43/49, Batch Loss: 74667.0859
# Epoch 118, Batch 44/49, Batch Loss: 104624.9844
# Epoch 118, Batch 45/49, Batch Loss: 77774.0938
# Epoch 118, Batch 46/49, Batch Loss: 97683.4688
# Epoch 118, Batch 47/49, Batch Loss: 74137.9453
# Epoch 118, Batch 48/49, Batch Loss: 89025.7031
# Epoch 118, Batch 49/49, Batch Loss: 47662.5469
# Batch 1/17, Batch Loss: 287700.3750
# Batch 2/17, Batch Loss: 215976.2500
# Batch 3/17, Batch Loss: 144579.0312
# Batch 4/17, Batch Loss: 295648.1562
# Batch 5/17, Batch Loss: 188176.4219
# Batch 6/17, Batch Loss: 399953.7188
# Batch 7/17, Batch Loss: 243964.3594
# Batch 8/17, Batch Loss: 248069.1719
# Batch 9/17, Batch Loss: 167016.4375
# Batch 10/17, Batch Loss: 153351.0000
# Batch 11/17, Batch Loss: 248294.2969
# Batch 12/17, Batch Loss: 242433.2344
# Batch 13/17, Batch Loss: 503544.2500
# Batch 14/17, Batch Loss: 129448.0391
# Batch 15/17, Batch Loss: 192172.4219
# Batch 16/17, Batch Loss: 95405.5703
# Batch 17/17, Batch Loss: 217760.2500
# Test Error:
#  Avg loss: 233734.881434, Avg error: 146824.298443
#
# Epoch 119, Batch 1/49, Batch Loss: 68554.8125
# Epoch 119, Batch 2/49, Batch Loss: 87779.6719
# Epoch 119, Batch 3/49, Batch Loss: 109867.6797
# Epoch 119, Batch 4/49, Batch Loss: 80683.8125
# Epoch 119, Batch 5/49, Batch Loss: 66164.5781
# Epoch 119, Batch 6/49, Batch Loss: 83782.9375
# Epoch 119, Batch 7/49, Batch Loss: 86093.3125
# Epoch 119, Batch 8/49, Batch Loss: 56068.1797
# Epoch 119, Batch 9/49, Batch Loss: 80527.1016
# Epoch 119, Batch 10/49, Batch Loss: 81932.8438
# Epoch 119, Batch 11/49, Batch Loss: 61030.0352
# Epoch 119, Batch 12/49, Batch Loss: 81003.9219
# Epoch 119, Batch 13/49, Batch Loss: 67639.9844
# Epoch 119, Batch 14/49, Batch Loss: 81765.8984
# Epoch 119, Batch 15/49, Batch Loss: 85495.8906
# Epoch 119, Batch 16/49, Batch Loss: 145055.2344
# Epoch 119, Batch 17/49, Batch Loss: 86884.8203
# Epoch 119, Batch 18/49, Batch Loss: 57686.1523
# Epoch 119, Batch 19/49, Batch Loss: 61500.8008
# Epoch 119, Batch 20/49, Batch Loss: 123350.2500
# Epoch 119, Batch 21/49, Batch Loss: 119005.8672
# Epoch 119, Batch 22/49, Batch Loss: 56553.5117
# Epoch 119, Batch 23/49, Batch Loss: 72028.4453
# Epoch 119, Batch 24/49, Batch Loss: 80942.1406
# Epoch 119, Batch 25/49, Batch Loss: 55939.4336
# Epoch 119, Batch 26/49, Batch Loss: 73445.8750
# Epoch 119, Batch 27/49, Batch Loss: 65315.6680
# Epoch 119, Batch 28/49, Batch Loss: 74793.0078
# Epoch 119, Batch 29/49, Batch Loss: 90459.4062
# Epoch 119, Batch 30/49, Batch Loss: 118229.9062
# Epoch 119, Batch 31/49, Batch Loss: 143674.2188
# Epoch 119, Batch 32/49, Batch Loss: 65681.4844
# Epoch 119, Batch 33/49, Batch Loss: 82178.3984
# Epoch 119, Batch 34/49, Batch Loss: 98799.1172
# Epoch 119, Batch 35/49, Batch Loss: 88399.5938
# Epoch 119, Batch 36/49, Batch Loss: 54390.5547
# Epoch 119, Batch 37/49, Batch Loss: 69988.2578
# Epoch 119, Batch 38/49, Batch Loss: 140875.0781
# Epoch 119, Batch 39/49, Batch Loss: 60544.8555
# Epoch 119, Batch 40/49, Batch Loss: 63689.7656
# Epoch 119, Batch 41/49, Batch Loss: 129125.2891
# Epoch 119, Batch 42/49, Batch Loss: 91722.5625
# Epoch 119, Batch 43/49, Batch Loss: 89947.0078
# Epoch 119, Batch 44/49, Batch Loss: 101689.8828
# ...
# Epoch 170, Batch 44/49, Batch Loss: 77557.1016
# Epoch 170, Batch 45/49, Batch Loss: 78891.2969
# Epoch 170, Batch 46/49, Batch Loss: 55584.0469
# Epoch 170, Batch 47/49, Batch Loss: 56642.2773
# Epoch 170, Batch 48/49, Batch Loss: 56783.8125
# Epoch 170, Batch 49/49, Batch Loss: 83593.0625
# Batch 1/17, Batch Loss: 286370.0000
# Batch 2/17, Batch Loss: 210828.7969
# Batch 3/17, Batch Loss: 179541.1719
# Batch 4/17, Batch Loss: 303221.7188
# Batch 5/17, Batch Loss: 194655.3438
# Batch 6/17, Batch Loss: 395919.0938
# Batch 7/17, Batch Loss: 237023.8750
# Batch 8/17, Batch Loss: 264825.1875
# Batch 9/17, Batch Loss: 197232.1875
# Batch 10/17, Batch Loss: 138934.5938
# Batch 11/17, Batch Loss: 251638.6250
# Batch 12/17, Batch Loss: 260793.7031
# Batch 13/17, Batch Loss: 512523.4062
# Batch 14/17, Batch Loss: 153979.5625
# Batch 15/17, Batch Loss: 182130.4062
# Batch 16/17, Batch Loss: 106829.2891
# Batch 17/17, Batch Loss: 227917.9375
# Test Error:
#  Avg loss: 241433.229320, Avg error: 155713.078287
#
# 2024-10-08 22:49:06.547934 Epoch 170, Average Training loss 74761.13903061225
# Epoch 171, Batch 1/49, Batch Loss: 68384.0625
# Epoch 171, Batch 2/49, Batch Loss: 66022.1875
# Epoch 171, Batch 3/49, Batch Loss: 67437.6797
# Epoch 171, Batch 4/49, Batch Loss: 106077.3438
# Epoch 171, Batch 5/49, Batch Loss: 79292.4609
# Epoch 171, Batch 6/49, Batch Loss: 56806.2305
# Epoch 171, Batch 7/49, Batch Loss: 56745.5625
# Epoch 171, Batch 8/49, Batch Loss: 93332.1016
# Epoch 171, Batch 9/49, Batch Loss: 61898.9844
# Epoch 171, Batch 10/49, Batch Loss: 48662.2969
# Epoch 171, Batch 11/49, Batch Loss: 66010.8047
# Epoch 171, Batch 12/49, Batch Loss: 79478.7188
# Epoch 171, Batch 13/49, Batch Loss: 54809.3945
# Epoch 171, Batch 14/49, Batch Loss: 56931.3008
# Epoch 171, Batch 15/49, Batch Loss: 93469.4453
# Epoch 171, Batch 16/49, Batch Loss: 71416.9609
# Epoch 171, Batch 17/49, Batch Loss: 140397.1094
# Epoch 171, Batch 18/49, Batch Loss: 71430.7500
# Epoch 171, Batch 19/49, Batch Loss: 59534.1055
# Epoch 171, Batch 20/49, Batch Loss: 55089.0664
# Epoch 171, Batch 21/49, Batch Loss: 118123.7031
# Epoch 171, Batch 22/49, Batch Loss: 58122.0469
# Epoch 171, Batch 23/49, Batch Loss: 70875.5156
# Epoch 171, Batch 24/49, Batch Loss: 54598.0977
# Epoch 171, Batch 25/49, Batch Loss: 72335.9219
# Epoch 171, Batch 26/49, Batch Loss: 70032.9766
# Epoch 171, Batch 27/49, Batch Loss: 64602.4531
# Epoch 171, Batch 28/49, Batch Loss: 64522.2891
# Epoch 171, Batch 29/49, Batch Loss: 62220.0078
# Epoch 171, Batch 30/49, Batch Loss: 69026.0000
# Epoch 171, Batch 31/49, Batch Loss: 72028.3047
# Epoch 171, Batch 32/49, Batch Loss: 58638.5820
# Epoch 171, Batch 33/49, Batch Loss: 57531.3125
# Epoch 171, Batch 34/49, Batch Loss: 49195.0156
# Epoch 171, Batch 35/49, Batch Loss: 64717.7305
# Epoch 171, Batch 36/49, Batch Loss: 63881.0352
# Epoch 171, Batch 37/49, Batch Loss: 48146.9844
# Epoch 171, Batch 38/49, Batch Loss: 70817.4375
# Epoch 171, Batch 39/49, Batch Loss: 58987.7773
# Epoch 171, Batch 40/49, Batch Loss: 84105.2500
# Epoch 171, Batch 41/49, Batch Loss: 60286.9180
# Epoch 171, Batch 42/49, Batch Loss: 61691.7852
# Epoch 171, Batch 43/49, Batch Loss: 77256.8516
# Epoch 171, Batch 44/49, Batch Loss: 62995.1953
# Epoch 171, Batch 45/49, Batch Loss: 67604.9062
# Epoch 171, Batch 46/49, Batch Loss: 68018.4609
# Epoch 171, Batch 47/49, Batch Loss: 68274.2500
# Epoch 171, Batch 48/49, Batch Loss: 67752.8047
# Epoch 171, Batch 49/49, Batch Loss: 54211.0156
# Batch 1/17, Batch Loss: 306893.6875
# Batch 2/17, Batch Loss: 226751.8125
# Batch 3/17, Batch Loss: 188772.8125
# Batch 4/17, Batch Loss: 337654.4062
# Batch 5/17, Batch Loss: 213256.6094
# Batch 6/17, Batch Loss: 398860.8125
# Batch 7/17, Batch Loss: 239971.1250
# Batch 8/17, Batch Loss: 277949.3125
# Batch 9/17, Batch Loss: 209704.6250
# Batch 10/17, Batch Loss: 157756.7500
# Batch 11/17, Batch Loss: 264689.0938
# Batch 12/17, Batch Loss: 284776.9062
# Batch 13/17, Batch Loss: 530642.4375
# Batch 14/17, Batch Loss: 192668.2500
# Batch 15/17, Batch Loss: 211748.1875
# Batch 16/17, Batch Loss: 123169.2500
# Batch 17/17, Batch Loss: 261467.7500
# Test Error:
#  Avg loss: 260396.107537, Avg error: 176546.961938
#
# Epoch 172, Batch 1/49, Batch Loss: 60786.6484
# Epoch 172, Batch 2/49, Batch Loss: 55193.5430
# Epoch 172, Batch 3/49, Batch Loss: 65870.0156
# Epoch 172, Batch 4/49, Batch Loss: 66006.5234
# Epoch 172, Batch 5/49, Batch Loss: 68292.0391
# Epoch 172, Batch 6/49, Batch Loss: 48645.8398
# Epoch 172, Batch 7/49, Batch Loss: 95810.0859
# Epoch 172, Batch 8/49, Batch Loss: 52198.3984
# Epoch 172, Batch 9/49, Batch Loss: 136613.7812
# Epoch 172, Batch 10/49, Batch Loss: 78023.4922
# Epoch 172, Batch 11/49, Batch Loss: 58445.3281
# Epoch 172, Batch 12/49, Batch Loss: 51080.0391
# Epoch 172, Batch 13/49, Batch Loss: 101513.2891
# Epoch 172, Batch 14/49, Batch Loss: 104588.0703
# Epoch 172, Batch 15/49, Batch Loss: 85444.0781
# Epoch 172, Batch 16/49, Batch Loss: 54517.8789
# Epoch 172, Batch 17/49, Batch Loss: 107446.4062
# Epoch 172, Batch 18/49, Batch Loss: 71433.3516
# Epoch 172, Batch 19/49, Batch Loss: 79082.3203
# Epoch 172, Batch 20/49, Batch Loss: 93702.7422
# Epoch 172, Batch 21/49, Batch Loss: 60102.0469
# Epoch 172, Batch 22/49, Batch Loss: 51013.9648
# Epoch 172, Batch 23/49, Batch Loss: 59804.2070
# Epoch 172, Batch 24/49, Batch Loss: 71139.2344
# Epoch 172, Batch 25/49, Batch Loss: 71670.9922
# Epoch 172, Batch 26/49, Batch Loss: 68131.3281
# Epoch 172, Batch 27/49, Batch Loss: 64005.8242
# Epoch 172, Batch 28/49, Batch Loss: 67323.5234
# Epoch 172, Batch 29/49, Batch Loss: 82563.5469
# Epoch 172, Batch 30/49, Batch Loss: 71504.0625
# Epoch 172, Batch 31/49, Batch Loss: 63633.6484
# Epoch 172, Batch 32/49, Batch Loss: 128123.7969
# Epoch 172, Batch 33/49, Batch Loss: 79772.3750
# Epoch 172, Batch 34/49, Batch Loss: 70076.8438
# Epoch 172, Batch 35/49, Batch Loss: 69626.7188
# Epoch 172, Batch 36/49, Batch Loss: 101202.4141
# Epoch 172, Batch 37/49, Batch Loss: 81758.9844
# Epoch 172, Batch 38/49, Batch Loss: 81497.3594
# Epoch 172, Batch 39/49, Batch Loss: 71129.3438
# Epoch 172, Batch 40/49, Batch Loss: 69952.1562
# Epoch 172, Batch 41/49, Batch Loss: 66582.4609
# Epoch 172, Batch 42/49, Batch Loss: 50090.5078
# Epoch 172, Batch 43/49, Batch Loss: 48156.7852
# Epoch 172, Batch 44/49, Batch Loss: 84672.9219
# Epoch 172, Batch 45/49, Batch Loss: 68385.8359
# Epoch 172, Batch 46/49, Batch Loss: 74649.7891
# Epoch 172, Batch 47/49, Batch Loss: 133447.5938
# Epoch 172, Batch 48/49, Batch Loss: 75164.1797
# Epoch 172, Batch 49/49, Batch Loss: 67147.3203
# Batch 1/17, Batch Loss: 282605.4062
# Batch 2/17, Batch Loss: 217597.9531
# Batch 3/17, Batch Loss: 159524.1250
# Batch 4/17, Batch Loss: 321971.1562
# Batch 5/17, Batch Loss: 189642.5469
# Batch 6/17, Batch Loss: 389367.1562
# Batch 7/17, Batch Loss: 234644.0469
# Batch 8/17, Batch Loss: 264169.7500
# Batch 9/17, Batch Loss: 195598.4531
# Batch 10/17, Batch Loss: 135108.9375
# Batch 11/17, Batch Loss: 257617.1875
# Batch 12/17, Batch Loss: 263675.3438
# Batch 13/17, Batch Loss: 522742.9375
# Batch 14/17, Batch Loss: 156301.7031
# Batch 15/17, Batch Loss: 192954.9688
# Batch 16/17, Batch Loss: 118625.8594
# Batch 17/17, Batch Loss: 236160.3438
# Test Error:
#  Avg loss: 243429.875000, Avg error: 158931.007785
#
# Epoch 173, Batch 1/49, Batch Loss: 59276.1523
# Epoch 173, Batch 2/49, Batch Loss: 64988.6328
# Epoch 173, Batch 3/49, Batch Loss: 76543.7422
# Epoch 173, Batch 4/49, Batch Loss: 108506.8516
# Epoch 173, Batch 5/49, Batch Loss: 66198.9688
# Epoch 173, Batch 6/49, Batch Loss: 68809.5625
# Epoch 173, Batch 7/49, Batch Loss: 64907.9688
# Epoch 173, Batch 8/49, Batch Loss: 68306.1406
# Epoch 173, Batch 9/49, Batch Loss: 86986.5000
# Epoch 173, Batch 10/49, Batch Loss: 59573.6875
# Epoch 173, Batch 11/49, Batch Loss: 70081.4844
# Epoch 173, Batch 12/49, Batch Loss: 66595.9844
# Epoch 173, Batch 13/49, Batch Loss: 58168.5117
# Epoch 173, Batch 14/49, Batch Loss: 59883.8047
# Epoch 173, Batch 15/49, Batch Loss: 71574.3125
# Epoch 173, Batch 16/49, Batch Loss: 82304.1875
# Epoch 173, Batch 17/49, Batch Loss: 72230.8906
# Epoch 173, Batch 18/49, Batch Loss: 56809.7617
# Epoch 173, Batch 19/49, Batch Loss: 73637.6016
# Epoch 173, Batch 20/49, Batch Loss: 78315.0859
# Epoch 173, Batch 21/49, Batch Loss: 71048.7031
# Epoch 173, Batch 22/49, Batch Loss: 64792.5430
# Epoch 173, Batch 23/49, Batch Loss: 51217.2305
# Epoch 173, Batch 24/49, Batch Loss: 93802.1641
# Epoch 173, Batch 25/49, Batch Loss: 79368.3828
# Epoch 173, Batch 26/49, Batch Loss: 90578.3516
# Epoch 173, Batch 27/49, Batch Loss: 80063.5625
# Epoch 173, Batch 28/49, Batch Loss: 119947.7109
# Epoch 173, Batch 29/49, Batch Loss: 69721.4062
# Epoch 173, Batch 30/49, Batch Loss: 70303.6328
# Epoch 173, Batch 31/49, Batch Loss: 63281.0938
# Epoch 173, Batch 32/49, Batch Loss: 65318.6680
# Epoch 173, Batch 33/49, Batch Loss: 64626.9727
# Epoch 173, Batch 34/49, Batch Loss: 79533.6719
# Epoch 173, Batch 35/49, Batch Loss: 59389.4219
# Epoch 173, Batch 36/49, Batch Loss: 120105.7969
# Epoch 173, Batch 37/49, Batch Loss: 78896.3125
# Epoch 173, Batch 38/49, Batch Loss: 121335.6562
# Epoch 173, Batch 39/49, Batch Loss: 68703.5469
# Epoch 173, Batch 40/49, Batch Loss: 76920.1797
# Epoch 173, Batch 41/49, Batch Loss: 80832.5625
# Epoch 173, Batch 42/49, Batch Loss: 94329.6172
# Epoch 173, Batch 43/49, Batch Loss: 71121.8203
# Epoch 173, Batch 44/49, Batch Loss: 94302.5859
# Epoch 173, Batch 45/49, Batch Loss: 64683.1094
# Epoch 173, Batch 46/49, Batch Loss: 62356.2891
# Epoch 173, Batch 47/49, Batch Loss: 90625.2266
# Epoch 173, Batch 48/49, Batch Loss: 67751.8906
# Epoch 173, Batch 49/49, Batch Loss: 71422.8203
# Batch 1/17, Batch Loss: 288358.0000
# Batch 2/17, Batch Loss: 223496.3906
# Batch 3/17, Batch Loss: 159348.5938
# Batch 4/17, Batch Loss: 315222.5625
# Batch 5/17, Batch Loss: 195238.7812
# Batch 6/17, Batch Loss: 392873.0000
# Batch 7/17, Batch Loss: 232804.3438
# Batch 8/17, Batch Loss: 263856.6562
# Batch 9/17, Batch Loss: 197258.5000
# Batch 10/17, Batch Loss: 147660.6094
# Batch 11/17, Batch Loss: 265212.6875
# Batch 12/17, Batch Loss: 263681.1875
# Batch 13/17, Batch Loss: 516847.1250
# Batch 14/17, Batch Loss: 217019.6406
# Batch 15/17, Batch Loss: 180987.3125
# Batch 16/17, Batch Loss: 109243.4609
# Batch 17/17, Batch Loss: 241014.9219
# Test Error:
#  Avg loss: 247654.339614, Avg error: 162299.851644
#
# Epoch 174, Batch 1/49, Batch Loss: 62852.5117
# Epoch 174, Batch 2/49, Batch Loss: 44246.9766
# Epoch 174, Batch 3/49, Batch Loss: 49918.1484
# Epoch 174, Batch 4/49, Batch Loss: 50488.0000
# Epoch 174, Batch 5/49, Batch Loss: 58577.4219
# Epoch 174, Batch 6/49, Batch Loss: 56968.2070
# Epoch 174, Batch 7/49, Batch Loss: 79908.3672
# Epoch 174, Batch 8/49, Batch Loss: 66737.4922
# Epoch 174, Batch 9/49, Batch Loss: 59657.6016
# Epoch 174, Batch 10/49, Batch Loss: 73358.0703
# Epoch 174, Batch 11/49, Batch Loss: 62887.9453
# Epoch 174, Batch 12/49, Batch Loss: 61135.8320
# Epoch 174, Batch 13/49, Batch Loss: 59653.8477
# Epoch 174, Batch 14/49, Batch Loss: 70019.6875
# Epoch 174, Batch 15/49, Batch Loss: 73279.0234
# Epoch 174, Batch 16/49, Batch Loss: 55064.8828
# Epoch 174, Batch 17/49, Batch Loss: 73581.5078
# Epoch 174, Batch 18/49, Batch Loss: 78458.5703
# Epoch 174, Batch 19/49, Batch Loss: 97525.2031
# Epoch 174, Batch 20/49, Batch Loss: 54645.5664
# Epoch 174, Batch 21/49, Batch Loss: 70914.1875
# Epoch 174, Batch 22/49, Batch Loss: 63720.7305
# Epoch 174, Batch 23/49, Batch Loss: 51582.4570
# Epoch 174, Batch 24/49, Batch Loss: 67946.1641
# Epoch 174, Batch 25/49, Batch Loss: 75473.7266
# Epoch 174, Batch 26/49, Batch Loss: 82210.1719
# Epoch 174, Batch 27/49, Batch Loss: 44681.6094
# Epoch 174, Batch 28/49, Batch Loss: 59706.3789
# Epoch 174, Batch 29/49, Batch Loss: 67286.4297
# Epoch 174, Batch 30/49, Batch Loss: 75579.2266
# Epoch 174, Batch 31/49, Batch Loss: 89569.9844
# Epoch 174, Batch 32/49, Batch Loss: 67922.0156
# Epoch 174, Batch 33/49, Batch Loss: 56300.9492
# Epoch 174, Batch 34/49, Batch Loss: 80669.5156
# Epoch 174, Batch 35/49, Batch Loss: 103051.6484
# Epoch 174, Batch 36/49, Batch Loss: 64348.1094
# Epoch 174, Batch 37/49, Batch Loss: 101975.6172
# Epoch 174, Batch 38/49, Batch Loss: 55419.2422
# Epoch 174, Batch 39/49, Batch Loss: 94863.6484
# Epoch 174, Batch 40/49, Batch Loss: 105574.2422
# Epoch 174, Batch 41/49, Batch Loss: 63205.2773
# Epoch 174, Batch 42/49, Batch Loss: 95873.4297
# Epoch 174, Batch 43/49, Batch Loss: 61908.4375
# Epoch 174, Batch 44/49, Batch Loss: 77075.6797
# Epoch 174, Batch 45/49, Batch Loss: 154046.0781
# Epoch 174, Batch 46/49, Batch Loss: 87165.6641
# Epoch 174, Batch 47/49, Batch Loss: 60184.9258
# Epoch 174, Batch 48/49, Batch Loss: 81539.3438
# Epoch 174, Batch 49/49, Batch Loss: 96322.0547
# Batch 1/17, Batch Loss: 293904.7812
# Batch 2/17, Batch Loss: 221118.2344
# Batch 3/17, Batch Loss: 196098.7188
# Batch 4/17, Batch Loss: 345800.2188
# Batch 5/17, Batch Loss: 208581.4219
# Batch 6/17, Batch Loss: 401649.1250
# Batch 7/17, Batch Loss: 231583.3906
# Batch 8/17, Batch Loss: 277817.4062
# Batch 9/17, Batch Loss: 224399.5469
# Batch 10/17, Batch Loss: 131695.8438
# Batch 11/17, Batch Loss: 272095.7188
# Batch 12/17, Batch Loss: 293734.3125
# Batch 13/17, Batch Loss: 543184.3750
# Batch 14/17, Batch Loss: 220856.6719
# Batch 15/17, Batch Loss: 213341.7031
# Batch 16/17, Batch Loss: 121352.6172
# Batch 17/17, Batch Loss: 257808.7188
# Test Error:
#  Avg loss: 262060.164982, Avg error: 179015.303633
#
# Epoch 175, Batch 1/49, Batch Loss: 79725.6328
# Epoch 175, Batch 2/49, Batch Loss: 44459.1797
# Epoch 175, Batch 3/49, Batch Loss: 47613.5430
# Epoch 175, Batch 4/49, Batch Loss: 54769.4141
# Epoch 175, Batch 5/49, Batch Loss: 70970.1094
# Epoch 175, Batch 6/49, Batch Loss: 59388.5820
# Epoch 175, Batch 7/49, Batch Loss: 61769.9375
# Epoch 175, Batch 8/49, Batch Loss: 75451.7656
# Epoch 175, Batch 9/49, Batch Loss: 57820.6445
# Epoch 175, Batch 10/49, Batch Loss: 54131.6680
# Epoch 175, Batch 11/49, Batch Loss: 105055.8359
# Epoch 175, Batch 12/49, Batch Loss: 68824.3828
# Epoch 175, Batch 13/49, Batch Loss: 90599.7734
# Epoch 175, Batch 14/49, Batch Loss: 69514.9688
# Epoch 175, Batch 15/49, Batch Loss: 70761.7344
# Epoch 175, Batch 16/49, Batch Loss: 48413.4141
# Epoch 175, Batch 17/49, Batch Loss: 64986.6094
# Epoch 175, Batch 18/49, Batch Loss: 75349.7500
# Epoch 175, Batch 19/49, Batch Loss: 58167.9609
# Epoch 175, Batch 20/49, Batch Loss: 76533.5234
# Epoch 175, Batch 21/49, Batch Loss: 67903.9375
# Epoch 175, Batch 22/49, Batch Loss: 69777.9922
# Epoch 175, Batch 23/49, Batch Loss: 60692.5625
# Epoch 175, Batch 24/49, Batch Loss: 106186.2500
# Epoch 175, Batch 25/49, Batch Loss: 63326.7109
# Epoch 175, Batch 26/49, Batch Loss: 65478.4375
# Epoch 175, Batch 27/49, Batch Loss: 48149.2227
# Epoch 175, Batch 28/49, Batch Loss: 61129.5469
# Epoch 175, Batch 29/49, Batch Loss: 56027.6289
# Epoch 175, Batch 30/49, Batch Loss: 64959.0469
# Epoch 175, Batch 31/49, Batch Loss: 73988.3828
# Epoch 175, Batch 32/49, Batch Loss: 75051.2891
# Epoch 175, Batch 33/49, Batch Loss: 53178.9375
# Epoch 175, Batch 34/49, Batch Loss: 63334.8828
# Epoch 175, Batch 35/49, Batch Loss: 87531.9688
# Epoch 175, Batch 36/49, Batch Loss: 87302.3281
# Epoch 175, Batch 37/49, Batch Loss: 73777.6953
# Epoch 175, Batch 38/49, Batch Loss: 72653.6562
# Epoch 175, Batch 39/49, Batch Loss: 73551.5156
# Epoch 175, Batch 40/49, Batch Loss: 127023.7344
# Epoch 175, Batch 41/49, Batch Loss: 85484.3047
# Epoch 175, Batch 42/49, Batch Loss: 137515.3438
# Epoch 175, Batch 43/49, Batch Loss: 73962.0156
# Epoch 175, Batch 44/49, Batch Loss: 59078.2383
# Epoch 175, Batch 45/49, Batch Loss: 51033.2812
# Epoch 175, Batch 46/49, Batch Loss: 55579.7812
# Epoch 175, Batch 47/49, Batch Loss: 79831.6250
# Epoch 175, Batch 48/49, Batch Loss: 69643.5781
# Epoch 175, Batch 49/49, Batch Loss: 86240.2188
# Batch 1/17, Batch Loss: 289994.9062
# Batch 2/17, Batch Loss: 221473.7969
# Batch 3/17, Batch Loss: 155181.3594
# Batch 4/17, Batch Loss: 309806.1562
# Batch 5/17, Batch Loss: 197950.3281
# Batch 6/17, Batch Loss: 404315.9688
# Batch 7/17, Batch Loss: 240813.6719
# Batch 8/17, Batch Loss: 273231.6250
# Batch 9/17, Batch Loss: 190850.3438
# Batch 10/17, Batch Loss: 136328.6406
# Batch 11/17, Batch Loss: 249738.9844
# Batch 12/17, Batch Loss: 266498.8750
# Batch 13/17, Batch Loss: 521728.8438
# Batch 14/17, Batch Loss: 146918.9531
# Batch 15/17, Batch Loss: 181061.1250
# Batch 16/17, Batch Loss: 111461.9922
# Batch 17/17, Batch Loss: 250581.9375
# Test Error:
#  Avg loss: 243996.323989, Avg error: 159332.157007

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        2.5         3  1915    92021      117.png   485000
# 1        2.5         3  2248    92677      132.png  1199000
# 2        1.0         3  1132    96019      154.png   170000
# 3        4.0         6  3375    92880      245.png   538000
# 4        2.5         3  2733    91901       84.png   689000

# %%
len(test)
# Out:
# 54

# %%
# Crear dataset
test_data = CustomImageDataset(df=test)

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
len(test_loader)
# Out:
# 6

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 363031.15625, Valor real: 485000.0
# Predicción: 321519.03125, Valor real: 1199000.0
# Predicción: 120499.171875, Valor real: 170000.0
# Predicción: 433430.78125, Valor real: 538000.0
# Predicción: 455020.28125, Valor real: 689000.0
# Predicción: 157800.84375, Valor real: 118900.0
# Predicción: 542409.75, Valor real: 799000.0
# Predicción: 401018.3125, Valor real: 895000.0
# Predicción: 347858.65625, Valor real: 599000.0
# Predicción: 402020.84375, Valor real: 535000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 384051.2812
# MAE en el conjunto de prueba: 246846.5781

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
