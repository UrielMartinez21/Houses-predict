# %%
"""
Cambios en la arquitectura de la red neuronal convolucional

    - Valor de funcion de regularizacion L2 a 0.01
    - Se añadio resnet50 como base de la red
    - Se agrego funcion para guardar el mejor modelo
    - Se quito un data por repeticion
    - Funcion de decaimiento 10e6
    - dropout con valor de 0.2
"""
# Out:
# '\nCambios en la arquitectura de la red neuronal convolucional\n\n    - Valor de funcion de regularizacion L2 a 0.01\n    - Se añadio resnet50 como base de la red\n    - Se agrego funcion para guardar el mejor modelo\n    - Se quito un data por repeticion\n    - Funcion de decaimiento 10e6\n    - dropout con valor de 0.2\n'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler
from PIL import Image

# %%
seed = 21
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# --> Definir si viene desde local o drive

# ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
ruta = '../Dataset/Mosaico/'

ruta_modelo = '../models/'
nombre_modelo = 'model_resnet50_l2_lambda5.pth'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')
train.head()
# Out:
#    bedrooms  bathrooms  area  zipcode mosaic_image    price
# 0         2        1.0  1184    91901       82.png   397500
# 1         2        2.0  1248    93446      471.png   175000
# 2         5        4.0  4190    85255       18.png  1199000
# 3         2        2.0  1152    92276      352.png    99900
# 4         2        1.0  1000    92276      416.png    67000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """Devuelve el número de muestras en el dataset."""
        return len(self.df)

    def __getitem__(self, idx):
        """
        Obtiene una muestra del dataset en el índice `idx`.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen utilizando PIL.Image.open para que las transformaciones funcionen correctamente.
        mosaic_image = Image.open(f"{ruta}Imagenes/{img_path}").convert("RGB")

        # Obtener los valores de las características numéricas para la muestra actual.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización con los valores de ImageNet
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 1 para matplotlib
    image_tensor = torch.clamp(image_tensor, 0, 1)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image)  # Mostrar sin conversión a uint8 porque los valores están en rango [0, 1]
    if title:
        plt.title(title)
    plt.axis('off')  # Quitar los ejes
    plt.show()

# %%
from torchvision import models

class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()

        # Cargar el modelo preentrenado ResNet50
        self.image_features_ = models.resnet50(pretrained=True)

        # Eliminar la última capa de clasificación (fully connected) de ResNet50
        self.image_features_ = nn.Sequential(*list(self.image_features_.children())[:-1])

        # Procesamiento de las características numéricas (4 características)
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),   # Aquí usas 4 datos numéricos
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )

        # Capa final que combina las características visuales y numéricas
        self.combined_features_ = nn.Sequential(
            nn.Linear(2048 + 64*3*3, 64*3*3*2*2),  # 2048 provienen de ResNet50 + numéricas
            nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),
            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),  # Predicción final
        )

    def forward(self, x, y):
        # Pasar las imágenes por ResNet50 para obtener las características visuales
        x = self.image_features_(x)
        # print(x.shape)
        x = x.view(x.size(0), -1)
        # print(x.shape)

        # Pasar las características numéricas por la red densa
        y = self.numeric_features_(y)

        # Combinar características visuales y numéricas
        z = torch.cat((x, y), dim=1)
        # print(z.shape)

        # Pasar las características combinadas por las capas finales
        z = self.combined_features_(z)

        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            #print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    #print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []
    prev_loss = 0

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            l2_lambda = 0.01
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            #print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)
        #print(f"Epoch {epoch}, Epoch Loss: {loss_train:.4f}")

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        # Verificar si la pérdida de validación disminuye
        if epoch == 1:
            prev_loss = val_loss
        else:
            if val_loss < prev_loss:
                # Guardar el modelo si la pérdida de validación disminuye
                torch.save(model, f"{ruta_modelo}model_resnet50_l2_lambda5.pth")
                prev_loss = val_loss
                print(f"Modelo guardado en epoch {epoch} con loss {val_loss}".center(100, '='))

        # Imprimir la pérdida promedio en cada epoch
        print(f'[+]Epoch {epoch} - Av.Training loss {loss_train} - Av.Validation loss {val_loss}')
        # print(f'\t[+]Epoch {epoch}, Av.Validation loss {val_loss}')
    #print(prev_loss)
    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones adicionales
# data1 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(256),                               # Redimensionar a 256x256
#     transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
#     transforms.ToTensor(),                                # Convertir la imagen a un tensor
#     transforms.Normalize(
#         (0.485, 0.456, 0.406),                            # Media de ImageNet
#         (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
#     )
# ]))

# Dataset con transformación de normalización para ResNet50
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Resize(256),                               # Redimensionar a 256x256
    transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
    transforms.ToTensor(),                                # Convertir la imagen a un tensor
    transforms.Normalize(
        (0.485, 0.456, 0.406),                            # Media de ImageNet
        (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
    )
]))

# Dataset con desplazamiento de canales (RGB a BGR) y normalización para ResNet50
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Resize(256),                               # Redimensionar a 256x256
    transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
    transforms.ToTensor(),                                # Convertir la imagen a un tensor
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),  # Cambiar los canales RGB a BGR (se aplica después de ToTensor)
    transforms.Normalize(
        (0.485, 0.456, 0.406),                            # Media de ImageNet
        (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
    )
]))

# Dataset con volteo horizontal y normalización para ResNet50
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.8),               # Volteo horizontal con una probabilidad de 80%
    transforms.Resize(256),                               # Redimensionar a 256x256
    transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
    transforms.ToTensor(),                                # Convertir la imagen a un tensor
    transforms.Normalize(
        (0.485, 0.456, 0.406),                            # Media de ImageNet
        (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
    )
]))

# Dataset con volteo vertical y normalización para ResNet50
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=0.8),                 # Volteo vertical con una probabilidad de 80%
    transforms.Resize(256),                               # Redimensionar a 256x256
    transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
    transforms.ToTensor(),                                # Convertir la imagen a un tensor
    transforms.Normalize(
        (0.485, 0.456, 0.406),                            # Media de ImageNet
        (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
    )
]))

# Dataset con desenfoque gaussiano y normalización para ResNet50
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Resize(256),                               # Redimensionar a 256x256
    transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
    transforms.ToTensor(),                                # Convertir la imagen a un tensor
    transforms.Normalize(
        (0.485, 0.456, 0.406),                            # Media de ImageNet
        (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 1813 Val: 202

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data2, data3, data4, data5, data6

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
# optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-6)
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda
# c:\Users\Lab.Comp 1\Desktop\Uriel-TT\houses-prediction\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Lab.Comp 1\Desktop\Uriel-TT\houses-prediction\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# --> Crear los dataloaders
batch_size_train = 32
batch_size_val = 32

train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 1813 - Baches 57
# Muestras de test: 202 - Baches 7

# %%
# Entrenamiento
n_epochs = 500
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# [+]Epoch 1 - Av.Training loss 416784.3083881579 - Av.Validation loss 354794.45535714284
# =======================Modelo guardado en epoch 2 con loss 302801.65178571426=======================
# [+]Epoch 2 - Av.Training loss 227719.24095394736 - Av.Validation loss 302801.65178571426
# =========================Modelo guardado en epoch 3 con loss 263823.796875==========================
# [+]Epoch 3 - Av.Training loss 196172.4610745614 - Av.Validation loss 263823.796875
# =======================Modelo guardado en epoch 4 con loss 263171.34151785716=======================
# [+]Epoch 4 - Av.Training loss 173566.2347861842 - Av.Validation loss 263171.34151785716
# =======================Modelo guardado en epoch 5 con loss 154431.56473214287=======================
# [+]Epoch 5 - Av.Training loss 147202.17434210525 - Av.Validation loss 154431.56473214287
# [+]Epoch 6 - Av.Training loss 127287.67502741228 - Av.Validation loss 203970.21205357142
# =======================Modelo guardado en epoch 7 con loss 142818.0189732143========================
# [+]Epoch 7 - Av.Training loss 118735.18818530702 - Av.Validation loss 142818.0189732143
# =======================Modelo guardado en epoch 8 con loss 131026.19084821429=======================
# [+]Epoch 8 - Av.Training loss 113737.85677083333 - Av.Validation loss 131026.19084821429
# [+]Epoch 9 - Av.Training loss 102593.01493969298 - Av.Validation loss 131118.24776785713
# [+]Epoch 10 - Av.Training loss 96295.62815241228 - Av.Validation loss 189283.8236607143
# ======================Modelo guardado en epoch 11 con loss 127112.63058035714=======================
# [+]Epoch 11 - Av.Training loss 101758.20805921052 - Av.Validation loss 127112.63058035714
# [+]Epoch 12 - Av.Training loss 85726.00082236843 - Av.Validation loss 165760.59263392858
# [+]Epoch 13 - Av.Training loss 88753.11855811403 - Av.Validation loss 129780.58928571429
# ======================Modelo guardado en epoch 14 con loss 121462.62276785714=======================
# [+]Epoch 14 - Av.Training loss 84339.47135416667 - Av.Validation loss 121462.62276785714
# ========================Modelo guardado en epoch 15 con loss 112178.90234375========================
# [+]Epoch 15 - Av.Training loss 87019.07250548246 - Av.Validation loss 112178.90234375
# [+]Epoch 16 - Av.Training loss 79200.75027412281 - Av.Validation loss 112243.30915178571
# ======================Modelo guardado en epoch 17 con loss 102037.74888392857=======================
# [+]Epoch 17 - Av.Training loss 82601.67687774122 - Av.Validation loss 102037.74888392857
# [+]Epoch 18 - Av.Training loss 74845.34971217105 - Av.Validation loss 110148.90848214286
# [+]Epoch 19 - Av.Training loss 75687.30715460527 - Av.Validation loss 108315.31138392857
# [+]Epoch 20 - Av.Training loss 71709.42098410087 - Av.Validation loss 109984.45424107143
# [+]Epoch 21 - Av.Training loss 70795.23351836622 - Av.Validation loss 117326.19642857143
# [+]Epoch 22 - Av.Training loss 66841.18105811403 - Av.Validation loss 151205.7845982143
# [+]Epoch 23 - Av.Training loss 75455.98985745614 - Av.Validation loss 151035.10267857142
# [+]Epoch 24 - Av.Training loss 65229.96203399123 - Av.Validation loss 109299.74107142857
# [+]Epoch 25 - Av.Training loss 63729.09347587719 - Av.Validation loss 113717.14174107143
# [+]Epoch 26 - Av.Training loss 71460.43777412281 - Av.Validation loss 102421.49051339286
# [+]Epoch 27 - Av.Training loss 83615.62650767544 - Av.Validation loss 126650.26339285714
# ======================Modelo guardado en epoch 28 con loss 100371.19475446429=======================
# [+]Epoch 28 - Av.Training loss 63574.809073464916 - Av.Validation loss 100371.19475446429
# [+]Epoch 29 - Av.Training loss 64892.90063048246 - Av.Validation loss 106443.52901785714
# [+]Epoch 30 - Av.Training loss 64745.462719298244 - Av.Validation loss 109119.921875
# =======================Modelo guardado en epoch 31 con loss 95473.29073660714=======================
# [+]Epoch 31 - Av.Training loss 59535.72539747807 - Av.Validation loss 95473.29073660714
# [+]Epoch 32 - Av.Training loss 58745.92495888158 - Av.Validation loss 109724.54296875
# [+]Epoch 33 - Av.Training loss 66932.1290433114 - Av.Validation loss 161492.18861607142
# [+]Epoch 34 - Av.Training loss 62990.05770285088 - Av.Validation loss 105185.28794642857
# [+]Epoch 35 - Av.Training loss 65176.14398300439 - Av.Validation loss 112807.32477678571
# [+]Epoch 36 - Av.Training loss 60747.43983004386 - Av.Validation loss 99871.78738839286
# [+]Epoch 37 - Av.Training loss 64234.33908991228 - Av.Validation loss 117525.83816964286
# [+]Epoch 38 - Av.Training loss 71736.43205180921 - Av.Validation loss 111409.4453125
# =======================Modelo guardado en epoch 39 con loss 89067.90290178571=======================
# [+]Epoch 39 - Av.Training loss 61448.64182428728 - Av.Validation loss 89067.90290178571
# [+]Epoch 40 - Av.Training loss 71187.67985882676 - Av.Validation loss 117543.60714285714
# [+]Epoch 41 - Av.Training loss 63461.56356222588 - Av.Validation loss 97741.47879464286
# [+]Epoch 42 - Av.Training loss 65001.76589912281 - Av.Validation loss 92880.921875
# [+]Epoch 43 - Av.Training loss 57458.80365953947 - Av.Validation loss 104438.43917410714
# [+]Epoch 44 - Av.Training loss 56346.44706003289 - Av.Validation loss 113723.84207589286
# [+]Epoch 45 - Av.Training loss 61393.598341557015 - Av.Validation loss 93391.11077008929
# [+]Epoch 46 - Av.Training loss 71783.47039473684 - Av.Validation loss 98077.23549107143
# [+]Epoch 47 - Av.Training loss 60049.732593201756 - Av.Validation loss 103840.95758928571
# [+]Epoch 48 - Av.Training loss 60354.369311951756 - Av.Validation loss 96750.97433035714
# [+]Epoch 49 - Av.Training loss 55699.99972587719 - Av.Validation loss 110771.81975446429
# [+]Epoch 50 - Av.Training loss 64469.32185444079 - Av.Validation loss 103311.16629464286
# [+]Epoch 51 - Av.Training loss 51412.623732182015 - Av.Validation loss 126945.421875
# [+]Epoch 52 - Av.Training loss 56875.33004385965 - Av.Validation loss 91160.90513392857
# [+]Epoch 53 - Av.Training loss 50022.555989583336 - Av.Validation loss 93670.87946428571
# [+]Epoch 54 - Av.Training loss 54016.91837993421 - Av.Validation loss 95760.31417410714
# =======================Modelo guardado en epoch 55 con loss 88991.05580357143=======================
# [+]Epoch 55 - Av.Training loss 49474.64021381579 - Av.Validation loss 88991.05580357143
# [+]Epoch 56 - Av.Training loss 57849.208813048244 - Av.Validation loss 104049.37834821429
# [+]Epoch 57 - Av.Training loss 54756.79440789474 - Av.Validation loss 101272.8828125
# [+]Epoch 58 - Av.Training loss 49364.639665570176 - Av.Validation loss 104580.45200892857
# [+]Epoch 59 - Av.Training loss 53376.908854166664 - Av.Validation loss 104216.57924107143
# [+]Epoch 60 - Av.Training loss 55203.31109512061 - Av.Validation loss 110131.21372767857
# [+]Epoch 61 - Av.Training loss 48160.01199287281 - Av.Validation loss 102644.54910714286
# [+]Epoch 62 - Av.Training loss 49883.99403782895 - Av.Validation loss 102008.97879464286
# [+]Epoch 63 - Av.Training loss 52230.897786458336 - Av.Validation loss 107478.99497767857
# [+]Epoch 64 - Av.Training loss 48114.36859237939 - Av.Validation loss 95473.56863839286
# [+]Epoch 65 - Av.Training loss 56798.696820175435 - Av.Validation loss 104411.49441964286
# [+]Epoch 66 - Av.Training loss 46146.017441063595 - Av.Validation loss 106372.61160714286
# [+]Epoch 67 - Av.Training loss 43096.979989035084 - Av.Validation loss 111184.42131696429
# [+]Epoch 68 - Av.Training loss 41907.867667214916 - Av.Validation loss 105589.20703125
# [+]Epoch 69 - Av.Training loss 46639.10361842105 - Av.Validation loss 108583.9140625
# [+]Epoch 70 - Av.Training loss 44220.62078536184 - Av.Validation loss 94689.16015625
# ========================Modelo guardado en epoch 71 con loss 84268.439453125========================
# [+]Epoch 71 - Av.Training loss 41824.042489035084 - Av.Validation loss 84268.439453125
# [+]Epoch 72 - Av.Training loss 46300.43582099781 - Av.Validation loss 103061.28459821429
# [+]Epoch 73 - Av.Training loss 46188.127432839916 - Av.Validation loss 104891.07366071429
# [+]Epoch 74 - Av.Training loss 49660.131544682015 - Av.Validation loss 92691.86104910714
# [+]Epoch 75 - Av.Training loss 44283.16347998904 - Av.Validation loss 101175.19084821429
# [+]Epoch 76 - Av.Training loss 37042.31585800439 - Av.Validation loss 105217.12667410714
# [+]Epoch 77 - Av.Training loss 40111.93719161184 - Av.Validation loss 109408.78683035714
# [+]Epoch 78 - Av.Training loss 37865.50366639254 - Av.Validation loss 105595.6953125
# [+]Epoch 79 - Av.Training loss 35314.48882949561 - Av.Validation loss 102450.53236607143
# [+]Epoch 80 - Av.Training loss 36088.81003289474 - Av.Validation loss 96820.21037946429
# [+]Epoch 81 - Av.Training loss 38200.24948601974 - Av.Validation loss 108243.41685267857
# [+]Epoch 82 - Av.Training loss 35037.15316611842 - Av.Validation loss 106015.71875
# [+]Epoch 83 - Av.Training loss 36074.98022889254 - Av.Validation loss 99332.78069196429
# [+]Epoch 84 - Av.Training loss 37757.15957373904 - Av.Validation loss 97150.86160714286
# [+]Epoch 85 - Av.Training loss 35907.17084703947 - Av.Validation loss 87839.85212053571
# [+]Epoch 86 - Av.Training loss 34653.475603070176 - Av.Validation loss 96272.38895089286
# [+]Epoch 87 - Av.Training loss 33121.119003563595 - Av.Validation loss 101137.07366071429
# [+]Epoch 88 - Av.Training loss 35330.172046326756 - Av.Validation loss 95290.11272321429
# [+]Epoch 89 - Av.Training loss 35443.655598958336 - Av.Validation loss 101053.4375
# [+]Epoch 90 - Av.Training loss 31964.655256304824 - Av.Validation loss 92457.11941964286
# [+]Epoch 91 - Av.Training loss 34536.79773163377 - Av.Validation loss 104594.63950892857
# [+]Epoch 92 - Av.Training loss 33626.156112938595 - Av.Validation loss 103929.71149553571
# [+]Epoch 93 - Av.Training loss 32482.580592105263 - Av.Validation loss 105841.12667410714
# [+]Epoch 94 - Av.Training loss 32070.78820586623 - Av.Validation loss 96821.98660714286
# [+]Epoch 95 - Av.Training loss 34524.32384183114 - Av.Validation loss 103965.85546875
# [+]Epoch 96 - Av.Training loss 35118.89833470395 - Av.Validation loss 99387.01450892857
# [+]Epoch 97 - Av.Training loss 35578.00637335526 - Av.Validation loss 104072.62834821429
# [+]Epoch 98 - Av.Training loss 32327.846662554824 - Av.Validation loss 111369.82533482143
# [+]Epoch 99 - Av.Training loss 32824.83891858553 - Av.Validation loss 106389.66852678571
# [+]Epoch 100 - Av.Training loss 29008.431743421053 - Av.Validation loss 91236.23214285714
# [+]Epoch 101 - Av.Training loss 29906.391207510966 - Av.Validation loss 93874.51088169643
# [+]Epoch 102 - Av.Training loss 30685.94054961623 - Av.Validation loss 92185.00334821429
# [+]Epoch 103 - Av.Training loss 28110.79375685307 - Av.Validation loss 97303.69921875
# [+]Epoch 104 - Av.Training loss 29605.121436403508 - Av.Validation loss 103240.49665178571
# [+]Epoch 105 - Av.Training loss 29646.941303453947 - Av.Validation loss 106724.36886160714
# [+]Epoch 106 - Av.Training loss 31664.288582785088 - Av.Validation loss 98943.12723214286
# [+]Epoch 107 - Av.Training loss 31729.636410361843 - Av.Validation loss 107566.11941964286
# [+]Epoch 108 - Av.Training loss 34590.939316063595 - Av.Validation loss 105066.31808035714
# [+]Epoch 109 - Av.Training loss 32378.158374451756 - Av.Validation loss 111258.52008928571
# [+]Epoch 110 - Av.Training loss 31802.413754111843 - Av.Validation loss 103717.0625
# [+]Epoch 111 - Av.Training loss 33364.52895422149 - Av.Validation loss 88833.55412946429
# [+]Epoch 112 - Av.Training loss 32178.502604166668 - Av.Validation loss 93040.38727678571
# [+]Epoch 113 - Av.Training loss 31175.805441337718 - Av.Validation loss 97972.68080357143
# [+]Epoch 114 - Av.Training loss 30548.22896107456 - Av.Validation loss 99279.51171875
# [+]Epoch 115 - Av.Training loss 38158.31479577851 - Av.Validation loss 111603.41685267857
# [+]Epoch 116 - Av.Training loss 28866.560478344298 - Av.Validation loss 115341.23549107143
# [+]Epoch 117 - Av.Training loss 33389.17310855263 - Av.Validation loss 105404.68359375
# [+]Epoch 118 - Av.Training loss 29929.710834703947 - Av.Validation loss 103732.01841517857
# [+]Epoch 119 - Av.Training loss 28308.016327439695 - Av.Validation loss 101370.37109375
# [+]Epoch 120 - Av.Training loss 33057.31219161184 - Av.Validation loss 99153.44754464286
# [+]Epoch 121 - Av.Training loss 29349.404091282893 - Av.Validation loss 113659.14620535714
# [+]Epoch 122 - Av.Training loss 28553.328125 - Av.Validation loss 106857.1796875
# [+]Epoch 123 - Av.Training loss 26052.459875274122 - Av.Validation loss 96038.44977678571
# [+]Epoch 124 - Av.Training loss 26550.65458813048 - Av.Validation loss 107157.86886160714
# [+]Epoch 125 - Av.Training loss 29296.050644188595 - Av.Validation loss 102750.83872767857
# [+]Epoch 126 - Av.Training loss 26995.261239035088 - Av.Validation loss 96639.41127232143
# [+]Epoch 127 - Av.Training loss 26518.681811951756 - Av.Validation loss 98405.43526785714
# [+]Epoch 128 - Av.Training loss 27669.333813048244 - Av.Validation loss 97374.51171875
# [+]Epoch 129 - Av.Training loss 27303.53861705044 - Av.Validation loss 104259.65066964286
# [+]Epoch 130 - Av.Training loss 27939.13438870614 - Av.Validation loss 106040.30245535714
# [+]Epoch 131 - Av.Training loss 29927.978515625 - Av.Validation loss 108273.75669642857
# [+]Epoch 132 - Av.Training loss 27686.146484375 - Av.Validation loss 95424.1015625
# [+]Epoch 133 - Av.Training loss 29506.478584155702 - Av.Validation loss 105724.83984375
# [+]Epoch 134 - Av.Training loss 27826.374451754386 - Av.Validation loss 104644.49051339286
# [+]Epoch 135 - Av.Training loss 26164.84892406798 - Av.Validation loss 108762.58035714286
# [+]Epoch 136 - Av.Training loss 27092.207579495614 - Av.Validation loss 108688.63504464286
# [+]Epoch 137 - Av.Training loss 29440.58525219298 - Av.Validation loss 104739.43024553571
# [+]Epoch 138 - Av.Training loss 27593.488778097588 - Av.Validation loss 100775.56417410714
# [+]Epoch 139 - Av.Training loss 29288.967859100878 - Av.Validation loss 105928.20368303571
# [+]Epoch 140 - Av.Training loss 26000.936009457237 - Av.Validation loss 98748.45814732143
# [+]Epoch 141 - Av.Training loss 26585.92574698465 - Av.Validation loss 90457.8046875
# [+]Epoch 142 - Av.Training loss 27464.573550575657 - Av.Validation loss 109556.17578125
# [+]Epoch 143 - Av.Training loss 27730.516207510966 - Av.Validation loss 100114.05803571429
# [+]Epoch 144 - Av.Training loss 27209.736842105263 - Av.Validation loss 103514.54296875
# [+]Epoch 145 - Av.Training loss 28400.830729166668 - Av.Validation loss 115938.42299107143
# [+]Epoch 146 - Av.Training loss 25894.945552357458 - Av.Validation loss 112741.47488839286
# [+]Epoch 147 - Av.Training loss 24389.364771792763 - Av.Validation loss 108481.40736607143
# [+]Epoch 148 - Av.Training loss 27424.35908374452 - Av.Validation loss 106499.69587053571
# [+]Epoch 149 - Av.Training loss 28675.840991639256 - Av.Validation loss 101234.37276785714
# [+]Epoch 150 - Av.Training loss 27196.01295230263 - Av.Validation loss 100115.99051339286
# [+]Epoch 151 - Av.Training loss 28473.795093201756 - Av.Validation loss 108048.68917410714
# [+]Epoch 152 - Av.Training loss 30869.563425164473 - Av.Validation loss 95151.68303571429
# [+]Epoch 153 - Av.Training loss 28963.773574561405 - Av.Validation loss 101009.49107142857
# [+]Epoch 154 - Av.Training loss 25592.46056058114 - Av.Validation loss 94534.66657366071
# [+]Epoch 155 - Av.Training loss 24609.516276041668 - Av.Validation loss 108103.78292410714
# [+]Epoch 156 - Av.Training loss 24881.051449424343 - Av.Validation loss 108008.45535714286
# [+]Epoch 157 - Av.Training loss 25027.299821820176 - Av.Validation loss 97535.73883928571
# [+]Epoch 158 - Av.Training loss 24474.952987938595 - Av.Validation loss 88673.73018973214
# [+]Epoch 159 - Av.Training loss 23828.192519873905 - Av.Validation loss 107494.15959821429
# [+]Epoch 160 - Av.Training loss 22684.445209703947 - Av.Validation loss 87977.56138392857
# [+]Epoch 161 - Av.Training loss 24825.379831414473 - Av.Validation loss 113374.19642857143
# [+]Epoch 162 - Av.Training loss 23294.99271861294 - Av.Validation loss 94832.10770089286
# [+]Epoch 163 - Av.Training loss 29702.871110882676 - Av.Validation loss 98360.97823660714
# [+]Epoch 164 - Av.Training loss 28586.49590529057 - Av.Validation loss 100836.95479910714
# [+]Epoch 165 - Av.Training loss 23057.40864857456 - Av.Validation loss 115904.31361607143
# [+]Epoch 166 - Av.Training loss 23678.622121710527 - Av.Validation loss 101023.14927455357
# [+]Epoch 167 - Av.Training loss 24776.584909539473 - Av.Validation loss 102447.79129464286
# [+]Epoch 168 - Av.Training loss 24543.668397066886 - Av.Validation loss 107703.00111607143
# [+]Epoch 169 - Av.Training loss 24916.921857867324 - Av.Validation loss 106972.83816964286
# [+]Epoch 170 - Av.Training loss 26909.484683388157 - Av.Validation loss 102601.47823660714
# [+]Epoch 171 - Av.Training loss 27448.69861910636 - Av.Validation loss 86173.61049107143
# [+]Epoch 172 - Av.Training loss 23787.337976288378 - Av.Validation loss 102705.67745535714
# [+]Epoch 173 - Av.Training loss 23106.721953810305 - Av.Validation loss 98281.33258928571
# [+]Epoch 174 - Av.Training loss 25361.228035910088 - Av.Validation loss 109792.73856026786
# [+]Epoch 175 - Av.Training loss 24188.300318667763 - Av.Validation loss 108668.53878348214
# [+]Epoch 176 - Av.Training loss 24039.10420093202 - Av.Validation loss 87769.32840401786
# [+]Epoch 177 - Av.Training loss 29048.971765350878 - Av.Validation loss 109054.37611607143
# [+]Epoch 178 - Av.Training loss 25761.525390625 - Av.Validation loss 105041.79743303571
# [+]Epoch 179 - Av.Training loss 27318.144959566886 - Av.Validation loss 96178.99944196429
# [+]Epoch 180 - Av.Training loss 24246.967567845393 - Av.Validation loss 106869.94475446429
# [+]Epoch 181 - Av.Training loss 23436.16431949013 - Av.Validation loss 109447.77399553571
# [+]Epoch 182 - Av.Training loss 25466.971097176534 - Av.Validation loss 108049.26729910714
# [+]Epoch 183 - Av.Training loss 21045.93835663377 - Av.Validation loss 117302.3125
# [+]Epoch 184 - Av.Training loss 23687.04180372807 - Av.Validation loss 107861.02622767857
# [+]Epoch 185 - Av.Training loss 25940.754043311405 - Av.Validation loss 98039.44196428571
# [+]Epoch 186 - Av.Training loss 26317.757983826756 - Av.Validation loss 97434.87220982143
# [+]Epoch 187 - Av.Training loss 22241.967841968202 - Av.Validation loss 106435.71177455357
# [+]Epoch 188 - Av.Training loss 21880.291649533992 - Av.Validation loss 104126.35770089286
# [+]Epoch 189 - Av.Training loss 25216.691577576756 - Av.Validation loss 101374.26534598214
# [+]Epoch 190 - Av.Training loss 25323.696511787282 - Av.Validation loss 110421.34821428571
# [+]Epoch 191 - Av.Training loss 23157.10509183114 - Av.Validation loss 101162.72935267857
# [+]Epoch 192 - Av.Training loss 23925.703364857458 - Av.Validation loss 99433.89341517857
# [+]Epoch 193 - Av.Training loss 22887.244140625 - Av.Validation loss 110915.36551339286
# [+]Epoch 194 - Av.Training loss 22831.977333470393 - Av.Validation loss 108895.63616071429
# [+]Epoch 195 - Av.Training loss 22995.487544544958 - Av.Validation loss 100182.76171875
# [+]Epoch 196 - Av.Training loss 28375.107182017542 - Av.Validation loss 101220.45005580357
# [+]Epoch 197 - Av.Training loss 23410.117992735744 - Av.Validation loss 107558.51785714286
# [+]Epoch 198 - Av.Training loss 25682.574989720393 - Av.Validation loss 95498.1171875
# [+]Epoch 199 - Av.Training loss 25279.151504248905 - Av.Validation loss 104882.75669642857
# [+]Epoch 200 - Av.Training loss 22267.94111499452 - Av.Validation loss 103970.0625
# [+]Epoch 201 - Av.Training loss 22131.594777960527 - Av.Validation loss 96297.62779017857
# [+]Epoch 202 - Av.Training loss 21227.113915158992 - Av.Validation loss 101355.85379464286
# [+]Epoch 203 - Av.Training loss 22296.871196546053 - Av.Validation loss 120425.25334821429
# [+]Epoch 204 - Av.Training loss 21471.217944764256 - Av.Validation loss 102450.25083705357
# [+]Epoch 205 - Av.Training loss 21854.305595531798 - Av.Validation loss 113462.21902901786
# [+]Epoch 206 - Av.Training loss 23951.88240131579 - Av.Validation loss 117285.72042410714
# [+]Epoch 207 - Av.Training loss 24439.280941611843 - Av.Validation loss 112914.71540178571
# [+]Epoch 208 - Av.Training loss 24133.790433114034 - Av.Validation loss 101989.79185267857
# [+]Epoch 209 - Av.Training loss 21251.21277069627 - Av.Validation loss 106161.54464285714
# [+]Epoch 210 - Av.Training loss 21111.22791598136 - Av.Validation loss 103400.88560267857
# [+]Epoch 211 - Av.Training loss 21942.604971902412 - Av.Validation loss 99950.09542410714
# [+]Epoch 212 - Av.Training loss 20981.38750685307 - Av.Validation loss 104681.65011160714
# [+]Epoch 213 - Av.Training loss 20874.372687088817 - Av.Validation loss 102805.56640625
# [+]Epoch 214 - Av.Training loss 21924.995665433114 - Av.Validation loss 117401.34263392857
# [+]Epoch 215 - Av.Training loss 21136.95357044956 - Av.Validation loss 107027.02790178571
# [+]Epoch 216 - Av.Training loss 21944.16431949013 - Av.Validation loss 101454.35491071429
# [+]Epoch 217 - Av.Training loss 24006.864531935305 - Av.Validation loss 110692.53348214286
# [+]Epoch 218 - Av.Training loss 24600.515145285088 - Av.Validation loss 114572.44419642857
# [+]Epoch 219 - Av.Training loss 24437.166632401317 - Av.Validation loss 100026.35602678571
# [+]Epoch 220 - Av.Training loss 20548.38212719298 - Av.Validation loss 119511.04352678571
# [+]Epoch 221 - Av.Training loss 21740.09762198465 - Av.Validation loss 109766.67410714286
# [+]Epoch 222 - Av.Training loss 20206.829427083332 - Av.Validation loss 113753.50111607143
# [+]Epoch 223 - Av.Training loss 22247.15669544956 - Av.Validation loss 116784.10546875
# [+]Epoch 224 - Av.Training loss 20741.555612664473 - Av.Validation loss 115686.95424107143
# [+]Epoch 225 - Av.Training loss 22252.45631167763 - Av.Validation loss 114934.33091517857
# [+]Epoch 226 - Av.Training loss 23994.988109923244 - Av.Validation loss 114649.05580357143
# [+]Epoch 227 - Av.Training loss 22308.313151041668 - Av.Validation loss 119051.06194196429
# [+]Epoch 228 - Av.Training loss 20090.51228412829 - Av.Validation loss 101945.33872767857
# [+]Epoch 229 - Av.Training loss 18818.542471902412 - Av.Validation loss 96206.11272321429
# [+]Epoch 230 - Av.Training loss 20771.79409950658 - Av.Validation loss 107700.65401785714
# [+]Epoch 231 - Av.Training loss 21286.822060032893 - Av.Validation loss 103525.07645089286
# [+]Epoch 232 - Av.Training loss 22644.54130688048 - Av.Validation loss 125586.36160714286
# [+]Epoch 233 - Av.Training loss 23587.37691885965 - Av.Validation loss 100091.76395089286
# [+]Epoch 234 - Av.Training loss 22653.2470703125 - Av.Validation loss 115005.56584821429
# [+]Epoch 235 - Av.Training loss 20093.857027823466 - Av.Validation loss 105886.75558035714
# [+]Epoch 236 - Av.Training loss 21750.243797971492 - Av.Validation loss 119988.44196428571
# [+]Epoch 237 - Av.Training loss 22794.45022957785 - Av.Validation loss 110554.11104910714
# [+]Epoch 238 - Av.Training loss 21805.338781524122 - Av.Validation loss 116657.15178571429
# [+]Epoch 239 - Av.Training loss 23449.472930372805 - Av.Validation loss 113701.72879464286
# [+]Epoch 240 - Av.Training loss 22073.9111328125 - Av.Validation loss 107737.53125
# [+]Epoch 241 - Av.Training loss 21146.994534676534 - Av.Validation loss 120859.76450892857
# [+]Epoch 242 - Av.Training loss 21332.142338267542 - Av.Validation loss 96869.80133928571
# [+]Epoch 243 - Av.Training loss 20509.32027823465 - Av.Validation loss 110018.38169642857
# [+]Epoch 244 - Av.Training loss 19852.98888089364 - Av.Validation loss 120611.8828125
# [+]Epoch 245 - Av.Training loss 22252.308079769737 - Av.Validation loss 112930.25669642857
# [+]Epoch 246 - Av.Training loss 23477.56426466557 - Av.Validation loss 111474.34263392857
# [+]Epoch 247 - Av.Training loss 22776.887866639256 - Av.Validation loss 119725.34765625
# [+]Epoch 248 - Av.Training loss 22972.297354714912 - Av.Validation loss 112670.11495535714
# [+]Epoch 249 - Av.Training loss 23655.63104783443 - Av.Validation loss 112473.83426339286
# [+]Epoch 250 - Av.Training loss 23395.749040570176 - Av.Validation loss 109743.58649553571
# [+]Epoch 251 - Av.Training loss 21117.967310855263 - Av.Validation loss 96780.95479910714
# [+]Epoch 252 - Av.Training loss 22216.006184895832 - Av.Validation loss 101122.27008928571
# [+]Epoch 253 - Av.Training loss 21772.10562294408 - Av.Validation loss 107259.42466517857
# [+]Epoch 254 - Av.Training loss 21601.75394051535 - Av.Validation loss 114151.41629464286
# [+]Epoch 255 - Av.Training loss 20114.034316748905 - Av.Validation loss 113153.84598214286
# [+]Epoch 256 - Av.Training loss 22827.455574972588 - Av.Validation loss 86106.08872767857
# [+]Epoch 257 - Av.Training loss 21089.633891858553 - Av.Validation loss 90132.43582589286
# [+]Epoch 258 - Av.Training loss 20025.0380859375 - Av.Validation loss 100024.13504464286
# [+]Epoch 259 - Av.Training loss 18664.29995888158 - Av.Validation loss 104362.41629464286
# [+]Epoch 260 - Av.Training loss 19858.09882127193 - Av.Validation loss 99826.69698660714
# [+]Epoch 261 - Av.Training loss 18205.196940104168 - Av.Validation loss 94981.79241071429
# [+]Epoch 262 - Av.Training loss 19269.597759046053 - Av.Validation loss 111171.01506696429
# [+]Epoch 263 - Av.Training loss 19519.58915844298 - Av.Validation loss 106370.25055803571
# [+]Epoch 264 - Av.Training loss 22041.44317091557 - Av.Validation loss 101304.05580357143
# [+]Epoch 265 - Av.Training loss 21264.07588061952 - Av.Validation loss 102081.34207589286
# [+]Epoch 266 - Av.Training loss 20746.515402275218 - Av.Validation loss 113188.97209821429
# [+]Epoch 267 - Av.Training loss 20790.27381441886 - Av.Validation loss 112902.84877232143
# [+]Epoch 268 - Av.Training loss 21058.631202028508 - Av.Validation loss 124318.59598214286
# [+]Epoch 269 - Av.Training loss 17700.88675301535 - Av.Validation loss 125364.28236607143
# [+]Epoch 270 - Av.Training loss 18476.339192708332 - Av.Validation loss 103732.73046875
# [+]Epoch 271 - Av.Training loss 19899.699270148027 - Av.Validation loss 100301.6953125
# [+]Epoch 272 - Av.Training loss 21525.20838473136 - Av.Validation loss 123469.71763392857
# [+]Epoch 273 - Av.Training loss 18973.510348135966 - Av.Validation loss 109541.046875
# [+]Epoch 274 - Av.Training loss 22495.253032483553 - Av.Validation loss 114309.43526785714
# [+]Epoch 275 - Av.Training loss 19660.530341968202 - Av.Validation loss 122545.77678571429
# [+]Epoch 276 - Av.Training loss 20593.134525767542 - Av.Validation loss 114650.06919642857
# [+]Epoch 277 - Av.Training loss 19574.070706551534 - Av.Validation loss 104217.04799107143
# [+]Epoch 278 - Av.Training loss 20551.112133360744 - Av.Validation loss 103024.13337053571
# [+]Epoch 279 - Av.Training loss 24595.276949698466 - Av.Validation loss 114700.96316964286
# [+]Epoch 280 - Av.Training loss 20717.50525973136 - Av.Validation loss 101573.30357142857
# [+]Epoch 281 - Av.Training loss 21136.598855537282 - Av.Validation loss 110673.04966517857
# [+]Epoch 282 - Av.Training loss 21824.274482593202 - Av.Validation loss 115537.39732142857
# [+]Epoch 283 - Av.Training loss 22319.545829906798 - Av.Validation loss 115205.03962053571
# [+]Epoch 284 - Av.Training loss 20334.4921875 - Av.Validation loss 109741.40457589286
# [+]Epoch 285 - Av.Training loss 20105.414336622805 - Av.Validation loss 97019.58258928571
# [+]Epoch 286 - Av.Training loss 21984.71691680373 - Av.Validation loss 110289.81529017857
# [+]Epoch 287 - Av.Training loss 18350.84453810307 - Av.Validation loss 101484.78292410714
# [+]Epoch 288 - Av.Training loss 18480.942211485744 - Av.Validation loss 107342.49441964286
# [+]Epoch 289 - Av.Training loss 23152.713593064695 - Av.Validation loss 117120.34514508929
# [+]Epoch 290 - Av.Training loss 22373.31039268092 - Av.Validation loss 112556.89285714286
# [+]Epoch 291 - Av.Training loss 21891.733758223683 - Av.Validation loss 104198.3203125
# [+]Epoch 292 - Av.Training loss 19355.102967379386 - Av.Validation loss 109874.68526785714
# [+]Epoch 293 - Av.Training loss 21310.80220326206 - Av.Validation loss 100028.86160714286
# [+]Epoch 294 - Av.Training loss 20462.718612938595 - Av.Validation loss 117651.3671875
# [+]Epoch 295 - Av.Training loss 19478.064778645832 - Av.Validation loss 107828.60714285714
# [+]Epoch 296 - Av.Training loss 23510.851511101973 - Av.Validation loss 96348.86969866071
# [+]Epoch 297 - Av.Training loss 19783.190635279607 - Av.Validation loss 116432.84654017857
# [+]Epoch 298 - Av.Training loss 18706.675233004386 - Av.Validation loss 106997.640625
# [+]Epoch 299 - Av.Training loss 17707.76103344298 - Av.Validation loss 102605.23158482143
# [+]Epoch 300 - Av.Training loss 18779.024842379386 - Av.Validation loss 121491.23214285714
# [+]Epoch 301 - Av.Training loss 17770.21525493421 - Av.Validation loss 101979.82003348214
# [+]Epoch 302 - Av.Training loss 20579.59371573465 - Av.Validation loss 104427.76729910714
# [+]Epoch 303 - Av.Training loss 19175.743969298244 - Av.Validation loss 104998.9765625
# [+]Epoch 304 - Av.Training loss 18036.59664542215 - Av.Validation loss 112391.96261160714
# [+]Epoch 305 - Av.Training loss 21395.146415844298 - Av.Validation loss 91870.23967633929
# [+]Epoch 306 - Av.Training loss 19056.32474986294 - Av.Validation loss 118518.75055803571
# [+]Epoch 307 - Av.Training loss 20170.663137335527 - Av.Validation loss 119070.21428571429
# [+]Epoch 308 - Av.Training loss 21109.693153782893 - Av.Validation loss 110602.71763392857
# [+]Epoch 309 - Av.Training loss 18743.16575863487 - Av.Validation loss 111733.21540178571
# [+]Epoch 310 - Av.Training loss 18652.719829358553 - Av.Validation loss 109392.78794642857
# [+]Epoch 311 - Av.Training loss 18626.648043448466 - Av.Validation loss 119613.07366071429
# [+]Epoch 312 - Av.Training loss 21014.902103892542 - Av.Validation loss 121702.92522321429
# [+]Epoch 313 - Av.Training loss 22735.019068667763 - Av.Validation loss 124443.78013392857
# [+]Epoch 314 - Av.Training loss 19430.054927357458 - Av.Validation loss 96027.09654017857
# [+]Epoch 315 - Av.Training loss 20682.043140076756 - Av.Validation loss 123701.32979910714
# [+]Epoch 316 - Av.Training loss 21133.876816063595 - Av.Validation loss 111317.72767857143
# [+]Epoch 317 - Av.Training loss 18783.665741502195 - Av.Validation loss 117373.30078125
# [+]Epoch 318 - Av.Training loss 18033.890350877195 - Av.Validation loss 102914.27650669643
# [+]Epoch 319 - Av.Training loss 17251.554636101973 - Av.Validation loss 96635.85044642857
# [+]Epoch 320 - Av.Training loss 22318.203621847588 - Av.Validation loss 105884.62123325893
# [+]Epoch 321 - Av.Training loss 17928.153011924343 - Av.Validation loss 117481.31138392857
# [+]Epoch 322 - Av.Training loss 17284.15864857456 - Av.Validation loss 127524.0
# [+]Epoch 323 - Av.Training loss 18489.595651726973 - Av.Validation loss 110573.92020089286
# [+]Epoch 324 - Av.Training loss 18232.332356770832 - Av.Validation loss 111562.27566964286
# [+]Epoch 325 - Av.Training loss 18823.73163377193 - Av.Validation loss 112850.31640625
# [+]Epoch 326 - Av.Training loss 18595.30179207785 - Av.Validation loss 119256.900390625
# [+]Epoch 327 - Av.Training loss 22009.347433525218 - Av.Validation loss 126229.2109375
# [+]Epoch 328 - Av.Training loss 19054.495288514256 - Av.Validation loss 98950.40290178571
# [+]Epoch 329 - Av.Training loss 18421.39423999452 - Av.Validation loss 102867.67912946429
# [+]Epoch 330 - Av.Training loss 21349.490165844298 - Av.Validation loss 103632.349609375
# [+]Epoch 331 - Av.Training loss 18120.001439144737 - Av.Validation loss 120536.17131696429
# [+]Epoch 332 - Av.Training loss 17907.372978344298 - Av.Validation loss 121364.13169642857
# [+]Epoch 333 - Av.Training loss 21177.23271313048 - Av.Validation loss 106548.00390625
# [+]Epoch 334 - Av.Training loss 17882.881904468202 - Av.Validation loss 110295.27232142857
# [+]Epoch 335 - Av.Training loss 17478.908408717107 - Av.Validation loss 112904.55078125
# [+]Epoch 336 - Av.Training loss 18677.079187225878 - Av.Validation loss 98834.96205357143
# [+]Epoch 337 - Av.Training loss 17287.447488349782 - Av.Validation loss 113364.67578125
# [+]Epoch 338 - Av.Training loss 18772.189281798244 - Av.Validation loss 119479.99553571429
# [+]Epoch 339 - Av.Training loss 19306.755842242324 - Av.Validation loss 124606.21651785714
# [+]Epoch 340 - Av.Training loss 17828.624486019737 - Av.Validation loss 121631.36551339286
# [+]Epoch 341 - Av.Training loss 18626.822968064695 - Av.Validation loss 123858.70814732143
# [+]Epoch 342 - Av.Training loss 18862.046069764256 - Av.Validation loss 105073.95145089286
# [+]Epoch 343 - Av.Training loss 19329.146912691886 - Av.Validation loss 98729.1953125
# [+]Epoch 344 - Av.Training loss 19552.16207510965 - Av.Validation loss 129153.44308035714
# [+]Epoch 345 - Av.Training loss 20009.103053042763 - Av.Validation loss 116799.71316964286
# [+]Epoch 346 - Av.Training loss 20917.521998355263 - Av.Validation loss 120826.6328125
# [+]Epoch 347 - Av.Training loss 19553.356942160088 - Av.Validation loss 116256.6171875
# [+]Epoch 348 - Av.Training loss 21030.681143777412 - Av.Validation loss 99536.47433035714
# [+]Epoch 349 - Av.Training loss 17634.877724095393 - Av.Validation loss 111934.79352678571
# [+]Epoch 350 - Av.Training loss 17861.43510142544 - Av.Validation loss 121163.02678571429
# [+]Epoch 351 - Av.Training loss 16533.048691063595 - Av.Validation loss 115109.42633928571
# [+]Epoch 352 - Av.Training loss 17755.04684073465 - Av.Validation loss 105988.98381696429
# [+]Epoch 353 - Av.Training loss 19974.765385142542 - Av.Validation loss 121301.05301339286
# [+]Epoch 354 - Av.Training loss 21492.130842242324 - Av.Validation loss 122305.51618303571
# [+]Epoch 355 - Av.Training loss 17904.471885279607 - Av.Validation loss 109405.18303571429
# [+]Epoch 356 - Av.Training loss 17266.514785498905 - Av.Validation loss 98097.64397321429
# [+]Epoch 357 - Av.Training loss 16456.276350054824 - Av.Validation loss 106381.8125
# [+]Epoch 358 - Av.Training loss 17720.71220531798 - Av.Validation loss 109208.65457589286
# [+]Epoch 359 - Av.Training loss 18078.883360745614 - Av.Validation loss 98384.44866071429
# [+]Epoch 360 - Av.Training loss 17206.694010416668 - Av.Validation loss 107769.10881696429
# [+]Epoch 361 - Av.Training loss 16272.233415570176 - Av.Validation loss 120536.77064732143
# [+]Epoch 362 - Av.Training loss 18609.03515625 - Av.Validation loss 110971.99330357143
# [+]Epoch 363 - Av.Training loss 17468.447976631032 - Av.Validation loss 113293.09988839286
# [+]Epoch 364 - Av.Training loss 18238.483090049343 - Av.Validation loss 107720.70647321429
# [+]Epoch 365 - Av.Training loss 17841.626850328947 - Av.Validation loss 113587.86774553571
# [+]Epoch 366 - Av.Training loss 20345.609803316886 - Av.Validation loss 99482.26841517857
# [+]Epoch 367 - Av.Training loss 17202.26411732456 - Av.Validation loss 108482.86272321429
# [+]Epoch 368 - Av.Training loss 16582.112767269737 - Av.Validation loss 105518.06082589286
# [+]Epoch 369 - Av.Training loss 21727.10017475329 - Av.Validation loss 111798.37109375
# [+]Epoch 370 - Av.Training loss 19138.46097176535 - Av.Validation loss 105417.54799107143
# [+]Epoch 371 - Av.Training loss 17557.88935718202 - Av.Validation loss 112197.47377232143
# [+]Epoch 372 - Av.Training loss 18815.173879523027 - Av.Validation loss 108429.26004464286
# [+]Epoch 373 - Av.Training loss 17797.63171600877 - Av.Validation loss 89291.30133928571
# [+]Epoch 374 - Av.Training loss 17527.87128220943 - Av.Validation loss 116591.12276785714
# [+]Epoch 375 - Av.Training loss 17736.52746367873 - Av.Validation loss 115148.45926339286
# [+]Epoch 376 - Av.Training loss 19041.908442982458 - Av.Validation loss 110809.40959821429
# [+]Epoch 377 - Av.Training loss 16988.72923519737 - Av.Validation loss 112424.15011160714
# [+]Epoch 378 - Av.Training loss 17564.94640899123 - Av.Validation loss 96239.65625
# [+]Epoch 379 - Av.Training loss 18420.885074013157 - Av.Validation loss 119782.21986607143
# [+]Epoch 380 - Av.Training loss 18385.274362664473 - Av.Validation loss 114178.64397321429
# [+]Epoch 381 - Av.Training loss 21097.004797149122 - Av.Validation loss 104788.38950892857
# [+]Epoch 382 - Av.Training loss 17496.76427151864 - Av.Validation loss 112690.38560267857
# [+]Epoch 383 - Av.Training loss 19446.686609100878 - Av.Validation loss 107714.91573660714
# [+]Epoch 384 - Av.Training loss 17483.917317708332 - Av.Validation loss 127216.2890625
# [+]Epoch 385 - Av.Training loss 17142.64009388706 - Av.Validation loss 109339.91294642857
# [+]Epoch 386 - Av.Training loss 20402.10701069079 - Av.Validation loss 123705.72823660714
# [+]Epoch 387 - Av.Training loss 18456.724695038378 - Av.Validation loss 109919.90569196429
# [+]Epoch 388 - Av.Training loss 18849.63724986294 - Av.Validation loss 117137.99553571429
# [+]Epoch 389 - Av.Training loss 20514.663103070176 - Av.Validation loss 113853.66573660714
# [+]Epoch 390 - Av.Training loss 17421.375325520832 - Av.Validation loss 118409.94363839286
# [+]Epoch 391 - Av.Training loss 19038.841145833332 - Av.Validation loss 117350.109375
# [+]Epoch 392 - Av.Training loss 18985.504968475878 - Av.Validation loss 113942.48939732143
# [+]Epoch 393 - Av.Training loss 16498.65523917215 - Av.Validation loss 114652.78627232143
# [+]Epoch 394 - Av.Training loss 16706.190566748905 - Av.Validation loss 122160.73995535714
# [+]Epoch 395 - Av.Training loss 17973.77828604715 - Av.Validation loss 119564.73214285714
# [+]Epoch 396 - Av.Training loss 17893.788017406798 - Av.Validation loss 125768.82589285714
# [+]Epoch 397 - Av.Training loss 17718.42052151864 - Av.Validation loss 121104.81305803571
# [+]Epoch 398 - Av.Training loss 17083.421703673244 - Av.Validation loss 123473.23214285714
# [+]Epoch 399 - Av.Training loss 16641.238623903508 - Av.Validation loss 113599.94642857143
# [+]Epoch 400 - Av.Training loss 18043.468698601973 - Av.Validation loss 115048.13783482143
# [+]Epoch 401 - Av.Training loss 18581.202987938595 - Av.Validation loss 113046.54575892857
# [+]Epoch 402 - Av.Training loss 16761.005431058114 - Av.Validation loss 119464.68303571429
# [+]Epoch 403 - Av.Training loss 15799.611191063597 - Av.Validation loss 106717.50892857143
# [+]Epoch 404 - Av.Training loss 17209.52009662829 - Av.Validation loss 107584.80078125
# [+]Epoch 405 - Av.Training loss 16398.565601014256 - Av.Validation loss 116987.72935267857
# [+]Epoch 406 - Av.Training loss 19726.768794544958 - Av.Validation loss 120888.19419642857
# [+]Epoch 407 - Av.Training loss 15653.550044544956 - Av.Validation loss 115122.66294642857
# [+]Epoch 408 - Av.Training loss 15616.101888020834 - Av.Validation loss 112455.20424107143
# [+]Epoch 409 - Av.Training loss 15947.662554824561 - Av.Validation loss 108013.99441964286
# [+]Epoch 410 - Av.Training loss 17173.123269599782 - Av.Validation loss 118852.67689732143
# [+]Epoch 411 - Av.Training loss 16374.978978207237 - Av.Validation loss 117463.93415178571
# [+]Epoch 412 - Av.Training loss 16426.676517955042 - Av.Validation loss 113298.23186383929
# [+]Epoch 413 - Av.Training loss 18988.69193736294 - Av.Validation loss 113035.17131696429
# [+]Epoch 414 - Av.Training loss 17182.753426535088 - Av.Validation loss 121421.02064732143
# [+]Epoch 415 - Av.Training loss 19150.56224300987 - Av.Validation loss 109797.36830357143
# [+]Epoch 416 - Av.Training loss 18129.336742735744 - Av.Validation loss 122120.81026785714
# [+]Epoch 417 - Av.Training loss 21284.19550095943 - Av.Validation loss 109053.76339285714
# [+]Epoch 418 - Av.Training loss 20035.508566337718 - Av.Validation loss 109481.71651785714
# [+]Epoch 419 - Av.Training loss 16687.995956688595 - Av.Validation loss 102256.14341517857
# [+]Epoch 420 - Av.Training loss 19542.314727247805 - Av.Validation loss 105540.017578125
# [+]Epoch 421 - Av.Training loss 19744.45283374452 - Av.Validation loss 114388.45591517857
# [+]Epoch 422 - Av.Training loss 16782.576103344298 - Av.Validation loss 107365.04352678571
# [+]Epoch 423 - Av.Training loss 18659.26089638158 - Av.Validation loss 121107.63169642857
# [+]Epoch 424 - Av.Training loss 16897.55453330592 - Av.Validation loss 108018.01702008929
# [+]Epoch 425 - Av.Training loss 16521.354286595393 - Av.Validation loss 121309.54910714286
# [+]Epoch 426 - Av.Training loss 16060.972724780702 - Av.Validation loss 105065.06361607143
# [+]Epoch 427 - Av.Training loss 15581.787657620614 - Av.Validation loss 96887.99497767857
# [+]Epoch 428 - Av.Training loss 16476.907706277412 - Av.Validation loss 110453.4609375
# [+]Epoch 429 - Av.Training loss 17077.497618558114 - Av.Validation loss 113396.625
# [+]Epoch 430 - Av.Training loss 16729.788411458332 - Av.Validation loss 113054.55357142857
# [+]Epoch 431 - Av.Training loss 17571.507195723683 - Av.Validation loss 117074.76785714286
# [+]Epoch 432 - Av.Training loss 17019.433371025218 - Av.Validation loss 113807.48604910714
# [+]Epoch 433 - Av.Training loss 17580.517338267542 - Av.Validation loss 124099.28683035714
# [+]Epoch 434 - Av.Training loss 18478.329752604168 - Av.Validation loss 115484.171875
# [+]Epoch 435 - Av.Training loss 18053.577782346492 - Av.Validation loss 96637.82533482143
# [+]Epoch 436 - Av.Training loss 17526.979252330042 - Av.Validation loss 125808.73995535714
# [+]Epoch 437 - Av.Training loss 17401.717002467107 - Av.Validation loss 115738.39397321429
# [+]Epoch 438 - Av.Training loss 18075.00435169956 - Av.Validation loss 106686.85825892857
# [+]Epoch 439 - Av.Training loss 18326.52850877193 - Av.Validation loss 103918.40625
# [+]Epoch 440 - Av.Training loss 17996.84510348136 - Av.Validation loss 111531.36244419643
# [+]Epoch 441 - Av.Training loss 17610.449835526317 - Av.Validation loss 124466.85100446429
# [+]Epoch 442 - Av.Training loss 17981.468852796053 - Av.Validation loss 125072.18582589286
# [+]Epoch 443 - Av.Training loss 18749.525167900218 - Av.Validation loss 92620.81640625
# [+]Epoch 444 - Av.Training loss 20739.42776864035 - Av.Validation loss 94510.91294642857
# [+]Epoch 445 - Av.Training loss 17022.37707305373 - Av.Validation loss 112431.61160714286
# [+]Epoch 446 - Av.Training loss 16277.294082373903 - Av.Validation loss 115349.00725446429
# [+]Epoch 447 - Av.Training loss 17347.843098958332 - Av.Validation loss 123767.72544642857
# [+]Epoch 448 - Av.Training loss 16580.94159470943 - Av.Validation loss 110312.96149553571
# [+]Epoch 449 - Av.Training loss 17606.873149671053 - Av.Validation loss 102738.59765625
# [+]Epoch 450 - Av.Training loss 15355.095429002193 - Av.Validation loss 118909.15625
# [+]Epoch 451 - Av.Training loss 16048.888363486842 - Av.Validation loss 120037.97433035714
# [+]Epoch 452 - Av.Training loss 16588.550455729168 - Av.Validation loss 103795.36272321429
# [+]Epoch 453 - Av.Training loss 16629.721045778508 - Av.Validation loss 118236.15625
# [+]Epoch 454 - Av.Training loss 16667.029947916668 - Av.Validation loss 94933.96875
# [+]Epoch 455 - Av.Training loss 17151.493215460527 - Av.Validation loss 119589.13113839286
# [+]Epoch 456 - Av.Training loss 17820.965117872805 - Av.Validation loss 107750.26506696429
# [+]Epoch 457 - Av.Training loss 17190.044904742324 - Av.Validation loss 125157.77790178571
# [+]Epoch 458 - Av.Training loss 17468.69682017544 - Av.Validation loss 110755.046875
# [+]Epoch 459 - Av.Training loss 16561.100243283992 - Av.Validation loss 117510.890625
# [+]Epoch 460 - Av.Training loss 17983.872550027412 - Av.Validation loss 112566.96763392857
# [+]Epoch 461 - Av.Training loss 17644.096508360744 - Av.Validation loss 110942.76785714286
# [+]Epoch 462 - Av.Training loss 17143.73910361842 - Av.Validation loss 133090.33984375
# [+]Epoch 463 - Av.Training loss 16248.000839501097 - Av.Validation loss 101587.16685267857
# [+]Epoch 464 - Av.Training loss 19253.84525767544 - Av.Validation loss 108894.80803571429
# [+]Epoch 465 - Av.Training loss 17554.97933799342 - Av.Validation loss 109997.86844308036
# [+]Epoch 466 - Av.Training loss 18710.163668448466 - Av.Validation loss 118910.71763392857
# [+]Epoch 467 - Av.Training loss 17188.46698533443 - Av.Validation loss 132897.44754464287
# [+]Epoch 468 - Av.Training loss 16616.135313870614 - Av.Validation loss 118805.8046875
# [+]Epoch 469 - Av.Training loss 16838.95267955044 - Av.Validation loss 121689.04241071429
# [+]Epoch 470 - Av.Training loss 15594.56486430921 - Av.Validation loss 103733.41964285714
# [+]Epoch 471 - Av.Training loss 14779.507795367324 - Av.Validation loss 127449.05691964286
# [+]Epoch 472 - Av.Training loss 15467.352556195176 - Av.Validation loss 119197.72991071429
# [+]Epoch 473 - Av.Training loss 16509.330729166668 - Av.Validation loss 123156.82589285714
# [+]Epoch 474 - Av.Training loss 15808.41582716557 - Av.Validation loss 118400.32924107143
# [+]Epoch 475 - Av.Training loss 15621.241296600878 - Av.Validation loss 125192.22544642857
# [+]Epoch 476 - Av.Training loss 16426.231102658992 - Av.Validation loss 107631.47991071429
# [+]Epoch 477 - Av.Training loss 15558.859614857456 - Av.Validation loss 127329.01785714286
# [+]Epoch 478 - Av.Training loss 16669.626336348683 - Av.Validation loss 115170.73660714286
# [+]Epoch 479 - Av.Training loss 16401.7529296875 - Av.Validation loss 116248.51450892857
# [+]Epoch 480 - Av.Training loss 15940.08341899671 - Av.Validation loss 110990.08761160714
# [+]Epoch 481 - Av.Training loss 18429.082699424343 - Av.Validation loss 103671.70758928571
# [+]Epoch 482 - Av.Training loss 16356.68025287829 - Av.Validation loss 112363.32979910714
# [+]Epoch 483 - Av.Training loss 16398.415244654607 - Av.Validation loss 124857.32700892857
# [+]Epoch 484 - Av.Training loss 16254.454838267544 - Av.Validation loss 122344.10491071429
# [+]Epoch 485 - Av.Training loss 19390.366707785088 - Av.Validation loss 114063.13783482143
# [+]Epoch 486 - Av.Training loss 16691.475945723683 - Av.Validation loss 111848.1328125
# [+]Epoch 487 - Av.Training loss 17583.875770970393 - Av.Validation loss 107269.48493303571
# [+]Epoch 488 - Av.Training loss 16796.40064761513 - Av.Validation loss 117833.97042410714
# [+]Epoch 489 - Av.Training loss 15758.93337102522 - Av.Validation loss 121578.08649553571
# [+]Epoch 490 - Av.Training loss 16421.537434895832 - Av.Validation loss 129045.07756696429
# [+]Epoch 491 - Av.Training loss 19361.604132401317 - Av.Validation loss 124048.22209821429
# [+]Epoch 492 - Av.Training loss 21356.80431058114 - Av.Validation loss 111182.41964285714
# [+]Epoch 493 - Av.Training loss 16976.961245888157 - Av.Validation loss 115436.86530412946
# [+]Epoch 494 - Av.Training loss 22264.28080455044 - Av.Validation loss 120999.02678571429
# [+]Epoch 495 - Av.Training loss 18824.78071888706 - Av.Validation loss 118340.67410714286
# [+]Epoch 496 - Av.Training loss 18835.943222313595 - Av.Validation loss 123333.35993303571
# [+]Epoch 497 - Av.Training loss 18033.615577028508 - Av.Validation loss 112172.36830357143
# [+]Epoch 498 - Av.Training loss 16362.013003700658 - Av.Validation loss 115297.80301339286
# [+]Epoch 499 - Av.Training loss 19822.965905975878 - Av.Validation loss 119027.86495535714
# [+]Epoch 500 - Av.Training loss 16538.844812225878 - Av.Validation loss 111016.92299107143

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Cargar modelo
model = torch.load(f"{ruta_modelo}model_resnet50_l2_lambda5.pth")
# Out:
# C:\Users\Lab.Comp 1\AppData\Local\Temp\ipykernel_12940\3065701310.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"{ruta_modelo}model_resnet50_l2_lambda5.pth")

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bedrooms  bathrooms  area  zipcode mosaic_image   price
# 0         3        2.0  1490    94501      192.png  949000
# 1         5        5.0  4014    92880      301.png  542000
# 2         5        3.0  2179    94531      520.png  430000
# 3         3        2.0  1200    60016       79.png  224900
# 4         2        2.0  1152    92276      332.png  138500

# %%
# Crear dataset
test_data = CustomImageDataset(df=test, transform=transforms.Compose([
    transforms.Resize(256),                               # Redimensionar a 256x256
    transforms.CenterCrop(224),                           # Recortar al centro para obtener 224x224
    transforms.ToTensor(),                                # Convertir la imagen a un tensor
    transforms.Normalize(
        (0.485, 0.456, 0.406),                            # Media de ImageNet
        (0.229, 0.224, 0.225)                             # Desviación estándar de ImageNet
    )
]))

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 641062.8125, Valor real: 949000.0
# Predicción: 680444.1875, Valor real: 542000.0
# Predicción: 644940.8125, Valor real: 430000.0
# Predicción: 217291.84375, Valor real: 224900.0
# Predicción: 287684.1875, Valor real: 138500.0
# Predicción: 713242.4375, Valor real: 699999.0
# Predicción: 363505.125, Valor real: 78000.0
# Predicción: 537538.8125, Valor real: 245000.0
# Predicción: 511172.28125, Valor real: 599900.0
# Predicción: 590166.5625, Valor real: 495000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 199138.8594
# MAE en el conjunto de prueba: 148581.7500

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
