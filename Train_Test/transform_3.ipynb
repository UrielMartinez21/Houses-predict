# %%
"""
Cambios en la arquitectura de la red neuronal convolucional

    - Cambio de tamaño de kernel de 5x5 a 3x3
    - Modificacion de funcion de optimizacion, se agrego regularizacion L2
    - Se cambio el valor de 0.5 a 0.8 en randomVerticalFlip y randomHorizontalFlip
"""

# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %%
# --> Definir si viene desde local o drive

ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')
train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))       # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')                         # Quitar los ejes
    plt.show()

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        """
        Las convoluciones más pequeñas, como de tamaño 3x3, son útiles para capturar características más detalladas.
        Al combinar capas de convoluciones más pequeñas (en lugar de kernels grandes como 5x5), el modelo puede aprender
        mejor características complejas a través de múltiples capas.
        """
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),   # Convolución más pequeña
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # Pooling
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=3, padding=1),           # Otra convolución 3x3
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(),                                           # Dropout para regularización

            nn.Conv2d(128, 128, kernel_size=3, padding=1),          # Convolución 3x3 más profunda
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(128, 64, kernel_size=3, padding=1),           # Última convolución 3x3
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(37440, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 64*24*24)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            # Valores a proar: 0.05, 0.01, 0.001
            l2_lambda = 0.05
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones
data1 = CustomImageDataset(df=train)

# Dataset con transformación de normalización
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desplazamiento de canales y normalización
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),    # Cambiar los canales RGB a BGR
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                        # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                         # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo horizontal y normalización
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.8),            # Girar horizontalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo vertical y normalización
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=0.8),              # Girar verticalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desenfoque gaussiano y normalización
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Imagen Original', 'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    if i == 1:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}")
    else:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data1, data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 2597 Val: 289

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data1, data2, data3, data4, data5, data6

# %%
# --> Crear los dataloaders
batch_size_train = 53
batch_size_val = 17
# batch_size=64

train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True, drop_last=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 2597 - Baches 49
# Muestras de test: 289 - Baches 17

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
# optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda

# %%
# Entrenamiento
n_epochs = 175
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 103, Batch 45/49, Batch Loss: 106641.3203
# Epoch 103, Batch 46/49, Batch Loss: 62697.2891
# Epoch 103, Batch 47/49, Batch Loss: 84044.0703
# Epoch 103, Batch 48/49, Batch Loss: 86852.8984
# Epoch 103, Batch 49/49, Batch Loss: 98867.5625
# Batch 1/17, Batch Loss: 236197.3750
# Batch 2/17, Batch Loss: 301791.9375
# Batch 3/17, Batch Loss: 199166.0938
# Batch 4/17, Batch Loss: 291984.9375
# Batch 5/17, Batch Loss: 175252.2656
# Batch 6/17, Batch Loss: 308534.1875
# Batch 7/17, Batch Loss: 206394.6875
# Batch 8/17, Batch Loss: 816275.8750
# Batch 9/17, Batch Loss: 278255.5000
# Batch 10/17, Batch Loss: 108969.9766
# Batch 11/17, Batch Loss: 444241.9062
# Batch 12/17, Batch Loss: 461676.5312
# Batch 13/17, Batch Loss: 148178.1562
# Batch 14/17, Batch Loss: 185547.5312
# Batch 15/17, Batch Loss: 109574.2891
# Batch 16/17, Batch Loss: 324669.0000
# Batch 17/17, Batch Loss: 173572.9375
# Test Error:
#  Avg loss: 280604.893382, Avg error: 187152.063581
#
# Epoch 104, Batch 1/49, Batch Loss: 115205.3750
# Epoch 104, Batch 2/49, Batch Loss: 72960.5000
# Epoch 104, Batch 3/49, Batch Loss: 85546.7969
# Epoch 104, Batch 4/49, Batch Loss: 72817.9688
# Epoch 104, Batch 5/49, Batch Loss: 90680.2734
# Epoch 104, Batch 6/49, Batch Loss: 118805.7188
# Epoch 104, Batch 7/49, Batch Loss: 73193.2109
# Epoch 104, Batch 8/49, Batch Loss: 81455.1797
# Epoch 104, Batch 9/49, Batch Loss: 85655.0547
# Epoch 104, Batch 10/49, Batch Loss: 94682.5156
# Epoch 104, Batch 11/49, Batch Loss: 99456.5781
# Epoch 104, Batch 12/49, Batch Loss: 110580.7344
# Epoch 104, Batch 13/49, Batch Loss: 75988.3750
# Epoch 104, Batch 14/49, Batch Loss: 157946.4219
# Epoch 104, Batch 15/49, Batch Loss: 86728.1328
# Epoch 104, Batch 16/49, Batch Loss: 114025.7578
# Epoch 104, Batch 17/49, Batch Loss: 108676.3359
# Epoch 104, Batch 18/49, Batch Loss: 100782.9453
# Epoch 104, Batch 19/49, Batch Loss: 73005.5000
# Epoch 104, Batch 20/49, Batch Loss: 66910.5781
# Epoch 104, Batch 21/49, Batch Loss: 124440.4844
# Epoch 104, Batch 22/49, Batch Loss: 125402.1406
# Epoch 104, Batch 23/49, Batch Loss: 102616.9062
# Epoch 104, Batch 24/49, Batch Loss: 125759.8047
# Epoch 104, Batch 25/49, Batch Loss: 104608.4453
# Epoch 104, Batch 26/49, Batch Loss: 98052.4297
# Epoch 104, Batch 27/49, Batch Loss: 85783.4141
# Epoch 104, Batch 28/49, Batch Loss: 66677.6250
# Epoch 104, Batch 29/49, Batch Loss: 90084.9062
# Epoch 104, Batch 30/49, Batch Loss: 97109.5000
# Epoch 104, Batch 31/49, Batch Loss: 93120.4141
# Epoch 104, Batch 32/49, Batch Loss: 71144.2578
# Epoch 104, Batch 33/49, Batch Loss: 52996.8828
# Epoch 104, Batch 34/49, Batch Loss: 79973.4688
# Epoch 104, Batch 35/49, Batch Loss: 78646.8984
# Epoch 104, Batch 36/49, Batch Loss: 76242.1797
# Epoch 104, Batch 37/49, Batch Loss: 62280.1055
# Epoch 104, Batch 38/49, Batch Loss: 62983.5703
# Epoch 104, Batch 39/49, Batch Loss: 76562.1094
# Epoch 104, Batch 40/49, Batch Loss: 105926.1797
# Epoch 104, Batch 41/49, Batch Loss: 104363.1094
# Epoch 104, Batch 42/49, Batch Loss: 96214.7969
# Epoch 104, Batch 43/49, Batch Loss: 77954.7344
# Epoch 104, Batch 44/49, Batch Loss: 53591.9961
# Epoch 104, Batch 45/49, Batch Loss: 73327.6719
# Epoch 104, Batch 46/49, Batch Loss: 80751.5078
# Epoch 104, Batch 47/49, Batch Loss: 67264.4219
# Epoch 104, Batch 48/49, Batch Loss: 78412.9062
# Epoch 104, Batch 49/49, Batch Loss: 63456.3594
# Batch 1/17, Batch Loss: 180660.1094
# Batch 2/17, Batch Loss: 254585.1875
# Batch 3/17, Batch Loss: 177069.4219
# Batch 4/17, Batch Loss: 265414.6250
# Batch 5/17, Batch Loss: 138541.9375
# Batch 6/17, Batch Loss: 228807.4219
# Batch 7/17, Batch Loss: 219340.6094
# Batch 8/17, Batch Loss: 771734.5000
# Batch 9/17, Batch Loss: 214412.6875
# Batch 10/17, Batch Loss: 88077.9141
# Batch 11/17, Batch Loss: 392912.2188
# Batch 12/17, Batch Loss: 300121.7500
# Batch 13/17, Batch Loss: 137528.2031
# Batch 14/17, Batch Loss: 114231.0312
# Batch 15/17, Batch Loss: 120462.3672
# Batch 16/17, Batch Loss: 296692.1562
# Batch 17/17, Batch Loss: 129238.0703
# Test Error:
#  Avg loss: 237048.835938, Avg error: 147075.464533
#
# Epoch 105, Batch 1/49, Batch Loss: 100534.3906
# Epoch 105, Batch 2/49, Batch Loss: 83162.8438
# Epoch 105, Batch 3/49, Batch Loss: 72525.0469
# Epoch 105, Batch 4/49, Batch Loss: 82297.9453
# Epoch 105, Batch 5/49, Batch Loss: 96494.6328
# Epoch 105, Batch 6/49, Batch Loss: 80903.3438
# Epoch 105, Batch 7/49, Batch Loss: 78431.0234
# Epoch 105, Batch 8/49, Batch Loss: 112475.7969
# Epoch 105, Batch 9/49, Batch Loss: 74699.0781
# Epoch 105, Batch 10/49, Batch Loss: 69822.6328
# Epoch 105, Batch 11/49, Batch Loss: 70613.0312
# Epoch 105, Batch 12/49, Batch Loss: 56575.6328
# Epoch 105, Batch 13/49, Batch Loss: 71923.9062
# Epoch 105, Batch 14/49, Batch Loss: 70807.5391
# Epoch 105, Batch 15/49, Batch Loss: 78007.0000
# Epoch 105, Batch 16/49, Batch Loss: 70623.5781
# Epoch 105, Batch 17/49, Batch Loss: 62598.6758
# Epoch 105, Batch 18/49, Batch Loss: 86262.9609
# Epoch 105, Batch 19/49, Batch Loss: 82660.8203
# Epoch 105, Batch 20/49, Batch Loss: 81147.9766
# Epoch 105, Batch 21/49, Batch Loss: 129070.8594
# Epoch 105, Batch 22/49, Batch Loss: 71903.9531
# Epoch 105, Batch 23/49, Batch Loss: 77359.4375
# Epoch 105, Batch 24/49, Batch Loss: 162009.8594
# Epoch 105, Batch 25/49, Batch Loss: 118269.6641
# Epoch 105, Batch 26/49, Batch Loss: 97420.0156
# Epoch 105, Batch 27/49, Batch Loss: 65199.3867
# Epoch 105, Batch 28/49, Batch Loss: 70465.6406
# Epoch 105, Batch 29/49, Batch Loss: 100796.2812
# Epoch 105, Batch 30/49, Batch Loss: 111484.6172
# Epoch 105, Batch 31/49, Batch Loss: 97881.3828
# Epoch 105, Batch 32/49, Batch Loss: 111271.4609
# Epoch 105, Batch 33/49, Batch Loss: 97400.7734
# Epoch 105, Batch 34/49, Batch Loss: 61400.7266
# Epoch 105, Batch 35/49, Batch Loss: 86609.9766
# Epoch 105, Batch 36/49, Batch Loss: 94545.8359
# Epoch 105, Batch 37/49, Batch Loss: 96386.8750
# Epoch 105, Batch 38/49, Batch Loss: 71688.0156
# Epoch 105, Batch 39/49, Batch Loss: 64381.0000
# Epoch 105, Batch 40/49, Batch Loss: 58052.9883
# Epoch 105, Batch 41/49, Batch Loss: 66684.1406
# Epoch 105, Batch 42/49, Batch Loss: 64700.6836
# Epoch 105, Batch 43/49, Batch Loss: 61214.2969
# Epoch 105, Batch 44/49, Batch Loss: 75192.1719
# Epoch 105, Batch 45/49, Batch Loss: 70037.9688
# Epoch 105, Batch 46/49, Batch Loss: 80114.1484
# Epoch 105, Batch 47/49, Batch Loss: 115213.0938
# Epoch 105, Batch 48/49, Batch Loss: 60924.5352
# Epoch 105, Batch 49/49, Batch Loss: 75670.4531
# Batch 1/17, Batch Loss: 181019.8906
# Batch 2/17, Batch Loss: 247871.7812
# Batch 3/17, Batch Loss: 154614.4375
# Batch 4/17, Batch Loss: 256426.1250
# Batch 5/17, Batch Loss: 134649.8594
# Batch 6/17, Batch Loss: 233300.0781
# Batch 7/17, Batch Loss: 210185.8906
# Batch 8/17, Batch Loss: 781821.0625
# Batch 9/17, Batch Loss: 223362.6094
# Batch 10/17, Batch Loss: 77312.7344
# Batch 11/17, Batch Loss: 387014.5938
# Batch 12/17, Batch Loss: 422870.9375
# Batch 13/17, Batch Loss: 142509.9688
# Batch 14/17, Batch Loss: 107824.9375
# Batch 15/17, Batch Loss: 103202.1719
# Batch 16/17, Batch Loss: 302784.6250
# Batch 17/17, Batch Loss: 92318.1016
# Test Error:
#  Avg loss: 238769.988511, Avg error: 141585.426903
#
# Epoch 106, Batch 1/49, Batch Loss: 94845.0781
# Epoch 106, Batch 2/49, Batch Loss: 68058.3359
# Epoch 106, Batch 3/49, Batch Loss: 70228.4375
# Epoch 106, Batch 4/49, Batch Loss: 77794.7734
# Epoch 106, Batch 5/49, Batch Loss: 69495.3359
# Epoch 106, Batch 6/49, Batch Loss: 63465.0039
# Epoch 106, Batch 7/49, Batch Loss: 77522.5781
# Epoch 106, Batch 8/49, Batch Loss: 89299.7891
# Epoch 106, Batch 9/49, Batch Loss: 90819.5234
# Epoch 106, Batch 10/49, Batch Loss: 77156.8203
# Epoch 106, Batch 11/49, Batch Loss: 98538.0781
# Epoch 106, Batch 12/49, Batch Loss: 64025.0195
# Epoch 106, Batch 13/49, Batch Loss: 76095.3125
# Epoch 106, Batch 14/49, Batch Loss: 97389.0938
# Epoch 106, Batch 15/49, Batch Loss: 68099.5000
# Epoch 106, Batch 16/49, Batch Loss: 82001.0625
# Epoch 106, Batch 17/49, Batch Loss: 74332.0312
# Epoch 106, Batch 18/49, Batch Loss: 83896.0156
# Epoch 106, Batch 19/49, Batch Loss: 77639.2734
# Epoch 106, Batch 20/49, Batch Loss: 63058.0977
# Epoch 106, Batch 21/49, Batch Loss: 120034.1875
# Epoch 106, Batch 22/49, Batch Loss: 63395.3516
# Epoch 106, Batch 23/49, Batch Loss: 68484.2266
# Epoch 106, Batch 24/49, Batch Loss: 62285.3320
# Epoch 106, Batch 25/49, Batch Loss: 102105.4141
# Epoch 106, Batch 26/49, Batch Loss: 89628.4922
# Epoch 106, Batch 27/49, Batch Loss: 125612.7734
# Epoch 106, Batch 28/49, Batch Loss: 87152.8672
# Epoch 106, Batch 29/49, Batch Loss: 75076.5859
# Epoch 106, Batch 30/49, Batch Loss: 101987.6875
# Epoch 106, Batch 31/49, Batch Loss: 57592.8047
# Epoch 106, Batch 32/49, Batch Loss: 119722.1250
# Epoch 106, Batch 33/49, Batch Loss: 63222.0977
# Epoch 106, Batch 34/49, Batch Loss: 69291.5859
# Epoch 106, Batch 35/49, Batch Loss: 64571.7656
# Epoch 106, Batch 36/49, Batch Loss: 55650.0273
# Epoch 106, Batch 37/49, Batch Loss: 84447.0391
# Epoch 106, Batch 38/49, Batch Loss: 53208.2227
# Epoch 106, Batch 39/49, Batch Loss: 70069.0938
# Epoch 106, Batch 40/49, Batch Loss: 52120.8125
# Epoch 106, Batch 41/49, Batch Loss: 75754.8438
# Epoch 106, Batch 42/49, Batch Loss: 104492.7188
# Epoch 106, Batch 43/49, Batch Loss: 68310.3125
# Epoch 106, Batch 44/49, Batch Loss: 70969.5469
# Epoch 106, Batch 45/49, Batch Loss: 59883.7344
# Epoch 106, Batch 46/49, Batch Loss: 80728.5547
# Epoch 106, Batch 47/49, Batch Loss: 74332.4766
# Epoch 106, Batch 48/49, Batch Loss: 89767.3281
# Epoch 106, Batch 49/49, Batch Loss: 63820.7031
# Batch 1/17, Batch Loss: 191224.9375
# Batch 2/17, Batch Loss: 285610.2188
# Batch 3/17, Batch Loss: 174671.0000
# Batch 4/17, Batch Loss: 263943.7812
# Batch 5/17, Batch Loss: 126689.6016
# Batch 6/17, Batch Loss: 232223.9531
# Batch 7/17, Batch Loss: 206057.0625
# Batch 8/17, Batch Loss: 765778.8750
# Batch 9/17, Batch Loss: 224177.0938
# Batch 10/17, Batch Loss: 82573.5391
# Batch 11/17, Batch Loss: 389941.9062
# Batch 12/17, Batch Loss: 288965.8438
# Batch 13/17, Batch Loss: 134923.5625
# Batch 14/17, Batch Loss: 146234.2031
# Batch 15/17, Batch Loss: 105915.9766
# Batch 16/17, Batch Loss: 289854.7500
# Batch 17/17, Batch Loss: 149257.7031
# Test Error:
#  Avg loss: 238708.471048, Avg error: 145961.255190
#
# Epoch 107, Batch 1/49, Batch Loss: 104486.0156
# Epoch 107, Batch 2/49, Batch Loss: 72432.4844
# Epoch 107, Batch 3/49, Batch Loss: 67138.7031
# Epoch 107, Batch 4/49, Batch Loss: 78640.3750
# Epoch 107, Batch 5/49, Batch Loss: 82092.0781
# Epoch 107, Batch 6/49, Batch Loss: 117017.1641
# Epoch 107, Batch 7/49, Batch Loss: 61112.0391
# Epoch 107, Batch 8/49, Batch Loss: 160110.2031
# Epoch 107, Batch 9/49, Batch Loss: 88032.1641
# Epoch 107, Batch 10/49, Batch Loss: 80530.8906
# Epoch 107, Batch 11/49, Batch Loss: 92679.0781
# Epoch 107, Batch 12/49, Batch Loss: 65500.8008
# Epoch 107, Batch 13/49, Batch Loss: 74304.0703
# Epoch 107, Batch 14/49, Batch Loss: 72733.6875
# Epoch 107, Batch 15/49, Batch Loss: 80356.4609
# Epoch 107, Batch 16/49, Batch Loss: 73133.3359
# Epoch 107, Batch 17/49, Batch Loss: 84930.9297
# Epoch 107, Batch 18/49, Batch Loss: 92515.1094
# Epoch 107, Batch 19/49, Batch Loss: 101745.4844
# Epoch 107, Batch 20/49, Batch Loss: 76989.2266
# Epoch 107, Batch 21/49, Batch Loss: 124386.3281
# Epoch 107, Batch 22/49, Batch Loss: 108554.7812
# Epoch 107, Batch 23/49, Batch Loss: 75656.8438
# Epoch 107, Batch 24/49, Batch Loss: 115043.3359
# Epoch 107, Batch 25/49, Batch Loss: 66170.7344
# Epoch 107, Batch 26/49, Batch Loss: 55752.2930
# Epoch 107, Batch 27/49, Batch Loss: 86266.1953
# Epoch 107, Batch 28/49, Batch Loss: 82089.5000
# Epoch 107, Batch 29/49, Batch Loss: 80505.2344
# Epoch 107, Batch 30/49, Batch Loss: 67190.7578
# Epoch 107, Batch 31/49, Batch Loss: 73608.5312
# Epoch 107, Batch 32/49, Batch Loss: 114614.8750
# Epoch 107, Batch 33/49, Batch Loss: 59496.9062
# Epoch 107, Batch 34/49, Batch Loss: 64124.2734
# Epoch 107, Batch 35/49, Batch Loss: 82721.5078
# Epoch 107, Batch 36/49, Batch Loss: 75517.0234
# Epoch 107, Batch 37/49, Batch Loss: 94472.8047
# Epoch 107, Batch 38/49, Batch Loss: 58342.2695
# Epoch 107, Batch 39/49, Batch Loss: 84593.4453
# Epoch 107, Batch 40/49, Batch Loss: 82909.8750
# Epoch 107, Batch 41/49, Batch Loss: 60979.5977
# Epoch 107, Batch 42/49, Batch Loss: 61427.0430
# Epoch 107, Batch 43/49, Batch Loss: 65691.3594
# Epoch 107, Batch 44/49, Batch Loss: 78804.1875
# Epoch 107, Batch 45/49, Batch Loss: 213760.9531
# Epoch 107, Batch 46/49, Batch Loss: 54108.8281
# Epoch 107, Batch 47/49, Batch Loss: 62358.4062
# Epoch 107, Batch 48/49, Batch Loss: 98462.5312
# Epoch 107, Batch 49/49, Batch Loss: 63139.9805
# Batch 1/17, Batch Loss: 166525.2188
# Batch 2/17, Batch Loss: 263611.1250
# Batch 3/17, Batch Loss: 134301.9219
# Batch 4/17, Batch Loss: 265322.7500
# Batch 5/17, Batch Loss: 115761.8203
# Batch 6/17, Batch Loss: 215700.6719
# Batch 7/17, Batch Loss: 204607.8750
# Batch 8/17, Batch Loss: 776679.2500
# Batch 9/17, Batch Loss: 198855.0781
# Batch 10/17, Batch Loss: 81245.6094
# Batch 11/17, Batch Loss: 409241.3750
# Batch 12/17, Batch Loss: 408097.1875
# Batch 13/17, Batch Loss: 139841.9844
# Batch 14/17, Batch Loss: 123571.8203
# Batch 15/17, Batch Loss: 112180.9141
# Batch 16/17, Batch Loss: 307346.4062
# Batch 17/17, Batch Loss: 115838.0234
# Test Error:
#  Avg loss: 237572.295956, Avg error: 138053.769464
#
# Epoch 108, Batch 1/49, Batch Loss: 69193.9609
# Epoch 108, Batch 2/49, Batch Loss: 59211.1445
# Epoch 108, Batch 3/49, Batch Loss: 89424.0625
# Epoch 108, Batch 4/49, Batch Loss: 61937.4766
# Epoch 108, Batch 5/49, Batch Loss: 53862.6914
# Epoch 108, Batch 6/49, Batch Loss: 76961.4375
# Epoch 108, Batch 7/49, Batch Loss: 60400.9102
# Epoch 108, Batch 8/49, Batch Loss: 82598.7422
# Epoch 108, Batch 9/49, Batch Loss: 86222.0312
# Epoch 108, Batch 10/49, Batch Loss: 74408.1172
# Epoch 108, Batch 11/49, Batch Loss: 77689.7031
# Epoch 108, Batch 12/49, Batch Loss: 77870.5156
# Epoch 108, Batch 13/49, Batch Loss: 76935.8984
# Epoch 108, Batch 14/49, Batch Loss: 69722.4141
# Epoch 108, Batch 15/49, Batch Loss: 59913.6367
# Epoch 108, Batch 16/49, Batch Loss: 90580.6875
# Epoch 108, Batch 17/49, Batch Loss: 67213.7812
# Epoch 108, Batch 18/49, Batch Loss: 72068.6875
# Epoch 108, Batch 19/49, Batch Loss: 83991.8203
# Epoch 108, Batch 20/49, Batch Loss: 136677.0938
# Epoch 108, Batch 21/49, Batch Loss: 78205.3516
# Epoch 108, Batch 22/49, Batch Loss: 88346.2578
# Epoch 108, Batch 23/49, Batch Loss: 77373.2188
# Epoch 108, Batch 24/49, Batch Loss: 84637.4297
# Epoch 108, Batch 25/49, Batch Loss: 79881.1172
# Epoch 108, Batch 26/49, Batch Loss: 80846.9844
# Epoch 108, Batch 27/49, Batch Loss: 67541.5703
# Epoch 108, Batch 28/49, Batch Loss: 64846.9609
# Epoch 108, Batch 29/49, Batch Loss: 67548.6484
# Epoch 108, Batch 30/49, Batch Loss: 112519.1328
# Epoch 108, Batch 31/49, Batch Loss: 82604.6484
# Epoch 108, Batch 32/49, Batch Loss: 74000.4688
# Epoch 108, Batch 33/49, Batch Loss: 64127.5547
# Epoch 108, Batch 34/49, Batch Loss: 64130.7188
# Epoch 108, Batch 35/49, Batch Loss: 103966.5000
# Epoch 108, Batch 36/49, Batch Loss: 77721.9297
# Epoch 108, Batch 37/49, Batch Loss: 67231.1719
# Epoch 108, Batch 38/49, Batch Loss: 73687.6797
# Epoch 108, Batch 39/49, Batch Loss: 62684.0195
# Epoch 108, Batch 40/49, Batch Loss: 113429.1094
# Epoch 108, Batch 41/49, Batch Loss: 70606.0078
# Epoch 108, Batch 42/49, Batch Loss: 79568.2734
# Epoch 108, Batch 43/49, Batch Loss: 103739.0938
# Epoch 108, Batch 44/49, Batch Loss: 81043.4375
# Epoch 108, Batch 45/49, Batch Loss: 79501.7031
# Epoch 108, Batch 46/49, Batch Loss: 120095.9375
# Epoch 108, Batch 47/49, Batch Loss: 83080.9922
# Epoch 108, Batch 48/49, Batch Loss: 73335.8125
# Epoch 108, Batch 49/49, Batch Loss: 112799.7969
# Batch 1/17, Batch Loss: 152163.7812
# Batch 2/17, Batch Loss: 289218.0312
# Batch 3/17, Batch Loss: 180673.0469
# Batch 4/17, Batch Loss: 302875.0625
# Batch 5/17, Batch Loss: 164647.3125
# Batch 6/17, Batch Loss: 265290.1562
# Batch 7/17, Batch Loss: 214060.9375
# Batch 8/17, Batch Loss: 804110.5000
# Batch 9/17, Batch Loss: 241345.4844
# Batch 10/17, Batch Loss: 102122.1719
# Batch 11/17, Batch Loss: 407681.3438
# Batch 12/17, Batch Loss: 452071.1250
# Batch 13/17, Batch Loss: 119243.8281
# Batch 14/17, Batch Loss: 180812.4062
# Batch 15/17, Batch Loss: 109787.7031
# Batch 16/17, Batch Loss: 325457.0625
# Batch 17/17, Batch Loss: 156786.9219
# Test Error:
#  Avg loss: 262843.933824, Avg error: 166033.176471
#
# Epoch 109, Batch 1/49, Batch Loss: 73450.2109
# Epoch 109, Batch 2/49, Batch Loss: 91168.1016
# Epoch 109, Batch 3/49, Batch Loss: 105652.0000
# Epoch 109, Batch 4/49, Batch Loss: 107116.2188
# Epoch 109, Batch 5/49, Batch Loss: 95055.7109
# Epoch 109, Batch 6/49, Batch Loss: 94861.2188
# Epoch 109, Batch 7/49, Batch Loss: 85364.3438
# Epoch 109, Batch 8/49, Batch Loss: 77330.9062
# Epoch 109, Batch 9/49, Batch Loss: 70150.3984
# Epoch 109, Batch 10/49, Batch Loss: 55609.7305
# Epoch 109, Batch 11/49, Batch Loss: 106290.6719
# Epoch 109, Batch 12/49, Batch Loss: 84987.1016
# Epoch 109, Batch 13/49, Batch Loss: 72369.2500
# Epoch 109, Batch 14/49, Batch Loss: 64971.0273
# Epoch 109, Batch 15/49, Batch Loss: 56363.2305
# Epoch 109, Batch 16/49, Batch Loss: 47894.9180
# Epoch 109, Batch 17/49, Batch Loss: 76643.8906
# Epoch 109, Batch 18/49, Batch Loss: 61195.0703
# Epoch 109, Batch 19/49, Batch Loss: 71866.1094
# Epoch 109, Batch 20/49, Batch Loss: 71210.5000
# Epoch 109, Batch 21/49, Batch Loss: 110868.9062
# Epoch 109, Batch 22/49, Batch Loss: 60185.6719
# Epoch 109, Batch 23/49, Batch Loss: 83834.9844
# Epoch 109, Batch 24/49, Batch Loss: 71422.0859
# Epoch 109, Batch 25/49, Batch Loss: 82499.9297
# Epoch 109, Batch 26/49, Batch Loss: 195585.5938
# Epoch 109, Batch 27/49, Batch Loss: 68929.7734
# Epoch 109, Batch 28/49, Batch Loss: 75187.2188
# Epoch 109, Batch 29/49, Batch Loss: 53955.1055
# Epoch 109, Batch 30/49, Batch Loss: 84250.5156
# Epoch 109, Batch 31/49, Batch Loss: 63440.0430
# Epoch 109, Batch 32/49, Batch Loss: 136483.1719
# Epoch 109, Batch 33/49, Batch Loss: 66058.2266
# Epoch 109, Batch 34/49, Batch Loss: 69779.0000
# Epoch 109, Batch 35/49, Batch Loss: 86916.9688
# Epoch 109, Batch 36/49, Batch Loss: 85233.2969
# Epoch 109, Batch 37/49, Batch Loss: 91136.5234
# Epoch 109, Batch 38/49, Batch Loss: 83145.3203
# Epoch 109, Batch 39/49, Batch Loss: 55313.9219
# Epoch 109, Batch 40/49, Batch Loss: 76532.4141
# Epoch 109, Batch 41/49, Batch Loss: 85829.4453
# Epoch 109, Batch 42/49, Batch Loss: 119961.1328
# Epoch 109, Batch 43/49, Batch Loss: 74779.6094
# Epoch 109, Batch 44/49, Batch Loss: 65267.2266
# Epoch 109, Batch 45/49, Batch Loss: 45963.7539
# Epoch 109, Batch 46/49, Batch Loss: 93472.1094
# Epoch 109, Batch 47/49, Batch Loss: 83872.9688
# Epoch 109, Batch 48/49, Batch Loss: 96915.9531
# Epoch 109, Batch 49/49, Batch Loss: 80853.7500
# Batch 1/17, Batch Loss: 191295.3438
# Batch 2/17, Batch Loss: 309399.4062
# Batch 3/17, Batch Loss: 151488.4531
# Batch 4/17, Batch Loss: 280553.6250
# Batch 5/17, Batch Loss: 137935.9531
# Batch 6/17, Batch Loss: 255532.0625
# Batch 7/17, Batch Loss: 225845.9688
# Batch 8/17, Batch Loss: 146954.4531
# Batch 9/17, Batch Loss: 255745.4375
# Batch 10/17, Batch Loss: 120626.3828
# Batch 11/17, Batch Loss: 336489.7188
# Batch 12/17, Batch Loss: 463689.6562
# Batch 13/17, Batch Loss: 117808.9375
# Batch 14/17, Batch Loss: 137056.5469
# Batch 15/17, Batch Loss: 96782.0078
# Batch 16/17, Batch Loss: 320368.0625
# Batch 17/17, Batch Loss: 161927.8594
# Test Error:
#  Avg loss: 218205.875000, Avg error: 149024.633651
#
# Epoch 110, Batch 1/49, Batch Loss: 61164.5547
# Epoch 110, Batch 2/49, Batch Loss: 70589.2891
# Epoch 110, Batch 3/49, Batch Loss: 86281.7656
# Epoch 110, Batch 4/49, Batch Loss: 106919.7812
# Epoch 110, Batch 5/49, Batch Loss: 64780.9102
# Epoch 110, Batch 6/49, Batch Loss: 50402.2578
# Epoch 110, Batch 7/49, Batch Loss: 74691.0312
# Epoch 110, Batch 8/49, Batch Loss: 120480.8984
# Epoch 110, Batch 9/49, Batch Loss: 71584.4844
# Epoch 110, Batch 10/49, Batch Loss: 72158.2812
# Epoch 110, Batch 11/49, Batch Loss: 69822.5469
# Epoch 110, Batch 12/49, Batch Loss: 80886.1953
# Epoch 110, Batch 13/49, Batch Loss: 85168.6875
# Epoch 110, Batch 14/49, Batch Loss: 101924.6094
# Epoch 110, Batch 15/49, Batch Loss: 61137.0938
# Epoch 110, Batch 16/49, Batch Loss: 70069.4219
# Epoch 110, Batch 17/49, Batch Loss: 66704.4922
# Epoch 110, Batch 18/49, Batch Loss: 80176.9141
# Epoch 110, Batch 19/49, Batch Loss: 126974.0859
# Epoch 110, Batch 20/49, Batch Loss: 101667.4922
# Epoch 110, Batch 21/49, Batch Loss: 110666.0859
# Epoch 110, Batch 22/49, Batch Loss: 74296.9219
# Epoch 110, Batch 23/49, Batch Loss: 70675.9219
# Epoch 110, Batch 24/49, Batch Loss: 78871.3828
# Epoch 110, Batch 25/49, Batch Loss: 86160.8828
# Epoch 110, Batch 26/49, Batch Loss: 73128.4297
# Epoch 110, Batch 27/49, Batch Loss: 71548.7656
# Epoch 110, Batch 28/49, Batch Loss: 76338.6875
# Epoch 110, Batch 29/49, Batch Loss: 78441.7500
# Epoch 110, Batch 30/49, Batch Loss: 76261.2344
# Epoch 110, Batch 31/49, Batch Loss: 96398.0859
# Epoch 110, Batch 32/49, Batch Loss: 80931.1719
# Epoch 110, Batch 33/49, Batch Loss: 105546.2578
# Epoch 110, Batch 34/49, Batch Loss: 179404.7812
# Epoch 110, Batch 35/49, Batch Loss: 174534.0312
# Epoch 110, Batch 36/49, Batch Loss: 82980.3125
# Epoch 110, Batch 37/49, Batch Loss: 87764.0859
# Epoch 110, Batch 38/49, Batch Loss: 100652.8906
# Epoch 110, Batch 39/49, Batch Loss: 89532.3906
# Epoch 110, Batch 40/49, Batch Loss: 63393.2070
# Epoch 110, Batch 41/49, Batch Loss: 93266.9297
# Epoch 110, Batch 42/49, Batch Loss: 64057.6328
# Epoch 110, Batch 43/49, Batch Loss: 99169.2500
# Epoch 110, Batch 44/49, Batch Loss: 124760.6797
# Epoch 110, Batch 45/49, Batch Loss: 117734.9766
# Epoch 110, Batch 46/49, Batch Loss: 130774.4062
# Epoch 110, Batch 47/49, Batch Loss: 91978.0859
# Epoch 110, Batch 48/49, Batch Loss: 57230.0977
# Epoch 110, Batch 49/49, Batch Loss: 93190.6641
# Batch 1/17, Batch Loss: 117026.2812
# Batch 2/17, Batch Loss: 274719.7188
# Batch 3/17, Batch Loss: 147763.6406
# Batch 4/17, Batch Loss: 229036.7500
# Batch 5/17, Batch Loss: 111484.8828
# Batch 6/17, Batch Loss: 184569.3438
# Batch 7/17, Batch Loss: 217742.3750
# Batch 8/17, Batch Loss: 711483.3750
# Batch 9/17, Batch Loss: 190687.9062
# Batch 10/17, Batch Loss: 72675.4141
# Batch 11/17, Batch Loss: 364363.6250
# Batch 12/17, Batch Loss: 394772.7812
# Batch 13/17, Batch Loss: 138960.5469
# Batch 14/17, Batch Loss: 89934.2891
# Batch 15/17, Batch Loss: 140204.5312
# Batch 16/17, Batch Loss: 255264.9375
# Batch 17/17, Batch Loss: 80379.3281
# Test Error:
#  Avg loss: 218886.454504, Avg error: 121229.602509
#
# 2024-10-02 23:21:27.710572 Epoch 110, Average Training loss 88842.34271364796
# Epoch 111, Batch 1/49, Batch Loss: 193188.6562
# Epoch 111, Batch 2/49, Batch Loss: 130264.3125
# Epoch 111, Batch 3/49, Batch Loss: 92889.6094
# Epoch 111, Batch 4/49, Batch Loss: 76064.1719
# Epoch 111, Batch 5/49, Batch Loss: 59008.3984
# Epoch 111, Batch 6/49, Batch Loss: 70816.8203
# Epoch 111, Batch 7/49, Batch Loss: 70288.4688
# Epoch 111, Batch 8/49, Batch Loss: 81982.9141
# Epoch 111, Batch 9/49, Batch Loss: 70642.6094
# Epoch 111, Batch 10/49, Batch Loss: 66026.7734
# Epoch 111, Batch 11/49, Batch Loss: 76928.5781
# Epoch 111, Batch 12/49, Batch Loss: 74423.2031
# Epoch 111, Batch 13/49, Batch Loss: 74290.4062
# Epoch 111, Batch 14/49, Batch Loss: 65723.5312
# Epoch 111, Batch 15/49, Batch Loss: 50244.9453
# Epoch 111, Batch 16/49, Batch Loss: 46867.3516
# Epoch 111, Batch 17/49, Batch Loss: 69005.4531
# Epoch 111, Batch 18/49, Batch Loss: 76008.5156
# Epoch 111, Batch 19/49, Batch Loss: 63822.0586
# Epoch 111, Batch 20/49, Batch Loss: 89413.6719
# Epoch 111, Batch 21/49, Batch Loss: 61957.1797
# Epoch 111, Batch 22/49, Batch Loss: 71654.2266
# Epoch 111, Batch 23/49, Batch Loss: 70630.5859
# Epoch 111, Batch 24/49, Batch Loss: 70043.4219
# Epoch 111, Batch 25/49, Batch Loss: 76440.4922
# Epoch 111, Batch 26/49, Batch Loss: 49539.7344
# Epoch 111, Batch 27/49, Batch Loss: 71930.8672
# Epoch 111, Batch 28/49, Batch Loss: 56978.2734
# Epoch 111, Batch 29/49, Batch Loss: 71015.0859
# Epoch 111, Batch 30/49, Batch Loss: 77969.7109
# Epoch 111, Batch 31/49, Batch Loss: 66858.3906
# Epoch 111, Batch 32/49, Batch Loss: 83424.9844
# Epoch 111, Batch 33/49, Batch Loss: 51834.1484
# Epoch 111, Batch 34/49, Batch Loss: 62962.4883
# Epoch 111, Batch 35/49, Batch Loss: 66513.3125
# Epoch 111, Batch 36/49, Batch Loss: 67827.1250
# Epoch 111, Batch 37/49, Batch Loss: 84713.2500
# Epoch 111, Batch 38/49, Batch Loss: 65151.3711
# Epoch 111, Batch 39/49, Batch Loss: 74965.0703
# Epoch 111, Batch 40/49, Batch Loss: 68664.0469
# Epoch 111, Batch 41/49, Batch Loss: 73970.6094
# Epoch 111, Batch 42/49, Batch Loss: 75135.2031
# Epoch 111, Batch 43/49, Batch Loss: 69875.1328
# Epoch 111, Batch 44/49, Batch Loss: 51267.4570
# Epoch 111, Batch 45/49, Batch Loss: 57514.5508
# Epoch 111, Batch 46/49, Batch Loss: 49525.2656
# Epoch 111, Batch 47/49, Batch Loss: 80385.7188
# Epoch 111, Batch 48/49, Batch Loss: 69128.2656
# Epoch 111, Batch 49/49, Batch Loss: 132094.5312
# Batch 1/17, Batch Loss: 176885.1250
# Batch 2/17, Batch Loss: 281816.2812
# Batch 3/17, Batch Loss: 130267.6719
# Batch 4/17, Batch Loss: 287843.8125
# Batch 5/17, Batch Loss: 143937.5312
# Batch 6/17, Batch Loss: 244836.9375
# Batch 7/17, Batch Loss: 215364.9531
# Batch 8/17, Batch Loss: 786400.4375
# Batch 9/17, Batch Loss: 228499.6875
# Batch 10/17, Batch Loss: 104561.3828
# Batch 11/17, Batch Loss: 387476.5625
# Batch 12/17, Batch Loss: 432807.7500
# Batch 13/17, Batch Loss: 101417.9844
# Batch 14/17, Batch Loss: 131902.2500
# Batch 15/17, Batch Loss: 68967.3672
# Batch 16/17, Batch Loss: 311513.7812
# Batch 17/17, Batch Loss: 141534.9062
# Test Error:
#  Avg loss: 245649.083640, Avg error: 151337.040009
#
# Epoch 112, Batch 1/49, Batch Loss: 189927.4844
# Epoch 112, Batch 2/49, Batch Loss: 62082.5156
# Epoch 112, Batch 3/49, Batch Loss: 82501.5000
# Epoch 112, Batch 4/49, Batch Loss: 73650.1172
# Epoch 112, Batch 5/49, Batch Loss: 60845.1250
# Epoch 112, Batch 6/49, Batch Loss: 55607.6484
# Epoch 112, Batch 7/49, Batch Loss: 55912.4883
# Epoch 112, Batch 8/49, Batch Loss: 64683.4219
# Epoch 112, Batch 9/49, Batch Loss: 76879.3125
# Epoch 112, Batch 10/49, Batch Loss: 52970.0664
# Epoch 112, Batch 11/49, Batch Loss: 57531.0039
# Epoch 112, Batch 12/49, Batch Loss: 89743.7812
# Epoch 112, Batch 13/49, Batch Loss: 71545.1172
# Epoch 112, Batch 14/49, Batch Loss: 77670.8672
# Epoch 112, Batch 15/49, Batch Loss: 67947.1406
# Epoch 112, Batch 16/49, Batch Loss: 67159.0859
# Epoch 112, Batch 17/49, Batch Loss: 95155.0781
# Epoch 112, Batch 18/49, Batch Loss: 87161.1094
# Epoch 112, Batch 19/49, Batch Loss: 56592.1953
# Epoch 112, Batch 20/49, Batch Loss: 82187.6250
# Epoch 112, Batch 21/49, Batch Loss: 77718.5156
# Epoch 112, Batch 22/49, Batch Loss: 68948.0859
# Epoch 112, Batch 23/49, Batch Loss: 74617.1094
# Epoch 112, Batch 24/49, Batch Loss: 185460.4062
# Epoch 112, Batch 25/49, Batch Loss: 64418.9023
# Epoch 112, Batch 26/49, Batch Loss: 75297.8438
# Epoch 112, Batch 27/49, Batch Loss: 85567.7031
# Epoch 112, Batch 28/49, Batch Loss: 90529.9375
# Epoch 112, Batch 29/49, Batch Loss: 76297.6172
# Epoch 112, Batch 30/49, Batch Loss: 75600.3906
# Epoch 112, Batch 31/49, Batch Loss: 69114.3906
# Epoch 112, Batch 32/49, Batch Loss: 57655.5977
# Epoch 112, Batch 33/49, Batch Loss: 61320.8750
# Epoch 112, Batch 34/49, Batch Loss: 103108.9844
# Epoch 112, Batch 35/49, Batch Loss: 89327.6484
# Epoch 112, Batch 36/49, Batch Loss: 83057.8906
# Epoch 112, Batch 37/49, Batch Loss: 82130.7109
# Epoch 112, Batch 38/49, Batch Loss: 84429.8828
# Epoch 112, Batch 39/49, Batch Loss: 66650.0469
# Epoch 112, Batch 40/49, Batch Loss: 78031.1562
# Epoch 112, Batch 41/49, Batch Loss: 65019.3477
# Epoch 112, Batch 42/49, Batch Loss: 80287.5000
# Epoch 112, Batch 43/49, Batch Loss: 62985.9492
# Epoch 112, Batch 44/49, Batch Loss: 64530.4414
# Epoch 112, Batch 45/49, Batch Loss: 63837.3086
# Epoch 112, Batch 46/49, Batch Loss: 87708.8203
# Epoch 112, Batch 47/49, Batch Loss: 98503.0156
# Epoch 112, Batch 48/49, Batch Loss: 56286.9062
# Epoch 112, Batch 49/49, Batch Loss: 82665.3438
# Batch 1/17, Batch Loss: 157717.2656
# Batch 2/17, Batch Loss: 272807.5938
# Batch 3/17, Batch Loss: 155222.0938
# Batch 4/17, Batch Loss: 288386.9688
# Batch 5/17, Batch Loss: 137202.0781
# Batch 6/17, Batch Loss: 230183.7969
# Batch 7/17, Batch Loss: 205621.9062
# Batch 8/17, Batch Loss: 783746.6875
# Batch 9/17, Batch Loss: 231692.4375
# Batch 10/17, Batch Loss: 99430.4453
# Batch 11/17, Batch Loss: 381049.6875
# Batch 12/17, Batch Loss: 434694.4688
# Batch 13/17, Batch Loss: 119663.8516
# Batch 14/17, Batch Loss: 126843.3906
# Batch 15/17, Batch Loss: 117995.1875
# Batch 16/17, Batch Loss: 261317.4062
# Batch 17/17, Batch Loss: 90112.6562
# Test Error:
#  Avg loss: 240805.171875, Avg error: 140792.749567
#
# Epoch 113, Batch 1/49, Batch Loss: 59360.4102
# Epoch 113, Batch 2/49, Batch Loss: 87489.8359
# Epoch 113, Batch 3/49, Batch Loss: 78661.9141
# Epoch 113, Batch 4/49, Batch Loss: 74216.5000
# Epoch 113, Batch 5/49, Batch Loss: 78946.5938
# Epoch 113, Batch 6/49, Batch Loss: 153619.6250
# Epoch 113, Batch 7/49, Batch Loss: 97349.2656
# Epoch 113, Batch 8/49, Batch Loss: 63619.6133
# Epoch 113, Batch 9/49, Batch Loss: 66115.1953
# Epoch 113, Batch 10/49, Batch Loss: 80277.7812
# Epoch 113, Batch 11/49, Batch Loss: 82190.3906
# Epoch 113, Batch 12/49, Batch Loss: 57364.5938
# Epoch 113, Batch 13/49, Batch Loss: 67925.5781
# Epoch 113, Batch 14/49, Batch Loss: 74989.1172
# Epoch 113, Batch 15/49, Batch Loss: 56795.9609
# Epoch 113, Batch 16/49, Batch Loss: 61105.2383
# Epoch 113, Batch 17/49, Batch Loss: 73254.8594
# Epoch 113, Batch 18/49, Batch Loss: 79031.6328
# Epoch 113, Batch 19/49, Batch Loss: 77887.7422
# Epoch 113, Batch 20/49, Batch Loss: 84804.6172
# Epoch 113, Batch 21/49, Batch Loss: 75574.7344
# Epoch 113, Batch 22/49, Batch Loss: 66449.2109
# Epoch 113, Batch 23/49, Batch Loss: 113251.5391
# Epoch 113, Batch 24/49, Batch Loss: 86374.8516
# Epoch 113, Batch 25/49, Batch Loss: 61372.9727
# Epoch 113, Batch 26/49, Batch Loss: 51785.5703
# Epoch 113, Batch 27/49, Batch Loss: 73331.5234
# Epoch 113, Batch 28/49, Batch Loss: 86840.9219
# Epoch 113, Batch 29/49, Batch Loss: 65184.0391
# Epoch 113, Batch 30/49, Batch Loss: 96258.9531
# Epoch 113, Batch 31/49, Batch Loss: 68190.9609
# Epoch 113, Batch 32/49, Batch Loss: 69000.5234
# Epoch 113, Batch 33/49, Batch Loss: 87510.1719
# Epoch 113, Batch 34/49, Batch Loss: 64115.7383
# Epoch 113, Batch 35/49, Batch Loss: 174524.7344
# Epoch 113, Batch 36/49, Batch Loss: 77823.3750
# Epoch 113, Batch 37/49, Batch Loss: 85042.7031
# Epoch 113, Batch 38/49, Batch Loss: 84537.6562
# Epoch 113, Batch 39/49, Batch Loss: 95067.5469
# Epoch 113, Batch 40/49, Batch Loss: 105608.4062
# Epoch 113, Batch 41/49, Batch Loss: 75370.3750
# Epoch 113, Batch 42/49, Batch Loss: 100917.6172
# Epoch 113, Batch 43/49, Batch Loss: 67016.5859
# Epoch 113, Batch 44/49, Batch Loss: 63567.1797
# Epoch 113, Batch 45/49, Batch Loss: 59835.2148
# Epoch 113, Batch 46/49, Batch Loss: 70054.8672
# Epoch 113, Batch 47/49, Batch Loss: 62479.9062
# Epoch 113, Batch 48/49, Batch Loss: 70109.9219
# Epoch 113, Batch 49/49, Batch Loss: 71279.1562
# Batch 1/17, Batch Loss: 195704.2969
# Batch 2/17, Batch Loss: 246520.5625
# Batch 3/17, Batch Loss: 157732.1719
# Batch 4/17, Batch Loss: 260778.8125
# Batch 5/17, Batch Loss: 154903.5625
# Batch 6/17, Batch Loss: 260153.2031
# Batch 7/17, Batch Loss: 213742.7031
# Batch 8/17, Batch Loss: 800054.7500
# Batch 9/17, Batch Loss: 235987.0000
# Batch 10/17, Batch Loss: 109632.3750
# Batch 11/17, Batch Loss: 410888.9688
# Batch 12/17, Batch Loss: 448230.9062
# Batch 13/17, Batch Loss: 115146.8047
# Batch 14/17, Batch Loss: 134192.8281
# Batch 15/17, Batch Loss: 115047.1797
# Batch 16/17, Batch Loss: 311713.9062
# Batch 17/17, Batch Loss: 161001.5156
# Test Error:
#  Avg loss: 254790.090993, Avg error: 160127.001298
#
# Epoch 114, Batch 1/49, Batch Loss: 80345.0156
# Epoch 114, Batch 2/49, Batch Loss: 124465.9688
# Epoch 114, Batch 3/49, Batch Loss: 72294.0469
# Epoch 114, Batch 4/49, Batch Loss: 120939.7109
# Epoch 114, Batch 5/49, Batch Loss: 65655.0469
# Epoch 114, Batch 6/49, Batch Loss: 74063.3125
# Epoch 114, Batch 7/49, Batch Loss: 54359.1094
# Epoch 114, Batch 8/49, Batch Loss: 52511.5586
# Epoch 114, Batch 9/49, Batch Loss: 79593.1797
# Epoch 114, Batch 10/49, Batch Loss: 69506.3359
# Epoch 114, Batch 11/49, Batch Loss: 116280.7891
# Epoch 114, Batch 12/49, Batch Loss: 55355.3008
# Epoch 114, Batch 13/49, Batch Loss: 69366.7812
# Epoch 114, Batch 14/49, Batch Loss: 74709.1484
# Epoch 114, Batch 15/49, Batch Loss: 82290.4922
# Epoch 114, Batch 16/49, Batch Loss: 58858.4727
# Epoch 114, Batch 17/49, Batch Loss: 63096.1992
# Epoch 114, Batch 18/49, Batch Loss: 66012.5234
# Epoch 114, Batch 19/49, Batch Loss: 62774.0273
# Epoch 114, Batch 20/49, Batch Loss: 75203.9766
# Epoch 114, Batch 21/49, Batch Loss: 84595.0000
# Epoch 114, Batch 22/49, Batch Loss: 65342.8945
# Epoch 114, Batch 23/49, Batch Loss: 62143.7148
# Epoch 114, Batch 24/49, Batch Loss: 87487.3906
# Epoch 114, Batch 25/49, Batch Loss: 91877.2969
# Epoch 114, Batch 26/49, Batch Loss: 67496.0547
# Epoch 114, Batch 27/49, Batch Loss: 62042.3320
# Epoch 114, Batch 28/49, Batch Loss: 75093.8125
# Epoch 114, Batch 29/49, Batch Loss: 96599.5391
# Epoch 114, Batch 30/49, Batch Loss: 94460.0234
# Epoch 114, Batch 31/49, Batch Loss: 83754.4375
# Epoch 114, Batch 32/49, Batch Loss: 113284.3281
# Epoch 114, Batch 33/49, Batch Loss: 73215.8594
# Epoch 114, Batch 34/49, Batch Loss: 97501.8906
# Epoch 114, Batch 35/49, Batch Loss: 58480.6719
# Epoch 114, Batch 36/49, Batch Loss: 74536.3594
# Epoch 114, Batch 37/49, Batch Loss: 86338.9219
# Epoch 114, Batch 38/49, Batch Loss: 69404.7969
# Epoch 114, Batch 39/49, Batch Loss: 70809.8750
# Epoch 114, Batch 40/49, Batch Loss: 65123.3047
# Epoch 114, Batch 41/49, Batch Loss: 67661.6328
# Epoch 114, Batch 42/49, Batch Loss: 61605.9062
# Epoch 114, Batch 43/49, Batch Loss: 46758.5586
# Epoch 114, Batch 44/49, Batch Loss: 59831.8828
# Epoch 114, Batch 45/49, Batch Loss: 140208.1562
# Epoch 114, Batch 46/49, Batch Loss: 47550.2656
# Epoch 114, Batch 47/49, Batch Loss: 86597.5312
# Epoch 114, Batch 48/49, Batch Loss: 94774.1406
# Epoch 114, Batch 49/49, Batch Loss: 75749.6484
# Batch 1/17, Batch Loss: 169423.9688
# Batch 2/17, Batch Loss: 214641.1719
# Batch 3/17, Batch Loss: 121015.9766
# Batch 4/17, Batch Loss: 275727.0938
# Batch 5/17, Batch Loss: 131037.9922
# Batch 6/17, Batch Loss: 234044.4062
# Batch 7/17, Batch Loss: 176387.9844
# Batch 8/17, Batch Loss: 776487.3125
# Batch 9/17, Batch Loss: 204035.5312
# Batch 10/17, Batch Loss: 103870.0547
# Batch 11/17, Batch Loss: 373493.4375
# Batch 12/17, Batch Loss: 422649.8125
# Batch 13/17, Batch Loss: 139507.7812
# Batch 14/17, Batch Loss: 103890.0000
# Batch 15/17, Batch Loss: 118076.0703
# Batch 16/17, Batch Loss: 289051.3750
# Batch 17/17, Batch Loss: 124722.4922
# Test Error:
#  Avg loss: 234003.674173, Avg error: 137115.169118
#
# Epoch 115, Batch 1/49, Batch Loss: 65834.5469
# Epoch 115, Batch 2/49, Batch Loss: 74191.9531
# Epoch 115, Batch 3/49, Batch Loss: 65385.4727
# Epoch 115, Batch 4/49, Batch Loss: 61050.6602
# Epoch 115, Batch 5/49, Batch Loss: 66625.0234
# Epoch 115, Batch 6/49, Batch Loss: 68073.3203
# Epoch 115, Batch 7/49, Batch Loss: 66469.8281
# Epoch 115, Batch 8/49, Batch Loss: 84394.3906
# Epoch 115, Batch 9/49, Batch Loss: 80027.9062
# Epoch 115, Batch 10/49, Batch Loss: 73100.5312
# Epoch 115, Batch 11/49, Batch Loss: 87041.1719
# Epoch 115, Batch 12/49, Batch Loss: 82651.1797
# Epoch 115, Batch 13/49, Batch Loss: 81272.1406
# Epoch 115, Batch 14/49, Batch Loss: 87161.8672
# Epoch 115, Batch 15/49, Batch Loss: 89577.0156
# Epoch 115, Batch 16/49, Batch Loss: 75882.2031
# Epoch 115, Batch 17/49, Batch Loss: 72605.3203
# Epoch 115, Batch 18/49, Batch Loss: 54113.0000
# Epoch 115, Batch 19/49, Batch Loss: 92387.1953
# Epoch 115, Batch 20/49, Batch Loss: 47498.6719
# Epoch 115, Batch 21/49, Batch Loss: 56416.8711
# Epoch 115, Batch 22/49, Batch Loss: 74907.3516
# Epoch 115, Batch 23/49, Batch Loss: 80663.3438
# Epoch 115, Batch 24/49, Batch Loss: 91307.6797
# Epoch 115, Batch 25/49, Batch Loss: 59723.5430
# Epoch 115, Batch 26/49, Batch Loss: 61841.6250
# Epoch 115, Batch 27/49, Batch Loss: 97156.4062
# Epoch 115, Batch 28/49, Batch Loss: 76201.5625
# Epoch 115, Batch 29/49, Batch Loss: 71497.6875
# Epoch 115, Batch 30/49, Batch Loss: 78667.6875
# Epoch 115, Batch 31/49, Batch Loss: 77029.9062
# Epoch 115, Batch 32/49, Batch Loss: 76254.1406
# Epoch 115, Batch 33/49, Batch Loss: 68231.0859
# Epoch 115, Batch 34/49, Batch Loss: 76711.5938
# Epoch 115, Batch 35/49, Batch Loss: 62461.3086
# Epoch 115, Batch 36/49, Batch Loss: 72978.0781
# Epoch 115, Batch 37/49, Batch Loss: 57487.3828
# Epoch 115, Batch 38/49, Batch Loss: 50831.5000
# Epoch 115, Batch 39/49, Batch Loss: 98335.9531
# Epoch 115, Batch 40/49, Batch Loss: 78337.8047
# Epoch 115, Batch 41/49, Batch Loss: 53080.8203
# Epoch 115, Batch 42/49, Batch Loss: 78211.4062
# Epoch 115, Batch 43/49, Batch Loss: 63414.2539
# Epoch 115, Batch 44/49, Batch Loss: 46675.2578
# Epoch 115, Batch 45/49, Batch Loss: 58905.4219
# Epoch 115, Batch 46/49, Batch Loss: 139944.5156
# Epoch 115, Batch 47/49, Batch Loss: 77580.6953
# Epoch 115, Batch 48/49, Batch Loss: 71949.3828
# Epoch 115, Batch 49/49, Batch Loss: 94453.8594
# Batch 1/17, Batch Loss: 182933.6875
# Batch 2/17, Batch Loss: 244141.2031
# Batch 3/17, Batch Loss: 139431.7812
# Batch 4/17, Batch Loss: 287459.4062
# Batch 5/17, Batch Loss: 143616.7812
# Batch 6/17, Batch Loss: 233337.0625
# Batch 7/17, Batch Loss: 168891.3750
# Batch 8/17, Batch Loss: 802603.4375
# Batch 9/17, Batch Loss: 232202.9219
# Batch 10/17, Batch Loss: 107763.0938
# Batch 11/17, Batch Loss: 419775.9062
# Batch 12/17, Batch Loss: 428588.8125
# Batch 13/17, Batch Loss: 129514.0156
# Batch 14/17, Batch Loss: 135614.5469
# Batch 15/17, Batch Loss: 61849.5547
# Batch 16/17, Batch Loss: 304731.7500
# Batch 17/17, Batch Loss: 127871.9922
# Test Error:
#  Avg loss: 244136.901654, Avg error: 151338.487024
#
# Epoch 116, Batch 1/49, Batch Loss: 66761.7188
# Epoch 116, Batch 2/49, Batch Loss: 70968.9844
# Epoch 116, Batch 3/49, Batch Loss: 72905.8203
# Epoch 116, Batch 4/49, Batch Loss: 58494.1328
# Epoch 116, Batch 5/49, Batch Loss: 70418.6094
# Epoch 116, Batch 6/49, Batch Loss: 51022.2852
# Epoch 116, Batch 7/49, Batch Loss: 55278.7578
# Epoch 116, Batch 8/49, Batch Loss: 62992.4883
# Epoch 116, Batch 9/49, Batch Loss: 76320.7500
# Epoch 116, Batch 10/49, Batch Loss: 65297.3984
# Epoch 116, Batch 11/49, Batch Loss: 84238.8750
# Epoch 116, Batch 12/49, Batch Loss: 129050.4375
# Epoch 116, Batch 13/49, Batch Loss: 70360.6016
# Epoch 116, Batch 14/49, Batch Loss: 69147.3125
# Epoch 116, Batch 15/49, Batch Loss: 79363.8047
# Epoch 116, Batch 16/49, Batch Loss: 95861.1094
# Epoch 116, Batch 17/49, Batch Loss: 53489.5898
# Epoch 116, Batch 18/49, Batch Loss: 89841.7891
# Epoch 116, Batch 19/49, Batch Loss: 74764.9844
# Epoch 116, Batch 20/49, Batch Loss: 69904.7578
# Epoch 116, Batch 21/49, Batch Loss: 66881.9766
# Epoch 116, Batch 22/49, Batch Loss: 59526.7578
# Epoch 116, Batch 23/49, Batch Loss: 129673.2656
# Epoch 116, Batch 24/49, Batch Loss: 118937.1094
# Epoch 116, Batch 25/49, Batch Loss: 104218.8047
# Epoch 116, Batch 26/49, Batch Loss: 70947.8281
# Epoch 116, Batch 27/49, Batch Loss: 79752.8203
# Epoch 116, Batch 28/49, Batch Loss: 125418.7422
# Epoch 116, Batch 29/49, Batch Loss: 63407.3477
# Epoch 116, Batch 30/49, Batch Loss: 79160.9609
# Epoch 116, Batch 31/49, Batch Loss: 67206.3672
# Epoch 116, Batch 32/49, Batch Loss: 83297.8672
# Epoch 116, Batch 33/49, Batch Loss: 84303.4609
# Epoch 116, Batch 34/49, Batch Loss: 89020.8359
# Epoch 116, Batch 35/49, Batch Loss: 58098.2891
# Epoch 116, Batch 36/49, Batch Loss: 96439.7188
# Epoch 116, Batch 37/49, Batch Loss: 78213.1328
# Epoch 116, Batch 38/49, Batch Loss: 105141.6250
# Epoch 116, Batch 39/49, Batch Loss: 111901.0078
# Epoch 116, Batch 40/49, Batch Loss: 104506.7109
# Epoch 116, Batch 41/49, Batch Loss: 61905.9922
# Epoch 116, Batch 42/49, Batch Loss: 65452.4375
# Epoch 116, Batch 43/49, Batch Loss: 93583.7969
# Epoch 116, Batch 44/49, Batch Loss: 51672.0703
# Epoch 116, Batch 45/49, Batch Loss: 54757.9219
# Epoch 116, Batch 46/49, Batch Loss: 84614.5391
# Epoch 116, Batch 47/49, Batch Loss: 67885.7891
# Epoch 116, Batch 48/49, Batch Loss: 61759.9805
# Epoch 116, Batch 49/49, Batch Loss: 89146.5156
# Batch 1/17, Batch Loss: 202120.8125
# Batch 2/17, Batch Loss: 253594.7500
# Batch 3/17, Batch Loss: 166430.3281
# Batch 4/17, Batch Loss: 309573.4062
# Batch 5/17, Batch Loss: 143288.4531
# Batch 6/17, Batch Loss: 306434.3438
# Batch 7/17, Batch Loss: 163053.0625
# Batch 8/17, Batch Loss: 811879.1875
# Batch 9/17, Batch Loss: 254726.0625
# Batch 10/17, Batch Loss: 117257.2188
# Batch 11/17, Batch Loss: 382890.1562
# Batch 12/17, Batch Loss: 462026.4062
# Batch 13/17, Batch Loss: 113603.9141
# Batch 14/17, Batch Loss: 137645.0469
# Batch 15/17, Batch Loss: 76439.8438
# Batch 16/17, Batch Loss: 316410.8125
# Batch 17/17, Batch Loss: 122060.3281
# Test Error:
#  Avg loss: 255260.831342, Avg error: 162890.502163
#
# Epoch 117, Batch 1/49, Batch Loss: 150501.1406
# Epoch 117, Batch 2/49, Batch Loss: 87425.8203
# Epoch 117, Batch 3/49, Batch Loss: 61399.1758
# Epoch 117, Batch 4/49, Batch Loss: 98359.4688
# Epoch 117, Batch 5/49, Batch Loss: 88575.5938
# Epoch 117, Batch 6/49, Batch Loss: 86218.1250
# Epoch 117, Batch 7/49, Batch Loss: 62484.3867
# Epoch 117, Batch 8/49, Batch Loss: 55621.0586
# Epoch 117, Batch 9/49, Batch Loss: 125842.5859
# Epoch 117, Batch 10/49, Batch Loss: 72751.4297
# Epoch 117, Batch 11/49, Batch Loss: 66460.3047
# Epoch 117, Batch 12/49, Batch Loss: 64769.0547
# Epoch 117, Batch 13/49, Batch Loss: 66447.5938
# Epoch 117, Batch 14/49, Batch Loss: 91170.0547
# Epoch 117, Batch 15/49, Batch Loss: 70258.4297
# Epoch 117, Batch 16/49, Batch Loss: 64299.1992
# Epoch 117, Batch 17/49, Batch Loss: 72787.9219
# Epoch 117, Batch 18/49, Batch Loss: 56610.3906
# Epoch 117, Batch 19/49, Batch Loss: 61281.5039
# Epoch 117, Batch 20/49, Batch Loss: 62662.8125
# Epoch 117, Batch 21/49, Batch Loss: 56500.3242
# Epoch 117, Batch 22/49, Batch Loss: 68429.0469
# Epoch 117, Batch 23/49, Batch Loss: 79599.8672
# Epoch 117, Batch 24/49, Batch Loss: 58684.8125
# Epoch 117, Batch 25/49, Batch Loss: 72982.8672
# Epoch 117, Batch 26/49, Batch Loss: 56076.4102
# Epoch 117, Batch 27/49, Batch Loss: 103148.0156
# Epoch 117, Batch 28/49, Batch Loss: 50078.8125
# Epoch 117, Batch 29/49, Batch Loss: 87670.5547
# Epoch 117, Batch 30/49, Batch Loss: 78330.6641
# Epoch 117, Batch 31/49, Batch Loss: 88177.2656
# Epoch 117, Batch 32/49, Batch Loss: 59838.0273
# Epoch 117, Batch 33/49, Batch Loss: 123964.7734
# Epoch 117, Batch 34/49, Batch Loss: 94050.5547
# Epoch 117, Batch 35/49, Batch Loss: 69354.9219
# Epoch 117, Batch 36/49, Batch Loss: 68970.6172
# Epoch 117, Batch 37/49, Batch Loss: 96619.4141
# Epoch 117, Batch 38/49, Batch Loss: 74132.6562
# Epoch 117, Batch 39/49, Batch Loss: 83323.9609
# Epoch 117, Batch 40/49, Batch Loss: 59865.2734
# Epoch 117, Batch 41/49, Batch Loss: 59001.3516
# Epoch 117, Batch 42/49, Batch Loss: 51757.4219
# Epoch 117, Batch 43/49, Batch Loss: 85513.7344
# Epoch 117, Batch 44/49, Batch Loss: 174135.4844
# Epoch 117, Batch 45/49, Batch Loss: 98327.0547
# Epoch 117, Batch 46/49, Batch Loss: 107120.1328
# Epoch 117, Batch 47/49, Batch Loss: 74069.0000
# Epoch 117, Batch 48/49, Batch Loss: 114174.1094
# Epoch 117, Batch 49/49, Batch Loss: 82299.3203
# Batch 1/17, Batch Loss: 108473.2500
# Batch 2/17, Batch Loss: 202103.9688
# Batch 3/17, Batch Loss: 132629.3281
# Batch 4/17, Batch Loss: 254417.1250
# Batch 5/17, Batch Loss: 120324.1328
# Batch 6/17, Batch Loss: 191110.0625
# Batch 7/17, Batch Loss: 206856.6094
# Batch 8/17, Batch Loss: 763289.6875
# Batch 9/17, Batch Loss: 205363.8750
# Batch 10/17, Batch Loss: 85723.8828
# Batch 11/17, Batch Loss: 361613.7500
# Batch 12/17, Batch Loss: 404986.7500
# Batch 13/17, Batch Loss: 110187.6719
# Batch 14/17, Batch Loss: 102300.6250
# Batch 15/17, Batch Loss: 72302.2891
# Batch 16/17, Batch Loss: 259162.3750
# Batch 17/17, Batch Loss: 88858.4219
# Test Error:
#  Avg loss: 215864.929688, Avg error: 122164.909170
#
# Epoch 118, Batch 1/49, Batch Loss: 88455.7109
# Epoch 118, Batch 2/49, Batch Loss: 95562.8984
# Epoch 118, Batch 3/49, Batch Loss: 178593.7656
# Epoch 118, Batch 4/49, Batch Loss: 48633.2344
# Epoch 118, Batch 5/49, Batch Loss: 62818.9219
# Epoch 118, Batch 6/49, Batch Loss: 100351.5312
# Epoch 118, Batch 7/49, Batch Loss: 78134.2188
# Epoch 118, Batch 8/49, Batch Loss: 99414.6328
# Epoch 118, Batch 9/49, Batch Loss: 91549.9766
# Epoch 118, Batch 10/49, Batch Loss: 70992.4297
# Epoch 118, Batch 11/49, Batch Loss: 109012.6875
# Epoch 118, Batch 12/49, Batch Loss: 196041.5469
# Epoch 118, Batch 13/49, Batch Loss: 114860.6719
# Epoch 118, Batch 14/49, Batch Loss: 77299.7734
# Epoch 118, Batch 15/49, Batch Loss: 73386.7812
# Epoch 118, Batch 16/49, Batch Loss: 108928.9453
# Epoch 118, Batch 17/49, Batch Loss: 87208.0156
# Epoch 118, Batch 18/49, Batch Loss: 82427.5938
# Epoch 118, Batch 19/49, Batch Loss: 87475.4609
# Epoch 118, Batch 20/49, Batch Loss: 91501.7109
# Epoch 118, Batch 21/49, Batch Loss: 83162.7656
# Epoch 118, Batch 22/49, Batch Loss: 82123.9297
# Epoch 118, Batch 23/49, Batch Loss: 113900.2188
# Epoch 118, Batch 24/49, Batch Loss: 81341.8125
# Epoch 118, Batch 25/49, Batch Loss: 144607.5312
# Epoch 118, Batch 26/49, Batch Loss: 61745.3828
# Epoch 118, Batch 27/49, Batch Loss: 125631.0703
# Epoch 118, Batch 28/49, Batch Loss: 69897.3750
# Epoch 118, Batch 29/49, Batch Loss: 69498.4141
# Epoch 118, Batch 30/49, Batch Loss: 53480.6680
# Epoch 118, Batch 31/49, Batch Loss: 80930.8672
# Epoch 118, Batch 32/49, Batch Loss: 58797.3320
# Epoch 118, Batch 33/49, Batch Loss: 68896.4688
# Epoch 118, Batch 34/49, Batch Loss: 71958.0547
# Epoch 118, Batch 35/49, Batch Loss: 158647.3594
# Epoch 118, Batch 36/49, Batch Loss: 83583.4297
# Epoch 118, Batch 37/49, Batch Loss: 75215.7734
# Epoch 118, Batch 38/49, Batch Loss: 62131.3047
# Epoch 118, Batch 39/49, Batch Loss: 68970.1094
# Epoch 118, Batch 40/49, Batch Loss: 70361.0938
# Epoch 118, Batch 41/49, Batch Loss: 70855.2656
# Epoch 118, Batch 42/49, Batch Loss: 62969.3242
# Epoch 118, Batch 43/49, Batch Loss: 63749.4492
# Epoch 118, Batch 44/49, Batch Loss: 72310.5000
# Epoch 118, Batch 45/49, Batch Loss: 68442.0234
# Epoch 118, Batch 46/49, Batch Loss: 48801.8945
# Epoch 118, Batch 47/49, Batch Loss: 88088.2031
# Epoch 118, Batch 48/49, Batch Loss: 63898.8672
# Epoch 118, Batch 49/49, Batch Loss: 66810.5156
# Batch 1/17, Batch Loss: 114510.8438
# Batch 2/17, Batch Loss: 293235.0625
# Batch 3/17, Batch Loss: 132564.6719
# Batch 4/17, Batch Loss: 277287.0312
# Batch 5/17, Batch Loss: 141499.8750
# Batch 6/17, Batch Loss: 216139.7500
# Batch 7/17, Batch Loss: 216975.2812
# Batch 8/17, Batch Loss: 786633.7500
# Batch 9/17, Batch Loss: 207345.1719
# Batch 10/17, Batch Loss: 82754.5078
# Batch 11/17, Batch Loss: 336494.3125
# Batch 12/17, Batch Loss: 425357.1875
# Batch 13/17, Batch Loss: 116300.1641
# Batch 14/17, Batch Loss: 114192.4688
# Batch 15/17, Batch Loss: 105142.6484
# Batch 16/17, Batch Loss: 304978.8438
# Batch 17/17, Batch Loss: 127017.4766
# Test Error:
#  Avg loss: 235201.708640, Avg error: 141614.881488
#
# Epoch 119, Batch 1/49, Batch Loss: 75254.8750
# Epoch 119, Batch 2/49, Batch Loss: 64065.4727
# Epoch 119, Batch 3/49, Batch Loss: 67630.1641
# Epoch 119, Batch 4/49, Batch Loss: 77422.2422
# Epoch 119, Batch 5/49, Batch Loss: 114030.0703
# Epoch 119, Batch 6/49, Batch Loss: 71308.4062
# Epoch 119, Batch 7/49, Batch Loss: 103448.3672
# Epoch 119, Batch 8/49, Batch Loss: 61293.7578
# Epoch 119, Batch 9/49, Batch Loss: 78101.2031
# Epoch 119, Batch 10/49, Batch Loss: 83206.5625
# Epoch 119, Batch 11/49, Batch Loss: 87069.1953
# Epoch 119, Batch 12/49, Batch Loss: 113138.6406
# Epoch 119, Batch 13/49, Batch Loss: 104221.9609
# Epoch 119, Batch 14/49, Batch Loss: 70895.6094
# Epoch 119, Batch 15/49, Batch Loss: 76592.4531
# Epoch 119, Batch 16/49, Batch Loss: 71068.7734
# Epoch 119, Batch 17/49, Batch Loss: 73436.2188
# Epoch 119, Batch 18/49, Batch Loss: 65376.0312
# Epoch 119, Batch 19/49, Batch Loss: 62970.5039
# Epoch 119, Batch 20/49, Batch Loss: 69218.8203
# Epoch 119, Batch 21/49, Batch Loss: 74256.1094
# Epoch 119, Batch 22/49, Batch Loss: 78040.3750
# Epoch 119, Batch 23/49, Batch Loss: 112822.8672
# Epoch 119, Batch 24/49, Batch Loss: 88306.6875
# Epoch 119, Batch 25/49, Batch Loss: 74281.5312
# Epoch 119, Batch 26/49, Batch Loss: 63939.0430
# Epoch 119, Batch 27/49, Batch Loss: 66574.4062
# Epoch 119, Batch 28/49, Batch Loss: 90611.8438
# Epoch 119, Batch 29/49, Batch Loss: 62087.3984
# Epoch 119, Batch 30/49, Batch Loss: 85270.9922
# Epoch 119, Batch 31/49, Batch Loss: 95410.1719
# Epoch 119, Batch 32/49, Batch Loss: 64485.5742
# Epoch 119, Batch 33/49, Batch Loss: 63175.1953
# Epoch 119, Batch 34/49, Batch Loss: 59022.6875
# Epoch 119, Batch 35/49, Batch Loss: 69543.5547
# Epoch 119, Batch 36/49, Batch Loss: 105288.7656
# Epoch 119, Batch 37/49, Batch Loss: 79830.7500
# Epoch 119, Batch 38/49, Batch Loss: 62353.6562
# Epoch 119, Batch 39/49, Batch Loss: 80529.7734
# Epoch 119, Batch 40/49, Batch Loss: 76518.7969
# Epoch 119, Batch 41/49, Batch Loss: 88182.8594
# Epoch 119, Batch 42/49, Batch Loss: 72317.7734
# Epoch 119, Batch 43/49, Batch Loss: 86176.3906
# Epoch 119, Batch 44/49, Batch Loss: 72865.9141
# Epoch 119, Batch 45/49, Batch Loss: 95992.4375
# ...
# Epoch 170, Batch 44/49, Batch Loss: 49631.6836
# Epoch 170, Batch 45/49, Batch Loss: 68096.3281
# Epoch 170, Batch 46/49, Batch Loss: 75236.9297
# Epoch 170, Batch 47/49, Batch Loss: 62177.7422
# Epoch 170, Batch 48/49, Batch Loss: 79393.9844
# Epoch 170, Batch 49/49, Batch Loss: 63863.6758
# Batch 1/17, Batch Loss: 165680.9531
# Batch 2/17, Batch Loss: 290682.1250
# Batch 3/17, Batch Loss: 155127.8281
# Batch 4/17, Batch Loss: 277495.5938
# Batch 5/17, Batch Loss: 129002.2109
# Batch 6/17, Batch Loss: 228768.2500
# Batch 7/17, Batch Loss: 196667.8594
# Batch 8/17, Batch Loss: 819608.5625
# Batch 9/17, Batch Loss: 207137.2812
# Batch 10/17, Batch Loss: 86438.6797
# Batch 11/17, Batch Loss: 342343.2812
# Batch 12/17, Batch Loss: 427807.2500
# Batch 13/17, Batch Loss: 126198.2266
# Batch 14/17, Batch Loss: 118304.8672
# Batch 15/17, Batch Loss: 55985.8477
# Batch 16/17, Batch Loss: 301603.0938
# Batch 17/17, Batch Loss: 127651.4844
# Test Error:
#  Avg loss: 238617.846737, Avg error: 144766.773140
#
# 2024-10-03 00:23:53.081595 Epoch 170, Average Training loss 76105.16828762754
# Epoch 171, Batch 1/49, Batch Loss: 66534.5078
# Epoch 171, Batch 2/49, Batch Loss: 73163.3750
# Epoch 171, Batch 3/49, Batch Loss: 71855.1406
# Epoch 171, Batch 4/49, Batch Loss: 66027.4922
# Epoch 171, Batch 5/49, Batch Loss: 63945.0039
# Epoch 171, Batch 6/49, Batch Loss: 61269.9023
# Epoch 171, Batch 7/49, Batch Loss: 73939.7656
# Epoch 171, Batch 8/49, Batch Loss: 64644.3438
# Epoch 171, Batch 9/49, Batch Loss: 119031.4062
# Epoch 171, Batch 10/49, Batch Loss: 61318.5078
# Epoch 171, Batch 11/49, Batch Loss: 64754.1328
# Epoch 171, Batch 12/49, Batch Loss: 111345.8750
# Epoch 171, Batch 13/49, Batch Loss: 73260.7188
# Epoch 171, Batch 14/49, Batch Loss: 66060.7969
# Epoch 171, Batch 15/49, Batch Loss: 120695.5781
# Epoch 171, Batch 16/49, Batch Loss: 77284.2266
# Epoch 171, Batch 17/49, Batch Loss: 73074.2188
# Epoch 171, Batch 18/49, Batch Loss: 74836.7734
# Epoch 171, Batch 19/49, Batch Loss: 62540.1367
# Epoch 171, Batch 20/49, Batch Loss: 71728.6094
# Epoch 171, Batch 21/49, Batch Loss: 61018.1992
# Epoch 171, Batch 22/49, Batch Loss: 57134.3906
# Epoch 171, Batch 23/49, Batch Loss: 59733.8633
# Epoch 171, Batch 24/49, Batch Loss: 65614.5391
# Epoch 171, Batch 25/49, Batch Loss: 68449.4297
# Epoch 171, Batch 26/49, Batch Loss: 61276.0391
# Epoch 171, Batch 27/49, Batch Loss: 121489.6953
# Epoch 171, Batch 28/49, Batch Loss: 61187.3281
# Epoch 171, Batch 29/49, Batch Loss: 117489.2812
# Epoch 171, Batch 30/49, Batch Loss: 57619.3555
# Epoch 171, Batch 31/49, Batch Loss: 60237.0898
# Epoch 171, Batch 32/49, Batch Loss: 61104.7891
# Epoch 171, Batch 33/49, Batch Loss: 88002.8594
# Epoch 171, Batch 34/49, Batch Loss: 72567.1172
# Epoch 171, Batch 35/49, Batch Loss: 51935.9688
# Epoch 171, Batch 36/49, Batch Loss: 68662.6641
# Epoch 171, Batch 37/49, Batch Loss: 100154.3438
# Epoch 171, Batch 38/49, Batch Loss: 55745.8750
# Epoch 171, Batch 39/49, Batch Loss: 62819.8242
# Epoch 171, Batch 40/49, Batch Loss: 66111.8516
# Epoch 171, Batch 41/49, Batch Loss: 55486.6914
# Epoch 171, Batch 42/49, Batch Loss: 70388.2344
# Epoch 171, Batch 43/49, Batch Loss: 62600.0117
# Epoch 171, Batch 44/49, Batch Loss: 93964.2422
# Epoch 171, Batch 45/49, Batch Loss: 64142.1562
# Epoch 171, Batch 46/49, Batch Loss: 62238.1016
# Epoch 171, Batch 47/49, Batch Loss: 58661.0977
# Epoch 171, Batch 48/49, Batch Loss: 66815.5938
# Epoch 171, Batch 49/49, Batch Loss: 71904.6094
# Batch 1/17, Batch Loss: 137839.8750
# Batch 2/17, Batch Loss: 281250.3750
# Batch 3/17, Batch Loss: 138403.0781
# Batch 4/17, Batch Loss: 279353.2188
# Batch 5/17, Batch Loss: 121835.6953
# Batch 6/17, Batch Loss: 210893.7188
# Batch 7/17, Batch Loss: 201400.5312
# Batch 8/17, Batch Loss: 821919.1875
# Batch 9/17, Batch Loss: 243046.9531
# Batch 10/17, Batch Loss: 93802.1953
# Batch 11/17, Batch Loss: 405150.4062
# Batch 12/17, Batch Loss: 431438.0625
# Batch 13/17, Batch Loss: 134056.1094
# Batch 14/17, Batch Loss: 135553.7969
# Batch 15/17, Batch Loss: 92787.6562
# Batch 16/17, Batch Loss: 294601.4062
# Batch 17/17, Batch Loss: 114231.2266
# Test Error:
#  Avg loss: 243386.087776, Avg error: 141892.839533
#
# Epoch 172, Batch 1/49, Batch Loss: 57728.2148
# Epoch 172, Batch 2/49, Batch Loss: 61463.1172
# Epoch 172, Batch 3/49, Batch Loss: 66976.7656
# Epoch 172, Batch 4/49, Batch Loss: 75747.1953
# Epoch 172, Batch 5/49, Batch Loss: 57037.5586
# Epoch 172, Batch 6/49, Batch Loss: 64179.2031
# Epoch 172, Batch 7/49, Batch Loss: 192865.6875
# Epoch 172, Batch 8/49, Batch Loss: 160178.5938
# Epoch 172, Batch 9/49, Batch Loss: 62102.9688
# Epoch 172, Batch 10/49, Batch Loss: 101269.3047
# Epoch 172, Batch 11/49, Batch Loss: 90933.9688
# Epoch 172, Batch 12/49, Batch Loss: 78684.1250
# Epoch 172, Batch 13/49, Batch Loss: 64288.0273
# Epoch 172, Batch 14/49, Batch Loss: 69386.4219
# Epoch 172, Batch 15/49, Batch Loss: 82045.0469
# Epoch 172, Batch 16/49, Batch Loss: 72516.4219
# Epoch 172, Batch 17/49, Batch Loss: 81214.2812
# Epoch 172, Batch 18/49, Batch Loss: 48925.6953
# Epoch 172, Batch 19/49, Batch Loss: 96480.0234
# Epoch 172, Batch 20/49, Batch Loss: 100671.1094
# Epoch 172, Batch 21/49, Batch Loss: 87419.1016
# Epoch 172, Batch 22/49, Batch Loss: 58129.8438
# Epoch 172, Batch 23/49, Batch Loss: 61398.0859
# Epoch 172, Batch 24/49, Batch Loss: 46196.6367
# Epoch 172, Batch 25/49, Batch Loss: 45399.0078
# Epoch 172, Batch 26/49, Batch Loss: 74514.6641
# Epoch 172, Batch 27/49, Batch Loss: 130274.3906
# Epoch 172, Batch 28/49, Batch Loss: 89004.7109
# Epoch 172, Batch 29/49, Batch Loss: 85885.3984
# Epoch 172, Batch 30/49, Batch Loss: 67577.5781
# Epoch 172, Batch 31/49, Batch Loss: 60888.9297
# Epoch 172, Batch 32/49, Batch Loss: 79086.7578
# Epoch 172, Batch 33/49, Batch Loss: 68125.0938
# Epoch 172, Batch 34/49, Batch Loss: 105865.4688
# Epoch 172, Batch 35/49, Batch Loss: 69788.9922
# Epoch 172, Batch 36/49, Batch Loss: 71632.0703
# Epoch 172, Batch 37/49, Batch Loss: 50546.3633
# Epoch 172, Batch 38/49, Batch Loss: 62967.0547
# Epoch 172, Batch 39/49, Batch Loss: 100711.7734
# Epoch 172, Batch 40/49, Batch Loss: 81435.3516
# Epoch 172, Batch 41/49, Batch Loss: 60081.5078
# Epoch 172, Batch 42/49, Batch Loss: 66781.2344
# Epoch 172, Batch 43/49, Batch Loss: 129397.0156
# Epoch 172, Batch 44/49, Batch Loss: 65663.5859
# Epoch 172, Batch 45/49, Batch Loss: 81850.8438
# Epoch 172, Batch 46/49, Batch Loss: 71297.2500
# Epoch 172, Batch 47/49, Batch Loss: 98568.7656
# Epoch 172, Batch 48/49, Batch Loss: 78564.0703
# Epoch 172, Batch 49/49, Batch Loss: 78065.2812
# Batch 1/17, Batch Loss: 152375.9219
# Batch 2/17, Batch Loss: 283429.4062
# Batch 3/17, Batch Loss: 116325.7344
# Batch 4/17, Batch Loss: 267890.2500
# Batch 5/17, Batch Loss: 119894.0234
# Batch 6/17, Batch Loss: 208498.7344
# Batch 7/17, Batch Loss: 175323.7969
# Batch 8/17, Batch Loss: 763341.1875
# Batch 9/17, Batch Loss: 204560.5938
# Batch 10/17, Batch Loss: 95703.0469
# Batch 11/17, Batch Loss: 391444.8750
# Batch 12/17, Batch Loss: 259454.0469
# Batch 13/17, Batch Loss: 132317.5000
# Batch 14/17, Batch Loss: 117603.6641
# Batch 15/17, Batch Loss: 97460.2188
# Batch 16/17, Batch Loss: 287046.3125
# Batch 17/17, Batch Loss: 104993.2031
# Test Error:
#  Avg loss: 222215.442096, Avg error: 129608.976211
#
# Epoch 173, Batch 1/49, Batch Loss: 41430.1250
# Epoch 173, Batch 2/49, Batch Loss: 72831.0781
# Epoch 173, Batch 3/49, Batch Loss: 73008.9766
# Epoch 173, Batch 4/49, Batch Loss: 89646.1016
# Epoch 173, Batch 5/49, Batch Loss: 59258.3242
# Epoch 173, Batch 6/49, Batch Loss: 66039.0469
# Epoch 173, Batch 7/49, Batch Loss: 54597.2461
# Epoch 173, Batch 8/49, Batch Loss: 74441.5391
# Epoch 173, Batch 9/49, Batch Loss: 67430.3672
# Epoch 173, Batch 10/49, Batch Loss: 84660.0625
# Epoch 173, Batch 11/49, Batch Loss: 85515.5469
# Epoch 173, Batch 12/49, Batch Loss: 73878.7734
# Epoch 173, Batch 13/49, Batch Loss: 78139.6172
# Epoch 173, Batch 14/49, Batch Loss: 189657.6719
# Epoch 173, Batch 15/49, Batch Loss: 48469.5352
# Epoch 173, Batch 16/49, Batch Loss: 71025.2500
# Epoch 173, Batch 17/49, Batch Loss: 66653.1953
# Epoch 173, Batch 18/49, Batch Loss: 89606.8047
# Epoch 173, Batch 19/49, Batch Loss: 74885.0469
# Epoch 173, Batch 20/49, Batch Loss: 104207.8438
# Epoch 173, Batch 21/49, Batch Loss: 67482.5625
# Epoch 173, Batch 22/49, Batch Loss: 81641.2656
# Epoch 173, Batch 23/49, Batch Loss: 89320.5156
# Epoch 173, Batch 24/49, Batch Loss: 69129.0234
# Epoch 173, Batch 25/49, Batch Loss: 77124.6562
# Epoch 173, Batch 26/49, Batch Loss: 65073.8789
# Epoch 173, Batch 27/49, Batch Loss: 69241.6484
# Epoch 173, Batch 28/49, Batch Loss: 69000.2812
# Epoch 173, Batch 29/49, Batch Loss: 68406.1250
# Epoch 173, Batch 30/49, Batch Loss: 79904.1172
# Epoch 173, Batch 31/49, Batch Loss: 90728.4141
# Epoch 173, Batch 32/49, Batch Loss: 68154.0938
# Epoch 173, Batch 33/49, Batch Loss: 74572.3438
# Epoch 173, Batch 34/49, Batch Loss: 63550.8750
# Epoch 173, Batch 35/49, Batch Loss: 59578.3086
# Epoch 173, Batch 36/49, Batch Loss: 73632.7031
# Epoch 173, Batch 37/49, Batch Loss: 72469.7109
# Epoch 173, Batch 38/49, Batch Loss: 59334.0430
# Epoch 173, Batch 39/49, Batch Loss: 96205.6797
# Epoch 173, Batch 40/49, Batch Loss: 56034.9922
# Epoch 173, Batch 41/49, Batch Loss: 83030.4688
# Epoch 173, Batch 42/49, Batch Loss: 62072.9375
# Epoch 173, Batch 43/49, Batch Loss: 55765.5039
# Epoch 173, Batch 44/49, Batch Loss: 65112.1719
# Epoch 173, Batch 45/49, Batch Loss: 54005.8984
# Epoch 173, Batch 46/49, Batch Loss: 65922.8203
# Epoch 173, Batch 47/49, Batch Loss: 98218.8281
# Epoch 173, Batch 48/49, Batch Loss: 51690.5547
# Epoch 173, Batch 49/49, Batch Loss: 76340.8047
# Batch 1/17, Batch Loss: 175280.0312
# Batch 2/17, Batch Loss: 238527.9844
# Batch 3/17, Batch Loss: 156015.0312
# Batch 4/17, Batch Loss: 275274.2188
# Batch 5/17, Batch Loss: 121016.1484
# Batch 6/17, Batch Loss: 227068.9844
# Batch 7/17, Batch Loss: 206441.9531
# Batch 8/17, Batch Loss: 822467.4375
# Batch 9/17, Batch Loss: 204329.3438
# Batch 10/17, Batch Loss: 103277.9297
# Batch 11/17, Batch Loss: 398383.7188
# Batch 12/17, Batch Loss: 438040.2500
# Batch 13/17, Batch Loss: 117003.9453
# Batch 14/17, Batch Loss: 103518.3906
# Batch 15/17, Batch Loss: 96800.0547
# Batch 16/17, Batch Loss: 300210.5312
# Batch 17/17, Batch Loss: 135744.9531
# Test Error:
#  Avg loss: 242317.700368, Avg error: 146823.206747
#
# Epoch 174, Batch 1/49, Batch Loss: 60187.8125
# Epoch 174, Batch 2/49, Batch Loss: 52777.6328
# Epoch 174, Batch 3/49, Batch Loss: 54146.0664
# Epoch 174, Batch 4/49, Batch Loss: 75011.0625
# Epoch 174, Batch 5/49, Batch Loss: 63113.7500
# Epoch 174, Batch 6/49, Batch Loss: 43951.5898
# Epoch 174, Batch 7/49, Batch Loss: 60498.6641
# Epoch 174, Batch 8/49, Batch Loss: 115947.2656
# Epoch 174, Batch 9/49, Batch Loss: 63088.2383
# Epoch 174, Batch 10/49, Batch Loss: 73955.3125
# Epoch 174, Batch 11/49, Batch Loss: 49080.5938
# Epoch 174, Batch 12/49, Batch Loss: 55327.2344
# Epoch 174, Batch 13/49, Batch Loss: 73880.9297
# Epoch 174, Batch 14/49, Batch Loss: 104989.1719
# Epoch 174, Batch 15/49, Batch Loss: 70317.9062
# Epoch 174, Batch 16/49, Batch Loss: 65529.7266
# Epoch 174, Batch 17/49, Batch Loss: 69124.1250
# Epoch 174, Batch 18/49, Batch Loss: 68676.4062
# Epoch 174, Batch 19/49, Batch Loss: 65764.6875
# Epoch 174, Batch 20/49, Batch Loss: 52193.4766
# Epoch 174, Batch 21/49, Batch Loss: 153016.7969
# Epoch 174, Batch 22/49, Batch Loss: 51928.9492
# Epoch 174, Batch 23/49, Batch Loss: 60035.4297
# Epoch 174, Batch 24/49, Batch Loss: 64074.4453
# Epoch 174, Batch 25/49, Batch Loss: 66346.6797
# Epoch 174, Batch 26/49, Batch Loss: 54297.1953
# Epoch 174, Batch 27/49, Batch Loss: 55189.5156
# Epoch 174, Batch 28/49, Batch Loss: 68585.2812
# Epoch 174, Batch 29/49, Batch Loss: 56253.5781
# Epoch 174, Batch 30/49, Batch Loss: 51444.4414
# Epoch 174, Batch 31/49, Batch Loss: 86078.7812
# Epoch 174, Batch 32/49, Batch Loss: 74575.9766
# Epoch 174, Batch 33/49, Batch Loss: 58239.3320
# Epoch 174, Batch 34/49, Batch Loss: 66813.0078
# Epoch 174, Batch 35/49, Batch Loss: 110733.8203
# Epoch 174, Batch 36/49, Batch Loss: 89495.9453
# Epoch 174, Batch 37/49, Batch Loss: 63301.7422
# Epoch 174, Batch 38/49, Batch Loss: 55366.8711
# Epoch 174, Batch 39/49, Batch Loss: 89525.6719
# Epoch 174, Batch 40/49, Batch Loss: 62512.7812
# Epoch 174, Batch 41/49, Batch Loss: 64199.9688
# Epoch 174, Batch 42/49, Batch Loss: 78306.3516
# Epoch 174, Batch 43/49, Batch Loss: 97982.5938
# Epoch 174, Batch 44/49, Batch Loss: 108096.2500
# Epoch 174, Batch 45/49, Batch Loss: 71586.4219
# Epoch 174, Batch 46/49, Batch Loss: 183983.1719
# Epoch 174, Batch 47/49, Batch Loss: 79079.4766
# Epoch 174, Batch 48/49, Batch Loss: 78866.9375
# Epoch 174, Batch 49/49, Batch Loss: 83454.8516
# Batch 1/17, Batch Loss: 186626.2812
# Batch 2/17, Batch Loss: 237498.1094
# Batch 3/17, Batch Loss: 148340.6719
# Batch 4/17, Batch Loss: 325836.0938
# Batch 5/17, Batch Loss: 137901.3281
# Batch 6/17, Batch Loss: 309248.1250
# Batch 7/17, Batch Loss: 157480.5938
# Batch 8/17, Batch Loss: 334602.4062
# Batch 9/17, Batch Loss: 221535.4062
# Batch 10/17, Batch Loss: 135717.7344
# Batch 11/17, Batch Loss: 394326.8125
# Batch 12/17, Batch Loss: 451169.7812
# Batch 13/17, Batch Loss: 130951.4453
# Batch 14/17, Batch Loss: 157825.4688
# Batch 15/17, Batch Loss: 99677.8203
# Batch 16/17, Batch Loss: 312096.3438
# Batch 17/17, Batch Loss: 143376.5000
# Test Error:
#  Avg loss: 228482.995404, Avg error: 153309.418685
#
# Epoch 175, Batch 1/49, Batch Loss: 118795.0312
# Epoch 175, Batch 2/49, Batch Loss: 60200.9141
# Epoch 175, Batch 3/49, Batch Loss: 60929.3906
# Epoch 175, Batch 4/49, Batch Loss: 91589.9688
# Epoch 175, Batch 5/49, Batch Loss: 49975.5625
# Epoch 175, Batch 6/49, Batch Loss: 82970.4453
# Epoch 175, Batch 7/49, Batch Loss: 155241.1875
# Epoch 175, Batch 8/49, Batch Loss: 102398.7812
# Epoch 175, Batch 9/49, Batch Loss: 135586.9531
# Epoch 175, Batch 10/49, Batch Loss: 62451.0391
# Epoch 175, Batch 11/49, Batch Loss: 80583.2031
# Epoch 175, Batch 12/49, Batch Loss: 62342.3320
# Epoch 175, Batch 13/49, Batch Loss: 78133.9609
# Epoch 175, Batch 14/49, Batch Loss: 94711.5078
# Epoch 175, Batch 15/49, Batch Loss: 78715.2266
# Epoch 175, Batch 16/49, Batch Loss: 62121.4336
# Epoch 175, Batch 17/49, Batch Loss: 106870.5938
# Epoch 175, Batch 18/49, Batch Loss: 76109.8750
# Epoch 175, Batch 19/49, Batch Loss: 68661.1875
# Epoch 175, Batch 20/49, Batch Loss: 64204.8164
# Epoch 175, Batch 21/49, Batch Loss: 67622.2422
# Epoch 175, Batch 22/49, Batch Loss: 79767.6484
# Epoch 175, Batch 23/49, Batch Loss: 61042.2344
# Epoch 175, Batch 24/49, Batch Loss: 78484.8281
# Epoch 175, Batch 25/49, Batch Loss: 71599.7656
# Epoch 175, Batch 26/49, Batch Loss: 74874.2109
# Epoch 175, Batch 27/49, Batch Loss: 62293.4844
# Epoch 175, Batch 28/49, Batch Loss: 64821.5391
# Epoch 175, Batch 29/49, Batch Loss: 98249.8906
# Epoch 175, Batch 30/49, Batch Loss: 54259.7891
# Epoch 175, Batch 31/49, Batch Loss: 112253.3594
# Epoch 175, Batch 32/49, Batch Loss: 63083.2500
# Epoch 175, Batch 33/49, Batch Loss: 57100.0469
# Epoch 175, Batch 34/49, Batch Loss: 80147.0703
# Epoch 175, Batch 35/49, Batch Loss: 83447.1484
# Epoch 175, Batch 36/49, Batch Loss: 88300.8750
# Epoch 175, Batch 37/49, Batch Loss: 78710.1094
# Epoch 175, Batch 38/49, Batch Loss: 64994.6406
# Epoch 175, Batch 39/49, Batch Loss: 63127.2656
# Epoch 175, Batch 40/49, Batch Loss: 71112.7969
# Epoch 175, Batch 41/49, Batch Loss: 54260.4375
# Epoch 175, Batch 42/49, Batch Loss: 75189.2734
# Epoch 175, Batch 43/49, Batch Loss: 65950.2578
# Epoch 175, Batch 44/49, Batch Loss: 67971.7344
# Epoch 175, Batch 45/49, Batch Loss: 67263.2266
# Epoch 175, Batch 46/49, Batch Loss: 62570.8203
# Epoch 175, Batch 47/49, Batch Loss: 75784.8125
# Epoch 175, Batch 48/49, Batch Loss: 70299.8984
# Epoch 175, Batch 49/49, Batch Loss: 103828.1719
# Batch 1/17, Batch Loss: 163662.3906
# Batch 2/17, Batch Loss: 241709.2344
# Batch 3/17, Batch Loss: 134793.6406
# Batch 4/17, Batch Loss: 253980.0781
# Batch 5/17, Batch Loss: 120798.8359
# Batch 6/17, Batch Loss: 227699.4844
# Batch 7/17, Batch Loss: 152786.8281
# Batch 8/17, Batch Loss: 793996.3125
# Batch 9/17, Batch Loss: 196728.3594
# Batch 10/17, Batch Loss: 87247.3516
# Batch 11/17, Batch Loss: 279410.6875
# Batch 12/17, Batch Loss: 420555.4062
# Batch 13/17, Batch Loss: 130526.9375
# Batch 14/17, Batch Loss: 104080.1094
# Batch 15/17, Batch Loss: 62432.0156
# Batch 16/17, Batch Loss: 283926.4062
# Batch 17/17, Batch Loss: 104735.9062
# Test Error:
#  Avg loss: 221121.763787, Avg error: 124685.296713

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        2.5         3  1915    92021      117.png   485000
# 1        2.5         3  2248    92677      132.png  1199000
# 2        1.0         3  1132    96019      154.png   170000
# 3        4.0         6  3375    92880      245.png   538000
# 4        2.5         3  2733    91901       84.png   689000

# %%
len(test)
# Out:
# 54

# %%
# Crear dataset
test_data = CustomImageDataset(df=test)

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
len(test_loader)
# Out:
# 6

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 486192.4375, Valor real: 485000.0
# Predicción: 464867.71875, Valor real: 1199000.0
# Predicción: 108042.7109375, Valor real: 170000.0
# Predicción: 623046.4375, Valor real: 538000.0
# Predicción: 643924.3125, Valor real: 689000.0
# Predicción: 304553.0625, Valor real: 118900.0
# Predicción: 496158.375, Valor real: 799000.0
# Predicción: 451717.9375, Valor real: 895000.0
# Predicción: 739857.625, Valor real: 599000.0
# Predicción: 436715.78125, Valor real: 535000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 325879.4375
# MAE en el conjunto de prueba: 208754.7031

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
