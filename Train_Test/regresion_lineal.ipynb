# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %%
# --> Definir si viene desde local o drive

ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')
train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))       # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')                         # Quitar los ejes
    plt.show()

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super(LinearRegressionModel, self).__init__()

        # Procesamiento de las características numéricas (tabulares)
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),  # Ajustar esto según el número de características tabulares
            nn.ReLU(),
            nn.Linear(64, 64*3),
            nn.ReLU(),
        )

        # Capa lineal final para la regresión
        # Asumiendo que la imagen tiene 3 canales (RGB) y 400x400 dimensiones
        # Entonces el número total de características sería: 3 * 400 * 400 = 480,000
        self.fc_image = nn.Linear(3 * 400 * 400, 256)  # Imagen convertida en vector plano  -> (480000, 256)
        self.fc_combined = nn.Linear(480192, 1)    # Capa para combinar imagen + numéricas -> (448, 1)
        # (53x480192 and 448x1)

    def forward(self, images, numeric_features):
        # Aplanar la imagen a un vector
        images = images.view(images.size(0), -1)  # De [batch, 3, 400, 400] a [batch, 3*400*400]
        # print(images.shape)

        # Pasar las características numéricas a través de su red
        numeric_features = self.numeric_features_(numeric_features)
        # print(numeric_features.shape)

        # Concatenar las características de la imagen y numéricas
        combined = torch.cat((images, numeric_features), dim=1)
        # print(combined.shape)

        # Aplicar regresión lineal a las características combinadas
        output = self.fc_combined(combined)
        # print(output.shape)

        return output.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():  # No se calculan gradientes en la fase de evaluación
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Forward pass: Predicciones
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss

            # Calcular error absoluto total para monitorear el error
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()  # Poner el modelo en modo entrenamiento

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Forward pass
            output = model(imgs, numeric_features)

            # Calcular la pérdida
            loss = loss_fn(output, price)

            # Backpropagation y optimización
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        # Calcular pérdida promedio en el conjunto de entrenamiento
        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        # Validación al final de cada época
        model.eval()  # Poner el modelo en modo evaluación
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print(f'{datetime.datetime.now()} Epoch {epoch}, Average Training loss {loss_train:.4f}')

    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones
data1 = CustomImageDataset(df=train)

# Dataset con transformación de normalización
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desplazamiento de canales y normalización
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),    # Cambiar los canales RGB a BGR
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                        # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                         # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo horizontal y normalización
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),            # Girar horizontalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo vertical y normalización
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=0.5),              # Girar verticalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desenfoque gaussiano y normalización
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Imagen Original', 'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    if i == 1:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}")
    else:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data1, data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 2597 Val: 289

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data1, data2, data3, data4, data5, data6

# %%
# --> Crear los dataloaders
batch_size_train = 53
batch_size_val = 17
# batch_size=64

train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True, drop_last=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 2597 - Baches 49
# Muestras de test: 289 - Baches 17

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = LinearRegressionModel().to(device)             # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda

# %%
# Entrenamiento
n_epochs = 165
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 93, Batch 45/49, Batch Loss: 401963.3750
# Epoch 93, Batch 46/49, Batch Loss: 277669.0312
# Epoch 93, Batch 47/49, Batch Loss: 374197.5000
# Epoch 93, Batch 48/49, Batch Loss: 247589.0156
# Epoch 93, Batch 49/49, Batch Loss: 349931.8438
# Batch 1/17, Batch Loss: 316536.8750
# Batch 2/17, Batch Loss: 176501.8594
# Batch 3/17, Batch Loss: 314324.3750
# Batch 4/17, Batch Loss: 356338.4688
# Batch 5/17, Batch Loss: 209454.3906
# Batch 6/17, Batch Loss: 381704.5625
# Batch 7/17, Batch Loss: 325461.7188
# Batch 8/17, Batch Loss: 288547.3438
# Batch 9/17, Batch Loss: 498677.7812
# Batch 10/17, Batch Loss: 273461.3438
# Batch 11/17, Batch Loss: 288353.8750
# Batch 12/17, Batch Loss: 714368.3750
# Batch 13/17, Batch Loss: 372905.3750
# Batch 14/17, Batch Loss: 290867.4062
# Batch 15/17, Batch Loss: 299136.5938
# Batch 16/17, Batch Loss: 359333.3438
# Batch 17/17, Batch Loss: 525260.0000
# Test Error:
#  Avg loss: 352425.511029, Avg error: 262021.611592
#
# Epoch 94, Batch 1/49, Batch Loss: 341262.5938
# Epoch 94, Batch 2/49, Batch Loss: 238859.7188
# Epoch 94, Batch 3/49, Batch Loss: 223424.4844
# Epoch 94, Batch 4/49, Batch Loss: 426515.1250
# Epoch 94, Batch 5/49, Batch Loss: 788079.2500
# Epoch 94, Batch 6/49, Batch Loss: 576460.3125
# Epoch 94, Batch 7/49, Batch Loss: 266408.0938
# Epoch 94, Batch 8/49, Batch Loss: 285122.5000
# Epoch 94, Batch 9/49, Batch Loss: 504093.5000
# Epoch 94, Batch 10/49, Batch Loss: 334632.9375
# Epoch 94, Batch 11/49, Batch Loss: 211232.5781
# Epoch 94, Batch 12/49, Batch Loss: 250826.4531
# Epoch 94, Batch 13/49, Batch Loss: 405294.2812
# Epoch 94, Batch 14/49, Batch Loss: 529549.3125
# Epoch 94, Batch 15/49, Batch Loss: 475942.3750
# Epoch 94, Batch 16/49, Batch Loss: 409386.1562
# Epoch 94, Batch 17/49, Batch Loss: 803277.0625
# Epoch 94, Batch 18/49, Batch Loss: 340961.0312
# Epoch 94, Batch 19/49, Batch Loss: 295172.7500
# Epoch 94, Batch 20/49, Batch Loss: 463040.8438
# Epoch 94, Batch 21/49, Batch Loss: 272889.9375
# Epoch 94, Batch 22/49, Batch Loss: 276665.8438
# Epoch 94, Batch 23/49, Batch Loss: 393139.7188
# Epoch 94, Batch 24/49, Batch Loss: 506919.9375
# Epoch 94, Batch 25/49, Batch Loss: 307262.4375
# Epoch 94, Batch 26/49, Batch Loss: 836291.3750
# Epoch 94, Batch 27/49, Batch Loss: 768445.5000
# Epoch 94, Batch 28/49, Batch Loss: 248434.2188
# Epoch 94, Batch 29/49, Batch Loss: 308282.2812
# Epoch 94, Batch 30/49, Batch Loss: 313988.5625
# Epoch 94, Batch 31/49, Batch Loss: 373119.5938
# Epoch 94, Batch 32/49, Batch Loss: 276066.0625
# Epoch 94, Batch 33/49, Batch Loss: 285478.0938
# Epoch 94, Batch 34/49, Batch Loss: 274779.6250
# Epoch 94, Batch 35/49, Batch Loss: 352365.4375
# Epoch 94, Batch 36/49, Batch Loss: 222238.7656
# Epoch 94, Batch 37/49, Batch Loss: 282524.0000
# Epoch 94, Batch 38/49, Batch Loss: 284759.7500
# Epoch 94, Batch 39/49, Batch Loss: 263455.2500
# Epoch 94, Batch 40/49, Batch Loss: 340675.0312
# Epoch 94, Batch 41/49, Batch Loss: 306142.3438
# Epoch 94, Batch 42/49, Batch Loss: 321300.4375
# Epoch 94, Batch 43/49, Batch Loss: 792319.0625
# Epoch 94, Batch 44/49, Batch Loss: 319155.8125
# Epoch 94, Batch 45/49, Batch Loss: 443037.2500
# Epoch 94, Batch 46/49, Batch Loss: 334160.7500
# Epoch 94, Batch 47/49, Batch Loss: 350787.7812
# Epoch 94, Batch 48/49, Batch Loss: 380553.3438
# Epoch 94, Batch 49/49, Batch Loss: 291763.0312
# Batch 1/17, Batch Loss: 307469.3750
# Batch 2/17, Batch Loss: 174680.2500
# Batch 3/17, Batch Loss: 309490.7500
# Batch 4/17, Batch Loss: 354138.2812
# Batch 5/17, Batch Loss: 210138.6719
# Batch 6/17, Batch Loss: 387533.2812
# Batch 7/17, Batch Loss: 331115.8750
# Batch 8/17, Batch Loss: 284953.4062
# Batch 9/17, Batch Loss: 498349.3438
# Batch 10/17, Batch Loss: 268729.3750
# Batch 11/17, Batch Loss: 294350.5938
# Batch 12/17, Batch Loss: 716319.6250
# Batch 13/17, Batch Loss: 371222.0938
# Batch 14/17, Batch Loss: 286660.7500
# Batch 15/17, Batch Loss: 307699.6875
# Batch 16/17, Batch Loss: 366837.3125
# Batch 17/17, Batch Loss: 532353.8125
# Test Error:
#  Avg loss: 353061.322610, Avg error: 262395.424740
#
# Epoch 95, Batch 1/49, Batch Loss: 253660.6875
# Epoch 95, Batch 2/49, Batch Loss: 317374.6250
# Epoch 95, Batch 3/49, Batch Loss: 777243.0000
# Epoch 95, Batch 4/49, Batch Loss: 322570.2500
# Epoch 95, Batch 5/49, Batch Loss: 466548.2812
# Epoch 95, Batch 6/49, Batch Loss: 251767.4531
# Epoch 95, Batch 7/49, Batch Loss: 375592.0938
# Epoch 95, Batch 8/49, Batch Loss: 257524.5312
# Epoch 95, Batch 9/49, Batch Loss: 782813.0625
# Epoch 95, Batch 10/49, Batch Loss: 314312.4688
# Epoch 95, Batch 11/49, Batch Loss: 490189.0625
# Epoch 95, Batch 12/49, Batch Loss: 276564.6250
# Epoch 95, Batch 13/49, Batch Loss: 348857.4062
# Epoch 95, Batch 14/49, Batch Loss: 349658.6250
# Epoch 95, Batch 15/49, Batch Loss: 513478.3750
# Epoch 95, Batch 16/49, Batch Loss: 340254.0312
# Epoch 95, Batch 17/49, Batch Loss: 249339.3438
# Epoch 95, Batch 18/49, Batch Loss: 459735.2812
# Epoch 95, Batch 19/49, Batch Loss: 290945.7500
# Epoch 95, Batch 20/49, Batch Loss: 371716.2188
# Epoch 95, Batch 21/49, Batch Loss: 231191.9688
# Epoch 95, Batch 22/49, Batch Loss: 319305.6250
# Epoch 95, Batch 23/49, Batch Loss: 267681.2188
# Epoch 95, Batch 24/49, Batch Loss: 278276.5625
# Epoch 95, Batch 25/49, Batch Loss: 466031.3750
# Epoch 95, Batch 26/49, Batch Loss: 193743.7969
# Epoch 95, Batch 27/49, Batch Loss: 463198.5625
# Epoch 95, Batch 28/49, Batch Loss: 319060.6250
# Epoch 95, Batch 29/49, Batch Loss: 291063.2500
# Epoch 95, Batch 30/49, Batch Loss: 626046.0625
# Epoch 95, Batch 31/49, Batch Loss: 403770.0312
# Epoch 95, Batch 32/49, Batch Loss: 775954.5625
# Epoch 95, Batch 33/49, Batch Loss: 423675.6562
# Epoch 95, Batch 34/49, Batch Loss: 398149.0312
# Epoch 95, Batch 35/49, Batch Loss: 344136.3125
# Epoch 95, Batch 36/49, Batch Loss: 239171.2656
# Epoch 95, Batch 37/49, Batch Loss: 431251.6250
# Epoch 95, Batch 38/49, Batch Loss: 221496.0781
# Epoch 95, Batch 39/49, Batch Loss: 292757.5000
# Epoch 95, Batch 40/49, Batch Loss: 294477.0000
# Epoch 95, Batch 41/49, Batch Loss: 795334.6250
# Epoch 95, Batch 42/49, Batch Loss: 274872.6875
# Epoch 95, Batch 43/49, Batch Loss: 348586.2812
# Epoch 95, Batch 44/49, Batch Loss: 408136.0000
# Epoch 95, Batch 45/49, Batch Loss: 372334.2188
# Epoch 95, Batch 46/49, Batch Loss: 267310.0312
# Epoch 95, Batch 47/49, Batch Loss: 777551.4375
# Epoch 95, Batch 48/49, Batch Loss: 387023.9688
# Epoch 95, Batch 49/49, Batch Loss: 214703.7031
# Batch 1/17, Batch Loss: 309651.6250
# Batch 2/17, Batch Loss: 174483.7812
# Batch 3/17, Batch Loss: 308983.0625
# Batch 4/17, Batch Loss: 354039.2812
# Batch 5/17, Batch Loss: 209882.3750
# Batch 6/17, Batch Loss: 385495.6562
# Batch 7/17, Batch Loss: 329265.8750
# Batch 8/17, Batch Loss: 285496.6562
# Batch 9/17, Batch Loss: 498920.6250
# Batch 10/17, Batch Loss: 269221.7812
# Batch 11/17, Batch Loss: 292043.5000
# Batch 12/17, Batch Loss: 716384.1875
# Batch 13/17, Batch Loss: 371309.9688
# Batch 14/17, Batch Loss: 287230.2500
# Batch 15/17, Batch Loss: 306386.0312
# Batch 16/17, Batch Loss: 365386.9062
# Batch 17/17, Batch Loss: 528601.0000
# Test Error:
#  Avg loss: 352516.621324, Avg error: 262101.256920
#
# Epoch 96, Batch 1/49, Batch Loss: 307402.4688
# Epoch 96, Batch 2/49, Batch Loss: 358602.3438
# Epoch 96, Batch 3/49, Batch Loss: 254483.6562
# Epoch 96, Batch 4/49, Batch Loss: 277936.9688
# Epoch 96, Batch 5/49, Batch Loss: 225005.3125
# Epoch 96, Batch 6/49, Batch Loss: 221608.7656
# Epoch 96, Batch 7/49, Batch Loss: 281166.0938
# Epoch 96, Batch 8/49, Batch Loss: 291047.5000
# Epoch 96, Batch 9/49, Batch Loss: 486277.2812
# Epoch 96, Batch 10/49, Batch Loss: 421596.8438
# Epoch 96, Batch 11/49, Batch Loss: 453921.7500
# Epoch 96, Batch 12/49, Batch Loss: 291770.4375
# Epoch 96, Batch 13/49, Batch Loss: 359736.5938
# Epoch 96, Batch 14/49, Batch Loss: 376186.7500
# Epoch 96, Batch 15/49, Batch Loss: 325663.0938
# Epoch 96, Batch 16/49, Batch Loss: 406951.1875
# Epoch 96, Batch 17/49, Batch Loss: 508297.7812
# Epoch 96, Batch 18/49, Batch Loss: 600823.2500
# Epoch 96, Batch 19/49, Batch Loss: 515820.1562
# Epoch 96, Batch 20/49, Batch Loss: 334373.5000
# Epoch 96, Batch 21/49, Batch Loss: 364996.8750
# Epoch 96, Batch 22/49, Batch Loss: 306290.1562
# Epoch 96, Batch 23/49, Batch Loss: 775475.3125
# Epoch 96, Batch 24/49, Batch Loss: 437285.4375
# Epoch 96, Batch 25/49, Batch Loss: 379055.1250
# Epoch 96, Batch 26/49, Batch Loss: 246772.4688
# Epoch 96, Batch 27/49, Batch Loss: 755011.3125
# Epoch 96, Batch 28/49, Batch Loss: 321878.5312
# Epoch 96, Batch 29/49, Batch Loss: 288700.2812
# Epoch 96, Batch 30/49, Batch Loss: 271459.5000
# Epoch 96, Batch 31/49, Batch Loss: 271549.1250
# Epoch 96, Batch 32/49, Batch Loss: 267011.7812
# Epoch 96, Batch 33/49, Batch Loss: 452139.0000
# Epoch 96, Batch 34/49, Batch Loss: 293830.9375
# Epoch 96, Batch 35/49, Batch Loss: 298682.5625
# Epoch 96, Batch 36/49, Batch Loss: 439934.0312
# Epoch 96, Batch 37/49, Batch Loss: 379321.8750
# Epoch 96, Batch 38/49, Batch Loss: 757935.0000
# Epoch 96, Batch 39/49, Batch Loss: 326454.5938
# Epoch 96, Batch 40/49, Batch Loss: 327130.6875
# Epoch 96, Batch 41/49, Batch Loss: 256973.3594
# Epoch 96, Batch 42/49, Batch Loss: 256446.6250
# Epoch 96, Batch 43/49, Batch Loss: 382014.6562
# Epoch 96, Batch 44/49, Batch Loss: 476779.5625
# Epoch 96, Batch 45/49, Batch Loss: 235409.6406
# Epoch 96, Batch 46/49, Batch Loss: 390008.4688
# Epoch 96, Batch 47/49, Batch Loss: 292393.8438
# Epoch 96, Batch 48/49, Batch Loss: 299450.7188
# Epoch 96, Batch 49/49, Batch Loss: 1035469.0000
# Batch 1/17, Batch Loss: 318283.2500
# Batch 2/17, Batch Loss: 175850.9219
# Batch 3/17, Batch Loss: 308873.3125
# Batch 4/17, Batch Loss: 355798.1875
# Batch 5/17, Batch Loss: 208585.3281
# Batch 6/17, Batch Loss: 380773.1875
# Batch 7/17, Batch Loss: 324361.9375
# Batch 8/17, Batch Loss: 288442.5312
# Batch 9/17, Batch Loss: 500703.6562
# Batch 10/17, Batch Loss: 273153.0312
# Batch 11/17, Batch Loss: 285467.7188
# Batch 12/17, Batch Loss: 714916.8750
# Batch 13/17, Batch Loss: 371841.2812
# Batch 14/17, Batch Loss: 292161.0625
# Batch 15/17, Batch Loss: 299797.8438
# Batch 16/17, Batch Loss: 359552.8438
# Batch 17/17, Batch Loss: 523079.0625
# Test Error:
#  Avg loss: 351861.295956, Avg error: 261725.664360
#
# Epoch 97, Batch 1/49, Batch Loss: 298790.9375
# Epoch 97, Batch 2/49, Batch Loss: 361460.3750
# Epoch 97, Batch 3/49, Batch Loss: 511739.8125
# Epoch 97, Batch 4/49, Batch Loss: 210906.1875
# Epoch 97, Batch 5/49, Batch Loss: 216767.8750
# Epoch 97, Batch 6/49, Batch Loss: 341658.9375
# Epoch 97, Batch 7/49, Batch Loss: 230984.0625
# Epoch 97, Batch 8/49, Batch Loss: 259431.5312
# Epoch 97, Batch 9/49, Batch Loss: 262533.4688
# Epoch 97, Batch 10/49, Batch Loss: 288395.2812
# Epoch 97, Batch 11/49, Batch Loss: 289706.1562
# Epoch 97, Batch 12/49, Batch Loss: 775726.4375
# Epoch 97, Batch 13/49, Batch Loss: 316470.9688
# Epoch 97, Batch 14/49, Batch Loss: 410781.2500
# Epoch 97, Batch 15/49, Batch Loss: 355619.2812
# Epoch 97, Batch 16/49, Batch Loss: 253335.1094
# Epoch 97, Batch 17/49, Batch Loss: 312547.3125
# Epoch 97, Batch 18/49, Batch Loss: 381705.8438
# Epoch 97, Batch 19/49, Batch Loss: 270536.3750
# Epoch 97, Batch 20/49, Batch Loss: 399870.7500
# Epoch 97, Batch 21/49, Batch Loss: 828174.8750
# Epoch 97, Batch 22/49, Batch Loss: 327763.2188
# Epoch 97, Batch 23/49, Batch Loss: 273972.9688
# Epoch 97, Batch 24/49, Batch Loss: 291667.8125
# Epoch 97, Batch 25/49, Batch Loss: 588566.1875
# Epoch 97, Batch 26/49, Batch Loss: 407883.4688
# Epoch 97, Batch 27/49, Batch Loss: 849492.5000
# Epoch 97, Batch 28/49, Batch Loss: 315243.9375
# Epoch 97, Batch 29/49, Batch Loss: 266919.3125
# Epoch 97, Batch 30/49, Batch Loss: 767824.5000
# Epoch 97, Batch 31/49, Batch Loss: 364565.2812
# Epoch 97, Batch 32/49, Batch Loss: 262859.9062
# Epoch 97, Batch 33/49, Batch Loss: 243754.2188
# Epoch 97, Batch 34/49, Batch Loss: 330065.0625
# Epoch 97, Batch 35/49, Batch Loss: 327073.7188
# Epoch 97, Batch 36/49, Batch Loss: 789269.1250
# Epoch 97, Batch 37/49, Batch Loss: 304436.8125
# Epoch 97, Batch 38/49, Batch Loss: 242255.9688
# Epoch 97, Batch 39/49, Batch Loss: 319494.7812
# Epoch 97, Batch 40/49, Batch Loss: 272693.2188
# Epoch 97, Batch 41/49, Batch Loss: 640242.3125
# Epoch 97, Batch 42/49, Batch Loss: 303635.5625
# Epoch 97, Batch 43/49, Batch Loss: 501491.6875
# Epoch 97, Batch 44/49, Batch Loss: 264136.5000
# Epoch 97, Batch 45/49, Batch Loss: 485385.8438
# Epoch 97, Batch 46/49, Batch Loss: 298656.3125
# Epoch 97, Batch 47/49, Batch Loss: 369178.5000
# Epoch 97, Batch 48/49, Batch Loss: 405513.0625
# Epoch 97, Batch 49/49, Batch Loss: 351946.0938
# Batch 1/17, Batch Loss: 316378.5000
# Batch 2/17, Batch Loss: 175459.6875
# Batch 3/17, Batch Loss: 308050.0000
# Batch 4/17, Batch Loss: 355592.5000
# Batch 5/17, Batch Loss: 209154.0938
# Batch 6/17, Batch Loss: 382054.4688
# Batch 7/17, Batch Loss: 324406.1562
# Batch 8/17, Batch Loss: 287658.4062
# Batch 9/17, Batch Loss: 499850.0625
# Batch 10/17, Batch Loss: 271633.0625
# Batch 11/17, Batch Loss: 285983.0312
# Batch 12/17, Batch Loss: 715370.6875
# Batch 13/17, Batch Loss: 371155.2500
# Batch 14/17, Batch Loss: 292069.5312
# Batch 15/17, Batch Loss: 300578.3438
# Batch 16/17, Batch Loss: 360520.0000
# Batch 17/17, Batch Loss: 524033.1875
# Test Error:
#  Avg loss: 351761.586397, Avg error: 261744.494810
#
# Epoch 98, Batch 1/49, Batch Loss: 329108.1562
# Epoch 98, Batch 2/49, Batch Loss: 217731.7656
# Epoch 98, Batch 3/49, Batch Loss: 325326.0938
# Epoch 98, Batch 4/49, Batch Loss: 326533.9688
# Epoch 98, Batch 5/49, Batch Loss: 331927.5312
# Epoch 98, Batch 6/49, Batch Loss: 338559.2500
# Epoch 98, Batch 7/49, Batch Loss: 767611.5625
# Epoch 98, Batch 8/49, Batch Loss: 316894.5000
# Epoch 98, Batch 9/49, Batch Loss: 600065.9375
# Epoch 98, Batch 10/49, Batch Loss: 374041.5938
# Epoch 98, Batch 11/49, Batch Loss: 755179.7500
# Epoch 98, Batch 12/49, Batch Loss: 320335.6875
# Epoch 98, Batch 13/49, Batch Loss: 289632.4062
# Epoch 98, Batch 14/49, Batch Loss: 794351.6875
# Epoch 98, Batch 15/49, Batch Loss: 293786.6562
# Epoch 98, Batch 16/49, Batch Loss: 311610.0625
# Epoch 98, Batch 17/49, Batch Loss: 385986.1562
# Epoch 98, Batch 18/49, Batch Loss: 356442.4062
# Epoch 98, Batch 19/49, Batch Loss: 291792.2188
# Epoch 98, Batch 20/49, Batch Loss: 338454.9375
# Epoch 98, Batch 21/49, Batch Loss: 776659.0625
# Epoch 98, Batch 22/49, Batch Loss: 636558.3125
# Epoch 98, Batch 23/49, Batch Loss: 356918.9375
# Epoch 98, Batch 24/49, Batch Loss: 254100.7969
# Epoch 98, Batch 25/49, Batch Loss: 294290.7500
# Epoch 98, Batch 26/49, Batch Loss: 304787.9375
# Epoch 98, Batch 27/49, Batch Loss: 254305.5938
# Epoch 98, Batch 28/49, Batch Loss: 304414.8438
# Epoch 98, Batch 29/49, Batch Loss: 300385.5938
# Epoch 98, Batch 30/49, Batch Loss: 249628.0625
# Epoch 98, Batch 31/49, Batch Loss: 489647.4062
# Epoch 98, Batch 32/49, Batch Loss: 369633.8125
# Epoch 98, Batch 33/49, Batch Loss: 270301.0938
# Epoch 98, Batch 34/49, Batch Loss: 377267.7188
# Epoch 98, Batch 35/49, Batch Loss: 762874.3125
# Epoch 98, Batch 36/49, Batch Loss: 343276.7188
# Epoch 98, Batch 37/49, Batch Loss: 244602.1250
# Epoch 98, Batch 38/49, Batch Loss: 379576.3438
# Epoch 98, Batch 39/49, Batch Loss: 460844.5938
# Epoch 98, Batch 40/49, Batch Loss: 464344.1250
# Epoch 98, Batch 41/49, Batch Loss: 434091.6250
# Epoch 98, Batch 42/49, Batch Loss: 365372.5312
# Epoch 98, Batch 43/49, Batch Loss: 281035.4062
# Epoch 98, Batch 44/49, Batch Loss: 219934.8438
# Epoch 98, Batch 45/49, Batch Loss: 288817.3438
# Epoch 98, Batch 46/49, Batch Loss: 316267.6875
# Epoch 98, Batch 47/49, Batch Loss: 237920.0156
# Epoch 98, Batch 48/49, Batch Loss: 439121.9062
# Epoch 98, Batch 49/49, Batch Loss: 426686.5000
# Batch 1/17, Batch Loss: 310018.7812
# Batch 2/17, Batch Loss: 173939.2188
# Batch 3/17, Batch Loss: 304237.5625
# Batch 4/17, Batch Loss: 353900.9375
# Batch 5/17, Batch Loss: 209427.4062
# Batch 6/17, Batch Loss: 385335.0625
# Batch 7/17, Batch Loss: 327966.3750
# Batch 8/17, Batch Loss: 285087.7500
# Batch 9/17, Batch Loss: 499658.7812
# Batch 10/17, Batch Loss: 268790.1875
# Batch 11/17, Batch Loss: 289247.2188
# Batch 12/17, Batch Loss: 716867.3750
# Batch 13/17, Batch Loss: 370677.1875
# Batch 14/17, Batch Loss: 289377.2500
# Batch 15/17, Batch Loss: 305263.3438
# Batch 16/17, Batch Loss: 364707.0312
# Batch 17/17, Batch Loss: 530703.8125
# Test Error:
#  Avg loss: 352070.898897, Avg error: 261915.614187
#
# Epoch 99, Batch 1/49, Batch Loss: 309818.6562
# Epoch 99, Batch 2/49, Batch Loss: 272915.1250
# Epoch 99, Batch 3/49, Batch Loss: 803703.2500
# Epoch 99, Batch 4/49, Batch Loss: 352310.0625
# Epoch 99, Batch 5/49, Batch Loss: 336386.7188
# Epoch 99, Batch 6/49, Batch Loss: 331377.2188
# Epoch 99, Batch 7/49, Batch Loss: 267830.3750
# Epoch 99, Batch 8/49, Batch Loss: 397645.1562
# Epoch 99, Batch 9/49, Batch Loss: 767029.0000
# Epoch 99, Batch 10/49, Batch Loss: 250190.9375
# Epoch 99, Batch 11/49, Batch Loss: 336635.5625
# Epoch 99, Batch 12/49, Batch Loss: 326507.5000
# Epoch 99, Batch 13/49, Batch Loss: 468380.8125
# Epoch 99, Batch 14/49, Batch Loss: 467620.3750
# Epoch 99, Batch 15/49, Batch Loss: 274457.2500
# Epoch 99, Batch 16/49, Batch Loss: 236938.1875
# Epoch 99, Batch 17/49, Batch Loss: 394490.4688
# Epoch 99, Batch 18/49, Batch Loss: 251327.1406
# Epoch 99, Batch 19/49, Batch Loss: 295334.3125
# Epoch 99, Batch 20/49, Batch Loss: 296909.5625
# Epoch 99, Batch 21/49, Batch Loss: 310545.5000
# Epoch 99, Batch 22/49, Batch Loss: 315972.0938
# Epoch 99, Batch 23/49, Batch Loss: 248958.1562
# Epoch 99, Batch 24/49, Batch Loss: 226825.5625
# Epoch 99, Batch 25/49, Batch Loss: 326291.4688
# Epoch 99, Batch 26/49, Batch Loss: 619414.8125
# Epoch 99, Batch 27/49, Batch Loss: 768193.5625
# Epoch 99, Batch 28/49, Batch Loss: 316945.5625
# Epoch 99, Batch 29/49, Batch Loss: 350923.3125
# Epoch 99, Batch 30/49, Batch Loss: 568991.6250
# Epoch 99, Batch 31/49, Batch Loss: 392231.8125
# Epoch 99, Batch 32/49, Batch Loss: 339885.5312
# Epoch 99, Batch 33/49, Batch Loss: 322863.3750
# Epoch 99, Batch 34/49, Batch Loss: 292275.1562
# Epoch 99, Batch 35/49, Batch Loss: 492476.7500
# Epoch 99, Batch 36/49, Batch Loss: 437344.5938
# Epoch 99, Batch 37/49, Batch Loss: 243414.2031
# Epoch 99, Batch 38/49, Batch Loss: 407185.1875
# Epoch 99, Batch 39/49, Batch Loss: 297685.7812
# Epoch 99, Batch 40/49, Batch Loss: 302802.2500
# Epoch 99, Batch 41/49, Batch Loss: 305696.4062
# Epoch 99, Batch 42/49, Batch Loss: 233287.2969
# Epoch 99, Batch 43/49, Batch Loss: 361097.0625
# Epoch 99, Batch 44/49, Batch Loss: 265438.3438
# Epoch 99, Batch 45/49, Batch Loss: 350923.2500
# Epoch 99, Batch 46/49, Batch Loss: 793127.6250
# Epoch 99, Batch 47/49, Batch Loss: 781926.8125
# Epoch 99, Batch 48/49, Batch Loss: 394113.3125
# Epoch 99, Batch 49/49, Batch Loss: 418332.4062
# Batch 1/17, Batch Loss: 303236.6562
# Batch 2/17, Batch Loss: 174188.4531
# Batch 3/17, Batch Loss: 302079.8125
# Batch 4/17, Batch Loss: 353292.3125
# Batch 5/17, Batch Loss: 210661.9531
# Batch 6/17, Batch Loss: 391541.8125
# Batch 7/17, Batch Loss: 333302.5625
# Batch 8/17, Batch Loss: 283150.9688
# Batch 9/17, Batch Loss: 499187.8438
# Batch 10/17, Batch Loss: 264875.2500
# Batch 11/17, Batch Loss: 295847.5938
# Batch 12/17, Batch Loss: 718410.8125
# Batch 13/17, Batch Loss: 369144.0312
# Batch 14/17, Batch Loss: 285041.5625
# Batch 15/17, Batch Loss: 313441.0938
# Batch 16/17, Batch Loss: 372291.7500
# Batch 17/17, Batch Loss: 535535.2500
# Test Error:
#  Avg loss: 353248.806985, Avg error: 263258.522491
#
# Epoch 100, Batch 1/49, Batch Loss: 793899.5000
# Epoch 100, Batch 2/49, Batch Loss: 291708.5000
# Epoch 100, Batch 3/49, Batch Loss: 266290.7500
# Epoch 100, Batch 4/49, Batch Loss: 263715.4688
# Epoch 100, Batch 5/49, Batch Loss: 494472.1250
# Epoch 100, Batch 6/49, Batch Loss: 447115.9062
# Epoch 100, Batch 7/49, Batch Loss: 310803.3438
# Epoch 100, Batch 8/49, Batch Loss: 324755.6875
# Epoch 100, Batch 9/49, Batch Loss: 426568.4375
# Epoch 100, Batch 10/49, Batch Loss: 242149.3125
# Epoch 100, Batch 11/49, Batch Loss: 251075.8281
# Epoch 100, Batch 12/49, Batch Loss: 235122.6250
# Epoch 100, Batch 13/49, Batch Loss: 225113.5938
# Epoch 100, Batch 14/49, Batch Loss: 358994.6250
# Epoch 100, Batch 15/49, Batch Loss: 448830.2500
# Epoch 100, Batch 16/49, Batch Loss: 359658.4062
# Epoch 100, Batch 17/49, Batch Loss: 799937.3125
# Epoch 100, Batch 18/49, Batch Loss: 293136.8438
# Epoch 100, Batch 19/49, Batch Loss: 342526.3750
# Epoch 100, Batch 20/49, Batch Loss: 510529.6250
# Epoch 100, Batch 21/49, Batch Loss: 381230.0312
# Epoch 100, Batch 22/49, Batch Loss: 430033.0000
# Epoch 100, Batch 23/49, Batch Loss: 293671.2812
# Epoch 100, Batch 24/49, Batch Loss: 323208.6250
# Epoch 100, Batch 25/49, Batch Loss: 348372.5625
# Epoch 100, Batch 26/49, Batch Loss: 278689.5625
# Epoch 100, Batch 27/49, Batch Loss: 329999.0000
# Epoch 100, Batch 28/49, Batch Loss: 316532.3438
# Epoch 100, Batch 29/49, Batch Loss: 274076.1562
# Epoch 100, Batch 30/49, Batch Loss: 287989.2812
# Epoch 100, Batch 31/49, Batch Loss: 361569.4375
# Epoch 100, Batch 32/49, Batch Loss: 237554.6094
# Epoch 100, Batch 33/49, Batch Loss: 273032.6562
# Epoch 100, Batch 34/49, Batch Loss: 419266.5000
# Epoch 100, Batch 35/49, Batch Loss: 256433.7656
# Epoch 100, Batch 36/49, Batch Loss: 868677.6250
# Epoch 100, Batch 37/49, Batch Loss: 299951.4688
# Epoch 100, Batch 38/49, Batch Loss: 359410.0938
# Epoch 100, Batch 39/49, Batch Loss: 274787.7500
# Epoch 100, Batch 40/49, Batch Loss: 803626.0000
# Epoch 100, Batch 41/49, Batch Loss: 236114.3125
# Epoch 100, Batch 42/49, Batch Loss: 294361.5938
# Epoch 100, Batch 43/49, Batch Loss: 359800.6875
# Epoch 100, Batch 44/49, Batch Loss: 293467.2188
# Epoch 100, Batch 45/49, Batch Loss: 359315.2812
# Epoch 100, Batch 46/49, Batch Loss: 493191.8750
# Epoch 100, Batch 47/49, Batch Loss: 757322.0000
# Epoch 100, Batch 48/49, Batch Loss: 301319.8125
# Epoch 100, Batch 49/49, Batch Loss: 592756.6250
# Batch 1/17, Batch Loss: 312887.2188
# Batch 2/17, Batch Loss: 174050.0625
# Batch 3/17, Batch Loss: 303293.0312
# Batch 4/17, Batch Loss: 354832.8438
# Batch 5/17, Batch Loss: 208613.3125
# Batch 6/17, Batch Loss: 383738.5625
# Batch 7/17, Batch Loss: 324842.9688
# Batch 8/17, Batch Loss: 286146.9688
# Batch 9/17, Batch Loss: 500316.2812
# Batch 10/17, Batch Loss: 269613.3750
# Batch 11/17, Batch Loss: 284869.6250
# Batch 12/17, Batch Loss: 715987.5000
# Batch 13/17, Batch Loss: 369917.0000
# Batch 14/17, Batch Loss: 291747.5312
# Batch 15/17, Batch Loss: 301258.6250
# Batch 16/17, Batch Loss: 361458.5625
# Batch 17/17, Batch Loss: 526494.7500
# Test Error:
#  Avg loss: 351180.483456, Avg error: 261258.283737
#
# 2024-09-29 21:54:30.787803 Epoch 100, Average Training loss 383513.5851
# Epoch 101, Batch 1/49, Batch Loss: 302792.3438
# Epoch 101, Batch 2/49, Batch Loss: 793927.6250
# Epoch 101, Batch 3/49, Batch Loss: 277376.1875
# Epoch 101, Batch 4/49, Batch Loss: 232580.7812
# Epoch 101, Batch 5/49, Batch Loss: 264014.3750
# Epoch 101, Batch 6/49, Batch Loss: 582121.3125
# Epoch 101, Batch 7/49, Batch Loss: 452818.9688
# Epoch 101, Batch 8/49, Batch Loss: 225542.2500
# Epoch 101, Batch 9/49, Batch Loss: 332920.4062
# Epoch 101, Batch 10/49, Batch Loss: 442994.6250
# Epoch 101, Batch 11/49, Batch Loss: 303379.0312
# Epoch 101, Batch 12/49, Batch Loss: 392214.0000
# Epoch 101, Batch 13/49, Batch Loss: 316401.3125
# Epoch 101, Batch 14/49, Batch Loss: 246277.1562
# Epoch 101, Batch 15/49, Batch Loss: 321628.7188
# Epoch 101, Batch 16/49, Batch Loss: 770552.0625
# Epoch 101, Batch 17/49, Batch Loss: 757581.9375
# Epoch 101, Batch 18/49, Batch Loss: 456098.0000
# Epoch 101, Batch 19/49, Batch Loss: 461711.5000
# Epoch 101, Batch 20/49, Batch Loss: 314925.3750
# Epoch 101, Batch 21/49, Batch Loss: 237079.8750
# Epoch 101, Batch 22/49, Batch Loss: 260123.5781
# Epoch 101, Batch 23/49, Batch Loss: 417197.0625
# Epoch 101, Batch 24/49, Batch Loss: 324169.3125
# Epoch 101, Batch 25/49, Batch Loss: 284335.1250
# Epoch 101, Batch 26/49, Batch Loss: 787318.6250
# Epoch 101, Batch 27/49, Batch Loss: 307736.9062
# Epoch 101, Batch 28/49, Batch Loss: 337896.9062
# Epoch 101, Batch 29/49, Batch Loss: 372682.4688
# Epoch 101, Batch 30/49, Batch Loss: 604759.1875
# Epoch 101, Batch 31/49, Batch Loss: 249038.8594
# Epoch 101, Batch 32/49, Batch Loss: 430409.3750
# Epoch 101, Batch 33/49, Batch Loss: 357809.0938
# Epoch 101, Batch 34/49, Batch Loss: 269163.6875
# Epoch 101, Batch 35/49, Batch Loss: 755843.3750
# Epoch 101, Batch 36/49, Batch Loss: 310345.5625
# Epoch 101, Batch 37/49, Batch Loss: 363280.5625
# Epoch 101, Batch 38/49, Batch Loss: 235690.3750
# Epoch 101, Batch 39/49, Batch Loss: 447164.6875
# Epoch 101, Batch 40/49, Batch Loss: 407712.8750
# Epoch 101, Batch 41/49, Batch Loss: 395191.2812
# Epoch 101, Batch 42/49, Batch Loss: 323461.0312
# Epoch 101, Batch 43/49, Batch Loss: 329447.4062
# Epoch 101, Batch 44/49, Batch Loss: 257907.0156
# Epoch 101, Batch 45/49, Batch Loss: 337958.7500
# Epoch 101, Batch 46/49, Batch Loss: 279559.4062
# Epoch 101, Batch 47/49, Batch Loss: 282067.7812
# Epoch 101, Batch 48/49, Batch Loss: 474334.6875
# Epoch 101, Batch 49/49, Batch Loss: 200191.0625
# Batch 1/17, Batch Loss: 309544.3750
# Batch 2/17, Batch Loss: 173802.6875
# Batch 3/17, Batch Loss: 301969.9375
# Batch 4/17, Batch Loss: 354201.2188
# Batch 5/17, Batch Loss: 208968.6094
# Batch 6/17, Batch Loss: 386243.1250
# Batch 7/17, Batch Loss: 327756.2812
# Batch 8/17, Batch Loss: 285091.2188
# Batch 9/17, Batch Loss: 498373.8750
# Batch 10/17, Batch Loss: 267675.5000
# Batch 11/17, Batch Loss: 289440.2812
# Batch 12/17, Batch Loss: 716783.0625
# Batch 13/17, Batch Loss: 369342.5000
# Batch 14/17, Batch Loss: 288803.4062
# Batch 15/17, Batch Loss: 306997.6562
# Batch 16/17, Batch Loss: 365857.2188
# Batch 17/17, Batch Loss: 530262.5000
# Test Error:
#  Avg loss: 351830.203125, Avg error: 261929.046713
#
# Epoch 102, Batch 1/49, Batch Loss: 400516.3125
# Epoch 102, Batch 2/49, Batch Loss: 501886.0625
# Epoch 102, Batch 3/49, Batch Loss: 594196.3750
# Epoch 102, Batch 4/49, Batch Loss: 312259.0625
# Epoch 102, Batch 5/49, Batch Loss: 248409.9531
# Epoch 102, Batch 6/49, Batch Loss: 336189.8125
# Epoch 102, Batch 7/49, Batch Loss: 314889.1250
# Epoch 102, Batch 8/49, Batch Loss: 329375.0312
# Epoch 102, Batch 9/49, Batch Loss: 292175.6875
# Epoch 102, Batch 10/49, Batch Loss: 282238.0938
# Epoch 102, Batch 11/49, Batch Loss: 391950.6250
# Epoch 102, Batch 12/49, Batch Loss: 319289.9375
# Epoch 102, Batch 13/49, Batch Loss: 795529.1875
# Epoch 102, Batch 14/49, Batch Loss: 273500.2812
# Epoch 102, Batch 15/49, Batch Loss: 291387.6562
# Epoch 102, Batch 16/49, Batch Loss: 514012.5000
# Epoch 102, Batch 17/49, Batch Loss: 504847.8125
# Epoch 102, Batch 18/49, Batch Loss: 301230.0938
# Epoch 102, Batch 19/49, Batch Loss: 266112.4688
# Epoch 102, Batch 20/49, Batch Loss: 839402.5000
# Epoch 102, Batch 21/49, Batch Loss: 267125.6562
# Epoch 102, Batch 22/49, Batch Loss: 336486.8750
# Epoch 102, Batch 23/49, Batch Loss: 246257.6094
# Epoch 102, Batch 24/49, Batch Loss: 333046.8125
# Epoch 102, Batch 25/49, Batch Loss: 348419.8750
# Epoch 102, Batch 26/49, Batch Loss: 328727.9062
# Epoch 102, Batch 27/49, Batch Loss: 270419.4375
# Epoch 102, Batch 28/49, Batch Loss: 317613.3438
# Epoch 102, Batch 29/49, Batch Loss: 322400.9062
# Epoch 102, Batch 30/49, Batch Loss: 445622.8125
# Epoch 102, Batch 31/49, Batch Loss: 757776.3125
# Epoch 102, Batch 32/49, Batch Loss: 250052.1094
# Epoch 102, Batch 33/49, Batch Loss: 304599.4062
# Epoch 102, Batch 34/49, Batch Loss: 473200.8125
# Epoch 102, Batch 35/49, Batch Loss: 236613.8906
# Epoch 102, Batch 36/49, Batch Loss: 328156.7500
# Epoch 102, Batch 37/49, Batch Loss: 258637.7344
# Epoch 102, Batch 38/49, Batch Loss: 301227.7188
# Epoch 102, Batch 39/49, Batch Loss: 466844.0625
# Epoch 102, Batch 40/49, Batch Loss: 322665.1250
# Epoch 102, Batch 41/49, Batch Loss: 299744.8438
# Epoch 102, Batch 42/49, Batch Loss: 338546.7188
# Epoch 102, Batch 43/49, Batch Loss: 248733.0469
# Epoch 102, Batch 44/49, Batch Loss: 331490.9375
# Epoch 102, Batch 45/49, Batch Loss: 758594.2500
# Epoch 102, Batch 46/49, Batch Loss: 805981.8125
# Epoch 102, Batch 47/49, Batch Loss: 387146.3750
# Epoch 102, Batch 48/49, Batch Loss: 289451.1875
# Epoch 102, Batch 49/49, Batch Loss: 402335.8750
# Batch 1/17, Batch Loss: 306436.6250
# Batch 2/17, Batch Loss: 172746.0625
# Batch 3/17, Batch Loss: 298509.0312
# Batch 4/17, Batch Loss: 352699.8438
# Batch 5/17, Batch Loss: 208727.2344
# Batch 6/17, Batch Loss: 390813.9688
# Batch 7/17, Batch Loss: 330494.1562
# Batch 8/17, Batch Loss: 284000.5938
# Batch 9/17, Batch Loss: 501145.5625
# Batch 10/17, Batch Loss: 265595.6875
# Batch 11/17, Batch Loss: 291906.1875
# Batch 12/17, Batch Loss: 718881.3750
# Batch 13/17, Batch Loss: 369183.3750
# Batch 14/17, Batch Loss: 286760.3125
# Batch 15/17, Batch Loss: 310044.9688
# Batch 16/17, Batch Loss: 369553.0312
# Batch 17/17, Batch Loss: 535553.1875
# Test Error:
#  Avg loss: 352532.423713, Avg error: 262514.887543
#
# Epoch 103, Batch 1/49, Batch Loss: 518879.7812
# Epoch 103, Batch 2/49, Batch Loss: 298812.0000
# Epoch 103, Batch 3/49, Batch Loss: 346396.5000
# Epoch 103, Batch 4/49, Batch Loss: 791538.8750
# Epoch 103, Batch 5/49, Batch Loss: 275191.2188
# Epoch 103, Batch 6/49, Batch Loss: 292060.8750
# Epoch 103, Batch 7/49, Batch Loss: 454366.0625
# Epoch 103, Batch 8/49, Batch Loss: 281562.9688
# Epoch 103, Batch 9/49, Batch Loss: 213835.3750
# Epoch 103, Batch 10/49, Batch Loss: 229720.8594
# Epoch 103, Batch 11/49, Batch Loss: 391111.1562
# Epoch 103, Batch 12/49, Batch Loss: 772625.3750
# Epoch 103, Batch 13/49, Batch Loss: 805634.1875
# Epoch 103, Batch 14/49, Batch Loss: 291395.6875
# Epoch 103, Batch 15/49, Batch Loss: 358371.3750
# Epoch 103, Batch 16/49, Batch Loss: 505259.7500
# Epoch 103, Batch 17/49, Batch Loss: 850718.5625
# Epoch 103, Batch 18/49, Batch Loss: 284232.4375
# Epoch 103, Batch 19/49, Batch Loss: 368093.4375
# Epoch 103, Batch 20/49, Batch Loss: 285482.2188
# Epoch 103, Batch 21/49, Batch Loss: 359691.9375
# Epoch 103, Batch 22/49, Batch Loss: 304699.7500
# Epoch 103, Batch 23/49, Batch Loss: 215826.0469
# Epoch 103, Batch 24/49, Batch Loss: 298807.9062
# Epoch 103, Batch 25/49, Batch Loss: 345094.1250
# Epoch 103, Batch 26/49, Batch Loss: 265242.4375
# Epoch 103, Batch 27/49, Batch Loss: 248394.4531
# Epoch 103, Batch 28/49, Batch Loss: 303246.5625
# Epoch 103, Batch 29/49, Batch Loss: 775481.1875
# Epoch 103, Batch 30/49, Batch Loss: 355918.6875
# Epoch 103, Batch 31/49, Batch Loss: 359805.3750
# Epoch 103, Batch 32/49, Batch Loss: 371816.5000
# Epoch 103, Batch 33/49, Batch Loss: 279557.0938
# Epoch 103, Batch 34/49, Batch Loss: 324721.6562
# Epoch 103, Batch 35/49, Batch Loss: 633616.8125
# Epoch 103, Batch 36/49, Batch Loss: 303593.8125
# Epoch 103, Batch 37/49, Batch Loss: 525591.1875
# Epoch 103, Batch 38/49, Batch Loss: 294452.6250
# Epoch 103, Batch 39/49, Batch Loss: 236610.3750
# Epoch 103, Batch 40/49, Batch Loss: 292297.6562
# Epoch 103, Batch 41/49, Batch Loss: 273054.6250
# Epoch 103, Batch 42/49, Batch Loss: 299213.6875
# Epoch 103, Batch 43/49, Batch Loss: 329269.7188
# Epoch 103, Batch 44/49, Batch Loss: 342048.9375
# Epoch 103, Batch 45/49, Batch Loss: 354260.6875
# Epoch 103, Batch 46/49, Batch Loss: 302777.5312
# Epoch 103, Batch 47/49, Batch Loss: 527170.0000
# Epoch 103, Batch 48/49, Batch Loss: 270799.2188
# Epoch 103, Batch 49/49, Batch Loss: 298880.1250
# Batch 1/17, Batch Loss: 305841.6875
# Batch 2/17, Batch Loss: 173076.0312
# Batch 3/17, Batch Loss: 297088.7188
# Batch 4/17, Batch Loss: 353261.7500
# Batch 5/17, Batch Loss: 209088.7031
# Batch 6/17, Batch Loss: 390366.3125
# Batch 7/17, Batch Loss: 331209.7812
# Batch 8/17, Batch Loss: 283587.9062
# Batch 9/17, Batch Loss: 500222.5938
# Batch 10/17, Batch Loss: 265283.3438
# Batch 11/17, Batch Loss: 292695.6875
# Batch 12/17, Batch Loss: 718870.0625
# Batch 13/17, Batch Loss: 368862.8750
# Batch 14/17, Batch Loss: 286581.0000
# Batch 15/17, Batch Loss: 311411.6562
# Batch 16/17, Batch Loss: 370812.7500
# Batch 17/17, Batch Loss: 537214.3750
# Test Error:
#  Avg loss: 352675.013787, Avg error: 262716.431661
#
# Epoch 104, Batch 1/49, Batch Loss: 233108.3438
# Epoch 104, Batch 2/49, Batch Loss: 228454.0000
# Epoch 104, Batch 3/49, Batch Loss: 333757.9062
# Epoch 104, Batch 4/49, Batch Loss: 355658.8438
# Epoch 104, Batch 5/49, Batch Loss: 235591.4375
# Epoch 104, Batch 6/49, Batch Loss: 429925.6562
# Epoch 104, Batch 7/49, Batch Loss: 775513.6250
# Epoch 104, Batch 8/49, Batch Loss: 263870.0000
# Epoch 104, Batch 9/49, Batch Loss: 236158.6719
# Epoch 104, Batch 10/49, Batch Loss: 760757.5000
# Epoch 104, Batch 11/49, Batch Loss: 429121.9375
# Epoch 104, Batch 12/49, Batch Loss: 278819.3438
# Epoch 104, Batch 13/49, Batch Loss: 295784.9688
# Epoch 104, Batch 14/49, Batch Loss: 241653.9688
# Epoch 104, Batch 15/49, Batch Loss: 553605.6250
# Epoch 104, Batch 16/49, Batch Loss: 318943.0625
# Epoch 104, Batch 17/49, Batch Loss: 368496.1875
# Epoch 104, Batch 18/49, Batch Loss: 350705.5312
# Epoch 104, Batch 19/49, Batch Loss: 331727.5625
# Epoch 104, Batch 20/49, Batch Loss: 390655.4062
# Epoch 104, Batch 21/49, Batch Loss: 396682.1875
# Epoch 104, Batch 22/49, Batch Loss: 775868.0000
# Epoch 104, Batch 23/49, Batch Loss: 258661.0156
# Epoch 104, Batch 24/49, Batch Loss: 327855.8750
# Epoch 104, Batch 25/49, Batch Loss: 240389.8125
# Epoch 104, Batch 26/49, Batch Loss: 238114.8281
# Epoch 104, Batch 27/49, Batch Loss: 291557.5625
# Epoch 104, Batch 28/49, Batch Loss: 308096.7500
# Epoch 104, Batch 29/49, Batch Loss: 306604.6250
# Epoch 104, Batch 30/49, Batch Loss: 239953.5781
# Epoch 104, Batch 31/49, Batch Loss: 293804.0312
# Epoch 104, Batch 32/49, Batch Loss: 293192.8125
# Epoch 104, Batch 33/49, Batch Loss: 217756.8125
# Epoch 104, Batch 34/49, Batch Loss: 303622.7188
# Epoch 104, Batch 35/49, Batch Loss: 258461.7500
# Epoch 104, Batch 36/49, Batch Loss: 380137.5312
# Epoch 104, Batch 37/49, Batch Loss: 313712.6875
# Epoch 104, Batch 38/49, Batch Loss: 364846.7188
# Epoch 104, Batch 39/49, Batch Loss: 775883.3750
# Epoch 104, Batch 40/49, Batch Loss: 374614.3125
# Epoch 104, Batch 41/49, Batch Loss: 439280.8438
# Epoch 104, Batch 42/49, Batch Loss: 799832.0625
# Epoch 104, Batch 43/49, Batch Loss: 445645.1250
# Epoch 104, Batch 44/49, Batch Loss: 643370.6250
# Epoch 104, Batch 45/49, Batch Loss: 610439.9375
# Epoch 104, Batch 46/49, Batch Loss: 312240.7812
# Epoch 104, Batch 47/49, Batch Loss: 342927.5625
# Epoch 104, Batch 48/49, Batch Loss: 324933.0000
# Epoch 104, Batch 49/49, Batch Loss: 477604.1875
# Batch 1/17, Batch Loss: 333819.2500
# Batch 2/17, Batch Loss: 180285.6562
# Batch 3/17, Batch Loss: 302904.6250
# Batch 4/17, Batch Loss: 361036.1875
# Batch 5/17, Batch Loss: 207343.1250
# Batch 6/17, Batch Loss: 375097.6250
# Batch 7/17, Batch Loss: 315895.5938
# Batch 8/17, Batch Loss: 293555.9375
# Batch 9/17, Batch Loss: 505642.2500
# Batch 10/17, Batch Loss: 280778.2188
# Batch 11/17, Batch Loss: 269830.4375
# Batch 12/17, Batch Loss: 714481.8125
# Batch 13/17, Batch Loss: 372995.3750
# Batch 14/17, Batch Loss: 303570.3438
# Batch 15/17, Batch Loss: 286045.2188
# Batch 16/17, Batch Loss: 349649.5625
# Batch 17/17, Batch Loss: 513510.9688
# Test Error:
#  Avg loss: 350967.187500, Avg error: 261978.733564
#
# Epoch 105, Batch 1/49, Batch Loss: 775728.0000
# Epoch 105, Batch 2/49, Batch Loss: 361510.6875
# Epoch 105, Batch 3/49, Batch Loss: 286674.1250
# Epoch 105, Batch 4/49, Batch Loss: 283688.1250
# Epoch 105, Batch 5/49, Batch Loss: 350619.0938
# Epoch 105, Batch 6/49, Batch Loss: 259282.2812
# Epoch 105, Batch 7/49, Batch Loss: 327204.5312
# Epoch 105, Batch 8/49, Batch Loss: 432941.2500
# Epoch 105, Batch 9/49, Batch Loss: 219245.6875
# Epoch 105, Batch 10/49, Batch Loss: 261981.3281
# Epoch 105, Batch 11/49, Batch Loss: 234606.8281
# Epoch 105, Batch 12/49, Batch Loss: 303148.1250
# Epoch 105, Batch 13/49, Batch Loss: 552603.8750
# Epoch 105, Batch 14/49, Batch Loss: 327464.4688
# Epoch 105, Batch 15/49, Batch Loss: 564682.6250
# Epoch 105, Batch 16/49, Batch Loss: 343487.3438
# Epoch 105, Batch 17/49, Batch Loss: 279743.0000
# Epoch 105, Batch 18/49, Batch Loss: 290945.1875
# Epoch 105, Batch 19/49, Batch Loss: 268443.6875
# Epoch 105, Batch 20/49, Batch Loss: 271977.8438
# Epoch 105, Batch 21/49, Batch Loss: 299837.7812
# Epoch 105, Batch 22/49, Batch Loss: 360505.1562
# Epoch 105, Batch 23/49, Batch Loss: 491476.5312
# Epoch 105, Batch 24/49, Batch Loss: 261281.7656
# Epoch 105, Batch 25/49, Batch Loss: 322232.6875
# Epoch 105, Batch 26/49, Batch Loss: 392233.5312
# Epoch 105, Batch 27/49, Batch Loss: 402355.5000
# Epoch 105, Batch 28/49, Batch Loss: 291608.9062
# Epoch 105, Batch 29/49, Batch Loss: 758197.0000
# Epoch 105, Batch 30/49, Batch Loss: 256688.3750
# Epoch 105, Batch 31/49, Batch Loss: 224946.8750
# Epoch 105, Batch 32/49, Batch Loss: 368969.0000
# Epoch 105, Batch 33/49, Batch Loss: 244289.4219
# Epoch 105, Batch 34/49, Batch Loss: 272652.8750
# Epoch 105, Batch 35/49, Batch Loss: 511618.4375
# Epoch 105, Batch 36/49, Batch Loss: 459553.0000
# Epoch 105, Batch 37/49, Batch Loss: 464539.3750
# Epoch 105, Batch 38/49, Batch Loss: 459803.8750
# Epoch 105, Batch 39/49, Batch Loss: 329606.8125
# Epoch 105, Batch 40/49, Batch Loss: 499561.7500
# Epoch 105, Batch 41/49, Batch Loss: 772390.8125
# Epoch 105, Batch 42/49, Batch Loss: 454381.3438
# Epoch 105, Batch 43/49, Batch Loss: 273120.4688
# Epoch 105, Batch 44/49, Batch Loss: 395615.9062
# Epoch 105, Batch 45/49, Batch Loss: 272502.4688
# Epoch 105, Batch 46/49, Batch Loss: 320690.8125
# Epoch 105, Batch 47/49, Batch Loss: 759583.9375
# Epoch 105, Batch 48/49, Batch Loss: 740196.0625
# Epoch 105, Batch 49/49, Batch Loss: 272231.1562
# Batch 1/17, Batch Loss: 330601.6875
# Batch 2/17, Batch Loss: 178750.2031
# Batch 3/17, Batch Loss: 301485.7500
# Batch 4/17, Batch Loss: 360205.6250
# Batch 5/17, Batch Loss: 207779.1562
# Batch 6/17, Batch Loss: 376150.6562
# Batch 7/17, Batch Loss: 317027.6875
# Batch 8/17, Batch Loss: 291924.7188
# Batch 9/17, Batch Loss: 504768.9062
# Batch 10/17, Batch Loss: 277620.9688
# Batch 11/17, Batch Loss: 271747.0625
# Batch 12/17, Batch Loss: 715010.1250
# Batch 13/17, Batch Loss: 372186.5312
# Batch 14/17, Batch Loss: 302598.1875
# Batch 15/17, Batch Loss: 289150.9062
# Batch 16/17, Batch Loss: 351710.0312
# Batch 17/17, Batch Loss: 517928.3438
# Test Error:
#  Avg loss: 350979.208640, Avg error: 261953.521626
#
# Epoch 106, Batch 1/49, Batch Loss: 339519.0000
# Epoch 106, Batch 2/49, Batch Loss: 287978.6562
# Epoch 106, Batch 3/49, Batch Loss: 242697.4375
# Epoch 106, Batch 4/49, Batch Loss: 256732.4062
# Epoch 106, Batch 5/49, Batch Loss: 361301.7188
# Epoch 106, Batch 6/49, Batch Loss: 495242.8438
# Epoch 106, Batch 7/49, Batch Loss: 713313.6875
# Epoch 106, Batch 8/49, Batch Loss: 385727.5625
# Epoch 106, Batch 9/49, Batch Loss: 410456.9062
# Epoch 106, Batch 10/49, Batch Loss: 337546.0000
# Epoch 106, Batch 11/49, Batch Loss: 265738.5625
# Epoch 106, Batch 12/49, Batch Loss: 364928.4375
# Epoch 106, Batch 13/49, Batch Loss: 279796.5625
# Epoch 106, Batch 14/49, Batch Loss: 320728.7812
# Epoch 106, Batch 15/49, Batch Loss: 261659.3594
# Epoch 106, Batch 16/49, Batch Loss: 260910.7969
# Epoch 106, Batch 17/49, Batch Loss: 472614.1250
# Epoch 106, Batch 18/49, Batch Loss: 314955.4688
# Epoch 106, Batch 19/49, Batch Loss: 245199.2656
# Epoch 106, Batch 20/49, Batch Loss: 374413.2500
# Epoch 106, Batch 21/49, Batch Loss: 277830.3438
# Epoch 106, Batch 22/49, Batch Loss: 752492.4375
# Epoch 106, Batch 23/49, Batch Loss: 377838.5625
# Epoch 106, Batch 24/49, Batch Loss: 292314.9688
# Epoch 106, Batch 25/49, Batch Loss: 490814.4375
# Epoch 106, Batch 26/49, Batch Loss: 289293.3750
# Epoch 106, Batch 27/49, Batch Loss: 301907.2188
# Epoch 106, Batch 28/49, Batch Loss: 312318.8438
# Epoch 106, Batch 29/49, Batch Loss: 766071.5000
# Epoch 106, Batch 30/49, Batch Loss: 293530.3438
# Epoch 106, Batch 31/49, Batch Loss: 359165.3750
# Epoch 106, Batch 32/49, Batch Loss: 287424.0625
# Epoch 106, Batch 33/49, Batch Loss: 772902.3125
# Epoch 106, Batch 34/49, Batch Loss: 360399.1562
# Epoch 106, Batch 35/49, Batch Loss: 322162.3438
# Epoch 106, Batch 36/49, Batch Loss: 379665.2500
# Epoch 106, Batch 37/49, Batch Loss: 266807.5312
# Epoch 106, Batch 38/49, Batch Loss: 774079.5625
# Epoch 106, Batch 39/49, Batch Loss: 347725.6250
# Epoch 106, Batch 40/49, Batch Loss: 750190.5625
# Epoch 106, Batch 41/49, Batch Loss: 280140.2500
# Epoch 106, Batch 42/49, Batch Loss: 312833.1250
# Epoch 106, Batch 43/49, Batch Loss: 315895.3750
# Epoch 106, Batch 44/49, Batch Loss: 279746.5312
# Epoch 106, Batch 45/49, Batch Loss: 226898.5469
# Epoch 106, Batch 46/49, Batch Loss: 492287.1875
# Epoch 106, Batch 47/49, Batch Loss: 487035.8125
# Epoch 106, Batch 48/49, Batch Loss: 402104.5312
# Epoch 106, Batch 49/49, Batch Loss: 356511.3125
# Batch 1/17, Batch Loss: 302980.4688
# Batch 2/17, Batch Loss: 174465.3750
# Batch 3/17, Batch Loss: 294596.0938
# Batch 4/17, Batch Loss: 353510.5625
# Batch 5/17, Batch Loss: 211094.6719
# Batch 6/17, Batch Loss: 394634.6562
# Batch 7/17, Batch Loss: 335093.5312
# Batch 8/17, Batch Loss: 283327.6250
# Batch 9/17, Batch Loss: 499189.3125
# Batch 10/17, Batch Loss: 262954.2812
# Batch 11/17, Batch Loss: 296738.1875
# Batch 12/17, Batch Loss: 719924.2500
# Batch 13/17, Batch Loss: 366906.3438
# Batch 14/17, Batch Loss: 286102.5000
# Batch 15/17, Batch Loss: 319640.8125
# Batch 16/17, Batch Loss: 378041.0312
# Batch 17/17, Batch Loss: 542785.0000
# Test Error:
#  Avg loss: 354234.394301, Avg error: 264612.285467
#
# Epoch 107, Batch 1/49, Batch Loss: 293061.4688
# Epoch 107, Batch 2/49, Batch Loss: 495355.7188
# Epoch 107, Batch 3/49, Batch Loss: 420800.7188
# Epoch 107, Batch 4/49, Batch Loss: 266928.9375
# Epoch 107, Batch 5/49, Batch Loss: 286925.3750
# Epoch 107, Batch 6/49, Batch Loss: 340553.2812
# Epoch 107, Batch 7/49, Batch Loss: 299905.9688
# Epoch 107, Batch 8/49, Batch Loss: 253484.8438
# Epoch 107, Batch 9/49, Batch Loss: 752009.5000
# Epoch 107, Batch 10/49, Batch Loss: 260908.4531
# Epoch 107, Batch 11/49, Batch Loss: 266062.3750
# Epoch 107, Batch 12/49, Batch Loss: 514927.1250
# Epoch 107, Batch 13/49, Batch Loss: 334497.1875
# Epoch 107, Batch 14/49, Batch Loss: 294197.1250
# Epoch 107, Batch 15/49, Batch Loss: 358692.3750
# Epoch 107, Batch 16/49, Batch Loss: 284462.5938
# Epoch 107, Batch 17/49, Batch Loss: 420949.8438
# Epoch 107, Batch 18/49, Batch Loss: 204586.5156
# Epoch 107, Batch 19/49, Batch Loss: 777962.4375
# Epoch 107, Batch 20/49, Batch Loss: 385992.8125
# Epoch 107, Batch 21/49, Batch Loss: 753684.1875
# Epoch 107, Batch 22/49, Batch Loss: 341366.0312
# Epoch 107, Batch 23/49, Batch Loss: 467792.9375
# Epoch 107, Batch 24/49, Batch Loss: 779385.6875
# Epoch 107, Batch 25/49, Batch Loss: 267052.0312
# Epoch 107, Batch 26/49, Batch Loss: 486516.3125
# Epoch 107, Batch 27/49, Batch Loss: 269428.5312
# Epoch 107, Batch 28/49, Batch Loss: 297293.8125
# Epoch 107, Batch 29/49, Batch Loss: 319997.2188
# Epoch 107, Batch 30/49, Batch Loss: 384334.0938
# Epoch 107, Batch 31/49, Batch Loss: 233601.5312
# Epoch 107, Batch 32/49, Batch Loss: 247229.8906
# Epoch 107, Batch 33/49, Batch Loss: 408358.6250
# Epoch 107, Batch 34/49, Batch Loss: 279234.3438
# Epoch 107, Batch 35/49, Batch Loss: 252616.6094
# Epoch 107, Batch 36/49, Batch Loss: 447343.4375
# Epoch 107, Batch 37/49, Batch Loss: 759403.6875
# Epoch 107, Batch 38/49, Batch Loss: 372398.8438
# Epoch 107, Batch 39/49, Batch Loss: 402357.5938
# Epoch 107, Batch 40/49, Batch Loss: 270600.8750
# Epoch 107, Batch 41/49, Batch Loss: 251571.7031
# Epoch 107, Batch 42/49, Batch Loss: 254543.6562
# Epoch 107, Batch 43/49, Batch Loss: 335110.0000
# Epoch 107, Batch 44/49, Batch Loss: 301938.7500
# Epoch 107, Batch 45/49, Batch Loss: 282040.6562
# Epoch 107, Batch 46/49, Batch Loss: 402638.4375
# Epoch 107, Batch 47/49, Batch Loss: 433304.3750
# Epoch 107, Batch 48/49, Batch Loss: 264156.3125
# Epoch 107, Batch 49/49, Batch Loss: 714050.5000
# Batch 1/17, Batch Loss: 327403.6250
# Batch 2/17, Batch Loss: 177000.7500
# Batch 3/17, Batch Loss: 300088.5312
# Batch 4/17, Batch Loss: 359123.9062
# Batch 5/17, Batch Loss: 208081.8125
# Batch 6/17, Batch Loss: 376823.1562
# Batch 7/17, Batch Loss: 317867.9375
# Batch 8/17, Batch Loss: 290101.2812
# Batch 9/17, Batch Loss: 503500.1250
# Batch 10/17, Batch Loss: 275745.2812
# Batch 11/17, Batch Loss: 274433.1562
# Batch 12/17, Batch Loss: 714237.8125
# Batch 13/17, Batch Loss: 369460.8750
# Batch 14/17, Batch Loss: 300498.0625
# Batch 15/17, Batch Loss: 293623.4062
# Batch 16/17, Batch Loss: 354785.1250
# Batch 17/17, Batch Loss: 519088.8750
# Test Error:
#  Avg loss: 350697.865809, Avg error: 261513.258651
#
# Epoch 108, Batch 1/49, Batch Loss: 310466.7812
# Epoch 108, Batch 2/49, Batch Loss: 278752.1875
# Epoch 108, Batch 3/49, Batch Loss: 271846.0938
# Epoch 108, Batch 4/49, Batch Loss: 351186.6875
# Epoch 108, Batch 5/49, Batch Loss: 939556.8750
# Epoch 108, Batch 6/49, Batch Loss: 326841.1250
# Epoch 108, Batch 7/49, Batch Loss: 355098.0312
# Epoch 108, Batch 8/49, Batch Loss: 311873.2500
# Epoch 108, Batch 9/49, Batch Loss: 333369.2188
# Epoch 108, Batch 10/49, Batch Loss: 377527.1250
# Epoch 108, Batch 11/49, Batch Loss: 783482.8750
# Epoch 108, Batch 12/49, Batch Loss: 478153.8438
# Epoch 108, Batch 13/49, Batch Loss: 377042.7188
# Epoch 108, Batch 14/49, Batch Loss: 502842.5625
# Epoch 108, Batch 15/49, Batch Loss: 458924.1562
# Epoch 108, Batch 16/49, Batch Loss: 391538.0000
# Epoch 108, Batch 17/49, Batch Loss: 360089.8750
# Epoch 108, Batch 18/49, Batch Loss: 229302.2812
# Epoch 108, Batch 19/49, Batch Loss: 289407.2500
# Epoch 108, Batch 20/49, Batch Loss: 308318.7500
# Epoch 108, Batch 21/49, Batch Loss: 763363.6875
# Epoch 108, Batch 22/49, Batch Loss: 412085.2812
# Epoch 108, Batch 23/49, Batch Loss: 269743.0938
# Epoch 108, Batch 24/49, Batch Loss: 360112.7500
# Epoch 108, Batch 25/49, Batch Loss: 455210.6250
# Epoch 108, Batch 26/49, Batch Loss: 471716.7188
# Epoch 108, Batch 27/49, Batch Loss: 802053.3750
# Epoch 108, Batch 28/49, Batch Loss: 300227.4062
# Epoch 108, Batch 29/49, Batch Loss: 333284.9062
# Epoch 108, Batch 30/49, Batch Loss: 193895.4219
# Epoch 108, Batch 31/49, Batch Loss: 291789.4375
# Epoch 108, Batch 32/49, Batch Loss: 274490.4062
# Epoch 108, Batch 33/49, Batch Loss: 284944.7188
# Epoch 108, Batch 34/49, Batch Loss: 346487.7500
# Epoch 108, Batch 35/49, Batch Loss: 310962.1250
# Epoch 108, Batch 36/49, Batch Loss: 349684.9688
# Epoch 108, Batch 37/49, Batch Loss: 284028.5000
# Epoch 108, Batch 38/49, Batch Loss: 248961.0781
# Epoch 108, Batch 39/49, Batch Loss: 250267.2344
# Epoch 108, Batch 40/49, Batch Loss: 348992.1250
# Epoch 108, Batch 41/49, Batch Loss: 305672.2812
# Epoch 108, Batch 42/49, Batch Loss: 285163.0625
# Epoch 108, Batch 43/49, Batch Loss: 270575.2812
# Epoch 108, Batch 44/49, Batch Loss: 287263.2500
# Epoch 108, Batch 45/49, Batch Loss: 291613.7188
# Epoch 108, Batch 46/49, Batch Loss: 314445.4375
# Epoch 108, Batch 47/49, Batch Loss: 291283.3438
# Epoch 108, Batch 48/49, Batch Loss: 766930.4375
# Epoch 108, Batch 49/49, Batch Loss: 508522.9062
# Batch 1/17, Batch Loss: 320661.7500
# Batch 2/17, Batch Loss: 175086.1562
# Batch 3/17, Batch Loss: 298273.4688
# Batch 4/17, Batch Loss: 357423.0000
# Batch 5/17, Batch Loss: 209810.7969
# Batch 6/17, Batch Loss: 379600.6875
# Batch 7/17, Batch Loss: 320758.6875
# Batch 8/17, Batch Loss: 287230.2188
# Batch 9/17, Batch Loss: 500337.2188
# Batch 10/17, Batch Loss: 270865.4062
# Batch 11/17, Batch Loss: 279445.6875
# Batch 12/17, Batch Loss: 714786.0000
# Batch 13/17, Batch Loss: 367954.6562
# Batch 14/17, Batch Loss: 296576.5625
# Batch 15/17, Batch Loss: 300849.8750
# Batch 16/17, Batch Loss: 359899.2188
# Batch 17/17, Batch Loss: 526635.5625
# Test Error:
#  Avg loss: 350952.644301, Avg error: 261593.121972
#
# Epoch 109, Batch 1/49, Batch Loss: 301236.5000
# Epoch 109, Batch 2/49, Batch Loss: 763254.5000
# Epoch 109, Batch 3/49, Batch Loss: 316111.6562
# Epoch 109, Batch 4/49, Batch Loss: 320078.7188
# Epoch 109, Batch 5/49, Batch Loss: 305630.8438
# Epoch 109, Batch 6/49, Batch Loss: 431554.0938
# Epoch 109, Batch 7/49, Batch Loss: 322913.6875
# Epoch 109, Batch 8/49, Batch Loss: 257252.3438
# Epoch 109, Batch 9/49, Batch Loss: 335327.7188
# Epoch 109, Batch 10/49, Batch Loss: 327674.6875
# Epoch 109, Batch 11/49, Batch Loss: 418086.3125
# Epoch 109, Batch 12/49, Batch Loss: 326697.1875
# Epoch 109, Batch 13/49, Batch Loss: 317295.9688
# Epoch 109, Batch 14/49, Batch Loss: 309105.0625
# Epoch 109, Batch 15/49, Batch Loss: 935820.4375
# Epoch 109, Batch 16/49, Batch Loss: 755170.5625
# Epoch 109, Batch 17/49, Batch Loss: 332195.3438
# Epoch 109, Batch 18/49, Batch Loss: 262917.9062
# Epoch 109, Batch 19/49, Batch Loss: 321435.5625
# Epoch 109, Batch 20/49, Batch Loss: 576838.6875
# Epoch 109, Batch 21/49, Batch Loss: 300463.4062
# Epoch 109, Batch 22/49, Batch Loss: 313273.1250
# Epoch 109, Batch 23/49, Batch Loss: 409524.5312
# Epoch 109, Batch 24/49, Batch Loss: 556580.8750
# Epoch 109, Batch 25/49, Batch Loss: 306860.6250
# Epoch 109, Batch 26/49, Batch Loss: 347592.3125
# Epoch 109, Batch 27/49, Batch Loss: 278066.0000
# Epoch 109, Batch 28/49, Batch Loss: 292737.1250
# Epoch 109, Batch 29/49, Batch Loss: 319853.5938
# Epoch 109, Batch 30/49, Batch Loss: 462809.6562
# Epoch 109, Batch 31/49, Batch Loss: 549371.2500
# Epoch 109, Batch 32/49, Batch Loss: 299619.5625
# Epoch 109, Batch 33/49, Batch Loss: 311191.8438
# Epoch 109, Batch 34/49, Batch Loss: 760626.9375
# Epoch 109, Batch 35/49, Batch Loss: 329124.3125
# Epoch 109, Batch 36/49, Batch Loss: 268247.1875
# Epoch 109, Batch 37/49, Batch Loss: 283815.0312
# ...
# Epoch 160, Batch 48/49, Batch Loss: 318955.4688
# Epoch 160, Batch 49/49, Batch Loss: 345645.2812
# Batch 1/17, Batch Loss: 340874.7188
# Batch 2/17, Batch Loss: 178778.7500
# Batch 3/17, Batch Loss: 271697.0312
# Batch 4/17, Batch Loss: 363551.4688
# Batch 5/17, Batch Loss: 206724.9219
# Batch 6/17, Batch Loss: 374849.1250
# Batch 7/17, Batch Loss: 310959.0938
# Batch 8/17, Batch Loss: 288922.8750
# Batch 9/17, Batch Loss: 505911.8438
# Batch 10/17, Batch Loss: 274961.3438
# Batch 11/17, Batch Loss: 254627.6250
# Batch 12/17, Batch Loss: 711680.4375
# Batch 13/17, Batch Loss: 360061.6562
# Batch 14/17, Batch Loss: 312507.2188
# Batch 15/17, Batch Loss: 297735.3750
# Batch 16/17, Batch Loss: 353880.2812
# Batch 17/17, Batch Loss: 517857.1562
# Test Error:
#  Avg loss: 348563.583640, Avg error: 260651.570934
#
# 2024-09-29 22:37:52.180788 Epoch 160, Average Training loss 377620.6282
# Epoch 161, Batch 1/49, Batch Loss: 285502.8750
# Epoch 161, Batch 2/49, Batch Loss: 495585.3125
# Epoch 161, Batch 3/49, Batch Loss: 351938.9062
# Epoch 161, Batch 4/49, Batch Loss: 460203.4062
# Epoch 161, Batch 5/49, Batch Loss: 306031.1875
# Epoch 161, Batch 6/49, Batch Loss: 756849.5000
# Epoch 161, Batch 7/49, Batch Loss: 321378.4062
# Epoch 161, Batch 8/49, Batch Loss: 336193.3125
# Epoch 161, Batch 9/49, Batch Loss: 274937.5000
# Epoch 161, Batch 10/49, Batch Loss: 293043.4688
# Epoch 161, Batch 11/49, Batch Loss: 837935.3750
# Epoch 161, Batch 12/49, Batch Loss: 263755.5000
# Epoch 161, Batch 13/49, Batch Loss: 268427.2188
# Epoch 161, Batch 14/49, Batch Loss: 777187.1875
# Epoch 161, Batch 15/49, Batch Loss: 866302.8750
# Epoch 161, Batch 16/49, Batch Loss: 283145.8125
# Epoch 161, Batch 17/49, Batch Loss: 222708.0625
# Epoch 161, Batch 18/49, Batch Loss: 504505.3750
# Epoch 161, Batch 19/49, Batch Loss: 510365.3750
# Epoch 161, Batch 20/49, Batch Loss: 270743.3438
# Epoch 161, Batch 21/49, Batch Loss: 362895.1562
# Epoch 161, Batch 22/49, Batch Loss: 238344.1562
# Epoch 161, Batch 23/49, Batch Loss: 319201.6562
# Epoch 161, Batch 24/49, Batch Loss: 387823.4375
# Epoch 161, Batch 25/49, Batch Loss: 224892.8281
# Epoch 161, Batch 26/49, Batch Loss: 232375.9062
# Epoch 161, Batch 27/49, Batch Loss: 347281.5000
# Epoch 161, Batch 28/49, Batch Loss: 315910.0312
# Epoch 161, Batch 29/49, Batch Loss: 219880.7031
# Epoch 161, Batch 30/49, Batch Loss: 230422.9844
# Epoch 161, Batch 31/49, Batch Loss: 347260.6250
# Epoch 161, Batch 32/49, Batch Loss: 365127.1875
# Epoch 161, Batch 33/49, Batch Loss: 338997.0625
# Epoch 161, Batch 34/49, Batch Loss: 467600.4375
# Epoch 161, Batch 35/49, Batch Loss: 790852.9375
# Epoch 161, Batch 36/49, Batch Loss: 322782.1250
# Epoch 161, Batch 37/49, Batch Loss: 359513.1250
# Epoch 161, Batch 38/49, Batch Loss: 332948.1250
# Epoch 161, Batch 39/49, Batch Loss: 295432.0625
# Epoch 161, Batch 40/49, Batch Loss: 320388.1875
# Epoch 161, Batch 41/49, Batch Loss: 305199.6875
# Epoch 161, Batch 42/49, Batch Loss: 240528.5156
# Epoch 161, Batch 43/49, Batch Loss: 316239.4062
# Epoch 161, Batch 44/49, Batch Loss: 456106.5312
# Epoch 161, Batch 45/49, Batch Loss: 222783.3906
# Epoch 161, Batch 46/49, Batch Loss: 355912.6562
# Epoch 161, Batch 47/49, Batch Loss: 359159.5312
# Epoch 161, Batch 48/49, Batch Loss: 235138.4062
# Epoch 161, Batch 49/49, Batch Loss: 249712.6406
# Batch 1/17, Batch Loss: 318019.3438
# Batch 2/17, Batch Loss: 173309.6719
# Batch 3/17, Batch Loss: 267461.3438
# Batch 4/17, Batch Loss: 361027.1250
# Batch 5/17, Batch Loss: 210285.9375
# Batch 6/17, Batch Loss: 387757.5000
# Batch 7/17, Batch Loss: 321212.3125
# Batch 8/17, Batch Loss: 285395.0625
# Batch 9/17, Batch Loss: 503397.1875
# Batch 10/17, Batch Loss: 264914.1875
# Batch 11/17, Batch Loss: 270783.3125
# Batch 12/17, Batch Loss: 714097.4375
# Batch 13/17, Batch Loss: 358165.1562
# Batch 14/17, Batch Loss: 302469.2500
# Batch 15/17, Batch Loss: 318320.6875
# Batch 16/17, Batch Loss: 371655.4375
# Batch 17/17, Batch Loss: 538160.2500
# Test Error:
#  Avg loss: 350966.541360, Avg error: 263075.487024
#
# Epoch 162, Batch 1/49, Batch Loss: 324448.1250
# Epoch 162, Batch 2/49, Batch Loss: 211692.9219
# Epoch 162, Batch 3/49, Batch Loss: 236215.4375
# Epoch 162, Batch 4/49, Batch Loss: 321984.9375
# Epoch 162, Batch 5/49, Batch Loss: 332171.3438
# Epoch 162, Batch 6/49, Batch Loss: 359407.6562
# Epoch 162, Batch 7/49, Batch Loss: 197610.1562
# Epoch 162, Batch 8/49, Batch Loss: 353796.6875
# Epoch 162, Batch 9/49, Batch Loss: 241503.9844
# Epoch 162, Batch 10/49, Batch Loss: 460736.5938
# Epoch 162, Batch 11/49, Batch Loss: 445466.5312
# Epoch 162, Batch 12/49, Batch Loss: 380737.8750
# Epoch 162, Batch 13/49, Batch Loss: 335685.2500
# Epoch 162, Batch 14/49, Batch Loss: 289579.7188
# Epoch 162, Batch 15/49, Batch Loss: 271481.8125
# Epoch 162, Batch 16/49, Batch Loss: 456735.0000
# Epoch 162, Batch 17/49, Batch Loss: 294404.8125
# Epoch 162, Batch 18/49, Batch Loss: 341183.0312
# Epoch 162, Batch 19/49, Batch Loss: 254075.2969
# Epoch 162, Batch 20/49, Batch Loss: 338269.1562
# Epoch 162, Batch 21/49, Batch Loss: 254690.1875
# Epoch 162, Batch 22/49, Batch Loss: 301207.7188
# Epoch 162, Batch 23/49, Batch Loss: 442627.2500
# Epoch 162, Batch 24/49, Batch Loss: 266776.9688
# Epoch 162, Batch 25/49, Batch Loss: 340416.3750
# Epoch 162, Batch 26/49, Batch Loss: 237491.2344
# Epoch 162, Batch 27/49, Batch Loss: 771874.7500
# Epoch 162, Batch 28/49, Batch Loss: 773080.1250
# Epoch 162, Batch 29/49, Batch Loss: 745126.0625
# Epoch 162, Batch 30/49, Batch Loss: 270936.4688
# Epoch 162, Batch 31/49, Batch Loss: 528380.1250
# Epoch 162, Batch 32/49, Batch Loss: 560873.1875
# Epoch 162, Batch 33/49, Batch Loss: 482860.0625
# Epoch 162, Batch 34/49, Batch Loss: 239716.6562
# Epoch 162, Batch 35/49, Batch Loss: 282740.0000
# Epoch 162, Batch 36/49, Batch Loss: 759898.9375
# Epoch 162, Batch 37/49, Batch Loss: 291921.9062
# Epoch 162, Batch 38/49, Batch Loss: 348907.0625
# Epoch 162, Batch 39/49, Batch Loss: 765149.6250
# Epoch 162, Batch 40/49, Batch Loss: 309909.6875
# Epoch 162, Batch 41/49, Batch Loss: 313815.5938
# Epoch 162, Batch 42/49, Batch Loss: 491271.0625
# Epoch 162, Batch 43/49, Batch Loss: 321848.1250
# Epoch 162, Batch 44/49, Batch Loss: 347800.3750
# Epoch 162, Batch 45/49, Batch Loss: 320735.9375
# Epoch 162, Batch 46/49, Batch Loss: 293299.4062
# Epoch 162, Batch 47/49, Batch Loss: 380783.8750
# Epoch 162, Batch 48/49, Batch Loss: 213728.8906
# Epoch 162, Batch 49/49, Batch Loss: 378470.7500
# Batch 1/17, Batch Loss: 330657.0000
# Batch 2/17, Batch Loss: 175185.1094
# Batch 3/17, Batch Loss: 268608.8750
# Batch 4/17, Batch Loss: 361364.6875
# Batch 5/17, Batch Loss: 207837.3594
# Batch 6/17, Batch Loss: 380242.5938
# Batch 7/17, Batch Loss: 315025.5625
# Batch 8/17, Batch Loss: 287468.0625
# Batch 9/17, Batch Loss: 505594.3750
# Batch 10/17, Batch Loss: 269706.7188
# Batch 11/17, Batch Loss: 261665.3594
# Batch 12/17, Batch Loss: 712195.3750
# Batch 13/17, Batch Loss: 358913.8750
# Batch 14/17, Batch Loss: 307546.3125
# Batch 15/17, Batch Loss: 307403.6562
# Batch 16/17, Batch Loss: 361902.1875
# Batch 17/17, Batch Loss: 525742.3750
# Test Error:
#  Avg loss: 349238.793199, Avg error: 261406.443772
#
# Epoch 163, Batch 1/49, Batch Loss: 203424.1719
# Epoch 163, Batch 2/49, Batch Loss: 207399.2031
# Epoch 163, Batch 3/49, Batch Loss: 281583.2812
# Epoch 163, Batch 4/49, Batch Loss: 355926.4062
# Epoch 163, Batch 5/49, Batch Loss: 246715.9531
# Epoch 163, Batch 6/49, Batch Loss: 296653.5000
# Epoch 163, Batch 7/49, Batch Loss: 352237.8125
# Epoch 163, Batch 8/49, Batch Loss: 325479.7188
# Epoch 163, Batch 9/49, Batch Loss: 492678.0938
# Epoch 163, Batch 10/49, Batch Loss: 230394.9844
# Epoch 163, Batch 11/49, Batch Loss: 320308.3438
# Epoch 163, Batch 12/49, Batch Loss: 317715.4688
# Epoch 163, Batch 13/49, Batch Loss: 237978.8594
# Epoch 163, Batch 14/49, Batch Loss: 281657.4062
# Epoch 163, Batch 15/49, Batch Loss: 380324.1250
# Epoch 163, Batch 16/49, Batch Loss: 295032.5000
# Epoch 163, Batch 17/49, Batch Loss: 337073.0625
# Epoch 163, Batch 18/49, Batch Loss: 349197.8125
# Epoch 163, Batch 19/49, Batch Loss: 340588.5938
# Epoch 163, Batch 20/49, Batch Loss: 304196.1562
# Epoch 163, Batch 21/49, Batch Loss: 266242.5000
# Epoch 163, Batch 22/49, Batch Loss: 391869.0000
# Epoch 163, Batch 23/49, Batch Loss: 253965.4062
# Epoch 163, Batch 24/49, Batch Loss: 853021.5000
# Epoch 163, Batch 25/49, Batch Loss: 297334.7812
# Epoch 163, Batch 26/49, Batch Loss: 319732.6562
# Epoch 163, Batch 27/49, Batch Loss: 371282.6875
# Epoch 163, Batch 28/49, Batch Loss: 288473.8750
# Epoch 163, Batch 29/49, Batch Loss: 779992.0000
# Epoch 163, Batch 30/49, Batch Loss: 292349.1562
# Epoch 163, Batch 31/49, Batch Loss: 501947.9062
# Epoch 163, Batch 32/49, Batch Loss: 337601.6250
# Epoch 163, Batch 33/49, Batch Loss: 263406.4062
# Epoch 163, Batch 34/49, Batch Loss: 357676.1562
# Epoch 163, Batch 35/49, Batch Loss: 795729.7500
# Epoch 163, Batch 36/49, Batch Loss: 311013.6875
# Epoch 163, Batch 37/49, Batch Loss: 409310.0625
# Epoch 163, Batch 38/49, Batch Loss: 231169.7500
# Epoch 163, Batch 39/49, Batch Loss: 546166.8750
# Epoch 163, Batch 40/49, Batch Loss: 240569.5625
# Epoch 163, Batch 41/49, Batch Loss: 323758.2812
# Epoch 163, Batch 42/49, Batch Loss: 374573.5625
# Epoch 163, Batch 43/49, Batch Loss: 836475.4375
# Epoch 163, Batch 44/49, Batch Loss: 272579.4688
# Epoch 163, Batch 45/49, Batch Loss: 391490.1875
# Epoch 163, Batch 46/49, Batch Loss: 392593.7188
# Epoch 163, Batch 47/49, Batch Loss: 750031.9375
# Epoch 163, Batch 48/49, Batch Loss: 329508.1875
# Epoch 163, Batch 49/49, Batch Loss: 393977.1875
# Batch 1/17, Batch Loss: 339194.9062
# Batch 2/17, Batch Loss: 177701.4375
# Batch 3/17, Batch Loss: 269297.2188
# Batch 4/17, Batch Loss: 362934.5625
# Batch 5/17, Batch Loss: 206062.5938
# Batch 6/17, Batch Loss: 376530.8750
# Batch 7/17, Batch Loss: 311977.2812
# Batch 8/17, Batch Loss: 289109.8125
# Batch 9/17, Batch Loss: 507253.0625
# Batch 10/17, Batch Loss: 273604.0938
# Batch 11/17, Batch Loss: 255563.0469
# Batch 12/17, Batch Loss: 712218.0000
# Batch 13/17, Batch Loss: 359756.5312
# Batch 14/17, Batch Loss: 311229.8125
# Batch 15/17, Batch Loss: 299970.6562
# Batch 16/17, Batch Loss: 355466.9062
# Batch 17/17, Batch Loss: 519764.0312
# Test Error:
#  Avg loss: 348684.401654, Avg error: 260698.858131
#
# Epoch 164, Batch 1/49, Batch Loss: 279453.7500
# Epoch 164, Batch 2/49, Batch Loss: 460501.3750
# Epoch 164, Batch 3/49, Batch Loss: 429989.5000
# Epoch 164, Batch 4/49, Batch Loss: 279779.0000
# Epoch 164, Batch 5/49, Batch Loss: 841121.0000
# Epoch 164, Batch 6/49, Batch Loss: 273487.0938
# Epoch 164, Batch 7/49, Batch Loss: 430552.0312
# Epoch 164, Batch 8/49, Batch Loss: 307320.0312
# Epoch 164, Batch 9/49, Batch Loss: 458974.5312
# Epoch 164, Batch 10/49, Batch Loss: 297366.2188
# Epoch 164, Batch 11/49, Batch Loss: 264482.8750
# Epoch 164, Batch 12/49, Batch Loss: 431435.6875
# Epoch 164, Batch 13/49, Batch Loss: 769896.5625
# Epoch 164, Batch 14/49, Batch Loss: 309564.2500
# Epoch 164, Batch 15/49, Batch Loss: 253927.8906
# Epoch 164, Batch 16/49, Batch Loss: 225189.9062
# Epoch 164, Batch 17/49, Batch Loss: 269849.8438
# Epoch 164, Batch 18/49, Batch Loss: 310765.0312
# Epoch 164, Batch 19/49, Batch Loss: 238510.6406
# Epoch 164, Batch 20/49, Batch Loss: 284451.2188
# Epoch 164, Batch 21/49, Batch Loss: 321565.1875
# Epoch 164, Batch 22/49, Batch Loss: 488594.9375
# Epoch 164, Batch 23/49, Batch Loss: 234283.6094
# Epoch 164, Batch 24/49, Batch Loss: 309259.1562
# Epoch 164, Batch 25/49, Batch Loss: 269412.4062
# Epoch 164, Batch 26/49, Batch Loss: 309857.3750
# Epoch 164, Batch 27/49, Batch Loss: 338130.0938
# Epoch 164, Batch 28/49, Batch Loss: 262191.9375
# Epoch 164, Batch 29/49, Batch Loss: 380778.0312
# Epoch 164, Batch 30/49, Batch Loss: 379705.5938
# Epoch 164, Batch 31/49, Batch Loss: 328327.0312
# Epoch 164, Batch 32/49, Batch Loss: 255806.0312
# Epoch 164, Batch 33/49, Batch Loss: 245668.4844
# Epoch 164, Batch 34/49, Batch Loss: 311889.4375
# Epoch 164, Batch 35/49, Batch Loss: 255330.8125
# Epoch 164, Batch 36/49, Batch Loss: 479690.1250
# Epoch 164, Batch 37/49, Batch Loss: 246234.1250
# Epoch 164, Batch 38/49, Batch Loss: 788487.3125
# Epoch 164, Batch 39/49, Batch Loss: 372430.3438
# Epoch 164, Batch 40/49, Batch Loss: 295126.4062
# Epoch 164, Batch 41/49, Batch Loss: 391897.3438
# Epoch 164, Batch 42/49, Batch Loss: 392904.9688
# Epoch 164, Batch 43/49, Batch Loss: 272412.0938
# Epoch 164, Batch 44/49, Batch Loss: 291661.3125
# Epoch 164, Batch 45/49, Batch Loss: 241065.4062
# Epoch 164, Batch 46/49, Batch Loss: 291871.1250
# Epoch 164, Batch 47/49, Batch Loss: 754338.0625
# Epoch 164, Batch 48/49, Batch Loss: 487170.9688
# Epoch 164, Batch 49/49, Batch Loss: 862738.5625
# Batch 1/17, Batch Loss: 326945.5625
# Batch 2/17, Batch Loss: 174326.7188
# Batch 3/17, Batch Loss: 268271.7188
# Batch 4/17, Batch Loss: 361257.2812
# Batch 5/17, Batch Loss: 208260.1406
# Batch 6/17, Batch Loss: 381108.9062
# Batch 7/17, Batch Loss: 316682.0938
# Batch 8/17, Batch Loss: 286525.2500
# Batch 9/17, Batch Loss: 505596.6250
# Batch 10/17, Batch Loss: 268645.0625
# Batch 11/17, Batch Loss: 263192.3750
# Batch 12/17, Batch Loss: 712476.5000
# Batch 13/17, Batch Loss: 357951.8125
# Batch 14/17, Batch Loss: 305802.0938
# Batch 15/17, Batch Loss: 309143.7500
# Batch 16/17, Batch Loss: 363095.5625
# Batch 17/17, Batch Loss: 528233.9375
# Test Error:
#  Avg loss: 349265.611213, Avg error: 261501.134083
#
# Epoch 165, Batch 1/49, Batch Loss: 368279.2500
# Epoch 165, Batch 2/49, Batch Loss: 490618.5938
# Epoch 165, Batch 3/49, Batch Loss: 360837.5312
# Epoch 165, Batch 4/49, Batch Loss: 199441.0625
# Epoch 165, Batch 5/49, Batch Loss: 422384.0625
# Epoch 165, Batch 6/49, Batch Loss: 239475.4062
# Epoch 165, Batch 7/49, Batch Loss: 486796.5625
# Epoch 165, Batch 8/49, Batch Loss: 219303.7812
# Epoch 165, Batch 9/49, Batch Loss: 261486.9375
# Epoch 165, Batch 10/49, Batch Loss: 377804.6875
# Epoch 165, Batch 11/49, Batch Loss: 335566.7188
# Epoch 165, Batch 12/49, Batch Loss: 770488.8750
# Epoch 165, Batch 13/49, Batch Loss: 256678.1406
# Epoch 165, Batch 14/49, Batch Loss: 317742.6562
# Epoch 165, Batch 15/49, Batch Loss: 363287.6562
# Epoch 165, Batch 16/49, Batch Loss: 353101.5000
# Epoch 165, Batch 17/49, Batch Loss: 241854.5781
# Epoch 165, Batch 18/49, Batch Loss: 321376.1250
# Epoch 165, Batch 19/49, Batch Loss: 504069.9375
# Epoch 165, Batch 20/49, Batch Loss: 378106.8125
# Epoch 165, Batch 21/49, Batch Loss: 753790.7500
# Epoch 165, Batch 22/49, Batch Loss: 452383.9375
# Epoch 165, Batch 23/49, Batch Loss: 758323.3750
# Epoch 165, Batch 24/49, Batch Loss: 770874.5000
# Epoch 165, Batch 25/49, Batch Loss: 278207.5938
# Epoch 165, Batch 26/49, Batch Loss: 297333.4062
# Epoch 165, Batch 27/49, Batch Loss: 272656.7188
# Epoch 165, Batch 28/49, Batch Loss: 265772.1562
# Epoch 165, Batch 29/49, Batch Loss: 257020.4531
# Epoch 165, Batch 30/49, Batch Loss: 363423.7500
# Epoch 165, Batch 31/49, Batch Loss: 464255.0938
# Epoch 165, Batch 32/49, Batch Loss: 258124.1719
# Epoch 165, Batch 33/49, Batch Loss: 263492.7500
# Epoch 165, Batch 34/49, Batch Loss: 340474.2188
# Epoch 165, Batch 35/49, Batch Loss: 345954.4688
# Epoch 165, Batch 36/49, Batch Loss: 794553.5000
# Epoch 165, Batch 37/49, Batch Loss: 345893.5000
# Epoch 165, Batch 38/49, Batch Loss: 394670.0000
# Epoch 165, Batch 39/49, Batch Loss: 397055.1562
# Epoch 165, Batch 40/49, Batch Loss: 314800.9062
# Epoch 165, Batch 41/49, Batch Loss: 276600.0312
# Epoch 165, Batch 42/49, Batch Loss: 389711.0312
# Epoch 165, Batch 43/49, Batch Loss: 254049.8750
# Epoch 165, Batch 44/49, Batch Loss: 363809.8438
# Epoch 165, Batch 45/49, Batch Loss: 271600.7500
# Epoch 165, Batch 46/49, Batch Loss: 392383.6250
# Epoch 165, Batch 47/49, Batch Loss: 274639.7812
# Epoch 165, Batch 48/49, Batch Loss: 275790.1562
# Epoch 165, Batch 49/49, Batch Loss: 348373.6875
# Batch 1/17, Batch Loss: 322068.6875
# Batch 2/17, Batch Loss: 173450.4062
# Batch 3/17, Batch Loss: 266624.0625
# Batch 4/17, Batch Loss: 361790.5938
# Batch 5/17, Batch Loss: 208709.6562
# Batch 6/17, Batch Loss: 384873.1562
# Batch 7/17, Batch Loss: 319450.6875
# Batch 8/17, Batch Loss: 285883.4062
# Batch 9/17, Batch Loss: 504092.8438
# Batch 10/17, Batch Loss: 266752.1250
# Batch 11/17, Batch Loss: 265801.6250
# Batch 12/17, Batch Loss: 713040.2500
# Batch 13/17, Batch Loss: 357829.2500
# Batch 14/17, Batch Loss: 304732.5938
# Batch 15/17, Batch Loss: 313426.4062
# Batch 16/17, Batch Loss: 366656.1562
# Batch 17/17, Batch Loss: 530848.1875
# Test Error:
#  Avg loss: 349766.476103, Avg error: 262117.721453

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        2.5         3  1915    92021      117.png   485000
# 1        2.5         3  2248    92677      132.png  1199000
# 2        1.0         3  1132    96019      154.png   170000
# 3        4.0         6  3375    92880      245.png   538000
# 4        2.5         3  2733    91901       84.png   689000

# %%
len(test)
# Out:
# 54

# %%
# Crear dataset
test_data = CustomImageDataset(df=test)

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
len(test_loader)
# Out:
# 6

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 638556.4375, Valor real: 485000.0
# Predicción: 358768.09375, Valor real: 1199000.0
# Predicción: -47545.3359375, Valor real: 170000.0
# Predicción: 564006.5625, Valor real: 538000.0
# Predicción: 668555.25, Valor real: 689000.0
# Predicción: -201345.78125, Valor real: 118900.0
# Predicción: 603366.0, Valor real: 799000.0
# Predicción: 1156074.625, Valor real: 895000.0
# Predicción: 419995.46875, Valor real: 599000.0
# Predicción: 696976.125, Valor real: 535000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 318209.5625
# MAE en el conjunto de prueba: 233055.0312

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
