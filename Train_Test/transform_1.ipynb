# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %%
# --> Definir si viene desde local o drive

ruta = '/content/drive/MyDrive/Dataset/Mosaico/'
# ruta = '../Dataset/Mosaico/'

# %% [markdown]
# ## Lectura de dataset train

# %%
train = pd.read_csv(f'{ruta}train.csv')
train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %% [markdown]
# ## Clases y funciones auxiliares

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        mosaic_image = read_image(f"{ruta}Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1) # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)   # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None, apply_desnormalize=False):
    # Deshacer la normalización
    if apply_desnormalize:
        image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))       # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')                         # Quitar los ejes
    plt.show()

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=5, stride=1, padding=2),   # 400x400
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 200x200
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 100x100
            nn.Dropout(),

            nn.Conv2d(128, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 50x50

            nn.Conv2d(128, 64, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                  # 25x25
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(37440, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 64*24*24)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
def test_loop(dataloader, model, loss_fn, device):
    """
    Función para realizar un bucle de prueba en el conjunto de datos de prueba.
    """
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader, device):
    """
    Función para realizar el bucle de entrenamiento.
    """
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            l2_lambda = 0.001
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn, device=device)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Ejecución de entrenamiento

# %%
# --> Aumentar el tamaño de las muestras de entrenamiento y validación.

# Dataset sin transformaciones
data1 = CustomImageDataset(df=train)

# Dataset con transformación de normalización
data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desplazamiento de canales y normalización
data3 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Lambda(lambda img: img[[2, 1, 0], :, :]),    # Cambiar los canales RGB a BGR
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                        # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                         # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo horizontal y normalización
data4 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),            # Girar horizontalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con transformación de volteo vertical y normalización
data5 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.RandomVerticalFlip(p=0.5),              # Girar verticalmente con una probabilidad del 50%
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# Dataset con desenfoque gaussiano y normalización
data6 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# %%
# --> Ver las imágenes de entrenamiento con diferentes transformaciones.

lista_titulos = [
    'Imagen Original', 'Normalización', 'Ajuste de Brillo',
    'Volteo Horizontal', 'Volteo Vertical', 'Desenfoque Gaussiano'
    ]

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2, data3, data4, data5, data6]

# Iterar
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    if i == 1:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}")
    else:
        show_image(image, title=f"{i} - {lista_titulos[i-1]}", apply_desnormalize=True)

# %%
# --> Combinar los conjuntos de datos en un solo conjunto de datos
conjunto_datos = ConcatDataset((data1, data2, data3, data4, data5, data6))

valor_train = int(0.9 * len(conjunto_datos))
valor_val = len(conjunto_datos) - valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 2597 Val: 289

# %%
# --> Dividir el conjunto de datos en conjuntos de entrenamiento y validación
train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2, data3, data4, data5, data6)), [valor_train, valor_val])

# --> Eliminar las variables que ya no se necesitan
del data1, data2, data3, data4, data5, data6

# %%
# --> Crear los dataloaders
batch_size_train = 53
batch_size_val = 17
# batch_size=64

train_dataloader = DataLoader(train_data, batch_size=batch_size_train, shuffle=True, drop_last=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size_val, shuffle=False)

print(f"Muestras de train: {len(train_data)} - Baches {len(train_dataloader)}")
print(f"Muestras de test: {len(val_data)} - Baches {len(val_dataloader)}")
# Out:
# Muestras de train: 2597 - Baches 49
# Muestras de test: 289 - Baches 17

# %%
# --> Definir dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo: {device}")

# --> Definir modelo
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)

# --> Definir optimizador y la función de pérdida
optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Dispositivo: cuda

# %%
# Entrenamiento
n_epochs = 165
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    device=device
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 93, Batch 45/49, Batch Loss: 93607.8047
# Epoch 93, Batch 46/49, Batch Loss: 96929.8516
# Epoch 93, Batch 47/49, Batch Loss: 72422.7656
# Epoch 93, Batch 48/49, Batch Loss: 82656.6953
# Epoch 93, Batch 49/49, Batch Loss: 66725.5000
# Batch 1/17, Batch Loss: 182915.7656
# Batch 2/17, Batch Loss: 95331.7344
# Batch 3/17, Batch Loss: 170344.5781
# Batch 4/17, Batch Loss: 126033.5703
# Batch 5/17, Batch Loss: 1376023.6250
# Batch 6/17, Batch Loss: 95927.9375
# Batch 7/17, Batch Loss: 166744.5469
# Batch 8/17, Batch Loss: 79454.9219
# Batch 9/17, Batch Loss: 128275.5156
# Batch 10/17, Batch Loss: 77169.3047
# Batch 11/17, Batch Loss: 135744.0781
# Batch 12/17, Batch Loss: 327602.7812
# Batch 13/17, Batch Loss: 113114.3672
# Batch 14/17, Batch Loss: 211733.5000
# Batch 15/17, Batch Loss: 187022.0781
# Batch 16/17, Batch Loss: 107046.1641
# Batch 17/17, Batch Loss: 149075.3594
# Test Error:
#  Avg loss: 219385.872243, Avg error: 110355.779844
#
# Epoch 94, Batch 1/49, Batch Loss: 165926.5938
# Epoch 94, Batch 2/49, Batch Loss: 83334.1875
# Epoch 94, Batch 3/49, Batch Loss: 105947.6406
# Epoch 94, Batch 4/49, Batch Loss: 85645.1016
# Epoch 94, Batch 5/49, Batch Loss: 58025.7070
# Epoch 94, Batch 6/49, Batch Loss: 69559.1641
# Epoch 94, Batch 7/49, Batch Loss: 74981.3750
# Epoch 94, Batch 8/49, Batch Loss: 74057.9688
# Epoch 94, Batch 9/49, Batch Loss: 81376.3047
# Epoch 94, Batch 10/49, Batch Loss: 66254.8203
# Epoch 94, Batch 11/49, Batch Loss: 87266.8594
# Epoch 94, Batch 12/49, Batch Loss: 83567.8438
# Epoch 94, Batch 13/49, Batch Loss: 76511.9688
# Epoch 94, Batch 14/49, Batch Loss: 71021.8516
# Epoch 94, Batch 15/49, Batch Loss: 104547.8594
# Epoch 94, Batch 16/49, Batch Loss: 76595.7188
# Epoch 94, Batch 17/49, Batch Loss: 58743.7812
# Epoch 94, Batch 18/49, Batch Loss: 91782.9453
# Epoch 94, Batch 19/49, Batch Loss: 59724.0273
# Epoch 94, Batch 20/49, Batch Loss: 64479.0703
# Epoch 94, Batch 21/49, Batch Loss: 59875.1328
# Epoch 94, Batch 22/49, Batch Loss: 83208.1875
# Epoch 94, Batch 23/49, Batch Loss: 78658.3984
# Epoch 94, Batch 24/49, Batch Loss: 55364.9922
# Epoch 94, Batch 25/49, Batch Loss: 113146.7812
# Epoch 94, Batch 26/49, Batch Loss: 65200.8320
# Epoch 94, Batch 27/49, Batch Loss: 61293.5742
# Epoch 94, Batch 28/49, Batch Loss: 72761.0391
# Epoch 94, Batch 29/49, Batch Loss: 72286.6016
# Epoch 94, Batch 30/49, Batch Loss: 72134.9609
# Epoch 94, Batch 31/49, Batch Loss: 76497.6953
# Epoch 94, Batch 32/49, Batch Loss: 56456.8828
# Epoch 94, Batch 33/49, Batch Loss: 108209.8594
# Epoch 94, Batch 34/49, Batch Loss: 93685.4375
# Epoch 94, Batch 35/49, Batch Loss: 72722.1797
# Epoch 94, Batch 36/49, Batch Loss: 67628.1797
# Epoch 94, Batch 37/49, Batch Loss: 47366.3281
# Epoch 94, Batch 38/49, Batch Loss: 38417.9414
# Epoch 94, Batch 39/49, Batch Loss: 51423.4531
# Epoch 94, Batch 40/49, Batch Loss: 145738.2656
# Epoch 94, Batch 41/49, Batch Loss: 94733.0234
# Epoch 94, Batch 42/49, Batch Loss: 71897.2891
# Epoch 94, Batch 43/49, Batch Loss: 77590.2969
# Epoch 94, Batch 44/49, Batch Loss: 77901.2734
# Epoch 94, Batch 45/49, Batch Loss: 96482.8594
# Epoch 94, Batch 46/49, Batch Loss: 65488.9180
# Epoch 94, Batch 47/49, Batch Loss: 61554.2891
# Epoch 94, Batch 48/49, Batch Loss: 70464.9297
# Epoch 94, Batch 49/49, Batch Loss: 62936.1562
# Batch 1/17, Batch Loss: 173195.3906
# Batch 2/17, Batch Loss: 209234.4531
# Batch 3/17, Batch Loss: 187457.7188
# Batch 4/17, Batch Loss: 179238.8281
# Batch 5/17, Batch Loss: 1358776.5000
# Batch 6/17, Batch Loss: 84948.9609
# Batch 7/17, Batch Loss: 59750.5508
# Batch 8/17, Batch Loss: 171701.8125
# Batch 9/17, Batch Loss: 166309.2656
# Batch 10/17, Batch Loss: 74651.5625
# Batch 11/17, Batch Loss: 120648.8594
# Batch 12/17, Batch Loss: 249372.2656
# Batch 13/17, Batch Loss: 47412.6172
# Batch 14/17, Batch Loss: 135189.1875
# Batch 15/17, Batch Loss: 113281.6250
# Batch 16/17, Batch Loss: 202959.7656
# Batch 17/17, Batch Loss: 147673.4375
# Test Error:
#  Avg loss: 216576.635340, Avg error: 104807.575692
#
# Epoch 95, Batch 1/49, Batch Loss: 83376.6016
# Epoch 95, Batch 2/49, Batch Loss: 129252.7422
# Epoch 95, Batch 3/49, Batch Loss: 80248.0234
# Epoch 95, Batch 4/49, Batch Loss: 68807.4922
# Epoch 95, Batch 5/49, Batch Loss: 54036.7070
# Epoch 95, Batch 6/49, Batch Loss: 59873.4141
# Epoch 95, Batch 7/49, Batch Loss: 105717.3047
# Epoch 95, Batch 8/49, Batch Loss: 75074.9375
# Epoch 95, Batch 9/49, Batch Loss: 90266.5312
# Epoch 95, Batch 10/49, Batch Loss: 67759.9219
# Epoch 95, Batch 11/49, Batch Loss: 74425.3750
# Epoch 95, Batch 12/49, Batch Loss: 74456.5156
# Epoch 95, Batch 13/49, Batch Loss: 118448.9297
# Epoch 95, Batch 14/49, Batch Loss: 64748.5352
# Epoch 95, Batch 15/49, Batch Loss: 65082.2305
# Epoch 95, Batch 16/49, Batch Loss: 88827.4922
# Epoch 95, Batch 17/49, Batch Loss: 61529.3359
# Epoch 95, Batch 18/49, Batch Loss: 58913.2812
# Epoch 95, Batch 19/49, Batch Loss: 75509.7344
# Epoch 95, Batch 20/49, Batch Loss: 59156.4336
# Epoch 95, Batch 21/49, Batch Loss: 58105.1484
# Epoch 95, Batch 22/49, Batch Loss: 71173.3828
# Epoch 95, Batch 23/49, Batch Loss: 64090.7656
# Epoch 95, Batch 24/49, Batch Loss: 100346.3438
# Epoch 95, Batch 25/49, Batch Loss: 64250.5039
# Epoch 95, Batch 26/49, Batch Loss: 73989.8594
# Epoch 95, Batch 27/49, Batch Loss: 64348.6289
# Epoch 95, Batch 28/49, Batch Loss: 122236.3203
# Epoch 95, Batch 29/49, Batch Loss: 74327.6250
# Epoch 95, Batch 30/49, Batch Loss: 50232.9141
# Epoch 95, Batch 31/49, Batch Loss: 53856.6211
# Epoch 95, Batch 32/49, Batch Loss: 59568.1133
# Epoch 95, Batch 33/49, Batch Loss: 86343.9062
# Epoch 95, Batch 34/49, Batch Loss: 99049.9453
# Epoch 95, Batch 35/49, Batch Loss: 56643.6758
# Epoch 95, Batch 36/49, Batch Loss: 91106.6016
# Epoch 95, Batch 37/49, Batch Loss: 61577.6367
# Epoch 95, Batch 38/49, Batch Loss: 78146.7734
# Epoch 95, Batch 39/49, Batch Loss: 131354.6875
# Epoch 95, Batch 40/49, Batch Loss: 74913.7812
# Epoch 95, Batch 41/49, Batch Loss: 55964.3750
# Epoch 95, Batch 42/49, Batch Loss: 88153.0547
# Epoch 95, Batch 43/49, Batch Loss: 82535.8594
# Epoch 95, Batch 44/49, Batch Loss: 89419.1016
# Epoch 95, Batch 45/49, Batch Loss: 212368.4375
# Epoch 95, Batch 46/49, Batch Loss: 72362.6875
# Epoch 95, Batch 47/49, Batch Loss: 79072.1250
# Epoch 95, Batch 48/49, Batch Loss: 80207.2812
# Epoch 95, Batch 49/49, Batch Loss: 111013.9922
# Batch 1/17, Batch Loss: 204223.8594
# Batch 2/17, Batch Loss: 161425.5625
# Batch 3/17, Batch Loss: 214787.5312
# Batch 4/17, Batch Loss: 195469.2969
# Batch 5/17, Batch Loss: 1367160.1250
# Batch 6/17, Batch Loss: 254372.4375
# Batch 7/17, Batch Loss: 196597.3594
# Batch 8/17, Batch Loss: 142745.8594
# Batch 9/17, Batch Loss: 155696.2500
# Batch 10/17, Batch Loss: 85994.4375
# Batch 11/17, Batch Loss: 153397.3281
# Batch 12/17, Batch Loss: 301331.9062
# Batch 13/17, Batch Loss: 79628.2656
# Batch 14/17, Batch Loss: 183685.0781
# Batch 15/17, Batch Loss: 146923.2344
# Batch 16/17, Batch Loss: 133388.1250
# Batch 17/17, Batch Loss: 149325.3594
# Test Error:
#  Avg loss: 242714.824449, Avg error: 144278.009516
#
# Epoch 96, Batch 1/49, Batch Loss: 89039.2188
# Epoch 96, Batch 2/49, Batch Loss: 119933.8594
# Epoch 96, Batch 3/49, Batch Loss: 74565.6562
# Epoch 96, Batch 4/49, Batch Loss: 104518.2500
# Epoch 96, Batch 5/49, Batch Loss: 56086.3164
# Epoch 96, Batch 6/49, Batch Loss: 51060.8750
# Epoch 96, Batch 7/49, Batch Loss: 84782.4453
# Epoch 96, Batch 8/49, Batch Loss: 77982.3750
# Epoch 96, Batch 9/49, Batch Loss: 65725.7344
# Epoch 96, Batch 10/49, Batch Loss: 77740.5625
# Epoch 96, Batch 11/49, Batch Loss: 99792.3594
# Epoch 96, Batch 12/49, Batch Loss: 70261.0000
# Epoch 96, Batch 13/49, Batch Loss: 59686.7344
# Epoch 96, Batch 14/49, Batch Loss: 86825.9766
# Epoch 96, Batch 15/49, Batch Loss: 72725.6875
# Epoch 96, Batch 16/49, Batch Loss: 88958.4531
# Epoch 96, Batch 17/49, Batch Loss: 81146.7422
# Epoch 96, Batch 18/49, Batch Loss: 71864.1250
# Epoch 96, Batch 19/49, Batch Loss: 92323.4609
# Epoch 96, Batch 20/49, Batch Loss: 75068.7734
# Epoch 96, Batch 21/49, Batch Loss: 68263.4219
# Epoch 96, Batch 22/49, Batch Loss: 77525.6719
# Epoch 96, Batch 23/49, Batch Loss: 59831.9258
# Epoch 96, Batch 24/49, Batch Loss: 172420.5625
# Epoch 96, Batch 25/49, Batch Loss: 60831.1406
# Epoch 96, Batch 26/49, Batch Loss: 65259.7930
# Epoch 96, Batch 27/49, Batch Loss: 58146.5469
# Epoch 96, Batch 28/49, Batch Loss: 71423.9531
# Epoch 96, Batch 29/49, Batch Loss: 77205.8203
# Epoch 96, Batch 30/49, Batch Loss: 59120.9688
# Epoch 96, Batch 31/49, Batch Loss: 64614.9336
# Epoch 96, Batch 32/49, Batch Loss: 49738.4180
# Epoch 96, Batch 33/49, Batch Loss: 73997.4219
# Epoch 96, Batch 34/49, Batch Loss: 44272.8984
# Epoch 96, Batch 35/49, Batch Loss: 49740.2852
# Epoch 96, Batch 36/49, Batch Loss: 53710.5547
# Epoch 96, Batch 37/49, Batch Loss: 83611.2500
# Epoch 96, Batch 38/49, Batch Loss: 64631.9492
# Epoch 96, Batch 39/49, Batch Loss: 68330.6875
# Epoch 96, Batch 40/49, Batch Loss: 106334.6406
# Epoch 96, Batch 41/49, Batch Loss: 63181.5352
# Epoch 96, Batch 42/49, Batch Loss: 99141.8750
# Epoch 96, Batch 43/49, Batch Loss: 87679.6875
# Epoch 96, Batch 44/49, Batch Loss: 85993.6250
# Epoch 96, Batch 45/49, Batch Loss: 84892.4766
# Epoch 96, Batch 46/49, Batch Loss: 125435.4375
# Epoch 96, Batch 47/49, Batch Loss: 68901.9531
# Epoch 96, Batch 48/49, Batch Loss: 149074.0625
# Epoch 96, Batch 49/49, Batch Loss: 62197.7578
# Batch 1/17, Batch Loss: 219844.5312
# Batch 2/17, Batch Loss: 201188.5312
# Batch 3/17, Batch Loss: 206436.3281
# Batch 4/17, Batch Loss: 146677.9219
# Batch 5/17, Batch Loss: 206442.9062
# Batch 6/17, Batch Loss: 248005.8594
# Batch 7/17, Batch Loss: 194987.9219
# Batch 8/17, Batch Loss: 161499.1250
# Batch 9/17, Batch Loss: 177976.4375
# Batch 10/17, Batch Loss: 81831.4141
# Batch 11/17, Batch Loss: 168508.3125
# Batch 12/17, Batch Loss: 316895.3750
# Batch 13/17, Batch Loss: 109904.7422
# Batch 14/17, Batch Loss: 164365.0312
# Batch 15/17, Batch Loss: 159557.7812
# Batch 16/17, Batch Loss: 195370.3594
# Batch 17/17, Batch Loss: 177252.1094
# Test Error:
#  Avg loss: 184514.393382, Avg error: 123384.792820
#
# Epoch 97, Batch 1/49, Batch Loss: 84452.3359
# Epoch 97, Batch 2/49, Batch Loss: 92542.5938
# Epoch 97, Batch 3/49, Batch Loss: 63091.9180
# Epoch 97, Batch 4/49, Batch Loss: 52755.9727
# Epoch 97, Batch 5/49, Batch Loss: 76369.1094
# Epoch 97, Batch 6/49, Batch Loss: 77093.0156
# Epoch 97, Batch 7/49, Batch Loss: 69954.7734
# Epoch 97, Batch 8/49, Batch Loss: 62135.9727
# Epoch 97, Batch 9/49, Batch Loss: 60679.8203
# Epoch 97, Batch 10/49, Batch Loss: 61690.0156
# Epoch 97, Batch 11/49, Batch Loss: 55975.2109
# Epoch 97, Batch 12/49, Batch Loss: 72777.8203
# Epoch 97, Batch 13/49, Batch Loss: 82659.6328
# Epoch 97, Batch 14/49, Batch Loss: 76443.0703
# Epoch 97, Batch 15/49, Batch Loss: 114089.1953
# Epoch 97, Batch 16/49, Batch Loss: 70103.5781
# Epoch 97, Batch 17/49, Batch Loss: 82385.6172
# Epoch 97, Batch 18/49, Batch Loss: 91026.5156
# Epoch 97, Batch 19/49, Batch Loss: 75376.6562
# Epoch 97, Batch 20/49, Batch Loss: 109180.1094
# Epoch 97, Batch 21/49, Batch Loss: 89759.0078
# Epoch 97, Batch 22/49, Batch Loss: 76509.6328
# Epoch 97, Batch 23/49, Batch Loss: 74730.2344
# Epoch 97, Batch 24/49, Batch Loss: 61854.1055
# Epoch 97, Batch 25/49, Batch Loss: 64809.2461
# Epoch 97, Batch 26/49, Batch Loss: 59952.1406
# Epoch 97, Batch 27/49, Batch Loss: 86668.8906
# Epoch 97, Batch 28/49, Batch Loss: 89811.5703
# Epoch 97, Batch 29/49, Batch Loss: 96902.8516
# Epoch 97, Batch 30/49, Batch Loss: 68046.6641
# Epoch 97, Batch 31/49, Batch Loss: 81111.9922
# Epoch 97, Batch 32/49, Batch Loss: 99832.5312
# Epoch 97, Batch 33/49, Batch Loss: 79980.9062
# Epoch 97, Batch 34/49, Batch Loss: 81771.8516
# Epoch 97, Batch 35/49, Batch Loss: 58126.1992
# Epoch 97, Batch 36/49, Batch Loss: 71929.0000
# Epoch 97, Batch 37/49, Batch Loss: 67407.7109
# Epoch 97, Batch 38/49, Batch Loss: 78620.6172
# Epoch 97, Batch 39/49, Batch Loss: 60867.6484
# Epoch 97, Batch 40/49, Batch Loss: 61865.2969
# Epoch 97, Batch 41/49, Batch Loss: 76465.0547
# Epoch 97, Batch 42/49, Batch Loss: 50397.2422
# Epoch 97, Batch 43/49, Batch Loss: 53041.0312
# Epoch 97, Batch 44/49, Batch Loss: 77100.5469
# Epoch 97, Batch 45/49, Batch Loss: 98585.9844
# Epoch 97, Batch 46/49, Batch Loss: 91841.8359
# Epoch 97, Batch 47/49, Batch Loss: 54810.0977
# Epoch 97, Batch 48/49, Batch Loss: 53898.5352
# Epoch 97, Batch 49/49, Batch Loss: 81388.6562
# Batch 1/17, Batch Loss: 230370.2500
# Batch 2/17, Batch Loss: 233503.0469
# Batch 3/17, Batch Loss: 227915.8906
# Batch 4/17, Batch Loss: 187540.0781
# Batch 5/17, Batch Loss: 320915.2188
# Batch 6/17, Batch Loss: 277380.8438
# Batch 7/17, Batch Loss: 104526.7266
# Batch 8/17, Batch Loss: 112594.0234
# Batch 9/17, Batch Loss: 171052.7500
# Batch 10/17, Batch Loss: 82865.1172
# Batch 11/17, Batch Loss: 146534.7188
# Batch 12/17, Batch Loss: 253449.7656
# Batch 13/17, Batch Loss: 77707.1094
# Batch 14/17, Batch Loss: 208363.4844
# Batch 15/17, Batch Loss: 184842.3594
# Batch 16/17, Batch Loss: 144808.1562
# Batch 17/17, Batch Loss: 191747.9688
# Test Error:
#  Avg loss: 185653.971048, Avg error: 123228.147924
#
# Epoch 98, Batch 1/49, Batch Loss: 81708.4062
# Epoch 98, Batch 2/49, Batch Loss: 98033.6953
# Epoch 98, Batch 3/49, Batch Loss: 90506.3828
# Epoch 98, Batch 4/49, Batch Loss: 65646.1875
# Epoch 98, Batch 5/49, Batch Loss: 63996.7305
# Epoch 98, Batch 6/49, Batch Loss: 78885.7891
# Epoch 98, Batch 7/49, Batch Loss: 99804.7266
# Epoch 98, Batch 8/49, Batch Loss: 80335.9297
# Epoch 98, Batch 9/49, Batch Loss: 97065.6250
# Epoch 98, Batch 10/49, Batch Loss: 72709.7812
# Epoch 98, Batch 11/49, Batch Loss: 57067.6914
# Epoch 98, Batch 12/49, Batch Loss: 107092.5156
# Epoch 98, Batch 13/49, Batch Loss: 250295.0625
# Epoch 98, Batch 14/49, Batch Loss: 102180.3594
# Epoch 98, Batch 15/49, Batch Loss: 69472.3047
# Epoch 98, Batch 16/49, Batch Loss: 61386.3125
# Epoch 98, Batch 17/49, Batch Loss: 112229.3594
# Epoch 98, Batch 18/49, Batch Loss: 93393.3125
# Epoch 98, Batch 19/49, Batch Loss: 61931.0352
# Epoch 98, Batch 20/49, Batch Loss: 91637.9219
# Epoch 98, Batch 21/49, Batch Loss: 83853.6484
# Epoch 98, Batch 22/49, Batch Loss: 62428.2422
# Epoch 98, Batch 23/49, Batch Loss: 96283.0000
# Epoch 98, Batch 24/49, Batch Loss: 133864.6719
# Epoch 98, Batch 25/49, Batch Loss: 104238.9375
# Epoch 98, Batch 26/49, Batch Loss: 113262.9531
# Epoch 98, Batch 27/49, Batch Loss: 121903.6797
# Epoch 98, Batch 28/49, Batch Loss: 70740.5312
# Epoch 98, Batch 29/49, Batch Loss: 75713.4453
# Epoch 98, Batch 30/49, Batch Loss: 109537.0703
# Epoch 98, Batch 31/49, Batch Loss: 142472.2812
# Epoch 98, Batch 32/49, Batch Loss: 87126.8281
# Epoch 98, Batch 33/49, Batch Loss: 70019.4219
# Epoch 98, Batch 34/49, Batch Loss: 155282.2344
# Epoch 98, Batch 35/49, Batch Loss: 57118.2070
# Epoch 98, Batch 36/49, Batch Loss: 142975.7812
# Epoch 98, Batch 37/49, Batch Loss: 74157.9453
# Epoch 98, Batch 38/49, Batch Loss: 62464.6094
# Epoch 98, Batch 39/49, Batch Loss: 81738.5703
# Epoch 98, Batch 40/49, Batch Loss: 80352.6328
# Epoch 98, Batch 41/49, Batch Loss: 74762.8828
# Epoch 98, Batch 42/49, Batch Loss: 69750.5781
# Epoch 98, Batch 43/49, Batch Loss: 65457.3008
# Epoch 98, Batch 44/49, Batch Loss: 82091.8984
# Epoch 98, Batch 45/49, Batch Loss: 100229.1641
# Epoch 98, Batch 46/49, Batch Loss: 67142.0547
# Epoch 98, Batch 47/49, Batch Loss: 93094.6562
# Epoch 98, Batch 48/49, Batch Loss: 81997.9219
# Epoch 98, Batch 49/49, Batch Loss: 56628.2344
# Batch 1/17, Batch Loss: 190490.7188
# Batch 2/17, Batch Loss: 110770.2578
# Batch 3/17, Batch Loss: 147400.3750
# Batch 4/17, Batch Loss: 126006.4922
# Batch 5/17, Batch Loss: 1354780.1250
# Batch 6/17, Batch Loss: 79335.5859
# Batch 7/17, Batch Loss: 69139.3984
# Batch 8/17, Batch Loss: 163330.9844
# Batch 9/17, Batch Loss: 118830.1953
# Batch 10/17, Batch Loss: 69766.4844
# Batch 11/17, Batch Loss: 122112.5391
# Batch 12/17, Batch Loss: 329325.4375
# Batch 13/17, Batch Loss: 110198.5859
# Batch 14/17, Batch Loss: 169976.1562
# Batch 15/17, Batch Loss: 163408.4375
# Batch 16/17, Batch Loss: 194322.6094
# Batch 17/17, Batch Loss: 141018.3594
# Test Error:
#  Avg loss: 215306.631893, Avg error: 102482.634083
#
# Epoch 99, Batch 1/49, Batch Loss: 115432.5625
# Epoch 99, Batch 2/49, Batch Loss: 105182.8594
# Epoch 99, Batch 3/49, Batch Loss: 63329.9258
# Epoch 99, Batch 4/49, Batch Loss: 107680.2031
# Epoch 99, Batch 5/49, Batch Loss: 84814.5234
# Epoch 99, Batch 6/49, Batch Loss: 104713.4766
# Epoch 99, Batch 7/49, Batch Loss: 90669.5391
# Epoch 99, Batch 8/49, Batch Loss: 92010.0859
# Epoch 99, Batch 9/49, Batch Loss: 68079.1172
# Epoch 99, Batch 10/49, Batch Loss: 109249.3906
# Epoch 99, Batch 11/49, Batch Loss: 106599.0391
# Epoch 99, Batch 12/49, Batch Loss: 81931.2578
# Epoch 99, Batch 13/49, Batch Loss: 68512.8750
# Epoch 99, Batch 14/49, Batch Loss: 81713.5859
# Epoch 99, Batch 15/49, Batch Loss: 72308.4062
# Epoch 99, Batch 16/49, Batch Loss: 77275.9531
# Epoch 99, Batch 17/49, Batch Loss: 97202.2031
# Epoch 99, Batch 18/49, Batch Loss: 78315.3828
# Epoch 99, Batch 19/49, Batch Loss: 79019.0000
# Epoch 99, Batch 20/49, Batch Loss: 73750.0391
# Epoch 99, Batch 21/49, Batch Loss: 117186.8516
# Epoch 99, Batch 22/49, Batch Loss: 58058.0586
# Epoch 99, Batch 23/49, Batch Loss: 136937.7500
# Epoch 99, Batch 24/49, Batch Loss: 79862.8047
# Epoch 99, Batch 25/49, Batch Loss: 58673.7031
# Epoch 99, Batch 26/49, Batch Loss: 68749.7344
# Epoch 99, Batch 27/49, Batch Loss: 73262.0078
# Epoch 99, Batch 28/49, Batch Loss: 65754.9297
# Epoch 99, Batch 29/49, Batch Loss: 60746.6250
# Epoch 99, Batch 30/49, Batch Loss: 84717.7031
# Epoch 99, Batch 31/49, Batch Loss: 126261.2266
# Epoch 99, Batch 32/49, Batch Loss: 81770.6797
# Epoch 99, Batch 33/49, Batch Loss: 53547.8086
# Epoch 99, Batch 34/49, Batch Loss: 66610.6250
# Epoch 99, Batch 35/49, Batch Loss: 79143.8438
# Epoch 99, Batch 36/49, Batch Loss: 90627.7656
# Epoch 99, Batch 37/49, Batch Loss: 61481.4492
# Epoch 99, Batch 38/49, Batch Loss: 109814.7969
# Epoch 99, Batch 39/49, Batch Loss: 62833.2773
# Epoch 99, Batch 40/49, Batch Loss: 82856.6875
# Epoch 99, Batch 41/49, Batch Loss: 91958.1562
# Epoch 99, Batch 42/49, Batch Loss: 85614.8594
# Epoch 99, Batch 43/49, Batch Loss: 79583.5156
# Epoch 99, Batch 44/49, Batch Loss: 69219.0391
# Epoch 99, Batch 45/49, Batch Loss: 75248.5547
# Epoch 99, Batch 46/49, Batch Loss: 55547.4453
# Epoch 99, Batch 47/49, Batch Loss: 113622.1484
# Epoch 99, Batch 48/49, Batch Loss: 52640.1680
# Epoch 99, Batch 49/49, Batch Loss: 63484.6836
# Batch 1/17, Batch Loss: 206923.7656
# Batch 2/17, Batch Loss: 146213.7812
# Batch 3/17, Batch Loss: 160394.4531
# Batch 4/17, Batch Loss: 109066.2422
# Batch 5/17, Batch Loss: 345135.6875
# Batch 6/17, Batch Loss: 112836.2969
# Batch 7/17, Batch Loss: 99135.2734
# Batch 8/17, Batch Loss: 107008.0312
# Batch 9/17, Batch Loss: 164097.1875
# Batch 10/17, Batch Loss: 66538.2500
# Batch 11/17, Batch Loss: 137769.9219
# Batch 12/17, Batch Loss: 299503.1250
# Batch 13/17, Batch Loss: 108232.0938
# Batch 14/17, Batch Loss: 205146.4375
# Batch 15/17, Batch Loss: 220590.8438
# Batch 16/17, Batch Loss: 135801.6719
# Batch 17/17, Batch Loss: 175568.3438
# Test Error:
#  Avg loss: 164703.612132, Avg error: 105454.657439
#
# Epoch 100, Batch 1/49, Batch Loss: 58460.8867
# Epoch 100, Batch 2/49, Batch Loss: 93272.7266
# Epoch 100, Batch 3/49, Batch Loss: 80282.8672
# Epoch 100, Batch 4/49, Batch Loss: 55577.7539
# Epoch 100, Batch 5/49, Batch Loss: 69180.4453
# Epoch 100, Batch 6/49, Batch Loss: 54149.0312
# Epoch 100, Batch 7/49, Batch Loss: 68106.6641
# Epoch 100, Batch 8/49, Batch Loss: 61892.9609
# Epoch 100, Batch 9/49, Batch Loss: 66300.7422
# Epoch 100, Batch 10/49, Batch Loss: 97503.2266
# Epoch 100, Batch 11/49, Batch Loss: 69211.9766
# Epoch 100, Batch 12/49, Batch Loss: 67548.3906
# Epoch 100, Batch 13/49, Batch Loss: 172714.6719
# Epoch 100, Batch 14/49, Batch Loss: 84996.6562
# Epoch 100, Batch 15/49, Batch Loss: 55039.9609
# Epoch 100, Batch 16/49, Batch Loss: 63763.6406
# Epoch 100, Batch 17/49, Batch Loss: 63174.9531
# Epoch 100, Batch 18/49, Batch Loss: 61410.1328
# Epoch 100, Batch 19/49, Batch Loss: 55343.1094
# Epoch 100, Batch 20/49, Batch Loss: 75323.0391
# Epoch 100, Batch 21/49, Batch Loss: 69931.6328
# Epoch 100, Batch 22/49, Batch Loss: 66693.5156
# Epoch 100, Batch 23/49, Batch Loss: 71455.7109
# Epoch 100, Batch 24/49, Batch Loss: 84073.6953
# Epoch 100, Batch 25/49, Batch Loss: 94863.2891
# Epoch 100, Batch 26/49, Batch Loss: 99965.1484
# Epoch 100, Batch 27/49, Batch Loss: 54905.0898
# Epoch 100, Batch 28/49, Batch Loss: 86667.2266
# Epoch 100, Batch 29/49, Batch Loss: 120450.6016
# Epoch 100, Batch 30/49, Batch Loss: 76110.9766
# Epoch 100, Batch 31/49, Batch Loss: 93129.2656
# Epoch 100, Batch 32/49, Batch Loss: 51164.0625
# Epoch 100, Batch 33/49, Batch Loss: 98189.1641
# Epoch 100, Batch 34/49, Batch Loss: 104846.0703
# Epoch 100, Batch 35/49, Batch Loss: 110652.7422
# Epoch 100, Batch 36/49, Batch Loss: 117065.2422
# Epoch 100, Batch 37/49, Batch Loss: 87214.5391
# Epoch 100, Batch 38/49, Batch Loss: 53795.7500
# Epoch 100, Batch 39/49, Batch Loss: 96947.0859
# Epoch 100, Batch 40/49, Batch Loss: 132078.5781
# Epoch 100, Batch 41/49, Batch Loss: 68900.0234
# Epoch 100, Batch 42/49, Batch Loss: 87585.5938
# Epoch 100, Batch 43/49, Batch Loss: 90926.6719
# Epoch 100, Batch 44/49, Batch Loss: 71455.7266
# Epoch 100, Batch 45/49, Batch Loss: 61053.0508
# Epoch 100, Batch 46/49, Batch Loss: 78858.8516
# Epoch 100, Batch 47/49, Batch Loss: 72569.7109
# Epoch 100, Batch 48/49, Batch Loss: 67959.1719
# Epoch 100, Batch 49/49, Batch Loss: 84552.7578
# Batch 1/17, Batch Loss: 200790.1719
# Batch 2/17, Batch Loss: 194972.8281
# Batch 3/17, Batch Loss: 166670.1562
# Batch 4/17, Batch Loss: 114390.2422
# Batch 5/17, Batch Loss: 243796.3594
# Batch 6/17, Batch Loss: 259772.1562
# Batch 7/17, Batch Loss: 99604.4688
# Batch 8/17, Batch Loss: 114146.6406
# Batch 9/17, Batch Loss: 220087.8750
# Batch 10/17, Batch Loss: 105211.6094
# Batch 11/17, Batch Loss: 118128.3906
# Batch 12/17, Batch Loss: 230048.2656
# Batch 13/17, Batch Loss: 96048.7891
# Batch 14/17, Batch Loss: 237119.0938
# Batch 15/17, Batch Loss: 142728.6094
# Batch 16/17, Batch Loss: 130892.3203
# Batch 17/17, Batch Loss: 142012.9531
# Test Error:
#  Avg loss: 165671.819393, Avg error: 117019.494377
#
# 2024-09-26 23:09:44.957506 Epoch 100, Average Training loss 80149.28125
# Epoch 101, Batch 1/49, Batch Loss: 107520.3984
# Epoch 101, Batch 2/49, Batch Loss: 61154.4219
# Epoch 101, Batch 3/49, Batch Loss: 82194.0625
# Epoch 101, Batch 4/49, Batch Loss: 85154.8906
# Epoch 101, Batch 5/49, Batch Loss: 130360.1250
# Epoch 101, Batch 6/49, Batch Loss: 68904.0625
# Epoch 101, Batch 7/49, Batch Loss: 71537.7969
# Epoch 101, Batch 8/49, Batch Loss: 113636.4609
# Epoch 101, Batch 9/49, Batch Loss: 101074.9062
# Epoch 101, Batch 10/49, Batch Loss: 144534.8281
# Epoch 101, Batch 11/49, Batch Loss: 98543.3984
# Epoch 101, Batch 12/49, Batch Loss: 77588.2188
# Epoch 101, Batch 13/49, Batch Loss: 63563.1484
# Epoch 101, Batch 14/49, Batch Loss: 83451.5234
# Epoch 101, Batch 15/49, Batch Loss: 97298.6172
# Epoch 101, Batch 16/49, Batch Loss: 159150.1719
# Epoch 101, Batch 17/49, Batch Loss: 82437.8359
# Epoch 101, Batch 18/49, Batch Loss: 47814.4062
# Epoch 101, Batch 19/49, Batch Loss: 66936.7734
# Epoch 101, Batch 20/49, Batch Loss: 86769.1094
# Epoch 101, Batch 21/49, Batch Loss: 124917.0234
# Epoch 101, Batch 22/49, Batch Loss: 63937.3984
# Epoch 101, Batch 23/49, Batch Loss: 65159.8008
# Epoch 101, Batch 24/49, Batch Loss: 43350.3320
# Epoch 101, Batch 25/49, Batch Loss: 74615.1172
# Epoch 101, Batch 26/49, Batch Loss: 89715.0781
# Epoch 101, Batch 27/49, Batch Loss: 82584.8750
# Epoch 101, Batch 28/49, Batch Loss: 83485.2734
# Epoch 101, Batch 29/49, Batch Loss: 61993.3516
# Epoch 101, Batch 30/49, Batch Loss: 120143.8672
# Epoch 101, Batch 31/49, Batch Loss: 86648.5781
# Epoch 101, Batch 32/49, Batch Loss: 68966.7891
# Epoch 101, Batch 33/49, Batch Loss: 59874.8398
# Epoch 101, Batch 34/49, Batch Loss: 66488.4609
# Epoch 101, Batch 35/49, Batch Loss: 99305.7266
# Epoch 101, Batch 36/49, Batch Loss: 60624.7930
# Epoch 101, Batch 37/49, Batch Loss: 68952.1562
# Epoch 101, Batch 38/49, Batch Loss: 60038.2305
# Epoch 101, Batch 39/49, Batch Loss: 69503.8281
# Epoch 101, Batch 40/49, Batch Loss: 54379.7539
# Epoch 101, Batch 41/49, Batch Loss: 87308.4531
# Epoch 101, Batch 42/49, Batch Loss: 71350.7109
# Epoch 101, Batch 43/49, Batch Loss: 67880.9453
# Epoch 101, Batch 44/49, Batch Loss: 72751.7500
# Epoch 101, Batch 45/49, Batch Loss: 76385.7266
# Epoch 101, Batch 46/49, Batch Loss: 59919.5586
# Epoch 101, Batch 47/49, Batch Loss: 114321.0078
# Epoch 101, Batch 48/49, Batch Loss: 74384.3672
# Epoch 101, Batch 49/49, Batch Loss: 83998.3203
# Batch 1/17, Batch Loss: 194999.7500
# Batch 2/17, Batch Loss: 176900.4219
# Batch 3/17, Batch Loss: 176365.4531
# Batch 4/17, Batch Loss: 172307.5469
# Batch 5/17, Batch Loss: 1366643.7500
# Batch 6/17, Batch Loss: 228646.0312
# Batch 7/17, Batch Loss: 169849.7500
# Batch 8/17, Batch Loss: 143109.0312
# Batch 9/17, Batch Loss: 130651.3203
# Batch 10/17, Batch Loss: 70136.1016
# Batch 11/17, Batch Loss: 135948.6562
# Batch 12/17, Batch Loss: 316993.9062
# Batch 13/17, Batch Loss: 99125.4922
# Batch 14/17, Batch Loss: 184697.5000
# Batch 15/17, Batch Loss: 141008.2969
# Batch 16/17, Batch Loss: 211236.8594
# Batch 17/17, Batch Loss: 160770.3594
# Test Error:
#  Avg loss: 239964.130974, Avg error: 115398.254325
#
# Epoch 102, Batch 1/49, Batch Loss: 91098.9297
# Epoch 102, Batch 2/49, Batch Loss: 54714.8008
# Epoch 102, Batch 3/49, Batch Loss: 62891.9453
# Epoch 102, Batch 4/49, Batch Loss: 56056.9609
# Epoch 102, Batch 5/49, Batch Loss: 72365.5938
# Epoch 102, Batch 6/49, Batch Loss: 66650.2266
# Epoch 102, Batch 7/49, Batch Loss: 71189.1641
# Epoch 102, Batch 8/49, Batch Loss: 54541.7266
# Epoch 102, Batch 9/49, Batch Loss: 81726.5859
# Epoch 102, Batch 10/49, Batch Loss: 64086.8867
# Epoch 102, Batch 11/49, Batch Loss: 94612.4844
# Epoch 102, Batch 12/49, Batch Loss: 74286.7734
# Epoch 102, Batch 13/49, Batch Loss: 61979.0781
# Epoch 102, Batch 14/49, Batch Loss: 53193.5703
# Epoch 102, Batch 15/49, Batch Loss: 66397.3359
# Epoch 102, Batch 16/49, Batch Loss: 80599.3672
# Epoch 102, Batch 17/49, Batch Loss: 59675.8828
# Epoch 102, Batch 18/49, Batch Loss: 61434.5977
# Epoch 102, Batch 19/49, Batch Loss: 58498.6250
# Epoch 102, Batch 20/49, Batch Loss: 72352.2734
# Epoch 102, Batch 21/49, Batch Loss: 65075.8516
# Epoch 102, Batch 22/49, Batch Loss: 70835.6016
# Epoch 102, Batch 23/49, Batch Loss: 74630.6172
# Epoch 102, Batch 24/49, Batch Loss: 88550.6562
# Epoch 102, Batch 25/49, Batch Loss: 77386.7500
# Epoch 102, Batch 26/49, Batch Loss: 54064.5664
# Epoch 102, Batch 27/49, Batch Loss: 69714.8906
# Epoch 102, Batch 28/49, Batch Loss: 59606.5625
# Epoch 102, Batch 29/49, Batch Loss: 70420.6406
# Epoch 102, Batch 30/49, Batch Loss: 61766.9453
# Epoch 102, Batch 31/49, Batch Loss: 51739.5898
# Epoch 102, Batch 32/49, Batch Loss: 53153.8750
# Epoch 102, Batch 33/49, Batch Loss: 92391.7500
# Epoch 102, Batch 34/49, Batch Loss: 73405.4844
# Epoch 102, Batch 35/49, Batch Loss: 65370.2070
# Epoch 102, Batch 36/49, Batch Loss: 79299.7500
# Epoch 102, Batch 37/49, Batch Loss: 84086.4766
# Epoch 102, Batch 38/49, Batch Loss: 80003.3750
# Epoch 102, Batch 39/49, Batch Loss: 73731.1641
# Epoch 102, Batch 40/49, Batch Loss: 164745.9375
# Epoch 102, Batch 41/49, Batch Loss: 56646.2773
# Epoch 102, Batch 42/49, Batch Loss: 71151.8750
# Epoch 102, Batch 43/49, Batch Loss: 75954.2500
# Epoch 102, Batch 44/49, Batch Loss: 82479.5938
# Epoch 102, Batch 45/49, Batch Loss: 99303.8984
# Epoch 102, Batch 46/49, Batch Loss: 54761.0625
# Epoch 102, Batch 47/49, Batch Loss: 74578.2578
# Epoch 102, Batch 48/49, Batch Loss: 50406.4141
# Epoch 102, Batch 49/49, Batch Loss: 68951.3281
# Batch 1/17, Batch Loss: 206757.9844
# Batch 2/17, Batch Loss: 229074.9688
# Batch 3/17, Batch Loss: 157572.7031
# Batch 4/17, Batch Loss: 91049.8984
# Batch 5/17, Batch Loss: 276340.7500
# Batch 6/17, Batch Loss: 136715.4375
# Batch 7/17, Batch Loss: 174871.5000
# Batch 8/17, Batch Loss: 162257.1094
# Batch 9/17, Batch Loss: 81923.2578
# Batch 10/17, Batch Loss: 77805.9141
# Batch 11/17, Batch Loss: 152165.1094
# Batch 12/17, Batch Loss: 243411.4844
# Batch 13/17, Batch Loss: 52954.0703
# Batch 14/17, Batch Loss: 174312.8906
# Batch 15/17, Batch Loss: 201939.2969
# Batch 16/17, Batch Loss: 133869.5469
# Batch 17/17, Batch Loss: 181983.4375
# Test Error:
#  Avg loss: 160882.668199, Avg error: 98657.399654
#
# Epoch 103, Batch 1/49, Batch Loss: 63460.2734
# Epoch 103, Batch 2/49, Batch Loss: 58965.0352
# Epoch 103, Batch 3/49, Batch Loss: 96008.5078
# Epoch 103, Batch 4/49, Batch Loss: 80260.6172
# Epoch 103, Batch 5/49, Batch Loss: 86339.0547
# Epoch 103, Batch 6/49, Batch Loss: 123353.6641
# Epoch 103, Batch 7/49, Batch Loss: 66671.0156
# Epoch 103, Batch 8/49, Batch Loss: 79342.7344
# Epoch 103, Batch 9/49, Batch Loss: 86455.0781
# Epoch 103, Batch 10/49, Batch Loss: 86182.1562
# Epoch 103, Batch 11/49, Batch Loss: 110942.4766
# Epoch 103, Batch 12/49, Batch Loss: 70068.9609
# Epoch 103, Batch 13/49, Batch Loss: 53327.5781
# Epoch 103, Batch 14/49, Batch Loss: 80384.2891
# Epoch 103, Batch 15/49, Batch Loss: 55276.1289
# Epoch 103, Batch 16/49, Batch Loss: 108749.2031
# Epoch 103, Batch 17/49, Batch Loss: 117268.3281
# Epoch 103, Batch 18/49, Batch Loss: 61863.6719
# Epoch 103, Batch 19/49, Batch Loss: 74055.0391
# Epoch 103, Batch 20/49, Batch Loss: 76400.6719
# Epoch 103, Batch 21/49, Batch Loss: 57139.4102
# Epoch 103, Batch 22/49, Batch Loss: 51980.8750
# Epoch 103, Batch 23/49, Batch Loss: 59173.3906
# Epoch 103, Batch 24/49, Batch Loss: 70625.7031
# Epoch 103, Batch 25/49, Batch Loss: 107978.9219
# Epoch 103, Batch 26/49, Batch Loss: 65943.3906
# Epoch 103, Batch 27/49, Batch Loss: 56602.6953
# Epoch 103, Batch 28/49, Batch Loss: 65529.5469
# Epoch 103, Batch 29/49, Batch Loss: 65297.2070
# Epoch 103, Batch 30/49, Batch Loss: 114254.4766
# Epoch 103, Batch 31/49, Batch Loss: 67592.1250
# Epoch 103, Batch 32/49, Batch Loss: 59770.8906
# Epoch 103, Batch 33/49, Batch Loss: 79105.0781
# Epoch 103, Batch 34/49, Batch Loss: 64965.5703
# Epoch 103, Batch 35/49, Batch Loss: 62362.1016
# Epoch 103, Batch 36/49, Batch Loss: 55664.5781
# Epoch 103, Batch 37/49, Batch Loss: 72979.9453
# Epoch 103, Batch 38/49, Batch Loss: 62851.3555
# Epoch 103, Batch 39/49, Batch Loss: 86690.5000
# Epoch 103, Batch 40/49, Batch Loss: 65592.0859
# Epoch 103, Batch 41/49, Batch Loss: 90596.8516
# Epoch 103, Batch 42/49, Batch Loss: 63066.0352
# Epoch 103, Batch 43/49, Batch Loss: 57291.7148
# Epoch 103, Batch 44/49, Batch Loss: 60779.5781
# Epoch 103, Batch 45/49, Batch Loss: 45940.6406
# Epoch 103, Batch 46/49, Batch Loss: 61440.5703
# Epoch 103, Batch 47/49, Batch Loss: 65777.8750
# Epoch 103, Batch 48/49, Batch Loss: 73309.6250
# Epoch 103, Batch 49/49, Batch Loss: 63817.8555
# Batch 1/17, Batch Loss: 182408.8281
# Batch 2/17, Batch Loss: 226379.2500
# Batch 3/17, Batch Loss: 188360.8125
# Batch 4/17, Batch Loss: 199285.2031
# Batch 5/17, Batch Loss: 275257.0938
# Batch 6/17, Batch Loss: 238681.9688
# Batch 7/17, Batch Loss: 167785.6406
# Batch 8/17, Batch Loss: 129339.9531
# Batch 9/17, Batch Loss: 78371.6797
# Batch 10/17, Batch Loss: 73156.3984
# Batch 11/17, Batch Loss: 152827.1094
# Batch 12/17, Batch Loss: 304416.3438
# Batch 13/17, Batch Loss: 39268.3633
# Batch 14/17, Batch Loss: 176388.2500
# Batch 15/17, Batch Loss: 146961.6250
# Batch 16/17, Batch Loss: 119159.2188
# Batch 17/17, Batch Loss: 156858.5156
# Test Error:
#  Avg loss: 167935.661994, Avg error: 101725.671064
#
# Epoch 104, Batch 1/49, Batch Loss: 64908.9336
# Epoch 104, Batch 2/49, Batch Loss: 67181.3047
# Epoch 104, Batch 3/49, Batch Loss: 72256.3672
# Epoch 104, Batch 4/49, Batch Loss: 68384.4453
# Epoch 104, Batch 5/49, Batch Loss: 93342.5625
# Epoch 104, Batch 6/49, Batch Loss: 48794.4336
# Epoch 104, Batch 7/49, Batch Loss: 72986.1172
# Epoch 104, Batch 8/49, Batch Loss: 59505.3789
# Epoch 104, Batch 9/49, Batch Loss: 51494.3164
# Epoch 104, Batch 10/49, Batch Loss: 113089.4297
# Epoch 104, Batch 11/49, Batch Loss: 67790.1406
# Epoch 104, Batch 12/49, Batch Loss: 85080.6797
# Epoch 104, Batch 13/49, Batch Loss: 80194.7500
# Epoch 104, Batch 14/49, Batch Loss: 83870.5703
# Epoch 104, Batch 15/49, Batch Loss: 66009.8125
# Epoch 104, Batch 16/49, Batch Loss: 91676.3516
# Epoch 104, Batch 17/49, Batch Loss: 81514.3047
# Epoch 104, Batch 18/49, Batch Loss: 78696.5703
# Epoch 104, Batch 19/49, Batch Loss: 88503.3203
# Epoch 104, Batch 20/49, Batch Loss: 166486.5156
# Epoch 104, Batch 21/49, Batch Loss: 79951.5156
# Epoch 104, Batch 22/49, Batch Loss: 63152.8320
# Epoch 104, Batch 23/49, Batch Loss: 72434.2266
# Epoch 104, Batch 24/49, Batch Loss: 58825.9766
# Epoch 104, Batch 25/49, Batch Loss: 69794.7344
# Epoch 104, Batch 26/49, Batch Loss: 63487.3555
# Epoch 104, Batch 27/49, Batch Loss: 76402.1094
# Epoch 104, Batch 28/49, Batch Loss: 71507.5234
# Epoch 104, Batch 29/49, Batch Loss: 91541.8750
# Epoch 104, Batch 30/49, Batch Loss: 90144.9688
# Epoch 104, Batch 31/49, Batch Loss: 80603.8047
# Epoch 104, Batch 32/49, Batch Loss: 65571.6406
# Epoch 104, Batch 33/49, Batch Loss: 73420.9219
# Epoch 104, Batch 34/49, Batch Loss: 56984.6875
# Epoch 104, Batch 35/49, Batch Loss: 75660.2109
# Epoch 104, Batch 36/49, Batch Loss: 68015.4297
# Epoch 104, Batch 37/49, Batch Loss: 63769.6992
# Epoch 104, Batch 38/49, Batch Loss: 62566.6914
# Epoch 104, Batch 39/49, Batch Loss: 96121.0625
# Epoch 104, Batch 40/49, Batch Loss: 56673.2227
# Epoch 104, Batch 41/49, Batch Loss: 70700.6094
# Epoch 104, Batch 42/49, Batch Loss: 72401.8125
# Epoch 104, Batch 43/49, Batch Loss: 55597.9492
# Epoch 104, Batch 44/49, Batch Loss: 110628.3828
# Epoch 104, Batch 45/49, Batch Loss: 74426.5547
# Epoch 104, Batch 46/49, Batch Loss: 102663.8594
# Epoch 104, Batch 47/49, Batch Loss: 89291.4219
# Epoch 104, Batch 48/49, Batch Loss: 73445.5938
# Epoch 104, Batch 49/49, Batch Loss: 82738.8828
# Batch 1/17, Batch Loss: 212966.7812
# Batch 2/17, Batch Loss: 85727.3359
# Batch 3/17, Batch Loss: 188521.9844
# Batch 4/17, Batch Loss: 193713.3438
# Batch 5/17, Batch Loss: 1379643.8750
# Batch 6/17, Batch Loss: 253508.9844
# Batch 7/17, Batch Loss: 166908.0000
# Batch 8/17, Batch Loss: 103393.0078
# Batch 9/17, Batch Loss: 163752.1250
# Batch 10/17, Batch Loss: 99144.1172
# Batch 11/17, Batch Loss: 135967.3750
# Batch 12/17, Batch Loss: 245956.9688
# Batch 13/17, Batch Loss: 110294.3125
# Batch 14/17, Batch Loss: 236821.0938
# Batch 15/17, Batch Loss: 142484.3125
# Batch 16/17, Batch Loss: 205715.4531
# Batch 17/17, Batch Loss: 135654.3281
# Test Error:
#  Avg loss: 238833.729320, Avg error: 123439.670848
#
# Epoch 105, Batch 1/49, Batch Loss: 104949.5156
# Epoch 105, Batch 2/49, Batch Loss: 74466.9844
# Epoch 105, Batch 3/49, Batch Loss: 107408.7266
# Epoch 105, Batch 4/49, Batch Loss: 68782.9453
# Epoch 105, Batch 5/49, Batch Loss: 50240.8867
# Epoch 105, Batch 6/49, Batch Loss: 61939.1719
# Epoch 105, Batch 7/49, Batch Loss: 87078.4688
# Epoch 105, Batch 8/49, Batch Loss: 88991.0078
# Epoch 105, Batch 9/49, Batch Loss: 80832.9219
# Epoch 105, Batch 10/49, Batch Loss: 67629.9766
# Epoch 105, Batch 11/49, Batch Loss: 88380.6328
# Epoch 105, Batch 12/49, Batch Loss: 94485.4844
# Epoch 105, Batch 13/49, Batch Loss: 57225.1406
# Epoch 105, Batch 14/49, Batch Loss: 74831.1016
# Epoch 105, Batch 15/49, Batch Loss: 63754.2148
# Epoch 105, Batch 16/49, Batch Loss: 58759.2812
# Epoch 105, Batch 17/49, Batch Loss: 61715.6367
# Epoch 105, Batch 18/49, Batch Loss: 129973.1016
# Epoch 105, Batch 19/49, Batch Loss: 66771.8203
# Epoch 105, Batch 20/49, Batch Loss: 72072.9922
# Epoch 105, Batch 21/49, Batch Loss: 67734.0156
# Epoch 105, Batch 22/49, Batch Loss: 74411.3828
# Epoch 105, Batch 23/49, Batch Loss: 53816.2422
# Epoch 105, Batch 24/49, Batch Loss: 69025.8828
# Epoch 105, Batch 25/49, Batch Loss: 60255.8750
# Epoch 105, Batch 26/49, Batch Loss: 69364.5859
# Epoch 105, Batch 27/49, Batch Loss: 68598.8906
# Epoch 105, Batch 28/49, Batch Loss: 80116.8594
# Epoch 105, Batch 29/49, Batch Loss: 93204.5938
# Epoch 105, Batch 30/49, Batch Loss: 84932.3906
# Epoch 105, Batch 31/49, Batch Loss: 61226.8906
# Epoch 105, Batch 32/49, Batch Loss: 76366.3516
# Epoch 105, Batch 33/49, Batch Loss: 65151.5391
# Epoch 105, Batch 34/49, Batch Loss: 70736.2578
# Epoch 105, Batch 35/49, Batch Loss: 71976.1250
# Epoch 105, Batch 36/49, Batch Loss: 54079.2773
# Epoch 105, Batch 37/49, Batch Loss: 68463.9062
# Epoch 105, Batch 38/49, Batch Loss: 74350.4844
# Epoch 105, Batch 39/49, Batch Loss: 65296.9258
# Epoch 105, Batch 40/49, Batch Loss: 79969.0312
# Epoch 105, Batch 41/49, Batch Loss: 56390.4883
# Epoch 105, Batch 42/49, Batch Loss: 66315.0234
# Epoch 105, Batch 43/49, Batch Loss: 61053.4961
# Epoch 105, Batch 44/49, Batch Loss: 134744.1406
# Epoch 105, Batch 45/49, Batch Loss: 118647.6641
# Epoch 105, Batch 46/49, Batch Loss: 73642.8594
# Epoch 105, Batch 47/49, Batch Loss: 59298.3242
# Epoch 105, Batch 48/49, Batch Loss: 52481.5469
# Epoch 105, Batch 49/49, Batch Loss: 61340.8398
# Batch 1/17, Batch Loss: 189167.2500
# Batch 2/17, Batch Loss: 241132.2344
# Batch 3/17, Batch Loss: 197571.5000
# Batch 4/17, Batch Loss: 202433.8438
# Batch 5/17, Batch Loss: 1368797.2500
# Batch 6/17, Batch Loss: 116932.6719
# Batch 7/17, Batch Loss: 163615.9688
# Batch 8/17, Batch Loss: 148290.0469
# Batch 9/17, Batch Loss: 190467.9219
# Batch 10/17, Batch Loss: 82345.7031
# Batch 11/17, Batch Loss: 113440.1719
# Batch 12/17, Batch Loss: 308584.2812
# Batch 13/17, Batch Loss: 34153.7734
# Batch 14/17, Batch Loss: 217653.2031
# Batch 15/17, Batch Loss: 155267.8438
# Batch 16/17, Batch Loss: 114916.8906
# Batch 17/17, Batch Loss: 130154.6562
# Test Error:
#  Avg loss: 233819.130055, Avg error: 113642.956207
#
# Epoch 106, Batch 1/49, Batch Loss: 44413.0430
# Epoch 106, Batch 2/49, Batch Loss: 52965.4297
# Epoch 106, Batch 3/49, Batch Loss: 60413.0039
# Epoch 106, Batch 4/49, Batch Loss: 63010.0273
# Epoch 106, Batch 5/49, Batch Loss: 71227.8672
# Epoch 106, Batch 6/49, Batch Loss: 84990.6328
# Epoch 106, Batch 7/49, Batch Loss: 54557.9102
# Epoch 106, Batch 8/49, Batch Loss: 52758.8711
# Epoch 106, Batch 9/49, Batch Loss: 59521.6523
# Epoch 106, Batch 10/49, Batch Loss: 82342.3750
# Epoch 106, Batch 11/49, Batch Loss: 106612.1328
# Epoch 106, Batch 12/49, Batch Loss: 102783.3906
# Epoch 106, Batch 13/49, Batch Loss: 73146.2812
# Epoch 106, Batch 14/49, Batch Loss: 75506.9219
# Epoch 106, Batch 15/49, Batch Loss: 99386.8984
# Epoch 106, Batch 16/49, Batch Loss: 65345.9609
# Epoch 106, Batch 17/49, Batch Loss: 101505.9219
# Epoch 106, Batch 18/49, Batch Loss: 105172.9531
# Epoch 106, Batch 19/49, Batch Loss: 68549.9297
# Epoch 106, Batch 20/49, Batch Loss: 64302.3242
# Epoch 106, Batch 21/49, Batch Loss: 71091.4219
# Epoch 106, Batch 22/49, Batch Loss: 68197.3125
# Epoch 106, Batch 23/49, Batch Loss: 82687.7188
# Epoch 106, Batch 24/49, Batch Loss: 69699.2969
# Epoch 106, Batch 25/49, Batch Loss: 59386.3594
# Epoch 106, Batch 26/49, Batch Loss: 69021.6875
# Epoch 106, Batch 27/49, Batch Loss: 59575.3516
# Epoch 106, Batch 28/49, Batch Loss: 57834.1328
# Epoch 106, Batch 29/49, Batch Loss: 70433.6172
# Epoch 106, Batch 30/49, Batch Loss: 72595.1172
# Epoch 106, Batch 31/49, Batch Loss: 50580.9375
# Epoch 106, Batch 32/49, Batch Loss: 88299.6406
# Epoch 106, Batch 33/49, Batch Loss: 60258.1953
# Epoch 106, Batch 34/49, Batch Loss: 99974.2422
# Epoch 106, Batch 35/49, Batch Loss: 68180.9766
# Epoch 106, Batch 36/49, Batch Loss: 110402.0156
# Epoch 106, Batch 37/49, Batch Loss: 80283.2344
# Epoch 106, Batch 38/49, Batch Loss: 63324.8203
# Epoch 106, Batch 39/49, Batch Loss: 56044.2969
# Epoch 106, Batch 40/49, Batch Loss: 58683.0703
# Epoch 106, Batch 41/49, Batch Loss: 53261.2578
# Epoch 106, Batch 42/49, Batch Loss: 100234.6953
# Epoch 106, Batch 43/49, Batch Loss: 72160.0078
# Epoch 106, Batch 44/49, Batch Loss: 69609.9609
# Epoch 106, Batch 45/49, Batch Loss: 73646.6719
# Epoch 106, Batch 46/49, Batch Loss: 60348.2266
# Epoch 106, Batch 47/49, Batch Loss: 63704.9688
# Epoch 106, Batch 48/49, Batch Loss: 75039.5938
# Epoch 106, Batch 49/49, Batch Loss: 66811.3594
# Batch 1/17, Batch Loss: 207388.6094
# Batch 2/17, Batch Loss: 155685.4688
# Batch 3/17, Batch Loss: 208999.6562
# Batch 4/17, Batch Loss: 195285.6250
# Batch 5/17, Batch Loss: 189058.0312
# Batch 6/17, Batch Loss: 107446.6719
# Batch 7/17, Batch Loss: 178624.4062
# Batch 8/17, Batch Loss: 135993.0000
# Batch 9/17, Batch Loss: 96612.7891
# Batch 10/17, Batch Loss: 56284.8906
# Batch 11/17, Batch Loss: 123910.1406
# Batch 12/17, Batch Loss: 322766.8750
# Batch 13/17, Batch Loss: 30350.3867
# Batch 14/17, Batch Loss: 188569.6719
# Batch 15/17, Batch Loss: 190175.4531
# Batch 16/17, Batch Loss: 108403.2188
# Batch 17/17, Batch Loss: 149600.0312
# Test Error:
#  Avg loss: 155597.348575, Avg error: 90251.820285
#
# Epoch 107, Batch 1/49, Batch Loss: 41728.8477
# Epoch 107, Batch 2/49, Batch Loss: 103937.9844
# Epoch 107, Batch 3/49, Batch Loss: 111614.0547
# Epoch 107, Batch 4/49, Batch Loss: 70145.2188
# Epoch 107, Batch 5/49, Batch Loss: 96180.7109
# Epoch 107, Batch 6/49, Batch Loss: 83689.7109
# Epoch 107, Batch 7/49, Batch Loss: 74596.7422
# Epoch 107, Batch 8/49, Batch Loss: 74677.0078
# Epoch 107, Batch 9/49, Batch Loss: 64434.8008
# Epoch 107, Batch 10/49, Batch Loss: 59521.8984
# Epoch 107, Batch 11/49, Batch Loss: 98657.0469
# Epoch 107, Batch 12/49, Batch Loss: 55295.8242
# Epoch 107, Batch 13/49, Batch Loss: 65102.9453
# Epoch 107, Batch 14/49, Batch Loss: 65476.9961
# Epoch 107, Batch 15/49, Batch Loss: 69937.9766
# Epoch 107, Batch 16/49, Batch Loss: 80771.9062
# Epoch 107, Batch 17/49, Batch Loss: 80452.1641
# Epoch 107, Batch 18/49, Batch Loss: 64531.8711
# Epoch 107, Batch 19/49, Batch Loss: 70010.6250
# Epoch 107, Batch 20/49, Batch Loss: 99799.9609
# Epoch 107, Batch 21/49, Batch Loss: 100851.1094
# Epoch 107, Batch 22/49, Batch Loss: 61326.1680
# Epoch 107, Batch 23/49, Batch Loss: 57162.7461
# Epoch 107, Batch 24/49, Batch Loss: 190127.7656
# Epoch 107, Batch 25/49, Batch Loss: 92624.1250
# Epoch 107, Batch 26/49, Batch Loss: 93660.2812
# Epoch 107, Batch 27/49, Batch Loss: 69462.5547
# Epoch 107, Batch 28/49, Batch Loss: 103702.1250
# Epoch 107, Batch 29/49, Batch Loss: 67431.1016
# Epoch 107, Batch 30/49, Batch Loss: 64100.2617
# Epoch 107, Batch 31/49, Batch Loss: 72127.2344
# Epoch 107, Batch 32/49, Batch Loss: 72151.8750
# Epoch 107, Batch 33/49, Batch Loss: 59484.0352
# Epoch 107, Batch 34/49, Batch Loss: 66640.7734
# Epoch 107, Batch 35/49, Batch Loss: 67192.1406
# Epoch 107, Batch 36/49, Batch Loss: 71499.4375
# Epoch 107, Batch 37/49, Batch Loss: 91339.3359
# Epoch 107, Batch 38/49, Batch Loss: 75692.4453
# Epoch 107, Batch 39/49, Batch Loss: 64025.2695
# Epoch 107, Batch 40/49, Batch Loss: 73048.7656
# Epoch 107, Batch 41/49, Batch Loss: 71247.8594
# Epoch 107, Batch 42/49, Batch Loss: 72298.8672
# Epoch 107, Batch 43/49, Batch Loss: 106006.2109
# Epoch 107, Batch 44/49, Batch Loss: 101127.2031
# Epoch 107, Batch 45/49, Batch Loss: 48525.8672
# Epoch 107, Batch 46/49, Batch Loss: 77054.7031
# Epoch 107, Batch 47/49, Batch Loss: 73233.2031
# Epoch 107, Batch 48/49, Batch Loss: 100404.3750
# Epoch 107, Batch 49/49, Batch Loss: 101389.5234
# Batch 1/17, Batch Loss: 227476.0469
# Batch 2/17, Batch Loss: 210690.0156
# Batch 3/17, Batch Loss: 156439.7344
# Batch 4/17, Batch Loss: 193175.6719
# Batch 5/17, Batch Loss: 279656.1250
# Batch 6/17, Batch Loss: 246638.5000
# Batch 7/17, Batch Loss: 169730.7656
# Batch 8/17, Batch Loss: 105938.3828
# Batch 9/17, Batch Loss: 118554.7266
# Batch 10/17, Batch Loss: 71197.9766
# Batch 11/17, Batch Loss: 164998.1250
# Batch 12/17, Batch Loss: 328691.4375
# Batch 13/17, Batch Loss: 53991.6211
# Batch 14/17, Batch Loss: 198917.3281
# Batch 15/17, Batch Loss: 116234.3203
# Batch 16/17, Batch Loss: 186121.2656
# Batch 17/17, Batch Loss: 177861.6719
# Test Error:
#  Avg loss: 176841.983226, Avg error: 109914.729671
#
# Epoch 108, Batch 1/49, Batch Loss: 81746.1875
# Epoch 108, Batch 2/49, Batch Loss: 59101.0977
# Epoch 108, Batch 3/49, Batch Loss: 179763.6562
# Epoch 108, Batch 4/49, Batch Loss: 87464.2188
# Epoch 108, Batch 5/49, Batch Loss: 116639.4688
# Epoch 108, Batch 6/49, Batch Loss: 63155.6836
# Epoch 108, Batch 7/49, Batch Loss: 164486.4688
# Epoch 108, Batch 8/49, Batch Loss: 69067.7109
# Epoch 108, Batch 9/49, Batch Loss: 66802.3828
# Epoch 108, Batch 10/49, Batch Loss: 114546.9609
# Epoch 108, Batch 11/49, Batch Loss: 79460.2109
# Epoch 108, Batch 12/49, Batch Loss: 130215.9688
# Epoch 108, Batch 13/49, Batch Loss: 103259.0547
# Epoch 108, Batch 14/49, Batch Loss: 71626.6797
# Epoch 108, Batch 15/49, Batch Loss: 74613.1953
# Epoch 108, Batch 16/49, Batch Loss: 92724.7891
# Epoch 108, Batch 17/49, Batch Loss: 87176.1406
# Epoch 108, Batch 18/49, Batch Loss: 72334.7344
# Epoch 108, Batch 19/49, Batch Loss: 60348.1289
# Epoch 108, Batch 20/49, Batch Loss: 55958.6641
# Epoch 108, Batch 21/49, Batch Loss: 48318.3945
# Epoch 108, Batch 22/49, Batch Loss: 116102.9531
# Epoch 108, Batch 23/49, Batch Loss: 106339.5156
# Epoch 108, Batch 24/49, Batch Loss: 54641.1992
# Epoch 108, Batch 25/49, Batch Loss: 83943.9062
# Epoch 108, Batch 26/49, Batch Loss: 59667.0586
# Epoch 108, Batch 27/49, Batch Loss: 98367.9844
# Epoch 108, Batch 28/49, Batch Loss: 124375.0781
# Epoch 108, Batch 29/49, Batch Loss: 46459.9141
# Epoch 108, Batch 30/49, Batch Loss: 77766.6328
# Epoch 108, Batch 31/49, Batch Loss: 78578.2969
# Epoch 108, Batch 32/49, Batch Loss: 91868.2969
# Epoch 108, Batch 33/49, Batch Loss: 81769.9688
# Epoch 108, Batch 34/49, Batch Loss: 63892.3672
# Epoch 108, Batch 35/49, Batch Loss: 70095.8125
# Epoch 108, Batch 36/49, Batch Loss: 77843.4453
# Epoch 108, Batch 37/49, Batch Loss: 173008.8750
# Epoch 108, Batch 38/49, Batch Loss: 60776.5742
# Epoch 108, Batch 39/49, Batch Loss: 78689.2422
# Epoch 108, Batch 40/49, Batch Loss: 44275.9062
# Epoch 108, Batch 41/49, Batch Loss: 79029.4844
# Epoch 108, Batch 42/49, Batch Loss: 75171.4531
# Epoch 108, Batch 43/49, Batch Loss: 96383.6094
# Epoch 108, Batch 44/49, Batch Loss: 72406.6094
# Epoch 108, Batch 45/49, Batch Loss: 81180.0781
# Epoch 108, Batch 46/49, Batch Loss: 64934.6758
# Epoch 108, Batch 47/49, Batch Loss: 77318.3281
# Epoch 108, Batch 48/49, Batch Loss: 61351.2812
# Epoch 108, Batch 49/49, Batch Loss: 63758.2539
# Batch 1/17, Batch Loss: 216152.2812
# Batch 2/17, Batch Loss: 233365.0000
# Batch 3/17, Batch Loss: 194994.4375
# Batch 4/17, Batch Loss: 169213.0469
# Batch 5/17, Batch Loss: 220739.5312
# Batch 6/17, Batch Loss: 127841.2031
# Batch 7/17, Batch Loss: 163323.3750
# Batch 8/17, Batch Loss: 161196.5000
# Batch 9/17, Batch Loss: 100659.7188
# Batch 10/17, Batch Loss: 79690.7188
# Batch 11/17, Batch Loss: 126359.9297
# Batch 12/17, Batch Loss: 245751.0781
# Batch 13/17, Batch Loss: 52819.3555
# Batch 14/17, Batch Loss: 196366.7031
# Batch 15/17, Batch Loss: 188340.9219
# Batch 16/17, Batch Loss: 206042.7188
# Batch 17/17, Batch Loss: 165628.0938
# Test Error:
#  Avg loss: 167557.918428, Avg error: 96866.433607
#
# Epoch 109, Batch 1/49, Batch Loss: 61696.6484
# Epoch 109, Batch 2/49, Batch Loss: 86281.0938
# Epoch 109, Batch 3/49, Batch Loss: 60986.1445
# Epoch 109, Batch 4/49, Batch Loss: 133949.3438
# Epoch 109, Batch 5/49, Batch Loss: 65036.8164
# Epoch 109, Batch 6/49, Batch Loss: 66733.6328
# Epoch 109, Batch 7/49, Batch Loss: 48515.5117
# Epoch 109, Batch 8/49, Batch Loss: 71414.2422
# Epoch 109, Batch 9/49, Batch Loss: 68555.5078
# Epoch 109, Batch 10/49, Batch Loss: 68629.2578
# Epoch 109, Batch 11/49, Batch Loss: 66285.7266
# Epoch 109, Batch 12/49, Batch Loss: 66305.6641
# Epoch 109, Batch 13/49, Batch Loss: 72020.8906
# Epoch 109, Batch 14/49, Batch Loss: 53591.1953
# Epoch 109, Batch 15/49, Batch Loss: 194222.4375
# Epoch 109, Batch 16/49, Batch Loss: 85798.1562
# Epoch 109, Batch 17/49, Batch Loss: 66440.6484
# Epoch 109, Batch 18/49, Batch Loss: 61673.2617
# Epoch 109, Batch 19/49, Batch Loss: 60700.6016
# Epoch 109, Batch 20/49, Batch Loss: 70992.3438
# Epoch 109, Batch 21/49, Batch Loss: 68819.9062
# Epoch 109, Batch 22/49, Batch Loss: 61723.1445
# Epoch 109, Batch 23/49, Batch Loss: 52055.4180
# Epoch 109, Batch 24/49, Batch Loss: 85082.6953
# Epoch 109, Batch 25/49, Batch Loss: 76839.5312
# Epoch 109, Batch 26/49, Batch Loss: 70583.4141
# Epoch 109, Batch 27/49, Batch Loss: 66744.2891
# Epoch 109, Batch 28/49, Batch Loss: 62650.1562
# Epoch 109, Batch 29/49, Batch Loss: 78985.0703
# Epoch 109, Batch 30/49, Batch Loss: 52529.8516
# Epoch 109, Batch 31/49, Batch Loss: 72422.4219
# Epoch 109, Batch 32/49, Batch Loss: 98037.1953
# Epoch 109, Batch 33/49, Batch Loss: 65520.9375
# Epoch 109, Batch 34/49, Batch Loss: 84973.7812
# Epoch 109, Batch 35/49, Batch Loss: 73065.7422
# Epoch 109, Batch 36/49, Batch Loss: 58619.0859
# Epoch 109, Batch 37/49, Batch Loss: 60747.7070
# Epoch 109, Batch 38/49, Batch Loss: 71364.6328
# Epoch 109, Batch 39/49, Batch Loss: 84248.3438
# Epoch 109, Batch 40/49, Batch Loss: 56863.8164
# Epoch 109, Batch 41/49, Batch Loss: 48665.5820
# Epoch 109, Batch 42/49, Batch Loss: 77574.5547
# Epoch 109, Batch 43/49, Batch Loss: 58324.2578
# Epoch 109, Batch 44/49, Batch Loss: 69822.4531
# Epoch 109, Batch 45/49, Batch Loss: 57629.8164
# Epoch 109, Batch 46/49, Batch Loss: 66425.4141
# Epoch 109, Batch 47/49, Batch Loss: 66712.7891
# Epoch 109, Batch 48/49, Batch Loss: 58519.7891
# Epoch 109, Batch 49/49, Batch Loss: 65030.8008
# Batch 1/17, Batch Loss: 196148.8750
# Batch 2/17, Batch Loss: 220451.2812
# Batch 3/17, Batch Loss: 194491.1094
# Batch 4/17, Batch Loss: 166457.2656
# Batch 5/17, Batch Loss: 215606.4688
# ...
# Epoch 160, Batch 43/49, Batch Loss: 54384.0117
# Epoch 160, Batch 44/49, Batch Loss: 60415.4688
# Epoch 160, Batch 45/49, Batch Loss: 71864.4609
# Epoch 160, Batch 46/49, Batch Loss: 56568.2500
# Epoch 160, Batch 47/49, Batch Loss: 88570.6484
# Epoch 160, Batch 48/49, Batch Loss: 61280.3789
# Epoch 160, Batch 49/49, Batch Loss: 53143.2188
# Batch 1/17, Batch Loss: 225139.6250
# Batch 2/17, Batch Loss: 197874.8281
# Batch 3/17, Batch Loss: 155969.0625
# Batch 4/17, Batch Loss: 132567.7500
# Batch 5/17, Batch Loss: 1360059.3750
# Batch 6/17, Batch Loss: 262237.0312
# Batch 7/17, Batch Loss: 80628.1953
# Batch 8/17, Batch Loss: 158101.1719
# Batch 9/17, Batch Loss: 64575.6914
# Batch 10/17, Batch Loss: 81929.7656
# Batch 11/17, Batch Loss: 136794.1250
# Batch 12/17, Batch Loss: 236739.9062
# Batch 13/17, Batch Loss: 45806.0703
# Batch 14/17, Batch Loss: 158695.0781
# Batch 15/17, Batch Loss: 151616.3125
# Batch 16/17, Batch Loss: 191887.9531
# Batch 17/17, Batch Loss: 112769.1641
# Test Error:
#  Avg loss: 220787.712086, Avg error: 103164.772059
#
# 2024-09-27 00:15:13.870400 Epoch 160, Average Training loss 71885.24194834183
# Epoch 161, Batch 1/49, Batch Loss: 61287.7617
# Epoch 161, Batch 2/49, Batch Loss: 56705.5039
# Epoch 161, Batch 3/49, Batch Loss: 60509.0078
# Epoch 161, Batch 4/49, Batch Loss: 47555.6562
# Epoch 161, Batch 5/49, Batch Loss: 69388.0391
# Epoch 161, Batch 6/49, Batch Loss: 77375.7188
# Epoch 161, Batch 7/49, Batch Loss: 115033.6875
# Epoch 161, Batch 8/49, Batch Loss: 61581.7109
# Epoch 161, Batch 9/49, Batch Loss: 72832.9297
# Epoch 161, Batch 10/49, Batch Loss: 51953.5820
# Epoch 161, Batch 11/49, Batch Loss: 60633.3789
# Epoch 161, Batch 12/49, Batch Loss: 89303.4922
# Epoch 161, Batch 13/49, Batch Loss: 67775.4141
# Epoch 161, Batch 14/49, Batch Loss: 71407.1094
# Epoch 161, Batch 15/49, Batch Loss: 66361.3281
# Epoch 161, Batch 16/49, Batch Loss: 84121.7188
# Epoch 161, Batch 17/49, Batch Loss: 88774.8047
# Epoch 161, Batch 18/49, Batch Loss: 77934.0547
# Epoch 161, Batch 19/49, Batch Loss: 57286.4492
# Epoch 161, Batch 20/49, Batch Loss: 72439.5859
# Epoch 161, Batch 21/49, Batch Loss: 62499.8008
# Epoch 161, Batch 22/49, Batch Loss: 83420.5312
# Epoch 161, Batch 23/49, Batch Loss: 53660.3555
# Epoch 161, Batch 24/49, Batch Loss: 69222.4453
# Epoch 161, Batch 25/49, Batch Loss: 105683.9219
# Epoch 161, Batch 26/49, Batch Loss: 54346.6484
# Epoch 161, Batch 27/49, Batch Loss: 56416.6211
# Epoch 161, Batch 28/49, Batch Loss: 95431.9141
# Epoch 161, Batch 29/49, Batch Loss: 47332.4844
# Epoch 161, Batch 30/49, Batch Loss: 76214.0703
# Epoch 161, Batch 31/49, Batch Loss: 48774.0781
# Epoch 161, Batch 32/49, Batch Loss: 48661.3672
# Epoch 161, Batch 33/49, Batch Loss: 82995.8281
# Epoch 161, Batch 34/49, Batch Loss: 80517.0469
# Epoch 161, Batch 35/49, Batch Loss: 89840.6797
# Epoch 161, Batch 36/49, Batch Loss: 45793.7734
# Epoch 161, Batch 37/49, Batch Loss: 65104.5039
# Epoch 161, Batch 38/49, Batch Loss: 101295.2188
# Epoch 161, Batch 39/49, Batch Loss: 68598.7969
# Epoch 161, Batch 40/49, Batch Loss: 55440.6016
# Epoch 161, Batch 41/49, Batch Loss: 67127.2812
# Epoch 161, Batch 42/49, Batch Loss: 62813.6641
# Epoch 161, Batch 43/49, Batch Loss: 75095.1250
# Epoch 161, Batch 44/49, Batch Loss: 56948.1289
# Epoch 161, Batch 45/49, Batch Loss: 85719.5078
# Epoch 161, Batch 46/49, Batch Loss: 67027.8828
# Epoch 161, Batch 47/49, Batch Loss: 66765.4297
# Epoch 161, Batch 48/49, Batch Loss: 55106.8125
# Epoch 161, Batch 49/49, Batch Loss: 75302.1250
# Batch 1/17, Batch Loss: 197763.5938
# Batch 2/17, Batch Loss: 163235.9688
# Batch 3/17, Batch Loss: 130907.1094
# Batch 4/17, Batch Loss: 163494.3750
# Batch 5/17, Batch Loss: 289330.0000
# Batch 6/17, Batch Loss: 114804.6094
# Batch 7/17, Batch Loss: 169452.7188
# Batch 8/17, Batch Loss: 86071.2422
# Batch 9/17, Batch Loss: 173784.8594
# Batch 10/17, Batch Loss: 88499.0703
# Batch 11/17, Batch Loss: 134366.7812
# Batch 12/17, Batch Loss: 220505.4219
# Batch 13/17, Batch Loss: 110874.2109
# Batch 14/17, Batch Loss: 219201.4688
# Batch 15/17, Batch Loss: 202520.5625
# Batch 16/17, Batch Loss: 174214.2344
# Batch 17/17, Batch Loss: 197753.7500
# Test Error:
#  Avg loss: 166869.410386, Avg error: 102920.269896
#
# Epoch 162, Batch 1/49, Batch Loss: 49515.1719
# Epoch 162, Batch 2/49, Batch Loss: 79214.7891
# Epoch 162, Batch 3/49, Batch Loss: 55827.6641
# Epoch 162, Batch 4/49, Batch Loss: 73028.1094
# Epoch 162, Batch 5/49, Batch Loss: 57161.6211
# Epoch 162, Batch 6/49, Batch Loss: 64114.8008
# Epoch 162, Batch 7/49, Batch Loss: 51759.8359
# Epoch 162, Batch 8/49, Batch Loss: 56116.8945
# Epoch 162, Batch 9/49, Batch Loss: 58531.8086
# Epoch 162, Batch 10/49, Batch Loss: 105936.6016
# Epoch 162, Batch 11/49, Batch Loss: 65643.0156
# Epoch 162, Batch 12/49, Batch Loss: 58175.9492
# Epoch 162, Batch 13/49, Batch Loss: 62174.9336
# Epoch 162, Batch 14/49, Batch Loss: 60663.8164
# Epoch 162, Batch 15/49, Batch Loss: 63565.7188
# Epoch 162, Batch 16/49, Batch Loss: 68400.9297
# Epoch 162, Batch 17/49, Batch Loss: 60921.1211
# Epoch 162, Batch 18/49, Batch Loss: 47658.2617
# Epoch 162, Batch 19/49, Batch Loss: 54746.7422
# Epoch 162, Batch 20/49, Batch Loss: 55044.5352
# Epoch 162, Batch 21/49, Batch Loss: 53772.6953
# Epoch 162, Batch 22/49, Batch Loss: 74637.7344
# Epoch 162, Batch 23/49, Batch Loss: 45806.7109
# Epoch 162, Batch 24/49, Batch Loss: 80731.1562
# Epoch 162, Batch 25/49, Batch Loss: 76619.9688
# Epoch 162, Batch 26/49, Batch Loss: 72985.9453
# Epoch 162, Batch 27/49, Batch Loss: 76625.8281
# Epoch 162, Batch 28/49, Batch Loss: 121650.3047
# Epoch 162, Batch 29/49, Batch Loss: 71167.2344
# Epoch 162, Batch 30/49, Batch Loss: 39221.6055
# Epoch 162, Batch 31/49, Batch Loss: 49109.8086
# Epoch 162, Batch 32/49, Batch Loss: 50935.1602
# Epoch 162, Batch 33/49, Batch Loss: 77459.9922
# Epoch 162, Batch 34/49, Batch Loss: 111653.3750
# Epoch 162, Batch 35/49, Batch Loss: 80176.7578
# Epoch 162, Batch 36/49, Batch Loss: 103391.6719
# Epoch 162, Batch 37/49, Batch Loss: 62285.2852
# Epoch 162, Batch 38/49, Batch Loss: 99610.1641
# Epoch 162, Batch 39/49, Batch Loss: 72594.8594
# Epoch 162, Batch 40/49, Batch Loss: 56240.1914
# Epoch 162, Batch 41/49, Batch Loss: 86497.2109
# Epoch 162, Batch 42/49, Batch Loss: 50401.9062
# Epoch 162, Batch 43/49, Batch Loss: 74819.9062
# Epoch 162, Batch 44/49, Batch Loss: 54140.8594
# Epoch 162, Batch 45/49, Batch Loss: 59945.9180
# Epoch 162, Batch 46/49, Batch Loss: 87388.9453
# Epoch 162, Batch 47/49, Batch Loss: 63948.4570
# Epoch 162, Batch 48/49, Batch Loss: 41998.1172
# Epoch 162, Batch 49/49, Batch Loss: 81505.8281
# Batch 1/17, Batch Loss: 217085.0000
# Batch 2/17, Batch Loss: 175046.4844
# Batch 3/17, Batch Loss: 161370.2031
# Batch 4/17, Batch Loss: 117901.7578
# Batch 5/17, Batch Loss: 173160.1562
# Batch 6/17, Batch Loss: 103025.5234
# Batch 7/17, Batch Loss: 81737.4219
# Batch 8/17, Batch Loss: 131065.2734
# Batch 9/17, Batch Loss: 73552.6094
# Batch 10/17, Batch Loss: 78319.2266
# Batch 11/17, Batch Loss: 127056.4922
# Batch 12/17, Batch Loss: 271360.8750
# Batch 13/17, Batch Loss: 100973.8828
# Batch 14/17, Batch Loss: 222617.5156
# Batch 15/17, Batch Loss: 169953.3906
# Batch 16/17, Batch Loss: 124960.1641
# Batch 17/17, Batch Loss: 122123.1953
# Test Error:
#  Avg loss: 144194.657169, Avg error: 83897.601211
#
# Epoch 163, Batch 1/49, Batch Loss: 57829.1875
# Epoch 163, Batch 2/49, Batch Loss: 58364.5117
# Epoch 163, Batch 3/49, Batch Loss: 53383.4062
# Epoch 163, Batch 4/49, Batch Loss: 51098.9414
# Epoch 163, Batch 5/49, Batch Loss: 56123.0781
# Epoch 163, Batch 6/49, Batch Loss: 85037.2969
# Epoch 163, Batch 7/49, Batch Loss: 52016.3398
# Epoch 163, Batch 8/49, Batch Loss: 56917.2461
# Epoch 163, Batch 9/49, Batch Loss: 64198.5156
# Epoch 163, Batch 10/49, Batch Loss: 67644.4922
# Epoch 163, Batch 11/49, Batch Loss: 56300.6758
# Epoch 163, Batch 12/49, Batch Loss: 60672.1719
# Epoch 163, Batch 13/49, Batch Loss: 99898.6406
# Epoch 163, Batch 14/49, Batch Loss: 82352.4375
# Epoch 163, Batch 15/49, Batch Loss: 70476.6094
# Epoch 163, Batch 16/49, Batch Loss: 66849.1094
# Epoch 163, Batch 17/49, Batch Loss: 95603.1094
# Epoch 163, Batch 18/49, Batch Loss: 83082.9141
# Epoch 163, Batch 19/49, Batch Loss: 48479.5703
# Epoch 163, Batch 20/49, Batch Loss: 48554.6914
# Epoch 163, Batch 21/49, Batch Loss: 70090.6641
# Epoch 163, Batch 22/49, Batch Loss: 54168.2266
# Epoch 163, Batch 23/49, Batch Loss: 66262.2109
# Epoch 163, Batch 24/49, Batch Loss: 53909.0000
# Epoch 163, Batch 25/49, Batch Loss: 49192.2461
# Epoch 163, Batch 26/49, Batch Loss: 54969.2344
# Epoch 163, Batch 27/49, Batch Loss: 111951.3438
# Epoch 163, Batch 28/49, Batch Loss: 59828.5703
# Epoch 163, Batch 29/49, Batch Loss: 47656.2734
# Epoch 163, Batch 30/49, Batch Loss: 60590.3711
# Epoch 163, Batch 31/49, Batch Loss: 59424.4844
# Epoch 163, Batch 32/49, Batch Loss: 63344.2461
# Epoch 163, Batch 33/49, Batch Loss: 56660.0625
# Epoch 163, Batch 34/49, Batch Loss: 51500.1602
# Epoch 163, Batch 35/49, Batch Loss: 65290.8320
# Epoch 163, Batch 36/49, Batch Loss: 62856.7031
# Epoch 163, Batch 37/49, Batch Loss: 70543.3984
# Epoch 163, Batch 38/49, Batch Loss: 68035.5938
# Epoch 163, Batch 39/49, Batch Loss: 68560.6562
# Epoch 163, Batch 40/49, Batch Loss: 62126.0117
# Epoch 163, Batch 41/49, Batch Loss: 34064.5977
# Epoch 163, Batch 42/49, Batch Loss: 56213.0117
# Epoch 163, Batch 43/49, Batch Loss: 72194.7344
# Epoch 163, Batch 44/49, Batch Loss: 55432.9180
# Epoch 163, Batch 45/49, Batch Loss: 51121.7500
# Epoch 163, Batch 46/49, Batch Loss: 65678.1719
# Epoch 163, Batch 47/49, Batch Loss: 61427.2656
# Epoch 163, Batch 48/49, Batch Loss: 88636.8438
# Epoch 163, Batch 49/49, Batch Loss: 80968.3828
# Batch 1/17, Batch Loss: 227515.0469
# Batch 2/17, Batch Loss: 199682.7500
# Batch 3/17, Batch Loss: 156445.5938
# Batch 4/17, Batch Loss: 189526.6875
# Batch 5/17, Batch Loss: 218322.1875
# Batch 6/17, Batch Loss: 89213.9219
# Batch 7/17, Batch Loss: 146976.0469
# Batch 8/17, Batch Loss: 94897.8125
# Batch 9/17, Batch Loss: 158653.5781
# Batch 10/17, Batch Loss: 79687.4844
# Batch 11/17, Batch Loss: 146153.0781
# Batch 12/17, Batch Loss: 280463.4688
# Batch 13/17, Batch Loss: 104600.3281
# Batch 14/17, Batch Loss: 144090.0938
# Batch 15/17, Batch Loss: 156079.4531
# Batch 16/17, Batch Loss: 113691.0312
# Batch 17/17, Batch Loss: 172163.9688
# Test Error:
#  Avg loss: 157538.972426, Avg error: 88173.991133
#
# Epoch 164, Batch 1/49, Batch Loss: 60334.8438
# Epoch 164, Batch 2/49, Batch Loss: 52837.2773
# Epoch 164, Batch 3/49, Batch Loss: 64910.0039
# Epoch 164, Batch 4/49, Batch Loss: 70099.9766
# Epoch 164, Batch 5/49, Batch Loss: 53190.3789
# Epoch 164, Batch 6/49, Batch Loss: 81907.2891
# Epoch 164, Batch 7/49, Batch Loss: 54370.2812
# Epoch 164, Batch 8/49, Batch Loss: 68605.4297
# Epoch 164, Batch 9/49, Batch Loss: 68490.2188
# Epoch 164, Batch 10/49, Batch Loss: 62985.7773
# Epoch 164, Batch 11/49, Batch Loss: 62394.8359
# Epoch 164, Batch 12/49, Batch Loss: 64843.2891
# Epoch 164, Batch 13/49, Batch Loss: 77057.7109
# Epoch 164, Batch 14/49, Batch Loss: 54095.3867
# Epoch 164, Batch 15/49, Batch Loss: 73226.1797
# Epoch 164, Batch 16/49, Batch Loss: 46472.7461
# Epoch 164, Batch 17/49, Batch Loss: 66416.1328
# Epoch 164, Batch 18/49, Batch Loss: 107086.2109
# Epoch 164, Batch 19/49, Batch Loss: 77906.9688
# Epoch 164, Batch 20/49, Batch Loss: 47458.3789
# Epoch 164, Batch 21/49, Batch Loss: 94184.1797
# Epoch 164, Batch 22/49, Batch Loss: 59410.9258
# Epoch 164, Batch 23/49, Batch Loss: 87882.1016
# Epoch 164, Batch 24/49, Batch Loss: 111488.6875
# Epoch 164, Batch 25/49, Batch Loss: 48541.0508
# Epoch 164, Batch 26/49, Batch Loss: 59948.2109
# Epoch 164, Batch 27/49, Batch Loss: 74754.6953
# Epoch 164, Batch 28/49, Batch Loss: 66387.3906
# Epoch 164, Batch 29/49, Batch Loss: 76690.5859
# Epoch 164, Batch 30/49, Batch Loss: 71970.8438
# Epoch 164, Batch 31/49, Batch Loss: 71983.0156
# Epoch 164, Batch 32/49, Batch Loss: 62407.5039
# Epoch 164, Batch 33/49, Batch Loss: 45229.7695
# Epoch 164, Batch 34/49, Batch Loss: 98652.5078
# Epoch 164, Batch 35/49, Batch Loss: 60032.0586
# Epoch 164, Batch 36/49, Batch Loss: 45035.3789
# Epoch 164, Batch 37/49, Batch Loss: 82224.7188
# Epoch 164, Batch 38/49, Batch Loss: 48175.5234
# Epoch 164, Batch 39/49, Batch Loss: 77104.2109
# Epoch 164, Batch 40/49, Batch Loss: 70219.1719
# Epoch 164, Batch 41/49, Batch Loss: 71354.2422
# Epoch 164, Batch 42/49, Batch Loss: 60613.0859
# Epoch 164, Batch 43/49, Batch Loss: 59377.2852
# Epoch 164, Batch 44/49, Batch Loss: 61639.6797
# Epoch 164, Batch 45/49, Batch Loss: 41590.8125
# Epoch 164, Batch 46/49, Batch Loss: 98783.4922
# Epoch 164, Batch 47/49, Batch Loss: 108539.2812
# Epoch 164, Batch 48/49, Batch Loss: 54056.3516
# Epoch 164, Batch 49/49, Batch Loss: 53842.2930
# Batch 1/17, Batch Loss: 233041.1250
# Batch 2/17, Batch Loss: 248697.0781
# Batch 3/17, Batch Loss: 159837.0156
# Batch 4/17, Batch Loss: 119458.9453
# Batch 5/17, Batch Loss: 266380.2812
# Batch 6/17, Batch Loss: 106950.8906
# Batch 7/17, Batch Loss: 165581.8906
# Batch 8/17, Batch Loss: 148390.0312
# Batch 9/17, Batch Loss: 135950.7812
# Batch 10/17, Batch Loss: 93082.5625
# Batch 11/17, Batch Loss: 156029.8594
# Batch 12/17, Batch Loss: 256069.0156
# Batch 13/17, Batch Loss: 106975.7344
# Batch 14/17, Batch Loss: 191969.5625
# Batch 15/17, Batch Loss: 168184.3438
# Batch 16/17, Batch Loss: 127523.8359
# Batch 17/17, Batch Loss: 142864.7500
# Test Error:
#  Avg loss: 166293.394301, Avg error: 106120.101211
#
# Epoch 165, Batch 1/49, Batch Loss: 81047.2344
# Epoch 165, Batch 2/49, Batch Loss: 94474.4766
# Epoch 165, Batch 3/49, Batch Loss: 81150.8828
# Epoch 165, Batch 4/49, Batch Loss: 116183.7656
# Epoch 165, Batch 5/49, Batch Loss: 73049.1641
# Epoch 165, Batch 6/49, Batch Loss: 65207.0859
# Epoch 165, Batch 7/49, Batch Loss: 68091.0938
# Epoch 165, Batch 8/49, Batch Loss: 76686.4688
# Epoch 165, Batch 9/49, Batch Loss: 61906.2266
# Epoch 165, Batch 10/49, Batch Loss: 68851.5938
# Epoch 165, Batch 11/49, Batch Loss: 57494.2383
# Epoch 165, Batch 12/49, Batch Loss: 64782.8789
# Epoch 165, Batch 13/49, Batch Loss: 67317.2109
# Epoch 165, Batch 14/49, Batch Loss: 103892.7812
# Epoch 165, Batch 15/49, Batch Loss: 50163.3555
# Epoch 165, Batch 16/49, Batch Loss: 49038.5781
# Epoch 165, Batch 17/49, Batch Loss: 89391.5391
# Epoch 165, Batch 18/49, Batch Loss: 74429.3281
# Epoch 165, Batch 19/49, Batch Loss: 86201.7891
# Epoch 165, Batch 20/49, Batch Loss: 76350.9766
# Epoch 165, Batch 21/49, Batch Loss: 59799.9414
# Epoch 165, Batch 22/49, Batch Loss: 67771.3828
# Epoch 165, Batch 23/49, Batch Loss: 84270.8750
# Epoch 165, Batch 24/49, Batch Loss: 63983.1016
# Epoch 165, Batch 25/49, Batch Loss: 62598.6562
# Epoch 165, Batch 26/49, Batch Loss: 54982.7734
# Epoch 165, Batch 27/49, Batch Loss: 72217.3438
# Epoch 165, Batch 28/49, Batch Loss: 69232.2188
# Epoch 165, Batch 29/49, Batch Loss: 45151.6797
# Epoch 165, Batch 30/49, Batch Loss: 73427.1719
# Epoch 165, Batch 31/49, Batch Loss: 62048.2852
# Epoch 165, Batch 32/49, Batch Loss: 62141.5781
# Epoch 165, Batch 33/49, Batch Loss: 55861.5820
# Epoch 165, Batch 34/49, Batch Loss: 53996.8516
# Epoch 165, Batch 35/49, Batch Loss: 58410.6953
# Epoch 165, Batch 36/49, Batch Loss: 70812.3984
# Epoch 165, Batch 37/49, Batch Loss: 57389.7852
# Epoch 165, Batch 38/49, Batch Loss: 50973.3555
# Epoch 165, Batch 39/49, Batch Loss: 90561.5469
# Epoch 165, Batch 40/49, Batch Loss: 50751.6523
# Epoch 165, Batch 41/49, Batch Loss: 42634.6094
# Epoch 165, Batch 42/49, Batch Loss: 94487.1094
# Epoch 165, Batch 43/49, Batch Loss: 66901.6641
# Epoch 165, Batch 44/49, Batch Loss: 63879.8359
# Epoch 165, Batch 45/49, Batch Loss: 55644.7852
# Epoch 165, Batch 46/49, Batch Loss: 74062.6953
# Epoch 165, Batch 47/49, Batch Loss: 62969.3086
# Epoch 165, Batch 48/49, Batch Loss: 49942.5977
# Epoch 165, Batch 49/49, Batch Loss: 60919.1797
# Batch 1/17, Batch Loss: 220045.9531
# Batch 2/17, Batch Loss: 183584.8281
# Batch 3/17, Batch Loss: 171335.4219
# Batch 4/17, Batch Loss: 167843.1250
# Batch 5/17, Batch Loss: 1348480.1250
# Batch 6/17, Batch Loss: 131288.5469
# Batch 7/17, Batch Loss: 145351.9531
# Batch 8/17, Batch Loss: 119709.2812
# Batch 9/17, Batch Loss: 145680.9688
# Batch 10/17, Batch Loss: 49065.0859
# Batch 11/17, Batch Loss: 132121.3906
# Batch 12/17, Batch Loss: 235138.2656
# Batch 13/17, Batch Loss: 38430.7617
# Batch 14/17, Batch Loss: 154948.1875
# Batch 15/17, Batch Loss: 163593.5469
# Batch 16/17, Batch Loss: 109860.9141
# Batch 17/17, Batch Loss: 183458.3906
# Test Error:
#  Avg loss: 217643.338006, Avg error: 104390.338452

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Probar modelo

# %%
# Importar dataset
test = pd.read_csv(f'{ruta}test.csv')
test.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        2.5         3  1915    92021      117.png   485000
# 1        2.5         3  2248    92677      132.png  1199000
# 2        1.0         3  1132    96019      154.png   170000
# 3        4.0         6  3375    92880      245.png   538000
# 4        2.5         3  2733    91901       84.png   689000

# %%
len(test)
# Out:
# 54

# %%
# Crear dataset
test_data = CustomImageDataset(df=test)

# %%
# Crear dataloader
test_loader = DataLoader(test_data, batch_size=9, shuffle=False)

# %%
len(test_loader)
# Out:
# 6

# %%
# Predecir precios de casa

def predict(model, test_loader, device):
    model.eval()  # Poner el modelo en modo evaluación
    predictions = []
    actuals = []

    with torch.no_grad():  # Deshabilitar el cálculo de gradientes
        for batch_idx, (imgs, numeric_features, target) in enumerate(test_loader):
            # Mover los datos a la GPU si está disponible
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            target = target.to(device)

            # Forward pass: obtener las predicciones
            output = model(imgs, numeric_features)

            # Almacenar las predicciones y los valores reales (en CPU para facilidad)
            predictions.append(output.cpu().numpy())
            actuals.append(target.cpu().numpy())

    # Convertir las listas de predicciones y reales en arrays de NumPy
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)

    return predictions, actuals

# %%
# Llamar a la función de predicción
predictions, actuals = predict(model, test_loader, device)

# Mostrar algunas predicciones junto con los valores reales
for i in range(10):  # Mostrar los primeros 10 ejemplos
    print(f"Predicción: {predictions[i]}, Valor real: {actuals[i]}")
# Out:
# Predicción: 331528.125, Valor real: 485000.0
# Predicción: 431564.46875, Valor real: 1199000.0
# Predicción: 261727.875, Valor real: 170000.0
# Predicción: 500365.5625, Valor real: 538000.0
# Predicción: 480437.9375, Valor real: 689000.0
# Predicción: 232088.8125, Valor real: 118900.0
# Predicción: 470344.5625, Valor real: 799000.0
# Predicción: 599149.75, Valor real: 895000.0
# Predicción: 451134.8125, Valor real: 599000.0
# Predicción: 270431.5625, Valor real: 535000.0

# %%
# Evaluacion

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calcular RMSE
rmse = np.sqrt(mean_squared_error(actuals, predictions))
print(f"RMSE en el conjunto de prueba: {rmse:.4f}")

# Calcular MAE
mae = mean_absolute_error(actuals, predictions)
print(f"MAE en el conjunto de prueba: {mae:.4f}")
# Out:
# RMSE en el conjunto de prueba: 343795.0938
# MAE en el conjunto de prueba: 223937.0156

# %%
import matplotlib.pyplot as plt

# Graficar las predicciones vs los valores reales
plt.figure(figsize=(8, 6))
plt.scatter(actuals, predictions, alpha=0.5)
plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'r--')  # Línea de igualdad (predicción = realidad)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales en el conjunto de prueba')
plt.show()
