# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Dataset/Mosaico'

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Lectura de dataset train y test

# %%
# --> Desde local
train = pd.read_csv('../Dataset/Mosaico/train.csv')
test = pd.read_csv('../Dataset/Mosaico/test.csv')

# --> Desde google
# train = pd.read_csv('/content/drive/MyDrive/Dataset/Dataset/Mosaico/train.csv')
# test = pd.read_csv('/content/drive/MyDrive/Dataset/Dataset/Mosaico/test.csv')

train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image    price
# 0        5.0         5  3816    92880      284.png   589900
# 1        2.0         2  1440    92276      347.png   106000
# 2        3.0         4  1625    93510      440.png   639000
# 3        3.0         4  2454    93510      421.png  5858000
# 4        4.5         4  4038    92677      149.png  1795000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bathrooms     428 non-null    float64
#  1   bedrooms      428 non-null    int64
#  2   area          428 non-null    int64
#  3   zipcode       428 non-null    int64
#  4   mosaic_image  428 non-null    object
#  5   price         428 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 20.2+ KB

# %% [markdown]
# ## Preparar Dataset

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        # mosaic_image = read_image(f"/content/drive/MyDrive/Dataset/Dataset/Mosaico/Imagenes/{img_path}").float()
        # Alternativamente, puedes leer la imagen desde otra ruta local.
        mosaic_image = read_image(f"../Dataset/Mosaico/Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %% [markdown]
# ## Aumentar datos

# %%
data1 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Resize(224),                             # Asegura que todas las imágenes sean de 224x224 (si es necesario)
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

data2 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Resize(224),
    # transforms.ColorJitter(
    #     brightness=0.3, contrast=0.3, saturation=0.3              # Ajustes moderados de color
    # ),
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),    # Aplicar desenfoque gaussiano
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),
        (85.9875, 82.3628, 80.8718)
    )
]))

# data3 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(224),
#     # transforms.ColorJitter(
#     #     brightness=0.4, contrast=0.4, saturation=0.4    # Un poco más de variabilidad en los colores
#     # ),
#     transforms.Normalize(
#         (58.0583, 55.1679, 52.9831),
#         (85.9875, 82.3628, 80.8718)
#     )
# ]))

# data4 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(224),
#     # transforms.ColorJitter(
#     #     brightness=0.2, contrast=0.2, saturation=0.2    # Ajustes más conservadores
#     # ),
#     transforms.Normalize(
#         (58.0583, 55.1679, 52.9831),
#         (85.9875, 82.3628, 80.8718)
#     )
# ]))

# data5 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(224),
#     transforms.Normalize(
#         (58.0583, 55.1679, 52.9831),
#         (85.9875, 82.3628, 80.8718)
#     )
# ]))

# data6 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(224),
#     transforms.Normalize(
#         (58.0583, 55.1679, 52.9831),
#         (85.9875, 82.3628, 80.8718)
#     )
# ]))

# data7 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(224),
#     # transforms.ColorJitter(
#     #     brightness=0.3, contrast=0.3, saturation=0.3    # Variabilidad en el color, pero sin exagerar
#     # ),
#     transforms.Normalize(
#         (58.0583, 55.1679, 52.9831),
#         (85.9875, 82.3628, 80.8718)
#     )
# ]))

# %% [markdown]
# ## Ver imagenes de cada data

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1)  # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)    # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None):
    # Deshacer la normalización
    image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))
    
    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))  # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')  # Quitar los ejes
    plt.show()

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1, data2]
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]
    
    # Mostrar la imagen
    show_image(image, title=f"Imagen de data{i}")

# %% [markdown]
# ## Dividir en train y test

# %%
# Crear un conjunto de datos combinado
conjunto_datos = ConcatDataset((data1,data2))

# %%
# Determinar el tamaño de los conjuntos de entrenamiento y validación
valor_train = int(0.8*len(conjunto_datos))
valor_val = len(conjunto_datos)-valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 684 Val: 172

# %%
# Dividir el conjunto de datos en conjuntos de entrenamiento y validación

train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2)),[valor_train,valor_val])

# del data1,data2,data3,data4,data5,data6,data7
del data1,data2

# %%
# Crear los dataloaders

batch_size=64
train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Red neuronal

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=5, stride=2, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(),

            # nn.Conv2d(128, 256, kernel_size=5, padding=2),
            # nn.ReLU(inplace=True),
            # nn.MaxPool2d(kernel_size=3, stride=2),
            # nn.Dropout(),

            nn.Conv2d(128, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(128, 64, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            # nn.Linear(64*3*3*2, 64*3*3*2*2),
            nn.Linear(3264, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        x=x.view(-1, 64*7*6)
        y=self.numeric_features_(y)
        z=torch.cat((x,y),1)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
# Definir el dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))

# Definir el modelo, la función de pérdida y el optimizador
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)
optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Using cpu device

# %% [markdown]
# ## Ciclos de entrenamiento y pruebas

# %%
def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader):
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            l2_lambda = 0.001
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Entrenamiento

# %%
# Entrenamiento
n_epochs = 200
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader
)
# Out:
# Epoch 1, Batch 1/11, Batch Loss: 665599.6875
# Epoch 1, Batch 2/11, Batch Loss: 605665.0625
# Epoch 1, Batch 3/11, Batch Loss: 717118.1250
# Epoch 1, Batch 4/11, Batch Loss: 642754.9375
# Epoch 1, Batch 5/11, Batch Loss: 861971.0000
# Epoch 1, Batch 6/11, Batch Loss: 1028177.5625
# Epoch 1, Batch 7/11, Batch Loss: 672048.4375
# Epoch 1, Batch 8/11, Batch Loss: 539943.2500
# Epoch 1, Batch 9/11, Batch Loss: 863119.3750
# Epoch 1, Batch 10/11, Batch Loss: 488308.9688
# Epoch 1, Batch 11/11, Batch Loss: 412696.0312
# Batch 1/3, Batch Loss: 663682.1875
# Batch 2/3, Batch Loss: 832939.6250
# Batch 3/3, Batch Loss: 480686.8125
# Test Error:
#  Avg loss: 659102.875000, Avg error: 402546.901163
#
# 2024-09-14 20:44:48.865982 Epoch 1, Average Training loss 681582.0397727273
# Epoch 2, Batch 1/11, Batch Loss: 805100.0625
# Epoch 2, Batch 2/11, Batch Loss: 353388.7500
# Epoch 2, Batch 3/11, Batch Loss: 431012.5938
# Epoch 2, Batch 4/11, Batch Loss: 333545.7812
# Epoch 2, Batch 5/11, Batch Loss: 809462.5625
# Epoch 2, Batch 6/11, Batch Loss: 432906.3125
# Epoch 2, Batch 7/11, Batch Loss: 442831.3125
# Epoch 2, Batch 8/11, Batch Loss: 504736.5625
# Epoch 2, Batch 9/11, Batch Loss: 429523.9688
# Epoch 2, Batch 10/11, Batch Loss: 566232.8750
# Epoch 2, Batch 11/11, Batch Loss: 434149.6562
# Batch 1/3, Batch Loss: 649072.2500
# Batch 2/3, Batch Loss: 905887.2500
# Batch 3/3, Batch Loss: 424388.9062
# Test Error:
#  Avg loss: 659782.802083, Avg error: 418359.296512
#
# Epoch 3, Batch 1/11, Batch Loss: 399720.5312
# Epoch 3, Batch 2/11, Batch Loss: 379234.6250
# Epoch 3, Batch 3/11, Batch Loss: 427079.2812
# Epoch 3, Batch 4/11, Batch Loss: 781728.6875
# Epoch 3, Batch 5/11, Batch Loss: 370047.9688
# Epoch 3, Batch 6/11, Batch Loss: 417712.1250
# Epoch 3, Batch 7/11, Batch Loss: 453015.4375
# Epoch 3, Batch 8/11, Batch Loss: 435274.1875
# Epoch 3, Batch 9/11, Batch Loss: 327064.4375
# Epoch 3, Batch 10/11, Batch Loss: 941755.8125
# Epoch 3, Batch 11/11, Batch Loss: 412707.3438
# Batch 1/3, Batch Loss: 682661.8125
# Batch 2/3, Batch Loss: 832592.3125
# Batch 3/3, Batch Loss: 591943.8125
# Test Error:
#  Avg loss: 702399.312500, Avg error: 426916.604651
#
# Epoch 4, Batch 1/11, Batch Loss: 802409.5625
# Epoch 4, Batch 2/11, Batch Loss: 355887.8438
# Epoch 4, Batch 3/11, Batch Loss: 496895.7812
# Epoch 4, Batch 4/11, Batch Loss: 741861.7500
# Epoch 4, Batch 5/11, Batch Loss: 430428.6562
# Epoch 4, Batch 6/11, Batch Loss: 455417.0000
# Epoch 4, Batch 7/11, Batch Loss: 590164.5625
# Epoch 4, Batch 8/11, Batch Loss: 377318.3438
# Epoch 4, Batch 9/11, Batch Loss: 503921.8125
# Epoch 4, Batch 10/11, Batch Loss: 411910.8438
# Epoch 4, Batch 11/11, Batch Loss: 410223.8750
# Batch 1/3, Batch Loss: 743231.6250
# Batch 2/3, Batch Loss: 755229.0625
# Batch 3/3, Batch Loss: 516997.9375
# Test Error:
#  Avg loss: 671819.541667, Avg error: 404076.139535
#
# Epoch 5, Batch 1/11, Batch Loss: 471620.1562
# Epoch 5, Batch 2/11, Batch Loss: 374719.1250
# Epoch 5, Batch 3/11, Batch Loss: 370945.6875
# Epoch 5, Batch 4/11, Batch Loss: 366762.4688
# Epoch 5, Batch 5/11, Batch Loss: 875949.7500
# Epoch 5, Batch 6/11, Batch Loss: 306940.9688
# Epoch 5, Batch 7/11, Batch Loss: 383629.5938
# Epoch 5, Batch 8/11, Batch Loss: 779974.6875
# Epoch 5, Batch 9/11, Batch Loss: 461159.7500
# Epoch 5, Batch 10/11, Batch Loss: 464116.5625
# Epoch 5, Batch 11/11, Batch Loss: 497186.4375
# Batch 1/3, Batch Loss: 858619.0625
# Batch 2/3, Batch Loss: 475836.5312
# Batch 3/3, Batch Loss: 405459.3125
# Test Error:
#  Avg loss: 579971.635417, Avg error: 361445.127907
#
# Epoch 6, Batch 1/11, Batch Loss: 430539.1250
# Epoch 6, Batch 2/11, Batch Loss: 479307.9062
# Epoch 6, Batch 3/11, Batch Loss: 425761.7812
# Epoch 6, Batch 4/11, Batch Loss: 591137.6250
# Epoch 6, Batch 5/11, Batch Loss: 771946.1875
# Epoch 6, Batch 6/11, Batch Loss: 406246.7500
# Epoch 6, Batch 7/11, Batch Loss: 477094.4062
# Epoch 6, Batch 8/11, Batch Loss: 363434.3750
# Epoch 6, Batch 9/11, Batch Loss: 780302.1250
# Epoch 6, Batch 10/11, Batch Loss: 328388.7188
# Epoch 6, Batch 11/11, Batch Loss: 368161.8750
# Batch 1/3, Batch Loss: 647503.1875
# Batch 2/3, Batch Loss: 771090.4375
# Batch 3/3, Batch Loss: 387992.8438
# Test Error:
#  Avg loss: 602195.489583, Avg error: 360988.773256
#
# Epoch 7, Batch 1/11, Batch Loss: 772502.8125
# Epoch 7, Batch 2/11, Batch Loss: 419997.0000
# Epoch 7, Batch 3/11, Batch Loss: 407260.0625
# Epoch 7, Batch 4/11, Batch Loss: 284453.7188
# Epoch 7, Batch 5/11, Batch Loss: 357415.8438
# Epoch 7, Batch 6/11, Batch Loss: 380418.8125
# Epoch 7, Batch 7/11, Batch Loss: 425286.1250
# Epoch 7, Batch 8/11, Batch Loss: 561136.7500
# Epoch 7, Batch 9/11, Batch Loss: 314541.8750
# Epoch 7, Batch 10/11, Batch Loss: 775629.8750
# Epoch 7, Batch 11/11, Batch Loss: 420480.4062
# Batch 1/3, Batch Loss: 580538.2500
# Batch 2/3, Batch Loss: 580587.6250
# Batch 3/3, Batch Loss: 723854.5000
# Test Error:
#  Avg loss: 628326.791667, Avg error: 346001.348837
#
# Epoch 8, Batch 1/11, Batch Loss: 558965.5625
# Epoch 8, Batch 2/11, Batch Loss: 774359.6875
# Epoch 8, Batch 3/11, Batch Loss: 311932.1250
# Epoch 8, Batch 4/11, Batch Loss: 356666.8438
# Epoch 8, Batch 5/11, Batch Loss: 396551.1562
# Epoch 8, Batch 6/11, Batch Loss: 268932.5625
# Epoch 8, Batch 7/11, Batch Loss: 747554.1875
# Epoch 8, Batch 8/11, Batch Loss: 437912.5625
# Epoch 8, Batch 9/11, Batch Loss: 326034.8125
# Epoch 8, Batch 10/11, Batch Loss: 392932.7812
# Epoch 8, Batch 11/11, Batch Loss: 335767.4688
# Batch 1/3, Batch Loss: 558758.1250
# Batch 2/3, Batch Loss: 566508.5625
# Batch 3/3, Batch Loss: 705299.1875
# Test Error:
#  Avg loss: 610188.625000, Avg error: 332654.651163
#
# Epoch 9, Batch 1/11, Batch Loss: 305111.9375
# Epoch 9, Batch 2/11, Batch Loss: 461661.3750
# Epoch 9, Batch 3/11, Batch Loss: 737965.8125
# Epoch 9, Batch 4/11, Batch Loss: 353307.3750
# Epoch 9, Batch 5/11, Batch Loss: 430003.5625
# Epoch 9, Batch 6/11, Batch Loss: 773786.1250
# Epoch 9, Batch 7/11, Batch Loss: 334518.5625
# Epoch 9, Batch 8/11, Batch Loss: 324002.7812
# Epoch 9, Batch 9/11, Batch Loss: 463096.6562
# Epoch 9, Batch 10/11, Batch Loss: 335459.4375
# Epoch 9, Batch 11/11, Batch Loss: 329770.6875
# Batch 1/3, Batch Loss: 535056.9375
# Batch 2/3, Batch Loss: 577831.1875
# Batch 3/3, Batch Loss: 633569.1250
# Test Error:
#  Avg loss: 582152.416667, Avg error: 318780.558140
#
# Epoch 10, Batch 1/11, Batch Loss: 368054.2812
# Epoch 10, Batch 2/11, Batch Loss: 546676.0625
# Epoch 10, Batch 3/11, Batch Loss: 346560.3750
# Epoch 10, Batch 4/11, Batch Loss: 321065.9062
# Epoch 10, Batch 5/11, Batch Loss: 763420.6250
# Epoch 10, Batch 6/11, Batch Loss: 345815.9062
# Epoch 10, Batch 7/11, Batch Loss: 356774.2188
# Epoch 10, Batch 8/11, Batch Loss: 418766.2188
# Epoch 10, Batch 9/11, Batch Loss: 383776.8125
# Epoch 10, Batch 10/11, Batch Loss: 734178.5625
# Epoch 10, Batch 11/11, Batch Loss: 281803.1562
# Batch 1/3, Batch Loss: 524179.4375
# Batch 2/3, Batch Loss: 490574.6250
# Batch 3/3, Batch Loss: 630826.1875
# Test Error:
#  Avg loss: 548526.750000, Avg error: 293492.534884
#
# 2024-09-14 20:48:34.164076 Epoch 10, Average Training loss 442444.73863636365
# Epoch 11, Batch 1/11, Batch Loss: 285663.4375
# Epoch 11, Batch 2/11, Batch Loss: 393595.6562
# Epoch 11, Batch 3/11, Batch Loss: 356240.9688
# Epoch 11, Batch 4/11, Batch Loss: 331243.3750
# Epoch 11, Batch 5/11, Batch Loss: 391870.5625
# Epoch 11, Batch 6/11, Batch Loss: 511688.0312
# Epoch 11, Batch 7/11, Batch Loss: 728806.3125
# Epoch 11, Batch 8/11, Batch Loss: 728972.9375
# Epoch 11, Batch 9/11, Batch Loss: 431906.9062
# Epoch 11, Batch 10/11, Batch Loss: 337265.1875
# Epoch 11, Batch 11/11, Batch Loss: 423993.1875
# Batch 1/3, Batch Loss: 391646.3438
# Batch 2/3, Batch Loss: 675481.8750
# Batch 3/3, Batch Loss: 754528.3125
# Test Error:
#  Avg loss: 607218.843750, Avg error: 352075.779070
#
# Epoch 12, Batch 1/11, Batch Loss: 386847.2500
# Epoch 12, Batch 2/11, Batch Loss: 459620.0625
# Epoch 12, Batch 3/11, Batch Loss: 410495.3750
# Epoch 12, Batch 4/11, Batch Loss: 332649.7812
# Epoch 12, Batch 5/11, Batch Loss: 451975.6562
# Epoch 12, Batch 6/11, Batch Loss: 417246.2500
# Epoch 12, Batch 7/11, Batch Loss: 987618.1250
# Epoch 12, Batch 8/11, Batch Loss: 419357.9375
# Epoch 12, Batch 9/11, Batch Loss: 439333.1875
# Epoch 12, Batch 10/11, Batch Loss: 323904.0938
# Epoch 12, Batch 11/11, Batch Loss: 347228.8750
# Batch 1/3, Batch Loss: 420795.0000
# Batch 2/3, Batch Loss: 611977.0000
# Batch 3/3, Batch Loss: 629227.3125
# Test Error:
#  Avg loss: 553999.770833, Avg error: 305255.063953
#
# Epoch 13, Batch 1/11, Batch Loss: 731423.5625
# Epoch 13, Batch 2/11, Batch Loss: 325532.4375
# Epoch 13, Batch 3/11, Batch Loss: 350297.8125
# Epoch 13, Batch 4/11, Batch Loss: 461741.7812
# Epoch 13, Batch 5/11, Batch Loss: 440583.1250
# Epoch 13, Batch 6/11, Batch Loss: 770846.6875
# Epoch 13, Batch 7/11, Batch Loss: 319194.7188
# Epoch 13, Batch 8/11, Batch Loss: 351869.2500
# Epoch 13, Batch 9/11, Batch Loss: 325294.4062
# Epoch 13, Batch 10/11, Batch Loss: 404520.0312
# Epoch 13, Batch 11/11, Batch Loss: 382177.3125
# Batch 1/3, Batch Loss: 318999.9688
# Batch 2/3, Batch Loss: 584401.2500
# Batch 3/3, Batch Loss: 628035.5625
# Test Error:
#  Avg loss: 510478.927083, Avg error: 271454.755814
#
# Epoch 14, Batch 1/11, Batch Loss: 704356.5625
# Epoch 14, Batch 2/11, Batch Loss: 303089.2500
# Epoch 14, Batch 3/11, Batch Loss: 717617.5000
# Epoch 14, Batch 4/11, Batch Loss: 299405.2812
# Epoch 14, Batch 5/11, Batch Loss: 266739.5938
# Epoch 14, Batch 6/11, Batch Loss: 397616.5625
# Epoch 14, Batch 7/11, Batch Loss: 500269.5000
# Epoch 14, Batch 8/11, Batch Loss: 351529.2188
# Epoch 14, Batch 9/11, Batch Loss: 418324.2500
# Epoch 14, Batch 10/11, Batch Loss: 281870.5625
# Epoch 14, Batch 11/11, Batch Loss: 314323.6250
# Batch 1/3, Batch Loss: 414244.3125
# Batch 2/3, Batch Loss: 668854.3125
# Batch 3/3, Batch Loss: 537787.8125
# Test Error:
#  Avg loss: 540295.479167, Avg error: 295553.151163
#
# Epoch 15, Batch 1/11, Batch Loss: 336546.0312
# Epoch 15, Batch 2/11, Batch Loss: 325206.7812
# Epoch 15, Batch 3/11, Batch Loss: 435573.7188
# Epoch 15, Batch 4/11, Batch Loss: 344807.4688
# Epoch 15, Batch 5/11, Batch Loss: 301945.8750
# Epoch 15, Batch 6/11, Batch Loss: 299223.1875
# Epoch 15, Batch 7/11, Batch Loss: 429804.6875
# Epoch 15, Batch 8/11, Batch Loss: 362743.4375
# Epoch 15, Batch 9/11, Batch Loss: 314070.2500
# Epoch 15, Batch 10/11, Batch Loss: 340870.0000
# Epoch 15, Batch 11/11, Batch Loss: 1181116.3750
# Batch 1/3, Batch Loss: 564851.6875
# Batch 2/3, Batch Loss: 619925.8750
# Batch 3/3, Batch Loss: 251580.7969
# Test Error:
#  Avg loss: 478786.119792, Avg error: 271082.220930
#
# Epoch 16, Batch 1/11, Batch Loss: 247033.7344
# Epoch 16, Batch 2/11, Batch Loss: 726475.4375
# Epoch 16, Batch 3/11, Batch Loss: 735683.8125
# Epoch 16, Batch 4/11, Batch Loss: 390786.8125
# Epoch 16, Batch 5/11, Batch Loss: 315593.1562
# Epoch 16, Batch 6/11, Batch Loss: 287196.8750
# Epoch 16, Batch 7/11, Batch Loss: 457366.9062
# Epoch 16, Batch 8/11, Batch Loss: 359511.9688
# Epoch 16, Batch 9/11, Batch Loss: 393724.4062
# Epoch 16, Batch 10/11, Batch Loss: 298879.5938
# Epoch 16, Batch 11/11, Batch Loss: 347132.7500
# Batch 1/3, Batch Loss: 504518.1875
# Batch 2/3, Batch Loss: 337470.9375
# Batch 3/3, Batch Loss: 714619.8750
# Test Error:
#  Avg loss: 518869.666667, Avg error: 264917.325581
#
# Epoch 17, Batch 1/11, Batch Loss: 357352.5938
# Epoch 17, Batch 2/11, Batch Loss: 251973.7812
# Epoch 17, Batch 3/11, Batch Loss: 513444.9375
# Epoch 17, Batch 4/11, Batch Loss: 314744.0938
# Epoch 17, Batch 5/11, Batch Loss: 260225.8125
# Epoch 17, Batch 6/11, Batch Loss: 704888.3750
# Epoch 17, Batch 7/11, Batch Loss: 318430.9375
# Epoch 17, Batch 8/11, Batch Loss: 272540.4062
# Epoch 17, Batch 9/11, Batch Loss: 320080.6875
# Epoch 17, Batch 10/11, Batch Loss: 786287.6875
# Epoch 17, Batch 11/11, Batch Loss: 404363.1250
# Batch 1/3, Batch Loss: 314109.6250
# Batch 2/3, Batch Loss: 607541.8125
# Batch 3/3, Batch Loss: 558344.3125
# Test Error:
#  Avg loss: 493331.916667, Avg error: 259969.377907
#
# Epoch 18, Batch 1/11, Batch Loss: 704982.1250
# Epoch 18, Batch 2/11, Batch Loss: 800264.5625
# Epoch 18, Batch 3/11, Batch Loss: 289439.9062
# Epoch 18, Batch 4/11, Batch Loss: 359461.3750
# Epoch 18, Batch 5/11, Batch Loss: 330127.4375
# Epoch 18, Batch 6/11, Batch Loss: 350969.2500
# Epoch 18, Batch 7/11, Batch Loss: 316293.7812
# Epoch 18, Batch 8/11, Batch Loss: 253703.0781
# Epoch 18, Batch 9/11, Batch Loss: 452803.5000
# Epoch 18, Batch 10/11, Batch Loss: 368553.4062
# Epoch 18, Batch 11/11, Batch Loss: 381733.6250
# Batch 1/3, Batch Loss: 340185.0312
# Batch 2/3, Batch Loss: 534757.8125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Entrenamiento
#       2 n_epochs = 200
# ----> 3 train_losses, val_losses = training_loop(
#       4     n_epochs=n_epochs,
#       5     optimizer=optimizer,
#       6     model=model,
#       7     loss_fn=loss_fn,
#       8     train_loader=train_dataloader,
#       9     val_loader=val_dataloader
#      10 )
#
# Cell In[36], line 36, in training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader)
#      33 train_losses.append(loss_train)
#      35 model.eval()
# ---> 36 val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn)
#      37 val_losses.append(val_loss)
#      39 if epoch == 1 or epoch % 10 == 0:
#
# Cell In[35], line 15, in test_loop(dataloader, model, loss_fn)
#      12 price = price.to(device)
#      14 # Predecir
# ---> 15 pred = model(imgs, numeric_features)
#      17 # Calcular pérdida
#      18 batch_loss = loss_fn(pred, price).item()
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[32], line 52, in NeuralNetwork.forward(self, x, y)
#      51 def forward(self, x,y):
# ---> 52     x = self.image_features_(x)
#      53     x=x.view(-1, 64*7*6)
#      54     y=self.numeric_features_(y)
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\uriel\OneDrive\Escritorio\Uriel\IPN\ESCOM\TT\Codigo\my_code\.venv\Lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
