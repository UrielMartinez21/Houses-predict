# %% [markdown]
# ## Instalar bibliotecas necesarias

# %%
# !pip install torch                    # Install the PyTorch library for deep learning.
# !pip install pandas                   # Install the Pandas library for data manipulation.
# !pip install scikit-learn             # Install scikit-learn for machine learning tasks.
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# ## Acceder a drive

# %%
from google.colab import drive

# Montar Google Drive en /content/drive
drive.mount('/content/drive')

# Listar archivos en el directorio raíz de Google Drive
# !ls '/content/drive/MyDrive/Dataset/Mosaico'
# Out:
# Mounted at /content/drive
# dataset.csv  Imagenes  test.csv  train.csv

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision.io import read_image
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader,ConcatDataset
from sklearn.preprocessing import LabelEncoder
from torch import nn
from torch import optim
import datetime
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Lectura de dataset train y test

# %%
# --> Desde local
# train = pd.read_csv('../Dataset/Mosaico/train.csv')
# test = pd.read_csv('../Dataset/Mosaico/test.csv')

# --> Desde google
train = pd.read_csv('/content/drive/MyDrive/Dataset/Mosaico/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Dataset/Mosaico/test.csv')

train.head()
# Out:
#    bathrooms  bedrooms  area  zipcode mosaic_image   price
# 0        2.0         4  7841    60016       78.png  299000
# 1        2.5         3  3233    62234       70.png  259000
# 2        1.0         2  1110    94501      204.png  649000
# 3        3.0         4  2256    62214       72.png  144900
# 4        2.0         2  2036    92276      287.png  175000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bathrooms     481 non-null    float64
#  1   bedrooms      481 non-null    int64
#  2   area          481 non-null    int64
#  3   zipcode       481 non-null    int64
#  4   mosaic_image  481 non-null    object
#  5   price         481 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 22.7+ KB

# %% [markdown]
# ## Preparar Dataset

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Constructor de la clase que inicializa el dataset personalizado.
        df: DataFrame que contiene los datos (rutas de las imágenes y características numéricas).
        transform: Transformaciones opcionales que se aplicarán a las imágenes (si se proporciona).
        """
        self.df = df  # Guardar el DataFrame que contiene las rutas de imágenes y las características numéricas.
        self.transform = transform  # Almacenar las transformaciones opcionales para las imágenes.

        # Seleccionar las columnas que contienen las características numéricas que deseas estandarizar.
        self.numeric_features = ['bedrooms', 'bathrooms', 'area', 'zipcode']

        # Inicializar el estandarizador de sklearn (StandardScaler) y ajustarlo a las características numéricas.
        # Esto normaliza las características para que tengan media 0 y desviación estándar 1.
        self.scaler = StandardScaler()

        # Aplicar el estandarizador a las columnas de características numéricas y actualizar el DataFrame.
        # Las características numéricas se estandarizan y reemplazan en el DataFrame original.
        self.df[self.numeric_features] = self.scaler.fit_transform(self.df[self.numeric_features])

    def __len__(self):
        """
        Método que devuelve la longitud del dataset, es decir, el número de muestras en el DataFrame.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Método que obtiene una muestra del dataset en el índice `idx`.
        Este método es necesario para que el DataLoader pueda iterar sobre el dataset.
        idx: Índice de la muestra a recuperar.

        Devuelve:
        - La imagen procesada (como un tensor).
        - Las características numéricas estandarizadas (como un tensor).
        - El valor objetivo (precio), también convertido a tensor.
        """
        # Obtener la ruta de la imagen correspondiente al índice dado.
        img_path = self.df.loc[idx, 'mosaic_image']

        # Leer la imagen desde el disco utilizando torchvision.io.read_image.
        # Convierte la imagen en un tensor y ajusta su tipo de dato a flotante (float32).
        # Desde Google Drive
        mosaic_image = read_image(f"/content/drive/MyDrive/Dataset/Mosaico/Imagenes/{img_path}").float()
        # Desde local
        # mosaic_image = read_image(f"../Dataset/Mosaico/Imagenes/{img_path}").float()

        # Obtener los valores de las características numéricas para la muestra actual.
        # Convertir estos valores en tensores de tipo float32.
        bathrooms = torch.tensor(self.df.loc[idx, 'bathrooms'], dtype=torch.float32)
        bedrooms = torch.tensor(self.df.loc[idx, 'bedrooms'], dtype=torch.float32)
        area = torch.tensor(self.df.loc[idx, 'area'], dtype=torch.float32)
        zipcode = torch.tensor(self.df.loc[idx, 'zipcode'], dtype=torch.float32)
        price = torch.tensor(self.df.loc[idx, 'price'], dtype=torch.float32)  # Precio como el valor objetivo.

        # Aplicar las transformaciones a la imagen si se proporcionaron en el constructor.
        if self.transform:
            mosaic_image = self.transform(mosaic_image)

        # Concatenar las características numéricas (bathrooms, bedrooms, area, zipcode) en un único tensor.
        # Utilizar torch.hstack para concatenar los tensores a lo largo del eje horizontal.
        numeric_features = torch.hstack((bathrooms, bedrooms, area, zipcode))

        # Devolver la imagen procesada, las características numéricas estandarizadas y el precio objetivo.
        return mosaic_image, numeric_features, price

# %% [markdown]
# ## Aumentar datos

# %%
data1 = CustomImageDataset(df=train, transform=transforms.Compose([
    transforms.Resize(400),                             # Asegura que todas las imágenes sean de 224x224 (si es necesario)
    transforms.Normalize(
        (58.0583, 55.1679, 52.9831),                    # Media para normalizar los canales RGB
        (85.9875, 82.3628, 80.8718)                     # Desviación estándar para normalizar
    )
]))

# data2 = CustomImageDataset(df=train, transform=transforms.Compose([
#     transforms.Resize(512),
#     # transforms.ColorJitter(
#     #     brightness=0.3, contrast=0.3, saturation=0.3              # Ajustes moderados de color
#     # ),
#     transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),    # Aplicar desenfoque gaussiano
#     transforms.Normalize(
#         (58.0583, 55.1679, 52.9831),
#         (85.9875, 82.3628, 80.8718)
#     )
# ]))

# %% [markdown]
# ## Ver imagenes de cada data

# %%
import matplotlib.pyplot as plt
import torch

# Función para deshacer la normalización (inverso de transforms.Normalize)
def denormalize(tensor, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1)  # Ajustar la media a la forma del tensor
    std = torch.tensor(std).view(3, 1, 1)    # Ajustar la desviación estándar a la forma del tensor
    return tensor * std + mean

# Función para mostrar una imagen
def show_image(image_tensor, title=None):
    # Deshacer la normalización
    image_tensor = denormalize(image_tensor, mean=(58.0583, 55.1679, 52.9831), std=(85.9875, 82.3628, 80.8718))

    # Asegurarse de que los valores de los píxeles estén entre 0 y 255
    image_tensor = torch.clamp(image_tensor, 0, 255)

    # Convertir el tensor a numpy
    image = image_tensor.permute(1, 2, 0).cpu().numpy()  # Cambia las dimensiones de (C, H, W) a (H, W, C)

    # Mostrar la imagen
    plt.imshow(image.astype('uint8'))  # Convertir los valores a uint8 para que matplotlib pueda mostrarlos correctamente
    if title:
        plt.title(title)
    plt.axis('off')  # Quitar los ejes
    plt.show()

# Visualizar la primera imagen de cada conjunto de datos
datasets = [data1]
for i, dataset in enumerate(datasets, 1):
    # Obtener la primera muestra del conjunto de datos (imagen, características numéricas, precio)
    image, _, _ = dataset[0]

    # Mostrar la imagen
    show_image(image, title=f"Imagen de data{i}")

# %% [markdown]
# ## Dividir en train y test

# %%
# Crear un conjunto de datos combinado
# conjunto_datos = ConcatDataset((data1,data2))

# %%
conjunto_datos = data1

# Determinar el tamaño de los conjuntos de entrenamiento y validación
valor_train = int(0.9*len(conjunto_datos))
valor_val = len(conjunto_datos)-valor_train

print(f"Train: {valor_train} Val: {valor_val}")
# Out:
# Train: 432 Val: 49

# %%
# Dividir el conjunto de datos en conjuntos de entrenamiento y validación
# train_data,val_data=torch.utils.data.random_split(ConcatDataset((data1, data2)),[valor_train,valor_val])
train_data,val_data=torch.utils.data.random_split(conjunto_datos,[valor_train,valor_val])

# Eliminar las variables que ya no se necesitan
del data1

# %%
# Crear los dataloaders
batch_size=64

train_dataloader = DataLoader(
    train_data,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,     # Descartar el último lote si su tamaño es menor que el tamaño del lote
    pin_memory=True,    # Usar la memoria de la GPU para acelerar la carga de datos
    num_workers=2       # Usar 2 subprocesos para cargar los datos
)

val_dataloader = DataLoader(
    val_data,
    batch_size=batch_size,
    shuffle=False,
    pin_memory=True,
    num_workers=2
)

# %% [markdown]
# ## Red neuronal

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.image_features_ = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=5, stride=1, padding=2),   # 400x400
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 200x200
            nn.Dropout(),

            nn.Conv2d(16, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 100x100
            nn.Dropout(),

            nn.Conv2d(128, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # 50x50

            nn.Conv2d(128, 64, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                  # 25x25
        )
        self.numeric_features_ = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64, 64*3),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(64*3, 64*3*3),
            nn.ReLU(inplace=True),
        )
        self.combined_features_ = nn.Sequential(
            nn.Linear(37440, 64*3*3*2*2),
            nn.ReLU(inplace=True),
            nn.Dropout(),

            nn.Linear(64*3*3*2*2, 64*3*3*2),
            nn.ReLU(inplace=True),

            nn.Linear(64*3*3*2, 64),
            nn.Linear(64, 1),
        )

    def forward(self, x,y):
        x = self.image_features_(x)
        # print(x.shape)
        x=x.view(-1, 64*24*24)
        # print(x.shape)
        y=self.numeric_features_(y)
        # print(y.shape)
        z=torch.cat((x,y),1)
        # print(z.shape)
        z=self.combined_features_(z)
        return z.squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
# Definir el dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))

# Definir el modelo, la función de pérdida y el optimizador
model = NeuralNetwork().to(device)              # Modelo de red neuronal mandarlo al dispositivo (GPU)
optimizer=optim.Adam(model.parameters(),1e-3)   # Adam optimizer para optimización
# loss_fn=nn.MSELoss()                          # Mean Squared Error Loss para regresión
loss_fn = RMSELoss()                            # RMSE Loss para regresión
# Out:
# Using cuda device

# %% [markdown]
# ## Ciclos de entrenamiento y pruebas

# %%
def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss = 0
    total_error = 0

    with torch.no_grad():
        for batch_idx, (imgs, numeric_features, price) in enumerate(dataloader):
            # Mandar datos al dispositivo
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            # Predecir
            pred = model(imgs, numeric_features)

            # Calcular pérdida
            batch_loss = loss_fn(pred, price).item()
            test_loss += batch_loss
            total_error += torch.abs(pred - price).sum().item()

            # Imprimir la pérdida de cada batch
            print(f"Batch {batch_idx+1}/{num_batches}, Batch Loss: {batch_loss:.4f}")

    # Calcular pérdida y error promedio
    test_loss /= num_batches
    avg_error = total_error / size

    print(f"Test Error: \n Avg loss: {test_loss:.6f}, Avg error: {avg_error:.6f} \n")
    return test_loss

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, val_loader):
    train_losses = []
    val_losses = []

    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        model.train()

        for batch_idx, (imgs, numeric_features, price) in enumerate(train_loader):
            imgs = imgs.to(device)
            numeric_features = numeric_features.to(device)
            price = price.to(device)

            output = model(imgs, numeric_features)

            loss = loss_fn(output, price)

            # L2 Regularization
            l2_lambda = 0.001
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l2_lambda * l2_norm

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

            # Imprimir la pérdida en cada batch
            print(f"Epoch {epoch}, Batch {batch_idx+1}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")

        loss_train /= len(train_loader)
        train_losses.append(loss_train)

        model.eval()
        val_loss = test_loop(dataloader=val_loader, model=model, loss_fn=loss_fn)
        val_losses.append(val_loss)

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Average Training loss {}'.format(datetime.datetime.now(), epoch, loss_train))

    return train_losses, val_losses

# %% [markdown]
# ## Entrenamiento

# %%
# Entrenamiento
n_epochs = 500
train_losses, val_losses = training_loop(
    n_epochs=n_epochs,
    optimizer=optimizer,
    model=model,
    loss_fn=loss_fn,
    train_loader=train_dataloader,
    val_loader=val_dataloader
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 6, Batch 1/6, Batch Loss: 672370.2500
# Epoch 6, Batch 2/6, Batch Loss: 511781.8125
# Epoch 6, Batch 3/6, Batch Loss: 467438.9375
# Epoch 6, Batch 4/6, Batch Loss: 351850.3438
# Epoch 6, Batch 5/6, Batch Loss: 451055.8125
# Epoch 6, Batch 6/6, Batch Loss: 420744.8125
# Batch 1/1, Batch Loss: 1066878.3750
# Test Error:
#  Avg loss: 1066878.375000, Avg error: 504151.755102
#
# Epoch 7, Batch 1/6, Batch Loss: 625876.5625
# Epoch 7, Batch 2/6, Batch Loss: 502497.8438
# Epoch 7, Batch 3/6, Batch Loss: 477234.2500
# Epoch 7, Batch 4/6, Batch Loss: 453069.3438
# Epoch 7, Batch 5/6, Batch Loss: 413911.1250
# Epoch 7, Batch 6/6, Batch Loss: 422490.9688
# Batch 1/1, Batch Loss: 996531.0625
# Test Error:
#  Avg loss: 996531.062500, Avg error: 425222.857143
#
# Epoch 8, Batch 1/6, Batch Loss: 425862.4062
# Epoch 8, Batch 2/6, Batch Loss: 432158.5938
# Epoch 8, Batch 3/6, Batch Loss: 311048.5938
# Epoch 8, Batch 4/6, Batch Loss: 516789.0625
# Epoch 8, Batch 5/6, Batch Loss: 595625.5000
# Epoch 8, Batch 6/6, Batch Loss: 446745.7812
# Batch 1/1, Batch Loss: 1016053.6875
# Test Error:
#  Avg loss: 1016053.687500, Avg error: 437637.346939
#
# Epoch 9, Batch 1/6, Batch Loss: 460535.6875
# Epoch 9, Batch 2/6, Batch Loss: 401681.2812
# Epoch 9, Batch 3/6, Batch Loss: 462259.9688
# Epoch 9, Batch 4/6, Batch Loss: 601251.6250
# Epoch 9, Batch 5/6, Batch Loss: 395124.5000
# Epoch 9, Batch 6/6, Batch Loss: 482655.4062
# Batch 1/1, Batch Loss: 1057113.2500
# Test Error:
#  Avg loss: 1057113.250000, Avg error: 487016.285714
#
# Epoch 10, Batch 1/6, Batch Loss: 483408.8438
# Epoch 10, Batch 2/6, Batch Loss: 504965.4375
# Epoch 10, Batch 3/6, Batch Loss: 386733.3125
# Epoch 10, Batch 4/6, Batch Loss: 528241.4375
# Epoch 10, Batch 5/6, Batch Loss: 410287.0000
# Epoch 10, Batch 6/6, Batch Loss: 410819.2500
# Batch 1/1, Batch Loss: 973890.9375
# Test Error:
#  Avg loss: 973890.937500, Avg error: 395236.938776
#
# 2024-09-16 03:08:03.921466 Epoch 10, Average Training loss 454075.8802083333
# Epoch 11, Batch 1/6, Batch Loss: 397308.8438
# Epoch 11, Batch 2/6, Batch Loss: 455818.3750
# Epoch 11, Batch 3/6, Batch Loss: 463197.0000
# Epoch 11, Batch 4/6, Batch Loss: 338108.5000
# Epoch 11, Batch 5/6, Batch Loss: 409195.1562
# Epoch 11, Batch 6/6, Batch Loss: 611852.1875
# Batch 1/1, Batch Loss: 1035206.2500
# Test Error:
#  Avg loss: 1035206.250000, Avg error: 455799.428571
#
# Epoch 12, Batch 1/6, Batch Loss: 481514.1562
# Epoch 12, Batch 2/6, Batch Loss: 403855.2812
# Epoch 12, Batch 3/6, Batch Loss: 389708.0000
# Epoch 12, Batch 4/6, Batch Loss: 430350.8125
# Epoch 12, Batch 5/6, Batch Loss: 424879.2500
# Epoch 12, Batch 6/6, Batch Loss: 576542.5000
# Batch 1/1, Batch Loss: 972942.0625
# Test Error:
#  Avg loss: 972942.062500, Avg error: 391129.714286
#
# Epoch 13, Batch 1/6, Batch Loss: 565132.6875
# Epoch 13, Batch 2/6, Batch Loss: 474123.4375
# Epoch 13, Batch 3/6, Batch Loss: 408384.2500
# Epoch 13, Batch 4/6, Batch Loss: 294050.1562
# Epoch 13, Batch 5/6, Batch Loss: 368743.7500
# Epoch 13, Batch 6/6, Batch Loss: 340325.9688
# Batch 1/1, Batch Loss: 1019477.8750
# Test Error:
#  Avg loss: 1019477.875000, Avg error: 436351.428571
#
# Epoch 14, Batch 1/6, Batch Loss: 345945.4688
# Epoch 14, Batch 2/6, Batch Loss: 457595.9688
# Epoch 14, Batch 3/6, Batch Loss: 326880.5000
# Epoch 14, Batch 4/6, Batch Loss: 368721.2188
# Epoch 14, Batch 5/6, Batch Loss: 438957.0625
# Epoch 14, Batch 6/6, Batch Loss: 556527.8750
# Batch 1/1, Batch Loss: 974071.1250
# Test Error:
#  Avg loss: 974071.125000, Avg error: 388780.040816
#
# Epoch 15, Batch 1/6, Batch Loss: 506808.2500
# Epoch 15, Batch 2/6, Batch Loss: 365635.8750
# Epoch 15, Batch 3/6, Batch Loss: 380758.0000
# Epoch 15, Batch 4/6, Batch Loss: 384096.5312
# Epoch 15, Batch 5/6, Batch Loss: 376375.7500
# Epoch 15, Batch 6/6, Batch Loss: 328989.8125
# Batch 1/1, Batch Loss: 982298.2500
# Test Error:
#  Avg loss: 982298.250000, Avg error: 399316.571429
#
# Epoch 16, Batch 1/6, Batch Loss: 413572.1562
# Epoch 16, Batch 2/6, Batch Loss: 328827.2812
# Epoch 16, Batch 3/6, Batch Loss: 397575.6875
# Epoch 16, Batch 4/6, Batch Loss: 298181.9062
# Epoch 16, Batch 5/6, Batch Loss: 504710.9688
# Epoch 16, Batch 6/6, Batch Loss: 397538.8750
# Batch 1/1, Batch Loss: 946803.9375
# Test Error:
#  Avg loss: 946803.937500, Avg error: 360983.755102
#
# Epoch 17, Batch 1/6, Batch Loss: 339657.5000
# Epoch 17, Batch 2/6, Batch Loss: 339264.7812
# Epoch 17, Batch 3/6, Batch Loss: 400102.9062
# Epoch 17, Batch 4/6, Batch Loss: 318415.2812
# Epoch 17, Batch 5/6, Batch Loss: 545693.7500
# Epoch 17, Batch 6/6, Batch Loss: 383331.2812
# Batch 1/1, Batch Loss: 933453.1875
# Test Error:
#  Avg loss: 933453.187500, Avg error: 346551.428571
#
# Epoch 18, Batch 1/6, Batch Loss: 411827.3750
# Epoch 18, Batch 2/6, Batch Loss: 334634.5938
# Epoch 18, Batch 3/6, Batch Loss: 370735.3125
# Epoch 18, Batch 4/6, Batch Loss: 383508.5000
# Epoch 18, Batch 5/6, Batch Loss: 320443.1562
# Epoch 18, Batch 6/6, Batch Loss: 419689.1562
# Batch 1/1, Batch Loss: 938990.1250
# Test Error:
#  Avg loss: 938990.125000, Avg error: 358430.530612
#
# Epoch 19, Batch 1/6, Batch Loss: 367747.4062
# Epoch 19, Batch 2/6, Batch Loss: 405938.7812
# Epoch 19, Batch 3/6, Batch Loss: 266560.7188
# Epoch 19, Batch 4/6, Batch Loss: 334937.5938
# Epoch 19, Batch 5/6, Batch Loss: 511783.0312
# Epoch 19, Batch 6/6, Batch Loss: 316056.9062
# Batch 1/1, Batch Loss: 936566.1875
# Test Error:
#  Avg loss: 936566.187500, Avg error: 359208.734694
#
# Epoch 20, Batch 1/6, Batch Loss: 345223.5625
# Epoch 20, Batch 2/6, Batch Loss: 438171.9688
# Epoch 20, Batch 3/6, Batch Loss: 342007.4688
# Epoch 20, Batch 4/6, Batch Loss: 328243.8438
# Epoch 20, Batch 5/6, Batch Loss: 410902.8438
# Epoch 20, Batch 6/6, Batch Loss: 355730.9062
# Batch 1/1, Batch Loss: 923521.5625
# Test Error:
#  Avg loss: 923521.562500, Avg error: 339846.530612
#
# 2024-09-16 03:09:25.616276 Epoch 20, Average Training loss 370046.765625
# Epoch 21, Batch 1/6, Batch Loss: 412565.3750
# Epoch 21, Batch 2/6, Batch Loss: 371096.2812
# Epoch 21, Batch 3/6, Batch Loss: 448336.4688
# Epoch 21, Batch 4/6, Batch Loss: 310403.9375
# Epoch 21, Batch 5/6, Batch Loss: 396667.8125
# Epoch 21, Batch 6/6, Batch Loss: 330742.5625
# Batch 1/1, Batch Loss: 950755.3750
# Test Error:
#  Avg loss: 950755.375000, Avg error: 381941.632653
#
# Epoch 22, Batch 1/6, Batch Loss: 487861.6562
# Epoch 22, Batch 2/6, Batch Loss: 392051.4375
# Epoch 22, Batch 3/6, Batch Loss: 313805.4375
# Epoch 22, Batch 4/6, Batch Loss: 293778.0938
# Epoch 22, Batch 5/6, Batch Loss: 449749.1875
# Epoch 22, Batch 6/6, Batch Loss: 319378.7188
# Batch 1/1, Batch Loss: 916037.5625
# Test Error:
#  Avg loss: 916037.562500, Avg error: 327631.387755
#
# Epoch 23, Batch 1/6, Batch Loss: 419346.5312
# Epoch 23, Batch 2/6, Batch Loss: 396554.0938
# Epoch 23, Batch 3/6, Batch Loss: 294617.1562
# Epoch 23, Batch 4/6, Batch Loss: 346404.1250
# Epoch 23, Batch 5/6, Batch Loss: 463445.5938
# Epoch 23, Batch 6/6, Batch Loss: 301956.2812
# Batch 1/1, Batch Loss: 924194.0000
# Test Error:
#  Avg loss: 924194.000000, Avg error: 337372.816327
#
# Epoch 24, Batch 1/6, Batch Loss: 429708.0000
# Epoch 24, Batch 2/6, Batch Loss: 344170.3125
# Epoch 24, Batch 3/6, Batch Loss: 319753.6562
# Epoch 24, Batch 4/6, Batch Loss: 314606.9062
# Epoch 24, Batch 5/6, Batch Loss: 355543.0938
# Epoch 24, Batch 6/6, Batch Loss: 388185.2812
# Batch 1/1, Batch Loss: 921353.9375
# Test Error:
#  Avg loss: 921353.937500, Avg error: 333169.469388
#
# Epoch 25, Batch 1/6, Batch Loss: 457862.1875
# Epoch 25, Batch 2/6, Batch Loss: 322723.6562
# Epoch 25, Batch 3/6, Batch Loss: 404162.5312
# Epoch 25, Batch 4/6, Batch Loss: 383441.2812
# Epoch 25, Batch 5/6, Batch Loss: 354882.0625
# Epoch 25, Batch 6/6, Batch Loss: 345089.9688
# Batch 1/1, Batch Loss: 952104.0000
# Test Error:
#  Avg loss: 952104.000000, Avg error: 382712.000000
#
# Epoch 26, Batch 1/6, Batch Loss: 466064.4062
# Epoch 26, Batch 2/6, Batch Loss: 400500.9688
# Epoch 26, Batch 3/6, Batch Loss: 280312.6562
# Epoch 26, Batch 4/6, Batch Loss: 371718.5938
# Epoch 26, Batch 5/6, Batch Loss: 387594.0625
# Epoch 26, Batch 6/6, Batch Loss: 353303.5938
# Batch 1/1, Batch Loss: 920784.4375
# Test Error:
#  Avg loss: 920784.437500, Avg error: 333509.959184
#
# Epoch 27, Batch 1/6, Batch Loss: 466687.8438
# Epoch 27, Batch 2/6, Batch Loss: 303155.6875
# Epoch 27, Batch 3/6, Batch Loss: 313554.7812
# Epoch 27, Batch 4/6, Batch Loss: 290854.3750
# Epoch 27, Batch 5/6, Batch Loss: 418183.8750
# Epoch 27, Batch 6/6, Batch Loss: 347667.2812
# Batch 1/1, Batch Loss: 916821.8750
# Test Error:
#  Avg loss: 916821.875000, Avg error: 326981.020408
#
# Epoch 28, Batch 1/6, Batch Loss: 335722.3125
# Epoch 28, Batch 2/6, Batch Loss: 394539.9375
# Epoch 28, Batch 3/6, Batch Loss: 327741.2812
# Epoch 28, Batch 4/6, Batch Loss: 371315.8438
# Epoch 28, Batch 5/6, Batch Loss: 453751.0625
# Epoch 28, Batch 6/6, Batch Loss: 376060.3125
# Batch 1/1, Batch Loss: 938618.5000
# Test Error:
#  Avg loss: 938618.500000, Avg error: 361257.755102
#
# Epoch 29, Batch 1/6, Batch Loss: 325409.0625
# Epoch 29, Batch 2/6, Batch Loss: 349192.5312
# Epoch 29, Batch 3/6, Batch Loss: 351867.8438
# Epoch 29, Batch 4/6, Batch Loss: 427995.7500
# Epoch 29, Batch 5/6, Batch Loss: 330847.1562
# Epoch 29, Batch 6/6, Batch Loss: 346860.4375
# Batch 1/1, Batch Loss: 929495.5000
# Test Error:
#  Avg loss: 929495.500000, Avg error: 347091.346939
#
# Epoch 30, Batch 1/6, Batch Loss: 345244.2812
# Epoch 30, Batch 2/6, Batch Loss: 426259.7188
# Epoch 30, Batch 3/6, Batch Loss: 376209.1562
# Epoch 30, Batch 4/6, Batch Loss: 349729.7812
# Epoch 30, Batch 5/6, Batch Loss: 286459.3750
# Epoch 30, Batch 6/6, Batch Loss: 378370.5312
# Batch 1/1, Batch Loss: 909086.9375
# Test Error:
#  Avg loss: 909086.937500, Avg error: 321192.000000
#
# 2024-09-16 03:10:46.101106 Epoch 30, Average Training loss 360378.8072916667
# Epoch 31, Batch 1/6, Batch Loss: 412209.6875
# Epoch 31, Batch 2/6, Batch Loss: 353460.3125
# Epoch 31, Batch 3/6, Batch Loss: 285047.9062
# Epoch 31, Batch 4/6, Batch Loss: 344144.2188
# Epoch 31, Batch 5/6, Batch Loss: 341023.7500
# Epoch 31, Batch 6/6, Batch Loss: 404067.5938
# Batch 1/1, Batch Loss: 925901.8750
# Test Error:
#  Avg loss: 925901.875000, Avg error: 344686.122449
#
# Epoch 32, Batch 1/6, Batch Loss: 323404.8750
# Epoch 32, Batch 2/6, Batch Loss: 367737.4375
# Epoch 32, Batch 3/6, Batch Loss: 380245.7812
# Epoch 32, Batch 4/6, Batch Loss: 335546.5938
# Epoch 32, Batch 5/6, Batch Loss: 344537.7188
# Epoch 32, Batch 6/6, Batch Loss: 289006.0312
# Batch 1/1, Batch Loss: 916343.1250
# Test Error:
#  Avg loss: 916343.125000, Avg error: 327063.571429
#
# Epoch 33, Batch 1/6, Batch Loss: 381114.8125
# Epoch 33, Batch 2/6, Batch Loss: 276223.6562
# Epoch 33, Batch 3/6, Batch Loss: 366136.2188
# Epoch 33, Batch 4/6, Batch Loss: 345253.5938
# Epoch 33, Batch 5/6, Batch Loss: 371198.9062
# Epoch 33, Batch 6/6, Batch Loss: 304777.0000
# Batch 1/1, Batch Loss: 905485.3750
# Test Error:
#  Avg loss: 905485.375000, Avg error: 315031.387755
#
# Epoch 34, Batch 1/6, Batch Loss: 303458.6250
# Epoch 34, Batch 2/6, Batch Loss: 459817.8438
# Epoch 34, Batch 3/6, Batch Loss: 304344.4688
# Epoch 34, Batch 4/6, Batch Loss: 305455.6250
# Epoch 34, Batch 5/6, Batch Loss: 287756.4062
# Epoch 34, Batch 6/6, Batch Loss: 452959.0312
# Batch 1/1, Batch Loss: 934633.6250
# Test Error:
#  Avg loss: 934633.625000, Avg error: 356549.183673
#
# Epoch 35, Batch 1/6, Batch Loss: 310539.5938
# Epoch 35, Batch 2/6, Batch Loss: 418803.5938
# Epoch 35, Batch 3/6, Batch Loss: 409754.7188
# Epoch 35, Batch 4/6, Batch Loss: 342090.6562
# Epoch 35, Batch 5/6, Batch Loss: 383779.0312
# Epoch 35, Batch 6/6, Batch Loss: 325620.8438
# Batch 1/1, Batch Loss: 900608.0625
# Test Error:
#  Avg loss: 900608.062500, Avg error: 313341.428571
#
# Epoch 36, Batch 1/6, Batch Loss: 319980.2812
# Epoch 36, Batch 2/6, Batch Loss: 433981.9375
# Epoch 36, Batch 3/6, Batch Loss: 292305.3750
# Epoch 36, Batch 4/6, Batch Loss: 317079.0000
# Epoch 36, Batch 5/6, Batch Loss: 323524.7812
# Epoch 36, Batch 6/6, Batch Loss: 345991.1250
# Batch 1/1, Batch Loss: 917034.6250
# Test Error:
#  Avg loss: 917034.625000, Avg error: 328987.571429
#
# Epoch 37, Batch 1/6, Batch Loss: 359548.4375
# Epoch 37, Batch 2/6, Batch Loss: 339139.2500
# Epoch 37, Batch 3/6, Batch Loss: 333793.3125
# Epoch 37, Batch 4/6, Batch Loss: 324173.1875
# Epoch 37, Batch 5/6, Batch Loss: 361248.0938
# Epoch 37, Batch 6/6, Batch Loss: 308829.1875
# Batch 1/1, Batch Loss: 941566.0625
# Test Error:
#  Avg loss: 941566.062500, Avg error: 365990.000000
#
# Epoch 38, Batch 1/6, Batch Loss: 253336.2500
# Epoch 38, Batch 2/6, Batch Loss: 368632.5625
# Epoch 38, Batch 3/6, Batch Loss: 278570.0625
# Epoch 38, Batch 4/6, Batch Loss: 452211.4688
# Epoch 38, Batch 5/6, Batch Loss: 329317.1875
# Epoch 38, Batch 6/6, Batch Loss: 403476.9375
# Batch 1/1, Batch Loss: 902708.6875
# Test Error:
#  Avg loss: 902708.687500, Avg error: 312348.775510
#
# Epoch 39, Batch 1/6, Batch Loss: 482936.5000
# Epoch 39, Batch 2/6, Batch Loss: 355616.3125
# Epoch 39, Batch 3/6, Batch Loss: 374476.4062
# Epoch 39, Batch 4/6, Batch Loss: 380656.5625
# Epoch 39, Batch 5/6, Batch Loss: 239042.1719
# Epoch 39, Batch 6/6, Batch Loss: 354126.0312
# Batch 1/1, Batch Loss: 926515.9375
# Test Error:
#  Avg loss: 926515.937500, Avg error: 342475.428571
#
# Epoch 40, Batch 1/6, Batch Loss: 413850.1562
# Epoch 40, Batch 2/6, Batch Loss: 373835.9375
# Epoch 40, Batch 3/6, Batch Loss: 457932.8125
# Epoch 40, Batch 4/6, Batch Loss: 341618.2812
# Epoch 40, Batch 5/6, Batch Loss: 262525.9375
# Epoch 40, Batch 6/6, Batch Loss: 395491.8750
# Batch 1/1, Batch Loss: 952969.1250
# Test Error:
#  Avg loss: 952969.125000, Avg error: 386258.693878
#
# 2024-09-16 03:12:05.188550 Epoch 40, Average Training loss 374209.1666666667
# Epoch 41, Batch 1/6, Batch Loss: 358366.2812
# Epoch 41, Batch 2/6, Batch Loss: 306099.7188
# Epoch 41, Batch 3/6, Batch Loss: 477993.8125
# Epoch 41, Batch 4/6, Batch Loss: 377991.8125
# Epoch 41, Batch 5/6, Batch Loss: 270617.0938
# Epoch 41, Batch 6/6, Batch Loss: 338068.6250
# Batch 1/1, Batch Loss: 889031.4375
# Test Error:
#  Avg loss: 889031.437500, Avg error: 309488.469388
#
# Epoch 42, Batch 1/6, Batch Loss: 317337.3438
# Epoch 42, Batch 2/6, Batch Loss: 384372.5938
# Epoch 42, Batch 3/6, Batch Loss: 324090.1562
# Epoch 42, Batch 4/6, Batch Loss: 347381.9062
# Epoch 42, Batch 5/6, Batch Loss: 368555.5625
# Epoch 42, Batch 6/6, Batch Loss: 493171.6875
# Batch 1/1, Batch Loss: 921021.7500
# Test Error:
#  Avg loss: 921021.750000, Avg error: 339500.326531
#
# Epoch 43, Batch 1/6, Batch Loss: 359355.8750
# Epoch 43, Batch 2/6, Batch Loss: 323223.9688
# Epoch 43, Batch 3/6, Batch Loss: 317853.8750
# Epoch 43, Batch 4/6, Batch Loss: 379815.0000
# Epoch 43, Batch 5/6, Batch Loss: 341698.1875
# Epoch 43, Batch 6/6, Batch Loss: 352583.7188
# Batch 1/1, Batch Loss: 924193.2500
# Test Error:
#  Avg loss: 924193.250000, Avg error: 343614.204082
#
# Epoch 44, Batch 1/6, Batch Loss: 278502.0000
# Epoch 44, Batch 2/6, Batch Loss: 434206.7500
# Epoch 44, Batch 3/6, Batch Loss: 351237.4375
# Epoch 44, Batch 4/6, Batch Loss: 382502.1875
# Epoch 44, Batch 5/6, Batch Loss: 356525.9688
# Epoch 44, Batch 6/6, Batch Loss: 326103.4375
# Batch 1/1, Batch Loss: 906267.1875
# Test Error:
#  Avg loss: 906267.187500, Avg error: 319584.938776
#
# Epoch 45, Batch 1/6, Batch Loss: 449890.7500
# Epoch 45, Batch 2/6, Batch Loss: 372686.4375
# Epoch 45, Batch 3/6, Batch Loss: 266333.4688
# Epoch 45, Batch 4/6, Batch Loss: 276468.2500
# Epoch 45, Batch 5/6, Batch Loss: 252074.4688
# Epoch 45, Batch 6/6, Batch Loss: 300315.5625
# Batch 1/1, Batch Loss: 918297.7500
# Test Error:
#  Avg loss: 918297.750000, Avg error: 331455.897959
#
# Epoch 46, Batch 1/6, Batch Loss: 423999.3750
# Epoch 46, Batch 2/6, Batch Loss: 284812.2812
# Epoch 46, Batch 3/6, Batch Loss: 376229.9688
# Epoch 46, Batch 4/6, Batch Loss: 301899.8125
# Epoch 46, Batch 5/6, Batch Loss: 269962.8125
# Epoch 46, Batch 6/6, Batch Loss: 365794.3750
# Batch 1/1, Batch Loss: 911148.2500
# Test Error:
#  Avg loss: 911148.250000, Avg error: 320430.571429
#
# Epoch 47, Batch 1/6, Batch Loss: 316962.5000
# Epoch 47, Batch 2/6, Batch Loss: 318206.8438
# Epoch 47, Batch 3/6, Batch Loss: 262490.0000
# Epoch 47, Batch 4/6, Batch Loss: 298955.6875
# Epoch 47, Batch 5/6, Batch Loss: 391186.4688
# Epoch 47, Batch 6/6, Batch Loss: 328566.7188
# Batch 1/1, Batch Loss: 904406.0625
# Test Error:
#  Avg loss: 904406.062500, Avg error: 311313.918367
#
# Epoch 48, Batch 1/6, Batch Loss: 417347.0938
# Epoch 48, Batch 2/6, Batch Loss: 345276.2812
# Epoch 48, Batch 3/6, Batch Loss: 466294.0312
# Epoch 48, Batch 4/6, Batch Loss: 282278.5312
# Epoch 48, Batch 5/6, Batch Loss: 248200.7500
# Epoch 48, Batch 6/6, Batch Loss: 283820.1875
# Batch 1/1, Batch Loss: 913835.5000
# Test Error:
#  Avg loss: 913835.500000, Avg error: 322191.632653
#
# Epoch 49, Batch 1/6, Batch Loss: 404828.6875
# Epoch 49, Batch 2/6, Batch Loss: 340025.3750
# Epoch 49, Batch 3/6, Batch Loss: 257085.7656
# Epoch 49, Batch 4/6, Batch Loss: 372884.6250
# Epoch 49, Batch 5/6, Batch Loss: 395176.8750
# Epoch 49, Batch 6/6, Batch Loss: 277869.0312
# Batch 1/1, Batch Loss: 910596.9375
# Test Error:
#  Avg loss: 910596.937500, Avg error: 318298.163265
#
# Epoch 50, Batch 1/6, Batch Loss: 303662.6250
# Epoch 50, Batch 2/6, Batch Loss: 329240.5000
# Epoch 50, Batch 3/6, Batch Loss: 415105.0938
# Epoch 50, Batch 4/6, Batch Loss: 412155.3750
# Epoch 50, Batch 5/6, Batch Loss: 269016.4688
# Epoch 50, Batch 6/6, Batch Loss: 308053.8125
# Batch 1/1, Batch Loss: 887823.8125
# Test Error:
#  Avg loss: 887823.812500, Avg error: 301306.244898
#
# 2024-09-16 03:13:31.749255 Epoch 50, Average Training loss 339538.9791666667
# Epoch 51, Batch 1/6, Batch Loss: 278687.2812
# Epoch 51, Batch 2/6, Batch Loss: 416788.7812
# Epoch 51, Batch 3/6, Batch Loss: 257845.6875
# Epoch 51, Batch 4/6, Batch Loss: 483466.7188
# Epoch 51, Batch 5/6, Batch Loss: 343636.7812
# Epoch 51, Batch 6/6, Batch Loss: 344782.1875
# Batch 1/1, Batch Loss: 896491.2500
# Test Error:
#  Avg loss: 896491.250000, Avg error: 308556.795918
#
# Epoch 52, Batch 1/6, Batch Loss: 282894.2188
# Epoch 52, Batch 2/6, Batch Loss: 289738.4688
# Epoch 52, Batch 3/6, Batch Loss: 328058.7188
# Epoch 52, Batch 4/6, Batch Loss: 379722.2500
# Epoch 52, Batch 5/6, Batch Loss: 294817.1562
# Epoch 52, Batch 6/6, Batch Loss: 368152.9688
# Batch 1/1, Batch Loss: 899862.8750
# Test Error:
#  Avg loss: 899862.875000, Avg error: 309070.408163
#
# Epoch 53, Batch 1/6, Batch Loss: 283109.4375
# Epoch 53, Batch 2/6, Batch Loss: 296982.9062
# Epoch 53, Batch 3/6, Batch Loss: 269896.9375
# Epoch 53, Batch 4/6, Batch Loss: 522621.4688
# Epoch 53, Batch 5/6, Batch Loss: 324412.8438
# Epoch 53, Batch 6/6, Batch Loss: 369198.5938
# Batch 1/1, Batch Loss: 912595.6875
# Test Error:
#  Avg loss: 912595.687500, Avg error: 321315.448980
#
# Epoch 54, Batch 1/6, Batch Loss: 275332.8125
# Epoch 54, Batch 2/6, Batch Loss: 404813.5938
# Epoch 54, Batch 3/6, Batch Loss: 371208.6562
# Epoch 54, Batch 4/6, Batch Loss: 240151.2344
# Epoch 54, Batch 5/6, Batch Loss: 340571.4062
# Epoch 54, Batch 6/6, Batch Loss: 499017.3125
# Batch 1/1, Batch Loss: 947646.5000
# Test Error:
#  Avg loss: 947646.500000, Avg error: 373801.632653
#
# Epoch 55, Batch 1/6, Batch Loss: 433437.9375
# Epoch 55, Batch 2/6, Batch Loss: 372756.8750
# Epoch 55, Batch 3/6, Batch Loss: 346550.4375
# Epoch 55, Batch 4/6, Batch Loss: 480917.5312
# Epoch 55, Batch 5/6, Batch Loss: 302418.9375
# Epoch 55, Batch 6/6, Batch Loss: 296461.5938
# Batch 1/1, Batch Loss: 894391.6875
# Test Error:
#  Avg loss: 894391.687500, Avg error: 305185.510204
#
# Epoch 56, Batch 1/6, Batch Loss: 335241.3438
# Epoch 56, Batch 2/6, Batch Loss: 317607.9688
# Epoch 56, Batch 3/6, Batch Loss: 330514.6250
# Epoch 56, Batch 4/6, Batch Loss: 311520.1250
# Epoch 56, Batch 5/6, Batch Loss: 368703.8438
# Epoch 56, Batch 6/6, Batch Loss: 467003.2812
# Batch 1/1, Batch Loss: 904778.6875
# Test Error:
#  Avg loss: 904778.687500, Avg error: 313222.000000
#
# Epoch 57, Batch 1/6, Batch Loss: 327629.7812
# Epoch 57, Batch 2/6, Batch Loss: 471812.4688
# Epoch 57, Batch 3/6, Batch Loss: 351784.1875
# Epoch 57, Batch 4/6, Batch Loss: 356403.6875
# Epoch 57, Batch 5/6, Batch Loss: 281647.8438
# Epoch 57, Batch 6/6, Batch Loss: 374753.5938
# Batch 1/1, Batch Loss: 945078.8750
# Test Error:
#  Avg loss: 945078.875000, Avg error: 380623.102041
#
# Epoch 58, Batch 1/6, Batch Loss: 356658.2188
# Epoch 58, Batch 2/6, Batch Loss: 514779.2812
# Epoch 58, Batch 3/6, Batch Loss: 254776.3750
# Epoch 58, Batch 4/6, Batch Loss: 292492.8438
# Epoch 58, Batch 5/6, Batch Loss: 342154.8125
# Epoch 58, Batch 6/6, Batch Loss: 450917.0312
# Batch 1/1, Batch Loss: 876958.3750
# Test Error:
#  Avg loss: 876958.375000, Avg error: 299223.306122
#
# Epoch 59, Batch 1/6, Batch Loss: 346448.0938
# Epoch 59, Batch 2/6, Batch Loss: 365097.2812
# Epoch 59, Batch 3/6, Batch Loss: 362230.5312
# Epoch 59, Batch 4/6, Batch Loss: 359823.0625
# Epoch 59, Batch 5/6, Batch Loss: 314015.2188
# Epoch 59, Batch 6/6, Batch Loss: 382277.6562
# Batch 1/1, Batch Loss: 921964.3125
# Test Error:
#  Avg loss: 921964.312500, Avg error: 337964.183673
#
# Epoch 60, Batch 1/6, Batch Loss: 403523.3125
# Epoch 60, Batch 2/6, Batch Loss: 285480.3438
# Epoch 60, Batch 3/6, Batch Loss: 381968.0625
# Epoch 60, Batch 4/6, Batch Loss: 270122.0625
# Epoch 60, Batch 5/6, Batch Loss: 337781.5625
# Epoch 60, Batch 6/6, Batch Loss: 329720.2188
# Batch 1/1, Batch Loss: 895420.0625
# Test Error:
#  Avg loss: 895420.062500, Avg error: 305209.183673
#
# 2024-09-16 03:14:51.474171 Epoch 60, Average Training loss 334765.9270833333
# Epoch 61, Batch 1/6, Batch Loss: 391777.5938
# Epoch 61, Batch 2/6, Batch Loss: 351098.6875
# Epoch 61, Batch 3/6, Batch Loss: 274464.0625
# Epoch 61, Batch 4/6, Batch Loss: 363687.8125
# Epoch 61, Batch 5/6, Batch Loss: 279847.2500
# Epoch 61, Batch 6/6, Batch Loss: 362401.0000
# Batch 1/1, Batch Loss: 902348.4375
# Test Error:
#  Avg loss: 902348.437500, Avg error: 307581.061224
#
# Epoch 62, Batch 1/6, Batch Loss: 361270.9062
# Epoch 62, Batch 2/6, Batch Loss: 298728.6562
# Epoch 62, Batch 3/6, Batch Loss: 324748.9688
# Epoch 62, Batch 4/6, Batch Loss: 385408.1250
# Epoch 62, Batch 5/6, Batch Loss: 421447.3438
# Epoch 62, Batch 6/6, Batch Loss: 312992.2500
# Batch 1/1, Batch Loss: 911145.5000
# Test Error:
#  Avg loss: 911145.500000, Avg error: 316794.346939
#
# Epoch 63, Batch 1/6, Batch Loss: 368553.9062
# Epoch 63, Batch 2/6, Batch Loss: 402587.0938
# Epoch 63, Batch 3/6, Batch Loss: 282619.5938
# Epoch 63, Batch 4/6, Batch Loss: 405161.7188
# Epoch 63, Batch 5/6, Batch Loss: 410796.2188
# Epoch 63, Batch 6/6, Batch Loss: 262286.4375
# Batch 1/1, Batch Loss: 925398.5625
# Test Error:
#  Avg loss: 925398.562500, Avg error: 337068.897959
#
# Epoch 64, Batch 1/6, Batch Loss: 490136.4688
# Epoch 64, Batch 2/6, Batch Loss: 271654.7812
# Epoch 64, Batch 3/6, Batch Loss: 411803.7500
# Epoch 64, Batch 4/6, Batch Loss: 270064.7188
# Epoch 64, Batch 5/6, Batch Loss: 357955.4375
# Epoch 64, Batch 6/6, Batch Loss: 288156.9375
# Batch 1/1, Batch Loss: 879790.7500
# Test Error:
#  Avg loss: 879790.750000, Avg error: 293569.224490
#
# Epoch 65, Batch 1/6, Batch Loss: 315670.7500
# Epoch 65, Batch 2/6, Batch Loss: 269952.4688
# Epoch 65, Batch 3/6, Batch Loss: 349481.5000
# Epoch 65, Batch 4/6, Batch Loss: 300138.3438
# Epoch 65, Batch 5/6, Batch Loss: 489236.7500
# Epoch 65, Batch 6/6, Batch Loss: 426990.4688
# Batch 1/1, Batch Loss: 917689.1875
# Test Error:
#  Avg loss: 917689.187500, Avg error: 327734.244898
#
# Epoch 66, Batch 1/6, Batch Loss: 238846.6250
# Epoch 66, Batch 2/6, Batch Loss: 298288.7500
# Epoch 66, Batch 3/6, Batch Loss: 460715.3750
# Epoch 66, Batch 4/6, Batch Loss: 400552.9688
# Epoch 66, Batch 5/6, Batch Loss: 313401.0312
# Epoch 66, Batch 6/6, Batch Loss: 354610.8750
# Batch 1/1, Batch Loss: 919772.1250
# Test Error:
#  Avg loss: 919772.125000, Avg error: 331942.918367
#
# Epoch 67, Batch 1/6, Batch Loss: 373435.5000
# Epoch 67, Batch 2/6, Batch Loss: 383490.4062
# Epoch 67, Batch 3/6, Batch Loss: 333531.5000
# Epoch 67, Batch 4/6, Batch Loss: 374175.1562
# Epoch 67, Batch 5/6, Batch Loss: 330741.1250
# Epoch 67, Batch 6/6, Batch Loss: 346326.6250
# Batch 1/1, Batch Loss: 882869.1875
# Test Error:
#  Avg loss: 882869.187500, Avg error: 294779.469388
#
# Epoch 68, Batch 1/6, Batch Loss: 336712.0000
# Epoch 68, Batch 2/6, Batch Loss: 335253.9375
# Epoch 68, Batch 3/6, Batch Loss: 459576.0938
# Epoch 68, Batch 4/6, Batch Loss: 301801.8438
# Epoch 68, Batch 5/6, Batch Loss: 336333.5312
# Epoch 68, Batch 6/6, Batch Loss: 424964.9062
# Batch 1/1, Batch Loss: 919910.1250
# Test Error:
#  Avg loss: 919910.125000, Avg error: 335643.428571
#
# Epoch 69, Batch 1/6, Batch Loss: 347640.7500
# Epoch 69, Batch 2/6, Batch Loss: 273031.7812
# Epoch 69, Batch 3/6, Batch Loss: 312671.4062
# Epoch 69, Batch 4/6, Batch Loss: 477905.1875
# Epoch 69, Batch 5/6, Batch Loss: 359198.0312
# Epoch 69, Batch 6/6, Batch Loss: 370505.1875
# Batch 1/1, Batch Loss: 880020.8125
# Test Error:
#  Avg loss: 880020.812500, Avg error: 295066.693878
#
# Epoch 70, Batch 1/6, Batch Loss: 427289.5312
# Epoch 70, Batch 2/6, Batch Loss: 311812.8438
# Epoch 70, Batch 3/6, Batch Loss: 236077.0312
# Epoch 70, Batch 4/6, Batch Loss: 276242.0000
# Epoch 70, Batch 5/6, Batch Loss: 315306.5625
# Epoch 70, Batch 6/6, Batch Loss: 463609.3125
# Batch 1/1, Batch Loss: 903579.1250
# Test Error:
#  Avg loss: 903579.125000, Avg error: 309325.346939
#
# 2024-09-16 03:16:12.061802 Epoch 70, Average Training loss 338389.546875
# Epoch 71, Batch 1/6, Batch Loss: 362500.4062
# Epoch 71, Batch 2/6, Batch Loss: 331419.9062
# Epoch 71, Batch 3/6, Batch Loss: 287770.6875
# Epoch 71, Batch 4/6, Batch Loss: 333495.4688
# Epoch 71, Batch 5/6, Batch Loss: 394512.7500
# Epoch 71, Batch 6/6, Batch Loss: 426701.5625
# Batch 1/1, Batch Loss: 914367.5000
# Test Error:
#  Avg loss: 914367.500000, Avg error: 320648.693878
#
# Epoch 72, Batch 1/6, Batch Loss: 397142.4375
# Epoch 72, Batch 2/6, Batch Loss: 362283.0000
# Epoch 72, Batch 3/6, Batch Loss: 373972.0938
# Epoch 72, Batch 4/6, Batch Loss: 279828.2188
# Epoch 72, Batch 5/6, Batch Loss: 285523.7188
# Epoch 72, Batch 6/6, Batch Loss: 293358.3438
# Batch 1/1, Batch Loss: 899189.7500
# Test Error:
#  Avg loss: 899189.750000, Avg error: 302196.040816
#
# Epoch 73, Batch 1/6, Batch Loss: 424885.3750
# Epoch 73, Batch 2/6, Batch Loss: 351423.2812
# Epoch 73, Batch 3/6, Batch Loss: 344190.0938
# Epoch 73, Batch 4/6, Batch Loss: 258646.9531
# Epoch 73, Batch 5/6, Batch Loss: 266125.9375
# Epoch 73, Batch 6/6, Batch Loss: 292302.7188
# Batch 1/1, Batch Loss: 882218.3750
# Test Error:
#  Avg loss: 882218.375000, Avg error: 289317.795918
#
# Epoch 74, Batch 1/6, Batch Loss: 331969.2500
# Epoch 74, Batch 2/6, Batch Loss: 296462.1875
# Epoch 74, Batch 3/6, Batch Loss: 411744.0312
# Epoch 74, Batch 4/6, Batch Loss: 323517.0938
# Epoch 74, Batch 5/6, Batch Loss: 269856.6875
# Epoch 74, Batch 6/6, Batch Loss: 283849.0312
# Batch 1/1, Batch Loss: 900609.1250
# Test Error:
#  Avg loss: 900609.125000, Avg error: 304089.081633
#
# Epoch 75, Batch 1/6, Batch Loss: 292174.7500
# Epoch 75, Batch 2/6, Batch Loss: 279393.1562
# Epoch 75, Batch 3/6, Batch Loss: 318991.3438
# Epoch 75, Batch 4/6, Batch Loss: 355388.1250
# Epoch 75, Batch 5/6, Batch Loss: 281174.6562
# Epoch 75, Batch 6/6, Batch Loss: 319527.3438
# Batch 1/1, Batch Loss: 891364.0000
# Test Error:
#  Avg loss: 891364.000000, Avg error: 295777.367347
#
# Epoch 76, Batch 1/6, Batch Loss: 380231.0000
# Epoch 76, Batch 2/6, Batch Loss: 315725.0625
# Epoch 76, Batch 3/6, Batch Loss: 287303.0000
# Epoch 76, Batch 4/6, Batch Loss: 438549.2812
# Epoch 76, Batch 5/6, Batch Loss: 294487.5938
# Epoch 76, Batch 6/6, Batch Loss: 299080.2812
# Batch 1/1, Batch Loss: 897841.4375
# Test Error:
#  Avg loss: 897841.437500, Avg error: 300604.775510
#
# Epoch 77, Batch 1/6, Batch Loss: 288209.0312
# Epoch 77, Batch 2/6, Batch Loss: 333821.5312
# Epoch 77, Batch 3/6, Batch Loss: 398255.2812
# Epoch 77, Batch 4/6, Batch Loss: 378045.8750
# Epoch 77, Batch 5/6, Batch Loss: 266832.0312
# Epoch 77, Batch 6/6, Batch Loss: 328172.0000
# Batch 1/1, Batch Loss: 879639.1250
# Test Error:
#  Avg loss: 879639.125000, Avg error: 295380.040816
#
# Epoch 78, Batch 1/6, Batch Loss: 395234.5312
# Epoch 78, Batch 2/6, Batch Loss: 273694.3438
# Epoch 78, Batch 3/6, Batch Loss: 255156.9844
# Epoch 78, Batch 4/6, Batch Loss: 335984.5000
# Epoch 78, Batch 5/6, Batch Loss: 267833.5625
# Epoch 78, Batch 6/6, Batch Loss: 300574.0312
# Batch 1/1, Batch Loss: 893365.0000
# Test Error:
#  Avg loss: 893365.000000, Avg error: 296407.428571
#
# Epoch 79, Batch 1/6, Batch Loss: 283271.9062
# Epoch 79, Batch 2/6, Batch Loss: 347506.3125
# Epoch 79, Batch 3/6, Batch Loss: 249362.7500
# Epoch 79, Batch 4/6, Batch Loss: 283168.5000
# Epoch 79, Batch 5/6, Batch Loss: 331739.6875
# Epoch 79, Batch 6/6, Batch Loss: 307978.0312
# Batch 1/1, Batch Loss: 882665.9375
# Test Error:
#  Avg loss: 882665.937500, Avg error: 287726.693878
#
# Epoch 80, Batch 1/6, Batch Loss: 288292.6250
# Epoch 80, Batch 2/6, Batch Loss: 236111.6562
# Epoch 80, Batch 3/6, Batch Loss: 258185.1562
# Epoch 80, Batch 4/6, Batch Loss: 288671.7188
# Epoch 80, Batch 5/6, Batch Loss: 293606.8438
# Epoch 80, Batch 6/6, Batch Loss: 432653.8438
# Batch 1/1, Batch Loss: 893579.1250
# Test Error:
#  Avg loss: 893579.125000, Avg error: 296828.081633
#
# 2024-09-16 03:17:32.460359 Epoch 80, Average Training loss 299586.9739583333
# Epoch 81, Batch 1/6, Batch Loss: 302942.7188
# Epoch 81, Batch 2/6, Batch Loss: 273639.3438
# Epoch 81, Batch 3/6, Batch Loss: 346017.8125
# Epoch 81, Batch 4/6, Batch Loss: 276934.8125
# Epoch 81, Batch 5/6, Batch Loss: 214602.6719
# Epoch 81, Batch 6/6, Batch Loss: 503190.9375
# Batch 1/1, Batch Loss: 918099.1875
# Test Error:
#  Avg loss: 918099.187500, Avg error: 332944.326531
#
# Epoch 82, Batch 1/6, Batch Loss: 256217.7344
# Epoch 82, Batch 2/6, Batch Loss: 283474.2812
# Epoch 82, Batch 3/6, Batch Loss: 278426.4375
# Epoch 82, Batch 4/6, Batch Loss: 381814.9375
# Epoch 82, Batch 5/6, Batch Loss: 318244.1562
# Epoch 82, Batch 6/6, Batch Loss: 366015.8438
# Batch 1/1, Batch Loss: 879241.3125
# Test Error:
#  Avg loss: 879241.312500, Avg error: 288619.959184
#
# Epoch 83, Batch 1/6, Batch Loss: 243592.2969
# Epoch 83, Batch 2/6, Batch Loss: 389726.4062
# Epoch 83, Batch 3/6, Batch Loss: 349909.1875
# Epoch 83, Batch 4/6, Batch Loss: 306124.5312
# Epoch 83, Batch 5/6, Batch Loss: 318458.2500
# Epoch 83, Batch 6/6, Batch Loss: 330096.2500
# Batch 1/1, Batch Loss: 878848.3750
# Test Error:
#  Avg loss: 878848.375000, Avg error: 289227.551020
#
# Epoch 84, Batch 1/6, Batch Loss: 276060.1250
# Epoch 84, Batch 2/6, Batch Loss: 237821.2656
# Epoch 84, Batch 3/6, Batch Loss: 296436.4375
# Epoch 84, Batch 4/6, Batch Loss: 366023.1875
# Epoch 84, Batch 5/6, Batch Loss: 299002.0625
# Epoch 84, Batch 6/6, Batch Loss: 370740.6562
# Batch 1/1, Batch Loss: 869144.6875
# Test Error:
#  Avg loss: 869144.687500, Avg error: 316070.224490
#
# Epoch 85, Batch 1/6, Batch Loss: 410078.1875
# Epoch 85, Batch 2/6, Batch Loss: 363822.5625
# Epoch 85, Batch 3/6, Batch Loss: 366953.7188
# Epoch 85, Batch 4/6, Batch Loss: 218723.5781
# Epoch 85, Batch 5/6, Batch Loss: 270873.3125
# Epoch 85, Batch 6/6, Batch Loss: 277912.7812
# Batch 1/1, Batch Loss: 909666.5625
# Test Error:
#  Avg loss: 909666.562500, Avg error: 325345.632653
#
# Epoch 86, Batch 1/6, Batch Loss: 317906.1875
# Epoch 86, Batch 2/6, Batch Loss: 310104.3125
# Epoch 86, Batch 3/6, Batch Loss: 318678.1875
# Epoch 86, Batch 4/6, Batch Loss: 274117.5938
# Epoch 86, Batch 5/6, Batch Loss: 291344.2500
# Epoch 86, Batch 6/6, Batch Loss: 401393.6250
# Batch 1/1, Batch Loss: 899364.9375
# Test Error:
#  Avg loss: 899364.937500, Avg error: 306444.285714
#
# Epoch 87, Batch 1/6, Batch Loss: 295375.5312
# Epoch 87, Batch 2/6, Batch Loss: 312213.7812
# Epoch 87, Batch 3/6, Batch Loss: 305024.0312
# Epoch 87, Batch 4/6, Batch Loss: 458070.1875
# Epoch 87, Batch 5/6, Batch Loss: 262476.0000
# Epoch 87, Batch 6/6, Batch Loss: 267812.6562
# Batch 1/1, Batch Loss: 897473.8750
# Test Error:
#  Avg loss: 897473.875000, Avg error: 305139.265306
#
# Epoch 88, Batch 1/6, Batch Loss: 269966.9375
# Epoch 88, Batch 2/6, Batch Loss: 336756.4062
# Epoch 88, Batch 3/6, Batch Loss: 226029.2031
# Epoch 88, Batch 4/6, Batch Loss: 312610.6562
# Epoch 88, Batch 5/6, Batch Loss: 314170.0000
# Epoch 88, Batch 6/6, Batch Loss: 322449.5625
# Batch 1/1, Batch Loss: 878617.7500
# Test Error:
#  Avg loss: 878617.750000, Avg error: 292439.510204
#
# Epoch 89, Batch 1/6, Batch Loss: 296410.6562
# Epoch 89, Batch 2/6, Batch Loss: 320924.5312
# Epoch 89, Batch 3/6, Batch Loss: 352677.7188
# Epoch 89, Batch 4/6, Batch Loss: 273887.4688
# Epoch 89, Batch 5/6, Batch Loss: 286822.9375
# Epoch 89, Batch 6/6, Batch Loss: 343994.0938
# Batch 1/1, Batch Loss: 872620.8750
# Test Error:
#  Avg loss: 872620.875000, Avg error: 300251.795918
#
# Epoch 90, Batch 1/6, Batch Loss: 300453.0625
# Epoch 90, Batch 2/6, Batch Loss: 271783.8750
# Epoch 90, Batch 3/6, Batch Loss: 271758.3125
# Epoch 90, Batch 4/6, Batch Loss: 376909.2812
# Epoch 90, Batch 5/6, Batch Loss: 271386.9688
# Epoch 90, Batch 6/6, Batch Loss: 247756.7188
# Batch 1/1, Batch Loss: 883530.8750
# Test Error:
#  Avg loss: 883530.875000, Avg error: 298848.653061
#
# 2024-09-16 03:18:50.736753 Epoch 90, Average Training loss 290008.0364583333
# Epoch 91, Batch 1/6, Batch Loss: 362848.6562
# Epoch 91, Batch 2/6, Batch Loss: 277470.5625
# Epoch 91, Batch 3/6, Batch Loss: 342111.3125
# Epoch 91, Batch 4/6, Batch Loss: 292221.1250
# Epoch 91, Batch 5/6, Batch Loss: 305564.6250
# Epoch 91, Batch 6/6, Batch Loss: 279780.8125
# Batch 1/1, Batch Loss: 903482.1250
# Test Error:
#  Avg loss: 903482.125000, Avg error: 315333.591837
#
# Epoch 92, Batch 1/6, Batch Loss: 261790.6562
# Epoch 92, Batch 2/6, Batch Loss: 231399.0000
# Epoch 92, Batch 3/6, Batch Loss: 304698.6875
# Epoch 92, Batch 4/6, Batch Loss: 333239.9375
# Epoch 92, Batch 5/6, Batch Loss: 264786.1562
# Epoch 92, Batch 6/6, Batch Loss: 317306.9062
# Batch 1/1, Batch Loss: 917021.3125
# Test Error:
#  Avg loss: 917021.312500, Avg error: 331039.061224
#
# Epoch 93, Batch 1/6, Batch Loss: 223277.5625
# Epoch 93, Batch 2/6, Batch Loss: 224451.2188
# Epoch 93, Batch 3/6, Batch Loss: 287052.7188
# Epoch 93, Batch 4/6, Batch Loss: 336822.1875
# Epoch 93, Batch 5/6, Batch Loss: 235494.4375
# Epoch 93, Batch 6/6, Batch Loss: 239720.0312
# Batch 1/1, Batch Loss: 897652.5000
# Test Error:
#  Avg loss: 897652.500000, Avg error: 309496.693878
#
# Epoch 94, Batch 1/6, Batch Loss: 317978.0625
# Epoch 94, Batch 2/6, Batch Loss: 268456.0000
# Epoch 94, Batch 3/6, Batch Loss: 230561.4688
# Epoch 94, Batch 4/6, Batch Loss: 280773.8125
# Epoch 94, Batch 5/6, Batch Loss: 278192.8750
# Epoch 94, Batch 6/6, Batch Loss: 297018.7812
# Batch 1/1, Batch Loss: 886073.9375
# Test Error:
#  Avg loss: 886073.937500, Avg error: 307381.714286
#
# Epoch 95, Batch 1/6, Batch Loss: 322628.2500
# Epoch 95, Batch 2/6, Batch Loss: 220161.5625
# Epoch 95, Batch 3/6, Batch Loss: 224752.3750
# Epoch 95, Batch 4/6, Batch Loss: 221935.4062
# Epoch 95, Batch 5/6, Batch Loss: 215881.8125
# Epoch 95, Batch 6/6, Batch Loss: 314428.4062
# Batch 1/1, Batch Loss: 873577.3750
# Test Error:
#  Avg loss: 873577.375000, Avg error: 340194.346939
#
# Epoch 96, Batch 1/6, Batch Loss: 315066.3438
# Epoch 96, Batch 2/6, Batch Loss: 223986.7656
# Epoch 96, Batch 3/6, Batch Loss: 326640.8750
# Epoch 96, Batch 4/6, Batch Loss: 323403.7812
# Epoch 96, Batch 5/6, Batch Loss: 231355.9375
# Epoch 96, Batch 6/6, Batch Loss: 193085.1406
# Batch 1/1, Batch Loss: 880239.7500
# Test Error:
#  Avg loss: 880239.750000, Avg error: 306958.857143
#
# Epoch 97, Batch 1/6, Batch Loss: 293299.4375
# Epoch 97, Batch 2/6, Batch Loss: 295722.0625
# Epoch 97, Batch 3/6, Batch Loss: 237923.8750
# Epoch 97, Batch 4/6, Batch Loss: 200850.5000
# Epoch 97, Batch 5/6, Batch Loss: 211677.7969
# Epoch 97, Batch 6/6, Batch Loss: 195013.3750
# Batch 1/1, Batch Loss: 902882.1875
# Test Error:
#  Avg loss: 902882.187500, Avg error: 312322.387755
#
# Epoch 98, Batch 1/6, Batch Loss: 204278.1562
# Epoch 98, Batch 2/6, Batch Loss: 228678.7656
# Epoch 98, Batch 3/6, Batch Loss: 245188.6719
# Epoch 98, Batch 4/6, Batch Loss: 292590.2812
# Epoch 98, Batch 5/6, Batch Loss: 258855.0625
# Epoch 98, Batch 6/6, Batch Loss: 289029.8125
# Batch 1/1, Batch Loss: 909622.7500
# Test Error:
#  Avg loss: 909622.750000, Avg error: 319172.367347
#
# Epoch 99, Batch 1/6, Batch Loss: 274399.4062
# Epoch 99, Batch 2/6, Batch Loss: 173023.1719
# Epoch 99, Batch 3/6, Batch Loss: 250008.3125
# Epoch 99, Batch 4/6, Batch Loss: 203320.9062
# Epoch 99, Batch 5/6, Batch Loss: 193658.0156
# Epoch 99, Batch 6/6, Batch Loss: 255692.1562
# Batch 1/1, Batch Loss: 906947.7500
# Test Error:
#  Avg loss: 906947.750000, Avg error: 314979.469388
#
# Epoch 100, Batch 1/6, Batch Loss: 203103.6094
# Epoch 100, Batch 2/6, Batch Loss: 214035.8906
# Epoch 100, Batch 3/6, Batch Loss: 222127.3750
# Epoch 100, Batch 4/6, Batch Loss: 181096.3906
# Epoch 100, Batch 5/6, Batch Loss: 248474.6094
# Epoch 100, Batch 6/6, Batch Loss: 216884.3281
# Batch 1/1, Batch Loss: 894964.3125
# Test Error:
#  Avg loss: 894964.312500, Avg error: 322863.408163
#
# 2024-09-16 03:20:10.940734 Epoch 100, Average Training loss 214287.03385416666
# Epoch 101, Batch 1/6, Batch Loss: 205263.3750
# Epoch 101, Batch 2/6, Batch Loss: 232408.7500
# Epoch 101, Batch 3/6, Batch Loss: 243005.5781
# Epoch 101, Batch 4/6, Batch Loss: 229558.9531
# Epoch 101, Batch 5/6, Batch Loss: 251727.0156
# Epoch 101, Batch 6/6, Batch Loss: 232952.5156
# Batch 1/1, Batch Loss: 923725.8125
# Test Error:
#  Avg loss: 923725.812500, Avg error: 333407.673469
#
# Epoch 102, Batch 1/6, Batch Loss: 201226.0156
# Epoch 102, Batch 2/6, Batch Loss: 160623.9219
# Epoch 102, Batch 3/6, Batch Loss: 268581.0000
# Epoch 102, Batch 4/6, Batch Loss: 197298.6562
# Epoch 102, Batch 5/6, Batch Loss: 199433.3750
# Epoch 102, Batch 6/6, Batch Loss: 221631.4531
# Batch 1/1, Batch Loss: 908384.1875
# Test Error:
#  Avg loss: 908384.187500, Avg error: 323447.122449
#
# Epoch 103, Batch 1/6, Batch Loss: 227687.2031
# Epoch 103, Batch 2/6, Batch Loss: 188855.0469
# Epoch 103, Batch 3/6, Batch Loss: 181542.3750
# Epoch 103, Batch 4/6, Batch Loss: 219071.9219
# Epoch 103, Batch 5/6, Batch Loss: 184855.9062
# Epoch 103, Batch 6/6, Batch Loss: 185537.1406
# Batch 1/1, Batch Loss: 918533.6875
# Test Error:
#  Avg loss: 918533.687500, Avg error: 329074.816327
#
# Epoch 104, Batch 1/6, Batch Loss: 181281.7812
# Epoch 104, Batch 2/6, Batch Loss: 187116.5469
# Epoch 104, Batch 3/6, Batch Loss: 181487.5469
# Epoch 104, Batch 4/6, Batch Loss: 173442.6250
# Epoch 104, Batch 5/6, Batch Loss: 238343.5469
# Epoch 104, Batch 6/6, Batch Loss: 246942.1562
# Batch 1/1, Batch Loss: 917582.6250
# Test Error:
#  Avg loss: 917582.625000, Avg error: 326194.000000
#
# Epoch 105, Batch 1/6, Batch Loss: 164202.0156
# Epoch 105, Batch 2/6, Batch Loss: 169778.2188
# Epoch 105, Batch 3/6, Batch Loss: 201445.4844
# Epoch 105, Batch 4/6, Batch Loss: 203457.0156
# Epoch 105, Batch 5/6, Batch Loss: 164031.7031
# Epoch 105, Batch 6/6, Batch Loss: 205997.9531
# Batch 1/1, Batch Loss: 906880.1250
# Test Error:
#  Avg loss: 906880.125000, Avg error: 367650.081633
#
# Epoch 106, Batch 1/6, Batch Loss: 231671.7500
# Epoch 106, Batch 2/6, Batch Loss: 217832.1562
# Epoch 106, Batch 3/6, Batch Loss: 194461.9219
# Epoch 106, Batch 4/6, Batch Loss: 235345.4688
# Epoch 106, Batch 5/6, Batch Loss: 246978.3906
# Epoch 106, Batch 6/6, Batch Loss: 170148.3438
# Batch 1/1, Batch Loss: 910384.5000
# Test Error:
#  Avg loss: 910384.500000, Avg error: 373790.244898
#
# Epoch 107, Batch 1/6, Batch Loss: 253404.2031
# Epoch 107, Batch 2/6, Batch Loss: 168622.8125
# Epoch 107, Batch 3/6, Batch Loss: 174765.6250
# Epoch 107, Batch 4/6, Batch Loss: 209980.6094
# Epoch 107, Batch 5/6, Batch Loss: 194140.4375
# Epoch 107, Batch 6/6, Batch Loss: 183515.1719
# Batch 1/1, Batch Loss: 907737.4375
# Test Error:
#  Avg loss: 907737.437500, Avg error: 366841.959184
#
# Epoch 108, Batch 1/6, Batch Loss: 247999.0000
# Epoch 108, Batch 2/6, Batch Loss: 170505.9688
# Epoch 108, Batch 3/6, Batch Loss: 188033.9844
# Epoch 108, Batch 4/6, Batch Loss: 206978.0625
# Epoch 108, Batch 5/6, Batch Loss: 206844.0156
# Epoch 108, Batch 6/6, Batch Loss: 185951.0312
# Batch 1/1, Batch Loss: 897838.8125
# Test Error:
#  Avg loss: 897838.812500, Avg error: 346547.510204
#
# Epoch 109, Batch 1/6, Batch Loss: 182633.9219
# Epoch 109, Batch 2/6, Batch Loss: 258680.2656
# Epoch 109, Batch 3/6, Batch Loss: 199020.2031
# Epoch 109, Batch 4/6, Batch Loss: 138043.9375
# Epoch 109, Batch 5/6, Batch Loss: 233833.1094
# Epoch 109, Batch 6/6, Batch Loss: 235330.9688
# Batch 1/1, Batch Loss: 930375.1875
# Test Error:
#  Avg loss: 930375.187500, Avg error: 326212.142857
#
# Epoch 110, Batch 1/6, Batch Loss: 218764.9062
# Epoch 110, Batch 2/6, Batch Loss: 192088.0938
# Epoch 110, Batch 3/6, Batch Loss: 188707.0625
# Epoch 110, Batch 4/6, Batch Loss: 121597.9766
# Epoch 110, Batch 5/6, Batch Loss: 175732.8906
# Epoch 110, Batch 6/6, Batch Loss: 175469.6250
# Batch 1/1, Batch Loss: 928325.0625
# Test Error:
#  Avg loss: 928325.062500, Avg error: 330074.408163
#
# 2024-09-16 03:21:31.984272 Epoch 110, Average Training loss 178726.75911458334
# Epoch 111, Batch 1/6, Batch Loss: 202190.2500
# Epoch 111, Batch 2/6, Batch Loss: 177210.9062
# Epoch 111, Batch 3/6, Batch Loss: 171676.6562
# Epoch 111, Batch 4/6, Batch Loss: 138977.0156
# Epoch 111, Batch 5/6, Batch Loss: 154835.0469
# Epoch 111, Batch 6/6, Batch Loss: 143025.6719
# Batch 1/1, Batch Loss: 920592.5625
# Test Error:
#  Avg loss: 920592.562500, Avg error: 327920.571429
#
# Epoch 112, Batch 1/6, Batch Loss: 161465.8594
# Epoch 112, Batch 2/6, Batch Loss: 128126.2656
# Epoch 112, Batch 3/6, Batch Loss: 206824.2500
# Epoch 112, Batch 4/6, Batch Loss: 124960.1953
# Epoch 112, Batch 5/6, Batch Loss: 216298.0469
# Epoch 112, Batch 6/6, Batch Loss: 191929.5781
# Batch 1/1, Batch Loss: 943654.6250
# Test Error:
#  Avg loss: 943654.625000, Avg error: 361236.244898
#
# Epoch 113, Batch 1/6, Batch Loss: 213743.4062
# Epoch 113, Batch 2/6, Batch Loss: 161193.1719
# Epoch 113, Batch 3/6, Batch Loss: 157395.2031
# Epoch 113, Batch 4/6, Batch Loss: 166603.1250
# Epoch 113, Batch 5/6, Batch Loss: 213235.3906
# Epoch 113, Batch 6/6, Batch Loss: 140331.9062
# Batch 1/1, Batch Loss: 940139.0000
# Test Error:
#  Avg loss: 940139.000000, Avg error: 350607.346939
#
# Epoch 114, Batch 1/6, Batch Loss: 177806.6562
# Epoch 114, Batch 2/6, Batch Loss: 192286.7812
# Epoch 114, Batch 3/6, Batch Loss: 145711.7656
# Epoch 114, Batch 4/6, Batch Loss: 159678.9531
# Epoch 114, Batch 5/6, Batch Loss: 187912.4688
# Epoch 114, Batch 6/6, Batch Loss: 216618.0469
# Batch 1/1, Batch Loss: 911722.5000
# Test Error:
#  Avg loss: 911722.500000, Avg error: 328669.714286
#
# Epoch 115, Batch 1/6, Batch Loss: 144487.9531
# Epoch 115, Batch 2/6, Batch Loss: 255616.4844
# Epoch 115, Batch 3/6, Batch Loss: 182181.8906
# Epoch 115, Batch 4/6, Batch Loss: 204141.7969
# Epoch 115, Batch 5/6, Batch Loss: 163956.1094
# Epoch 115, Batch 6/6, Batch Loss: 151571.1562
# Batch 1/1, Batch Loss: 906232.5000
# Test Error:
#  Avg loss: 906232.500000, Avg error: 342846.244898
#
# Epoch 116, Batch 1/6, Batch Loss: 208274.3281
# Epoch 116, Batch 2/6, Batch Loss: 158213.5312
# Epoch 116, Batch 3/6, Batch Loss: 153451.7812
# Epoch 116, Batch 4/6, Batch Loss: 189588.0781
# Epoch 116, Batch 5/6, Batch Loss: 165532.9531
# Epoch 116, Batch 6/6, Batch Loss: 164344.5781
# Batch 1/1, Batch Loss: 922236.6250
# Test Error:
#  Avg loss: 922236.625000, Avg error: 331646.285714
#
# Epoch 117, Batch 1/6, Batch Loss: 137670.9062
# Epoch 117, Batch 2/6, Batch Loss: 172939.7344
# Epoch 117, Batch 3/6, Batch Loss: 304113.3750
# Epoch 117, Batch 4/6, Batch Loss: 110931.7344
# Epoch 117, Batch 5/6, Batch Loss: 141470.0156
# Epoch 117, Batch 6/6, Batch Loss: 110194.2422
# Batch 1/1, Batch Loss: 917992.1250
# Test Error:
#  Avg loss: 917992.125000, Avg error: 329601.489796
#
# Epoch 118, Batch 1/6, Batch Loss: 139503.0625
# Epoch 118, Batch 2/6, Batch Loss: 131752.4844
# Epoch 118, Batch 3/6, Batch Loss: 158381.7500
# Epoch 118, Batch 4/6, Batch Loss: 117326.6250
# Epoch 118, Batch 5/6, Batch Loss: 131712.5469
# Epoch 118, Batch 6/6, Batch Loss: 157001.8594
# Batch 1/1, Batch Loss: 919286.8750
# Test Error:
#  Avg loss: 919286.875000, Avg error: 327282.510204
#
# Epoch 119, Batch 1/6, Batch Loss: 152418.2969
# Epoch 119, Batch 2/6, Batch Loss: 104576.0781
# Epoch 119, Batch 3/6, Batch Loss: 121461.4688
# Epoch 119, Batch 4/6, Batch Loss: 108471.2422
# Epoch 119, Batch 5/6, Batch Loss: 125713.8516
# Epoch 119, Batch 6/6, Batch Loss: 133252.0469
# Batch 1/1, Batch Loss: 908118.9375
# Test Error:
#  Avg loss: 908118.937500, Avg error: 324810.897959
#
# Epoch 120, Batch 1/6, Batch Loss: 138143.4062
# Epoch 120, Batch 2/6, Batch Loss: 137823.1562
# Epoch 120, Batch 3/6, Batch Loss: 142530.2969
# Epoch 120, Batch 4/6, Batch Loss: 103973.5547
# Epoch 120, Batch 5/6, Batch Loss: 157577.0469
# Epoch 120, Batch 6/6, Batch Loss: 111846.9219
# Batch 1/1, Batch Loss: 919492.8750
# Test Error:
#  Avg loss: 919492.875000, Avg error: 327978.938776
#
# 2024-09-16 03:22:52.193621 Epoch 120, Average Training loss 131982.39713541666
# Epoch 121, Batch 1/6, Batch Loss: 109990.7812
# Epoch 121, Batch 2/6, Batch Loss: 117954.9844
# Epoch 121, Batch 3/6, Batch Loss: 104661.3984
# Epoch 121, Batch 4/6, Batch Loss: 110910.8125
# Epoch 121, Batch 5/6, Batch Loss: 139008.9375
# Epoch 121, Batch 6/6, Batch Loss: 130846.4688
# Batch 1/1, Batch Loss: 920687.7500
# Test Error:
#  Avg loss: 920687.750000, Avg error: 332730.653061
#
# Epoch 122, Batch 1/6, Batch Loss: 93678.3594
# Epoch 122, Batch 2/6, Batch Loss: 112985.0625
# Epoch 122, Batch 3/6, Batch Loss: 129389.9453
# Epoch 122, Batch 4/6, Batch Loss: 136613.3594
# Epoch 122, Batch 5/6, Batch Loss: 98975.3516
# Epoch 122, Batch 6/6, Batch Loss: 97354.8281
# Batch 1/1, Batch Loss: 919812.1250
# Test Error:
#  Avg loss: 919812.125000, Avg error: 336202.653061
#
# Epoch 123, Batch 1/6, Batch Loss: 111942.5234
# Epoch 123, Batch 2/6, Batch Loss: 95626.5312
# Epoch 123, Batch 3/6, Batch Loss: 110103.1484
# Epoch 123, Batch 4/6, Batch Loss: 98031.6328
# Epoch 123, Batch 5/6, Batch Loss: 109026.3594
# Epoch 123, Batch 6/6, Batch Loss: 106526.9141
# Batch 1/1, Batch Loss: 929887.6875
# Test Error:
#  Avg loss: 929887.687500, Avg error: 332295.428571
#
# Epoch 124, Batch 1/6, Batch Loss: 109289.5547
# Epoch 124, Batch 2/6, Batch Loss: 102447.0234
# Epoch 124, Batch 3/6, Batch Loss: 111474.1484
# Epoch 124, Batch 4/6, Batch Loss: 91360.1953
# Epoch 124, Batch 5/6, Batch Loss: 104606.4453
# Epoch 124, Batch 6/6, Batch Loss: 87481.8281
# Batch 1/1, Batch Loss: 920438.0000
# Test Error:
#  Avg loss: 920438.000000, Avg error: 329847.265306
#
# Epoch 125, Batch 1/6, Batch Loss: 102948.7422
# Epoch 125, Batch 2/6, Batch Loss: 89558.6172
# Epoch 125, Batch 3/6, Batch Loss: 130973.0391
# Epoch 125, Batch 4/6, Batch Loss: 86004.3047
# Epoch 125, Batch 5/6, Batch Loss: 124419.8828
# Epoch 125, Batch 6/6, Batch Loss: 108760.3281
# Batch 1/1, Batch Loss: 916398.5000
# Test Error:
#  Avg loss: 916398.500000, Avg error: 324978.775510
#
# Epoch 126, Batch 1/6, Batch Loss: 112541.7656
# Epoch 126, Batch 2/6, Batch Loss: 146652.8281
# Epoch 126, Batch 3/6, Batch Loss: 140711.1250
# Epoch 126, Batch 4/6, Batch Loss: 109757.0938
# Epoch 126, Batch 5/6, Batch Loss: 122034.9688
# Epoch 126, Batch 6/6, Batch Loss: 101084.9766
# Batch 1/1, Batch Loss: 914821.5000
# Test Error:
#  Avg loss: 914821.500000, Avg error: 321743.061224
#
# Epoch 127, Batch 1/6, Batch Loss: 88717.5156
# Epoch 127, Batch 2/6, Batch Loss: 88515.0469
# Epoch 127, Batch 3/6, Batch Loss: 109020.8125
# Epoch 127, Batch 4/6, Batch Loss: 92498.9609
# Epoch 127, Batch 5/6, Batch Loss: 100153.4922
# Epoch 127, Batch 6/6, Batch Loss: 85532.5000
# Batch 1/1, Batch Loss: 920341.6875
# Test Error:
#  Avg loss: 920341.687500, Avg error: 329449.142857
#
# Epoch 128, Batch 1/6, Batch Loss: 84476.1953
# Epoch 128, Batch 2/6, Batch Loss: 117353.5938
# Epoch 128, Batch 3/6, Batch Loss: 101924.8906
# Epoch 128, Batch 4/6, Batch Loss: 91877.2109
# Epoch 128, Batch 5/6, Batch Loss: 91586.8516
# Epoch 128, Batch 6/6, Batch Loss: 118181.8359
# Batch 1/1, Batch Loss: 905408.0000
# Test Error:
#  Avg loss: 905408.000000, Avg error: 332740.836735
#
# Epoch 129, Batch 1/6, Batch Loss: 105562.9219
# Epoch 129, Batch 2/6, Batch Loss: 102718.8438
# Epoch 129, Batch 3/6, Batch Loss: 166854.9375
# Epoch 129, Batch 4/6, Batch Loss: 112363.5234
# Epoch 129, Batch 5/6, Batch Loss: 116177.6328
# Epoch 129, Batch 6/6, Batch Loss: 168487.3750
# Batch 1/1, Batch Loss: 914600.1875
# Test Error:
#  Avg loss: 914600.187500, Avg error: 333666.285714
#
# Epoch 130, Batch 1/6, Batch Loss: 109654.3438
# Epoch 130, Batch 2/6, Batch Loss: 138176.2969
# Epoch 130, Batch 3/6, Batch Loss: 120550.9141
# Epoch 130, Batch 4/6, Batch Loss: 88176.5078
# Epoch 130, Batch 5/6, Batch Loss: 99193.8594
# Epoch 130, Batch 6/6, Batch Loss: 93130.7266
# Batch 1/1, Batch Loss: 915032.6250
# Test Error:
#  Avg loss: 915032.625000, Avg error: 334019.346939
#
# 2024-09-16 03:24:12.184719 Epoch 130, Average Training loss 108147.10807291667
# Epoch 131, Batch 1/6, Batch Loss: 92247.4688
# Epoch 131, Batch 2/6, Batch Loss: 84202.6875
# Epoch 131, Batch 3/6, Batch Loss: 94401.1328
# Epoch 131, Batch 4/6, Batch Loss: 101437.2266
# Epoch 131, Batch 5/6, Batch Loss: 102637.8047
# Epoch 131, Batch 6/6, Batch Loss: 116268.1250
# Batch 1/1, Batch Loss: 904762.0000
# Test Error:
#  Avg loss: 904762.000000, Avg error: 326338.163265
#
# ...
#
# Epoch 459, Batch 1/6, Batch Loss: 72722.3828
# Epoch 459, Batch 2/6, Batch Loss: 108339.5625
# Epoch 459, Batch 3/6, Batch Loss: 86240.0781
# Epoch 459, Batch 4/6, Batch Loss: 55815.2695
# Epoch 459, Batch 5/6, Batch Loss: 55115.7930
# Epoch 459, Batch 6/6, Batch Loss: 74964.7422
# Batch 1/1, Batch Loss: 906855.5625
# Test Error:
#  Avg loss: 906855.562500, Avg error: 340747.510204
#
# Epoch 460, Batch 1/6, Batch Loss: 83886.5000
# Epoch 460, Batch 2/6, Batch Loss: 60940.5430
# Epoch 460, Batch 3/6, Batch Loss: 56061.8789
# Epoch 460, Batch 4/6, Batch Loss: 69249.7891
# Epoch 460, Batch 5/6, Batch Loss: 61676.6055
# Epoch 460, Batch 6/6, Batch Loss: 47914.3711
# Batch 1/1, Batch Loss: 914581.0000
# Test Error:
#  Avg loss: 914581.000000, Avg error: 340283.795918
#
# 2024-09-16 04:08:19.167081 Epoch 460, Average Training loss 63288.28125
# Epoch 461, Batch 1/6, Batch Loss: 75469.7656
# Epoch 461, Batch 2/6, Batch Loss: 51763.5586
# Epoch 461, Batch 3/6, Batch Loss: 62583.4336
# Epoch 461, Batch 4/6, Batch Loss: 48534.5391
# Epoch 461, Batch 5/6, Batch Loss: 43332.2422
# Epoch 461, Batch 6/6, Batch Loss: 43565.3008
# Batch 1/1, Batch Loss: 915200.3125
# Test Error:
#  Avg loss: 915200.312500, Avg error: 338369.571429
#
# Epoch 462, Batch 1/6, Batch Loss: 55089.9922
# Epoch 462, Batch 2/6, Batch Loss: 59497.6250
# Epoch 462, Batch 3/6, Batch Loss: 49308.0898
# Epoch 462, Batch 4/6, Batch Loss: 82311.6250
# Epoch 462, Batch 5/6, Batch Loss: 38813.9453
# Epoch 462, Batch 6/6, Batch Loss: 67840.1953
# Batch 1/1, Batch Loss: 904944.1875
# Test Error:
#  Avg loss: 904944.187500, Avg error: 335697.183673
#
# Epoch 463, Batch 1/6, Batch Loss: 76408.7656
# Epoch 463, Batch 2/6, Batch Loss: 48070.7070
# Epoch 463, Batch 3/6, Batch Loss: 52776.8828
# Epoch 463, Batch 4/6, Batch Loss: 67922.1484
# Epoch 463, Batch 5/6, Batch Loss: 72497.2500
# Epoch 463, Batch 6/6, Batch Loss: 54186.0586
# Batch 1/1, Batch Loss: 912820.2500
# Test Error:
#  Avg loss: 912820.250000, Avg error: 337178.244898
#
# Epoch 464, Batch 1/6, Batch Loss: 50190.0742
# Epoch 464, Batch 2/6, Batch Loss: 59366.2461
# Epoch 464, Batch 3/6, Batch Loss: 64674.1719
# Epoch 464, Batch 4/6, Batch Loss: 43234.8828
# Epoch 464, Batch 5/6, Batch Loss: 85026.1016
# Epoch 464, Batch 6/6, Batch Loss: 66302.1016
# Batch 1/1, Batch Loss: 921298.8750
# Test Error:
#  Avg loss: 921298.875000, Avg error: 340440.387755
#
# Epoch 465, Batch 1/6, Batch Loss: 54324.0781
# Epoch 465, Batch 2/6, Batch Loss: 63238.1406
# Epoch 465, Batch 3/6, Batch Loss: 57032.9062
# Epoch 465, Batch 4/6, Batch Loss: 45214.4023
# Epoch 465, Batch 5/6, Batch Loss: 51884.4688
# Epoch 465, Batch 6/6, Batch Loss: 53386.8945
# Batch 1/1, Batch Loss: 926705.1250
# Test Error:
#  Avg loss: 926705.125000, Avg error: 343611.755102
#
# Epoch 466, Batch 1/6, Batch Loss: 62798.3516
# Epoch 466, Batch 2/6, Batch Loss: 51409.0234
# Epoch 466, Batch 3/6, Batch Loss: 73144.1797
# Epoch 466, Batch 4/6, Batch Loss: 69957.1719
# Epoch 466, Batch 5/6, Batch Loss: 48519.4453
# Epoch 466, Batch 6/6, Batch Loss: 61805.2500
# Batch 1/1, Batch Loss: 920466.6875
# Test Error:
#  Avg loss: 920466.687500, Avg error: 339917.836735
#
# Epoch 467, Batch 1/6, Batch Loss: 64307.7695
# Epoch 467, Batch 2/6, Batch Loss: 57075.8633
# Epoch 467, Batch 3/6, Batch Loss: 49091.6289
# Epoch 467, Batch 4/6, Batch Loss: 47936.2461
# Epoch 467, Batch 5/6, Batch Loss: 35144.3242
# Epoch 467, Batch 6/6, Batch Loss: 50571.6172
# Batch 1/1, Batch Loss: 926754.3125
# Test Error:
#  Avg loss: 926754.312500, Avg error: 346245.306122
#
# Epoch 468, Batch 1/6, Batch Loss: 65045.2812
# Epoch 468, Batch 2/6, Batch Loss: 38765.8750
# Epoch 468, Batch 3/6, Batch Loss: 50616.5742
# Epoch 468, Batch 4/6, Batch Loss: 77098.5078
# Epoch 468, Batch 5/6, Batch Loss: 44760.1914
# Epoch 468, Batch 6/6, Batch Loss: 69061.7812
# Batch 1/1, Batch Loss: 931712.5000
# Test Error:
#  Avg loss: 931712.500000, Avg error: 349192.734694
#
# Epoch 469, Batch 1/6, Batch Loss: 73983.1797
# Epoch 469, Batch 2/6, Batch Loss: 57798.4688
# Epoch 469, Batch 3/6, Batch Loss: 51639.4883
# Epoch 469, Batch 4/6, Batch Loss: 76229.8359
# Epoch 469, Batch 5/6, Batch Loss: 59510.9297
# Epoch 469, Batch 6/6, Batch Loss: 42171.1406
# Batch 1/1, Batch Loss: 924630.8125
# Test Error:
#  Avg loss: 924630.812500, Avg error: 341397.836735
#
# Epoch 470, Batch 1/6, Batch Loss: 56787.7070
# Epoch 470, Batch 2/6, Batch Loss: 70068.7344
# Epoch 470, Batch 3/6, Batch Loss: 53948.2773
# Epoch 470, Batch 4/6, Batch Loss: 55312.6914
# Epoch 470, Batch 5/6, Batch Loss: 62761.6055
# Epoch 470, Batch 6/6, Batch Loss: 74481.3516
# Batch 1/1, Batch Loss: 917450.2500
# Test Error:
#  Avg loss: 917450.250000, Avg error: 336443.938776
#
# 2024-09-16 04:09:42.060729 Epoch 470, Average Training loss 62226.727864583336
# Epoch 471, Batch 1/6, Batch Loss: 49530.4453
# Epoch 471, Batch 2/6, Batch Loss: 86593.2266
# Epoch 471, Batch 3/6, Batch Loss: 82203.7109
# Epoch 471, Batch 4/6, Batch Loss: 46989.8359
# Epoch 471, Batch 5/6, Batch Loss: 53404.9609
# Epoch 471, Batch 6/6, Batch Loss: 68752.1641
# Batch 1/1, Batch Loss: 913344.4375
# Test Error:
#  Avg loss: 913344.437500, Avg error: 333947.102041
#
# Epoch 472, Batch 1/6, Batch Loss: 50020.6094
# Epoch 472, Batch 2/6, Batch Loss: 63709.6289
# Epoch 472, Batch 3/6, Batch Loss: 45816.7852
# Epoch 472, Batch 4/6, Batch Loss: 56146.9023
# Epoch 472, Batch 5/6, Batch Loss: 56533.6953
# Epoch 472, Batch 6/6, Batch Loss: 54517.8242
# Batch 1/1, Batch Loss: 920964.9375
# Test Error:
#  Avg loss: 920964.937500, Avg error: 341400.061224
#
# Epoch 473, Batch 1/6, Batch Loss: 47848.5469
# Epoch 473, Batch 2/6, Batch Loss: 33714.9883
# Epoch 473, Batch 3/6, Batch Loss: 45427.4922
# Epoch 473, Batch 4/6, Batch Loss: 67634.8750
# Epoch 473, Batch 5/6, Batch Loss: 43251.3398
# Epoch 473, Batch 6/6, Batch Loss: 58363.5898
# Batch 1/1, Batch Loss: 920735.6875
# Test Error:
#  Avg loss: 920735.687500, Avg error: 341228.571429
#
# Epoch 474, Batch 1/6, Batch Loss: 58825.6992
# Epoch 474, Batch 2/6, Batch Loss: 48772.1367
# Epoch 474, Batch 3/6, Batch Loss: 50601.9883
# Epoch 474, Batch 4/6, Batch Loss: 49104.0430
# Epoch 474, Batch 5/6, Batch Loss: 42085.5898
# Epoch 474, Batch 6/6, Batch Loss: 48563.2734
# Batch 1/1, Batch Loss: 920739.8750
# Test Error:
#  Avg loss: 920739.875000, Avg error: 338951.469388
#
# Epoch 475, Batch 1/6, Batch Loss: 41490.7695
# Epoch 475, Batch 2/6, Batch Loss: 54965.9062
# Epoch 475, Batch 3/6, Batch Loss: 38724.9336
# Epoch 475, Batch 4/6, Batch Loss: 61621.8789
# Epoch 475, Batch 5/6, Batch Loss: 45729.2617
# Epoch 475, Batch 6/6, Batch Loss: 51105.1758
# Batch 1/1, Batch Loss: 920203.7500
# Test Error:
#  Avg loss: 920203.750000, Avg error: 342646.612245
#
# Epoch 476, Batch 1/6, Batch Loss: 46363.4258
# Epoch 476, Batch 2/6, Batch Loss: 51638.9453
# Epoch 476, Batch 3/6, Batch Loss: 46887.8984
# Epoch 476, Batch 4/6, Batch Loss: 50461.9336
# Epoch 476, Batch 5/6, Batch Loss: 61304.0703
# Epoch 476, Batch 6/6, Batch Loss: 55161.6406
# Batch 1/1, Batch Loss: 923163.5625
# Test Error:
#  Avg loss: 923163.562500, Avg error: 345021.102041
#
# Epoch 477, Batch 1/6, Batch Loss: 51200.6680
# Epoch 477, Batch 2/6, Batch Loss: 64506.7188
# Epoch 477, Batch 3/6, Batch Loss: 39896.8125
# Epoch 477, Batch 4/6, Batch Loss: 83168.6719
# Epoch 477, Batch 5/6, Batch Loss: 44094.6992
# Epoch 477, Batch 6/6, Batch Loss: 57474.4688
# Batch 1/1, Batch Loss: 917554.3125
# Test Error:
#  Avg loss: 917554.312500, Avg error: 336907.571429
#
# Epoch 478, Batch 1/6, Batch Loss: 58791.6055
# Epoch 478, Batch 2/6, Batch Loss: 64426.6211
# Epoch 478, Batch 3/6, Batch Loss: 56666.8594
# Epoch 478, Batch 4/6, Batch Loss: 38119.7617
# Epoch 478, Batch 5/6, Batch Loss: 61354.2188
# Epoch 478, Batch 6/6, Batch Loss: 58941.8281
# Batch 1/1, Batch Loss: 917843.3125
# Test Error:
#  Avg loss: 917843.312500, Avg error: 339027.714286
#
# Epoch 479, Batch 1/6, Batch Loss: 39229.0156
# Epoch 479, Batch 2/6, Batch Loss: 60852.5938
# Epoch 479, Batch 3/6, Batch Loss: 46918.2109
# Epoch 479, Batch 4/6, Batch Loss: 52534.8320
# Epoch 479, Batch 5/6, Batch Loss: 58993.0039
# Epoch 479, Batch 6/6, Batch Loss: 54898.9414
# Batch 1/1, Batch Loss: 919273.6250
# Test Error:
#  Avg loss: 919273.625000, Avg error: 339475.346939
#
# Epoch 480, Batch 1/6, Batch Loss: 44160.7266
# Epoch 480, Batch 2/6, Batch Loss: 40131.2227
# Epoch 480, Batch 3/6, Batch Loss: 41821.3984
# Epoch 480, Batch 4/6, Batch Loss: 51190.0977
# Epoch 480, Batch 5/6, Batch Loss: 54086.9141
# Epoch 480, Batch 6/6, Batch Loss: 50779.4922
# Batch 1/1, Batch Loss: 914948.3750
# Test Error:
#  Avg loss: 914948.375000, Avg error: 332193.897959
#
# 2024-09-16 04:11:04.549935 Epoch 480, Average Training loss 47028.30859375
# Epoch 481, Batch 1/6, Batch Loss: 65482.2812
# Epoch 481, Batch 2/6, Batch Loss: 45922.5039
# Epoch 481, Batch 3/6, Batch Loss: 47495.0547
# Epoch 481, Batch 4/6, Batch Loss: 71631.5000
# Epoch 481, Batch 5/6, Batch Loss: 42701.5703
# Epoch 481, Batch 6/6, Batch Loss: 47525.6172
# Batch 1/1, Batch Loss: 918578.1250
# Test Error:
#  Avg loss: 918578.125000, Avg error: 339538.795918
#
# Epoch 482, Batch 1/6, Batch Loss: 52221.8438
# Epoch 482, Batch 2/6, Batch Loss: 53899.6016
# Epoch 482, Batch 3/6, Batch Loss: 50787.3164
# Epoch 482, Batch 4/6, Batch Loss: 43486.1016
# Epoch 482, Batch 5/6, Batch Loss: 49358.4805
# Epoch 482, Batch 6/6, Batch Loss: 76640.5938
# Batch 1/1, Batch Loss: 921028.2500
# Test Error:
#  Avg loss: 921028.250000, Avg error: 340660.775510
#
# Epoch 483, Batch 1/6, Batch Loss: 56434.7930
# Epoch 483, Batch 2/6, Batch Loss: 60563.9844
# Epoch 483, Batch 3/6, Batch Loss: 46323.1211
# Epoch 483, Batch 4/6, Batch Loss: 56102.9844
# Epoch 483, Batch 5/6, Batch Loss: 54047.2930
# Epoch 483, Batch 6/6, Batch Loss: 40590.8984
# Batch 1/1, Batch Loss: 916799.0625
# Test Error:
#  Avg loss: 916799.062500, Avg error: 338622.122449
#
# Epoch 484, Batch 1/6, Batch Loss: 48668.5859
# Epoch 484, Batch 2/6, Batch Loss: 55638.7734
# Epoch 484, Batch 3/6, Batch Loss: 69687.1406
# Epoch 484, Batch 4/6, Batch Loss: 44592.3398
# Epoch 484, Batch 5/6, Batch Loss: 66479.0547
# Epoch 484, Batch 6/6, Batch Loss: 54162.3008
# Batch 1/1, Batch Loss: 910531.4375
# Test Error:
#  Avg loss: 910531.437500, Avg error: 333329.469388
#
# Epoch 485, Batch 1/6, Batch Loss: 73927.5156
# Epoch 485, Batch 2/6, Batch Loss: 57195.9492
# Epoch 485, Batch 3/6, Batch Loss: 59036.3477
# Epoch 485, Batch 4/6, Batch Loss: 64568.1055
# Epoch 485, Batch 5/6, Batch Loss: 54801.5625
# Epoch 485, Batch 6/6, Batch Loss: 41476.5977
# Batch 1/1, Batch Loss: 907144.0000
# Test Error:
#  Avg loss: 907144.000000, Avg error: 335759.142857
#
# Epoch 486, Batch 1/6, Batch Loss: 69394.2266
# Epoch 486, Batch 2/6, Batch Loss: 52525.9688
# Epoch 486, Batch 3/6, Batch Loss: 42759.4492
# Epoch 486, Batch 4/6, Batch Loss: 51520.3008
# Epoch 486, Batch 5/6, Batch Loss: 74504.4922
# Epoch 486, Batch 6/6, Batch Loss: 59114.1719
# Batch 1/1, Batch Loss: 913677.6875
# Test Error:
#  Avg loss: 913677.687500, Avg error: 337112.387755
#
# Epoch 487, Batch 1/6, Batch Loss: 56236.5352
# Epoch 487, Batch 2/6, Batch Loss: 63283.4883
# Epoch 487, Batch 3/6, Batch Loss: 75834.5391
# Epoch 487, Batch 4/6, Batch Loss: 44313.3281
# Epoch 487, Batch 5/6, Batch Loss: 53970.1562
# Epoch 487, Batch 6/6, Batch Loss: 58953.3281
# Batch 1/1, Batch Loss: 924432.6875
# Test Error:
#  Avg loss: 924432.687500, Avg error: 341573.020408
#
# Epoch 488, Batch 1/6, Batch Loss: 42477.0078
# Epoch 488, Batch 2/6, Batch Loss: 57444.7695
# Epoch 488, Batch 3/6, Batch Loss: 58917.9453
# Epoch 488, Batch 4/6, Batch Loss: 50085.5352
# Epoch 488, Batch 5/6, Batch Loss: 89514.7578
# Epoch 488, Batch 6/6, Batch Loss: 42231.0664
# Batch 1/1, Batch Loss: 925729.5625
# Test Error:
#  Avg loss: 925729.562500, Avg error: 344026.530612
#
# Epoch 489, Batch 1/6, Batch Loss: 47229.0195
# Epoch 489, Batch 2/6, Batch Loss: 47018.1758
# Epoch 489, Batch 3/6, Batch Loss: 43986.4609
# Epoch 489, Batch 4/6, Batch Loss: 54931.7539
# Epoch 489, Batch 5/6, Batch Loss: 42119.0586
# Epoch 489, Batch 6/6, Batch Loss: 43794.0430
# Batch 1/1, Batch Loss: 926217.0000
# Test Error:
#  Avg loss: 926217.000000, Avg error: 343913.510204
#
# Epoch 490, Batch 1/6, Batch Loss: 72665.9141
# Epoch 490, Batch 2/6, Batch Loss: 84910.2266
# Epoch 490, Batch 3/6, Batch Loss: 55806.9453
# Epoch 490, Batch 4/6, Batch Loss: 63981.4336
# Epoch 490, Batch 5/6, Batch Loss: 54169.6641
# Epoch 490, Batch 6/6, Batch Loss: 45016.1992
# Batch 1/1, Batch Loss: 917678.4375
# Test Error:
#  Avg loss: 917678.437500, Avg error: 337557.632653
#
# 2024-09-16 04:12:26.336798 Epoch 490, Average Training loss 62758.397135416664
# Epoch 491, Batch 1/6, Batch Loss: 52491.6836
# Epoch 491, Batch 2/6, Batch Loss: 53892.5742
# Epoch 491, Batch 3/6, Batch Loss: 53885.0078
# Epoch 491, Batch 4/6, Batch Loss: 50907.2109
# Epoch 491, Batch 5/6, Batch Loss: 51773.9844
# Epoch 491, Batch 6/6, Batch Loss: 50042.4883
# Batch 1/1, Batch Loss: 922351.2500
# Test Error:
#  Avg loss: 922351.250000, Avg error: 342086.244898
#
# Epoch 492, Batch 1/6, Batch Loss: 47077.1367
# Epoch 492, Batch 2/6, Batch Loss: 54323.4531
# Epoch 492, Batch 3/6, Batch Loss: 54235.9570
# Epoch 492, Batch 4/6, Batch Loss: 51018.8672
# Epoch 492, Batch 5/6, Batch Loss: 52250.2031
# Epoch 492, Batch 6/6, Batch Loss: 52255.0156
# Batch 1/1, Batch Loss: 923661.0625
# Test Error:
#  Avg loss: 923661.062500, Avg error: 343317.265306
#
# Epoch 493, Batch 1/6, Batch Loss: 59911.2891
# Epoch 493, Batch 2/6, Batch Loss: 47995.0469
# Epoch 493, Batch 3/6, Batch Loss: 48935.0625
# Epoch 493, Batch 4/6, Batch Loss: 58649.0117
# Epoch 493, Batch 5/6, Batch Loss: 41967.8789
# Epoch 493, Batch 6/6, Batch Loss: 55173.1133
# Batch 1/1, Batch Loss: 918603.7500
# Test Error:
#  Avg loss: 918603.750000, Avg error: 337343.020408
#
# Epoch 494, Batch 1/6, Batch Loss: 46564.6445
# Epoch 494, Batch 2/6, Batch Loss: 50009.8516
# Epoch 494, Batch 3/6, Batch Loss: 51918.3086
# Epoch 494, Batch 4/6, Batch Loss: 48917.2539
# Epoch 494, Batch 5/6, Batch Loss: 56054.2695
# Epoch 494, Batch 6/6, Batch Loss: 60955.0898
# Batch 1/1, Batch Loss: 923852.5000
# Test Error:
#  Avg loss: 923852.500000, Avg error: 342304.612245
#
# Epoch 495, Batch 1/6, Batch Loss: 64672.2852
# Epoch 495, Batch 2/6, Batch Loss: 60551.6445
# Epoch 495, Batch 3/6, Batch Loss: 60259.3320
# Epoch 495, Batch 4/6, Batch Loss: 51262.7266
# Epoch 495, Batch 5/6, Batch Loss: 69764.2422
# Epoch 495, Batch 6/6, Batch Loss: 38583.8164
# Batch 1/1, Batch Loss: 924380.1875
# Test Error:
#  Avg loss: 924380.187500, Avg error: 342589.102041
#
# Epoch 496, Batch 1/6, Batch Loss: 68790.6172
# Epoch 496, Batch 2/6, Batch Loss: 58475.0703
# Epoch 496, Batch 3/6, Batch Loss: 49647.5898
# Epoch 496, Batch 4/6, Batch Loss: 40994.9648
# Epoch 496, Batch 5/6, Batch Loss: 33073.7539
# Epoch 496, Batch 6/6, Batch Loss: 57208.1445
# Batch 1/1, Batch Loss: 924553.1250
# Test Error:
#  Avg loss: 924553.125000, Avg error: 339229.795918
#
# Epoch 497, Batch 1/6, Batch Loss: 51073.6562
# Epoch 497, Batch 2/6, Batch Loss: 43684.9844
# Epoch 497, Batch 3/6, Batch Loss: 47053.8398
# Epoch 497, Batch 4/6, Batch Loss: 38113.2148
# Epoch 497, Batch 5/6, Batch Loss: 55881.0586
# Epoch 497, Batch 6/6, Batch Loss: 60416.3477
# Batch 1/1, Batch Loss: 919499.3125
# Test Error:
#  Avg loss: 919499.312500, Avg error: 332520.653061
#
# Epoch 498, Batch 1/6, Batch Loss: 53456.9844
# Epoch 498, Batch 2/6, Batch Loss: 46300.2070
# Epoch 498, Batch 3/6, Batch Loss: 44861.8398
# Epoch 498, Batch 4/6, Batch Loss: 52557.9375
# Epoch 498, Batch 5/6, Batch Loss: 55587.9141
# Epoch 498, Batch 6/6, Batch Loss: 69873.7422
# Batch 1/1, Batch Loss: 917922.8125
# Test Error:
#  Avg loss: 917922.812500, Avg error: 334700.612245
#
# Epoch 499, Batch 1/6, Batch Loss: 44044.2070
# Epoch 499, Batch 2/6, Batch Loss: 50360.8516
# Epoch 499, Batch 3/6, Batch Loss: 69153.4531
# Epoch 499, Batch 4/6, Batch Loss: 50999.0664
# Epoch 499, Batch 5/6, Batch Loss: 50290.9258
# Epoch 499, Batch 6/6, Batch Loss: 41256.8320
# Batch 1/1, Batch Loss: 918849.5000
# Test Error:
#  Avg loss: 918849.500000, Avg error: 340366.653061
#
# Epoch 500, Batch 1/6, Batch Loss: 68438.0938
# Epoch 500, Batch 2/6, Batch Loss: 40698.1680
# Epoch 500, Batch 3/6, Batch Loss: 48452.5039
# Epoch 500, Batch 4/6, Batch Loss: 47272.3086
# Epoch 500, Batch 5/6, Batch Loss: 46401.7227
# Epoch 500, Batch 6/6, Batch Loss: 55548.3242
# Batch 1/1, Batch Loss: 917380.1250
# Test Error:
#  Avg loss: 917380.125000, Avg error: 337997.428571
#
# 2024-09-16 04:13:47.460355 Epoch 500, Average Training loss 51135.186848958336

# %%
import matplotlib.pyplot as plt

# Graficar las pérdidas
plt.plot(range(1, n_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, n_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
